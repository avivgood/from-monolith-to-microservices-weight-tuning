# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'shopizer-2x' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "RuoYi-Vue"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# Logic		JwtAuthenticationTokenFilter		com.ruoyi.framework.security.filter
# Excluded	LogoutSuccessHandlerImpl		com.ruoyi.framework.security.handle
# Logic		AuthenticationEntryPointImpl		com.ruoyi.framework.security.handle
# Entity		AuthenticationContextHolder		com.ruoyi.framework.security.context
# Entity		PermissionContextHolder		com.ruoyi.framework.security.context
# Excluded	ThreadPoolConfig		com.ruoyi.framework.config
# Excluded	SecurityConfig		com.ruoyi.framework.config
# Excluded	ResourcesConfig		com.ruoyi.framework.config
# Excluded	RedisConfig		com.ruoyi.framework.config
# Excluded	I18nConfig		com.ruoyi.framework.config
# Logic		ServerConfig		com.ruoyi.framework.config
# Excluded	DruidConfig		com.ruoyi.framework.config
# Entity		FastJson2JsonRedisSerializer		com.ruoyi.framework.config
# Excluded	FilterConfig		com.ruoyi.framework.config
# Entity		KaptchaTextCreator		com.ruoyi.framework.config
# Excluded	MyBatisConfig		com.ruoyi.framework.config
# Excluded	ApplicationConfig		com.ruoyi.framework.config
# Excluded	CaptchaConfig		com.ruoyi.framework.config
# Excluded	DruidProperties		com.ruoyi.framework.config.properties
# Excluded	PermitAllUrlProperties		com.ruoyi.framework.config.properties
# Logic		RepeatSubmitInterceptor		com.ruoyi.framework.interceptor
# Logic		SameUrlDataInterceptor		com.ruoyi.framework.interceptor.impl
# Logic		LogAspect		com.ruoyi.framework.aspectj
# Logic		DataScopeAspect		com.ruoyi.framework.aspectj
# Logic		DataSourceAspect		com.ruoyi.framework.aspectj
# Logic		RateLimiterAspect		com.ruoyi.framework.aspectj
# Entity		AsyncManager		com.ruoyi.framework.manager
# Logic		ShutdownManager		com.ruoyi.framework.manager
# Entity		AsyncFactory		com.ruoyi.framework.manager.factory
# Logic		SysPasswordService		com.ruoyi.framework.web.service
# Logic		SysPermissionService		com.ruoyi.framework.web.service
# Logic		TokenService		com.ruoyi.framework.web.service
# Logic		UserDetailsServiceImpl		com.ruoyi.framework.web.service
# Logic		PermissionService		com.ruoyi.framework.web.service
# Logic		SysRegisterService		com.ruoyi.framework.web.service
# Logic		SysLoginService		com.ruoyi.framework.web.service
# Entity		Server		com.ruoyi.framework.web.domain
# Entity		Mem		com.ruoyi.framework.web.domain.server
# Entity		Sys		com.ruoyi.framework.web.domain.server
# Entity		Jvm		com.ruoyi.framework.web.domain.server
# Entity		SysFile		com.ruoyi.framework.web.domain.server
# Entity		Cpu		com.ruoyi.framework.web.domain.server
# Entity		GlobalExceptionHandler		com.ruoyi.framework.web.exception
# Entity		DynamicDataSource		com.ruoyi.framework.datasource
# Entity		DynamicDataSourceContextHolder		com.ruoyi.framework.datasource
# Entity		RuoYiServletInitializer		com.ruoyi
# Excluded	RuoYiApplication		com.ruoyi
# Excluded	SwaggerConfig		com.ruoyi.web.core.config
# Logic		SysOperlogController		com.ruoyi.web.controller.monitor
# Logic		SysLogininforController		com.ruoyi.web.controller.monitor
# Logic		CacheController		com.ruoyi.web.controller.monitor
# Logic		ServerController		com.ruoyi.web.controller.monitor
# Logic		SysUserOnlineController		com.ruoyi.web.controller.monitor
# Logic		TestController		com.ruoyi.web.controller.tool
# Entity		UserEntity		com.ruoyi.web.controller.tool
# Logic		CommonController		com.ruoyi.web.controller.common
# Logic		CaptchaController		com.ruoyi.web.controller.common
# Logic		SysNoticeController		com.ruoyi.web.controller.system
# Logic		SysConfigController		com.ruoyi.web.controller.system
# Logic		SysUserController		com.ruoyi.web.controller.system
# Logic		SysPostController		com.ruoyi.web.controller.system
# Logic		SysMenuController		com.ruoyi.web.controller.system
# Logic		SysRoleController		com.ruoyi.web.controller.system
# Logic		SysRegisterController		com.ruoyi.web.controller.system
# Logic		SysProfileController		com.ruoyi.web.controller.system
# Logic		SysDictDataController		com.ruoyi.web.controller.system
# Logic		SysDeptController		com.ruoyi.web.controller.system
# Logic		SysDictTypeController		com.ruoyi.web.controller.system
# Logic		SysIndexController		com.ruoyi.web.controller.system
# Logic		SysLoginController		com.ruoyi.web.controller.system
# Interface	ISysDictTypeService		com.ruoyi.system.service
# Interface	ISysRoleService		com.ruoyi.system.service
# Interface	ISysNoticeService		com.ruoyi.system.service
# Interface	ISysPostService		com.ruoyi.system.service
# Interface	ISysUserService		com.ruoyi.system.service
# Interface	ISysDictDataService		com.ruoyi.system.service
# Interface	ISysMenuService		com.ruoyi.system.service
# Interface	ISysConfigService		com.ruoyi.system.service
# Interface	ISysLogininforService		com.ruoyi.system.service
# Interface	ISysOperLogService		com.ruoyi.system.service
# Interface	ISysDeptService		com.ruoyi.system.service
# Interface	ISysUserOnlineService		com.ruoyi.system.service
# Logic		SysDeptServiceImpl		com.ruoyi.system.service.impl
# Logic		SysUserServiceImpl		com.ruoyi.system.service.impl
# Logic		SysPostServiceImpl		com.ruoyi.system.service.impl
# Logic		SysDictTypeServiceImpl		com.ruoyi.system.service.impl
# Logic		SysOperLogServiceImpl		com.ruoyi.system.service.impl
# Logic		SysUserOnlineServiceImpl		com.ruoyi.system.service.impl
# Logic		SysLogininforServiceImpl		com.ruoyi.system.service.impl
# Logic		SysNoticeServiceImpl		com.ruoyi.system.service.impl
# Logic		SysConfigServiceImpl		com.ruoyi.system.service.impl
# Logic		SysRoleServiceImpl		com.ruoyi.system.service.impl
# Logic		SysDictDataServiceImpl		com.ruoyi.system.service.impl
# Logic		SysMenuServiceImpl		com.ruoyi.system.service.impl
# Entity		SysUserOnline		com.ruoyi.system.domain
# Entity		SysRoleMenu		com.ruoyi.system.domain
# Entity		SysCache		com.ruoyi.system.domain
# Entity		SysUserPost		com.ruoyi.system.domain
# Entity		SysLogininfor		com.ruoyi.system.domain
# Entity		SysRoleDept		com.ruoyi.system.domain
# Entity		SysPost		com.ruoyi.system.domain
# Entity		SysConfig		com.ruoyi.system.domain
# Entity		SysNotice		com.ruoyi.system.domain
# Entity		SysOperLog		com.ruoyi.system.domain
# Entity		SysUserRole		com.ruoyi.system.domain
# Entity		MetaVo		com.ruoyi.system.domain.vo
# Entity		RouterVo		com.ruoyi.system.domain.vo
# Interface	SysPostMapper		com.ruoyi.system.mapper
# Interface	SysUserMapper		com.ruoyi.system.mapper
# Interface	SysDictDataMapper		com.ruoyi.system.mapper
# Interface	SysDictTypeMapper		com.ruoyi.system.mapper
# Interface	SysRoleDeptMapper		com.ruoyi.system.mapper
# Interface	SysMenuMapper		com.ruoyi.system.mapper
# Interface	SysDeptMapper		com.ruoyi.system.mapper
# Interface	SysRoleMapper		com.ruoyi.system.mapper
# Interface	SysUserPostMapper		com.ruoyi.system.mapper
# Interface	SysOperLogMapper		com.ruoyi.system.mapper
# Interface	SysLogininforMapper		com.ruoyi.system.mapper
# Interface	SysNoticeMapper		com.ruoyi.system.mapper
# Interface	SysRoleMenuMapper		com.ruoyi.system.mapper
# Interface	SysUserRoleMapper		com.ruoyi.system.mapper
# Interface	SysConfigMapper		com.ruoyi.system.mapper
# Entity		XssValidator		com.ruoyi.common.xss
# Entity		XssHttpServletRequestWrapper		com.ruoyi.common.filter
# Entity		RepeatedlyRequestWrapper		com.ruoyi.common.filter
# Entity		RepeatableFilter		com.ruoyi.common.filter
# Entity		XssFilter		com.ruoyi.common.filter
# Entity		PropertyPreExcludeFilter		com.ruoyi.common.filter
# Logic		RedisCache		com.ruoyi.common.core.redis
# Entity		BaseEntity		com.ruoyi.common.core.domain
# Entity		R		com.ruoyi.common.core.domain
# Entity		TreeSelect		com.ruoyi.common.core.domain
# Entity		AjaxResult		com.ruoyi.common.core.domain
# Entity		TreeEntity		com.ruoyi.common.core.domain
# Entity		LoginBody		com.ruoyi.common.core.domain.model
# Entity		RegisterBody		com.ruoyi.common.core.domain.model
# Entity		LoginUser		com.ruoyi.common.core.domain.model
# Entity		SysUser		com.ruoyi.common.core.domain.entity
# Entity		SysDept		com.ruoyi.common.core.domain.entity
# Entity		SysMenu		com.ruoyi.common.core.domain.entity
# Entity		SysDictData		com.ruoyi.common.core.domain.entity
# Entity		SysRole		com.ruoyi.common.core.domain.entity
# Entity		SysDictType		com.ruoyi.common.core.domain.entity
# Entity		BaseController		com.ruoyi.common.core.controller
# Entity		Convert		com.ruoyi.common.core.text
# Entity		StrFormatter		com.ruoyi.common.core.text
# Entity		CharsetKit		com.ruoyi.common.core.text
# Entity		PageDomain		com.ruoyi.common.core.page
# Entity		TableSupport		com.ruoyi.common.core.page
# Entity		TableDataInfo		com.ruoyi.common.core.page
# Entity		DateUtils		com.ruoyi.common.utils
# Entity		ServletUtils		com.ruoyi.common.utils
# Entity		SecurityUtils		com.ruoyi.common.utils
# Entity		DesensitizedUtil		com.ruoyi.common.utils
# Entity		LogUtils		com.ruoyi.common.utils
# Entity		ExceptionUtil		com.ruoyi.common.utils
# Entity		StringUtils		com.ruoyi.common.utils
# Entity		Arith		com.ruoyi.common.utils
# Entity		PageUtils		com.ruoyi.common.utils
# Entity		MessageUtils		com.ruoyi.common.utils
# Entity		DictUtils		com.ruoyi.common.utils
# Entity		Threads		com.ruoyi.common.utils
# Entity		Base64		com.ruoyi.common.utils.sign
# Entity		Md5Utils		com.ruoyi.common.utils.sign
# Entity		MimeTypeUtils		com.ruoyi.common.utils.file
# Entity		FileUtils		com.ruoyi.common.utils.file
# Entity		ImageUtils		com.ruoyi.common.utils.file
# Entity		FileUploadUtils		com.ruoyi.common.utils.file
# Entity		FileTypeUtils		com.ruoyi.common.utils.file
# Entity		SqlUtil		com.ruoyi.common.utils.sql
# Entity		ReflectUtils		com.ruoyi.common.utils.reflect
# Entity		AddressUtils		com.ruoyi.common.utils.ip
# Entity		IpUtils		com.ruoyi.common.utils.ip
# Logic		SpringUtils		com.ruoyi.common.utils.spring
# Entity		EscapeUtil		com.ruoyi.common.utils.html
# Entity		HTMLFilter		com.ruoyi.common.utils.html
# Entity		IdUtils		com.ruoyi.common.utils.uuid
# Entity		Seq		com.ruoyi.common.utils.uuid
# Entity		UUID		com.ruoyi.common.utils.uuid
# Interface	ExcelHandlerAdapter		com.ruoyi.common.utils.poi
# Entity		ExcelUtil		com.ruoyi.common.utils.poi
# Entity		HttpUtils		com.ruoyi.common.utils.http
# Entity		HttpHelper		com.ruoyi.common.utils.http
# Entity		BeanUtils		com.ruoyi.common.utils.bean
# Entity		BeanValidators		com.ruoyi.common.utils.bean
# Logic		RuoYiConfig		com.ruoyi.common.config
# Entity		SensitiveJsonSerializer		com.ruoyi.common.config.serializer
# Entity		UserConstants		com.ruoyi.common.constant
# Entity		GenConstants		com.ruoyi.common.constant
# Entity		Constants		com.ruoyi.common.constant
# Entity		CacheConstants		com.ruoyi.common.constant
# Entity		HttpStatus		com.ruoyi.common.constant
# Entity		ScheduleConstants		com.ruoyi.common.constant
# Entity		GlobalException		com.ruoyi.common.exception
# Entity		ServiceException		com.ruoyi.common.exception
# Entity		UtilException		com.ruoyi.common.exception
# Entity		DemoModeException		com.ruoyi.common.exception
# Entity		FileNameLengthLimitExceededException		com.ruoyi.common.exception.file
# Entity		FileException		com.ruoyi.common.exception.file
# Entity		FileSizeLimitExceededException		com.ruoyi.common.exception.file
# Entity		InvalidExtensionException		com.ruoyi.common.exception.file
# Entity		FileUploadException		com.ruoyi.common.exception.file
# Entity		UserException		com.ruoyi.common.exception.user
# Entity		UserPasswordNotMatchException		com.ruoyi.common.exception.user
# Entity		CaptchaException		com.ruoyi.common.exception.user
# Entity		CaptchaExpireException		com.ruoyi.common.exception.user
# Entity		BlackListException		com.ruoyi.common.exception.user
# Entity		UserNotExistsException		com.ruoyi.common.exception.user
# Entity		UserPasswordRetryLimitExceedException		com.ruoyi.common.exception.user
# Entity		TaskException		com.ruoyi.common.exception.job
# Entity		BaseException		com.ruoyi.common.exception.base

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		AuthenticationContextHolder		com.ruoyi.framework.security.context
# Entity		PermissionContextHolder		com.ruoyi.framework.security.context
# Entity		FastJson2JsonRedisSerializer		com.ruoyi.framework.config
# Entity		KaptchaTextCreator		com.ruoyi.framework.config
# Entity		AsyncManager		com.ruoyi.framework.manager
# Entity		AsyncFactory		com.ruoyi.framework.manager.factory
# Entity		Server		com.ruoyi.framework.web.domain
# Entity		Mem		com.ruoyi.framework.web.domain.server
# Entity		Sys		com.ruoyi.framework.web.domain.server
# Entity		Jvm		com.ruoyi.framework.web.domain.server
# Entity		SysFile		com.ruoyi.framework.web.domain.server
# Entity		Cpu		com.ruoyi.framework.web.domain.server
# Entity		GlobalExceptionHandler		com.ruoyi.framework.web.exception
# Entity		DynamicDataSource		com.ruoyi.framework.datasource
# Entity		DynamicDataSourceContextHolder		com.ruoyi.framework.datasource
# Entity		RuoYiServletInitializer		com.ruoyi
# Entity		UserEntity		com.ruoyi.web.controller.tool
# Entity		SysUserOnline		com.ruoyi.system.domain
# Entity		SysRoleMenu		com.ruoyi.system.domain
# Entity		SysCache		com.ruoyi.system.domain
# Entity		SysUserPost		com.ruoyi.system.domain
# Entity		SysLogininfor		com.ruoyi.system.domain
# Entity		SysRoleDept		com.ruoyi.system.domain
# Entity		SysPost		com.ruoyi.system.domain
# Entity		SysConfig		com.ruoyi.system.domain
# Entity		SysNotice		com.ruoyi.system.domain
# Entity		SysOperLog		com.ruoyi.system.domain
# Entity		SysUserRole		com.ruoyi.system.domain
# Entity		MetaVo		com.ruoyi.system.domain.vo
# Entity		RouterVo		com.ruoyi.system.domain.vo
# Entity		XssValidator		com.ruoyi.common.xss
# Entity		XssHttpServletRequestWrapper		com.ruoyi.common.filter
# Entity		RepeatedlyRequestWrapper		com.ruoyi.common.filter
# Entity		RepeatableFilter		com.ruoyi.common.filter
# Entity		XssFilter		com.ruoyi.common.filter
# Entity		PropertyPreExcludeFilter		com.ruoyi.common.filter
# Entity		BaseEntity		com.ruoyi.common.core.domain
# Entity		R		com.ruoyi.common.core.domain
# Entity		TreeSelect		com.ruoyi.common.core.domain
# Entity		AjaxResult		com.ruoyi.common.core.domain
# Entity		TreeEntity		com.ruoyi.common.core.domain
# Entity		LoginBody		com.ruoyi.common.core.domain.model
# Entity		RegisterBody		com.ruoyi.common.core.domain.model
# Entity		LoginUser		com.ruoyi.common.core.domain.model
# Entity		SysUser		com.ruoyi.common.core.domain.entity
# Entity		SysDept		com.ruoyi.common.core.domain.entity
# Entity		SysMenu		com.ruoyi.common.core.domain.entity
# Entity		SysDictData		com.ruoyi.common.core.domain.entity
# Entity		SysRole		com.ruoyi.common.core.domain.entity
# Entity		SysDictType		com.ruoyi.common.core.domain.entity
# Entity		BaseController		com.ruoyi.common.core.controller
# Entity		Convert		com.ruoyi.common.core.text
# Entity		StrFormatter		com.ruoyi.common.core.text
# Entity		CharsetKit		com.ruoyi.common.core.text
# Entity		PageDomain		com.ruoyi.common.core.page
# Entity		TableSupport		com.ruoyi.common.core.page
# Entity		TableDataInfo		com.ruoyi.common.core.page
# Entity		DateUtils		com.ruoyi.common.utils
# Entity		ServletUtils		com.ruoyi.common.utils
# Entity		SecurityUtils		com.ruoyi.common.utils
# Entity		DesensitizedUtil		com.ruoyi.common.utils
# Entity		LogUtils		com.ruoyi.common.utils
# Entity		ExceptionUtil		com.ruoyi.common.utils
# Entity		StringUtils		com.ruoyi.common.utils
# Entity		Arith		com.ruoyi.common.utils
# Entity		PageUtils		com.ruoyi.common.utils
# Entity		MessageUtils		com.ruoyi.common.utils
# Entity		DictUtils		com.ruoyi.common.utils
# Entity		Threads		com.ruoyi.common.utils
# Entity		Base64		com.ruoyi.common.utils.sign
# Entity		Md5Utils		com.ruoyi.common.utils.sign
# Entity		MimeTypeUtils		com.ruoyi.common.utils.file
# Entity		FileUtils		com.ruoyi.common.utils.file
# Entity		ImageUtils		com.ruoyi.common.utils.file
# Entity		FileUploadUtils		com.ruoyi.common.utils.file
# Entity		FileTypeUtils		com.ruoyi.common.utils.file
# Entity		SqlUtil		com.ruoyi.common.utils.sql
# Entity		ReflectUtils		com.ruoyi.common.utils.reflect
# Entity		AddressUtils		com.ruoyi.common.utils.ip
# Entity		IpUtils		com.ruoyi.common.utils.ip
# Entity		EscapeUtil		com.ruoyi.common.utils.html
# Entity		HTMLFilter		com.ruoyi.common.utils.html
# Entity		IdUtils		com.ruoyi.common.utils.uuid
# Entity		Seq		com.ruoyi.common.utils.uuid
# Entity		UUID		com.ruoyi.common.utils.uuid
# Entity		ExcelUtil		com.ruoyi.common.utils.poi
# Entity		HttpUtils		com.ruoyi.common.utils.http
# Entity		HttpHelper		com.ruoyi.common.utils.http
# Entity		BeanUtils		com.ruoyi.common.utils.bean
# Entity		BeanValidators		com.ruoyi.common.utils.bean
# Entity		SensitiveJsonSerializer		com.ruoyi.common.config.serializer
# Entity		UserConstants		com.ruoyi.common.constant
# Entity		GenConstants		com.ruoyi.common.constant
# Entity		Constants		com.ruoyi.common.constant
# Entity		CacheConstants		com.ruoyi.common.constant
# Entity		HttpStatus		com.ruoyi.common.constant
# Entity		ScheduleConstants		com.ruoyi.common.constant
# Entity		GlobalException		com.ruoyi.common.exception
# Entity		ServiceException		com.ruoyi.common.exception
# Entity		UtilException		com.ruoyi.common.exception
# Entity		DemoModeException		com.ruoyi.common.exception
# Entity		FileNameLengthLimitExceededException		com.ruoyi.common.exception.file
# Entity		FileException		com.ruoyi.common.exception.file
# Entity		FileSizeLimitExceededException		com.ruoyi.common.exception.file
# Entity		InvalidExtensionException		com.ruoyi.common.exception.file
# Entity		FileUploadException		com.ruoyi.common.exception.file
# Entity		UserException		com.ruoyi.common.exception.user
# Entity		UserPasswordNotMatchException		com.ruoyi.common.exception.user
# Entity		CaptchaException		com.ruoyi.common.exception.user
# Entity		CaptchaExpireException		com.ruoyi.common.exception.user
# Entity		BlackListException		com.ruoyi.common.exception.user
# Entity		UserNotExistsException		com.ruoyi.common.exception.user
# Entity		UserPasswordRetryLimitExceedException		com.ruoyi.common.exception.user
# Entity		TaskException		com.ruoyi.common.exception.job
# Entity		BaseException		com.ruoyi.common.exception.base
# Logic		JwtAuthenticationTokenFilter		com.ruoyi.framework.security.filter
# Logic		AuthenticationEntryPointImpl		com.ruoyi.framework.security.handle
# Logic		ServerConfig		com.ruoyi.framework.config
# Logic		RepeatSubmitInterceptor		com.ruoyi.framework.interceptor
# Logic		SameUrlDataInterceptor		com.ruoyi.framework.interceptor.impl
# Logic		LogAspect		com.ruoyi.framework.aspectj
# Logic		DataScopeAspect		com.ruoyi.framework.aspectj
# Logic		DataSourceAspect		com.ruoyi.framework.aspectj
# Logic		RateLimiterAspect		com.ruoyi.framework.aspectj
# Logic		ShutdownManager		com.ruoyi.framework.manager
# Logic		SysPasswordService		com.ruoyi.framework.web.service
# Logic		SysPermissionService		com.ruoyi.framework.web.service
# Logic		TokenService		com.ruoyi.framework.web.service
# Logic		UserDetailsServiceImpl		com.ruoyi.framework.web.service
# Logic		PermissionService		com.ruoyi.framework.web.service
# Logic		SysRegisterService		com.ruoyi.framework.web.service
# Logic		SysLoginService		com.ruoyi.framework.web.service
# Logic		SysOperlogController		com.ruoyi.web.controller.monitor
# Logic		SysLogininforController		com.ruoyi.web.controller.monitor
# Logic		CacheController		com.ruoyi.web.controller.monitor
# Logic		ServerController		com.ruoyi.web.controller.monitor
# Logic		SysUserOnlineController		com.ruoyi.web.controller.monitor
# Logic		TestController		com.ruoyi.web.controller.tool
# Logic		CommonController		com.ruoyi.web.controller.common
# Logic		CaptchaController		com.ruoyi.web.controller.common
# Logic		SysNoticeController		com.ruoyi.web.controller.system
# Logic		SysConfigController		com.ruoyi.web.controller.system
# Logic		SysUserController		com.ruoyi.web.controller.system
# Logic		SysPostController		com.ruoyi.web.controller.system
# Logic		SysMenuController		com.ruoyi.web.controller.system
# Logic		SysRoleController		com.ruoyi.web.controller.system
# Logic		SysRegisterController		com.ruoyi.web.controller.system
# Logic		SysProfileController		com.ruoyi.web.controller.system
# Logic		SysDictDataController		com.ruoyi.web.controller.system
# Logic		SysDeptController		com.ruoyi.web.controller.system
# Logic		SysDictTypeController		com.ruoyi.web.controller.system
# Logic		SysIndexController		com.ruoyi.web.controller.system
# Logic		SysLoginController		com.ruoyi.web.controller.system
# Logic		SysDeptServiceImpl		com.ruoyi.system.service.impl
# Logic		SysUserServiceImpl		com.ruoyi.system.service.impl
# Logic		SysPostServiceImpl		com.ruoyi.system.service.impl
# Logic		SysDictTypeServiceImpl		com.ruoyi.system.service.impl
# Logic		SysOperLogServiceImpl		com.ruoyi.system.service.impl
# Logic		SysUserOnlineServiceImpl		com.ruoyi.system.service.impl
# Logic		SysLogininforServiceImpl		com.ruoyi.system.service.impl
# Logic		SysNoticeServiceImpl		com.ruoyi.system.service.impl
# Logic		SysConfigServiceImpl		com.ruoyi.system.service.impl
# Logic		SysRoleServiceImpl		com.ruoyi.system.service.impl
# Logic		SysDictDataServiceImpl		com.ruoyi.system.service.impl
# Logic		SysMenuServiceImpl		com.ruoyi.system.service.impl
# Logic		RedisCache		com.ruoyi.common.core.redis
# Logic		SpringUtils		com.ruoyi.common.utils.spring
# Logic		RuoYiConfig		com.ruoyi.common.config
# Interface	ISysDictTypeService		com.ruoyi.system.service
# Interface	ISysRoleService		com.ruoyi.system.service
# Interface	ISysNoticeService		com.ruoyi.system.service
# Interface	ISysPostService		com.ruoyi.system.service
# Interface	ISysUserService		com.ruoyi.system.service
# Interface	ISysDictDataService		com.ruoyi.system.service
# Interface	ISysMenuService		com.ruoyi.system.service
# Interface	ISysConfigService		com.ruoyi.system.service
# Interface	ISysLogininforService		com.ruoyi.system.service
# Interface	ISysOperLogService		com.ruoyi.system.service
# Interface	ISysDeptService		com.ruoyi.system.service
# Interface	ISysUserOnlineService		com.ruoyi.system.service
# Interface	SysPostMapper		com.ruoyi.system.mapper
# Interface	SysUserMapper		com.ruoyi.system.mapper
# Interface	SysDictDataMapper		com.ruoyi.system.mapper
# Interface	SysDictTypeMapper		com.ruoyi.system.mapper
# Interface	SysRoleDeptMapper		com.ruoyi.system.mapper
# Interface	SysMenuMapper		com.ruoyi.system.mapper
# Interface	SysDeptMapper		com.ruoyi.system.mapper
# Interface	SysRoleMapper		com.ruoyi.system.mapper
# Interface	SysUserPostMapper		com.ruoyi.system.mapper
# Interface	SysOperLogMapper		com.ruoyi.system.mapper
# Interface	SysLogininforMapper		com.ruoyi.system.mapper
# Interface	SysNoticeMapper		com.ruoyi.system.mapper
# Interface	SysRoleMenuMapper		com.ruoyi.system.mapper
# Interface	SysUserRoleMapper		com.ruoyi.system.mapper
# Interface	SysConfigMapper		com.ruoyi.system.mapper
# Interface	ExcelHandlerAdapter		com.ruoyi.common.utils.poi
# Excluded	LogoutSuccessHandlerImpl		com.ruoyi.framework.security.handle
# Excluded	ThreadPoolConfig		com.ruoyi.framework.config
# Excluded	SecurityConfig		com.ruoyi.framework.config
# Excluded	ResourcesConfig		com.ruoyi.framework.config
# Excluded	RedisConfig		com.ruoyi.framework.config
# Excluded	I18nConfig		com.ruoyi.framework.config
# Excluded	DruidConfig		com.ruoyi.framework.config
# Excluded	FilterConfig		com.ruoyi.framework.config
# Excluded	MyBatisConfig		com.ruoyi.framework.config
# Excluded	ApplicationConfig		com.ruoyi.framework.config
# Excluded	CaptchaConfig		com.ruoyi.framework.config
# Excluded	DruidProperties		com.ruoyi.framework.config.properties
# Excluded	PermitAllUrlProperties		com.ruoyi.framework.config.properties
# Excluded	RuoYiApplication		com.ruoyi
# Excluded	SwaggerConfig		com.ruoyi.web.core.config

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')
# Out:
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysDeptMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserPostMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserPostMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserPostMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserPostMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysUserPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysPostMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictTypeMapperinterface does not have an implementing class!
# WARNING: SysOperLogMapperinterface does not have an implementing class!
# WARNING: SysOperLogMapperinterface does not have an implementing class!
# WARNING: SysOperLogMapperinterface does not have an implementing class!
# WARNING: SysOperLogMapperinterface does not have an implementing class!
# WARNING: SysOperLogMapperinterface does not have an implementing class!
# WARNING: SysLogininforMapperinterface does not have an implementing class!
# WARNING: SysLogininforMapperinterface does not have an implementing class!
# WARNING: SysLogininforMapperinterface does not have an implementing class!
# WARNING: SysLogininforMapperinterface does not have an implementing class!
# WARNING: SysNoticeMapperinterface does not have an implementing class!
# WARNING: SysNoticeMapperinterface does not have an implementing class!
# WARNING: SysNoticeMapperinterface does not have an implementing class!
# WARNING: SysNoticeMapperinterface does not have an implementing class!
# WARNING: SysNoticeMapperinterface does not have an implementing class!
# WARNING: SysNoticeMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysConfigMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMenuMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleDeptMapperinterface does not have an implementing class!
# WARNING: SysRoleMenuMapperinterface does not have an implementing class!
# WARNING: SysRoleDeptMapperinterface does not have an implementing class!
# WARNING: SysRoleMenuMapperinterface does not have an implementing class!
# WARNING: SysRoleDeptMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMenuMapperinterface does not have an implementing class!
# WARNING: SysRoleDeptMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysDictDataMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysRoleMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!
# WARNING: SysMenuMapperinterface does not have an implementing class!

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['doFilterInternal(JwtAuthenticationTokenFilter)', 'Calls', 'buildDetails(JwtAuthenticationTokenFilter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['excludePropertyPreFilter(LogAspect)', 'Calls', 'addExcludes(LogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isFilterObject(LogAspect)', 'Calls', 'isAssignableFrom(LogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isFilterObject(LogAspect)', 'Calls', 'isAssignableFrom(LogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysOperlogController)', 'Calls', 'startPage(SysOperlogController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysOperlogController)', 'Calls', 'getDataTable(SysOperlogController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysOperlogController)', 'Calls', 'toAjax(SysOperlogController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['clean(SysOperlogController)', 'Calls', 'success(SysOperlogController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysLogininforController)', 'Calls', 'startPage(SysLogininforController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysLogininforController)', 'Calls', 'getDataTable(SysLogininforController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysLogininforController)', 'Calls', 'toAjax(SysLogininforController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['clean(SysLogininforController)', 'Calls', 'success(SysLogininforController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unlock(SysLogininforController)', 'Calls', 'success(SysLogininforController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysUserOnlineController)', 'Calls', 'getDataTable(SysUserOnlineController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['forceLogout(SysUserOnlineController)', 'Calls', 'success(SysUserOnlineController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userList(TestController)', 'Calls', 'values(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUser(TestController)', 'Calls', 'isEmpty(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUser(TestController)', 'Calls', 'containsKey(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUser(TestController)', 'Calls', 'get(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['save(TestController)', 'Calls', 'put(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['update(TestController)', 'Calls', 'isEmpty(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['update(TestController)', 'Calls', 'containsKey(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['update(TestController)', 'Calls', 'remove(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['update(TestController)', 'Calls', 'put(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(TestController)', 'Calls', 'isEmpty(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(TestController)', 'Calls', 'containsKey(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(TestController)', 'Calls', 'remove(UserEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCode(CaptchaController)', 'Calls', 'equals(CaptchaController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCode(CaptchaController)', 'Calls', 'equals(CaptchaController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysNoticeController)', 'Calls', 'startPage(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysNoticeController)', 'Calls', 'getDataTable(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysNoticeController)', 'Calls', 'success(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysNoticeController)', 'Calls', 'getUsername(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysNoticeController)', 'Calls', 'getUsername(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysConfigController)', 'Calls', 'startPage(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysConfigController)', 'Calls', 'getDataTable(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getConfigKey(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysConfigController)', 'Calls', 'error(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysConfigController)', 'Calls', 'getUsername(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysConfigController)', 'Calls', 'toAjax(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysConfigController)', 'Calls', 'error(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysConfigController)', 'Calls', 'getUsername(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysConfigController)', 'Calls', 'toAjax(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refreshCache(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysUserController)', 'Calls', 'startPage(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysUserController)', 'Calls', 'getDataTable(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['importData(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['importData(SysUserController)', 'Calls', 'success(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysUserController)', 'Calls', 'getUserId(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysUserController)', 'Calls', 'error(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPwd(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPwd(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeStatus(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeStatus(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['insertAuthRole(SysUserController)', 'Calls', 'success(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deptTree(SysUserController)', 'Calls', 'success(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysPostController)', 'Calls', 'startPage(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysPostController)', 'Calls', 'getDataTable(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysPostController)', 'Calls', 'success(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysPostController)', 'Calls', 'error(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysPostController)', 'Calls', 'error(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysPostController)', 'Calls', 'getUsername(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysPostController)', 'Calls', 'toAjax(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysPostController)', 'Calls', 'error(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysPostController)', 'Calls', 'error(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysPostController)', 'Calls', 'getUsername(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysPostController)', 'Calls', 'toAjax(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysPostController)', 'Calls', 'toAjax(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['optionselect(SysPostController)', 'Calls', 'success(SysPostController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysMenuController)', 'Calls', 'success(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysMenuController)', 'Calls', 'success(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['treeselect(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['treeselect(SysMenuController)', 'Calls', 'success(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['roleMenuTreeselect(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysMenuController)', 'Calls', 'getUsername(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'getUsername(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysMenuController)', 'Calls', 'warn(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysMenuController)', 'Calls', 'warn(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysRoleController)', 'Calls', 'success(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'getLoginUser(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'success(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['dataScope(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeStatus(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeStatus(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['optionselect(SysRoleController)', 'Calls', 'success(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['allocatedList(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['allocatedList(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unallocatedList(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unallocatedList(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelAuthUser(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelAuthUserAll(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['selectAuthUserAll(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['register(SysRegisterController)', 'Calls', 'error(SysRegisterController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['register(SysRegisterController)', 'Calls', 'success(SysRegisterController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['register(SysRegisterController)', 'Calls', 'error(SysRegisterController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['profile(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'success(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'success(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['avatar(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['avatar(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysDictDataController)', 'Calls', 'startPage(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysDictDataController)', 'Calls', 'getDataTable(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['dictType(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDictDataController)', 'Calls', 'getUsername(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDictDataController)', 'Calls', 'toAjax(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDictDataController)', 'Calls', 'getUsername(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDictDataController)', 'Calls', 'toAjax(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysDeptController)', 'Calls', 'success(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['excludeChild(SysDeptController)', 'Calls', 'success(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysDeptController)', 'Calls', 'success(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDeptController)', 'Calls', 'getUsername(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'getUsername(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysDeptController)', 'Calls', 'warn(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysDeptController)', 'Calls', 'warn(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysDictTypeController)', 'Calls', 'startPage(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['list(SysDictTypeController)', 'Calls', 'getDataTable(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInfo(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDictTypeController)', 'Calls', 'error(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDictTypeController)', 'Calls', 'getUsername(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(SysDictTypeController)', 'Calls', 'toAjax(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDictTypeController)', 'Calls', 'error(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDictTypeController)', 'Calls', 'getUsername(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysDictTypeController)', 'Calls', 'toAjax(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['remove(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refreshCache(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['optionselect(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildMenus(SysMenuServiceImpl)', 'Calls', 'equals(SysMenuServiceImpl)'] skipped since target method is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['doFilterInternal(JwtAuthenticationTokenFilter)', 'Calls', 'buildDetails(JwtAuthenticationTokenFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['excludePropertyPreFilter(LogAspect)', 'Calls', 'addExcludes(LogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['isFilterObject(LogAspect)', 'Calls', 'isAssignableFrom(LogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['isFilterObject(LogAspect)', 'Calls', 'isAssignableFrom(LogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysOperlogController)', 'Calls', 'startPage(SysOperlogController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysOperlogController)', 'Calls', 'getDataTable(SysOperlogController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysOperlogController)', 'Calls', 'toAjax(SysOperlogController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['clean(SysOperlogController)', 'Calls', 'success(SysOperlogController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysLogininforController)', 'Calls', 'startPage(SysLogininforController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysLogininforController)', 'Calls', 'getDataTable(SysLogininforController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysLogininforController)', 'Calls', 'toAjax(SysLogininforController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['clean(SysLogininforController)', 'Calls', 'success(SysLogininforController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unlock(SysLogininforController)', 'Calls', 'success(SysLogininforController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysUserOnlineController)', 'Calls', 'getDataTable(SysUserOnlineController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['forceLogout(SysUserOnlineController)', 'Calls', 'success(SysUserOnlineController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['userList(TestController)', 'Calls', 'values(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['getUser(TestController)', 'Calls', 'isEmpty(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['getUser(TestController)', 'Calls', 'containsKey(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['getUser(TestController)', 'Calls', 'get(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['save(TestController)', 'Calls', 'put(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['update(TestController)', 'Calls', 'isEmpty(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['update(TestController)', 'Calls', 'containsKey(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['update(TestController)', 'Calls', 'remove(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['update(TestController)', 'Calls', 'put(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['delete(TestController)', 'Calls', 'isEmpty(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['delete(TestController)', 'Calls', 'containsKey(UserEntity)']: discarding
# WARNING: Unable to recover target method for edge ['delete(TestController)', 'Calls', 'remove(UserEntity)']: discarding
# WARNING: unable to recover ['getCode(CaptchaController)', 'Calls', 'equals(CaptchaController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCode(CaptchaController)', 'Calls', 'equals(CaptchaController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysNoticeController)', 'Calls', 'startPage(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysNoticeController)', 'Calls', 'getDataTable(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysNoticeController)', 'Calls', 'success(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysNoticeController)', 'Calls', 'getUsername(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysNoticeController)', 'Calls', 'getUsername(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysConfigController)', 'Calls', 'startPage(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysConfigController)', 'Calls', 'getDataTable(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysConfigController)', 'Calls', 'success(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getConfigKey(SysConfigController)', 'Calls', 'success(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysConfigController)', 'Calls', 'error(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysConfigController)', 'Calls', 'getUsername(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysConfigController)', 'Calls', 'toAjax(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysConfigController)', 'Calls', 'error(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysConfigController)', 'Calls', 'getUsername(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysConfigController)', 'Calls', 'toAjax(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysConfigController)', 'Calls', 'success(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['refreshCache(SysConfigController)', 'Calls', 'success(SysConfigController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysUserController)', 'Calls', 'startPage(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysUserController)', 'Calls', 'getDataTable(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['importData(SysUserController)', 'Calls', 'getUsername(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['importData(SysUserController)', 'Calls', 'success(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysUserController)', 'Calls', 'getUsername(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysUserController)', 'Calls', 'toAjax(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysUserController)', 'Calls', 'getUsername(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysUserController)', 'Calls', 'toAjax(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysUserController)', 'Calls', 'getUserId(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysUserController)', 'Calls', 'error(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysUserController)', 'Calls', 'toAjax(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resetPwd(SysUserController)', 'Calls', 'getUsername(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resetPwd(SysUserController)', 'Calls', 'toAjax(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changeStatus(SysUserController)', 'Calls', 'getUsername(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changeStatus(SysUserController)', 'Calls', 'toAjax(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['insertAuthRole(SysUserController)', 'Calls', 'success(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deptTree(SysUserController)', 'Calls', 'success(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysPostController)', 'Calls', 'startPage(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysPostController)', 'Calls', 'getDataTable(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysPostController)', 'Calls', 'success(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysPostController)', 'Calls', 'error(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysPostController)', 'Calls', 'error(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysPostController)', 'Calls', 'getUsername(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysPostController)', 'Calls', 'toAjax(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysPostController)', 'Calls', 'error(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysPostController)', 'Calls', 'error(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysPostController)', 'Calls', 'getUsername(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysPostController)', 'Calls', 'toAjax(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysPostController)', 'Calls', 'toAjax(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['optionselect(SysPostController)', 'Calls', 'success(SysPostController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysMenuController)', 'Calls', 'success(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysMenuController)', 'Calls', 'success(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['treeselect(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['treeselect(SysMenuController)', 'Calls', 'success(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['roleMenuTreeselect(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysMenuController)', 'Calls', 'error(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysMenuController)', 'Calls', 'error(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysMenuController)', 'Calls', 'getUsername(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysMenuController)', 'Calls', 'getUsername(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysMenuController)', 'Calls', 'warn(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysMenuController)', 'Calls', 'warn(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysRoleController)', 'Calls', 'success(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysRoleController)', 'Calls', 'error(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysRoleController)', 'Calls', 'error(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysRoleController)', 'Calls', 'getLoginUser(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysRoleController)', 'Calls', 'success(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['dataScope(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changeStatus(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changeStatus(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['optionselect(SysRoleController)', 'Calls', 'success(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['allocatedList(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['allocatedList(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unallocatedList(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unallocatedList(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['cancelAuthUser(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['cancelAuthUserAll(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['selectAuthUserAll(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['register(SysRegisterController)', 'Calls', 'error(SysRegisterController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['register(SysRegisterController)', 'Calls', 'success(SysRegisterController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['register(SysRegisterController)', 'Calls', 'error(SysRegisterController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['profile(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateProfile(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateProfile(SysProfileController)', 'Calls', 'success(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePwd(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePwd(SysProfileController)', 'Calls', 'success(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['avatar(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['avatar(SysProfileController)', 'Calls', 'error(SysProfileController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysDictDataController)', 'Calls', 'startPage(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysDictDataController)', 'Calls', 'getDataTable(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['dictType(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDictDataController)', 'Calls', 'getUsername(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDictDataController)', 'Calls', 'toAjax(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDictDataController)', 'Calls', 'getUsername(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDictDataController)', 'Calls', 'toAjax(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysDeptController)', 'Calls', 'success(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['excludeChild(SysDeptController)', 'Calls', 'success(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysDeptController)', 'Calls', 'success(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDeptController)', 'Calls', 'error(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDeptController)', 'Calls', 'getUsername(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDeptController)', 'Calls', 'getUsername(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysDeptController)', 'Calls', 'warn(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysDeptController)', 'Calls', 'warn(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysDictTypeController)', 'Calls', 'startPage(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['list(SysDictTypeController)', 'Calls', 'getDataTable(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInfo(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDictTypeController)', 'Calls', 'error(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDictTypeController)', 'Calls', 'getUsername(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(SysDictTypeController)', 'Calls', 'toAjax(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDictTypeController)', 'Calls', 'error(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDictTypeController)', 'Calls', 'getUsername(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysDictTypeController)', 'Calls', 'toAjax(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['remove(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['refreshCache(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['optionselect(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildMenus(SysMenuServiceImpl)', 'Calls', 'equals(SysMenuServiceImpl)'] since target method may be from a superclass. (Not implemented yet)

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# INFO: Edge ['doFilterInternal(JwtAuthenticationTokenFilter)', 'Calls', 'buildDetails(JwtAuthenticationTokenFilter)'] skipped
# INFO: Edge ['excludePropertyPreFilter(LogAspect)', 'Calls', 'addExcludes(LogAspect)'] skipped
# INFO: Edge ['isFilterObject(LogAspect)', 'Calls', 'isAssignableFrom(LogAspect)'] skipped
# INFO: Edge ['isFilterObject(LogAspect)', 'Calls', 'isAssignableFrom(LogAspect)'] skipped
# INFO: Edge ['list(SysOperlogController)', 'Calls', 'startPage(SysOperlogController)'] skipped
# INFO: Edge ['list(SysOperlogController)', 'Calls', 'getDataTable(SysOperlogController)'] skipped
# INFO: Edge ['remove(SysOperlogController)', 'Calls', 'toAjax(SysOperlogController)'] skipped
# INFO: Edge ['clean(SysOperlogController)', 'Calls', 'success(SysOperlogController)'] skipped
# INFO: Edge ['list(SysLogininforController)', 'Calls', 'startPage(SysLogininforController)'] skipped
# INFO: Edge ['list(SysLogininforController)', 'Calls', 'getDataTable(SysLogininforController)'] skipped
# INFO: Edge ['remove(SysLogininforController)', 'Calls', 'toAjax(SysLogininforController)'] skipped
# INFO: Edge ['clean(SysLogininforController)', 'Calls', 'success(SysLogininforController)'] skipped
# INFO: Edge ['unlock(SysLogininforController)', 'Calls', 'success(SysLogininforController)'] skipped
# INFO: Edge ['list(SysUserOnlineController)', 'Calls', 'getDataTable(SysUserOnlineController)'] skipped
# INFO: Edge ['forceLogout(SysUserOnlineController)', 'Calls', 'success(SysUserOnlineController)'] skipped
# INFO: Edge ['userList(TestController)', 'Calls', 'values(UserEntity)'] skipped
# INFO: Edge ['getUser(TestController)', 'Calls', 'isEmpty(UserEntity)'] skipped
# INFO: Edge ['getUser(TestController)', 'Calls', 'containsKey(UserEntity)'] skipped
# INFO: Edge ['getUser(TestController)', 'Calls', 'get(UserEntity)'] skipped
# INFO: Edge ['save(TestController)', 'Calls', 'put(UserEntity)'] skipped
# INFO: Edge ['update(TestController)', 'Calls', 'isEmpty(UserEntity)'] skipped
# INFO: Edge ['update(TestController)', 'Calls', 'containsKey(UserEntity)'] skipped
# INFO: Edge ['update(TestController)', 'Calls', 'remove(UserEntity)'] skipped
# INFO: Edge ['update(TestController)', 'Calls', 'put(UserEntity)'] skipped
# INFO: Edge ['delete(TestController)', 'Calls', 'isEmpty(UserEntity)'] skipped
# INFO: Edge ['delete(TestController)', 'Calls', 'containsKey(UserEntity)'] skipped
# INFO: Edge ['delete(TestController)', 'Calls', 'remove(UserEntity)'] skipped
# INFO: Edge ['getCode(CaptchaController)', 'Calls', 'equals(CaptchaController)'] skipped
# INFO: Edge ['getCode(CaptchaController)', 'Calls', 'equals(CaptchaController)'] skipped
# INFO: Edge ['list(SysNoticeController)', 'Calls', 'startPage(SysNoticeController)'] skipped
# INFO: Edge ['list(SysNoticeController)', 'Calls', 'getDataTable(SysNoticeController)'] skipped
# INFO: Edge ['getInfo(SysNoticeController)', 'Calls', 'success(SysNoticeController)'] skipped
# INFO: Edge ['add(SysNoticeController)', 'Calls', 'getUsername(SysNoticeController)'] skipped
# INFO: Edge ['add(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] skipped
# INFO: Edge ['edit(SysNoticeController)', 'Calls', 'getUsername(SysNoticeController)'] skipped
# INFO: Edge ['edit(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] skipped
# INFO: Edge ['remove(SysNoticeController)', 'Calls', 'toAjax(SysNoticeController)'] skipped
# INFO: Edge ['list(SysConfigController)', 'Calls', 'startPage(SysConfigController)'] skipped
# INFO: Edge ['list(SysConfigController)', 'Calls', 'getDataTable(SysConfigController)'] skipped
# INFO: Edge ['getInfo(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped
# INFO: Edge ['getConfigKey(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped
# INFO: Edge ['add(SysConfigController)', 'Calls', 'error(SysConfigController)'] skipped
# INFO: Edge ['add(SysConfigController)', 'Calls', 'getUsername(SysConfigController)'] skipped
# INFO: Edge ['add(SysConfigController)', 'Calls', 'toAjax(SysConfigController)'] skipped
# INFO: Edge ['edit(SysConfigController)', 'Calls', 'error(SysConfigController)'] skipped
# INFO: Edge ['edit(SysConfigController)', 'Calls', 'getUsername(SysConfigController)'] skipped
# INFO: Edge ['edit(SysConfigController)', 'Calls', 'toAjax(SysConfigController)'] skipped
# INFO: Edge ['remove(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped
# INFO: Edge ['refreshCache(SysConfigController)', 'Calls', 'success(SysConfigController)'] skipped
# INFO: Edge ['list(SysUserController)', 'Calls', 'startPage(SysUserController)'] skipped
# INFO: Edge ['list(SysUserController)', 'Calls', 'getDataTable(SysUserController)'] skipped
# INFO: Edge ['importData(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped
# INFO: Edge ['importData(SysUserController)', 'Calls', 'success(SysUserController)'] skipped
# INFO: Edge ['add(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['add(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['add(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['add(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped
# INFO: Edge ['add(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped
# INFO: Edge ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['edit(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['edit(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped
# INFO: Edge ['edit(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped
# INFO: Edge ['remove(SysUserController)', 'Calls', 'getUserId(SysUserController)'] skipped
# INFO: Edge ['remove(SysUserController)', 'Calls', 'error(SysUserController)'] skipped
# INFO: Edge ['remove(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped
# INFO: Edge ['resetPwd(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped
# INFO: Edge ['resetPwd(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped
# INFO: Edge ['changeStatus(SysUserController)', 'Calls', 'getUsername(SysUserController)'] skipped
# INFO: Edge ['changeStatus(SysUserController)', 'Calls', 'toAjax(SysUserController)'] skipped
# INFO: Edge ['insertAuthRole(SysUserController)', 'Calls', 'success(SysUserController)'] skipped
# INFO: Edge ['deptTree(SysUserController)', 'Calls', 'success(SysUserController)'] skipped
# INFO: Edge ['list(SysPostController)', 'Calls', 'startPage(SysPostController)'] skipped
# INFO: Edge ['list(SysPostController)', 'Calls', 'getDataTable(SysPostController)'] skipped
# INFO: Edge ['getInfo(SysPostController)', 'Calls', 'success(SysPostController)'] skipped
# INFO: Edge ['add(SysPostController)', 'Calls', 'error(SysPostController)'] skipped
# INFO: Edge ['add(SysPostController)', 'Calls', 'error(SysPostController)'] skipped
# INFO: Edge ['add(SysPostController)', 'Calls', 'getUsername(SysPostController)'] skipped
# INFO: Edge ['add(SysPostController)', 'Calls', 'toAjax(SysPostController)'] skipped
# INFO: Edge ['edit(SysPostController)', 'Calls', 'error(SysPostController)'] skipped
# INFO: Edge ['edit(SysPostController)', 'Calls', 'error(SysPostController)'] skipped
# INFO: Edge ['edit(SysPostController)', 'Calls', 'getUsername(SysPostController)'] skipped
# INFO: Edge ['edit(SysPostController)', 'Calls', 'toAjax(SysPostController)'] skipped
# INFO: Edge ['remove(SysPostController)', 'Calls', 'toAjax(SysPostController)'] skipped
# INFO: Edge ['optionselect(SysPostController)', 'Calls', 'success(SysPostController)'] skipped
# INFO: Edge ['list(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] skipped
# INFO: Edge ['list(SysMenuController)', 'Calls', 'success(SysMenuController)'] skipped
# INFO: Edge ['getInfo(SysMenuController)', 'Calls', 'success(SysMenuController)'] skipped
# INFO: Edge ['treeselect(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] skipped
# INFO: Edge ['treeselect(SysMenuController)', 'Calls', 'success(SysMenuController)'] skipped
# INFO: Edge ['roleMenuTreeselect(SysMenuController)', 'Calls', 'getUserId(SysMenuController)'] skipped
# INFO: Edge ['add(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped
# INFO: Edge ['add(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped
# INFO: Edge ['add(SysMenuController)', 'Calls', 'getUsername(SysMenuController)'] skipped
# INFO: Edge ['add(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] skipped
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'error(SysMenuController)'] skipped
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'getUsername(SysMenuController)'] skipped
# INFO: Edge ['edit(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] skipped
# INFO: Edge ['remove(SysMenuController)', 'Calls', 'warn(SysMenuController)'] skipped
# INFO: Edge ['remove(SysMenuController)', 'Calls', 'warn(SysMenuController)'] skipped
# INFO: Edge ['remove(SysMenuController)', 'Calls', 'toAjax(SysMenuController)'] skipped
# INFO: Edge ['list(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] skipped
# INFO: Edge ['list(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] skipped
# INFO: Edge ['getInfo(SysRoleController)', 'Calls', 'success(SysRoleController)'] skipped
# INFO: Edge ['add(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped
# INFO: Edge ['add(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped
# INFO: Edge ['add(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] skipped
# INFO: Edge ['add(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'getLoginUser(SysRoleController)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'success(SysRoleController)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'error(SysRoleController)'] skipped
# INFO: Edge ['dataScope(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['changeStatus(SysRoleController)', 'Calls', 'getUsername(SysRoleController)'] skipped
# INFO: Edge ['changeStatus(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['remove(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['optionselect(SysRoleController)', 'Calls', 'success(SysRoleController)'] skipped
# INFO: Edge ['allocatedList(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] skipped
# INFO: Edge ['allocatedList(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] skipped
# INFO: Edge ['unallocatedList(SysRoleController)', 'Calls', 'startPage(SysRoleController)'] skipped
# INFO: Edge ['unallocatedList(SysRoleController)', 'Calls', 'getDataTable(SysRoleController)'] skipped
# INFO: Edge ['cancelAuthUser(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['cancelAuthUserAll(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['selectAuthUserAll(SysRoleController)', 'Calls', 'toAjax(SysRoleController)'] skipped
# INFO: Edge ['register(SysRegisterController)', 'Calls', 'error(SysRegisterController)'] skipped
# INFO: Edge ['register(SysRegisterController)', 'Calls', 'success(SysRegisterController)'] skipped
# INFO: Edge ['register(SysRegisterController)', 'Calls', 'error(SysRegisterController)'] skipped
# INFO: Edge ['profile(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'success(SysProfileController)'] skipped
# INFO: Edge ['updateProfile(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'success(SysProfileController)'] skipped
# INFO: Edge ['updatePwd(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['avatar(SysProfileController)', 'Calls', 'getLoginUser(SysProfileController)'] skipped
# INFO: Edge ['avatar(SysProfileController)', 'Calls', 'error(SysProfileController)'] skipped
# INFO: Edge ['list(SysDictDataController)', 'Calls', 'startPage(SysDictDataController)'] skipped
# INFO: Edge ['list(SysDictDataController)', 'Calls', 'getDataTable(SysDictDataController)'] skipped
# INFO: Edge ['getInfo(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] skipped
# INFO: Edge ['dictType(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] skipped
# INFO: Edge ['add(SysDictDataController)', 'Calls', 'getUsername(SysDictDataController)'] skipped
# INFO: Edge ['add(SysDictDataController)', 'Calls', 'toAjax(SysDictDataController)'] skipped
# INFO: Edge ['edit(SysDictDataController)', 'Calls', 'getUsername(SysDictDataController)'] skipped
# INFO: Edge ['edit(SysDictDataController)', 'Calls', 'toAjax(SysDictDataController)'] skipped
# INFO: Edge ['remove(SysDictDataController)', 'Calls', 'success(SysDictDataController)'] skipped
# INFO: Edge ['list(SysDeptController)', 'Calls', 'success(SysDeptController)'] skipped
# INFO: Edge ['excludeChild(SysDeptController)', 'Calls', 'success(SysDeptController)'] skipped
# INFO: Edge ['getInfo(SysDeptController)', 'Calls', 'success(SysDeptController)'] skipped
# INFO: Edge ['add(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped
# INFO: Edge ['add(SysDeptController)', 'Calls', 'getUsername(SysDeptController)'] skipped
# INFO: Edge ['add(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] skipped
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'error(SysDeptController)'] skipped
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'getUsername(SysDeptController)'] skipped
# INFO: Edge ['edit(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] skipped
# INFO: Edge ['remove(SysDeptController)', 'Calls', 'warn(SysDeptController)'] skipped
# INFO: Edge ['remove(SysDeptController)', 'Calls', 'warn(SysDeptController)'] skipped
# INFO: Edge ['remove(SysDeptController)', 'Calls', 'toAjax(SysDeptController)'] skipped
# INFO: Edge ['list(SysDictTypeController)', 'Calls', 'startPage(SysDictTypeController)'] skipped
# INFO: Edge ['list(SysDictTypeController)', 'Calls', 'getDataTable(SysDictTypeController)'] skipped
# INFO: Edge ['getInfo(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped
# INFO: Edge ['add(SysDictTypeController)', 'Calls', 'error(SysDictTypeController)'] skipped
# INFO: Edge ['add(SysDictTypeController)', 'Calls', 'getUsername(SysDictTypeController)'] skipped
# INFO: Edge ['add(SysDictTypeController)', 'Calls', 'toAjax(SysDictTypeController)'] skipped
# INFO: Edge ['edit(SysDictTypeController)', 'Calls', 'error(SysDictTypeController)'] skipped
# INFO: Edge ['edit(SysDictTypeController)', 'Calls', 'getUsername(SysDictTypeController)'] skipped
# INFO: Edge ['edit(SysDictTypeController)', 'Calls', 'toAjax(SysDictTypeController)'] skipped
# INFO: Edge ['remove(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped
# INFO: Edge ['refreshCache(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped
# INFO: Edge ['optionselect(SysDictTypeController)', 'Calls', 'success(SysDictTypeController)'] skipped
# INFO: Edge ['buildMenus(SysMenuServiceImpl)', 'Calls', 'equals(SysMenuServiceImpl)'] skipped

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity AuthenticationContextHolder
# Removed Entity PermissionContextHolder
# Removed Entity FastJson2JsonRedisSerializer
# Removed Entity KaptchaTextCreator
# Removed Entity AsyncFactory
# Removed Entity GlobalExceptionHandler
# Removed Entity DynamicDataSource
# Removed Entity DynamicDataSourceContextHolder
# Removed Entity RuoYiServletInitializer
# Removed Entity XssValidator
# Removed Entity XssHttpServletRequestWrapper
# Removed Entity RepeatableFilter
# Removed Entity XssFilter
# Removed Entity R
# Removed Entity BaseController
# Removed Entity Convert
# Removed Entity StrFormatter
# Removed Entity CharsetKit
# Removed Entity PageDomain
# Removed Entity TableSupport
# Removed Entity DateUtils
# Removed Entity ServletUtils
# Removed Entity SecurityUtils
# Removed Entity DesensitizedUtil
# Removed Entity LogUtils
# Removed Entity ExceptionUtil
# Removed Entity StringUtils
# Removed Entity Arith
# Removed Entity PageUtils
# Removed Entity MessageUtils
# Removed Entity DictUtils
# Removed Entity Threads
# Removed Entity Base64
# Removed Entity Md5Utils
# Removed Entity MimeTypeUtils
# Removed Entity FileUtils
# Removed Entity ImageUtils
# Removed Entity FileUploadUtils
# Removed Entity FileTypeUtils
# Removed Entity SqlUtil
# Removed Entity ReflectUtils
# Removed Entity AddressUtils
# Removed Entity IpUtils
# Removed Entity EscapeUtil
# Removed Entity HTMLFilter
# Removed Entity IdUtils
# Removed Entity Seq
# Removed Entity UUID
# Removed Entity ExcelUtil
# Removed Entity HttpUtils
# Removed Entity HttpHelper
# Removed Entity BeanUtils
# Removed Entity BeanValidators
# Removed Entity SensitiveJsonSerializer
# Removed Entity UserConstants
# Removed Entity GenConstants
# Removed Entity Constants
# Removed Entity CacheConstants
# Removed Entity HttpStatus
# Removed Entity ScheduleConstants
# Removed Entity GlobalException
# Removed Entity UtilException
# Removed Entity DemoModeException
# Removed Entity TaskException
# Removed commence (AuthenticationEntryPointImpl)
# Removed isRepeatSubmit (RepeatSubmitInterceptor)
# Removed boBefore (LogAspect)
# Removed dsPointCut (DataSourceAspect)
# Removed setRedisTemplate1 (RateLimiterAspect)
# Removed setLimitScript (RateLimiterAspect)
# Removed delete (TestController)
# Removed fileDownload (CommonController)
# Removed resourceDownload (CommonController)
# Removed deleteUserById (SysUserServiceImpl)
# Removed deletePostById (SysPostServiceImpl)
# Removed deleteNoticeById (SysNoticeServiceImpl)
# Removed selectRoleListByUserId (SysRoleServiceImpl)
# Removed deleteRoleById (SysRoleServiceImpl)
# Removed selectDictLabel (SysDictDataServiceImpl)
# Removed expire (RedisCache)
# Removed getExpire (RedisCache)
# Removed setCacheList (RedisCache)
# Removed getCacheList (RedisCache)
# Removed setCacheSet (RedisCache)
# Removed getCacheSet (RedisCache)
# Removed setCacheMap (RedisCache)
# Removed getCacheMap (RedisCache)
# Removed setCacheMapValue (RedisCache)
# Removed getCacheMapValue (RedisCache)
# Removed getMultiCacheMapValue (RedisCache)
# Removed deleteCacheMapValue (RedisCache)
# Removed postProcessBeanFactory (SpringUtils)
# Removed setApplicationContext (SpringUtils)
# Removed getBean (SpringUtils)
# Removed containsBean (SpringUtils)
# Removed isSingleton (SpringUtils)
# Removed getType (SpringUtils)
# Removed getAliases (SpringUtils)
# Removed getAopProxy (SpringUtils)
# Removed getRequiredProperty (SpringUtils)
# Removed setName (RuoYiConfig)
# Removed setVersion (RuoYiConfig)
# Removed getCopyrightYear (RuoYiConfig)
# Removed setCopyrightYear (RuoYiConfig)
# Removed setProfile (RuoYiConfig)
# Removed isAddressEnabled (RuoYiConfig)
# Removed setAddressEnabled (RuoYiConfig)
# Removed getCaptchaType (RuoYiConfig)
# Removed setCaptchaType (RuoYiConfig)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
