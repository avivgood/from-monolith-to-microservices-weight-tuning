# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'jpetstore' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "thingsboard"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/thingsboard/source/application/src/main/java/org/thingsboard/server/controller/EntityViewController.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/thingsboard/source/application/src/main/java/org/thingsboard/server/controller/RpcController.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/thingsboard/source/application/src/main/java/org/thingsboard/server/controller/TelemetryController.java:
# Entity		ThingsboardMqttTransportApplication		org.thingsboard.server.mqtt
# Excluded	ThingsboardHttpTransportApplication		org.thingsboard.server.http
# Entity		ThingsboardCoapTransportApplication		org.thingsboard.server.coap
# Entity		ThingsboardServerApplication		org.thingsboard.server
# Entity		ThingsboardInstallApplication		org.thingsboard.server
# Excluded	ThingsboardInstallConfiguration		org.thingsboard.server.install
# Logic		ThingsboardInstallService		org.thingsboard.server.install
# Entity		ThingsboardInstallException		org.thingsboard.server.install
# Logic		DefaultTbRuleEngineRpcService		org.thingsboard.server.service.rpc
# Logic		DefaultTbCoreDeviceRpcService		org.thingsboard.server.service.rpc
# Entity		ToDeviceRpcRequestActorMsg		org.thingsboard.server.service.rpc
# Entity		FromDeviceRpcResponse		org.thingsboard.server.service.rpc
# Interface	TbCoreDeviceRpcService		org.thingsboard.server.service.rpc
# Entity		LocalRequestMetaData		org.thingsboard.server.service.rpc
# Interface	TbRuleEngineDeviceRpcService		org.thingsboard.server.service.rpc
# Logic		AnnotationComponentDiscoveryService		org.thingsboard.server.service.component
# Interface	ComponentDiscoveryService		org.thingsboard.server.service.component
# Entity		JsInvokeResponse		org.thingsboard.server.service.script
# Entity		RuleNodeJsScriptEngine		org.thingsboard.server.service.script
# Logic		JsExecutorService		org.thingsboard.server.service.script
# Interface	JsInvokeService		org.thingsboard.server.service.script
# Entity		RuleNodeScriptFactory		org.thingsboard.server.service.script
# Logic		NashornJsInvokeService		org.thingsboard.server.service.script
# Entity		JsInvokeRequest		org.thingsboard.server.service.script
# Entity		JsStatCallback		org.thingsboard.server.service.script
# Entity		AbstractNashornJsInvokeService		org.thingsboard.server.service.script
# Entity		RemoteJsRequestEncoder		org.thingsboard.server.service.script
# Entity		RemoteJsResponseDecoder		org.thingsboard.server.service.script
# Entity		AbstractJsInvokeService		org.thingsboard.server.service.script
# Logic		RemoteJsInvokeService		org.thingsboard.server.service.script
# Logic		AccessValidator		org.thingsboard.server.service.security
# Entity		ValidationResult		org.thingsboard.server.service.security
# Entity		ValidationCallback		org.thingsboard.server.service.security
# Logic		SysAdminPermissions		org.thingsboard.server.service.security.permission
# Logic		CustomerUserPermissions		org.thingsboard.server.service.security.permission
# Interface	AccessControlService		org.thingsboard.server.service.security.permission
# Interface	PermissionChecker		org.thingsboard.server.service.security.permission
# Entity		AbstractPermissions		org.thingsboard.server.service.security.permission
# Logic		DefaultAccessControlService		org.thingsboard.server.service.security.permission
# Logic		TenantAdminPermissions		org.thingsboard.server.service.security.permission
# Interface	Permissions		org.thingsboard.server.service.security.permission
# Logic		DefaultDeviceAuthService		org.thingsboard.server.service.security.device
# Entity		SecurityUser		org.thingsboard.server.service.security.model
# Entity		UserPrincipal		org.thingsboard.server.service.security.model
# Entity		RawAccessJwtToken		org.thingsboard.server.service.security.model.token
# Interface	JwtToken		org.thingsboard.server.service.security.model.token
# Logic		JwtTokenFactory		org.thingsboard.server.service.security.model.token
# Entity		AccessJwtToken		org.thingsboard.server.service.security.model.token
# Entity		JwtAuthenticationToken		org.thingsboard.server.service.security.auth
# Entity		AbstractJwtAuthenticationToken		org.thingsboard.server.service.security.auth
# Entity		RefreshAuthenticationToken		org.thingsboard.server.service.security.auth
# Logic		Oauth2AuthenticationSuccessHandler		org.thingsboard.server.service.security.auth.oauth2
# Interface	OAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Logic		OAuth2ClientMapperProvider		org.thingsboard.server.service.security.auth.oauth2
# Logic		Oauth2AuthenticationFailureHandler		org.thingsboard.server.service.security.auth.oauth2
# Logic		BasicOAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Logic		CustomOAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Entity		AbstractOAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Logic		RefreshTokenRepository		org.thingsboard.server.service.security.auth.jwt
# Entity		RefreshTokenRequest		org.thingsboard.server.service.security.auth.jwt
# Entity		RefreshTokenProcessingFilter		org.thingsboard.server.service.security.auth.jwt
# Entity		JwtTokenAuthenticationProcessingFilter		org.thingsboard.server.service.security.auth.jwt
# Entity		SkipPathRequestMatcher		org.thingsboard.server.service.security.auth.jwt
# Logic		RefreshTokenAuthenticationProvider		org.thingsboard.server.service.security.auth.jwt
# Logic		JwtAuthenticationProvider		org.thingsboard.server.service.security.auth.jwt
# Logic		JwtHeaderTokenExtractor		org.thingsboard.server.service.security.auth.jwt.extractor
# Logic		JwtQueryTokenExtractor		org.thingsboard.server.service.security.auth.jwt.extractor
# Interface	TokenExtractor		org.thingsboard.server.service.security.auth.jwt.extractor
# Entity		RestAuthenticationDetails		org.thingsboard.server.service.security.auth.rest
# Logic		RestAwareAuthenticationFailureHandler		org.thingsboard.server.service.security.auth.rest
# Entity		RestAuthenticationDetailsSource		org.thingsboard.server.service.security.auth.rest
# Entity		LoginRequest		org.thingsboard.server.service.security.auth.rest
# Logic		RestAuthenticationProvider		org.thingsboard.server.service.security.auth.rest
# Entity		PublicLoginRequest		org.thingsboard.server.service.security.auth.rest
# Entity		RestPublicLoginProcessingFilter		org.thingsboard.server.service.security.auth.rest
# Entity		RestLoginProcessingFilter		org.thingsboard.server.service.security.auth.rest
# Logic		RestAwareAuthenticationSuccessHandler		org.thingsboard.server.service.security.auth.rest
# Logic		DefaultSystemSecurityService		org.thingsboard.server.service.security.system
# Interface	SystemSecurityService		org.thingsboard.server.service.security.system
# Entity		AuthMethodNotSupportedException		org.thingsboard.server.service.security.exception
# Entity		JwtExpiredTokenException		org.thingsboard.server.service.security.exception
# Entity		UserPasswordExpiredException		org.thingsboard.server.service.security.exception
# Logic		ExternalCallExecutorService		org.thingsboard.server.service.executors
# Logic		DbCallbackExecutorService		org.thingsboard.server.service.executors
# Logic		SharedEventLoopGroupService		org.thingsboard.server.service.executors
# Entity		AbstractCleanUpService		org.thingsboard.server.service.ttl
# Logic		TimescaleTimeseriesCleanUpService		org.thingsboard.server.service.ttl.timeseries
# Logic		PsqlTimeseriesCleanUpService		org.thingsboard.server.service.ttl.timeseries
# Entity		AbstractTimeseriesCleanUpService		org.thingsboard.server.service.ttl.timeseries
# Logic		EventsCleanUpService		org.thingsboard.server.service.ttl.events
# Logic		CassandraTsDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		CassandraEntityDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		CassandraTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Entity		SqlAbstractDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		PsqlEntityDatabaseSchemaService		org.thingsboard.server.service.install
# Entity		CassandraAbstractDatabaseSchemaService		org.thingsboard.server.service.install
# Interface	DatabaseSchemaService		org.thingsboard.server.service.install
# Interface	EntityDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		HsqlTsDatabaseSchemaService		org.thingsboard.server.service.install
# Entity		AbstractSqlTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		InstallScripts		org.thingsboard.server.service.install
# Logic		HsqlEntityDatabaseSchemaService		org.thingsboard.server.service.install
# Interface	SystemDataLoaderService		org.thingsboard.server.service.install
# Logic		DefaultSystemDataLoaderService		org.thingsboard.server.service.install
# Interface	DatabaseTsUpgradeService		org.thingsboard.server.service.install
# Entity		AbstractCassandraDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		TimescaleTsDatabaseSchemaService		org.thingsboard.server.service.install
# Interface	TsDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		SqlDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		CassandraDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		PsqlTsDatabaseSchemaService		org.thingsboard.server.service.install
# Entity		DatabaseHelper		org.thingsboard.server.service.install
# Logic		PsqlTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		TimescaleTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Interface	DatabaseEntitiesUpgradeService		org.thingsboard.server.service.install
# Entity		SqlDbHelper		org.thingsboard.server.service.install.sql
# Entity		CQLStatementsParser		org.thingsboard.server.service.install.cql
# Entity		CassandraDbHelper		org.thingsboard.server.service.install.cql
# Logic		DefaultDataUpdateService		org.thingsboard.server.service.install.update
# Entity		PaginatedUpdater		org.thingsboard.server.service.install.update
# Interface	DataUpdateService		org.thingsboard.server.service.install.update
# Logic		TbCoreTransportApiService		org.thingsboard.server.service.transport
# Interface	TbCoreToTransportService		org.thingsboard.server.service.transport
# Logic		DefaultTbCoreToTransportService		org.thingsboard.server.service.transport
# Interface	TransportApiService		org.thingsboard.server.service.transport
# Logic		DefaultTransportApiService		org.thingsboard.server.service.transport
# Entity		TransportToDeviceActorMsgWrapper		org.thingsboard.server.service.transport.msg
# Logic		DefaultMailService		org.thingsboard.server.service.mail
# Logic		MailExecutorService		org.thingsboard.server.service.mail
# Logic		ProtoWithFSTService		org.thingsboard.server.service.encoding
# Interface	DataDecodingEncodingService		org.thingsboard.server.service.encoding
# Interface	DeviceSessionCacheService		org.thingsboard.server.service.session
# Logic		DefaultDeviceSessionCacheService		org.thingsboard.server.service.session
# Logic		DefaultDeviceStateService		org.thingsboard.server.service.state
# Entity		DeviceStateData		org.thingsboard.server.service.state
# Interface	DeviceStateService		org.thingsboard.server.service.state
# Entity		DeviceState		org.thingsboard.server.service.state
# Interface	UpdateService		org.thingsboard.server.service.update
# Logic		DefaultUpdateService		org.thingsboard.server.service.update
# Interface	TelemetryWebSocketService		org.thingsboard.server.service.telemetry
# Entity		TelemetryWebSocketTextMsg		org.thingsboard.server.service.telemetry
# Interface	TelemetrySubscriptionService		org.thingsboard.server.service.telemetry
# Logic		DefaultTelemetryWebSocketService		org.thingsboard.server.service.telemetry
# Entity		AttributeData		org.thingsboard.server.service.telemetry
# Entity		SessionEvent		org.thingsboard.server.service.telemetry
# Entity		TsData		org.thingsboard.server.service.telemetry
# Entity		TelemetryWebSocketSessionRef		org.thingsboard.server.service.telemetry
# Interface	TelemetryWebSocketMsgEndpoint		org.thingsboard.server.service.telemetry
# Logic		DefaultTelemetrySubscriptionService		org.thingsboard.server.service.telemetry
# Entity		WsSessionMetaData		org.thingsboard.server.service.telemetry
# Entity		GetHistoryCmd		org.thingsboard.server.service.telemetry.cmd
# Interface	TelemetryPluginCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		AttributesSubscriptionCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		SubscriptionCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		TelemetryPluginCmdsWrapper		org.thingsboard.server.service.telemetry.cmd
# Entity		TimeseriesSubscriptionCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		SubscriptionUpdate		org.thingsboard.server.service.telemetry.sub
# Entity		SubscriptionState		org.thingsboard.server.service.telemetry.sub
# Entity		EntityNotFoundException		org.thingsboard.server.service.telemetry.exception
# Entity		UncheckedApiException		org.thingsboard.server.service.telemetry.exception
# Entity		UnauthorizedException		org.thingsboard.server.service.telemetry.exception
# Entity		AccessDeniedException		org.thingsboard.server.service.telemetry.exception
# Interface	ToErrorResponseEntity		org.thingsboard.server.service.telemetry.exception
# Entity		InternalErrorException		org.thingsboard.server.service.telemetry.exception
# Entity		InvalidParametersException		org.thingsboard.server.service.telemetry.exception
# Logic		DefaultSubscriptionManagerService		org.thingsboard.server.service.subscription
# Interface	TbLocalSubscriptionService		org.thingsboard.server.service.subscription
# Entity		TbTimeseriesSubscription		org.thingsboard.server.service.subscription
# Logic		DefaultTbLocalSubscriptionService		org.thingsboard.server.service.subscription
# Interface	SubscriptionManagerService		org.thingsboard.server.service.subscription
# Entity		TbSubscription		org.thingsboard.server.service.subscription
# Entity		TbAttributeSubscription		org.thingsboard.server.service.subscription
# Entity		TbSubscriptionUtils		org.thingsboard.server.service.subscription
# Logic		DefaultRuleEngineStatisticsService		org.thingsboard.server.service.stats
# Logic		DefaultJsInvokeStats		org.thingsboard.server.service.stats
# Interface	RuleEngineStatisticsService		org.thingsboard.server.service.stats
# Entity		TbMsgPackCallback		org.thingsboard.server.service.queue
# Entity		TbMsgPackProcessingContext		org.thingsboard.server.service.queue
# Interface	TbRuleEngineConsumerService		org.thingsboard.server.service.queue
# Logic		DefaultTenantRoutingInfoService		org.thingsboard.server.service.queue
# Entity		TbMsgProfilerInfo		org.thingsboard.server.service.queue
# Entity		TbCoreConsumerStats		org.thingsboard.server.service.queue
# Interface	TbClusterService		org.thingsboard.server.service.queue
# Logic		DefaultTbCoreConsumerService		org.thingsboard.server.service.queue
# Logic		DefaultTbRuleEngineConsumerService		org.thingsboard.server.service.queue
# Entity		TbPackCallback		org.thingsboard.server.service.queue
# Entity		TbTenantRuleEngineStats		org.thingsboard.server.service.queue
# Entity		TbRuleNodeProfilerInfo		org.thingsboard.server.service.queue
# Logic		DefaultTbClusterService		org.thingsboard.server.service.queue
# Interface	TbCoreConsumerService		org.thingsboard.server.service.queue
# Entity		TbRuleEngineConsumerStats		org.thingsboard.server.service.queue
# Entity		TbPackProcessingContext		org.thingsboard.server.service.queue
# Entity		SequentialByEntityIdTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		SequentialByTenantIdTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		IdMsgPair		org.thingsboard.server.service.queue.processing
# Entity		SequentialByOriginatorIdTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Logic		TbRuleEngineSubmitStrategyFactory		org.thingsboard.server.service.queue.processing
# Interface	TbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		AbstractConsumerService		org.thingsboard.server.service.queue.processing
# Entity		SequentialTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Logic		TbRuleEngineProcessingStrategyFactory		org.thingsboard.server.service.queue.processing
# Entity		TbRuleEngineProcessingDecision		org.thingsboard.server.service.queue.processing
# Entity		AbstractTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		TbRuleEngineProcessingResult		org.thingsboard.server.service.queue.processing
# Entity		BurstTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		BatchTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Interface	TbRuleEngineProcessingStrategy		org.thingsboard.server.service.queue.processing
# Entity		BaseController		org.thingsboard.server.controller
# Logic		AssetController		org.thingsboard.server.controller
# Logic		DashboardController		org.thingsboard.server.controller
# Logic		EntityRelationController		org.thingsboard.server.controller
# Logic		UserController		org.thingsboard.server.controller
# Logic		DeviceController		org.thingsboard.server.controller
# Logic		AuditLogController		org.thingsboard.server.controller
# Logic		AuthController		org.thingsboard.server.controller
# Logic		TenantController		org.thingsboard.server.controller
# Logic		RuleChainController		org.thingsboard.server.controller
# Entity		TbUrlConstants		org.thingsboard.server.controller
# Logic		EventController		org.thingsboard.server.controller
# Logic		QueueController		org.thingsboard.server.controller
# Logic		WidgetsBundleController		org.thingsboard.server.controller
# Logic		AdminController		org.thingsboard.server.controller
# Logic		ComponentDescriptorController		org.thingsboard.server.controller
# Entity		HttpValidationCallback		org.thingsboard.server.controller
# Logic		CustomerController		org.thingsboard.server.controller
# Logic		WidgetTypeController		org.thingsboard.server.controller
# Logic		AlarmController		org.thingsboard.server.controller
# Logic		TbWebSocketHandler		org.thingsboard.server.controller.plugin
# Entity		MiscUtils		org.thingsboard.server.utils
# Excluded	ThingsboardMessageConfiguration		org.thingsboard.server.config
# Excluded	SchedulingConfiguration		org.thingsboard.server.config
# Logic		WebConfig		org.thingsboard.server.config
# Excluded	AuditLogLevelProperties		org.thingsboard.server.config
# Excluded	JwtSettings		org.thingsboard.server.config
# Excluded	MvcCorsProperties		org.thingsboard.server.config
# Logic		RateLimitProcessingFilter		org.thingsboard.server.config
# Excluded	WebSocketConfiguration		org.thingsboard.server.config
# Excluded	ThingsboardSecurityConfiguration		org.thingsboard.server.config
# Excluded	SwaggerConfiguration		org.thingsboard.server.config
# Logic		ActorSystemContext		org.thingsboard.server.actors
# Entity		TbEntityTypeActorIdPredicate		org.thingsboard.server.actors
# Entity		ActorTerminationMsg		org.thingsboard.server.actors.shared
# Entity		ComponentMsgProcessor		org.thingsboard.server.actors.shared
# Entity		AbstractContextAwareMsgProcessor		org.thingsboard.server.actors.shared
# Logic		DefaultActorService		org.thingsboard.server.actors.service
# Entity		ContextBasedCreator		org.thingsboard.server.actors.service
# Interface	ActorService		org.thingsboard.server.actors.service
# Entity		ContextAwareActor		org.thingsboard.server.actors.service
# Entity		ComponentActor		org.thingsboard.server.actors.service
# Entity		SessionInfo		org.thingsboard.server.actors.device
# Entity		ToServerRpcRequestMetadata		org.thingsboard.server.actors.device
# Entity		DeviceActorCreator		org.thingsboard.server.actors.device
# Entity		SessionTimeoutCheckMsg		org.thingsboard.server.actors.device
# Entity		SessionInfoMetaData		org.thingsboard.server.actors.device
# Entity		DeviceActor		org.thingsboard.server.actors.device
# Entity		DeviceActorMessageProcessor		org.thingsboard.server.actors.device
# Entity		ToDeviceRpcRequestMetadata		org.thingsboard.server.actors.device
# Entity		TenantActor		org.thingsboard.server.actors.tenant
# Entity		DebugTbRateLimits		org.thingsboard.server.actors.tenant
# Entity		RuleChainToRuleNodeMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeRelation		org.thingsboard.server.actors.ruleChain
# Entity		DefaultTbContext		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainActorMessageProcessor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeCtx		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeToRuleChainTellNextMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainToRuleChainMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainActor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeActor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeToSelfErrorMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainManagerActor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeToSelfMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeActorMessageProcessor		org.thingsboard.server.actors.ruleChain
# Entity		StatsActor		org.thingsboard.server.actors.stats
# Entity		StatsPersistMsg		org.thingsboard.server.actors.stats
# Entity		StatsPersistTick		org.thingsboard.server.actors.stats
# Entity		AppActor		org.thingsboard.server.actors.app
# Entity		AppInitMsg		org.thingsboard.server.actors.app
# Entity		ThingsboardErrorResponse		org.thingsboard.server.exception
# Logic		ThingsboardErrorResponseHandler		org.thingsboard.server.exception
# Entity		ThingsboardCredentialsExpiredResponse		org.thingsboard.server.exception
# Entity		TbSendRpcRequestNodeConfiguration		org.thingsboard.rule.engine.rpc
# Entity		TbSendRPCReplyNode		org.thingsboard.rule.engine.rpc
# Entity		TbSendRpcReplyNodeConfiguration		org.thingsboard.rule.engine.rpc
# Entity		TbSendRPCRequestNode		org.thingsboard.rule.engine.rpc
# Entity		TbMqttNodeConfiguration		org.thingsboard.rule.engine.mqtt
# Entity		TbMqttNode		org.thingsboard.rule.engine.mqtt
# Entity		TbAzureIotHubNode		org.thingsboard.rule.engine.mqtt.azure
# Entity		AzureIotHubSasCredentials		org.thingsboard.rule.engine.mqtt.azure
# Entity		TbAzureIotHubNodeConfiguration		org.thingsboard.rule.engine.mqtt.azure
# Interface	MqttClientCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		AnonymousCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		BasicCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		CertPemClientCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		TbPubSubNodeConfiguration		org.thingsboard.rule.engine.gcp.pubsub
# Entity		TbPubSubNode		org.thingsboard.rule.engine.gcp.pubsub
# Entity		TbMsgTypeFilterNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbJsSwitchNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbCheckMessageNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbCheckMessageNode		org.thingsboard.rule.engine.filter
# Entity		TbMsgTypeSwitchNode		org.thingsboard.rule.engine.filter
# Entity		TbJsSwitchNode		org.thingsboard.rule.engine.filter
# Entity		TbCheckAlarmStatusNode		org.thingsboard.rule.engine.filter
# Entity		TbOriginatorTypeFilterNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbCheckRelationNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbMsgTypeFilterNode		org.thingsboard.rule.engine.filter
# Entity		TbOriginatorTypeSwitchNode		org.thingsboard.rule.engine.filter
# Entity		TbJsFilterNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbOriginatorTypeFilterNode		org.thingsboard.rule.engine.filter
# Entity		TbCheckAlarmStatusNodeConfig		org.thingsboard.rule.engine.filter
# Entity		TbJsFilterNode		org.thingsboard.rule.engine.filter
# Entity		TbCheckRelationNode		org.thingsboard.rule.engine.filter
# Entity		EntitiesTenantIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesRelatedDeviceIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesCustomerIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesRelatedEntityIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesFieldsAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntityContainer		org.thingsboard.rule.engine.util
# Entity		EntitiesAlarmOriginatorIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		TbSendEmailNode		org.thingsboard.rule.engine.mail
# Entity		TbMsgToEmailNodeConfiguration		org.thingsboard.rule.engine.mail
# Entity		TbMsgToEmailNode		org.thingsboard.rule.engine.mail
# Entity		TbSendEmailNodeConfiguration		org.thingsboard.rule.engine.mail
# Entity		EmailPojo		org.thingsboard.rule.engine.mail
# Entity		TbLogNode		org.thingsboard.rule.engine.action
# Entity		TbCreateRelationNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbDeleteRelationNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbMsgCountNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbAssignToCustomerNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractAlarmNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbCopyAttributesToEntityViewNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractCustomerActionNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractAlarmNode		org.thingsboard.rule.engine.action
# Entity		TbLogNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbUnassignFromCustomerNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbUnassignFromCustomerNode		org.thingsboard.rule.engine.action
# Entity		TbMsgCountNode		org.thingsboard.rule.engine.action
# Entity		TbCreateAlarmNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbCreateAlarmNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractRelationActionNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbAbstractRelationActionNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractCustomerActionNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbClearAlarmNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbSaveToCustomCassandraTableNode		org.thingsboard.rule.engine.action
# Entity		TbAssignToCustomerNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbCreateRelationNode		org.thingsboard.rule.engine.action
# Entity		TbClearAlarmNode		org.thingsboard.rule.engine.action
# Entity		TbDeleteRelationNode		org.thingsboard.rule.engine.action
# Entity		TbSaveToCustomCassandraTableNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbMsgDelayNode		org.thingsboard.rule.engine.delay
# Entity		TbMsgDelayNodeConfiguration		org.thingsboard.rule.engine.delay
# Entity		RelationsQuery		org.thingsboard.rule.engine.data
# Entity		DeviceRelationsQuery		org.thingsboard.rule.engine.data
# Entity		TbMsgAttributesNodeConfiguration		org.thingsboard.rule.engine.telemetry
# Entity		TbMsgTimeseriesNode		org.thingsboard.rule.engine.telemetry
# Entity		TbMsgAttributesNode		org.thingsboard.rule.engine.telemetry
# Entity		TelemetryNodeCallback		org.thingsboard.rule.engine.telemetry
# Entity		TbMsgTimeseriesNodeConfiguration		org.thingsboard.rule.engine.telemetry
# Entity		TbSqsNode		org.thingsboard.rule.engine.aws.sqs
# Entity		TbSqsNodeConfiguration		org.thingsboard.rule.engine.aws.sqs
# Entity		TbSnsNode		org.thingsboard.rule.engine.aws.sns
# Entity		TbSnsNodeConfiguration		org.thingsboard.rule.engine.aws.sns
# Entity		TbRestApiCallNodeConfiguration		org.thingsboard.rule.engine.rest
# Entity		TbRestApiCallNode		org.thingsboard.rule.engine.rest
# Entity		TbHttpClient		org.thingsboard.rule.engine.rest
# Entity		Coordinates		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingActionNode		org.thingsboard.rule.engine.geo
# Entity		AbstractGeofencingNode		org.thingsboard.rule.engine.geo
# Entity		GeoUtil		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingActionNodeConfiguration		org.thingsboard.rule.engine.geo
# Entity		EntityGeofencingState		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingFilterNode		org.thingsboard.rule.engine.geo
# Entity		Perimeter		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingFilterNodeConfiguration		org.thingsboard.rule.engine.geo
# Entity		TbMsgGeneratorNode		org.thingsboard.rule.engine.debug
# Entity		TbMsgGeneratorNodeConfiguration		org.thingsboard.rule.engine.debug
# Entity		TbTransformNodeConfiguration		org.thingsboard.rule.engine.transform
# Entity		TbAbstractTransformNode		org.thingsboard.rule.engine.transform
# Entity		TbTransformMsgNodeConfiguration		org.thingsboard.rule.engine.transform
# Entity		TbChangeOriginatorNodeConfiguration		org.thingsboard.rule.engine.transform
# Entity		TbTransformMsgNode		org.thingsboard.rule.engine.transform
# Entity		TbChangeOriginatorNode		org.thingsboard.rule.engine.transform
# Entity		TbRabbitMqNode		org.thingsboard.rule.engine.rabbitmq
# Entity		TbRabbitMqNodeConfiguration		org.thingsboard.rule.engine.rabbitmq
# Entity		TbSynchronizationBeginNode		org.thingsboard.rule.engine.transaction
# Entity		TbSynchronizationEndNode		org.thingsboard.rule.engine.transaction
# Entity		TbGetTenantDetailsNode		org.thingsboard.rule.engine.metadata
# Entity		TbAbstractGetEntityDetailsNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetRelatedAttrNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetTenantAttributeNode		org.thingsboard.rule.engine.metadata
# Entity		TbAbstractGetAttributesNode		org.thingsboard.rule.engine.metadata
# Entity		TbAbstractGetEntityDetailsNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetOriginatorFieldsNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetTenantDetailsNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetCustomerAttributeNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetDeviceAttrNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetAttributesNode		org.thingsboard.rule.engine.metadata
# Entity		TbEntityGetAttrNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetAttributesNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetTelemetryNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetTelemetryNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetDeviceAttrNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetOriginatorFieldsConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetEntityAttrNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetCustomerDetailsNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetCustomerDetailsNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetRelatedAttributeNode		org.thingsboard.rule.engine.metadata
# Entity		TbKafkaNodeConfiguration		org.thingsboard.rule.engine.kafka
# Entity		TbKafkaNode		org.thingsboard.rule.engine.kafka
# Entity		TbCheckpointNodeConfiguration		org.thingsboard.rule.engine.flow
# Entity		TbAckNode		org.thingsboard.rule.engine.flow
# Entity		TbCheckpointNode		org.thingsboard.rule.engine.flow
# Interface	TbNode		org.thingsboard.rule.engine.api
# Interface	NodeConfiguration		org.thingsboard.rule.engine.api
# Entity		TbNodeConfiguration		org.thingsboard.rule.engine.api
# Entity		EmptyNodeConfiguration		org.thingsboard.rule.engine.api
# Interface	MailService		org.thingsboard.rule.engine.api
# Interface	RuleEngineRpcService		org.thingsboard.rule.engine.api
# Entity		NodeDefinition		org.thingsboard.rule.engine.api
# Entity		RuleEngineDeviceRpcRequest		org.thingsboard.rule.engine.api
# Entity		RuleEngineDeviceRpcResponse		org.thingsboard.rule.engine.api
# Entity		TbNodeState		org.thingsboard.rule.engine.api
# Entity		TbNodeException		org.thingsboard.rule.engine.api
# Entity		TbRelationTypes		org.thingsboard.rule.engine.api
# Interface	TbContext		org.thingsboard.rule.engine.api
# Interface	ScriptEngine		org.thingsboard.rule.engine.api
# Interface	RuleEngineTelemetryService		org.thingsboard.rule.engine.api
# Entity		DeviceAttributesEventNotificationMsg		org.thingsboard.rule.engine.api.msg
# Entity		DeviceNameOrTypeUpdateMsg		org.thingsboard.rule.engine.api.msg
# Entity		DeviceAttributes		org.thingsboard.rule.engine.api.msg
# Entity		DeviceMetaData		org.thingsboard.rule.engine.api.msg
# Interface	ToDeviceActorNotificationMsg		org.thingsboard.rule.engine.api.msg
# Entity		DeviceCredentialsUpdateNotificationMsg		org.thingsboard.rule.engine.api.msg
# Entity		TbNodeUtils		org.thingsboard.rule.engine.api.util
# Entity		AbstractListeningExecutor		org.thingsboard.common.util
# Entity		AzureIotHubUtil		org.thingsboard.common.util
# Entity		ThingsBoardThreadFactory		org.thingsboard.common.util
# Entity		DonAsynchron		org.thingsboard.common.util
# Interface	ListeningExecutor		org.thingsboard.common.util
# Logic		MqttTransportContext		org.thingsboard.server.transport.mqtt
# Logic		MqttTransportService		org.thingsboard.server.transport.mqtt
# Entity		MqttTransportHandler		org.thingsboard.server.transport.mqtt
# Entity		MqttTransportServerInitializer		org.thingsboard.server.transport.mqtt
# Entity		MqttTopics		org.thingsboard.server.transport.mqtt
# Logic		MqttSslHandlerProvider		org.thingsboard.server.transport.mqtt
# Entity		SslUtil		org.thingsboard.server.transport.mqtt.util
# Entity		DeviceSessionCtx		org.thingsboard.server.transport.mqtt.session
# Entity		GatewayDeviceSessionCtx		org.thingsboard.server.transport.mqtt.session
# Entity		MqttDeviceAwareSessionContext		org.thingsboard.server.transport.mqtt.session
# Entity		GatewaySessionHandler		org.thingsboard.server.transport.mqtt.session
# Entity		MqttTopicMatcher		org.thingsboard.server.transport.mqtt.session
# Logic		JsonMqttAdaptor		org.thingsboard.server.transport.mqtt.adaptors
# Interface	MqttTransportAdaptor		org.thingsboard.server.transport.mqtt.adaptors
# Interface	TransportServiceCallback		org.thingsboard.server.common.transport
# Interface	SessionMsgListener		org.thingsboard.server.common.transport
# Interface	TransportAdaptor		org.thingsboard.server.common.transport
# Logic		TransportContext		org.thingsboard.server.common.transport
# Interface	TransportService		org.thingsboard.server.common.transport
# Excluded	JsonConverterConfig		org.thingsboard.server.common.transport.adaptor
# Entity		AdaptorException		org.thingsboard.server.common.transport.adaptor
# Entity		JsonConverter		org.thingsboard.server.common.transport.adaptor
# Entity		ToTransportMsgResponseDecoder		org.thingsboard.server.common.transport.service
# Entity		SessionMetaData		org.thingsboard.server.common.transport.service
# Entity		ToRuleEngineMsgEncoder		org.thingsboard.server.common.transport.service
# Logic		DefaultTransportService		org.thingsboard.server.common.transport.service
# Entity		TransportApiResponseDecoder		org.thingsboard.server.common.transport.service
# Entity		RpcRequestMetadata		org.thingsboard.server.common.transport.service
# Entity		TransportApiRequestEncoder		org.thingsboard.server.common.transport.service
# Logic		TransportTenantRoutingInfoService		org.thingsboard.server.common.transport.service
# Entity		JsonUtils		org.thingsboard.server.common.transport.util
# Entity		DeviceAwareSessionContext		org.thingsboard.server.common.transport.session
# Entity		DeviceAuthResult		org.thingsboard.server.common.transport.auth
# Interface	DeviceAuthService		org.thingsboard.server.common.transport.auth
# Logic		DeviceApiController		org.thingsboard.server.transport.http
# Logic		HttpTransportContext		org.thingsboard.server.transport.http
# Logic		CoapTransportContext		org.thingsboard.server.transport.coap
# Logic		CoapTransportService		org.thingsboard.server.transport.coap
# Entity		CoapTransportResource		org.thingsboard.server.transport.coap
# Entity		DeviceEmulator		org.thingsboard.server.transport.coap.client
# Logic		JsonCoapAdaptor		org.thingsboard.server.transport.coap.adaptors
# Interface	CoapTransportAdaptor		org.thingsboard.server.transport.coap.adaptors
# Entity		DataConstants		org.thingsboard.server.common.data
# Entity		ContactBased		org.thingsboard.server.common.data
# Entity		ShortCustomerInfo		org.thingsboard.server.common.data
# Entity		Device		org.thingsboard.server.common.data
# Entity		DashboardInfo		org.thingsboard.server.common.data
# Interface	HasName		org.thingsboard.server.common.data
# Entity		BaseData		org.thingsboard.server.common.data
# Entity		EntityFieldsData		org.thingsboard.server.common.data
# Entity		ClaimRequest		org.thingsboard.server.common.data
# Entity		AdminSettings		org.thingsboard.server.common.data
# Entity		Dashboard		org.thingsboard.server.common.data
# Entity		SearchTextBasedWithAdditionalInfo		org.thingsboard.server.common.data
# Interface	HasAdditionalInfo		org.thingsboard.server.common.data
# Entity		EntityView		org.thingsboard.server.common.data
# Entity		User		org.thingsboard.server.common.data
# Entity		UpdateMessage		org.thingsboard.server.common.data
# Entity		EntitySubtype		org.thingsboard.server.common.data
# Interface	HasCustomerId		org.thingsboard.server.common.data
# Entity		CacheConstants		org.thingsboard.server.common.data
# Interface	HasTenantId		org.thingsboard.server.common.data
# Entity		SearchTextBased		org.thingsboard.server.common.data
# Entity		UUIDConverter		org.thingsboard.server.common.data
# Entity		Customer		org.thingsboard.server.common.data
# Entity		Event		org.thingsboard.server.common.data
# Entity		Tenant		org.thingsboard.server.common.data
# Entity		EntityRelationsQuery		org.thingsboard.server.common.data.relation
# Entity		EntityTypeFilter		org.thingsboard.server.common.data.relation
# Entity		EntityRelation		org.thingsboard.server.common.data.relation
# Entity		RelationsSearchParameters		org.thingsboard.server.common.data.relation
# Entity		EntityRelationInfo		org.thingsboard.server.common.data.relation
# Entity		RpcRequest		org.thingsboard.server.common.data.rpc
# Entity		ToDeviceRpcRequestBody		org.thingsboard.server.common.data.rpc
# Entity		DeviceTokenCredentials		org.thingsboard.server.common.data.security
# Interface	DeviceCredentialsFilter		org.thingsboard.server.common.data.security
# Entity		UserCredentials		org.thingsboard.server.common.data.security
# Entity		DeviceCredentials		org.thingsboard.server.common.data.security
# Entity		DeviceX509Credentials		org.thingsboard.server.common.data.security
# Entity		SecuritySettings		org.thingsboard.server.common.data.security.model
# Entity		UserPasswordPolicy		org.thingsboard.server.common.data.security.model
# Entity		AuditLog		org.thingsboard.server.common.data.audit
# Entity		WidgetType		org.thingsboard.server.common.data.widget
# Entity		WidgetsBundle		org.thingsboard.server.common.data.widget
# Entity		BasicTsKvEntry		org.thingsboard.server.common.data.kv
# Entity		StringDataEntry		org.thingsboard.server.common.data.kv
# Entity		BaseDeleteTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		LongDataEntry		org.thingsboard.server.common.data.kv
# Entity		BaseReadTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		BaseAttributeKvEntry		org.thingsboard.server.common.data.kv
# Interface	TsKvQuery		org.thingsboard.server.common.data.kv
# Entity		JsonDataEntry		org.thingsboard.server.common.data.kv
# Interface	AttributeKvEntry		org.thingsboard.server.common.data.kv
# Interface	ReadTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		DoubleDataEntry		org.thingsboard.server.common.data.kv
# Entity		BaseTsKvQuery		org.thingsboard.server.common.data.kv
# Interface	KvEntry		org.thingsboard.server.common.data.kv
# Interface	TsKvEntry		org.thingsboard.server.common.data.kv
# Interface	DeleteTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		BasicKvEntry		org.thingsboard.server.common.data.kv
# Entity		AttributeKey		org.thingsboard.server.common.data.kv
# Entity		BooleanDataEntry		org.thingsboard.server.common.data.kv
# Entity		OAuth2ClientInfo		org.thingsboard.server.common.data.oauth2
# Entity		DeviceSearchQuery		org.thingsboard.server.common.data.device
# Entity		RuleChain		org.thingsboard.server.common.data.rule
# Entity		RuleChainMetaData		org.thingsboard.server.common.data.rule
# Entity		RuleChainConnectionInfo		org.thingsboard.server.common.data.rule
# Entity		NodeConnectionInfo		org.thingsboard.server.common.data.rule
# Entity		RuleNode		org.thingsboard.server.common.data.rule
# Entity		EntityViewSearchQuery		org.thingsboard.server.common.data.entityview
# Entity		AlarmQuery		org.thingsboard.server.common.data.alarm
# Entity		Alarm		org.thingsboard.server.common.data.alarm
# Entity		AlarmInfo		org.thingsboard.server.common.data.alarm
# Entity		ComponentDescriptor		org.thingsboard.server.common.data.plugin
# Entity		AuditLogId		org.thingsboard.server.common.data.id
# Entity		WidgetsBundleId		org.thingsboard.server.common.data.id
# Interface	EntityId		org.thingsboard.server.common.data.id
# Entity		UserCredentialsId		org.thingsboard.server.common.data.id
# Entity		EntityIdDeserializer		org.thingsboard.server.common.data.id
# Entity		RuleChainId		org.thingsboard.server.common.data.id
# Entity		UserId		org.thingsboard.server.common.data.id
# Entity		CustomerId		org.thingsboard.server.common.data.id
# Entity		RuleNodeId		org.thingsboard.server.common.data.id
# Entity		AdminSettingsId		org.thingsboard.server.common.data.id
# Entity		OAuth2IntegrationId		org.thingsboard.server.common.data.id
# Entity		AssetId		org.thingsboard.server.common.data.id
# Entity		DeviceId		org.thingsboard.server.common.data.id
# Entity		WidgetTypeId		org.thingsboard.server.common.data.id
# Entity		AlarmId		org.thingsboard.server.common.data.id
# Entity		ComponentDescriptorId		org.thingsboard.server.common.data.id
# Entity		EntityIdFactory		org.thingsboard.server.common.data.id
# Entity		EventId		org.thingsboard.server.common.data.id
# Entity		DashboardId		org.thingsboard.server.common.data.id
# Entity		EntityViewId		org.thingsboard.server.common.data.id
# Entity		EntityIdSerializer		org.thingsboard.server.common.data.id
# Entity		TenantId		org.thingsboard.server.common.data.id
# Entity		UUIDBased		org.thingsboard.server.common.data.id
# Entity		NodeId		org.thingsboard.server.common.data.id
# Entity		IdBased		org.thingsboard.server.common.data.id
# Entity		DeviceCredentialsId		org.thingsboard.server.common.data.id
# Entity		TextPageLink		org.thingsboard.server.common.data.page
# Entity		PageDataIterable		org.thingsboard.server.common.data.page
# Entity		TextPageData		org.thingsboard.server.common.data.page
# Entity		TimePageData		org.thingsboard.server.common.data.page
# Entity		TimePageLink		org.thingsboard.server.common.data.page
# Entity		BasePageLink		org.thingsboard.server.common.data.page
# Entity		Asset		org.thingsboard.server.common.data.asset
# Entity		AssetSearchQuery		org.thingsboard.server.common.data.asset
# Entity		ThingsboardException		org.thingsboard.server.common.data.exception
# Entity		TelemetryEntityView		org.thingsboard.server.common.data.objects
# Entity		AttributesEntityView		org.thingsboard.server.common.data.objects
# Interface	RelationService		org.thingsboard.server.dao.relation
# Interface	ComponentDescriptorService		org.thingsboard.server.dao.component
# Interface	AuditLogService		org.thingsboard.server.dao.audit
# Interface	AdminSettingsService		org.thingsboard.server.dao.settings
# Interface	UserService		org.thingsboard.server.dao.user
# Interface	WidgetsBundleService		org.thingsboard.server.dao.widget
# Interface	WidgetTypeService		org.thingsboard.server.dao.widget
# Interface	TimeseriesService		org.thingsboard.server.dao.timeseries
# Interface	AsyncTask		org.thingsboard.server.dao.util
# Interface	DashboardService		org.thingsboard.server.dao.dashboard
# Entity		OAuth2User		org.thingsboard.server.dao.oauth2
# Interface	OAuth2Service		org.thingsboard.server.dao.oauth2
# Interface	ClaimDevicesService		org.thingsboard.server.dao.device
# Interface	DeviceCredentialsService		org.thingsboard.server.dao.device
# Interface	DeviceService		org.thingsboard.server.dao.device
# Entity		ClaimData		org.thingsboard.server.dao.device.claim
# Entity		ClaimResult		org.thingsboard.server.dao.device.claim
# Interface	RuleChainService		org.thingsboard.server.dao.rule
# Interface	EntityViewService		org.thingsboard.server.dao.entityview
# Interface	AttributesService		org.thingsboard.server.dao.attributes
# Interface	AlarmService		org.thingsboard.server.dao.alarm
# Entity		CassandraStatementTask		org.thingsboard.server.dao.nosql
# Interface	TenantService		org.thingsboard.server.dao.tenant
# Interface	EntityService		org.thingsboard.server.dao.entity
# Interface	AssetService		org.thingsboard.server.dao.asset
# Interface	EventService		org.thingsboard.server.dao.event
# Logic		CassandraCluster		org.thingsboard.server.dao.cassandra
# Logic		CassandraQueryOptions		org.thingsboard.server.dao.cassandra
# Logic		CassandraSocketOptions		org.thingsboard.server.dao.cassandra
# Entity		AbstractCassandraCluster		org.thingsboard.server.dao.cassandra
# Logic		CassandraInstallCluster		org.thingsboard.server.dao.cassandra
# Interface	CustomerService		org.thingsboard.server.dao.customer
# Entity		StatsCounter		org.thingsboard.server.common.stats
# Logic		DefaultStatsFactory		org.thingsboard.server.common.stats
# Entity		DefaultMessagesStats		org.thingsboard.server.common.stats
# Interface	StatsFactory		org.thingsboard.server.common.stats
# Interface	MessagesStats		org.thingsboard.server.common.stats
# Entity		DefaultCounter		org.thingsboard.server.common.stats
# Interface	TbQueueAdmin		org.thingsboard.server.queue
# Interface	TbQueueHandler		org.thingsboard.server.queue
# Interface	TbQueueMsgDecoder		org.thingsboard.server.queue
# Interface	TbQueueResponseTemplate		org.thingsboard.server.queue
# Interface	TbQueueMsgHeaders		org.thingsboard.server.queue
# Interface	TbQueueRequestTemplate		org.thingsboard.server.queue
# Interface	TbQueueCallback		org.thingsboard.server.queue
# Interface	TbQueueMsg		org.thingsboard.server.queue
# Interface	TbQueueConsumer		org.thingsboard.server.queue
# Interface	TbQueueProducer		org.thingsboard.server.queue
# Interface	TbQueueMsgMetadata		org.thingsboard.server.queue
# Entity		TbRuleEngineQueueAckStrategyConfiguration		org.thingsboard.server.queue.settings
# Logic		TbQueueTransportApiSettings		org.thingsboard.server.queue.settings
# Entity		TbRuleEngineQueueConfiguration		org.thingsboard.server.queue.settings
# Entity		TbRuleEngineQueueSubmitStrategyConfiguration		org.thingsboard.server.queue.settings
# Logic		TbQueueRemoteJsInvokeSettings		org.thingsboard.server.queue.settings
# Logic		TbQueueTransportNotificationSettings		org.thingsboard.server.queue.settings
# Excluded	TbQueueRuleEngineSettings		org.thingsboard.server.queue.settings
# Logic		TbQueueCoreSettings		org.thingsboard.server.queue.settings
# Entity		TbServiceBusConsumerTemplate		org.thingsboard.server.queue.azure.servicebus
# Logic		TbServiceBusQueueConfigs		org.thingsboard.server.queue.azure.servicebus
# Entity		TbServiceBusAdmin		org.thingsboard.server.queue.azure.servicebus
# Logic		TbServiceBusSettings		org.thingsboard.server.queue.azure.servicebus
# Entity		TbServiceBusProducerTemplate		org.thingsboard.server.queue.azure.servicebus
# Interface	DiscoveryService		org.thingsboard.server.queue.discovery
# Entity		ClusterTopologyChangeEvent		org.thingsboard.server.queue.discovery
# Logic		DummyDiscoveryService		org.thingsboard.server.queue.discovery
# Entity		ConsistentHashCircle		org.thingsboard.server.queue.discovery
# Logic		ZkDiscoveryService		org.thingsboard.server.queue.discovery
# Interface	TbServiceInfoProvider		org.thingsboard.server.queue.discovery
# Interface	PartitionService		org.thingsboard.server.queue.discovery
# Entity		TopicPartitionInfoKey		org.thingsboard.server.queue.discovery
# Entity		TenantRoutingInfo		org.thingsboard.server.queue.discovery
# Interface	TenantRoutingInfoService		org.thingsboard.server.queue.discovery
# Logic		HashPartitionService		org.thingsboard.server.queue.discovery
# Entity		PartitionChangeEvent		org.thingsboard.server.queue.discovery
# Logic		DefaultTbServiceInfoProvider		org.thingsboard.server.queue.discovery
# Logic		TbCoreQueueProducerProvider		org.thingsboard.server.queue.provider
# Logic		KafkaTbRuleEngineQueueFactory		org.thingsboard.server.queue.provider
# Interface	TbRuleEngineQueueFactory		org.thingsboard.server.queue.provider
# Logic		AwsSqsTbRuleEngineQueueFactory		org.thingsboard.server.queue.provider
# Logic		ServiceBusTbCoreQueueFactory		org.thingsboard.server.queue.provider
# Logic		TbTransportQueueProducerProvider		org.thingsboard.server.queue.provider
# Logic		TbRuleEngineProducerProvider		org.thingsboard.server.queue.provider
# Logic		RabbitMqMonolithQueueFactory		org.thingsboard.server.queue.provider
# Logic		AwsSqsTbCoreQueueFactory		org.thingsboard.server.queue.provider
# Logic		PubSubMonolithQueueFactory		org.thingsboard.server.queue.provider
# Logic		RabbitMqTransportQueueFactory		org.thingsboard.server.queue.provider
# Logic		KafkaMonolithQueueFactory		org.thingsboard.server.queue.provider
# Logic		ServiceBusTbRuleEngineQueueFactory		org.thingsboard.server.queue.provider
# Logic		AwsSqsMonolithQueueFactory		org.thingsboard.server.queue.provider
# ...
# Interface	WidgetsBundleDao		org.thingsboard.server.dao.widget
# Logic		CassandraWidgetTypeDao		org.thingsboard.server.dao.widget
# Logic		WidgetTypeServiceImpl		org.thingsboard.server.dao.widget
# Interface	WidgetTypeDao		org.thingsboard.server.dao.widget
# Logic		WidgetsBundleServiceImpl		org.thingsboard.server.dao.widget
# Logic		CassandraWidgetsBundleDao		org.thingsboard.server.dao.widget
# Entity		TbSqlBlockingQueueParams		org.thingsboard.server.dao.sql
# Entity		JpaAbstractSearchTimeDao		org.thingsboard.server.dao.sql
# Entity		TbSqlQueueElement		org.thingsboard.server.dao.sql
# Interface	TbSqlQueue		org.thingsboard.server.dao.sql
# Logic		JpaExecutorService		org.thingsboard.server.dao.sql
# Logic		ScheduledLogExecutorComponent		org.thingsboard.server.dao.sql
# Entity		JpaAbstractDao		org.thingsboard.server.dao.sql
# Entity		TbSqlBlockingQueue		org.thingsboard.server.dao.sql
# Entity		JpaAbstractDaoListeningExecutorService		org.thingsboard.server.dao.sql
# Entity		TbSqlBlockingQueueWrapper		org.thingsboard.server.dao.sql
# Entity		JpaAbstractSearchTextDao		org.thingsboard.server.dao.sql
# Repository		HsqlRelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Interface	RelationRepository		org.thingsboard.server.dao.sql.relation
# Repository		PsqlRelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Entity		AbstractRelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Logic		JpaRelationDao		org.thingsboard.server.dao.sql.relation
# Interface	RelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Repository		HsqlComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Entity		AbstractComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Logic		JpaBaseComponentDescriptorDao		org.thingsboard.server.dao.sql.component
# Repository		PsqlComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Interface	ComponentDescriptorRepository		org.thingsboard.server.dao.sql.component
# Interface	ComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Interface	AuditLogRepository		org.thingsboard.server.dao.sql.audit
# Logic		JpaAuditLogDao		org.thingsboard.server.dao.sql.audit
# Interface	AdminSettingsRepository		org.thingsboard.server.dao.sql.settings
# Logic		JpaAdminSettingsDao		org.thingsboard.server.dao.sql.settings
# Logic		JpaUserCredentialsDao		org.thingsboard.server.dao.sql.user
# Logic		JpaUserDao		org.thingsboard.server.dao.sql.user
# Interface	UserCredentialsRepository		org.thingsboard.server.dao.sql.user
# Interface	UserRepository		org.thingsboard.server.dao.sql.user
# Interface	WidgetTypeRepository		org.thingsboard.server.dao.sql.widget
# Interface	WidgetsBundleRepository		org.thingsboard.server.dao.sql.widget
# Logic		JpaWidgetsBundleDao		org.thingsboard.server.dao.sql.widget
# Logic		JpaWidgetTypeDao		org.thingsboard.server.dao.sql.widget
# Logic		JpaDashboardInfoDao		org.thingsboard.server.dao.sql.dashboard
# Logic		JpaDashboardDao		org.thingsboard.server.dao.sql.dashboard
# Interface	DashboardRepository		org.thingsboard.server.dao.sql.dashboard
# Interface	DashboardInfoRepository		org.thingsboard.server.dao.sql.dashboard
# Logic		JpaDeviceCredentialsDao		org.thingsboard.server.dao.sql.device
# Interface	DeviceRepository		org.thingsboard.server.dao.sql.device
# Logic		JpaDeviceDao		org.thingsboard.server.dao.sql.device
# Interface	DeviceCredentialsRepository		org.thingsboard.server.dao.sql.device
# Interface	RuleChainRepository		org.thingsboard.server.dao.sql.rule
# Interface	RuleNodeRepository		org.thingsboard.server.dao.sql.rule
# Logic		JpaRuleChainDao		org.thingsboard.server.dao.sql.rule
# Logic		JpaRuleNodeDao		org.thingsboard.server.dao.sql.rule
# Logic		JpaEntityViewDao		org.thingsboard.server.dao.sql.entityview
# Interface	EntityViewRepository		org.thingsboard.server.dao.sql.entityview
# Interface	AttributeKvRepository		org.thingsboard.server.dao.sql.attributes
# Repository		HsqlAttributesInsertRepository		org.thingsboard.server.dao.sql.attributes
# Logic		JpaAttributeDao		org.thingsboard.server.dao.sql.attributes
# Repository		PsqlAttributesInsertRepository		org.thingsboard.server.dao.sql.attributes
# Repository		AttributeKvInsertRepository		org.thingsboard.server.dao.sql.attributes
# Interface	AlarmRepository		org.thingsboard.server.dao.sql.alarm
# Logic		JpaAlarmDao		org.thingsboard.server.dao.sql.alarm
# Interface	TenantRepository		org.thingsboard.server.dao.sql.tenant
# Logic		JpaTenantDao		org.thingsboard.server.dao.sql.tenant
# Logic		JpaAssetDao		org.thingsboard.server.dao.sql.asset
# Interface	AssetRepository		org.thingsboard.server.dao.sql.asset
# Interface	EventRepository		org.thingsboard.server.dao.sql.event
# Logic		JpaBaseEventDao		org.thingsboard.server.dao.sql.event
# Repository		HsqlEventInsertRepository		org.thingsboard.server.dao.sql.event
# Interface	EventInsertRepository		org.thingsboard.server.dao.sql.event
# Entity		AbstractEventInsertRepository		org.thingsboard.server.dao.sql.event
# Repository		PsqlEventInsertRepository		org.thingsboard.server.dao.sql.event
# Logic		JpaCustomerDao		org.thingsboard.server.dao.sql.customer
# Interface	CustomerRepository		org.thingsboard.server.dao.sql.customer
# Interface	TimeseriesDao		org.thingsboard.server.dao.timeseries
# Logic		CassandraBaseTimeseriesDao		org.thingsboard.server.dao.timeseries
# Logic		BaseTimeseriesService		org.thingsboard.server.dao.timeseries
# Entity		AggregatePartitionsFunction		org.thingsboard.server.dao.timeseries
# Entity		PsqlPartition		org.thingsboard.server.dao.timeseries
# Entity		TsKvQueryCursor		org.thingsboard.server.dao.timeseries
# Entity		QueryCursor		org.thingsboard.server.dao.timeseries
# Entity		SimpleListenableFuture		org.thingsboard.server.dao.timeseries
# Entity		TimePaginatedRemover		org.thingsboard.server.dao.service
# Entity		PaginatedRemover		org.thingsboard.server.dao.service
# Entity		DataValidator		org.thingsboard.server.dao.service
# Entity		Validator		org.thingsboard.server.dao.service
# Entity		TenantRateLimitException		org.thingsboard.server.dao.util
# Interface	BufferedRateExecutor		org.thingsboard.server.dao.util
# Entity		AbstractBufferedRateExecutor		org.thingsboard.server.dao.util
# Entity		BufferedRateExecutorStats		org.thingsboard.server.dao.util
# Entity		AsyncTaskContext		org.thingsboard.server.dao.util
# Interface	AsyncRateLimiter		org.thingsboard.server.dao.util
# Entity		JacksonUtil		org.thingsboard.server.dao.util.mapping
# Entity		JsonStringSqlTypeDescriptor		org.thingsboard.server.dao.util.mapping
# Entity		JsonTypeDescriptor		org.thingsboard.server.dao.util.mapping
# Entity		AbstractJsonSqlTypeDescriptor		org.thingsboard.server.dao.util.mapping
# Entity		JsonStringType		org.thingsboard.server.dao.util.mapping
# Interface	DashboardInfoDao		org.thingsboard.server.dao.dashboard
# Logic		DashboardServiceImpl		org.thingsboard.server.dao.dashboard
# Interface	DashboardDao		org.thingsboard.server.dao.dashboard
# Logic		CassandraDashboardInfoDao		org.thingsboard.server.dao.dashboard
# Logic		CassandraDashboardDao		org.thingsboard.server.dao.dashboard
# Logic		OAuth2ServiceImpl		org.thingsboard.server.dao.oauth2
# Excluded	OAuth2Configuration		org.thingsboard.server.dao.oauth2
# Entity		OAuth2Client		org.thingsboard.server.dao.oauth2
# Entity		OAuth2ClientMapperConfig		org.thingsboard.server.dao.oauth2
# Interface	DeviceDao		org.thingsboard.server.dao.device
# Logic		DeviceCredentialsServiceImpl		org.thingsboard.server.dao.device
# Entity		ClaimDataInfo		org.thingsboard.server.dao.device
# Logic		CassandraDeviceCredentialsDao		org.thingsboard.server.dao.device
# Interface	DeviceCredentialsDao		org.thingsboard.server.dao.device
# Logic		ClaimDevicesServiceImpl		org.thingsboard.server.dao.device
# Logic		CassandraDeviceDao		org.thingsboard.server.dao.device
# Logic		DeviceServiceImpl		org.thingsboard.server.dao.device
# Interface	RuleChainDao		org.thingsboard.server.dao.rule
# Logic		CassandraRuleNodeDao		org.thingsboard.server.dao.rule
# Logic		CassandraRuleChainDao		org.thingsboard.server.dao.rule
# Interface	RuleNodeDao		org.thingsboard.server.dao.rule
# Logic		BaseRuleChainService		org.thingsboard.server.dao.rule
# Logic		CassandraEntityViewDao		org.thingsboard.server.dao.entityview
# Interface	EntityViewDao		org.thingsboard.server.dao.entityview
# Logic		EntityViewServiceImpl		org.thingsboard.server.dao.entityview
# Logic		CassandraBaseAttributesDao		org.thingsboard.server.dao.attributes
# Logic		BaseAttributesService		org.thingsboard.server.dao.attributes
# Interface	AttributesDao		org.thingsboard.server.dao.attributes
# Logic		BaseAlarmService		org.thingsboard.server.dao.alarm
# Logic		CassandraAlarmDao		org.thingsboard.server.dao.alarm
# Interface	AlarmDao		org.thingsboard.server.dao.alarm
# Entity		TsKey		org.thingsboard.server.dao.sqlts
# Entity		AbstractSqlTimeseriesDao		org.thingsboard.server.dao.sqlts
# Entity		EntityContainer		org.thingsboard.server.dao.sqlts
# Entity		AbstractChunkedAggregationTimeseriesDao		org.thingsboard.server.dao.sqlts
# Repository		AbstractInsertRepository		org.thingsboard.server.dao.sqlts.insert
# Interface	InsertTsRepository		org.thingsboard.server.dao.sqlts.insert
# Repository		HsqlInsertTsRepository		org.thingsboard.server.dao.sqlts.insert.hsql
# Repository		TimescaleInsertTsRepository		org.thingsboard.server.dao.sqlts.insert.timescale
# Repository		PsqlPartitioningRepository		org.thingsboard.server.dao.sqlts.insert.psql
# Repository		PsqlInsertTsRepository		org.thingsboard.server.dao.sqlts.insert.psql
# Interface	TsKvRepository		org.thingsboard.server.dao.sqlts.ts
# Logic		JpaHsqlTimeseriesDao		org.thingsboard.server.dao.sqlts.hsql
# Repository		AggregationRepository		org.thingsboard.server.dao.sqlts.timescale
# Interface	TsKvTimescaleRepository		org.thingsboard.server.dao.sqlts.timescale
# Logic		TimescaleTimeseriesDao		org.thingsboard.server.dao.sqlts.timescale
# Logic		JpaPsqlTimeseriesDao		org.thingsboard.server.dao.sqlts.psql
# Interface	TsKvDictionaryRepository		org.thingsboard.server.dao.sqlts.dictionary
# Entity		CassandraAbstractSearchTextDao		org.thingsboard.server.dao.nosql
# Entity		RateLimitedResultSetFuture		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractAsyncDao		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractDao		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractModelDao		org.thingsboard.server.dao.nosql
# Entity		TbResultSetFuture		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractSearchTimeDao		org.thingsboard.server.dao.nosql
# Logic		CassandraBufferedRateExecutor		org.thingsboard.server.dao.nosql
# Logic		CassandraTenantDao		org.thingsboard.server.dao.tenant
# Interface	TenantDao		org.thingsboard.server.dao.tenant
# Logic		TenantServiceImpl		org.thingsboard.server.dao.tenant
# Entity		EntitySubtypeEntity		org.thingsboard.server.dao.model
# Interface	BaseEntity		org.thingsboard.server.dao.model
# Entity		ModelConstants		org.thingsboard.server.dao.model
# Entity		BaseSqlEntity		org.thingsboard.server.dao.model
# Interface	ToData		org.thingsboard.server.dao.model
# Interface	SearchTextEntity		org.thingsboard.server.dao.model
# Entity		DeviceEntity		org.thingsboard.server.dao.model.sql
# Entity		DashboardEntity		org.thingsboard.server.dao.model.sql
# Entity		AttributeKvCompositeKey		org.thingsboard.server.dao.model.sql
# Entity		AdminSettingsEntity		org.thingsboard.server.dao.model.sql
# Entity		WidgetTypeEntity		org.thingsboard.server.dao.model.sql
# Entity		TenantEntity		org.thingsboard.server.dao.model.sql
# Entity		AbstractTsKvEntity		org.thingsboard.server.dao.model.sql
# Entity		AttributeKvEntity		org.thingsboard.server.dao.model.sql
# Entity		CustomerEntity		org.thingsboard.server.dao.model.sql
# Entity		WidgetsBundleEntity		org.thingsboard.server.dao.model.sql
# Entity		ComponentDescriptorEntity		org.thingsboard.server.dao.model.sql
# Entity		UserEntity		org.thingsboard.server.dao.model.sql
# Entity		RuleNodeEntity		org.thingsboard.server.dao.model.sql
# Entity		DashboardInfoEntity		org.thingsboard.server.dao.model.sql
# Entity		EntityViewEntity		org.thingsboard.server.dao.model.sql
# Entity		DeviceCredentialsEntity		org.thingsboard.server.dao.model.sql
# Entity		RuleChainEntity		org.thingsboard.server.dao.model.sql
# Entity		AlarmEntity		org.thingsboard.server.dao.model.sql
# Entity		AssetEntity		org.thingsboard.server.dao.model.sql
# Entity		UserCredentialsEntity		org.thingsboard.server.dao.model.sql
# Entity		RelationCompositeKey		org.thingsboard.server.dao.model.sql
# Entity		EventEntity		org.thingsboard.server.dao.model.sql
# Entity		RelationEntity		org.thingsboard.server.dao.model.sql
# Entity		AuditLogEntity		org.thingsboard.server.dao.model.sql
# Entity		EntityResultSet		org.thingsboard.server.dao.model.wrapper
# Entity		DeviceCredentialsTypeCodec		org.thingsboard.server.dao.model.type
# Entity		ActionStatusCodec		org.thingsboard.server.dao.model.type
# Entity		ActionTypeCodec		org.thingsboard.server.dao.model.type
# Entity		AlarmStatusCodec		org.thingsboard.server.dao.model.type
# Entity		JsonCodec		org.thingsboard.server.dao.model.type
# Entity		RelationTypeGroupCodec		org.thingsboard.server.dao.model.type
# Entity		ComponentTypeCodec		org.thingsboard.server.dao.model.type
# Entity		AuthorityCodec		org.thingsboard.server.dao.model.type
# Entity		ComponentLifecycleStateCodec		org.thingsboard.server.dao.model.type
# Entity		ComponentScopeCodec		org.thingsboard.server.dao.model.type
# Entity		EntityTypeCodec		org.thingsboard.server.dao.model.type
# Entity		AlarmSeverityCodec		org.thingsboard.server.dao.model.type
# Entity		TsKvEntity		org.thingsboard.server.dao.model.sqlts.ts
# Entity		TsKvCompositeKey		org.thingsboard.server.dao.model.sqlts.ts
# Entity		TimescaleTsKvEntity		org.thingsboard.server.dao.model.sqlts.timescale.ts
# Entity		TimescaleTsKvCompositeKey		org.thingsboard.server.dao.model.sqlts.timescale.ts
# Entity		TsKvDictionaryCompositeKey		org.thingsboard.server.dao.model.sqlts.dictionary
# Entity		TsKvDictionary		org.thingsboard.server.dao.model.sqlts.dictionary
# Entity		DeviceEntity		org.thingsboard.server.dao.model.nosql
# Entity		DashboardEntity		org.thingsboard.server.dao.model.nosql
# Entity		AdminSettingsEntity		org.thingsboard.server.dao.model.nosql
# Entity		WidgetTypeEntity		org.thingsboard.server.dao.model.nosql
# Entity		TenantEntity		org.thingsboard.server.dao.model.nosql
# Entity		CustomerEntity		org.thingsboard.server.dao.model.nosql
# Entity		WidgetsBundleEntity		org.thingsboard.server.dao.model.nosql
# Entity		ComponentDescriptorEntity		org.thingsboard.server.dao.model.nosql
# Entity		UserEntity		org.thingsboard.server.dao.model.nosql
# Entity		RuleNodeEntity		org.thingsboard.server.dao.model.nosql
# Entity		DashboardInfoEntity		org.thingsboard.server.dao.model.nosql
# Entity		EntityViewEntity		org.thingsboard.server.dao.model.nosql
# Entity		DeviceCredentialsEntity		org.thingsboard.server.dao.model.nosql
# Entity		RuleChainEntity		org.thingsboard.server.dao.model.nosql
# Entity		AlarmEntity		org.thingsboard.server.dao.model.nosql
# Entity		AssetEntity		org.thingsboard.server.dao.model.nosql
# Entity		UserCredentialsEntity		org.thingsboard.server.dao.model.nosql
# Entity		EventEntity		org.thingsboard.server.dao.model.nosql
# Entity		AuditLogEntity		org.thingsboard.server.dao.model.nosql
# Entity		AbstractEntityService		org.thingsboard.server.dao.entity
# Logic		BaseEntityService		org.thingsboard.server.dao.entity
# Entity		AssetTypeFilter		org.thingsboard.server.dao.asset
# Logic		CassandraAssetDao		org.thingsboard.server.dao.asset
# Interface	AssetDao		org.thingsboard.server.dao.asset
# Logic		BaseAssetService		org.thingsboard.server.dao.asset
# Logic		BaseEventService		org.thingsboard.server.dao.event
# Interface	EventDao		org.thingsboard.server.dao.event
# Logic		CassandraBaseEventDao		org.thingsboard.server.dao.event
# Interface	CustomerDao		org.thingsboard.server.dao.customer
# Logic		CassandraCustomerDao		org.thingsboard.server.dao.customer
# Logic		CustomerServiceImpl		org.thingsboard.server.dao.customer
# Entity		BufferLimitException		org.thingsboard.server.dao.exception
# Entity		DatabaseException		org.thingsboard.server.dao.exception
# Entity		DataValidationException		org.thingsboard.server.dao.exception
# Entity		IncorrectParameterException		org.thingsboard.server.dao.exception

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		ThingsboardMqttTransportApplication		org.thingsboard.server.mqtt
# Entity		ThingsboardCoapTransportApplication		org.thingsboard.server.coap
# Entity		ThingsboardServerApplication		org.thingsboard.server
# Entity		ThingsboardInstallApplication		org.thingsboard.server
# Entity		ThingsboardInstallException		org.thingsboard.server.install
# Entity		ToDeviceRpcRequestActorMsg		org.thingsboard.server.service.rpc
# Entity		FromDeviceRpcResponse		org.thingsboard.server.service.rpc
# Entity		LocalRequestMetaData		org.thingsboard.server.service.rpc
# Entity		JsInvokeResponse		org.thingsboard.server.service.script
# Entity		RuleNodeJsScriptEngine		org.thingsboard.server.service.script
# Entity		RuleNodeScriptFactory		org.thingsboard.server.service.script
# Entity		JsInvokeRequest		org.thingsboard.server.service.script
# Entity		JsStatCallback		org.thingsboard.server.service.script
# Entity		AbstractNashornJsInvokeService		org.thingsboard.server.service.script
# Entity		RemoteJsRequestEncoder		org.thingsboard.server.service.script
# Entity		RemoteJsResponseDecoder		org.thingsboard.server.service.script
# Entity		AbstractJsInvokeService		org.thingsboard.server.service.script
# Entity		ValidationResult		org.thingsboard.server.service.security
# Entity		ValidationCallback		org.thingsboard.server.service.security
# Entity		AbstractPermissions		org.thingsboard.server.service.security.permission
# Entity		SecurityUser		org.thingsboard.server.service.security.model
# Entity		UserPrincipal		org.thingsboard.server.service.security.model
# Entity		RawAccessJwtToken		org.thingsboard.server.service.security.model.token
# Entity		AccessJwtToken		org.thingsboard.server.service.security.model.token
# Entity		JwtAuthenticationToken		org.thingsboard.server.service.security.auth
# Entity		AbstractJwtAuthenticationToken		org.thingsboard.server.service.security.auth
# Entity		RefreshAuthenticationToken		org.thingsboard.server.service.security.auth
# Entity		AbstractOAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Entity		RefreshTokenRequest		org.thingsboard.server.service.security.auth.jwt
# Entity		RefreshTokenProcessingFilter		org.thingsboard.server.service.security.auth.jwt
# Entity		JwtTokenAuthenticationProcessingFilter		org.thingsboard.server.service.security.auth.jwt
# Entity		SkipPathRequestMatcher		org.thingsboard.server.service.security.auth.jwt
# Entity		RestAuthenticationDetails		org.thingsboard.server.service.security.auth.rest
# Entity		RestAuthenticationDetailsSource		org.thingsboard.server.service.security.auth.rest
# Entity		LoginRequest		org.thingsboard.server.service.security.auth.rest
# Entity		PublicLoginRequest		org.thingsboard.server.service.security.auth.rest
# Entity		RestPublicLoginProcessingFilter		org.thingsboard.server.service.security.auth.rest
# Entity		RestLoginProcessingFilter		org.thingsboard.server.service.security.auth.rest
# Entity		AuthMethodNotSupportedException		org.thingsboard.server.service.security.exception
# Entity		JwtExpiredTokenException		org.thingsboard.server.service.security.exception
# Entity		UserPasswordExpiredException		org.thingsboard.server.service.security.exception
# Entity		AbstractCleanUpService		org.thingsboard.server.service.ttl
# Entity		AbstractTimeseriesCleanUpService		org.thingsboard.server.service.ttl.timeseries
# Entity		SqlAbstractDatabaseSchemaService		org.thingsboard.server.service.install
# Entity		CassandraAbstractDatabaseSchemaService		org.thingsboard.server.service.install
# Entity		AbstractSqlTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Entity		AbstractCassandraDatabaseUpgradeService		org.thingsboard.server.service.install
# Entity		DatabaseHelper		org.thingsboard.server.service.install
# Entity		SqlDbHelper		org.thingsboard.server.service.install.sql
# Entity		CQLStatementsParser		org.thingsboard.server.service.install.cql
# Entity		CassandraDbHelper		org.thingsboard.server.service.install.cql
# Entity		PaginatedUpdater		org.thingsboard.server.service.install.update
# Entity		TransportToDeviceActorMsgWrapper		org.thingsboard.server.service.transport.msg
# Entity		DeviceStateData		org.thingsboard.server.service.state
# Entity		DeviceState		org.thingsboard.server.service.state
# Entity		TelemetryWebSocketTextMsg		org.thingsboard.server.service.telemetry
# Entity		AttributeData		org.thingsboard.server.service.telemetry
# Entity		SessionEvent		org.thingsboard.server.service.telemetry
# Entity		TsData		org.thingsboard.server.service.telemetry
# Entity		TelemetryWebSocketSessionRef		org.thingsboard.server.service.telemetry
# Entity		WsSessionMetaData		org.thingsboard.server.service.telemetry
# Entity		GetHistoryCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		AttributesSubscriptionCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		SubscriptionCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		TelemetryPluginCmdsWrapper		org.thingsboard.server.service.telemetry.cmd
# Entity		TimeseriesSubscriptionCmd		org.thingsboard.server.service.telemetry.cmd
# Entity		SubscriptionUpdate		org.thingsboard.server.service.telemetry.sub
# Entity		SubscriptionState		org.thingsboard.server.service.telemetry.sub
# Entity		EntityNotFoundException		org.thingsboard.server.service.telemetry.exception
# Entity		UncheckedApiException		org.thingsboard.server.service.telemetry.exception
# Entity		UnauthorizedException		org.thingsboard.server.service.telemetry.exception
# Entity		AccessDeniedException		org.thingsboard.server.service.telemetry.exception
# Entity		InternalErrorException		org.thingsboard.server.service.telemetry.exception
# Entity		InvalidParametersException		org.thingsboard.server.service.telemetry.exception
# Entity		TbTimeseriesSubscription		org.thingsboard.server.service.subscription
# Entity		TbSubscription		org.thingsboard.server.service.subscription
# Entity		TbAttributeSubscription		org.thingsboard.server.service.subscription
# Entity		TbSubscriptionUtils		org.thingsboard.server.service.subscription
# Entity		TbMsgPackCallback		org.thingsboard.server.service.queue
# Entity		TbMsgPackProcessingContext		org.thingsboard.server.service.queue
# Entity		TbMsgProfilerInfo		org.thingsboard.server.service.queue
# Entity		TbCoreConsumerStats		org.thingsboard.server.service.queue
# Entity		TbPackCallback		org.thingsboard.server.service.queue
# Entity		TbTenantRuleEngineStats		org.thingsboard.server.service.queue
# Entity		TbRuleNodeProfilerInfo		org.thingsboard.server.service.queue
# Entity		TbRuleEngineConsumerStats		org.thingsboard.server.service.queue
# Entity		TbPackProcessingContext		org.thingsboard.server.service.queue
# Entity		SequentialByEntityIdTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		SequentialByTenantIdTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		IdMsgPair		org.thingsboard.server.service.queue.processing
# Entity		SequentialByOriginatorIdTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		AbstractConsumerService		org.thingsboard.server.service.queue.processing
# Entity		SequentialTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		TbRuleEngineProcessingDecision		org.thingsboard.server.service.queue.processing
# Entity		AbstractTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		TbRuleEngineProcessingResult		org.thingsboard.server.service.queue.processing
# Entity		BurstTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		BatchTbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Entity		BaseController		org.thingsboard.server.controller
# Entity		TbUrlConstants		org.thingsboard.server.controller
# Entity		HttpValidationCallback		org.thingsboard.server.controller
# Entity		MiscUtils		org.thingsboard.server.utils
# Entity		TbEntityTypeActorIdPredicate		org.thingsboard.server.actors
# Entity		ActorTerminationMsg		org.thingsboard.server.actors.shared
# Entity		ComponentMsgProcessor		org.thingsboard.server.actors.shared
# Entity		AbstractContextAwareMsgProcessor		org.thingsboard.server.actors.shared
# Entity		ContextBasedCreator		org.thingsboard.server.actors.service
# Entity		ContextAwareActor		org.thingsboard.server.actors.service
# Entity		ComponentActor		org.thingsboard.server.actors.service
# Entity		SessionInfo		org.thingsboard.server.actors.device
# Entity		ToServerRpcRequestMetadata		org.thingsboard.server.actors.device
# Entity		DeviceActorCreator		org.thingsboard.server.actors.device
# Entity		SessionTimeoutCheckMsg		org.thingsboard.server.actors.device
# Entity		SessionInfoMetaData		org.thingsboard.server.actors.device
# Entity		DeviceActor		org.thingsboard.server.actors.device
# Entity		DeviceActorMessageProcessor		org.thingsboard.server.actors.device
# Entity		ToDeviceRpcRequestMetadata		org.thingsboard.server.actors.device
# Entity		TenantActor		org.thingsboard.server.actors.tenant
# Entity		DebugTbRateLimits		org.thingsboard.server.actors.tenant
# Entity		RuleChainToRuleNodeMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeRelation		org.thingsboard.server.actors.ruleChain
# Entity		DefaultTbContext		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainActorMessageProcessor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeCtx		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeToRuleChainTellNextMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainToRuleChainMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainActor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeActor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeToSelfErrorMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleChainManagerActor		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeToSelfMsg		org.thingsboard.server.actors.ruleChain
# Entity		RuleNodeActorMessageProcessor		org.thingsboard.server.actors.ruleChain
# Entity		StatsActor		org.thingsboard.server.actors.stats
# Entity		StatsPersistMsg		org.thingsboard.server.actors.stats
# Entity		StatsPersistTick		org.thingsboard.server.actors.stats
# Entity		AppActor		org.thingsboard.server.actors.app
# Entity		AppInitMsg		org.thingsboard.server.actors.app
# Entity		ThingsboardErrorResponse		org.thingsboard.server.exception
# Entity		ThingsboardCredentialsExpiredResponse		org.thingsboard.server.exception
# Entity		TbSendRpcRequestNodeConfiguration		org.thingsboard.rule.engine.rpc
# Entity		TbSendRPCReplyNode		org.thingsboard.rule.engine.rpc
# Entity		TbSendRpcReplyNodeConfiguration		org.thingsboard.rule.engine.rpc
# Entity		TbSendRPCRequestNode		org.thingsboard.rule.engine.rpc
# Entity		TbMqttNodeConfiguration		org.thingsboard.rule.engine.mqtt
# Entity		TbMqttNode		org.thingsboard.rule.engine.mqtt
# Entity		TbAzureIotHubNode		org.thingsboard.rule.engine.mqtt.azure
# Entity		AzureIotHubSasCredentials		org.thingsboard.rule.engine.mqtt.azure
# Entity		TbAzureIotHubNodeConfiguration		org.thingsboard.rule.engine.mqtt.azure
# Entity		AnonymousCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		BasicCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		CertPemClientCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Entity		TbPubSubNodeConfiguration		org.thingsboard.rule.engine.gcp.pubsub
# Entity		TbPubSubNode		org.thingsboard.rule.engine.gcp.pubsub
# Entity		TbMsgTypeFilterNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbJsSwitchNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbCheckMessageNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbCheckMessageNode		org.thingsboard.rule.engine.filter
# Entity		TbMsgTypeSwitchNode		org.thingsboard.rule.engine.filter
# Entity		TbJsSwitchNode		org.thingsboard.rule.engine.filter
# Entity		TbCheckAlarmStatusNode		org.thingsboard.rule.engine.filter
# Entity		TbOriginatorTypeFilterNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbCheckRelationNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbMsgTypeFilterNode		org.thingsboard.rule.engine.filter
# Entity		TbOriginatorTypeSwitchNode		org.thingsboard.rule.engine.filter
# Entity		TbJsFilterNodeConfiguration		org.thingsboard.rule.engine.filter
# Entity		TbOriginatorTypeFilterNode		org.thingsboard.rule.engine.filter
# Entity		TbCheckAlarmStatusNodeConfig		org.thingsboard.rule.engine.filter
# Entity		TbJsFilterNode		org.thingsboard.rule.engine.filter
# Entity		TbCheckRelationNode		org.thingsboard.rule.engine.filter
# Entity		EntitiesTenantIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesRelatedDeviceIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesCustomerIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesRelatedEntityIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntitiesFieldsAsyncLoader		org.thingsboard.rule.engine.util
# Entity		EntityContainer		org.thingsboard.rule.engine.util
# Entity		EntitiesAlarmOriginatorIdAsyncLoader		org.thingsboard.rule.engine.util
# Entity		TbSendEmailNode		org.thingsboard.rule.engine.mail
# Entity		TbMsgToEmailNodeConfiguration		org.thingsboard.rule.engine.mail
# Entity		TbMsgToEmailNode		org.thingsboard.rule.engine.mail
# Entity		TbSendEmailNodeConfiguration		org.thingsboard.rule.engine.mail
# Entity		EmailPojo		org.thingsboard.rule.engine.mail
# Entity		TbLogNode		org.thingsboard.rule.engine.action
# Entity		TbCreateRelationNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbDeleteRelationNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbMsgCountNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbAssignToCustomerNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractAlarmNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbCopyAttributesToEntityViewNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractCustomerActionNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractAlarmNode		org.thingsboard.rule.engine.action
# Entity		TbLogNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbUnassignFromCustomerNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbUnassignFromCustomerNode		org.thingsboard.rule.engine.action
# Entity		TbMsgCountNode		org.thingsboard.rule.engine.action
# Entity		TbCreateAlarmNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbCreateAlarmNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractRelationActionNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbAbstractRelationActionNode		org.thingsboard.rule.engine.action
# Entity		TbAbstractCustomerActionNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbClearAlarmNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbSaveToCustomCassandraTableNode		org.thingsboard.rule.engine.action
# Entity		TbAssignToCustomerNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbCreateRelationNode		org.thingsboard.rule.engine.action
# Entity		TbClearAlarmNode		org.thingsboard.rule.engine.action
# Entity		TbDeleteRelationNode		org.thingsboard.rule.engine.action
# Entity		TbSaveToCustomCassandraTableNodeConfiguration		org.thingsboard.rule.engine.action
# Entity		TbMsgDelayNode		org.thingsboard.rule.engine.delay
# Entity		TbMsgDelayNodeConfiguration		org.thingsboard.rule.engine.delay
# Entity		RelationsQuery		org.thingsboard.rule.engine.data
# Entity		DeviceRelationsQuery		org.thingsboard.rule.engine.data
# Entity		TbMsgAttributesNodeConfiguration		org.thingsboard.rule.engine.telemetry
# Entity		TbMsgTimeseriesNode		org.thingsboard.rule.engine.telemetry
# Entity		TbMsgAttributesNode		org.thingsboard.rule.engine.telemetry
# Entity		TelemetryNodeCallback		org.thingsboard.rule.engine.telemetry
# Entity		TbMsgTimeseriesNodeConfiguration		org.thingsboard.rule.engine.telemetry
# Entity		TbSqsNode		org.thingsboard.rule.engine.aws.sqs
# Entity		TbSqsNodeConfiguration		org.thingsboard.rule.engine.aws.sqs
# Entity		TbSnsNode		org.thingsboard.rule.engine.aws.sns
# Entity		TbSnsNodeConfiguration		org.thingsboard.rule.engine.aws.sns
# Entity		TbRestApiCallNodeConfiguration		org.thingsboard.rule.engine.rest
# Entity		TbRestApiCallNode		org.thingsboard.rule.engine.rest
# Entity		TbHttpClient		org.thingsboard.rule.engine.rest
# Entity		Coordinates		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingActionNode		org.thingsboard.rule.engine.geo
# Entity		AbstractGeofencingNode		org.thingsboard.rule.engine.geo
# Entity		GeoUtil		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingActionNodeConfiguration		org.thingsboard.rule.engine.geo
# Entity		EntityGeofencingState		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingFilterNode		org.thingsboard.rule.engine.geo
# Entity		Perimeter		org.thingsboard.rule.engine.geo
# Entity		TbGpsGeofencingFilterNodeConfiguration		org.thingsboard.rule.engine.geo
# Entity		TbMsgGeneratorNode		org.thingsboard.rule.engine.debug
# Entity		TbMsgGeneratorNodeConfiguration		org.thingsboard.rule.engine.debug
# Entity		TbTransformNodeConfiguration		org.thingsboard.rule.engine.transform
# Entity		TbAbstractTransformNode		org.thingsboard.rule.engine.transform
# Entity		TbTransformMsgNodeConfiguration		org.thingsboard.rule.engine.transform
# Entity		TbChangeOriginatorNodeConfiguration		org.thingsboard.rule.engine.transform
# Entity		TbTransformMsgNode		org.thingsboard.rule.engine.transform
# Entity		TbChangeOriginatorNode		org.thingsboard.rule.engine.transform
# Entity		TbRabbitMqNode		org.thingsboard.rule.engine.rabbitmq
# Entity		TbRabbitMqNodeConfiguration		org.thingsboard.rule.engine.rabbitmq
# Entity		TbSynchronizationBeginNode		org.thingsboard.rule.engine.transaction
# Entity		TbSynchronizationEndNode		org.thingsboard.rule.engine.transaction
# Entity		TbGetTenantDetailsNode		org.thingsboard.rule.engine.metadata
# Entity		TbAbstractGetEntityDetailsNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetRelatedAttrNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetTenantAttributeNode		org.thingsboard.rule.engine.metadata
# Entity		TbAbstractGetAttributesNode		org.thingsboard.rule.engine.metadata
# Entity		TbAbstractGetEntityDetailsNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetOriginatorFieldsNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetTenantDetailsNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetCustomerAttributeNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetDeviceAttrNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetAttributesNode		org.thingsboard.rule.engine.metadata
# Entity		TbEntityGetAttrNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetAttributesNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetTelemetryNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetTelemetryNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetDeviceAttrNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetOriginatorFieldsConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetEntityAttrNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetCustomerDetailsNode		org.thingsboard.rule.engine.metadata
# Entity		TbGetCustomerDetailsNodeConfiguration		org.thingsboard.rule.engine.metadata
# Entity		TbGetRelatedAttributeNode		org.thingsboard.rule.engine.metadata
# Entity		TbKafkaNodeConfiguration		org.thingsboard.rule.engine.kafka
# Entity		TbKafkaNode		org.thingsboard.rule.engine.kafka
# Entity		TbCheckpointNodeConfiguration		org.thingsboard.rule.engine.flow
# Entity		TbAckNode		org.thingsboard.rule.engine.flow
# Entity		TbCheckpointNode		org.thingsboard.rule.engine.flow
# Entity		TbNodeConfiguration		org.thingsboard.rule.engine.api
# Entity		EmptyNodeConfiguration		org.thingsboard.rule.engine.api
# Entity		NodeDefinition		org.thingsboard.rule.engine.api
# Entity		RuleEngineDeviceRpcRequest		org.thingsboard.rule.engine.api
# Entity		RuleEngineDeviceRpcResponse		org.thingsboard.rule.engine.api
# Entity		TbNodeState		org.thingsboard.rule.engine.api
# Entity		TbNodeException		org.thingsboard.rule.engine.api
# Entity		TbRelationTypes		org.thingsboard.rule.engine.api
# Entity		DeviceAttributesEventNotificationMsg		org.thingsboard.rule.engine.api.msg
# Entity		DeviceNameOrTypeUpdateMsg		org.thingsboard.rule.engine.api.msg
# Entity		DeviceAttributes		org.thingsboard.rule.engine.api.msg
# Entity		DeviceMetaData		org.thingsboard.rule.engine.api.msg
# Entity		DeviceCredentialsUpdateNotificationMsg		org.thingsboard.rule.engine.api.msg
# Entity		TbNodeUtils		org.thingsboard.rule.engine.api.util
# Entity		AbstractListeningExecutor		org.thingsboard.common.util
# Entity		AzureIotHubUtil		org.thingsboard.common.util
# Entity		ThingsBoardThreadFactory		org.thingsboard.common.util
# Entity		DonAsynchron		org.thingsboard.common.util
# Entity		MqttTransportHandler		org.thingsboard.server.transport.mqtt
# Entity		MqttTransportServerInitializer		org.thingsboard.server.transport.mqtt
# Entity		MqttTopics		org.thingsboard.server.transport.mqtt
# Entity		SslUtil		org.thingsboard.server.transport.mqtt.util
# Entity		DeviceSessionCtx		org.thingsboard.server.transport.mqtt.session
# Entity		GatewayDeviceSessionCtx		org.thingsboard.server.transport.mqtt.session
# Entity		MqttDeviceAwareSessionContext		org.thingsboard.server.transport.mqtt.session
# Entity		GatewaySessionHandler		org.thingsboard.server.transport.mqtt.session
# Entity		MqttTopicMatcher		org.thingsboard.server.transport.mqtt.session
# Entity		AdaptorException		org.thingsboard.server.common.transport.adaptor
# Entity		JsonConverter		org.thingsboard.server.common.transport.adaptor
# Entity		ToTransportMsgResponseDecoder		org.thingsboard.server.common.transport.service
# Entity		SessionMetaData		org.thingsboard.server.common.transport.service
# Entity		ToRuleEngineMsgEncoder		org.thingsboard.server.common.transport.service
# Entity		TransportApiResponseDecoder		org.thingsboard.server.common.transport.service
# Entity		RpcRequestMetadata		org.thingsboard.server.common.transport.service
# Entity		TransportApiRequestEncoder		org.thingsboard.server.common.transport.service
# Entity		JsonUtils		org.thingsboard.server.common.transport.util
# Entity		DeviceAwareSessionContext		org.thingsboard.server.common.transport.session
# Entity		DeviceAuthResult		org.thingsboard.server.common.transport.auth
# Entity		CoapTransportResource		org.thingsboard.server.transport.coap
# Entity		DeviceEmulator		org.thingsboard.server.transport.coap.client
# Entity		DataConstants		org.thingsboard.server.common.data
# Entity		ContactBased		org.thingsboard.server.common.data
# Entity		ShortCustomerInfo		org.thingsboard.server.common.data
# Entity		Device		org.thingsboard.server.common.data
# Entity		DashboardInfo		org.thingsboard.server.common.data
# Entity		BaseData		org.thingsboard.server.common.data
# Entity		EntityFieldsData		org.thingsboard.server.common.data
# Entity		ClaimRequest		org.thingsboard.server.common.data
# Entity		AdminSettings		org.thingsboard.server.common.data
# Entity		Dashboard		org.thingsboard.server.common.data
# Entity		SearchTextBasedWithAdditionalInfo		org.thingsboard.server.common.data
# Entity		EntityView		org.thingsboard.server.common.data
# Entity		User		org.thingsboard.server.common.data
# Entity		UpdateMessage		org.thingsboard.server.common.data
# Entity		EntitySubtype		org.thingsboard.server.common.data
# Entity		CacheConstants		org.thingsboard.server.common.data
# Entity		SearchTextBased		org.thingsboard.server.common.data
# Entity		UUIDConverter		org.thingsboard.server.common.data
# Entity		Customer		org.thingsboard.server.common.data
# Entity		Event		org.thingsboard.server.common.data
# Entity		Tenant		org.thingsboard.server.common.data
# Entity		EntityRelationsQuery		org.thingsboard.server.common.data.relation
# Entity		EntityTypeFilter		org.thingsboard.server.common.data.relation
# Entity		EntityRelation		org.thingsboard.server.common.data.relation
# Entity		RelationsSearchParameters		org.thingsboard.server.common.data.relation
# Entity		EntityRelationInfo		org.thingsboard.server.common.data.relation
# Entity		RpcRequest		org.thingsboard.server.common.data.rpc
# Entity		ToDeviceRpcRequestBody		org.thingsboard.server.common.data.rpc
# Entity		DeviceTokenCredentials		org.thingsboard.server.common.data.security
# Entity		UserCredentials		org.thingsboard.server.common.data.security
# Entity		DeviceCredentials		org.thingsboard.server.common.data.security
# Entity		DeviceX509Credentials		org.thingsboard.server.common.data.security
# Entity		SecuritySettings		org.thingsboard.server.common.data.security.model
# Entity		UserPasswordPolicy		org.thingsboard.server.common.data.security.model
# Entity		AuditLog		org.thingsboard.server.common.data.audit
# Entity		WidgetType		org.thingsboard.server.common.data.widget
# Entity		WidgetsBundle		org.thingsboard.server.common.data.widget
# Entity		BasicTsKvEntry		org.thingsboard.server.common.data.kv
# Entity		StringDataEntry		org.thingsboard.server.common.data.kv
# Entity		BaseDeleteTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		LongDataEntry		org.thingsboard.server.common.data.kv
# Entity		BaseReadTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		BaseAttributeKvEntry		org.thingsboard.server.common.data.kv
# Entity		JsonDataEntry		org.thingsboard.server.common.data.kv
# Entity		DoubleDataEntry		org.thingsboard.server.common.data.kv
# Entity		BaseTsKvQuery		org.thingsboard.server.common.data.kv
# Entity		BasicKvEntry		org.thingsboard.server.common.data.kv
# Entity		AttributeKey		org.thingsboard.server.common.data.kv
# Entity		BooleanDataEntry		org.thingsboard.server.common.data.kv
# Entity		OAuth2ClientInfo		org.thingsboard.server.common.data.oauth2
# Entity		DeviceSearchQuery		org.thingsboard.server.common.data.device
# Entity		RuleChain		org.thingsboard.server.common.data.rule
# Entity		RuleChainMetaData		org.thingsboard.server.common.data.rule
# Entity		RuleChainConnectionInfo		org.thingsboard.server.common.data.rule
# Entity		NodeConnectionInfo		org.thingsboard.server.common.data.rule
# Entity		RuleNode		org.thingsboard.server.common.data.rule
# Entity		EntityViewSearchQuery		org.thingsboard.server.common.data.entityview
# Entity		AlarmQuery		org.thingsboard.server.common.data.alarm
# Entity		Alarm		org.thingsboard.server.common.data.alarm
# Entity		AlarmInfo		org.thingsboard.server.common.data.alarm
# Entity		ComponentDescriptor		org.thingsboard.server.common.data.plugin
# Entity		AuditLogId		org.thingsboard.server.common.data.id
# Entity		WidgetsBundleId		org.thingsboard.server.common.data.id
# Entity		UserCredentialsId		org.thingsboard.server.common.data.id
# Entity		EntityIdDeserializer		org.thingsboard.server.common.data.id
# Entity		RuleChainId		org.thingsboard.server.common.data.id
# Entity		UserId		org.thingsboard.server.common.data.id
# Entity		CustomerId		org.thingsboard.server.common.data.id
# Entity		RuleNodeId		org.thingsboard.server.common.data.id
# Entity		AdminSettingsId		org.thingsboard.server.common.data.id
# Entity		OAuth2IntegrationId		org.thingsboard.server.common.data.id
# Entity		AssetId		org.thingsboard.server.common.data.id
# Entity		DeviceId		org.thingsboard.server.common.data.id
# Entity		WidgetTypeId		org.thingsboard.server.common.data.id
# Entity		AlarmId		org.thingsboard.server.common.data.id
# Entity		ComponentDescriptorId		org.thingsboard.server.common.data.id
# Entity		EntityIdFactory		org.thingsboard.server.common.data.id
# Entity		EventId		org.thingsboard.server.common.data.id
# Entity		DashboardId		org.thingsboard.server.common.data.id
# Entity		EntityViewId		org.thingsboard.server.common.data.id
# Entity		EntityIdSerializer		org.thingsboard.server.common.data.id
# Entity		TenantId		org.thingsboard.server.common.data.id
# Entity		UUIDBased		org.thingsboard.server.common.data.id
# Entity		NodeId		org.thingsboard.server.common.data.id
# Entity		IdBased		org.thingsboard.server.common.data.id
# Entity		DeviceCredentialsId		org.thingsboard.server.common.data.id
# Entity		TextPageLink		org.thingsboard.server.common.data.page
# Entity		PageDataIterable		org.thingsboard.server.common.data.page
# Entity		TextPageData		org.thingsboard.server.common.data.page
# Entity		TimePageData		org.thingsboard.server.common.data.page
# Entity		TimePageLink		org.thingsboard.server.common.data.page
# Entity		BasePageLink		org.thingsboard.server.common.data.page
# Entity		Asset		org.thingsboard.server.common.data.asset
# Entity		AssetSearchQuery		org.thingsboard.server.common.data.asset
# Entity		ThingsboardException		org.thingsboard.server.common.data.exception
# Entity		TelemetryEntityView		org.thingsboard.server.common.data.objects
# Entity		AttributesEntityView		org.thingsboard.server.common.data.objects
# Entity		OAuth2User		org.thingsboard.server.dao.oauth2
# Entity		ClaimData		org.thingsboard.server.dao.device.claim
# Entity		ClaimResult		org.thingsboard.server.dao.device.claim
# Entity		CassandraStatementTask		org.thingsboard.server.dao.nosql
# Entity		AbstractCassandraCluster		org.thingsboard.server.dao.cassandra
# Entity		StatsCounter		org.thingsboard.server.common.stats
# Entity		DefaultMessagesStats		org.thingsboard.server.common.stats
# Entity		DefaultCounter		org.thingsboard.server.common.stats
# Entity		TbRuleEngineQueueAckStrategyConfiguration		org.thingsboard.server.queue.settings
# Entity		TbRuleEngineQueueConfiguration		org.thingsboard.server.queue.settings
# Entity		TbRuleEngineQueueSubmitStrategyConfiguration		org.thingsboard.server.queue.settings
# Entity		TbServiceBusConsumerTemplate		org.thingsboard.server.queue.azure.servicebus
# Entity		TbServiceBusAdmin		org.thingsboard.server.queue.azure.servicebus
# Entity		TbServiceBusProducerTemplate		org.thingsboard.server.queue.azure.servicebus
# Entity		ClusterTopologyChangeEvent		org.thingsboard.server.queue.discovery
# Entity		ConsistentHashCircle		org.thingsboard.server.queue.discovery
# Entity		TopicPartitionInfoKey		org.thingsboard.server.queue.discovery
# Entity		TenantRoutingInfo		org.thingsboard.server.queue.discovery
# Entity		PartitionChangeEvent		org.thingsboard.server.queue.discovery
# Entity		InMemoryTbQueueProducer		org.thingsboard.server.queue.memory
# Entity		InMemoryTbQueueConsumer		org.thingsboard.server.queue.memory
# Entity		InMemoryStorage		org.thingsboard.server.queue.memory
# Entity		TbPubSubProducerTemplate		org.thingsboard.server.queue.pubsub
# Entity		TbPubSubAdmin		org.thingsboard.server.queue.pubsub
# Entity		TbPubSubConsumerTemplate		org.thingsboard.server.queue.pubsub
# Entity		AbstractTbQueueConsumerTemplate		org.thingsboard.server.queue.common
# Entity		AbstractParallelTbQueueConsumerTemplate		org.thingsboard.server.queue.common
# Entity		TbProtoJsQueueMsg		org.thingsboard.server.queue.common
# Entity		DefaultTbQueueMsgHeaders		org.thingsboard.server.queue.common
# Entity		DefaultTbQueueRequestTemplate		org.thingsboard.server.queue.common
# Entity		AbstractTbQueueTemplate		org.thingsboard.server.queue.common
# Entity		DefaultTbQueueMsg		org.thingsboard.server.queue.common
# Entity		TbProtoQueueMsg		org.thingsboard.server.queue.common
# Entity		TbQueueTbMsgCallbackWrapper		org.thingsboard.server.queue.common
# Entity		DefaultTbQueueResponseTemplate		org.thingsboard.server.queue.common
# Entity		AsyncCallbackTemplate		org.thingsboard.server.queue.common
# Entity		MultipleTbQueueTbMsgCallbackWrapper		org.thingsboard.server.queue.common
# Entity		TbAwsSqsAdmin		org.thingsboard.server.queue.sqs
# Entity		TbAwsSqsProducerTemplate		org.thingsboard.server.queue.sqs
# Entity		AwsSqsTbQueueMsgMetadata		org.thingsboard.server.queue.sqs
# Entity		TbAwsSqsConsumerTemplate		org.thingsboard.server.queue.sqs
# Entity		TbRabbitMqProducerTemplate		org.thingsboard.server.queue.rabbitmq
# Entity		TbRabbitMqConsumerTemplate		org.thingsboard.server.queue.rabbitmq
# Entity		TbRabbitMqAdmin		org.thingsboard.server.queue.rabbitmq
# Entity		TbKafkaConsumerTemplate		org.thingsboard.server.queue.kafka
# Entity		KafkaTbQueueMsgMetadata		org.thingsboard.server.queue.kafka
# Entity		TbKafkaProducerTemplate		org.thingsboard.server.queue.kafka
# Entity		TbKafkaAdmin		org.thingsboard.server.queue.kafka
# Entity		TbKafkaProperty		org.thingsboard.server.queue.kafka
# Entity		KafkaTbQueueMsg		org.thingsboard.server.queue.kafka
# Entity		TbStringActorId		org.thingsboard.server.actors
# Entity		AbstractTbActor		org.thingsboard.server.actors
# Entity		InitFailureStrategy		org.thingsboard.server.actors
# Entity		ProcessFailureStrategy		org.thingsboard.server.actors
# Entity		DefaultTbActorSystem		org.thingsboard.server.actors
# Entity		TbActorException		org.thingsboard.server.actors
# Entity		TbActorNotRegisteredException		org.thingsboard.server.actors
# Entity		TbActorSystemSettings		org.thingsboard.server.actors
# Entity		TbActorMailbox		org.thingsboard.server.actors
# Entity		TbEntityActorId		org.thingsboard.server.actors
# Entity		Dispatcher		org.thingsboard.server.actors
# Entity		TbMsg		org.thingsboard.server.common.msg
# Entity		EncryptionUtil		org.thingsboard.server.common.msg
# Entity		TbMsgMetaData		org.thingsboard.server.common.msg
# Entity		ToDeviceRpcRequest		org.thingsboard.server.common.msg.rpc
# Entity		ProcessingTimeoutException		org.thingsboard.server.common.msg.session.ex
# Entity		SessionException		org.thingsboard.server.common.msg.session.ex
# Entity		SessionAuthException		org.thingsboard.server.common.msg.session.ex
# Entity		TbRateLimits		org.thingsboard.server.common.msg.tools
# Entity		TbRateLimitsException		org.thingsboard.server.common.msg.tools
# Entity		ComponentLifecycleMsg		org.thingsboard.server.common.msg.plugin
# Entity		DeviceActorServerSideRpcTimeoutMsg		org.thingsboard.server.common.msg.timeout
# Entity		TimeoutMsg		org.thingsboard.server.common.msg.timeout
# Entity		ServiceQueueKey		org.thingsboard.server.common.msg.queue
# Entity		RuleNodeException		org.thingsboard.server.common.msg.queue
# Entity		QueueToRuleEngineMsg		org.thingsboard.server.common.msg.queue
# Entity		PartitionChangeMsg		org.thingsboard.server.common.msg.queue
# Entity		ServiceQueue		org.thingsboard.server.common.msg.queue
# Entity		RuleEngineException		org.thingsboard.server.common.msg.queue
# Entity		TopicPartitionInfo		org.thingsboard.server.common.msg.queue
# Entity		RuleNodeInfo		org.thingsboard.server.common.msg.queue
# Entity		MqttClientImpl		org.thingsboard.mqtt
# Entity		MqttChannelHandler		org.thingsboard.mqtt
# Entity		ChannelClosedException		org.thingsboard.mqtt
# Entity		MqttClientConfig		org.thingsboard.mqtt
# Entity		RetransmissionHandler		org.thingsboard.mqtt
# Entity		MqttSubscription		org.thingsboard.mqtt
# Entity		MqttPendingSubscription		org.thingsboard.mqtt
# Entity		MqttPingHandler		org.thingsboard.mqtt
# Entity		MqttConnectResult		org.thingsboard.mqtt
# Entity		MqttPendingPublish		org.thingsboard.mqtt
# Entity		MqttIncomingQos2Publish		org.thingsboard.mqtt
# Entity		MqttPendingUnsubscription		org.thingsboard.mqtt
# Entity		MqttLastWill		org.thingsboard.mqtt
# Entity		DaoUtil		org.thingsboard.server.dao
# Entity		PreviousDeviceCredentialsIdKeyGenerator		org.thingsboard.server.dao.cache
# Entity		CacheSpecs		org.thingsboard.server.dao.cache
# Entity		AuditLogQueryCursor		org.thingsboard.server.dao.audit
# Entity		AuditLogLevelFilter		org.thingsboard.server.dao.audit
# Entity		TbSqlBlockingQueueParams		org.thingsboard.server.dao.sql
# Entity		JpaAbstractSearchTimeDao		org.thingsboard.server.dao.sql
# Entity		TbSqlQueueElement		org.thingsboard.server.dao.sql
# Entity		JpaAbstractDao		org.thingsboard.server.dao.sql
# Entity		TbSqlBlockingQueue		org.thingsboard.server.dao.sql
# Entity		JpaAbstractDaoListeningExecutorService		org.thingsboard.server.dao.sql
# Entity		TbSqlBlockingQueueWrapper		org.thingsboard.server.dao.sql
# Entity		JpaAbstractSearchTextDao		org.thingsboard.server.dao.sql
# Entity		AbstractRelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Entity		AbstractComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Entity		AbstractEventInsertRepository		org.thingsboard.server.dao.sql.event
# Entity		AggregatePartitionsFunction		org.thingsboard.server.dao.timeseries
# Entity		PsqlPartition		org.thingsboard.server.dao.timeseries
# Entity		TsKvQueryCursor		org.thingsboard.server.dao.timeseries
# Entity		QueryCursor		org.thingsboard.server.dao.timeseries
# Entity		SimpleListenableFuture		org.thingsboard.server.dao.timeseries
# Entity		TimePaginatedRemover		org.thingsboard.server.dao.service
# Entity		PaginatedRemover		org.thingsboard.server.dao.service
# Entity		DataValidator		org.thingsboard.server.dao.service
# Entity		Validator		org.thingsboard.server.dao.service
# Entity		TenantRateLimitException		org.thingsboard.server.dao.util
# Entity		AbstractBufferedRateExecutor		org.thingsboard.server.dao.util
# Entity		BufferedRateExecutorStats		org.thingsboard.server.dao.util
# Entity		AsyncTaskContext		org.thingsboard.server.dao.util
# Entity		JacksonUtil		org.thingsboard.server.dao.util.mapping
# Entity		JsonStringSqlTypeDescriptor		org.thingsboard.server.dao.util.mapping
# Entity		JsonTypeDescriptor		org.thingsboard.server.dao.util.mapping
# Entity		AbstractJsonSqlTypeDescriptor		org.thingsboard.server.dao.util.mapping
# Entity		JsonStringType		org.thingsboard.server.dao.util.mapping
# Entity		OAuth2Client		org.thingsboard.server.dao.oauth2
# Entity		OAuth2ClientMapperConfig		org.thingsboard.server.dao.oauth2
# Entity		ClaimDataInfo		org.thingsboard.server.dao.device
# Entity		TsKey		org.thingsboard.server.dao.sqlts
# Entity		AbstractSqlTimeseriesDao		org.thingsboard.server.dao.sqlts
# Entity		EntityContainer		org.thingsboard.server.dao.sqlts
# Entity		AbstractChunkedAggregationTimeseriesDao		org.thingsboard.server.dao.sqlts
# Entity		CassandraAbstractSearchTextDao		org.thingsboard.server.dao.nosql
# Entity		RateLimitedResultSetFuture		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractAsyncDao		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractDao		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractModelDao		org.thingsboard.server.dao.nosql
# Entity		TbResultSetFuture		org.thingsboard.server.dao.nosql
# Entity		CassandraAbstractSearchTimeDao		org.thingsboard.server.dao.nosql
# Entity		EntitySubtypeEntity		org.thingsboard.server.dao.model
# Entity		ModelConstants		org.thingsboard.server.dao.model
# Entity		BaseSqlEntity		org.thingsboard.server.dao.model
# Entity		DeviceEntity		org.thingsboard.server.dao.model.sql
# Entity		DashboardEntity		org.thingsboard.server.dao.model.sql
# Entity		AttributeKvCompositeKey		org.thingsboard.server.dao.model.sql
# Entity		AdminSettingsEntity		org.thingsboard.server.dao.model.sql
# Entity		WidgetTypeEntity		org.thingsboard.server.dao.model.sql
# Entity		TenantEntity		org.thingsboard.server.dao.model.sql
# Entity		AbstractTsKvEntity		org.thingsboard.server.dao.model.sql
# Entity		AttributeKvEntity		org.thingsboard.server.dao.model.sql
# Entity		CustomerEntity		org.thingsboard.server.dao.model.sql
# Entity		WidgetsBundleEntity		org.thingsboard.server.dao.model.sql
# Entity		ComponentDescriptorEntity		org.thingsboard.server.dao.model.sql
# Entity		UserEntity		org.thingsboard.server.dao.model.sql
# Entity		RuleNodeEntity		org.thingsboard.server.dao.model.sql
# Entity		DashboardInfoEntity		org.thingsboard.server.dao.model.sql
# Entity		EntityViewEntity		org.thingsboard.server.dao.model.sql
# Entity		DeviceCredentialsEntity		org.thingsboard.server.dao.model.sql
# Entity		RuleChainEntity		org.thingsboard.server.dao.model.sql
# Entity		AlarmEntity		org.thingsboard.server.dao.model.sql
# Entity		AssetEntity		org.thingsboard.server.dao.model.sql
# Entity		UserCredentialsEntity		org.thingsboard.server.dao.model.sql
# Entity		RelationCompositeKey		org.thingsboard.server.dao.model.sql
# Entity		EventEntity		org.thingsboard.server.dao.model.sql
# Entity		RelationEntity		org.thingsboard.server.dao.model.sql
# Entity		AuditLogEntity		org.thingsboard.server.dao.model.sql
# Entity		EntityResultSet		org.thingsboard.server.dao.model.wrapper
# Entity		DeviceCredentialsTypeCodec		org.thingsboard.server.dao.model.type
# Entity		ActionStatusCodec		org.thingsboard.server.dao.model.type
# Entity		ActionTypeCodec		org.thingsboard.server.dao.model.type
# Entity		AlarmStatusCodec		org.thingsboard.server.dao.model.type
# Entity		JsonCodec		org.thingsboard.server.dao.model.type
# Entity		RelationTypeGroupCodec		org.thingsboard.server.dao.model.type
# Entity		ComponentTypeCodec		org.thingsboard.server.dao.model.type
# Entity		AuthorityCodec		org.thingsboard.server.dao.model.type
# Entity		ComponentLifecycleStateCodec		org.thingsboard.server.dao.model.type
# Entity		ComponentScopeCodec		org.thingsboard.server.dao.model.type
# Entity		EntityTypeCodec		org.thingsboard.server.dao.model.type
# Entity		AlarmSeverityCodec		org.thingsboard.server.dao.model.type
# Entity		TsKvEntity		org.thingsboard.server.dao.model.sqlts.ts
# Entity		TsKvCompositeKey		org.thingsboard.server.dao.model.sqlts.ts
# Entity		TimescaleTsKvEntity		org.thingsboard.server.dao.model.sqlts.timescale.ts
# Entity		TimescaleTsKvCompositeKey		org.thingsboard.server.dao.model.sqlts.timescale.ts
# Entity		TsKvDictionaryCompositeKey		org.thingsboard.server.dao.model.sqlts.dictionary
# Entity		TsKvDictionary		org.thingsboard.server.dao.model.sqlts.dictionary
# Entity		DeviceEntity		org.thingsboard.server.dao.model.nosql
# Entity		DashboardEntity		org.thingsboard.server.dao.model.nosql
# Entity		AdminSettingsEntity		org.thingsboard.server.dao.model.nosql
# Entity		WidgetTypeEntity		org.thingsboard.server.dao.model.nosql
# Entity		TenantEntity		org.thingsboard.server.dao.model.nosql
# Entity		CustomerEntity		org.thingsboard.server.dao.model.nosql
# Entity		WidgetsBundleEntity		org.thingsboard.server.dao.model.nosql
# Entity		ComponentDescriptorEntity		org.thingsboard.server.dao.model.nosql
# Entity		UserEntity		org.thingsboard.server.dao.model.nosql
# Entity		RuleNodeEntity		org.thingsboard.server.dao.model.nosql
# Entity		DashboardInfoEntity		org.thingsboard.server.dao.model.nosql
# Entity		EntityViewEntity		org.thingsboard.server.dao.model.nosql
# Entity		DeviceCredentialsEntity		org.thingsboard.server.dao.model.nosql
# Entity		RuleChainEntity		org.thingsboard.server.dao.model.nosql
# Entity		AlarmEntity		org.thingsboard.server.dao.model.nosql
# Entity		AssetEntity		org.thingsboard.server.dao.model.nosql
# Entity		UserCredentialsEntity		org.thingsboard.server.dao.model.nosql
# Entity		EventEntity		org.thingsboard.server.dao.model.nosql
# Entity		AuditLogEntity		org.thingsboard.server.dao.model.nosql
# Entity		AbstractEntityService		org.thingsboard.server.dao.entity
# Entity		AssetTypeFilter		org.thingsboard.server.dao.asset
# Entity		BufferLimitException		org.thingsboard.server.dao.exception
# Entity		DatabaseException		org.thingsboard.server.dao.exception
# Entity		DataValidationException		org.thingsboard.server.dao.exception
# Entity		IncorrectParameterException		org.thingsboard.server.dao.exception
# Logic		ThingsboardInstallService		org.thingsboard.server.install
# Logic		DefaultTbRuleEngineRpcService		org.thingsboard.server.service.rpc
# Logic		DefaultTbCoreDeviceRpcService		org.thingsboard.server.service.rpc
# Logic		AnnotationComponentDiscoveryService		org.thingsboard.server.service.component
# Logic		JsExecutorService		org.thingsboard.server.service.script
# Logic		NashornJsInvokeService		org.thingsboard.server.service.script
# Logic		RemoteJsInvokeService		org.thingsboard.server.service.script
# Logic		AccessValidator		org.thingsboard.server.service.security
# Logic		SysAdminPermissions		org.thingsboard.server.service.security.permission
# Logic		CustomerUserPermissions		org.thingsboard.server.service.security.permission
# Logic		DefaultAccessControlService		org.thingsboard.server.service.security.permission
# Logic		TenantAdminPermissions		org.thingsboard.server.service.security.permission
# Logic		DefaultDeviceAuthService		org.thingsboard.server.service.security.device
# Logic		JwtTokenFactory		org.thingsboard.server.service.security.model.token
# Logic		Oauth2AuthenticationSuccessHandler		org.thingsboard.server.service.security.auth.oauth2
# Logic		OAuth2ClientMapperProvider		org.thingsboard.server.service.security.auth.oauth2
# Logic		Oauth2AuthenticationFailureHandler		org.thingsboard.server.service.security.auth.oauth2
# Logic		BasicOAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Logic		CustomOAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Logic		RefreshTokenRepository		org.thingsboard.server.service.security.auth.jwt
# Logic		RefreshTokenAuthenticationProvider		org.thingsboard.server.service.security.auth.jwt
# Logic		JwtAuthenticationProvider		org.thingsboard.server.service.security.auth.jwt
# Logic		JwtHeaderTokenExtractor		org.thingsboard.server.service.security.auth.jwt.extractor
# Logic		JwtQueryTokenExtractor		org.thingsboard.server.service.security.auth.jwt.extractor
# Logic		RestAwareAuthenticationFailureHandler		org.thingsboard.server.service.security.auth.rest
# Logic		RestAuthenticationProvider		org.thingsboard.server.service.security.auth.rest
# Logic		RestAwareAuthenticationSuccessHandler		org.thingsboard.server.service.security.auth.rest
# Logic		DefaultSystemSecurityService		org.thingsboard.server.service.security.system
# Logic		ExternalCallExecutorService		org.thingsboard.server.service.executors
# Logic		DbCallbackExecutorService		org.thingsboard.server.service.executors
# Logic		SharedEventLoopGroupService		org.thingsboard.server.service.executors
# Logic		TimescaleTimeseriesCleanUpService		org.thingsboard.server.service.ttl.timeseries
# Logic		PsqlTimeseriesCleanUpService		org.thingsboard.server.service.ttl.timeseries
# Logic		EventsCleanUpService		org.thingsboard.server.service.ttl.events
# Logic		CassandraTsDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		CassandraEntityDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		CassandraTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		PsqlEntityDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		HsqlTsDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		InstallScripts		org.thingsboard.server.service.install
# Logic		HsqlEntityDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		DefaultSystemDataLoaderService		org.thingsboard.server.service.install
# Logic		TimescaleTsDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		SqlDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		CassandraDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		PsqlTsDatabaseSchemaService		org.thingsboard.server.service.install
# Logic		PsqlTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		TimescaleTsDatabaseUpgradeService		org.thingsboard.server.service.install
# Logic		DefaultDataUpdateService		org.thingsboard.server.service.install.update
# Logic		TbCoreTransportApiService		org.thingsboard.server.service.transport
# Logic		DefaultTbCoreToTransportService		org.thingsboard.server.service.transport
# Logic		DefaultTransportApiService		org.thingsboard.server.service.transport
# Logic		DefaultMailService		org.thingsboard.server.service.mail
# Logic		MailExecutorService		org.thingsboard.server.service.mail
# Logic		ProtoWithFSTService		org.thingsboard.server.service.encoding
# Logic		DefaultDeviceSessionCacheService		org.thingsboard.server.service.session
# Logic		DefaultDeviceStateService		org.thingsboard.server.service.state
# Logic		DefaultUpdateService		org.thingsboard.server.service.update
# Logic		DefaultTelemetryWebSocketService		org.thingsboard.server.service.telemetry
# Logic		DefaultTelemetrySubscriptionService		org.thingsboard.server.service.telemetry
# Logic		DefaultSubscriptionManagerService		org.thingsboard.server.service.subscription
# Logic		DefaultTbLocalSubscriptionService		org.thingsboard.server.service.subscription
# Logic		DefaultRuleEngineStatisticsService		org.thingsboard.server.service.stats
# Logic		DefaultJsInvokeStats		org.thingsboard.server.service.stats
# Logic		DefaultTenantRoutingInfoService		org.thingsboard.server.service.queue
# Logic		DefaultTbCoreConsumerService		org.thingsboard.server.service.queue
# Logic		DefaultTbRuleEngineConsumerService		org.thingsboard.server.service.queue
# Logic		DefaultTbClusterService		org.thingsboard.server.service.queue
# Logic		TbRuleEngineSubmitStrategyFactory		org.thingsboard.server.service.queue.processing
# Logic		TbRuleEngineProcessingStrategyFactory		org.thingsboard.server.service.queue.processing
# Logic		AssetController		org.thingsboard.server.controller
# Logic		DashboardController		org.thingsboard.server.controller
# Logic		EntityRelationController		org.thingsboard.server.controller
# Logic		UserController		org.thingsboard.server.controller
# Logic		DeviceController		org.thingsboard.server.controller
# Logic		AuditLogController		org.thingsboard.server.controller
# Logic		AuthController		org.thingsboard.server.controller
# Logic		TenantController		org.thingsboard.server.controller
# ...
# Logic		JpaPsqlTimeseriesDao		org.thingsboard.server.dao.sqlts.psql
# Logic		CassandraBufferedRateExecutor		org.thingsboard.server.dao.nosql
# Logic		CassandraTenantDao		org.thingsboard.server.dao.tenant
# Logic		TenantServiceImpl		org.thingsboard.server.dao.tenant
# Logic		BaseEntityService		org.thingsboard.server.dao.entity
# Logic		CassandraAssetDao		org.thingsboard.server.dao.asset
# Logic		BaseAssetService		org.thingsboard.server.dao.asset
# Logic		BaseEventService		org.thingsboard.server.dao.event
# Logic		CassandraBaseEventDao		org.thingsboard.server.dao.event
# Logic		CassandraCustomerDao		org.thingsboard.server.dao.customer
# Logic		CustomerServiceImpl		org.thingsboard.server.dao.customer
# Repository (cls)	HsqlRelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Repository (cls)	PsqlRelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Repository (cls)	HsqlComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Repository (cls)	PsqlComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Repository (cls)	HsqlAttributesInsertRepository		org.thingsboard.server.dao.sql.attributes
# Repository (cls)	PsqlAttributesInsertRepository		org.thingsboard.server.dao.sql.attributes
# Repository (cls)	AttributeKvInsertRepository		org.thingsboard.server.dao.sql.attributes
# Repository (cls)	HsqlEventInsertRepository		org.thingsboard.server.dao.sql.event
# Repository (cls)	PsqlEventInsertRepository		org.thingsboard.server.dao.sql.event
# Repository (cls)	AbstractInsertRepository		org.thingsboard.server.dao.sqlts.insert
# Repository (cls)	HsqlInsertTsRepository		org.thingsboard.server.dao.sqlts.insert.hsql
# Repository (cls)	TimescaleInsertTsRepository		org.thingsboard.server.dao.sqlts.insert.timescale
# Repository (cls)	PsqlPartitioningRepository		org.thingsboard.server.dao.sqlts.insert.psql
# Repository (cls)	PsqlInsertTsRepository		org.thingsboard.server.dao.sqlts.insert.psql
# Repository (cls)	AggregationRepository		org.thingsboard.server.dao.sqlts.timescale
# Interface	TbCoreDeviceRpcService		org.thingsboard.server.service.rpc
# Interface	TbRuleEngineDeviceRpcService		org.thingsboard.server.service.rpc
# Interface	ComponentDiscoveryService		org.thingsboard.server.service.component
# Interface	JsInvokeService		org.thingsboard.server.service.script
# Interface	AccessControlService		org.thingsboard.server.service.security.permission
# Interface	PermissionChecker		org.thingsboard.server.service.security.permission
# Interface	Permissions		org.thingsboard.server.service.security.permission
# Interface	JwtToken		org.thingsboard.server.service.security.model.token
# Interface	OAuth2ClientMapper		org.thingsboard.server.service.security.auth.oauth2
# Interface	TokenExtractor		org.thingsboard.server.service.security.auth.jwt.extractor
# Interface	SystemSecurityService		org.thingsboard.server.service.security.system
# Interface	DatabaseSchemaService		org.thingsboard.server.service.install
# Interface	EntityDatabaseSchemaService		org.thingsboard.server.service.install
# Interface	SystemDataLoaderService		org.thingsboard.server.service.install
# Interface	DatabaseTsUpgradeService		org.thingsboard.server.service.install
# Interface	TsDatabaseSchemaService		org.thingsboard.server.service.install
# Interface	DatabaseEntitiesUpgradeService		org.thingsboard.server.service.install
# Interface	DataUpdateService		org.thingsboard.server.service.install.update
# Interface	TbCoreToTransportService		org.thingsboard.server.service.transport
# Interface	TransportApiService		org.thingsboard.server.service.transport
# Interface	DataDecodingEncodingService		org.thingsboard.server.service.encoding
# Interface	DeviceSessionCacheService		org.thingsboard.server.service.session
# Interface	DeviceStateService		org.thingsboard.server.service.state
# Interface	UpdateService		org.thingsboard.server.service.update
# Interface	TelemetryWebSocketService		org.thingsboard.server.service.telemetry
# Interface	TelemetrySubscriptionService		org.thingsboard.server.service.telemetry
# Interface	TelemetryWebSocketMsgEndpoint		org.thingsboard.server.service.telemetry
# Interface	TelemetryPluginCmd		org.thingsboard.server.service.telemetry.cmd
# Interface	ToErrorResponseEntity		org.thingsboard.server.service.telemetry.exception
# Interface	TbLocalSubscriptionService		org.thingsboard.server.service.subscription
# Interface	SubscriptionManagerService		org.thingsboard.server.service.subscription
# Interface	RuleEngineStatisticsService		org.thingsboard.server.service.stats
# Interface	TbRuleEngineConsumerService		org.thingsboard.server.service.queue
# Interface	TbClusterService		org.thingsboard.server.service.queue
# Interface	TbCoreConsumerService		org.thingsboard.server.service.queue
# Interface	TbRuleEngineSubmitStrategy		org.thingsboard.server.service.queue.processing
# Interface	TbRuleEngineProcessingStrategy		org.thingsboard.server.service.queue.processing
# Interface	ActorService		org.thingsboard.server.actors.service
# Interface	MqttClientCredentials		org.thingsboard.rule.engine.mqtt.credentials
# Interface	TbNode		org.thingsboard.rule.engine.api
# Interface	NodeConfiguration		org.thingsboard.rule.engine.api
# Interface	MailService		org.thingsboard.rule.engine.api
# Interface	RuleEngineRpcService		org.thingsboard.rule.engine.api
# Interface	TbContext		org.thingsboard.rule.engine.api
# Interface	ScriptEngine		org.thingsboard.rule.engine.api
# Interface	RuleEngineTelemetryService		org.thingsboard.rule.engine.api
# Interface	ToDeviceActorNotificationMsg		org.thingsboard.rule.engine.api.msg
# Interface	ListeningExecutor		org.thingsboard.common.util
# Interface	MqttTransportAdaptor		org.thingsboard.server.transport.mqtt.adaptors
# Interface	TransportServiceCallback		org.thingsboard.server.common.transport
# Interface	SessionMsgListener		org.thingsboard.server.common.transport
# Interface	TransportAdaptor		org.thingsboard.server.common.transport
# Interface	TransportService		org.thingsboard.server.common.transport
# Interface	DeviceAuthService		org.thingsboard.server.common.transport.auth
# Interface	CoapTransportAdaptor		org.thingsboard.server.transport.coap.adaptors
# Interface	HasName		org.thingsboard.server.common.data
# Interface	HasAdditionalInfo		org.thingsboard.server.common.data
# Interface	HasCustomerId		org.thingsboard.server.common.data
# Interface	HasTenantId		org.thingsboard.server.common.data
# Interface	DeviceCredentialsFilter		org.thingsboard.server.common.data.security
# Interface	TsKvQuery		org.thingsboard.server.common.data.kv
# Interface	AttributeKvEntry		org.thingsboard.server.common.data.kv
# Interface	ReadTsKvQuery		org.thingsboard.server.common.data.kv
# Interface	KvEntry		org.thingsboard.server.common.data.kv
# Interface	TsKvEntry		org.thingsboard.server.common.data.kv
# Interface	DeleteTsKvQuery		org.thingsboard.server.common.data.kv
# Interface	EntityId		org.thingsboard.server.common.data.id
# Interface	RelationService		org.thingsboard.server.dao.relation
# Interface	ComponentDescriptorService		org.thingsboard.server.dao.component
# Interface	AuditLogService		org.thingsboard.server.dao.audit
# Interface	AdminSettingsService		org.thingsboard.server.dao.settings
# Interface	UserService		org.thingsboard.server.dao.user
# Interface	WidgetsBundleService		org.thingsboard.server.dao.widget
# Interface	WidgetTypeService		org.thingsboard.server.dao.widget
# Interface	TimeseriesService		org.thingsboard.server.dao.timeseries
# Interface	AsyncTask		org.thingsboard.server.dao.util
# Interface	DashboardService		org.thingsboard.server.dao.dashboard
# Interface	OAuth2Service		org.thingsboard.server.dao.oauth2
# Interface	ClaimDevicesService		org.thingsboard.server.dao.device
# Interface	DeviceCredentialsService		org.thingsboard.server.dao.device
# Interface	DeviceService		org.thingsboard.server.dao.device
# Interface	RuleChainService		org.thingsboard.server.dao.rule
# Interface	EntityViewService		org.thingsboard.server.dao.entityview
# Interface	AttributesService		org.thingsboard.server.dao.attributes
# Interface	AlarmService		org.thingsboard.server.dao.alarm
# Interface	TenantService		org.thingsboard.server.dao.tenant
# Interface	EntityService		org.thingsboard.server.dao.entity
# Interface	AssetService		org.thingsboard.server.dao.asset
# Interface	EventService		org.thingsboard.server.dao.event
# Interface	CustomerService		org.thingsboard.server.dao.customer
# Interface	StatsFactory		org.thingsboard.server.common.stats
# Interface	MessagesStats		org.thingsboard.server.common.stats
# Interface	TbQueueAdmin		org.thingsboard.server.queue
# Interface	TbQueueHandler		org.thingsboard.server.queue
# Interface	TbQueueMsgDecoder		org.thingsboard.server.queue
# Interface	TbQueueResponseTemplate		org.thingsboard.server.queue
# Interface	TbQueueMsgHeaders		org.thingsboard.server.queue
# Interface	TbQueueRequestTemplate		org.thingsboard.server.queue
# Interface	TbQueueCallback		org.thingsboard.server.queue
# Interface	TbQueueMsg		org.thingsboard.server.queue
# Interface	TbQueueConsumer		org.thingsboard.server.queue
# Interface	TbQueueProducer		org.thingsboard.server.queue
# Interface	TbQueueMsgMetadata		org.thingsboard.server.queue
# Interface	DiscoveryService		org.thingsboard.server.queue.discovery
# Interface	TbServiceInfoProvider		org.thingsboard.server.queue.discovery
# Interface	PartitionService		org.thingsboard.server.queue.discovery
# Interface	TenantRoutingInfoService		org.thingsboard.server.queue.discovery
# Interface	TbRuleEngineQueueFactory		org.thingsboard.server.queue.provider
# Interface	TbCoreQueueFactory		org.thingsboard.server.queue.provider
# Interface	TbTransportQueueFactory		org.thingsboard.server.queue.provider
# Interface	TbQueueProducerProvider		org.thingsboard.server.queue.provider
# Interface	TbKafkaEncoder		org.thingsboard.server.queue.kafka
# Interface	TbKafkaDecoder		org.thingsboard.server.queue.kafka
# Interface	JsInvokeStats		org.thingsboard.server.actors
# Interface	TbActorId		org.thingsboard.server.actors
# Interface	TbActorCreator		org.thingsboard.server.actors
# Interface	TbActorCtx		org.thingsboard.server.actors
# Interface	TbActorSystem		org.thingsboard.server.actors
# Interface	TbActorRef		org.thingsboard.server.actors
# Interface	TbActor		org.thingsboard.server.actors
# Interface	TbActorMsg		org.thingsboard.server.common.msg
# Interface	SessionContext		org.thingsboard.server.common.msg.session
# Interface	ToAllNodesMsg		org.thingsboard.server.common.msg.cluster
# Interface	TenantAwareMsg		org.thingsboard.server.common.msg.aware
# Interface	RuleChainAwareMsg		org.thingsboard.server.common.msg.aware
# Interface	CustomerAwareMsg		org.thingsboard.server.common.msg.aware
# Interface	NodeAwareMsg		org.thingsboard.server.common.msg.aware
# Interface	DeviceAwareMsg		org.thingsboard.server.common.msg.aware
# Interface	TbMsgCallback		org.thingsboard.server.common.msg.queue
# Interface	TbCallback		org.thingsboard.server.common.msg.queue
# Interface	MqttHandler		org.thingsboard.mqtt
# Interface	MqttClient		org.thingsboard.mqtt
# Interface	MqttClientCallback		org.thingsboard.mqtt
# Interface	Dao		org.thingsboard.server.dao
# Interface	RelationDao		org.thingsboard.server.dao.relation
# Interface	ComponentDescriptorDao		org.thingsboard.server.dao.component
# Interface	AuditLogDao		org.thingsboard.server.dao.audit
# Interface	AuditLogSink		org.thingsboard.server.dao.audit.sink
# Interface	AdminSettingsDao		org.thingsboard.server.dao.settings
# Interface	UserDao		org.thingsboard.server.dao.user
# Interface	UserCredentialsDao		org.thingsboard.server.dao.user
# Interface	WidgetsBundleDao		org.thingsboard.server.dao.widget
# Interface	WidgetTypeDao		org.thingsboard.server.dao.widget
# Interface	TbSqlQueue		org.thingsboard.server.dao.sql
# Interface	RelationRepository		org.thingsboard.server.dao.sql.relation
# Interface	RelationInsertRepository		org.thingsboard.server.dao.sql.relation
# Interface	ComponentDescriptorRepository		org.thingsboard.server.dao.sql.component
# Interface	ComponentDescriptorInsertRepository		org.thingsboard.server.dao.sql.component
# Interface	AuditLogRepository		org.thingsboard.server.dao.sql.audit
# Interface	AdminSettingsRepository		org.thingsboard.server.dao.sql.settings
# Interface	UserCredentialsRepository		org.thingsboard.server.dao.sql.user
# Interface	UserRepository		org.thingsboard.server.dao.sql.user
# Interface	WidgetTypeRepository		org.thingsboard.server.dao.sql.widget
# Interface	WidgetsBundleRepository		org.thingsboard.server.dao.sql.widget
# Interface	DashboardRepository		org.thingsboard.server.dao.sql.dashboard
# Interface	DashboardInfoRepository		org.thingsboard.server.dao.sql.dashboard
# Interface	DeviceRepository		org.thingsboard.server.dao.sql.device
# Interface	DeviceCredentialsRepository		org.thingsboard.server.dao.sql.device
# Interface	RuleChainRepository		org.thingsboard.server.dao.sql.rule
# Interface	RuleNodeRepository		org.thingsboard.server.dao.sql.rule
# Interface	EntityViewRepository		org.thingsboard.server.dao.sql.entityview
# Interface	AttributeKvRepository		org.thingsboard.server.dao.sql.attributes
# Interface	AlarmRepository		org.thingsboard.server.dao.sql.alarm
# Interface	TenantRepository		org.thingsboard.server.dao.sql.tenant
# Interface	AssetRepository		org.thingsboard.server.dao.sql.asset
# Interface	EventRepository		org.thingsboard.server.dao.sql.event
# Interface	EventInsertRepository		org.thingsboard.server.dao.sql.event
# Interface	CustomerRepository		org.thingsboard.server.dao.sql.customer
# Interface	TimeseriesDao		org.thingsboard.server.dao.timeseries
# Interface	BufferedRateExecutor		org.thingsboard.server.dao.util
# Interface	AsyncRateLimiter		org.thingsboard.server.dao.util
# Interface	DashboardInfoDao		org.thingsboard.server.dao.dashboard
# Interface	DashboardDao		org.thingsboard.server.dao.dashboard
# Interface	DeviceDao		org.thingsboard.server.dao.device
# Interface	DeviceCredentialsDao		org.thingsboard.server.dao.device
# Interface	RuleChainDao		org.thingsboard.server.dao.rule
# Interface	RuleNodeDao		org.thingsboard.server.dao.rule
# Interface	EntityViewDao		org.thingsboard.server.dao.entityview
# Interface	AttributesDao		org.thingsboard.server.dao.attributes
# Interface	AlarmDao		org.thingsboard.server.dao.alarm
# Interface	InsertTsRepository		org.thingsboard.server.dao.sqlts.insert
# Interface	TsKvRepository		org.thingsboard.server.dao.sqlts.ts
# Interface	TsKvTimescaleRepository		org.thingsboard.server.dao.sqlts.timescale
# Interface	TsKvDictionaryRepository		org.thingsboard.server.dao.sqlts.dictionary
# Interface	TenantDao		org.thingsboard.server.dao.tenant
# Interface	BaseEntity		org.thingsboard.server.dao.model
# Interface	ToData		org.thingsboard.server.dao.model
# Interface	SearchTextEntity		org.thingsboard.server.dao.model
# Interface	AssetDao		org.thingsboard.server.dao.asset
# Interface	EventDao		org.thingsboard.server.dao.event
# Interface	CustomerDao		org.thingsboard.server.dao.customer
# Excluded	ThingsboardHttpTransportApplication		org.thingsboard.server.http
# Excluded	ThingsboardInstallConfiguration		org.thingsboard.server.install
# Excluded	ThingsboardMessageConfiguration		org.thingsboard.server.config
# Excluded	SchedulingConfiguration		org.thingsboard.server.config
# Excluded	AuditLogLevelProperties		org.thingsboard.server.config
# Excluded	JwtSettings		org.thingsboard.server.config
# Excluded	MvcCorsProperties		org.thingsboard.server.config
# Excluded	WebSocketConfiguration		org.thingsboard.server.config
# Excluded	ThingsboardSecurityConfiguration		org.thingsboard.server.config
# Excluded	SwaggerConfiguration		org.thingsboard.server.config
# Excluded	JsonConverterConfig		org.thingsboard.server.common.transport.adaptor
# Excluded	TbQueueRuleEngineSettings		org.thingsboard.server.queue.settings
# Excluded	NoSqlDaoConfig		org.thingsboard.server.dao
# Excluded	TimescaleDaoConfig		org.thingsboard.server.dao
# Excluded	PsqlTsDaoConfig		org.thingsboard.server.dao
# Excluded	JpaDaoConfig		org.thingsboard.server.dao
# Excluded	HsqlTsDaoConfig		org.thingsboard.server.dao
# Excluded	TBRedisStandaloneConfiguration		org.thingsboard.server.dao.cache
# Excluded	TBRedisClusterConfiguration		org.thingsboard.server.dao.cache
# Excluded	CaffeineCacheConfiguration		org.thingsboard.server.dao.cache
# Excluded	TBRedisCacheConfiguration		org.thingsboard.server.dao.cache
# Excluded	OAuth2Configuration		org.thingsboard.server.dao.oauth2

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')
# Out:
# WARNING: Permissionsinterface does not have an implementing class!
# WARNING: EntityIdinterface does not have an implementing class!
# WARNING: EntityIdinterface does not have an implementing class!
# WARNING: EntityIdinterface does not have an implementing class!
# WARNING: EntityIdinterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorRefinterface does not have an implementing class!
# WARNING: TbActorRefinterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: TbActorRefinterface does not have an implementing class!
# WARNING: TbActorSysteminterface does not have an implementing class!
# WARNING: MessagesStatsinterface does not have an implementing class!
# WARNING: MessagesStatsinterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: TbQueueAdmininterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: RelationRepositoryinterface does not have an implementing class!
# WARNING: ComponentDescriptorRepositoryinterface does not have an implementing class!
# WARNING: ComponentDescriptorInsertRepositoryinterface does not have an implementing class!
# WARNING: ComponentDescriptorRepositoryinterface does not have an implementing class!
# WARNING: ComponentDescriptorRepositoryinterface does not have an implementing class!
# WARNING: ComponentDescriptorRepositoryinterface does not have an implementing class!
# WARNING: ComponentDescriptorRepositoryinterface does not have an implementing class!
# WARNING: AuditLogRepositoryinterface does not have an implementing class!
# WARNING: AdminSettingsRepositoryinterface does not have an implementing class!
# WARNING: UserCredentialsRepositoryinterface does not have an implementing class!
# WARNING: UserCredentialsRepositoryinterface does not have an implementing class!
# WARNING: UserCredentialsRepositoryinterface does not have an implementing class!
# WARNING: UserRepositoryinterface does not have an implementing class!
# WARNING: UserRepositoryinterface does not have an implementing class!
# WARNING: UserRepositoryinterface does not have an implementing class!
# WARNING: WidgetsBundleRepositoryinterface does not have an implementing class!
# WARNING: WidgetsBundleRepositoryinterface does not have an implementing class!
# WARNING: WidgetsBundleRepositoryinterface does not have an implementing class!
# WARNING: WidgetsBundleRepositoryinterface does not have an implementing class!
# WARNING: WidgetTypeRepositoryinterface does not have an implementing class!
# WARNING: WidgetTypeRepositoryinterface does not have an implementing class!
# WARNING: DashboardInfoRepositoryinterface does not have an implementing class!
# WARNING: DeviceCredentialsRepositoryinterface does not have an implementing class!
# WARNING: DeviceCredentialsRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: DeviceRepositoryinterface does not have an implementing class!
# WARNING: RuleChainRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: EntityViewRepositoryinterface does not have an implementing class!
# WARNING: AttributeKvRepositoryinterface does not have an implementing class!
# WARNING: AttributeKvRepositoryinterface does not have an implementing class!
# WARNING: AttributeKvRepositoryinterface does not have an implementing class!
# WARNING: AlarmRepositoryinterface does not have an implementing class!
# WARNING: TenantRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: AssetRepositoryinterface does not have an implementing class!
# WARNING: EventRepositoryinterface does not have an implementing class!
# WARNING: EventInsertRepositoryinterface does not have an implementing class!
# WARNING: EventRepositoryinterface does not have an implementing class!
# WARNING: EventRepositoryinterface does not have an implementing class!
# WARNING: EventRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: TsKvTimescaleRepositoryinterface does not have an implementing class!
# WARNING: TsKvTimescaleRepositoryinterface does not have an implementing class!

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['performInstall(ThingsboardInstallService)', 'Calls', 'createDatabaseSchema(CassandraEntityDatabaseSchemaService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['performInstall(ThingsboardInstallService)', 'Calls', 'createDatabaseSchema(CassandraTsDatabaseSchemaService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initExecutor(DefaultTbRuleEngineRpcService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRpcRequestToDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'isPresent(DefaultTbCoreDeviceRpcService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRpcRequestToDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'get(DefaultTbCoreDeviceRpcService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processRpcResponseFromDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['forwardRpcRequestToDeviceActor(DefaultTbRuleEngineRpcService)', 'Calls', 'put(FromDeviceRpcResponse)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRpcResponseToTbCore(DefaultTbRuleEngineRpcService)', 'Calls', 'isPresent(DefaultTbCoreDeviceRpcService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRpcResponseToTbCore(DefaultTbRuleEngineRpcService)', 'Calls', 'get(DefaultTbCoreDeviceRpcService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['scheduleTimeout(DefaultTbRuleEngineRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initExecutor(DefaultTbCoreDeviceRpcService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processRestApiRpcRequest(DefaultTbCoreDeviceRpcService)', 'Calls', 'put(FromDeviceRpcResponse)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processRpcResponseFromRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['forwardRpcRequestToDeviceActor(DefaultTbCoreDeviceRpcService)', 'Calls', 'put(ToDeviceRpcRequestActorMsg)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processRpcResponseFromDeviceActor(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(ToDeviceRpcRequestActorMsg)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRpcResponseToTbRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'isPresent(DefaultTbRuleEngineRpcService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRpcResponseToTbRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'get(DefaultTbRuleEngineRpcService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['scheduleToRuleEngineTimeout(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['scheduleToDeviceTimeout(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(ToDeviceRpcRequestActorMsg)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['registerRuleNodeComponents(AnnotationComponentDiscoveryService)', 'Calls', 'put(ComponentDescriptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['registerRuleNodeComponents(AnnotationComponentDiscoveryService)', 'Calls', 'computeIfAbsent(ComponentDescriptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['registerComponents(AnnotationComponentDiscoveryService)', 'Calls', 'put(ComponentDescriptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['discoverComponents(AnnotationComponentDiscoveryService)', 'Calls', 'values(ComponentDescriptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getComponent(AnnotationComponentDiscoveryService)', 'Calls', 'get(ComponentDescriptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doInvokeFunction(RemoteJsInvokeService)', 'Calls', 'onScriptExecutionError(RemoteJsInvokeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doInvokeFunction(RemoteJsInvokeService)', 'Calls', 'onScriptExecutionError(RemoteJsInvokeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationSuccessHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationSuccessHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onAuthenticationFailure(Oauth2AuthenticationFailureHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationFailureHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOrCreateUserByClientPrincipal(BasicOAuth2ClientMapper)', 'Calls', 'getOrCreateSecurityUserFromOAuth2User(BasicOAuth2ClientMapper)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOrCreateUserByClientPrincipal(CustomOAuth2ClientMapper)', 'Calls', 'getOrCreateSecurityUserFromOAuth2User(CustomOAuth2ClientMapper)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doCleanUp(TimescaleTimeseriesCleanUpService)', 'Calls', 'executeQuery(TimescaleTimeseriesCleanUpService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doCleanUp(PsqlTimeseriesCleanUpService)', 'Calls', 'executeQuery(PsqlTimeseriesCleanUpService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doCleanUp(PsqlTimeseriesCleanUpService)', 'Calls', 'executeQuery(PsqlTimeseriesCleanUpService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doCleanUp(EventsCleanUpService)', 'Calls', 'executeQuery(EventsCleanUpService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createDatabaseSchema(TimescaleTsDatabaseSchemaService)', 'Calls', 'executeQuery(TimescaleTsDatabaseSchemaService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createDatabaseSchema(PsqlTsDatabaseSchemaService)', 'Calls', 'executeQuery(PsqlTsDatabaseSchemaService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'checkVersion(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'isOldSchema(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['loadSql(PsqlTsDatabaseUpgradeService)', 'Calls', 'loadFunctions(PsqlTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'checkVersion(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'isOldSchema(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['insertTimeseries(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['loadSql(TimescaleTsDatabaseUpgradeService)', 'Calls', 'loadFunctions(TimescaleTsDatabaseUpgradeService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateData(DefaultDataUpdateService)', 'Calls', 'updateEntities(Tenant)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createJavaMailProperties(DefaultMailService)', 'Calls', 'equalsIgnoreCase(DefaultMailService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(DefaultDeviceStateService)', 'Calls', 'nextInt(DefaultDeviceStateService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'get(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'getOrDefault(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onDeviceInactivityTimeoutUpdate(DefaultDeviceStateService)', 'Calls', 'get(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onQueueMsg(DefaultDeviceStateService)', 'Calls', 'containsKey(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'forEach(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addDeviceUsingState(DefaultDeviceStateService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addDeviceUsingState(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'keySet(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'size(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOrFetchDeviceStateData(DefaultDeviceStateService)', 'Calls', 'get(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOrFetchDeviceStateData(DefaultDeviceStateService)', 'Calls', 'putIfAbsent(DeviceId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(DefaultUpdateService)', 'Calls', 'getClass(DefaultUpdateService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initExecutor(DefaultTelemetryWebSocketService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleWebSocketSessionEvent(DefaultTelemetryWebSocketService)', 'Calls', 'put(WsSessionMetaData)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleWebSocketSessionEvent(DefaultTelemetryWebSocketService)', 'Calls', 'remove(WsSessionMetaData)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(TenantId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(CustomerId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(TenantId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(CustomerId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Calls', 'get(WsSessionMetaData)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Calls', 'isInstance(DefaultTelemetryWebSocketService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleWsTimeseriesSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'isInstance(DefaultTelemetryWebSocketService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateSessionMetadata(DefaultTelemetryWebSocketService)', 'Calls', 'get(WsSessionMetaData)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['on(DefaultTelemetryWebSocketService)', 'Calls', 'onFailure(DefaultTelemetryWebSocketService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onApplicationEvent(DefaultTelemetrySubscriptionService)', 'Calls', 'clear(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onApplicationEvent(DefaultTelemetrySubscriptionService)', 'Calls', 'addAll(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'isPresent(DefaultSubscriptionManagerService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'get(DefaultSubscriptionManagerService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'isPresent(DefaultSubscriptionManagerService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'get(DefaultSubscriptionManagerService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['initExecutor(DefaultSubscriptionManagerService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'computeIfAbsent(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelSubscription(DefaultSubscriptionManagerService)', 'Calls', 'get(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelSubscription(DefaultSubscriptionManagerService)', 'Calls', 'remove(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'clear(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'addAll(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'remove(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeSubscriptionFromPartitionMap(DefaultSubscriptionManagerService)', 'Calls', 'get(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onApplicationEvent(DefaultTbLocalSubscriptionService)', 'Calls', 'values(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['pushSubscriptionToManagerService(DefaultTbLocalSubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSubscriptionUpdate(DefaultTbLocalSubscriptionService)', 'Calls', 'getOrDefault(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'get(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'remove(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cancelAllSessionSubscriptions(DefaultTbLocalSubscriptionService)', 'Calls', 'get(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['registerSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'computeIfAbsent(TbSubscription)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'get(AssetId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'get(AssetId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'put(AssetId)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['incrementRequests(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['incrementResponses(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['incrementFailures(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRequests(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getResponses(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getFailures(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleNotification(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printStats(DefaultTbCoreConsumerService)', 'Calls', 'printStats(TbCoreConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printStats(DefaultTbCoreConsumerService)', 'Calls', 'reset(TbCoreConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['forwardToSubMgrService(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['forwardToStateService(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['forwardToDeviceActor(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(DefaultTbRuleEngineConsumerService)', 'Calls', 'putIfAbsent(TbRuleEngineQueueConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(DefaultTbRuleEngineConsumerService)', 'Calls', 'put(TbRuleEngineConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['launchMainConsumers(DefaultTbRuleEngineConsumerService)', 'Calls', 'get(TbRuleEngineQueueConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['launchMainConsumers(DefaultTbRuleEngineConsumerService)', 'Calls', 'get(TbRuleEngineConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printStats(DefaultTbRuleEngineConsumerService)', 'Calls', 'forEach(TbRuleEngineConsumerStats)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'checkEntity(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'createPageLink(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAsset(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAsset(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTenantAsset(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'createPageLink(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'checkArrayParameter(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkEntityId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetTypes(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetTypes(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAssetTypes(AssetController)', 'Calls', 'handleException(AssetController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'checkDashboardInfoId(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'checkEntity(DashboardController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped since target method is not listed in the nodes file!
# ...
# INFO: Edge ['doProcessSaveOrUpdate(PsqlComponentDescriptorInsertRepository)', 'Calls', 'getQuery(PsqlComponentDescriptorInsertRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(HsqlEventInsertRepository)', 'Calls', 'saveAndGet(HsqlEventInsertRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doProcessSaveOrUpdate(HsqlEventInsertRepository)', 'Calls', 'getQuery(HsqlEventInsertRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(PsqlEventInsertRepository)', 'Calls', 'saveAndGet(PsqlEventInsertRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doProcessSaveOrUpdate(PsqlEventInsertRepository)', 'Calls', 'getQuery(PsqlEventInsertRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['prepareNodeDefinition(AnnotationComponentDiscoveryService)', 'Uses', 'NodeConfiguration'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleError(AccessValidator)', 'Uses', 'ToErrorResponseEntity'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['checkPermission(DefaultAccessControlService)', 'Uses', 'PermissionChecker'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getPermissionChecker(DefaultAccessControlService)', 'Uses', 'Permissions'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getPermissionChecker(DefaultAccessControlService)', 'Uses', 'PermissionChecker'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Uses', 'OAuth2ClientMapper'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Uses', 'JwtToken'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['onAuthenticationSuccess(RestAwareAuthenticationSuccessHandler)', 'Uses', 'JwtToken'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['init(TbCoreTransportApiService)', 'Uses', 'MessagesStats'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['decode(ProtoWithFSTService)', 'Uses', 'TbActorMsg'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['fetchDeviceState(DefaultDeviceStateService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['fetchDeviceState(DefaultDeviceStateService)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getEntryValue(DefaultDeviceStateService)', 'Uses', 'KvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsAttributesSubscriptionCmd(DefaultTelemetryWebSocketService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsAttributesSubscriptionByKeys(DefaultTelemetryWebSocketService)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsAttributesSubscriptionByKeys(DefaultTelemetryWebSocketService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsAttributesSubscription(DefaultTelemetryWebSocketService)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsAttributesSubscription(DefaultTelemetryWebSocketService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsTimeseriesSubscriptionCmd(DefaultTelemetryWebSocketService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsTimeseriesSubscriptionByKeys(DefaultTelemetryWebSocketService)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsTimeseriesSubscriptionByKeys(DefaultTelemetryWebSocketService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleWsTimeseriesSubscription(DefaultTelemetryWebSocketService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getSubscriptionCallback(DefaultTelemetryWebSocketService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['mergeAllAttributesFutures(DefaultTelemetryWebSocketService)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['onTimeSeriesUpdate(DefaultSubscriptionManagerService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['onAttributesUpdate(DefaultSubscriptionManagerService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['onAttributesUpdate(DefaultSubscriptionManagerService)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleNewAttributeSubscription(DefaultSubscriptionManagerService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleNewTelemetrySubscription(DefaultSubscriptionManagerService)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['toProto(DefaultSubscriptionManagerService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['addSubscription(DefaultTbLocalSubscriptionService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['launchMainConsumers(DefaultTbCoreConsumerService)', 'Uses', 'TbCallback'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['launchMainConsumers(DefaultTbCoreConsumerService)', 'Uses', 'TbActorMsg'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleNotification(DefaultTbCoreConsumerService)', 'Uses', 'TbActorMsg'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['launchConsumer(DefaultTbRuleEngineConsumerService)', 'Uses', 'TbRuleEngineSubmitStrategy'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['launchConsumer(DefaultTbRuleEngineConsumerService)', 'Uses', 'TbRuleEngineProcessingStrategy'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['launchConsumer(DefaultTbRuleEngineConsumerService)', 'Uses', 'TbMsgCallback'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleNotification(DefaultTbRuleEngineConsumerService)', 'Uses', 'TbActorMsg'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['deleteRelations(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getRelation(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findByFrom(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findInfoByFrom(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findByTo(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findInfoByTo(EntityRelationController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getUserToken(UserController)', 'Uses', 'JwtToken'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['activateUser(AuthController)', 'Uses', 'JwtToken'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['resetPassword(AuthController)', 'Uses', 'JwtToken'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['testScript(RuleChainController)', 'Uses', 'ScriptEngine'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getEvents(EventController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getAlarms(AlarmController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getHighestAlarmSeverity(AlarmController)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['initActorSystem(DefaultActorService)', 'Uses', 'TbActorRef'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['processTimeout(DefaultTransportService)', 'Uses', 'SessionMsgListener'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['processToTransportMsg(DefaultTransportService)', 'Uses', 'SessionMsgListener'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createTransportApiRequestTemplate(InMemoryTbTransportQueueFactory)', 'Uses', 'TbQueueAdmin'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['match(BaseRelationService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findRelationsRecursively(BaseRelationService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['constructActionData(AuditLogServiceImpl)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAlarms(JpaAlarmDao)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAllAsync(CassandraBaseTimeseriesDao)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAllAsync(CassandraBaseTimeseriesDao)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAllAsyncWithLimit(CassandraBaseTimeseriesDao)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['removeLatest(CassandraBaseTimeseriesDao)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getNewLatestEntryFuture(CassandraBaseTimeseriesDao)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getNewLatestEntryFuture(CassandraBaseTimeseriesDao)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['convertResultToTsKvEntryList(CassandraBaseTimeseriesDao)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['toKvEntry(CassandraBaseTimeseriesDao)', 'Uses', 'KvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAll(BaseTimeseriesService)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findLatest(BaseTimeseriesService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findLatest(BaseTimeseriesService)', 'Uses', 'ReadTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['save(BaseTimeseriesService)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['remove(BaseTimeseriesService)', 'Uses', 'DeleteTsKvQuery'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['registerClaimingInfo(ClaimDevicesServiceImpl)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getClaimData(ClaimDevicesServiceImpl)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findDevicesByQuery(DeviceServiceImpl)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['saveRuleChainMetaData(BaseRuleChainService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findEntityViewsByQuery(EntityViewServiceImpl)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['find(CassandraBaseAttributesDao)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAll(CassandraBaseAttributesDao)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['convertResultToAttributesKvEntry(CassandraBaseAttributesDao)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['convertResultToAttributesKvEntryList(CassandraBaseAttributesDao)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['save(BaseAttributesService)', 'Uses', 'AttributeKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createAlarmRelations(BaseAlarmService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['updateRelations(BaseAlarmService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAlarms(CassandraAlarmDao)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAllAndAggregateAsync(TimescaleTimeseriesDao)', 'Uses', 'TsKvEntry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['fetchEntityNameAsync(BaseEntityService)', 'Uses', 'HasName'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAssetsByQuery(BaseAssetService)', 'Uses', 'EntityId'] discarded since target entity is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['performInstall(ThingsboardInstallService)', 'Calls', 'createDatabaseSchema(CassandraEntityDatabaseSchemaService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['performInstall(ThingsboardInstallService)', 'Calls', 'createDatabaseSchema(CassandraTsDatabaseSchemaService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initExecutor(DefaultTbRuleEngineRpcService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendRpcRequestToDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'isPresent(DefaultTbCoreDeviceRpcService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendRpcRequestToDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'get(DefaultTbCoreDeviceRpcService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['processRpcResponseFromDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)']: discarding
# WARNING: Unable to recover target method for edge ['forwardRpcRequestToDeviceActor(DefaultTbRuleEngineRpcService)', 'Calls', 'put(FromDeviceRpcResponse)']: discarding
# WARNING: unable to recover ['sendRpcResponseToTbCore(DefaultTbRuleEngineRpcService)', 'Calls', 'isPresent(DefaultTbCoreDeviceRpcService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendRpcResponseToTbCore(DefaultTbRuleEngineRpcService)', 'Calls', 'get(DefaultTbCoreDeviceRpcService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['scheduleTimeout(DefaultTbRuleEngineRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)']: discarding
# WARNING: unable to recover ['initExecutor(DefaultTbCoreDeviceRpcService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['processRestApiRpcRequest(DefaultTbCoreDeviceRpcService)', 'Calls', 'put(FromDeviceRpcResponse)']: discarding
# WARNING: Unable to recover target method for edge ['processRpcResponseFromRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)']: discarding
# WARNING: Unable to recover target method for edge ['forwardRpcRequestToDeviceActor(DefaultTbCoreDeviceRpcService)', 'Calls', 'put(ToDeviceRpcRequestActorMsg)']: discarding
# WARNING: Unable to recover target method for edge ['processRpcResponseFromDeviceActor(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(ToDeviceRpcRequestActorMsg)']: discarding
# WARNING: unable to recover ['sendRpcResponseToTbRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'isPresent(DefaultTbRuleEngineRpcService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendRpcResponseToTbRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'get(DefaultTbRuleEngineRpcService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['scheduleToRuleEngineTimeout(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)']: discarding
# WARNING: Unable to recover target method for edge ['scheduleToDeviceTimeout(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(ToDeviceRpcRequestActorMsg)']: discarding
# WARNING: Unable to recover target method for edge ['registerRuleNodeComponents(AnnotationComponentDiscoveryService)', 'Calls', 'put(ComponentDescriptor)']: discarding
# WARNING: Unable to recover target method for edge ['registerRuleNodeComponents(AnnotationComponentDiscoveryService)', 'Calls', 'computeIfAbsent(ComponentDescriptor)']: discarding
# WARNING: Unable to recover target method for edge ['registerComponents(AnnotationComponentDiscoveryService)', 'Calls', 'put(ComponentDescriptor)']: discarding
# WARNING: Unable to recover target method for edge ['discoverComponents(AnnotationComponentDiscoveryService)', 'Calls', 'values(ComponentDescriptor)']: discarding
# WARNING: Unable to recover target method for edge ['getComponent(AnnotationComponentDiscoveryService)', 'Calls', 'get(ComponentDescriptor)']: discarding
# WARNING: unable to recover ['doInvokeFunction(RemoteJsInvokeService)', 'Calls', 'onScriptExecutionError(RemoteJsInvokeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doInvokeFunction(RemoteJsInvokeService)', 'Calls', 'onScriptExecutionError(RemoteJsInvokeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationSuccessHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationSuccessHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onAuthenticationFailure(Oauth2AuthenticationFailureHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationFailureHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOrCreateUserByClientPrincipal(BasicOAuth2ClientMapper)', 'Calls', 'getOrCreateSecurityUserFromOAuth2User(BasicOAuth2ClientMapper)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOrCreateUserByClientPrincipal(CustomOAuth2ClientMapper)', 'Calls', 'getOrCreateSecurityUserFromOAuth2User(CustomOAuth2ClientMapper)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doCleanUp(TimescaleTimeseriesCleanUpService)', 'Calls', 'executeQuery(TimescaleTimeseriesCleanUpService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doCleanUp(PsqlTimeseriesCleanUpService)', 'Calls', 'executeQuery(PsqlTimeseriesCleanUpService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doCleanUp(PsqlTimeseriesCleanUpService)', 'Calls', 'executeQuery(PsqlTimeseriesCleanUpService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doCleanUp(EventsCleanUpService)', 'Calls', 'executeQuery(EventsCleanUpService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createDatabaseSchema(TimescaleTsDatabaseSchemaService)', 'Calls', 'executeQuery(TimescaleTsDatabaseSchemaService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createDatabaseSchema(PsqlTsDatabaseSchemaService)', 'Calls', 'executeQuery(PsqlTsDatabaseSchemaService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'checkVersion(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'isOldSchema(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['loadSql(PsqlTsDatabaseUpgradeService)', 'Calls', 'loadFunctions(PsqlTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'checkVersion(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'isOldSchema(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['insertTimeseries(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['loadSql(TimescaleTsDatabaseUpgradeService)', 'Calls', 'loadFunctions(TimescaleTsDatabaseUpgradeService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['updateData(DefaultDataUpdateService)', 'Calls', 'updateEntities(Tenant)']: discarding
# WARNING: unable to recover ['createJavaMailProperties(DefaultMailService)', 'Calls', 'equalsIgnoreCase(DefaultMailService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(DefaultDeviceStateService)', 'Calls', 'nextInt(DefaultDeviceStateService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'get(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'getOrDefault(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onDeviceInactivityTimeoutUpdate(DefaultDeviceStateService)', 'Calls', 'get(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['onQueueMsg(DefaultDeviceStateService)', 'Calls', 'containsKey(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'forEach(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['addDeviceUsingState(DefaultDeviceStateService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['addDeviceUsingState(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['updateState(DefaultDeviceStateService)', 'Calls', 'keySet(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['updateState(DefaultDeviceStateService)', 'Calls', 'size(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['getOrFetchDeviceStateData(DefaultDeviceStateService)', 'Calls', 'get(DeviceId)']: discarding
# WARNING: Unable to recover target method for edge ['getOrFetchDeviceStateData(DefaultDeviceStateService)', 'Calls', 'putIfAbsent(DeviceId)']: discarding
# WARNING: unable to recover ['init(DefaultUpdateService)', 'Calls', 'getClass(DefaultUpdateService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initExecutor(DefaultTelemetryWebSocketService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['handleWebSocketSessionEvent(DefaultTelemetryWebSocketService)', 'Calls', 'put(WsSessionMetaData)']: discarding
# WARNING: Unable to recover target method for edge ['handleWebSocketSessionEvent(DefaultTelemetryWebSocketService)', 'Calls', 'remove(WsSessionMetaData)']: discarding
# WARNING: Unable to recover target method for edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(TenantId)']: discarding
# WARNING: Unable to recover target method for edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(CustomerId)']: discarding
# WARNING: Unable to recover target method for edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)']: discarding
# WARNING: Unable to recover target method for edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)']: discarding
# WARNING: Unable to recover target method for edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(TenantId)']: discarding
# WARNING: Unable to recover target method for edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(CustomerId)']: discarding
# WARNING: Unable to recover target method for edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)']: discarding
# WARNING: Unable to recover target method for edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)']: discarding
# WARNING: Unable to recover target method for edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Calls', 'get(WsSessionMetaData)']: discarding
# WARNING: unable to recover ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Calls', 'isInstance(DefaultTelemetryWebSocketService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleWsTimeseriesSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'isInstance(DefaultTelemetryWebSocketService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['validateSessionMetadata(DefaultTelemetryWebSocketService)', 'Calls', 'get(WsSessionMetaData)']: discarding
# WARNING: unable to recover ['on(DefaultTelemetryWebSocketService)', 'Calls', 'onFailure(DefaultTelemetryWebSocketService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['onApplicationEvent(DefaultTelemetrySubscriptionService)', 'Calls', 'clear(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onApplicationEvent(DefaultTelemetrySubscriptionService)', 'Calls', 'addAll(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)']: discarding
# WARNING: unable to recover ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'isPresent(DefaultSubscriptionManagerService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'get(DefaultSubscriptionManagerService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)']: discarding
# WARNING: unable to recover ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'isPresent(DefaultSubscriptionManagerService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'get(DefaultSubscriptionManagerService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initExecutor(DefaultSubscriptionManagerService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'contains(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'computeIfAbsent(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['cancelSubscription(DefaultSubscriptionManagerService)', 'Calls', 'get(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['cancelSubscription(DefaultSubscriptionManagerService)', 'Calls', 'remove(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'clear(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'addAll(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'remove(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['removeSubscriptionFromPartitionMap(DefaultSubscriptionManagerService)', 'Calls', 'get(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onApplicationEvent(DefaultTbLocalSubscriptionService)', 'Calls', 'values(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['pushSubscriptionToManagerService(DefaultTbLocalSubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['onSubscriptionUpdate(DefaultTbLocalSubscriptionService)', 'Calls', 'getOrDefault(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'get(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'remove(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)']: discarding
# WARNING: Unable to recover target method for edge ['cancelAllSessionSubscriptions(DefaultTbLocalSubscriptionService)', 'Calls', 'get(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['registerSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'computeIfAbsent(TbSubscription)']: discarding
# WARNING: Unable to recover target method for edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'get(AssetId)']: discarding
# WARNING: Unable to recover target method for edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'get(AssetId)']: discarding
# WARNING: unable to recover ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'put(AssetId)']: discarding
# WARNING: Unable to recover target method for edge ['incrementRequests(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['incrementResponses(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['incrementFailures(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['getRequests(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['getResponses(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['getFailures(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)']: discarding
# WARNING: Unable to recover target method for edge ['handleNotification(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['printStats(DefaultTbCoreConsumerService)', 'Calls', 'printStats(TbCoreConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['printStats(DefaultTbCoreConsumerService)', 'Calls', 'reset(TbCoreConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['forwardToSubMgrService(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['forwardToStateService(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['forwardToDeviceActor(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['init(DefaultTbRuleEngineConsumerService)', 'Calls', 'putIfAbsent(TbRuleEngineQueueConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['init(DefaultTbRuleEngineConsumerService)', 'Calls', 'put(TbRuleEngineConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['launchMainConsumers(DefaultTbRuleEngineConsumerService)', 'Calls', 'get(TbRuleEngineQueueConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['launchMainConsumers(DefaultTbRuleEngineConsumerService)', 'Calls', 'get(TbRuleEngineConsumerStats)']: discarding
# WARNING: Unable to recover target method for edge ['printStats(DefaultTbRuleEngineConsumerService)', 'Calls', 'forEach(TbRuleEngineConsumerStats)']: discarding
# WARNING: unable to recover ['getAssetById(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetById(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetById(AssetController)', 'Calls', 'checkAssetId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetById(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'checkEntity(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'emptyId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'checkAssetId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'getTenantId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'emptyId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignAssetFromCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAssets(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAssets(AssetController)', 'Calls', 'createPageLink(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAssets(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAsset(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAsset(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTenantAsset(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'checkParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'createPageLink(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCustomerAssets(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetsByIds(AssetController)', 'Calls', 'checkArrayParameter(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetsByIds(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetsByIds(AssetController)', 'Calls', 'toUUID(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetsByIds(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAssetsByIds(AssetController)', 'Calls', 'handleException(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] since target method may be from a superclass. (Not implemented yet)
# ...
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndType(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'in(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'findListByStatementAsync(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'findOneByStatement(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'executeAsyncRead(CassandraAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetById(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetById(BaseAssetService)', 'Calls', 'findById(JpaAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetByIdAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetByIdAsync(BaseAssetService)', 'Calls', 'findByIdAsync(JpaAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetByTenantIdAndName(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveAsset(BaseAssetService)', 'Calls', 'validate(Asset)']: discarding
# WARNING: unable to recover ['saveAsset(BaseAssetService)', 'Calls', 'save(JpaAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(BaseAssetService)', 'Calls', 'save(JpaAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsset(BaseAssetService)', 'Calls', 'extractConstraintViolationException(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(BaseAssetService)', 'Calls', 'deleteEntityRelations(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(BaseAssetService)', 'Calls', 'findById(JpaAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAsset(BaseAssetService)', 'Calls', 'removeById(JpaAssetDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantId(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndType(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndType(BaseAssetService)', 'Calls', 'validateString(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndType(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateIds(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndIdsAsync(BaseAssetService)', 'Calls', 'toUUIDs(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteAssetsByTenantId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteAssetsByTenantId(BaseAssetService)', 'Calls', 'removeEntities(TenantId)']: discarding
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerId(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validateString(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateIds(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'toUUIDs(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignCustomerAssets(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unassignCustomerAssets(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['unassignCustomerAssets(BaseAssetService)', 'Calls', 'removeEntities(CustomerId)']: discarding
# WARNING: unable to recover ['findAssetTypesByTenantId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['save(BaseEventService)', 'Calls', 'validate(Event)']: discarding
# WARNING: Unable to recover target method for edge ['saveAsync(BaseEventService)', 'Calls', 'validate(Event)']: discarding
# WARNING: Unable to recover target method for edge ['saveIfNotExists(BaseEventService)', 'Calls', 'validate(Event)']: discarding
# WARNING: unable to recover ['removeEvents(BaseEventService)', 'Calls', 'removeById(JpaBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsync(CassandraBaseEventDao)', 'Calls', 'ttl(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveAsync(CassandraBaseEventDao)', 'Calls', 'executeAsyncWrite(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvent(CassandraBaseEventDao)', 'Calls', 'select(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvent(CassandraBaseEventDao)', 'Calls', 'findOneByStatement(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvents(CassandraBaseEventDao)', 'Calls', 'findPageWithTimeSearch(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'select(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'findListByStatement(CassandraBaseEventDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomersByTenantId(CassandraCustomerDao)', 'Calls', 'findPageWithTextSearch(CassandraCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomersByTenantId(CassandraCustomerDao)', 'Calls', 'eq(CassandraCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'select(CassandraCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'eq(CassandraCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'eq(CassandraCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'findOneByStatement(CassandraCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomerById(CustomerServiceImpl)', 'Calls', 'findById(JpaCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomerByTenantIdAndTitle(CustomerServiceImpl)', 'Calls', 'validateId(CustomerServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomerByIdAsync(CustomerServiceImpl)', 'Calls', 'validateId(CustomerServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCustomerByIdAsync(CustomerServiceImpl)', 'Calls', 'findByIdAsync(JpaCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveCustomer(CustomerServiceImpl)', 'Calls', 'validate(Customer)']: discarding
# WARNING: unable to recover ['saveCustomer(CustomerServiceImpl)', 'Calls', 'save(JpaCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteCustomer(CustomerServiceImpl)', 'Calls', 'deleteEntityRelations(CustomerServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteCustomer(CustomerServiceImpl)', 'Calls', 'removeById(JpaCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findOrCreatePublicCustomer(CustomerServiceImpl)', 'Calls', 'readValue(CustomerServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findOrCreatePublicCustomer(CustomerServiceImpl)', 'Calls', 'save(JpaCustomerDao)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteCustomersByTenantId(CustomerServiceImpl)', 'Calls', 'removeEntities(TenantId)']: discarding

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# Adding new node for method getQuery(HsqlRelationInsertRepository)
# Adding new node for method getQuery(PsqlRelationInsertRepository)
# Adding new node for method saveAndGet(HsqlComponentDescriptorInsertRepository)
# Adding new node for method getQuery(HsqlComponentDescriptorInsertRepository)
# Adding new node for method saveAndGet(PsqlComponentDescriptorInsertRepository)
# Adding new node for method getQuery(PsqlComponentDescriptorInsertRepository)
# Adding new node for method saveAndGet(HsqlEventInsertRepository)
# Adding new node for method getQuery(HsqlEventInsertRepository)
# Adding new node for method saveAndGet(PsqlEventInsertRepository)
# Adding new node for method getQuery(PsqlEventInsertRepository)
# Adding new node for method replaceNullChars(TimescaleInsertTsRepository)
# Adding new node for method replaceNullChars(PsqlInsertTsRepository)
# INFO: Edge ['performInstall(ThingsboardInstallService)', 'Calls', 'createDatabaseSchema(CassandraEntityDatabaseSchemaService)'] skipped
# INFO: Edge ['performInstall(ThingsboardInstallService)', 'Calls', 'createDatabaseSchema(CassandraTsDatabaseSchemaService)'] skipped
# INFO: Edge ['initExecutor(DefaultTbRuleEngineRpcService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped
# INFO: Edge ['sendRpcRequestToDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'isPresent(DefaultTbCoreDeviceRpcService)'] skipped
# INFO: Edge ['sendRpcRequestToDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'get(DefaultTbCoreDeviceRpcService)'] skipped
# INFO: Edge ['processRpcResponseFromDevice(DefaultTbRuleEngineRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped
# INFO: Edge ['forwardRpcRequestToDeviceActor(DefaultTbRuleEngineRpcService)', 'Calls', 'put(FromDeviceRpcResponse)'] skipped
# INFO: Edge ['sendRpcResponseToTbCore(DefaultTbRuleEngineRpcService)', 'Calls', 'isPresent(DefaultTbCoreDeviceRpcService)'] skipped
# INFO: Edge ['sendRpcResponseToTbCore(DefaultTbRuleEngineRpcService)', 'Calls', 'get(DefaultTbCoreDeviceRpcService)'] skipped
# INFO: Edge ['scheduleTimeout(DefaultTbRuleEngineRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped
# INFO: Edge ['initExecutor(DefaultTbCoreDeviceRpcService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped
# INFO: Edge ['processRestApiRpcRequest(DefaultTbCoreDeviceRpcService)', 'Calls', 'put(FromDeviceRpcResponse)'] skipped
# INFO: Edge ['processRpcResponseFromRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped
# INFO: Edge ['forwardRpcRequestToDeviceActor(DefaultTbCoreDeviceRpcService)', 'Calls', 'put(ToDeviceRpcRequestActorMsg)'] skipped
# INFO: Edge ['processRpcResponseFromDeviceActor(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(ToDeviceRpcRequestActorMsg)'] skipped
# INFO: Edge ['sendRpcResponseToTbRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'isPresent(DefaultTbRuleEngineRpcService)'] skipped
# INFO: Edge ['sendRpcResponseToTbRuleEngine(DefaultTbCoreDeviceRpcService)', 'Calls', 'get(DefaultTbRuleEngineRpcService)'] skipped
# INFO: Edge ['scheduleToRuleEngineTimeout(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(FromDeviceRpcResponse)'] skipped
# INFO: Edge ['scheduleToDeviceTimeout(DefaultTbCoreDeviceRpcService)', 'Calls', 'remove(ToDeviceRpcRequestActorMsg)'] skipped
# INFO: Edge ['registerRuleNodeComponents(AnnotationComponentDiscoveryService)', 'Calls', 'put(ComponentDescriptor)'] skipped
# INFO: Edge ['registerRuleNodeComponents(AnnotationComponentDiscoveryService)', 'Calls', 'computeIfAbsent(ComponentDescriptor)'] skipped
# INFO: Edge ['registerComponents(AnnotationComponentDiscoveryService)', 'Calls', 'put(ComponentDescriptor)'] skipped
# INFO: Edge ['discoverComponents(AnnotationComponentDiscoveryService)', 'Calls', 'values(ComponentDescriptor)'] skipped
# INFO: Edge ['getComponent(AnnotationComponentDiscoveryService)', 'Calls', 'get(ComponentDescriptor)'] skipped
# INFO: Edge ['doInvokeFunction(RemoteJsInvokeService)', 'Calls', 'onScriptExecutionError(RemoteJsInvokeService)'] skipped
# INFO: Edge ['doInvokeFunction(RemoteJsInvokeService)', 'Calls', 'onScriptExecutionError(RemoteJsInvokeService)'] skipped
# INFO: Edge ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationSuccessHandler)'] skipped
# INFO: Edge ['onAuthenticationSuccess(Oauth2AuthenticationSuccessHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationSuccessHandler)'] skipped
# INFO: Edge ['onAuthenticationFailure(Oauth2AuthenticationFailureHandler)', 'Calls', 'getRedirectStrategy(Oauth2AuthenticationFailureHandler)'] skipped
# INFO: Edge ['getOrCreateUserByClientPrincipal(BasicOAuth2ClientMapper)', 'Calls', 'getOrCreateSecurityUserFromOAuth2User(BasicOAuth2ClientMapper)'] skipped
# INFO: Edge ['getOrCreateUserByClientPrincipal(CustomOAuth2ClientMapper)', 'Calls', 'getOrCreateSecurityUserFromOAuth2User(CustomOAuth2ClientMapper)'] skipped
# INFO: Edge ['doCleanUp(TimescaleTimeseriesCleanUpService)', 'Calls', 'executeQuery(TimescaleTimeseriesCleanUpService)'] skipped
# INFO: Edge ['doCleanUp(PsqlTimeseriesCleanUpService)', 'Calls', 'executeQuery(PsqlTimeseriesCleanUpService)'] skipped
# INFO: Edge ['doCleanUp(PsqlTimeseriesCleanUpService)', 'Calls', 'executeQuery(PsqlTimeseriesCleanUpService)'] skipped
# INFO: Edge ['doCleanUp(EventsCleanUpService)', 'Calls', 'executeQuery(EventsCleanUpService)'] skipped
# INFO: Edge ['createDatabaseSchema(TimescaleTsDatabaseSchemaService)', 'Calls', 'executeQuery(TimescaleTsDatabaseSchemaService)'] skipped
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(CassandraDatabaseUpgradeService)', 'Calls', 'loadCql(CassandraDatabaseUpgradeService)'] skipped
# INFO: Edge ['createDatabaseSchema(PsqlTsDatabaseSchemaService)', 'Calls', 'executeQuery(PsqlTsDatabaseSchemaService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'checkVersion(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'isOldSchema(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['copyTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['insertTimeseries(PsqlTsDatabaseUpgradeService)', 'Calls', 'executeQuery(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['loadSql(PsqlTsDatabaseUpgradeService)', 'Calls', 'loadFunctions(PsqlTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'checkVersion(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'isOldSchema(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['upgradeDatabase(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['insertTimeseries(TimescaleTsDatabaseUpgradeService)', 'Calls', 'executeQuery(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['loadSql(TimescaleTsDatabaseUpgradeService)', 'Calls', 'loadFunctions(TimescaleTsDatabaseUpgradeService)'] skipped
# INFO: Edge ['updateData(DefaultDataUpdateService)', 'Calls', 'updateEntities(Tenant)'] skipped
# INFO: Edge ['createJavaMailProperties(DefaultMailService)', 'Calls', 'equalsIgnoreCase(DefaultMailService)'] skipped
# INFO: Edge ['init(DefaultDeviceStateService)', 'Calls', 'nextInt(DefaultDeviceStateService)'] skipped
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['onDeviceDeleted(DefaultDeviceStateService)', 'Calls', 'get(TopicPartitionInfo)'] skipped
# INFO: Edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)'] skipped
# INFO: Edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'getOrDefault(DeviceId)'] skipped
# INFO: Edge ['onDeviceActivity(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)'] skipped
# INFO: Edge ['onDeviceInactivityTimeoutUpdate(DefaultDeviceStateService)', 'Calls', 'get(DeviceId)'] skipped
# INFO: Edge ['onQueueMsg(DefaultDeviceStateService)', 'Calls', 'containsKey(TopicPartitionInfo)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'keySet(TopicPartitionInfo)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(TopicPartitionInfo)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)'] skipped
# INFO: Edge ['initStateFromDB(DefaultDeviceStateService)', 'Calls', 'forEach(TopicPartitionInfo)'] skipped
# INFO: Edge ['addDeviceUsingState(DefaultDeviceStateService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)'] skipped
# INFO: Edge ['addDeviceUsingState(DefaultDeviceStateService)', 'Calls', 'put(DeviceId)'] skipped
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'keySet(DeviceId)'] skipped
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'size(DeviceId)'] skipped
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['updateState(DefaultDeviceStateService)', 'Calls', 'remove(DeviceId)'] skipped
# INFO: Edge ['getOrFetchDeviceStateData(DefaultDeviceStateService)', 'Calls', 'get(DeviceId)'] skipped
# INFO: Edge ['getOrFetchDeviceStateData(DefaultDeviceStateService)', 'Calls', 'putIfAbsent(DeviceId)'] skipped
# INFO: Edge ['init(DefaultUpdateService)', 'Calls', 'getClass(DefaultUpdateService)'] skipped
# INFO: Edge ['initExecutor(DefaultTelemetryWebSocketService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped
# INFO: Edge ['handleWebSocketSessionEvent(DefaultTelemetryWebSocketService)', 'Calls', 'put(WsSessionMetaData)'] skipped
# INFO: Edge ['handleWebSocketSessionEvent(DefaultTelemetryWebSocketService)', 'Calls', 'remove(WsSessionMetaData)'] skipped
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(TenantId)'] skipped
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(CustomerId)'] skipped
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped
# INFO: Edge ['processSessionClose(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(TenantId)'] skipped
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(CustomerId)'] skipped
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped
# INFO: Edge ['processSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'computeIfAbsent(UserId)'] skipped
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Calls', 'get(WsSessionMetaData)'] skipped
# INFO: Edge ['handleWsHistoryCmd(DefaultTelemetryWebSocketService)', 'Calls', 'isInstance(DefaultTelemetryWebSocketService)'] skipped
# INFO: Edge ['handleWsTimeseriesSubscription(DefaultTelemetryWebSocketService)', 'Calls', 'isInstance(DefaultTelemetryWebSocketService)'] skipped
# INFO: Edge ['validateSessionMetadata(DefaultTelemetryWebSocketService)', 'Calls', 'get(WsSessionMetaData)'] skipped
# INFO: Edge ['on(DefaultTelemetryWebSocketService)', 'Calls', 'onFailure(DefaultTelemetryWebSocketService)'] skipped
# INFO: Edge ['onApplicationEvent(DefaultTelemetrySubscriptionService)', 'Calls', 'clear(TopicPartitionInfo)'] skipped
# INFO: Edge ['onApplicationEvent(DefaultTelemetrySubscriptionService)', 'Calls', 'addAll(TopicPartitionInfo)'] skipped
# INFO: Edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped
# INFO: Edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'isPresent(DefaultSubscriptionManagerService)'] skipped
# INFO: Edge ['onAttributesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'get(DefaultSubscriptionManagerService)'] skipped
# INFO: Edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped
# INFO: Edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'isPresent(DefaultSubscriptionManagerService)'] skipped
# INFO: Edge ['onTimeSeriesUpdate(DefaultTelemetrySubscriptionService)', 'Calls', 'get(DefaultSubscriptionManagerService)'] skipped
# INFO: Edge ['initExecutor(DefaultSubscriptionManagerService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped
# INFO: Edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped
# INFO: Edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'computeIfAbsent(TopicPartitionInfo)'] skipped
# INFO: Edge ['addSubscription(DefaultSubscriptionManagerService)', 'Calls', 'computeIfAbsent(TbSubscription)'] skipped
# INFO: Edge ['cancelSubscription(DefaultSubscriptionManagerService)', 'Calls', 'get(TbSubscription)'] skipped
# INFO: Edge ['cancelSubscription(DefaultSubscriptionManagerService)', 'Calls', 'remove(TbSubscription)'] skipped
# INFO: Edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'clear(TopicPartitionInfo)'] skipped
# INFO: Edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'addAll(TopicPartitionInfo)'] skipped
# INFO: Edge ['onApplicationEvent(DefaultSubscriptionManagerService)', 'Calls', 'remove(TopicPartitionInfo)'] skipped
# INFO: Edge ['removeSubscriptionFromPartitionMap(DefaultSubscriptionManagerService)', 'Calls', 'get(TopicPartitionInfo)'] skipped
# INFO: Edge ['onApplicationEvent(DefaultTbLocalSubscriptionService)', 'Calls', 'values(TbSubscription)'] skipped
# INFO: Edge ['pushSubscriptionToManagerService(DefaultTbLocalSubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped
# INFO: Edge ['onSubscriptionUpdate(DefaultTbLocalSubscriptionService)', 'Calls', 'getOrDefault(TbSubscription)'] skipped
# INFO: Edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'get(TbSubscription)'] skipped
# INFO: Edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'remove(TbSubscription)'] skipped
# INFO: Edge ['cancelSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'contains(TopicPartitionInfo)'] skipped
# INFO: Edge ['cancelAllSessionSubscriptions(DefaultTbLocalSubscriptionService)', 'Calls', 'get(TbSubscription)'] skipped
# INFO: Edge ['registerSubscription(DefaultTbLocalSubscriptionService)', 'Calls', 'computeIfAbsent(TbSubscription)'] skipped
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'get(AssetId)'] skipped
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'get(AssetId)'] skipped
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'getServiceId(DefaultTbServiceInfoProvider)'] skipped
# INFO: Edge ['getServiceAssetId(DefaultRuleEngineStatisticsService)', 'Calls', 'put(AssetId)'] skipped
# INFO: Edge ['incrementRequests(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)'] skipped
# INFO: Edge ['incrementResponses(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)'] skipped
# INFO: Edge ['incrementFailures(DefaultJsInvokeStats)', 'Calls', 'add(StatsCounter)'] skipped
# INFO: Edge ['getRequests(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)'] skipped
# INFO: Edge ['getResponses(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)'] skipped
# INFO: Edge ['getFailures(DefaultJsInvokeStats)', 'Calls', 'get(StatsCounter)'] skipped
# INFO: Edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)'] skipped
# INFO: Edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)'] skipped
# INFO: Edge ['reset(DefaultJsInvokeStats)', 'Calls', 'clear(StatsCounter)'] skipped
# INFO: Edge ['handleNotification(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped
# INFO: Edge ['printStats(DefaultTbCoreConsumerService)', 'Calls', 'printStats(TbCoreConsumerStats)'] skipped
# INFO: Edge ['printStats(DefaultTbCoreConsumerService)', 'Calls', 'reset(TbCoreConsumerStats)'] skipped
# INFO: Edge ['forwardToSubMgrService(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped
# INFO: Edge ['forwardToStateService(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped
# INFO: Edge ['forwardToDeviceActor(DefaultTbCoreConsumerService)', 'Calls', 'log(TbCoreConsumerStats)'] skipped
# INFO: Edge ['init(DefaultTbRuleEngineConsumerService)', 'Calls', 'putIfAbsent(TbRuleEngineQueueConfiguration)'] skipped
# INFO: Edge ['init(DefaultTbRuleEngineConsumerService)', 'Calls', 'put(TbRuleEngineConsumerStats)'] skipped
# INFO: Edge ['launchMainConsumers(DefaultTbRuleEngineConsumerService)', 'Calls', 'get(TbRuleEngineQueueConfiguration)'] skipped
# INFO: Edge ['launchMainConsumers(DefaultTbRuleEngineConsumerService)', 'Calls', 'get(TbRuleEngineConsumerStats)'] skipped
# INFO: Edge ['printStats(DefaultTbRuleEngineConsumerService)', 'Calls', 'forEach(TbRuleEngineConsumerStats)'] skipped
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped
# INFO: Edge ['getAssetById(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'checkEntity(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped
# INFO: Edge ['saveAsset(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped
# INFO: Edge ['deleteAsset(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped
# INFO: Edge ['assignAssetToCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped
# INFO: Edge ['unassignAssetFromCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkAssetId(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'logEntityAction(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'emptyId(AssetController)'] skipped
# INFO: Edge ['assignAssetToPublicCustomer(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'createPageLink(AssetController)'] skipped
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getTenantAssets(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['getTenantAsset(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped
# INFO: Edge ['getTenantAsset(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getTenantAsset(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkParameter(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkCustomerId(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'createPageLink(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getCustomerAssets(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'checkArrayParameter(AssetController)'] skipped
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'toUUID(AssetController)'] skipped
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getAssetsByIds(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkEntityId(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'getTenantId(AssetController)'] skipped
# INFO: Edge ['findByQuery(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['getAssetTypes(AssetController)', 'Calls', 'getCurrentUser(AssetController)'] skipped
# INFO: Edge ['getAssetTypes(AssetController)', 'Calls', 'checkNotNull(AssetController)'] skipped
# INFO: Edge ['getAssetTypes(AssetController)', 'Calls', 'handleException(AssetController)'] skipped
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'checkDashboardInfoId(DashboardController)'] skipped
# INFO: Edge ['getDashboardInfoById(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['getDashboardById(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'checkEntity(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['saveDashboard(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['deleteDashboard(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'checkCustomerId(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToCustomer(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'checkCustomerId(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromCustomer(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['updateDashboardCustomers(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['addDashboardCustomers(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['removeDashboardCustomers(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['assignDashboardToPublicCustomer(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'checkDashboardId(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'logEntityAction(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'emptyId(DashboardController)'] skipped
# INFO: Edge ['unassignDashboardFromPublicCustomer(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['getTenantDashboards(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['getTenantDashboards(DashboardController)', 'Calls', 'createPageLink(DashboardController)'] skipped
# INFO: Edge ['getTenantDashboards(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['getTenantDashboards(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'checkParameter(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'getCurrentUser(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'toUUID(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'checkCustomerId(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'createPageLink(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'checkNotNull(DashboardController)'] skipped
# INFO: Edge ['getCustomerDashboards(DashboardController)', 'Calls', 'handleException(DashboardController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'checkNotNull(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'checkEntityId(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'checkEntityId(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'getTenantId(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# INFO: Edge ['saveRelation(EntityRelationController)', 'Calls', 'handleException(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkParameter(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkParameter(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkParameter(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkParameter(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkParameter(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkEntityId(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'checkEntityId(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'getTenantId(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'logEntityAction(EntityRelationController)'] skipped
# INFO: Edge ['deleteRelation(EntityRelationController)', 'Calls', 'getCurrentUser(EntityRelationController)'] skipped
# ...
# INFO: Edge ['savePartitionIfNotExist(JpaPsqlTimeseriesDao)', 'Calls', 'get(PsqlPartition)'] skipped
# INFO: Edge ['savePartition(JpaPsqlTimeseriesDao)', 'Calls', 'containsKey(PsqlPartition)'] skipped
# INFO: Edge ['savePartition(JpaPsqlTimeseriesDao)', 'Calls', 'put(PsqlPartition)'] skipped
# INFO: Edge ['printStats(CassandraBufferedRateExecutor)', 'Calls', 'getQueueSize(CassandraBufferedRateExecutor)'] skipped
# INFO: Edge ['findTenantsByRegion(CassandraTenantDao)', 'Calls', 'findPageWithTextSearch(CassandraTenantDao)'] skipped
# INFO: Edge ['findTenantsByRegion(CassandraTenantDao)', 'Calls', 'eq(CassandraTenantDao)'] skipped
# INFO: Edge ['findTenantById(TenantServiceImpl)', 'Calls', 'findById(JpaTenantDao)'] skipped
# INFO: Edge ['findTenantByIdAsync(TenantServiceImpl)', 'Calls', 'validateId(TenantServiceImpl)'] skipped
# INFO: Edge ['findTenantByIdAsync(TenantServiceImpl)', 'Calls', 'findByIdAsync(JpaTenantDao)'] skipped
# INFO: Edge ['saveTenant(TenantServiceImpl)', 'Calls', 'validate(Tenant)'] skipped
# INFO: Edge ['saveTenant(TenantServiceImpl)', 'Calls', 'save(JpaTenantDao)'] skipped
# INFO: Edge ['deleteTenant(TenantServiceImpl)', 'Calls', 'removeById(JpaTenantDao)'] skipped
# INFO: Edge ['deleteTenant(TenantServiceImpl)', 'Calls', 'deleteEntityRelations(TenantServiceImpl)'] skipped
# INFO: Edge ['deleteTenants(TenantServiceImpl)', 'Calls', 'removeEntities(Tenant)'] skipped
# INFO: Edge ['save(CassandraAssetDao)', 'Calls', 'executeWrite(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantId(CassandraAssetDao)', 'Calls', 'findPageWithTextSearch(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantId(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndType(CassandraAssetDao)', 'Calls', 'findPageWithTextSearch(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndType(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndType(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'in(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'findListByStatementAsync(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerId(CassandraAssetDao)', 'Calls', 'findPageWithTextSearch(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerId(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerId(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(CassandraAssetDao)', 'Calls', 'findPageWithTextSearch(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'in(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndIdsAsync(CassandraAssetDao)', 'Calls', 'findListByStatementAsync(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndName(CassandraAssetDao)', 'Calls', 'findOneByStatement(CassandraAssetDao)'] skipped
# INFO: Edge ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'select(CassandraAssetDao)'] skipped
# INFO: Edge ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'eq(CassandraAssetDao)'] skipped
# INFO: Edge ['findTenantAssetTypesAsync(CassandraAssetDao)', 'Calls', 'executeAsyncRead(CassandraAssetDao)'] skipped
# INFO: Edge ['findAssetById(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetById(BaseAssetService)', 'Calls', 'findById(JpaAssetDao)'] skipped
# INFO: Edge ['findAssetByIdAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetByIdAsync(BaseAssetService)', 'Calls', 'findByIdAsync(JpaAssetDao)'] skipped
# INFO: Edge ['findAssetByTenantIdAndName(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['saveAsset(BaseAssetService)', 'Calls', 'validate(Asset)'] skipped
# INFO: Edge ['saveAsset(BaseAssetService)', 'Calls', 'save(JpaAssetDao)'] skipped
# INFO: Edge ['saveAsset(BaseAssetService)', 'Calls', 'save(JpaAssetDao)'] skipped
# INFO: Edge ['saveAsset(BaseAssetService)', 'Calls', 'extractConstraintViolationException(BaseAssetService)'] skipped
# INFO: Edge ['deleteAsset(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['deleteAsset(BaseAssetService)', 'Calls', 'deleteEntityRelations(BaseAssetService)'] skipped
# INFO: Edge ['deleteAsset(BaseAssetService)', 'Calls', 'findById(JpaAssetDao)'] skipped
# INFO: Edge ['deleteAsset(BaseAssetService)', 'Calls', 'removeById(JpaAssetDao)'] skipped
# INFO: Edge ['findAssetsByTenantId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantId(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndType(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndType(BaseAssetService)', 'Calls', 'validateString(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndType(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateIds(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndIdsAsync(BaseAssetService)', 'Calls', 'toUUIDs(BaseAssetService)'] skipped
# INFO: Edge ['deleteAssetsByTenantId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['deleteAssetsByTenantId(BaseAssetService)', 'Calls', 'removeEntities(TenantId)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerId(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validateString(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdAndCustomerIdAndType(BaseAssetService)', 'Calls', 'validatePageLink(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'validateIds(BaseAssetService)'] skipped
# INFO: Edge ['findAssetsByTenantIdCustomerIdAndIdsAsync(BaseAssetService)', 'Calls', 'toUUIDs(BaseAssetService)'] skipped
# INFO: Edge ['unassignCustomerAssets(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['unassignCustomerAssets(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['unassignCustomerAssets(BaseAssetService)', 'Calls', 'removeEntities(CustomerId)'] skipped
# INFO: Edge ['findAssetTypesByTenantId(BaseAssetService)', 'Calls', 'validateId(BaseAssetService)'] skipped
# INFO: Edge ['save(BaseEventService)', 'Calls', 'validate(Event)'] skipped
# INFO: Edge ['saveAsync(BaseEventService)', 'Calls', 'validate(Event)'] skipped
# INFO: Edge ['saveIfNotExists(BaseEventService)', 'Calls', 'validate(Event)'] skipped
# INFO: Edge ['removeEvents(BaseEventService)', 'Calls', 'removeById(JpaBaseEventDao)'] skipped
# INFO: Edge ['saveAsync(CassandraBaseEventDao)', 'Calls', 'ttl(CassandraBaseEventDao)'] skipped
# INFO: Edge ['saveAsync(CassandraBaseEventDao)', 'Calls', 'executeAsyncWrite(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvent(CassandraBaseEventDao)', 'Calls', 'select(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvent(CassandraBaseEventDao)', 'Calls', 'findOneByStatement(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvents(CassandraBaseEventDao)', 'Calls', 'findPageWithTimeSearch(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'select(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'eq(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findLatestEvents(CassandraBaseEventDao)', 'Calls', 'findListByStatement(CassandraBaseEventDao)'] skipped
# INFO: Edge ['findCustomersByTenantId(CassandraCustomerDao)', 'Calls', 'findPageWithTextSearch(CassandraCustomerDao)'] skipped
# INFO: Edge ['findCustomersByTenantId(CassandraCustomerDao)', 'Calls', 'eq(CassandraCustomerDao)'] skipped
# INFO: Edge ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'select(CassandraCustomerDao)'] skipped
# INFO: Edge ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'eq(CassandraCustomerDao)'] skipped
# INFO: Edge ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'eq(CassandraCustomerDao)'] skipped
# INFO: Edge ['findCustomersByTenantIdAndTitle(CassandraCustomerDao)', 'Calls', 'findOneByStatement(CassandraCustomerDao)'] skipped
# INFO: Edge ['findCustomerById(CustomerServiceImpl)', 'Calls', 'findById(JpaCustomerDao)'] skipped
# INFO: Edge ['findCustomerByTenantIdAndTitle(CustomerServiceImpl)', 'Calls', 'validateId(CustomerServiceImpl)'] skipped
# INFO: Edge ['findCustomerByIdAsync(CustomerServiceImpl)', 'Calls', 'validateId(CustomerServiceImpl)'] skipped
# INFO: Edge ['findCustomerByIdAsync(CustomerServiceImpl)', 'Calls', 'findByIdAsync(JpaCustomerDao)'] skipped
# INFO: Edge ['saveCustomer(CustomerServiceImpl)', 'Calls', 'validate(Customer)'] skipped
# INFO: Edge ['saveCustomer(CustomerServiceImpl)', 'Calls', 'save(JpaCustomerDao)'] skipped
# INFO: Edge ['deleteCustomer(CustomerServiceImpl)', 'Calls', 'deleteEntityRelations(CustomerServiceImpl)'] skipped
# INFO: Edge ['deleteCustomer(CustomerServiceImpl)', 'Calls', 'removeById(JpaCustomerDao)'] skipped
# INFO: Edge ['findOrCreatePublicCustomer(CustomerServiceImpl)', 'Calls', 'readValue(CustomerServiceImpl)'] skipped
# INFO: Edge ['findOrCreatePublicCustomer(CustomerServiceImpl)', 'Calls', 'save(JpaCustomerDao)'] skipped
# INFO: Edge ['deleteCustomersByTenantId(CustomerServiceImpl)', 'Calls', 'removeEntities(TenantId)'] skipped
# INFO: Added edge ['processSaveOrUpdate(HsqlRelationInsertRepository)', 'Calls', 'getQuery(HsqlRelationInsertRepository)']
# INFO: Added edge ['processSaveOrUpdate(PsqlRelationInsertRepository)', 'Calls', 'getQuery(PsqlRelationInsertRepository)']
# INFO: Added edge ['saveOrUpdate(HsqlComponentDescriptorInsertRepository)', 'Calls', 'saveAndGet(HsqlComponentDescriptorInsertRepository)']
# INFO: Added edge ['doProcessSaveOrUpdate(HsqlComponentDescriptorInsertRepository)', 'Calls', 'getQuery(HsqlComponentDescriptorInsertRepository)']
# INFO: Added edge ['saveOrUpdate(PsqlComponentDescriptorInsertRepository)', 'Calls', 'saveAndGet(PsqlComponentDescriptorInsertRepository)']
# INFO: Added edge ['doProcessSaveOrUpdate(PsqlComponentDescriptorInsertRepository)', 'Calls', 'getQuery(PsqlComponentDescriptorInsertRepository)']
# INFO: Added edge ['saveOrUpdate(HsqlEventInsertRepository)', 'Calls', 'saveAndGet(HsqlEventInsertRepository)']
# INFO: Added edge ['doProcessSaveOrUpdate(HsqlEventInsertRepository)', 'Calls', 'getQuery(HsqlEventInsertRepository)']
# INFO: Added edge ['saveOrUpdate(PsqlEventInsertRepository)', 'Calls', 'saveAndGet(PsqlEventInsertRepository)']
# INFO: Added edge ['doProcessSaveOrUpdate(PsqlEventInsertRepository)', 'Calls', 'getQuery(PsqlEventInsertRepository)']
# INFO: Added edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(TimescaleInsertTsRepository)', 'Calls', 'replaceNullChars(TimescaleInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)']
# INFO: Added edge ['saveOrUpdate(PsqlInsertTsRepository)', 'Calls', 'replaceNullChars(PsqlInsertTsRepository)']
# INFO: Added edge [ 'getQuery(HsqlRelationInsertRepository)', 'Persists', 'AbstractRelationInsertRepository']
# INFO: Added edge [ 'getQuery(PsqlRelationInsertRepository)', 'Persists', 'AbstractRelationInsertRepository']
# INFO: Added edge [ 'saveAndGet(HsqlComponentDescriptorInsertRepository)', 'Persists', 'AbstractComponentDescriptorInsertRepository']
# INFO: Added edge [ 'getQuery(HsqlComponentDescriptorInsertRepository)', 'Persists', 'AbstractComponentDescriptorInsertRepository']
# INFO: Added edge [ 'saveAndGet(PsqlComponentDescriptorInsertRepository)', 'Persists', 'AbstractComponentDescriptorInsertRepository']
# INFO: Added edge [ 'getQuery(PsqlComponentDescriptorInsertRepository)', 'Persists', 'AbstractComponentDescriptorInsertRepository']
# INFO: Added edge [ 'saveAndGet(HsqlEventInsertRepository)', 'Persists', 'AbstractEventInsertRepository']
# INFO: Added edge [ 'getQuery(HsqlEventInsertRepository)', 'Persists', 'AbstractEventInsertRepository']
# INFO: Added edge [ 'saveAndGet(PsqlEventInsertRepository)', 'Persists', 'AbstractEventInsertRepository']
# INFO: Added edge [ 'getQuery(PsqlEventInsertRepository)', 'Persists', 'AbstractEventInsertRepository']

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity ThingsboardMqttTransportApplication
# Removed Entity ThingsboardCoapTransportApplication
# Removed Entity ThingsboardServerApplication
# Removed Entity ThingsboardInstallApplication
# Removed Entity JsInvokeResponse
# Removed Entity RuleNodeScriptFactory
# Removed Entity JsInvokeRequest
# Removed Entity JsStatCallback
# Removed Entity RemoteJsRequestEncoder
# Removed Entity RemoteJsResponseDecoder
# Removed Entity ValidationCallback
# Removed Entity AbstractPermissions
# Removed Entity AbstractOAuth2ClientMapper
# Removed Entity RefreshTokenRequest
# Removed Entity RefreshTokenProcessingFilter
# Removed Entity JwtTokenAuthenticationProcessingFilter
# Removed Entity SkipPathRequestMatcher
# Removed Entity RestAuthenticationDetailsSource
# Removed Entity LoginRequest
# Removed Entity PublicLoginRequest
# Removed Entity RestPublicLoginProcessingFilter
# Removed Entity RestLoginProcessingFilter
# Removed Entity SqlAbstractDatabaseSchemaService
# Removed Entity CassandraAbstractDatabaseSchemaService
# Removed Entity AbstractSqlTsDatabaseUpgradeService
# Removed Entity AbstractCassandraDatabaseUpgradeService
# Removed Entity DatabaseHelper
# Removed Entity SqlDbHelper
# Removed Entity CQLStatementsParser
# Removed Entity CassandraDbHelper
# Removed Entity PaginatedUpdater
# Removed Entity AttributeData
# Removed Entity TsData
# Removed Entity EntityNotFoundException
# Removed Entity UncheckedApiException
# Removed Entity InternalErrorException
# Removed Entity InvalidParametersException
# Removed Entity TbSubscriptionUtils
# Removed Entity TbPackCallback
# Removed Entity TbPackProcessingContext
# Removed Entity AbstractConsumerService
# Removed Entity BaseController
# Removed Entity TbUrlConstants
# Removed Entity MiscUtils
# Removed Entity TbEntityTypeActorIdPredicate
# Removed Entity ActorTerminationMsg
# Removed Entity ToServerRpcRequestMetadata
# Removed Entity StatsPersistTick
# Removed Entity AppInitMsg
# Removed Entity AzureIotHubSasCredentials
# Removed Entity AnonymousCredentials
# Removed Entity BasicCredentials
# Removed Entity CertPemClientCredentials
# Removed Entity EntitiesTenantIdAsyncLoader
# Removed Entity EntitiesRelatedDeviceIdAsyncLoader
# Removed Entity EntitiesCustomerIdAsyncLoader
# Removed Entity EntitiesRelatedEntityIdAsyncLoader
# Removed Entity EntitiesFieldsAsyncLoader
# Removed Entity EntityContainer
# Removed Entity EntitiesAlarmOriginatorIdAsyncLoader
# Removed Entity EmailPojo
# Removed Entity TbMsgCountNodeConfiguration
# Removed Entity TbAbstractAlarmNode
# Removed Entity TbMsgCountNode
# Removed Entity Coordinates
# Removed Entity AbstractGeofencingNode
# Removed Entity GeoUtil
# Removed Entity Perimeter
# Removed Entity TbSynchronizationBeginNode
# Removed Entity TbSynchronizationEndNode
# Removed Entity TbAbstractGetEntityDetailsNode
# Removed Entity TbAbstractGetAttributesNode
# Removed Entity TbNodeConfiguration
# Removed Entity TbNodeState
# Removed Entity TbNodeException
# Removed Entity TbRelationTypes
# Removed Entity TbNodeUtils
# Removed Entity AbstractListeningExecutor
# Removed Entity AzureIotHubUtil
# Removed Entity ThingsBoardThreadFactory
# Removed Entity DonAsynchron
# Removed Entity MqttTransportServerInitializer
# Removed Entity MqttTopics
# Removed Entity SslUtil
# Removed Entity JsonConverter
# Removed Entity ToTransportMsgResponseDecoder
# Removed Entity ToRuleEngineMsgEncoder
# Removed Entity TransportApiResponseDecoder
# Removed Entity TransportApiRequestEncoder
# Removed Entity JsonUtils
# Removed Entity DeviceEmulator
# Removed Entity DataConstants
# Removed Entity ContactBased
# Removed Entity EntityFieldsData
# Removed Entity SearchTextBasedWithAdditionalInfo
# Removed Entity CacheConstants
# Removed Entity SearchTextBased
# Removed Entity UUIDConverter
# Removed Entity RpcRequest
# Removed Entity DeviceTokenCredentials
# Removed Entity DeviceX509Credentials
# Removed Entity EntityIdDeserializer
# Removed Entity EntityIdFactory
# Removed Entity EntityIdSerializer
# Removed Entity IdBased
# Removed Entity AbstractCassandraCluster
# Removed Entity TbServiceBusConsumerTemplate
# Removed Entity TbServiceBusAdmin
# Removed Entity TbServiceBusProducerTemplate
# Removed Entity ConsistentHashCircle
# Removed Entity TbPubSubProducerTemplate
# Removed Entity TbPubSubAdmin
# Removed Entity TbPubSubConsumerTemplate
# Removed Entity AbstractParallelTbQueueConsumerTemplate
# Removed Entity TbProtoJsQueueMsg
# Removed Entity TbProtoQueueMsg
# Removed Entity TbQueueTbMsgCallbackWrapper
# Removed Entity AsyncCallbackTemplate
# Removed Entity MultipleTbQueueTbMsgCallbackWrapper
# Removed Entity TbAwsSqsAdmin
# Removed Entity TbAwsSqsProducerTemplate
# Removed Entity AwsSqsTbQueueMsgMetadata
# Removed Entity TbAwsSqsConsumerTemplate
# Removed Entity TbRabbitMqConsumerTemplate
# Removed Entity TbRabbitMqAdmin
# Removed Entity KafkaTbQueueMsgMetadata
# Removed Entity TbKafkaAdmin
# Removed Entity TbKafkaProperty
# Removed Entity KafkaTbQueueMsg
# Removed Entity TbStringActorId
# Removed Entity InitFailureStrategy
# Removed Entity ProcessFailureStrategy
# Removed Entity TbActorException
# Removed Entity TbActorNotRegisteredException
# Removed Entity TbEntityActorId
# Removed Entity EncryptionUtil
# Removed Entity ProcessingTimeoutException
# Removed Entity DeviceActorServerSideRpcTimeoutMsg
# Removed Entity TimeoutMsg
# Removed Entity ChannelClosedException
# Removed Entity RetransmissionHandler
# Removed Entity MqttPingHandler
# Removed Entity DaoUtil
# Removed Entity PreviousDeviceCredentialsIdKeyGenerator
# Removed Entity CacheSpecs
# Removed Entity AuditLogLevelFilter
# Removed Entity JpaAbstractSearchTimeDao
# Removed Entity TbSqlQueueElement
# Removed Entity JpaAbstractSearchTextDao
# Removed Entity SimpleListenableFuture
# Removed Entity TimePaginatedRemover
# Removed Entity PaginatedRemover
# Removed Entity DataValidator
# Removed Entity Validator
# Removed Entity AsyncTaskContext
# Removed Entity JacksonUtil
# Removed Entity JsonTypeDescriptor
# Removed Entity JsonStringType
# Removed Entity TsKey
# Removed Entity CassandraAbstractSearchTextDao
# Removed Entity RateLimitedResultSetFuture
# Removed Entity CassandraAbstractSearchTimeDao
# Removed Entity BaseSqlEntity
# Removed Entity DeviceEntity
# Removed Entity DashboardEntity
# Removed Entity AdminSettingsEntity
# Removed Entity WidgetTypeEntity
# Removed Entity TenantEntity
# Removed Entity CustomerEntity
# Removed Entity WidgetsBundleEntity
# Removed Entity ComponentDescriptorEntity
# Removed Entity UserEntity
# Removed Entity RuleNodeEntity
# Removed Entity DashboardInfoEntity
# Removed Entity EntityViewEntity
# Removed Entity DeviceCredentialsEntity
# Removed Entity RuleChainEntity
# Removed Entity AlarmEntity
# Removed Entity AssetEntity
# Removed Entity UserCredentialsEntity
# Removed Entity EventEntity
# Removed Entity AuditLogEntity
# Removed Entity EntityResultSet
# Removed Entity DeviceCredentialsTypeCodec
# Removed Entity ActionStatusCodec
# Removed Entity ActionTypeCodec
# Removed Entity AlarmStatusCodec
# Removed Entity JsonCodec
# Removed Entity RelationTypeGroupCodec
# Removed Entity ComponentTypeCodec
# Removed Entity AuthorityCodec
# Removed Entity ComponentLifecycleStateCodec
# Removed Entity ComponentScopeCodec
# Removed Entity EntityTypeCodec
# Removed Entity AlarmSeverityCodec
# Removed Entity TsKvCompositeKey
# Removed Entity TimescaleTsKvCompositeKey
# Removed Entity TsKvDictionaryCompositeKey
# Removed Entity TsKvDictionary
# Removed Entity AbstractEntityService
# Removed Entity AssetTypeFilter
# Removed Entity BufferLimitException
# Removed Entity DatabaseException
# Removed setTbCoreRpcService (DefaultTbRuleEngineRpcService)
# Removed initExecutor (DefaultTbRuleEngineRpcService)
# Removed shutdownExecutor (DefaultTbRuleEngineRpcService)
# Removed setTbRuleEngineRpcService (DefaultTbCoreDeviceRpcService)
# Removed initExecutor (DefaultTbCoreDeviceRpcService)
# Removed shutdownExecutor (DefaultTbCoreDeviceRpcService)
# Removed getThreadPollSize (JsExecutorService)
# Removed useJsSandbox (NashornJsInvokeService)
# Removed getMonitorThreadPoolSize (NashornJsInvokeService)
# Removed getMaxCpuTime (NashornJsInvokeService)
# Removed getMaxErrors (NashornJsInvokeService)
# Removed getMaxBlacklistDuration (NashornJsInvokeService)
# Removed printStats (RemoteJsInvokeService)
# Removed init (RemoteJsInvokeService)
# Removed destroy (RemoteJsInvokeService)
# Removed doEval (RemoteJsInvokeService)
# Removed doInvokeFunction (RemoteJsInvokeService)
# Removed doRelease (RemoteJsInvokeService)
# Removed getMaxBlacklistDuration (RemoteJsInvokeService)
# Removed initExecutor (AccessValidator)
# Removed shutdownExecutor (AccessValidator)
# Removed handleError (AccessValidator)
# Removed onAuthenticationFailure (Oauth2AuthenticationFailureHandler)
# Removed extract (JwtHeaderTokenExtractor)
# Removed extract (JwtQueryTokenExtractor)
# Removed supports (RestAuthenticationProvider)
# Removed getThreadPollSize (ExternalCallExecutorService)
# Removed getThreadPollSize (DbCallbackExecutorService)
# Removed init (SharedEventLoopGroupService)
# Removed destroy (SharedEventLoopGroupService)
# Removed doCleanUp (TimescaleTimeseriesCleanUpService)
# Removed doCleanUp (PsqlTimeseriesCleanUpService)
# Removed passwordEncoder (DefaultSystemDataLoaderService)
# Removed createDatabaseSchema (TimescaleTsDatabaseSchemaService)
# Removed createDatabaseSchema (PsqlTsDatabaseSchemaService)
# Removed onApplicationEvent (TbCoreTransportApiService)
# Removed destroy (TbCoreTransportApiService)
# Removed send (DefaultMailService)
# Removed getThreadPollSize (MailExecutorService)
# Removed decode (ProtoWithFSTService)
# Removed setTsSubService (DefaultDeviceStateService)
# Removed init (DefaultDeviceStateService)
# Removed stop (DefaultDeviceStateService)
# Removed destroy (DefaultUpdateService)
# Removed initExecutor (DefaultTelemetryWebSocketService)
# Removed shutdownExecutor (DefaultTelemetryWebSocketService)
# Removed mergeAllAttributesFutures (DefaultTelemetryWebSocketService)
# Removed getAggregation (DefaultTelemetryWebSocketService)
# Removed getLimit (DefaultTelemetryWebSocketService)
# Removed setSubscriptionManagerService (DefaultTelemetrySubscriptionService)
# Removed initExecutor (DefaultTelemetrySubscriptionService)
# Removed shutdownExecutor (DefaultTelemetrySubscriptionService)
# Removed shutdownExecutor (DefaultSubscriptionManagerService)
# Removed initExecutor (DefaultTbLocalSubscriptionService)
# Removed shutdownExecutor (DefaultTbLocalSubscriptionService)
# Removed incrementRequests (DefaultJsInvokeStats)
# Removed incrementResponses (DefaultJsInvokeStats)
# Removed incrementFailures (DefaultJsInvokeStats)
# Removed init (DefaultTbCoreConsumerService)
# Removed destroy (DefaultTbCoreConsumerService)
# Removed getServiceType (DefaultTbCoreConsumerService)
# Removed getNotificationPollDuration (DefaultTbCoreConsumerService)
# Removed getNotificationPackProcessingTimeout (DefaultTbCoreConsumerService)
# Removed printStats (DefaultTbCoreConsumerService)
# Removed stopMainConsumers (DefaultTbCoreConsumerService)
# Removed stop (DefaultTbRuleEngineConsumerService)
# Removed stopMainConsumers (DefaultTbRuleEngineConsumerService)
# Removed getServiceType (DefaultTbRuleEngineConsumerService)
# Removed getNotificationPollDuration (DefaultTbRuleEngineConsumerService)
# Removed getNotificationPackProcessingTimeout (DefaultTbRuleEngineConsumerService)
# Removed printStats (DefaultTbClusterService)
# Removed getServerTime (DashboardController)
# Removed getMaxDatapointsLimit (DashboardController)
# Removed deleteRelations (EntityRelationController)
# Removed isUserTokenAccessEnabled (UserController)
# Removed getTenantQueuesByServiceType (QueueController)
# Removed redirect (WebConfig)
# Removed getServiceId (ActorSystemContext)
# Removed toException (ActorSystemContext)
# Removed tell (ActorSystemContext)
# Removed stopActorSystem (DefaultActorService)
# Removed init (MqttTransportService)
# Removed shutdown (MqttTransportService)
# Removed init (TransportContext)
# Removed stop (TransportContext)
# Removed getNodeId (TransportContext)
# Removed destroy (DefaultTransportService)
# Removed setTransportService (TransportTenantRoutingInfoService)
# Removed getDeviceAttributes (DeviceApiController)
# Removed postDeviceAttributes (DeviceApiController)
# Removed postTelemetry (DeviceApiController)
# Removed claimDevice (DeviceApiController)
# Removed subscribeToCommands (DeviceApiController)
# Removed replyToCommand (DeviceApiController)
# Removed postRpcRequest (DeviceApiController)
# Removed subscribeToAttributes (DeviceApiController)
# Removed reportActivity (DeviceApiController)
# Removed shutdown (CoapTransportService)
# Removed getObserveNotification (JsonCoapAdaptor)
# Removed init (CassandraCluster)
# Removed initOpts (CassandraQueryOptions)
# Removed getDefaultReadConsistencyLevel (CassandraQueryOptions)
# Removed getDefaultWriteConsistencyLevel (CassandraQueryOptions)
# Removed initOpts (CassandraSocketOptions)
# Removed init (CassandraInstallCluster)
# Removed createGauge (DefaultStatsFactory)
# Removed checkReconnect (ZkDiscoveryService)
# Removed isService (DefaultTbServiceInfoProvider)
# Removed destroy (KafkaTbRuleEngineQueueFactory)
# Removed createTransportNotificationsMsgProducer (AwsSqsTbRuleEngineQueueFactory)
# Removed createRuleEngineMsgProducer (AwsSqsTbRuleEngineQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (AwsSqsTbRuleEngineQueueFactory)
# Removed createTbCoreMsgProducer (AwsSqsTbRuleEngineQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (AwsSqsTbRuleEngineQueueFactory)
# Removed destroy (AwsSqsTbRuleEngineQueueFactory)
# Removed createToCoreMsgConsumer (ServiceBusTbCoreQueueFactory)
# Removed destroy (ServiceBusTbCoreQueueFactory)
# Removed getTransportNotificationsMsgProducer (TbTransportQueueProducerProvider)
# Removed getRuleEngineMsgProducer (TbTransportQueueProducerProvider)
# Removed getTbCoreMsgProducer (TbTransportQueueProducerProvider)
# Removed getRuleEngineNotificationsMsgProducer (TbTransportQueueProducerProvider)
# Removed getTbCoreNotificationsMsgProducer (TbTransportQueueProducerProvider)
# Removed getTransportNotificationsMsgProducer (TbRuleEngineProducerProvider)
# Removed getRuleEngineMsgProducer (TbRuleEngineProducerProvider)
# Removed getRuleEngineNotificationsMsgProducer (TbRuleEngineProducerProvider)
# Removed getTbCoreMsgProducer (TbRuleEngineProducerProvider)
# Removed getTbCoreNotificationsMsgProducer (TbRuleEngineProducerProvider)
# Removed createTransportNotificationsMsgProducer (RabbitMqMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (RabbitMqMonolithQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (RabbitMqMonolithQueueFactory)
# Removed createTbCoreMsgProducer (RabbitMqMonolithQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (RabbitMqMonolithQueueFactory)
# Removed createToCoreMsgConsumer (RabbitMqMonolithQueueFactory)
# Removed createTransportApiRequestConsumer (RabbitMqMonolithQueueFactory)
# Removed createTransportApiResponseProducer (RabbitMqMonolithQueueFactory)
# Removed destroy (RabbitMqMonolithQueueFactory)
# Removed createTransportNotificationsMsgProducer (AwsSqsTbCoreQueueFactory)
# Removed createRuleEngineMsgProducer (AwsSqsTbCoreQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (AwsSqsTbCoreQueueFactory)
# Removed createTbCoreMsgProducer (AwsSqsTbCoreQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (AwsSqsTbCoreQueueFactory)
# Removed createToCoreMsgConsumer (AwsSqsTbCoreQueueFactory)
# Removed createTransportApiRequestConsumer (AwsSqsTbCoreQueueFactory)
# Removed createTransportApiResponseProducer (AwsSqsTbCoreQueueFactory)
# Removed destroy (AwsSqsTbCoreQueueFactory)
# Removed createTransportNotificationsMsgProducer (PubSubMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (PubSubMonolithQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (PubSubMonolithQueueFactory)
# Removed createTbCoreMsgProducer (PubSubMonolithQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (PubSubMonolithQueueFactory)
# Removed createToCoreMsgConsumer (PubSubMonolithQueueFactory)
# Removed createTransportApiRequestConsumer (PubSubMonolithQueueFactory)
# Removed createTransportApiResponseProducer (PubSubMonolithQueueFactory)
# Removed destroy (PubSubMonolithQueueFactory)
# Removed destroy (RabbitMqTransportQueueFactory)
# Removed destroy (KafkaMonolithQueueFactory)
# Removed createTransportNotificationsMsgProducer (ServiceBusTbRuleEngineQueueFactory)
# Removed createRuleEngineMsgProducer (ServiceBusTbRuleEngineQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (ServiceBusTbRuleEngineQueueFactory)
# Removed createTbCoreMsgProducer (ServiceBusTbRuleEngineQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (ServiceBusTbRuleEngineQueueFactory)
# Removed destroy (ServiceBusTbRuleEngineQueueFactory)
# Removed createTransportNotificationsMsgProducer (AwsSqsMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (AwsSqsMonolithQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (AwsSqsMonolithQueueFactory)
# Removed createTbCoreMsgProducer (AwsSqsMonolithQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (AwsSqsMonolithQueueFactory)
# Removed createToCoreMsgConsumer (AwsSqsMonolithQueueFactory)
# Removed createTransportApiRequestConsumer (AwsSqsMonolithQueueFactory)
# Removed createTransportApiResponseProducer (AwsSqsMonolithQueueFactory)
# Removed destroy (AwsSqsMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (ServiceBusTransportQueueFactory)
# Removed createTbCoreMsgProducer (ServiceBusTransportQueueFactory)
# Removed createTransportNotificationsConsumer (ServiceBusTransportQueueFactory)
# Removed destroy (ServiceBusTransportQueueFactory)
# Removed createTransportNotificationsMsgProducer (ServiceBusMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (ServiceBusMonolithQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (ServiceBusMonolithQueueFactory)
# Removed createTbCoreMsgProducer (ServiceBusMonolithQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (ServiceBusMonolithQueueFactory)
# Removed createToCoreMsgConsumer (ServiceBusMonolithQueueFactory)
# Removed createTransportApiRequestConsumer (ServiceBusMonolithQueueFactory)
# Removed createTransportApiResponseProducer (ServiceBusMonolithQueueFactory)
# Removed destroy (ServiceBusMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (PubSubTransportQueueFactory)
# Removed createTbCoreMsgProducer (PubSubTransportQueueFactory)
# Removed createTransportNotificationsConsumer (PubSubTransportQueueFactory)
# Removed destroy (PubSubTransportQueueFactory)
# Removed destroy (KafkaTbTransportQueueFactory)
# Removed createRuleEngineMsgProducer (InMemoryTbTransportQueueFactory)
# Removed createTbCoreMsgProducer (InMemoryTbTransportQueueFactory)
# Removed createTransportNotificationsConsumer (InMemoryTbTransportQueueFactory)
# Removed destroy (KafkaTbCoreQueueFactory)
# Removed createTransportNotificationsMsgProducer (RabbitMqTbCoreQueueFactory)
# Removed createRuleEngineMsgProducer (RabbitMqTbCoreQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (RabbitMqTbCoreQueueFactory)
# Removed createTbCoreMsgProducer (RabbitMqTbCoreQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (RabbitMqTbCoreQueueFactory)
# Removed createToCoreMsgConsumer (RabbitMqTbCoreQueueFactory)
# Removed createTransportApiRequestConsumer (RabbitMqTbCoreQueueFactory)
# Removed createTransportApiResponseProducer (RabbitMqTbCoreQueueFactory)
# Removed destroy (RabbitMqTbCoreQueueFactory)
# Removed createTransportNotificationsMsgProducer (RabbitMqTbRuleEngineQueueFactory)
# Removed createRuleEngineMsgProducer (RabbitMqTbRuleEngineQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (RabbitMqTbRuleEngineQueueFactory)
# Removed createTbCoreMsgProducer (RabbitMqTbRuleEngineQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (RabbitMqTbRuleEngineQueueFactory)
# Removed destroy (RabbitMqTbRuleEngineQueueFactory)
# Removed createTransportNotificationsMsgProducer (PubSubTbCoreQueueFactory)
# Removed createRuleEngineMsgProducer (PubSubTbCoreQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (PubSubTbCoreQueueFactory)
# Removed createTbCoreMsgProducer (PubSubTbCoreQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (PubSubTbCoreQueueFactory)
# Removed createToCoreMsgConsumer (PubSubTbCoreQueueFactory)
# Removed createTransportApiRequestConsumer (PubSubTbCoreQueueFactory)
# Removed createTransportApiResponseProducer (PubSubTbCoreQueueFactory)
# Removed destroy (PubSubTbCoreQueueFactory)
# Removed createTransportNotificationsMsgProducer (PubSubTbRuleEngineQueueFactory)
# Removed createRuleEngineMsgProducer (PubSubTbRuleEngineQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (PubSubTbRuleEngineQueueFactory)
# Removed createTbCoreMsgProducer (PubSubTbRuleEngineQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (PubSubTbRuleEngineQueueFactory)
# Removed destroy (PubSubTbRuleEngineQueueFactory)
# Removed createRuleEngineMsgProducer (AwsSqsTransportQueueFactory)
# Removed createTbCoreMsgProducer (AwsSqsTransportQueueFactory)
# Removed createTransportNotificationsConsumer (AwsSqsTransportQueueFactory)
# Removed destroy (AwsSqsTransportQueueFactory)
# Removed createTransportNotificationsMsgProducer (InMemoryMonolithQueueFactory)
# Removed createRuleEngineMsgProducer (InMemoryMonolithQueueFactory)
# Removed createRuleEngineNotificationsMsgProducer (InMemoryMonolithQueueFactory)
# Removed createTbCoreMsgProducer (InMemoryMonolithQueueFactory)
# Removed createTbCoreNotificationsMsgProducer (InMemoryMonolithQueueFactory)
# Removed createToCoreMsgConsumer (InMemoryMonolithQueueFactory)
# Removed createTransportApiRequestConsumer (InMemoryMonolithQueueFactory)
# Removed createTransportApiResponseProducer (InMemoryMonolithQueueFactory)
# Removed createRemoteJsRequestTemplate (InMemoryMonolithQueueFactory)
# Removed printInMemoryStats (InMemoryMonolithQueueFactory)
# Removed init (EnvironmentLogService)
# Removed init (TbPubSubSettings)
# Removed init (TbRabbitMqSettings)
# Removed toProps (TbKafkaSettings)
# Removed init (BaseRelationDao)
# Removed getListToBooleanFunction (BaseRelationService)
# Removed getColumnFamilyName (CassandraAuditLogDao)
# Removed stopExecutor (CassandraAuditLogDao)
# Removed init (ElasticsearchAuditLogSink)
# Removed getColumnFamilyName (CassandraAdminSettingsDao)
# Removed getColumnFamilyName (CassandraUserCredentialsDao)
# Removed getColumnFamilyName (CassandraUserDao)
# Removed getColumnFamilyName (CassandraWidgetTypeDao)
# Removed getColumnFamilyName (CassandraWidgetsBundleDao)
# Removed getThreadPollSize (JpaExecutorService)
# Removed init (ScheduledLogExecutorComponent)
# Removed stop (ScheduledLogExecutorComponent)
# Removed scheduleAtFixedRate (ScheduledLogExecutorComponent)
# Removed getCrudRepository (JpaDashboardInfoDao)
# Removed getCrudRepository (JpaRuleChainDao)
# Removed getCrudRepository (JpaRuleNodeDao)
# Removed destroy (JpaAttributeDao)
# Removed stop (CassandraBaseTimeseriesDao)
# Removed getColumnFamilyName (CassandraDashboardInfoDao)
# Removed getColumnFamilyName (CassandraDashboardDao)
# Removed getColumnFamilyName (CassandraDeviceCredentialsDao)
# Removed getColumnFamilyName (CassandraDeviceDao)
# Removed getColumnFamilyName (CassandraRuleNodeDao)
# Removed getColumnFamilyName (CassandraRuleChainDao)
# Removed getColumnFamilyName (CassandraEntityViewDao)
# Removed init (CassandraBaseAttributesDao)
# Removed stop (CassandraBaseAttributesDao)
# Removed startExecutor (BaseAlarmService)
# Removed stopExecutor (BaseAlarmService)
# Removed getColumnFamilyName (CassandraAlarmDao)
# Removed isDeleteOnSave (CassandraAlarmDao)
# Removed destroy (TimescaleTimeseriesDao)
# Removed init (JpaPsqlTimeseriesDao)
# Removed printStats (CassandraBufferedRateExecutor)
# Removed stop (CassandraBufferedRateExecutor)
# Removed create (CassandraBufferedRateExecutor)
# Removed getColumnFamilyName (CassandraTenantDao)
# Removed getColumnFamilyName (CassandraAssetDao)
# Removed getColumnFamilyName (CassandraCustomerDao)
# Removed getInsertString (HsqlComponentDescriptorInsertRepository)
# Removed getInsertOrUpdateStatement (PsqlComponentDescriptorInsertRepository)
# Removed getUpdateStatement (PsqlComponentDescriptorInsertRepository)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
