# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'shopizer-2x' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "JeecgBoot"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/JeecgBoot/source/jeecg-boot/jeecg-module-system/jeecg-system-biz/src/main/java/org/jeecg/modules/system/service/impl/ThirdAppDingtalkServiceImpl.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/JeecgBoot/source/jeecg-boot/jeecg-module-system/jeecg-system-biz/src/main/java/org/jeecg/config/firewall/SqlInjection/impl/DictTableWhiteListHandlerImpl.java:
# Excluded	JeecgSystemApplication		org.jeecg
# Entity		JeecgOneToMainUtil		org.jeecg.codegenerate
# Entity		JeecgOneGUI		org.jeecg.codegenerate
# Excluded	FlywayConfig		org.jeecg.config.flyway
# Interface	IOnlineBaseExtApi		org.jeecg.common.online.api
# Interface	ISysBaseAPI		org.jeecg.common.system.api
# Interface	IOnlineBaseExtApi		org.jeecg.common.online.api
# Entity		OnlineBaseExtApiFallback		org.jeecg.common.online.api.fallback
# Logic		OnlineBaseExtApiFallbackFactory		org.jeecg.common.online.api.factory
# Interface	ISysBaseAPI		org.jeecg.common.system.api
# Entity		SysBaseAPIFallback		org.jeecg.common.system.api.fallback
# Logic		SysBaseAPIFallbackFactory		org.jeecg.common.system.api.factory
# Interface	RedisService		org.jeecg.modules.monitor.service
# Logic		MailHealthIndicator		org.jeecg.modules.monitor.service.impl
# Logic		RedisServiceImpl		org.jeecg.modules.monitor.service.impl
# Entity		RedisInfo		org.jeecg.modules.monitor.domain
# Logic		ActuatorMemoryController		org.jeecg.modules.monitor.controller
# Logic		ActuatorRedisController		org.jeecg.modules.monitor.controller
# Excluded	CustomActuatorConfig		org.jeecg.modules.monitor.actuator
# Logic		CustomHttpTraceEndpoint		org.jeecg.modules.monitor.actuator.httptrace
# Entity		CustomInMemoryHttpTraceRepository		org.jeecg.modules.monitor.actuator.httptrace
# Logic		CustomUndertowMetricsHandler		org.jeecg.modules.monitor.actuator.undertow
# Entity		RedisConnectException		org.jeecg.modules.monitor.exception
# Logic		TenantPackUserLogAspect		org.jeecg.modules.aop
# Interface	IOssFileService		org.jeecg.modules.oss.service
# Logic		OssFileServiceImpl		org.jeecg.modules.oss.service.impl
# Logic		OssFileController		org.jeecg.modules.oss.controller
# Interface	OssFileMapper		org.jeecg.modules.oss.mapper
# Entity		OssFile		org.jeecg.modules.oss.entity
# Interface	IQuartzJobService		org.jeecg.modules.quartz.service
# Logic		QuartzJobServiceImpl		org.jeecg.modules.quartz.service.impl
# Logic		QuartzJobController		org.jeecg.modules.quartz.controller
# Interface	QuartzJobMapper		org.jeecg.modules.quartz.mapper
# Entity		QuartzJob		org.jeecg.modules.quartz.entity
# Entity		AsyncJob		org.jeecg.modules.quartz.job
# Entity		SampleJob		org.jeecg.modules.quartz.job
# Entity		SampleParamJob		org.jeecg.modules.quartz.job
# Entity		SwaggerInfo		org.jeecg.modules.openapi.swagger
# Entity		SwaggerOperationParameter		org.jeecg.modules.openapi.swagger
# Entity		SwaggerModel		org.jeecg.modules.openapi.swagger
# Entity		SwaggerDefinitionProperties		org.jeecg.modules.openapi.swagger
# Entity		SwaggerDefinition		org.jeecg.modules.openapi.swagger
# Entity		SwaggerInfoLicense		org.jeecg.modules.openapi.swagger
# Entity		SwaggerInfoContact		org.jeecg.modules.openapi.swagger
# Entity		SwaggerTag		org.jeecg.modules.openapi.swagger
# Entity		SwaggerOperationResponse		org.jeecg.modules.openapi.swagger
# Entity		SwaggerOperation		org.jeecg.modules.openapi.swagger
# Entity		SwaggerSchema		org.jeecg.modules.openapi.swagger
# Excluded	ApiFilterConfig		org.jeecg.modules.openapi.filter
# Entity		ApiAuthFilter		org.jeecg.modules.openapi.filter
# Interface	OpenApiLogService		org.jeecg.modules.openapi.service
# Interface	OpenApiAuthService		org.jeecg.modules.openapi.service
# Interface	OpenApiService		org.jeecg.modules.openapi.service
# Interface	OpenApiPermissionService		org.jeecg.modules.openapi.service
# Logic		OpenApiServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiPermissionServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiAuthServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiLogServiceImpl		org.jeecg.modules.openapi.service.impl
# Entity		PathGenerator		org.jeecg.modules.openapi.generator
# Entity		AKSKGenerator		org.jeecg.modules.openapi.generator
# Logic		OpenApiIndexController		org.jeecg.modules.openapi.controller
# Logic		OpenApiPermissionController		org.jeecg.modules.openapi.controller
# Logic		OpenApiLogController		org.jeecg.modules.openapi.controller
# Logic		OpenApiController		org.jeecg.modules.openapi.controller
# Logic		OpenApiAuthController		org.jeecg.modules.openapi.controller
# Interface	OpenApiMapper		org.jeecg.modules.openapi.mapper
# Interface	OpenApiAuthMapper		org.jeecg.modules.openapi.mapper
# Interface	OpenApiLogMapper		org.jeecg.modules.openapi.mapper
# Interface	OpenApiPermissionMapper		org.jeecg.modules.openapi.mapper
# Entity		OpenApiPermission		org.jeecg.modules.openapi.entity
# Entity		OpenApi		org.jeecg.modules.openapi.entity
# Entity		OpenApiHeader		org.jeecg.modules.openapi.entity
# Entity		OpenApiParam		org.jeecg.modules.openapi.entity
# Entity		OpenApiAuth		org.jeecg.modules.openapi.entity
# Entity		OpenApiLog		org.jeecg.modules.openapi.entity
# Logic		SystemApiController		org.jeecg.modules.api.controller
# Entity		AuthStateRedisCache		org.jeecg.modules.system.cache
# Logic		DictQueryBlackListHandler		org.jeecg.modules.system.security
# Interface	ISysDataLogService		org.jeecg.modules.system.service
# Interface	ISysDepartService		org.jeecg.modules.system.service
# Interface	ISysPackPermissionService		org.jeecg.modules.system.service
# Interface	ISysCheckRuleService		org.jeecg.modules.system.service
# Interface	ISysDepartRolePermissionService		org.jeecg.modules.system.service
# Interface	ISysGatewayRouteService		org.jeecg.modules.system.service
# Interface	ISysPermissionService		org.jeecg.modules.system.service
# Interface	ISysFillRuleService		org.jeecg.modules.system.service
# Interface	ISysCategoryService		org.jeecg.modules.system.service
# Interface	ISysDepartPermissionService		org.jeecg.modules.system.service
# Interface	ISysTenantPackService		org.jeecg.modules.system.service
# Interface	ISysDictItemService		org.jeecg.modules.system.service
# Interface	ISysRoleIndexService		org.jeecg.modules.system.service
# Interface	ISysDepartRoleUserService		org.jeecg.modules.system.service
# Interface	ISysPositionService		org.jeecg.modules.system.service
# Interface	ISysCommentService		org.jeecg.modules.system.service
# Interface	IThirdAppService		org.jeecg.modules.system.service
# Interface	ISysUserPositionService		org.jeecg.modules.system.service
# Interface	ISysRoleService		org.jeecg.modules.system.service
# Interface	ISysAnnouncementSendService		org.jeecg.modules.system.service
# Interface	ISysRolePermissionService		org.jeecg.modules.system.service
# Interface	ISysUserService		org.jeecg.modules.system.service
# Interface	ISysLogService		org.jeecg.modules.system.service
# Interface	ISysDepartRoleService		org.jeecg.modules.system.service
# Interface	ISysUserTenantService		org.jeecg.modules.system.service
# Interface	ISysTenantService		org.jeecg.modules.system.service
# Interface	ISysUserAgentService		org.jeecg.modules.system.service
# Interface	ISysFormFileService		org.jeecg.modules.system.service
# Interface	ISysDictService		org.jeecg.modules.system.service
# Interface	ISysTableWhiteListService		org.jeecg.modules.system.service
# Interface	ISysThirdAppConfigService		org.jeecg.modules.system.service
# Interface	ISysDataSourceService		org.jeecg.modules.system.service
# Interface	ISysUserRoleService		org.jeecg.modules.system.service
# Interface	ISysAnnouncementService		org.jeecg.modules.system.service
# Interface	ISysPermissionDataRuleService		org.jeecg.modules.system.service
# Interface	ISysThirdAccountService		org.jeecg.modules.system.service
# Interface	ISysUserDepartService		org.jeecg.modules.system.service
# Logic		SysUserTenantServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPermissionDataRuleImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartServiceImpl		org.jeecg.modules.system.service.impl
# Logic		ImportFileServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPackPermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysFillRuleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDataSourceServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysTenantServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysBaseApiImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysTenantPackServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserRoleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysAnnouncementServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysThirdAccountServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserDepartServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserPositionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysCategoryServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartPermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysRoleIndexServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserAgentServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysGatewayRouteServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDictItemServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysTableWhiteListServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysAnnouncementSendServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDataLogServiceImpl		org.jeecg.modules.system.service.impl
# Logic		ThirdAppWechatEnterpriseServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysLogServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartRoleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDictServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysCommentServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysRoleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartRolePermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysCheckRuleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysRolePermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPositionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartRoleUserServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysThirdAppConfigServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysFormFileServiceImpl		org.jeecg.modules.system.service.impl
# Entity		PermissionDataUtil		org.jeecg.modules.system.util
# Entity		ImportOldUserUtil		org.jeecg.modules.system.util
# Entity		RandImageUtil		org.jeecg.modules.system.util
# Entity		XssUtils		org.jeecg.modules.system.util
# Entity		FindsDepartsChildrenUtil		org.jeecg.modules.system.util
# Entity		SecurityUtil		org.jeecg.modules.system.util
# Entity		SysUserOnlineVO		org.jeecg.modules.system.vo
# Entity		SysUserPositionVo		org.jeecg.modules.system.vo
# Entity		SysUserExportVo		org.jeecg.modules.system.vo
# Entity		SysDepartExportVo		org.jeecg.modules.system.vo
# Entity		SysDictPage		org.jeecg.modules.system.vo
# Entity		SysUserTenantVo		org.jeecg.modules.system.vo
# Entity		SysDepartUsersVO		org.jeecg.modules.system.vo
# Entity		SysUserRoleCountVo		org.jeecg.modules.system.vo
# Entity		SysCommentVO		org.jeecg.modules.system.vo
# Entity		UserAvatar		org.jeecg.modules.system.vo
# Entity		SysCommentFileVo		org.jeecg.modules.system.vo
# Entity		SysUserDepVo		org.jeecg.modules.system.vo
# Entity		SysUserRoleVO		org.jeecg.modules.system.vo
# Entity		JdtDepartmentTreeVo		org.jeecg.modules.system.vo.thirdapp
# Entity		JwDepartmentTreeVo		org.jeecg.modules.system.vo.thirdapp
# Entity		JwUserDepartVo		org.jeecg.modules.system.vo.thirdapp
# Entity		SyncInfoVo		org.jeecg.modules.system.vo.thirdapp
# Entity		JwSysUserDepartVo		org.jeecg.modules.system.vo.thirdapp
# Entity		DepartInfo		org.jeecg.modules.system.vo.lowapp
# Entity		SysDictVo		org.jeecg.modules.system.vo.lowapp
# Entity		DepartAndUserInfo		org.jeecg.modules.system.vo.lowapp
# Entity		ExportDepartVo		org.jeecg.modules.system.vo.lowapp
# Entity		UpdateDepartInfo		org.jeecg.modules.system.vo.lowapp
# Entity		AppExportUserVo		org.jeecg.modules.system.vo.lowapp
# Entity		TenantDepartAuthInfo		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackAuth		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackUserCount		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackModel		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackUser		org.jeecg.modules.system.vo.tenant
# Entity		UserDepart		org.jeecg.modules.system.vo.tenant
# Entity		UserPosition		org.jeecg.modules.system.vo.tenant
# Entity		OrgCodeRule		org.jeecg.modules.system.rule
# Entity		OrderNumberRule		org.jeecg.modules.system.rule
# Entity		CategoryCodeRule		org.jeecg.modules.system.rule
# Logic		SysDataSourceController		org.jeecg.modules.system.controller
# Logic		SysUserController		org.jeecg.modules.system.controller
# Logic		LoginController		org.jeecg.modules.system.controller
# Logic		WechatVerifyController		org.jeecg.modules.system.controller
# Logic		SysDepartPermissionController		org.jeecg.modules.system.controller
# Logic		SysAppVersionController		org.jeecg.modules.system.controller
# Logic		SysCheckRuleController		org.jeecg.modules.system.controller
# Logic		SysPermissionController		org.jeecg.modules.system.controller
# Logic		SysRoleController		org.jeecg.modules.system.controller
# Logic		SysDictController		org.jeecg.modules.system.controller
# Logic		SysLogController		org.jeecg.modules.system.controller
# Logic		SysAnnouncementController		org.jeecg.modules.system.controller
# Logic		CommonController		org.jeecg.modules.system.controller
# Logic		SysDepartRoleController		org.jeecg.modules.system.controller
# Logic		SysRoleIndexController		org.jeecg.modules.system.controller
# Logic		SysFormFileController		org.jeecg.modules.system.controller
# Logic		SysDataLogController		org.jeecg.modules.system.controller
# Logic		SysCommentController		org.jeecg.modules.system.controller
# Logic		SysGatewayRouteController		org.jeecg.modules.system.controller
# Logic		SysDepartController		org.jeecg.modules.system.controller
# Logic		SysCategoryController		org.jeecg.modules.system.controller
# Logic		ThirdAppController		org.jeecg.modules.system.controller
# Logic		SysPositionController		org.jeecg.modules.system.controller
# Logic		SysUploadController		org.jeecg.modules.system.controller
# Logic		SysUserAgentController		org.jeecg.modules.system.controller
# Logic		SysAnnouncementSendController		org.jeecg.modules.system.controller
# Logic		DuplicateCheckController		org.jeecg.modules.system.controller
# Logic		SysTenantController		org.jeecg.modules.system.controller
# Logic		SysFillRuleController		org.jeecg.modules.system.controller
# Logic		SysUserOnlineController		org.jeecg.modules.system.controller
# Logic		SysTableWhiteListController		org.jeecg.modules.system.controller
# Logic		SysDictItemController		org.jeecg.modules.system.controller
# Logic		ThirdLoginController		org.jeecg.modules.system.controller
# Excluded	AuthStateConfiguration		org.jeecg.modules.system.config
# Interface	DefIndexConst		org.jeecg.modules.system.constant
# Entity		TreeSelectModel		org.jeecg.modules.system.model
# Entity		TreeModel		org.jeecg.modules.system.model
# Entity		SysDictTree		org.jeecg.modules.system.model
# Entity		SysPermissionTree		org.jeecg.modules.system.model
# Entity		SysDepartTreeModel		org.jeecg.modules.system.model
# Entity		DepartIdModel		org.jeecg.modules.system.model
# Entity		ThirdLoginModel		org.jeecg.modules.system.model
# Entity		SysUserSysDepartModel		org.jeecg.modules.system.model
# Entity		DuplicateCheckVo		org.jeecg.modules.system.model
# Entity		AnnouncementSendModel		org.jeecg.modules.system.model
# Entity		SysLoginModel		org.jeecg.modules.system.model
# Interface	SysCommentMapper		org.jeecg.modules.system.mapper
# Interface	SysUserDepartMapper		org.jeecg.modules.system.mapper
# Interface	SysFormFileMapper		org.jeecg.modules.system.mapper
# Interface	SysUserMapper		org.jeecg.modules.system.mapper
# Interface	SysDictItemMapper		org.jeecg.modules.system.mapper
# Interface	SysDataLogMapper		org.jeecg.modules.system.mapper
# Interface	SysUserPositionMapper		org.jeecg.modules.system.mapper
# Interface	SysTenantMapper		org.jeecg.modules.system.mapper
# Interface	SysThirdAppConfigMapper		org.jeecg.modules.system.mapper
# Interface	SysPermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysAnnouncementMapper		org.jeecg.modules.system.mapper
# Interface	SysTableWhiteListMapper		org.jeecg.modules.system.mapper
# Interface	SysUserAgentMapper		org.jeecg.modules.system.mapper
# Interface	SysCategoryMapper		org.jeecg.modules.system.mapper
# Interface	SysPermissionDataRuleMapper		org.jeecg.modules.system.mapper
# Interface	SysTenantPackUserMapper		org.jeecg.modules.system.mapper
# Interface	SysRoleMapper		org.jeecg.modules.system.mapper
# Interface	SysUserTenantMapper		org.jeecg.modules.system.mapper
# Interface	SysTenantPackMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartRoleUserMapper		org.jeecg.modules.system.mapper
# Interface	SysFillRuleMapper		org.jeecg.modules.system.mapper
# Interface	SysPackPermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartPermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysCheckRuleMapper		org.jeecg.modules.system.mapper
# Interface	SysThirdAccountMapper		org.jeecg.modules.system.mapper
# Interface	SysRolePermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartRolePermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysPositionMapper		org.jeecg.modules.system.mapper
# Interface	SysDataSourceMapper		org.jeecg.modules.system.mapper
# Interface	SysGatewayRouteMapper		org.jeecg.modules.system.mapper
# Interface	SysRoleIndexMapper		org.jeecg.modules.system.mapper
# Interface	SysLogMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartRoleMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartMapper		org.jeecg.modules.system.mapper
# Interface	SysUserRoleMapper		org.jeecg.modules.system.mapper
# Interface	SysAnnouncementSendMapper		org.jeecg.modules.system.mapper
# Interface	SysDictMapper		org.jeecg.modules.system.mapper
# Entity		SysUserDepart		org.jeecg.modules.system.entity
# Entity		SysPackPermission		org.jeecg.modules.system.entity
# Entity		SysDepartPermission		org.jeecg.modules.system.entity
# Entity		SysAnnouncementSend		org.jeecg.modules.system.entity
# Entity		SysDataLog		org.jeecg.modules.system.entity
# Entity		SysUser		org.jeecg.modules.system.entity
# Entity		SysTenantPack		org.jeecg.modules.system.entity
# Entity		SysDataSource		org.jeecg.modules.system.entity
# Entity		SysDepartRoleUser		org.jeecg.modules.system.entity
# Entity		SysPosition		org.jeecg.modules.system.entity
# Entity		SysRolePermission		org.jeecg.modules.system.entity
# Entity		SysUserPosition		org.jeecg.modules.system.entity
# Entity		SysUserAgent		org.jeecg.modules.system.entity
# Entity		SysCategory		org.jeecg.modules.system.entity
# Entity		SysThirdAccount		org.jeecg.modules.system.entity
# Entity		SysFillRule		org.jeecg.modules.system.entity
# Entity		SysPermission		org.jeecg.modules.system.entity
# Entity		SysDictItem		org.jeecg.modules.system.entity
# Entity		SysThirdAppConfig		org.jeecg.modules.system.entity
# Entity		SysComment		org.jeecg.modules.system.entity
# Entity		SysLog		org.jeecg.modules.system.entity
# Entity		SysRoleIndex		org.jeecg.modules.system.entity
# Entity		SysTableWhiteList		org.jeecg.modules.system.entity
# Entity		SysUserTenant		org.jeecg.modules.system.entity
# Entity		SysAppVersion		org.jeecg.modules.system.entity
# Entity		SysDepartRole		org.jeecg.modules.system.entity
# Entity		SysAnnouncement		org.jeecg.modules.system.entity
# Entity		SysRole		org.jeecg.modules.system.entity
# Entity		SysDepartRolePermission		org.jeecg.modules.system.entity
# Entity		SysGatewayRoute		org.jeecg.modules.system.entity
# Entity		SysCheckRule		org.jeecg.modules.system.entity
# Entity		SysTenant		org.jeecg.modules.system.entity
# Entity		SysTenantPackUser		org.jeecg.modules.system.entity
# Entity		SysDepart		org.jeecg.modules.system.entity
# Entity		SysDict		org.jeecg.modules.system.entity
# Entity		SysFormFile		org.jeecg.modules.system.entity
# Entity		SysUserRole		org.jeecg.modules.system.entity
# Entity		SysPermissionDataRule		org.jeecg.modules.system.entity
# Entity		CasServiceUtil		org.jeecg.modules.cas.util
# Entity		XmlUtils		org.jeecg.modules.cas.util
# Logic		CasClientController		org.jeecg.modules.cas.controller
# Interface	ISysMessageTemplateService		org.jeecg.modules.message.service
# Interface	ISysMessageService		org.jeecg.modules.message.service
# Logic		SysMessageTemplateServiceImpl		org.jeecg.modules.message.service.impl
# Logic		SysMessageServiceImpl		org.jeecg.modules.message.service.impl
# Logic		PushMsgUtil		org.jeecg.modules.message.util
# Interface	ISendMsgHandle		org.jeecg.modules.message.handle
# Entity		WxSendMsgHandle		org.jeecg.modules.message.handle.impl
# Entity		SmsSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		EmailSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		SystemSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		DdSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		QywxSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		TestSocketController		org.jeecg.modules.message.controller
# Logic		SysMessageController		org.jeecg.modules.message.controller
# Logic		SysMessageTemplateController		org.jeecg.modules.message.controller
# Logic		SocketHandler		org.jeecg.modules.message.websocket
# Logic		WebSocket		org.jeecg.modules.message.websocket
# Interface	SysMessageTemplateMapper		org.jeecg.modules.message.mapper
# Interface	SysMessageMapper		org.jeecg.modules.message.mapper
# Entity		MsgParams		org.jeecg.modules.message.entity
# Entity		SysMessage		org.jeecg.modules.message.entity
# Entity		SysMessageTemplate		org.jeecg.modules.message.entity
# Entity		SendMsgJob		org.jeecg.modules.message.job
# Logic		ShiroCacheClearRunner		org.jeecg.config.init
# Logic		SystemInitListener		org.jeecg.config.init
# Excluded	UndertowConfiguration		org.jeecg.config.init
# Excluded	CodeGenerateDbConfig		org.jeecg.config.init
# Logic		CodeTemplateInitListener		org.jeecg.config.init
# Logic		JimuDragExternalServiceImpl		org.jeecg.config.jimureport
# Logic		JimuReportTokenService		org.jeecg.config.jimureport
# Entity		TikaDocumentParser		org.jeecg.modules.airag.llm.document
# Interface	IAiragKnowledgeDocService		org.jeecg.modules.airag.llm.service
# Interface	IAiragKnowledgeService		org.jeecg.modules.airag.llm.service
# Interface	IAiragModelService		org.jeecg.modules.airag.llm.service
# Logic		AiragKnowledgeDocServiceImpl		org.jeecg.modules.airag.llm.service.impl
# Logic		AiragKnowledgeServiceImpl		org.jeecg.modules.airag.llm.service.impl
# Logic		AiragModelServiceImpl		org.jeecg.modules.airag.llm.service.impl
# Logic		AiragKnowledgeController		org.jeecg.modules.airag.llm.controller
# Logic		AiragModelController		org.jeecg.modules.airag.llm.controller
# Logic		KnowConfigBean		org.jeecg.modules.airag.llm.config
# Logic		EmbedStoreConfigBean		org.jeecg.modules.airag.llm.config
# Interface	AiragKnowledgeDocMapper		org.jeecg.modules.airag.llm.mapper
# Interface	AiragModelMapper		org.jeecg.modules.airag.llm.mapper
# Interface	AiragKnowledgeMapper		org.jeecg.modules.airag.llm.mapper
# Entity		CommandExecUtil		org.jeecg.modules.airag.llm.handler
# Logic		AIChatHandler		org.jeecg.modules.airag.llm.handler
# Logic		EmbeddingHandler		org.jeecg.modules.airag.llm.handler
# Entity		AiragModel		org.jeecg.modules.airag.llm.entity
# Entity		AiragKnowledge		org.jeecg.modules.airag.llm.entity
# Entity		AiragKnowledgeDoc		org.jeecg.modules.airag.llm.entity
# Entity		LLMConsts		org.jeecg.modules.airag.llm.consts
# Logic		JimuDataReader		org.jeecg.modules.airag.demo
# Logic		TestAiragEnhance		org.jeecg.modules.airag.demo
# Logic		AiOcrController		org.jeecg.modules.airag.ocr.controller
# Entity		AiOcr		org.jeecg.modules.airag.ocr.entity
# Interface	IAiragAppService		org.jeecg.modules.airag.app.service
# Interface	IAiragChatService		org.jeecg.modules.airag.app.service
# Logic		AiragAppServiceImpl		org.jeecg.modules.airag.app.service.impl
# Logic		AiragChatServiceImpl		org.jeecg.modules.airag.app.service.impl
# Entity		ChatConversation		org.jeecg.modules.airag.app.vo
# Entity		ChatSendParams		org.jeecg.modules.airag.app.vo
# Entity		AppDebugParams		org.jeecg.modules.airag.app.vo
# Logic		AiragAppController		org.jeecg.modules.airag.app.controller
# Logic		AiragChatController		org.jeecg.modules.airag.app.controller
# Interface	AiragAppMapper		org.jeecg.modules.airag.app.mapper
# Entity		AiragApp		org.jeecg.modules.airag.app.entity
# Entity		Prompts		org.jeecg.modules.airag.app.consts
# Entity		AiAppConsts		org.jeecg.modules.airag.app.consts
# Logic		DlMockController		org.jeecg.modules.dlglong.controller
# Entity		MockEntity		org.jeecg.modules.dlglong.entity
# Logic		OnlCgformDemoController		org.jeecg.modules.demo.online
# Logic		MockController		org.jeecg.modules.demo.mock
# Logic		VxeMockController		org.jeecg.modules.demo.mock.vxe.controller
# Logic		VxeSocket		org.jeecg.modules.demo.mock.vxe.websocket
# Entity		MockEntity		org.jeecg.modules.demo.mock.vxe.entity
# Interface	JcloudDemoService		org.jeecg.modules.demo.cloud.service
# Logic		JcloudDemoServiceImpl		org.jeecg.modules.demo.cloud.service.impl
# Logic		JcloudDemoProviderController		org.jeecg.modules.demo.cloud.controller
# Interface	BaseCommonService		org.jeecg.modules.base.service
# Logic		BaseCommonServiceImpl		org.jeecg.modules.base.service.impl
# Interface	BaseCommonMapper		org.jeecg.modules.base.mapper
# Entity		DruidWallConfigRegister		org.jeecg.config
# Entity		JeecgCloudCondition		org.jeecg.config
# Excluded	DruidConfig		org.jeecg.config
# Excluded	RestTemplateConfig		org.jeecg.config
# Excluded	WebSocketConfig		org.jeecg.config
# Logic		JeecgSmsTemplateConfig		org.jeecg.config
# Logic		JeecgBaseConfig		org.jeecg.config
# Excluded	AutoPoiConfig		org.jeecg.config
# Entity		CorsFilterCondition		org.jeecg.config
# Logic		StaticConfig		org.jeecg.config
# Excluded	WebMvcConfiguration		org.jeecg.config
# Logic		AutoPoiDictConfig		org.jeecg.config
# Excluded	Swagger3Config		org.jeecg.config
# Entity		SignUtil		org.jeecg.config.sign.util
# Entity		BodyReaderHttpServletRequestWrapper		org.jeecg.config.sign.util
# Entity		HttpUtils		org.jeecg.config.sign.util
# Entity		SignAuthInterceptor		org.jeecg.config.sign.interceptor
# Excluded	SignAuthConfiguration		org.jeecg.config.sign.interceptor
# Entity		WebsocketFilter		org.jeecg.config.filter
# Entity		RequestBodyReserveFilter		org.jeecg.config.filter
# Excluded	MinioConfig		org.jeecg.config.oss
# Excluded	OssConfiguration		org.jeecg.config.oss
# Entity		WeiXinPay		org.jeecg.config.vo
# Entity		Shiro		org.jeecg.config.vo
# Entity		Path		org.jeecg.config.vo
# Entity		Elasticsearch		org.jeecg.config.vo
# Entity		DomainUrl		org.jeecg.config.vo
# Entity		BaiduApi		org.jeecg.config.vo
# Entity		GaoDeApi		org.jeecg.config.vo
# Entity		Firewall		org.jeecg.config.vo
# Excluded	ShiroConfig		org.jeecg.config.shiro
# Entity		JwtToken		org.jeecg.config.shiro
# Logic		ShiroRealm		org.jeecg.config.shiro
# Entity		InMemoryIgnoreAuth		org.jeecg.config.shiro.ignore
# Logic		IgnoreAuthPostProcessor		org.jeecg.config.shiro.ignore
# Entity		ResourceCheckFilter		org.jeecg.config.shiro.filters
# Entity		JwtFilter		org.jeecg.config.shiro.filters
# Entity		CustomShiroFilterFactoryBean		org.jeecg.config.shiro.filters
# Entity		ThreadLocalDataHelper		org.jeecg.config.mybatis
# Logic		MybatisInterceptor		org.jeecg.config.mybatis
# Excluded	MybatisPlusSaasConfig		org.jeecg.config.mybatis
# Logic		DynamicTableAspect		org.jeecg.config.mybatis.aspect
# Entity		DynamicDatasourceInterceptor		org.jeecg.config.mybatis.interceptor
# Excluded	LowCodeModeConfiguration		org.jeecg.config.firewall.interceptor
# Logic		LowCodeModeInterceptor		org.jeecg.config.firewall.interceptor
# Entity		SysDictTableWhite		org.jeecg.config.firewall.SqlInjection
# Interface	IDictTableWhiteListHandler		org.jeecg.config.firewall.SqlInjection
# Logic		DictAspect		org.jeecg.common.aspect
# Logic		AutoLogAspect		org.jeecg.common.aspect
# Logic		PermissionDataAspect		org.jeecg.common.aspect
# Entity		ImportExcelUtil		org.jeecg.common.util
# Entity		PasswordUtil		org.jeecg.common.util
# Entity		DateUtils		org.jeecg.common.util
# Entity		BrowserUtils		org.jeecg.common.util
# Entity		Md5Util		org.jeecg.common.util
# Entity		DySmsHelper		org.jeecg.common.util
# Entity		DateRangeUtils		org.jeecg.common.util
# Entity		FileDownloadUtils		org.jeecg.common.util
# Entity		HTMLUtils		org.jeecg.common.util
# Entity		TokenUtils		org.jeecg.common.util
# Logic		PmsUtil		org.jeecg.common.util
# Entity		RestDesformUtil		org.jeecg.common.util
# Logic		SpringContextUtils		org.jeecg.common.util
# Entity		YouBianCodeUtil		org.jeecg.common.util
# Entity		IpUtils		org.jeecg.common.util
# Entity		UUIDGenerator		org.jeecg.common.util
# Entity		AssertUtils		org.jeecg.common.util
# Entity		SqlInjectionUtil		org.jeecg.common.util
# Entity		CommonUtils		org.jeecg.common.util
# Entity		FillRuleUtil		org.jeecg.common.util
# Entity		oConvertUtils		org.jeecg.common.util
# Entity		ReflectHelper		org.jeecg.common.util
# Entity		DySmsLimit		org.jeecg.common.util
# Entity		MinioUtil		org.jeecg.common.util
# Entity		MyClassLoader		org.jeecg.common.util
# Entity		RestUtil		org.jeecg.common.util
# Entity		AbstractQueryBlackListHandler		org.jeecg.common.util.security
# Entity		JdbcSecurityUtil		org.jeecg.common.util.security
# Entity		SecurityTools		org.jeecg.common.util.security
# Entity		SecurityReq		org.jeecg.common.util.security.entity
# Entity		SecurityResp		org.jeecg.common.util.security.entity
# Entity		SecuritySignResp		org.jeecg.common.util.security.entity
# Entity		MyKeyPair		org.jeecg.common.util.security.entity
# Entity		SecuritySignReq		org.jeecg.common.util.security.entity
# Entity		StrAttackFilter		org.jeecg.common.util.filter
# Entity		SsrfFileTypeFilter		org.jeecg.common.util.filter
# Entity		OssBootUtil		org.jeecg.common.util.oss
# Entity		FreemarkerParseFactory		org.jeecg.common.util.dynamic.db
# Entity		DataSourceCachePool		org.jeecg.common.util.dynamic.db
# Entity		DynamicDBUtil		org.jeecg.common.util.dynamic.db
# Entity		DbTypeUtils		org.jeecg.common.util.dynamic.db
# Entity		EncryptedString		org.jeecg.common.util.encryption
# Entity		AesEncryptUtil		org.jeecg.common.util.encryption
# Logic		JeecgElasticsearchTemplate		org.jeecg.common.es
# Entity		QueryStringBuilder		org.jeecg.common.es
# Entity		VxeSocketConst		org.jeecg.common.constant
# Interface	TenantConstant		org.jeecg.common.constant
# Logic		ProvinceCityArea		org.jeecg.common.constant
# Interface	CommonSendStatus		org.jeecg.common.constant
# Entity		DynamicTableConstant		org.jeecg.common.constant
# Interface	ServiceNameConstants		org.jeecg.common.constant
# Entity		WebsocketConst		org.jeecg.common.constant
# Interface	DataBaseConstant		org.jeecg.common.constant
# Interface	CommonConstant		org.jeecg.common.constant
# Entity		SymbolConstant		org.jeecg.common.constant
# Entity		FillRuleConstant		org.jeecg.common.constant
# Interface	IFillRuleHandler		org.jeecg.common.handler
# Entity		SensitiveSerialize		org.jeecg.common.desensitization
# Logic		SensitiveDataAspect		org.jeecg.common.desensitization.aspect
# Entity		SensitiveInfoUtil		org.jeecg.common.desensitization.util
# Interface	CommonAPI		org.jeecg.common.api
# Entity		Result		org.jeecg.common.api.vo
# Entity		OnlineAuthDTO		org.jeecg.common.api.dto
# Entity		LogDTO		org.jeecg.common.api.dto
# Entity		DataLogDTO		org.jeecg.common.api.dto
# Entity		FileDownDTO		org.jeecg.common.api.dto
# Entity		FileUploadDTO		org.jeecg.common.api.dto
# Entity		TemplateMessageDTO		org.jeecg.common.api.dto.message
# Entity		TemplateDTO		org.jeecg.common.api.dto.message
# Entity		BusTemplateMessageDTO		org.jeecg.common.api.dto.message
# Entity		MessageDTO		org.jeecg.common.api.dto.message
# Entity		BusMessageDTO		org.jeecg.common.api.dto.message
# Entity		ResourceUtil		org.jeecg.common.system.util
# Entity		SqlConcatUtil		org.jeecg.common.system.util
# Entity		JeecgDataAutorUtils		org.jeecg.common.system.util
# Entity		JwtUtil		org.jeecg.common.system.util
# Entity		ComboModel		org.jeecg.common.system.vo
# Entity		SelectTreeModel		org.jeecg.common.system.vo
# Entity		UserAccountInfo		org.jeecg.common.system.vo
# Entity		SysDepartModel		org.jeecg.common.system.vo
# Entity		SysUserCacheInfo		org.jeecg.common.system.vo
# Entity		SysPermissionDataRuleModel		org.jeecg.common.system.vo
# Entity		DictModel		org.jeecg.common.system.vo
# Entity		DictModelMany		org.jeecg.common.system.vo
# Entity		SysCategoryModel		org.jeecg.common.system.vo
# Entity		SysFilesModel		org.jeecg.common.system.vo
# Entity		DictQuery		org.jeecg.common.system.vo
# Entity		DynamicDataSourceModel		org.jeecg.common.system.vo
# Entity		LoginUser		org.jeecg.common.system.vo
# Entity		QueryGenerator		org.jeecg.common.system.query
# Entity		QueryCondition		org.jeecg.common.system.query
# Interface	UserFilterEnhance		org.jeecg.common.system.enhance
# Interface	JeecgService		org.jeecg.common.system.base.service
# Entity		JeecgServiceImpl		org.jeecg.common.system.base.service.impl
# Entity		JeecgController		org.jeecg.common.system.base.controller
# Entity		JeecgEntity		org.jeecg.common.system.base.entity
# Entity		JeecgBoot401Exception		org.jeecg.common.exception
# Entity		JeecgBootExceptionHandler		org.jeecg.common.exception
# Entity		JeecgSqlInjectionException		org.jeecg.common.exception
# Entity		JeecgBootAssertException		org.jeecg.common.exception
# Entity		JeecgBootException		org.jeecg.common.exception
# Entity		JeecgBootBizTipException		org.jeecg.common.exception
# Excluded	JeecgDemoCloudApplication		org.jeecg
# Excluded	JeecgGatewayApplication		org.jeecg
# Excluded	SentinelFilterContextConfig		org.jeecg.filter
# Logic		GlobalAccessTokenFilter		org.jeecg.filter
# Excluded	GatewaySentinelExceptionConfig		org.jeecg.fallback.sentinel
# Logic		DynamicRouteLoader		org.jeecg.loader
# Entity		PredicatesVo		org.jeecg.loader.vo
# Entity		GatewayRouteVo		org.jeecg.loader.vo
# Entity		MyRouteDefinition		org.jeecg.loader.vo
# Logic		MyInMemoryRouteDefinitionRepository		org.jeecg.loader.repository
# Logic		DynamicRouteService		org.jeecg.loader.repository
# Excluded	RateLimiterConfiguration		org.jeecg.config
# Excluded	GatewayRoutersConfig		org.jeecg.config
# Logic		LoderRouderHandler		org.jeecg.handler
# Logic		SwaggerResourceController		org.jeecg.handler.swagger
# Logic		MySwaggerResourceProvider		org.jeecg.handler.swagger
# Excluded	JeecgSentinelApplication		com.alibaba.csp.sentinel.dashboard
# Entity		SentinelConStants		com.alibaba.csp.sentinel.dashboard.constants
# Excluded	SentinelConfig		com.alibaba.csp.sentinel.dashboard.rule.nacos
# Logic		NacosConfigProperties		com.alibaba.csp.sentinel.dashboard.rule.nacos
# Logic		ParamFlowRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.paramflow
# Logic		ParamFlowRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.paramflow
# Logic		GateWayApiNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		GateWayFlowRulesNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		GateWayApiNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		GateWayFlowRulesNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		DegradeRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.degrade
# Logic		DegradeRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.degrade
# Entity		ParamFlowRuleCorrectEntity		com.alibaba.csp.sentinel.dashboard.rule.nacos.entity
# Entity		AuthorityRuleCorrectEntity		com.alibaba.csp.sentinel.dashboard.rule.nacos.entity
# Logic		SystemRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.system
# Logic		SystemRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.system
# Logic		AuthorityRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.authority
# Logic		AuthorityRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.authority
# Logic		FlowRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.flow
# Logic		FlowRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.flow
# Logic		DegradeController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		SystemController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		ParamFlowRuleController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		AuthorityRuleController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		GatewayApiController		com.alibaba.csp.sentinel.dashboard.controller.gateway
# Logic		GatewayFlowRuleController		com.alibaba.csp.sentinel.dashboard.controller.gateway
# Entity		BaseRuleController		com.alibaba.csp.sentinel.dashboard.controller.base
# Logic		FlowControllerV2		com.alibaba.csp.sentinel.dashboard.controller.v2
# Excluded	JeecgMonitorApplication		org.jeecg.monitor
# Excluded	SecuritySecureConfig		org.jeecg.monitor.config
# Excluded	XxlJobAdminApplication		com.xxl.job.admin
# Excluded	LoginService		com.xxl.job.admin.service
# Interface	XxlJobService		com.xxl.job.admin.service
# Logic		AdminBizImpl		com.xxl.job.admin.service.impl
# Logic		XxlJobServiceImpl		com.xxl.job.admin.service.impl
# Entity		JacksonUtil		com.xxl.job.admin.core.util
# Entity		LocalCacheUtil		com.xxl.job.admin.core.util
# Entity		FtlUtil		com.xxl.job.admin.core.util
# Entity		CookieUtil		com.xxl.job.admin.core.util
# Entity		I18nUtil		com.xxl.job.admin.core.util
# Entity		XxlJobScheduler		com.xxl.job.admin.core.scheduler
# Logic		XxlJobAdminConfig		com.xxl.job.admin.core.conf
# Entity		ExecutorRouter		com.xxl.job.admin.core.route
# Entity		ExecutorRouteRound		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteFirst		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteLast		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteBusyover		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteFailover		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteConsistentHash		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteLFU		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteRandom		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteLRU		com.xxl.job.admin.core.route.strategy
# Logic		JobAlarmer		com.xxl.job.admin.core.alarm
# Interface	JobAlarm		com.xxl.job.admin.core.alarm
# Logic		EmailJobAlarm		com.xxl.job.admin.core.alarm.impl
# Entity		CronExpression		com.xxl.job.admin.core.cron
# Entity		ValueSet		com.xxl.job.admin.core.cron
# Entity		XxlJobLogReport		com.xxl.job.admin.core.model
# Entity		XxlJobGroup		com.xxl.job.admin.core.model
# Entity		XxlJobLogGlue		com.xxl.job.admin.core.model
# Entity		XxlJobUser		com.xxl.job.admin.core.model
# Entity		XxlJobLog		com.xxl.job.admin.core.model
# Entity		XxlJobInfo		com.xxl.job.admin.core.model
# Entity		XxlJobRegistry		com.xxl.job.admin.core.model
# Entity		XxlJobTrigger		com.xxl.job.admin.core.trigger
# Entity		XxlJobCompleter		com.xxl.job.admin.core.complete
# Entity		JobRegistryHelper		com.xxl.job.admin.core.thread
# Entity		JobFailMonitorHelper		com.xxl.job.admin.core.thread
# Entity		JobCompleteHelper		com.xxl.job.admin.core.thread
# Entity		JobLogReportHelper		com.xxl.job.admin.core.thread
# Entity		JobScheduleHelper		com.xxl.job.admin.core.thread
# Entity		JobTriggerPoolHelper		com.xxl.job.admin.core.thread
# Entity		XxlJobException		com.xxl.job.admin.core.exception
# Logic		JobGroupController		com.xxl.job.admin.controller
# Logic		JobCodeController		com.xxl.job.admin.controller
# Logic		IndexController		com.xxl.job.admin.controller
# Logic		UserController		com.xxl.job.admin.controller
# Logic		JobLogController		com.xxl.job.admin.controller
# Logic		JobInfoController		com.xxl.job.admin.controller
# Logic		JobApiController		com.xxl.job.admin.controller
# Logic		WebExceptionResolver		com.xxl.job.admin.controller.resolver
# Excluded	WebMvcConfig		com.xxl.job.admin.controller.interceptor
# Logic		CookieInterceptor		com.xxl.job.admin.controller.interceptor
# Logic		PermissionInterceptor		com.xxl.job.admin.controller.interceptor
# Interface	XxlJobUserDao		com.xxl.job.admin.dao
# Interface	XxlJobLogDao		com.xxl.job.admin.dao
# Interface	XxlJobLogReportDao		com.xxl.job.admin.dao
# Interface	XxlJobLogGlueDao		com.xxl.job.admin.dao
# Interface	XxlJobRegistryDao		com.xxl.job.admin.dao
# Interface	XxlJobInfoDao		com.xxl.job.admin.dao
# Interface	XxlJobGroupDao		com.xxl.job.admin.dao
# Excluded	JeecgSystemCloudApplication		org.jeecg
# Excluded	JeecgNacosApplication		com.alibaba.nacos

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)) or "repository" in pkg_name(tree).lower() or "repositories" in pkg_name(tree).lower() or "repository" in decl.name.lower():

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		JeecgOneToMainUtil		org.jeecg.codegenerate
# Entity		JeecgOneGUI		org.jeecg.codegenerate
# Entity		OnlineBaseExtApiFallback		org.jeecg.common.online.api.fallback
# Entity		SysBaseAPIFallback		org.jeecg.common.system.api.fallback
# Entity		RedisInfo		org.jeecg.modules.monitor.domain
# Entity		RedisConnectException		org.jeecg.modules.monitor.exception
# Entity		OssFile		org.jeecg.modules.oss.entity
# Entity		QuartzJob		org.jeecg.modules.quartz.entity
# Entity		AsyncJob		org.jeecg.modules.quartz.job
# Entity		SampleJob		org.jeecg.modules.quartz.job
# Entity		SampleParamJob		org.jeecg.modules.quartz.job
# Entity		SwaggerInfo		org.jeecg.modules.openapi.swagger
# Entity		SwaggerOperationParameter		org.jeecg.modules.openapi.swagger
# Entity		SwaggerModel		org.jeecg.modules.openapi.swagger
# Entity		SwaggerDefinitionProperties		org.jeecg.modules.openapi.swagger
# Entity		SwaggerDefinition		org.jeecg.modules.openapi.swagger
# Entity		SwaggerInfoLicense		org.jeecg.modules.openapi.swagger
# Entity		SwaggerInfoContact		org.jeecg.modules.openapi.swagger
# Entity		SwaggerTag		org.jeecg.modules.openapi.swagger
# Entity		SwaggerOperationResponse		org.jeecg.modules.openapi.swagger
# Entity		SwaggerOperation		org.jeecg.modules.openapi.swagger
# Entity		SwaggerSchema		org.jeecg.modules.openapi.swagger
# Entity		ApiAuthFilter		org.jeecg.modules.openapi.filter
# Entity		PathGenerator		org.jeecg.modules.openapi.generator
# Entity		AKSKGenerator		org.jeecg.modules.openapi.generator
# Entity		OpenApiPermission		org.jeecg.modules.openapi.entity
# Entity		OpenApi		org.jeecg.modules.openapi.entity
# Entity		OpenApiHeader		org.jeecg.modules.openapi.entity
# Entity		OpenApiParam		org.jeecg.modules.openapi.entity
# Entity		OpenApiAuth		org.jeecg.modules.openapi.entity
# Entity		OpenApiLog		org.jeecg.modules.openapi.entity
# Entity		AuthStateRedisCache		org.jeecg.modules.system.cache
# Entity		PermissionDataUtil		org.jeecg.modules.system.util
# Entity		ImportOldUserUtil		org.jeecg.modules.system.util
# Entity		RandImageUtil		org.jeecg.modules.system.util
# Entity		XssUtils		org.jeecg.modules.system.util
# Entity		FindsDepartsChildrenUtil		org.jeecg.modules.system.util
# Entity		SecurityUtil		org.jeecg.modules.system.util
# Entity		SysUserOnlineVO		org.jeecg.modules.system.vo
# Entity		SysUserPositionVo		org.jeecg.modules.system.vo
# Entity		SysUserExportVo		org.jeecg.modules.system.vo
# Entity		SysDepartExportVo		org.jeecg.modules.system.vo
# Entity		SysDictPage		org.jeecg.modules.system.vo
# Entity		SysUserTenantVo		org.jeecg.modules.system.vo
# Entity		SysDepartUsersVO		org.jeecg.modules.system.vo
# Entity		SysUserRoleCountVo		org.jeecg.modules.system.vo
# Entity		SysCommentVO		org.jeecg.modules.system.vo
# Entity		UserAvatar		org.jeecg.modules.system.vo
# Entity		SysCommentFileVo		org.jeecg.modules.system.vo
# Entity		SysUserDepVo		org.jeecg.modules.system.vo
# Entity		SysUserRoleVO		org.jeecg.modules.system.vo
# Entity		JdtDepartmentTreeVo		org.jeecg.modules.system.vo.thirdapp
# Entity		JwDepartmentTreeVo		org.jeecg.modules.system.vo.thirdapp
# Entity		JwUserDepartVo		org.jeecg.modules.system.vo.thirdapp
# Entity		SyncInfoVo		org.jeecg.modules.system.vo.thirdapp
# Entity		JwSysUserDepartVo		org.jeecg.modules.system.vo.thirdapp
# Entity		DepartInfo		org.jeecg.modules.system.vo.lowapp
# Entity		SysDictVo		org.jeecg.modules.system.vo.lowapp
# Entity		DepartAndUserInfo		org.jeecg.modules.system.vo.lowapp
# Entity		ExportDepartVo		org.jeecg.modules.system.vo.lowapp
# Entity		UpdateDepartInfo		org.jeecg.modules.system.vo.lowapp
# Entity		AppExportUserVo		org.jeecg.modules.system.vo.lowapp
# Entity		TenantDepartAuthInfo		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackAuth		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackUserCount		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackModel		org.jeecg.modules.system.vo.tenant
# Entity		TenantPackUser		org.jeecg.modules.system.vo.tenant
# Entity		UserDepart		org.jeecg.modules.system.vo.tenant
# Entity		UserPosition		org.jeecg.modules.system.vo.tenant
# Entity		OrgCodeRule		org.jeecg.modules.system.rule
# Entity		OrderNumberRule		org.jeecg.modules.system.rule
# Entity		CategoryCodeRule		org.jeecg.modules.system.rule
# Entity		TreeSelectModel		org.jeecg.modules.system.model
# Entity		TreeModel		org.jeecg.modules.system.model
# Entity		SysDictTree		org.jeecg.modules.system.model
# Entity		SysPermissionTree		org.jeecg.modules.system.model
# Entity		SysDepartTreeModel		org.jeecg.modules.system.model
# Entity		DepartIdModel		org.jeecg.modules.system.model
# Entity		ThirdLoginModel		org.jeecg.modules.system.model
# Entity		SysUserSysDepartModel		org.jeecg.modules.system.model
# Entity		DuplicateCheckVo		org.jeecg.modules.system.model
# Entity		AnnouncementSendModel		org.jeecg.modules.system.model
# Entity		SysLoginModel		org.jeecg.modules.system.model
# Entity		SysUserDepart		org.jeecg.modules.system.entity
# Entity		SysPackPermission		org.jeecg.modules.system.entity
# Entity		SysDepartPermission		org.jeecg.modules.system.entity
# Entity		SysAnnouncementSend		org.jeecg.modules.system.entity
# Entity		SysDataLog		org.jeecg.modules.system.entity
# Entity		SysUser		org.jeecg.modules.system.entity
# Entity		SysTenantPack		org.jeecg.modules.system.entity
# Entity		SysDataSource		org.jeecg.modules.system.entity
# Entity		SysDepartRoleUser		org.jeecg.modules.system.entity
# Entity		SysPosition		org.jeecg.modules.system.entity
# Entity		SysRolePermission		org.jeecg.modules.system.entity
# Entity		SysUserPosition		org.jeecg.modules.system.entity
# Entity		SysUserAgent		org.jeecg.modules.system.entity
# Entity		SysCategory		org.jeecg.modules.system.entity
# Entity		SysThirdAccount		org.jeecg.modules.system.entity
# Entity		SysFillRule		org.jeecg.modules.system.entity
# Entity		SysPermission		org.jeecg.modules.system.entity
# Entity		SysDictItem		org.jeecg.modules.system.entity
# Entity		SysThirdAppConfig		org.jeecg.modules.system.entity
# Entity		SysComment		org.jeecg.modules.system.entity
# Entity		SysLog		org.jeecg.modules.system.entity
# Entity		SysRoleIndex		org.jeecg.modules.system.entity
# Entity		SysTableWhiteList		org.jeecg.modules.system.entity
# Entity		SysUserTenant		org.jeecg.modules.system.entity
# Entity		SysAppVersion		org.jeecg.modules.system.entity
# Entity		SysDepartRole		org.jeecg.modules.system.entity
# Entity		SysAnnouncement		org.jeecg.modules.system.entity
# Entity		SysRole		org.jeecg.modules.system.entity
# Entity		SysDepartRolePermission		org.jeecg.modules.system.entity
# Entity		SysGatewayRoute		org.jeecg.modules.system.entity
# Entity		SysCheckRule		org.jeecg.modules.system.entity
# Entity		SysTenant		org.jeecg.modules.system.entity
# Entity		SysTenantPackUser		org.jeecg.modules.system.entity
# Entity		SysDepart		org.jeecg.modules.system.entity
# Entity		SysDict		org.jeecg.modules.system.entity
# Entity		SysFormFile		org.jeecg.modules.system.entity
# Entity		SysUserRole		org.jeecg.modules.system.entity
# Entity		SysPermissionDataRule		org.jeecg.modules.system.entity
# Entity		CasServiceUtil		org.jeecg.modules.cas.util
# Entity		XmlUtils		org.jeecg.modules.cas.util
# Entity		WxSendMsgHandle		org.jeecg.modules.message.handle.impl
# Entity		SmsSendMsgHandle		org.jeecg.modules.message.handle.impl
# Entity		MsgParams		org.jeecg.modules.message.entity
# Entity		SysMessage		org.jeecg.modules.message.entity
# Entity		SysMessageTemplate		org.jeecg.modules.message.entity
# Entity		SendMsgJob		org.jeecg.modules.message.job
# Entity		TikaDocumentParser		org.jeecg.modules.airag.llm.document
# Entity		CommandExecUtil		org.jeecg.modules.airag.llm.handler
# Entity		AiragModel		org.jeecg.modules.airag.llm.entity
# Entity		AiragKnowledge		org.jeecg.modules.airag.llm.entity
# Entity		AiragKnowledgeDoc		org.jeecg.modules.airag.llm.entity
# Entity		LLMConsts		org.jeecg.modules.airag.llm.consts
# Entity		AiOcr		org.jeecg.modules.airag.ocr.entity
# Entity		ChatConversation		org.jeecg.modules.airag.app.vo
# Entity		ChatSendParams		org.jeecg.modules.airag.app.vo
# Entity		AppDebugParams		org.jeecg.modules.airag.app.vo
# Entity		AiragApp		org.jeecg.modules.airag.app.entity
# Entity		Prompts		org.jeecg.modules.airag.app.consts
# Entity		AiAppConsts		org.jeecg.modules.airag.app.consts
# Entity		MockEntity		org.jeecg.modules.dlglong.entity
# Entity		MockEntity		org.jeecg.modules.demo.mock.vxe.entity
# Entity		DruidWallConfigRegister		org.jeecg.config
# Entity		JeecgCloudCondition		org.jeecg.config
# Entity		CorsFilterCondition		org.jeecg.config
# Entity		SignUtil		org.jeecg.config.sign.util
# Entity		BodyReaderHttpServletRequestWrapper		org.jeecg.config.sign.util
# Entity		HttpUtils		org.jeecg.config.sign.util
# Entity		SignAuthInterceptor		org.jeecg.config.sign.interceptor
# Entity		WebsocketFilter		org.jeecg.config.filter
# Entity		RequestBodyReserveFilter		org.jeecg.config.filter
# Entity		WeiXinPay		org.jeecg.config.vo
# Entity		Shiro		org.jeecg.config.vo
# Entity		Path		org.jeecg.config.vo
# Entity		Elasticsearch		org.jeecg.config.vo
# Entity		DomainUrl		org.jeecg.config.vo
# Entity		BaiduApi		org.jeecg.config.vo
# Entity		GaoDeApi		org.jeecg.config.vo
# Entity		Firewall		org.jeecg.config.vo
# Entity		JwtToken		org.jeecg.config.shiro
# Entity		InMemoryIgnoreAuth		org.jeecg.config.shiro.ignore
# Entity		ResourceCheckFilter		org.jeecg.config.shiro.filters
# Entity		JwtFilter		org.jeecg.config.shiro.filters
# Entity		CustomShiroFilterFactoryBean		org.jeecg.config.shiro.filters
# Entity		ThreadLocalDataHelper		org.jeecg.config.mybatis
# Entity		DynamicDatasourceInterceptor		org.jeecg.config.mybatis.interceptor
# Entity		SysDictTableWhite		org.jeecg.config.firewall.SqlInjection
# Entity		ImportExcelUtil		org.jeecg.common.util
# Entity		PasswordUtil		org.jeecg.common.util
# Entity		DateUtils		org.jeecg.common.util
# Entity		BrowserUtils		org.jeecg.common.util
# Entity		Md5Util		org.jeecg.common.util
# Entity		DySmsHelper		org.jeecg.common.util
# Entity		DateRangeUtils		org.jeecg.common.util
# Entity		FileDownloadUtils		org.jeecg.common.util
# Entity		HTMLUtils		org.jeecg.common.util
# Entity		TokenUtils		org.jeecg.common.util
# Entity		RestDesformUtil		org.jeecg.common.util
# Entity		YouBianCodeUtil		org.jeecg.common.util
# Entity		IpUtils		org.jeecg.common.util
# Entity		UUIDGenerator		org.jeecg.common.util
# Entity		AssertUtils		org.jeecg.common.util
# Entity		SqlInjectionUtil		org.jeecg.common.util
# Entity		CommonUtils		org.jeecg.common.util
# Entity		FillRuleUtil		org.jeecg.common.util
# Entity		oConvertUtils		org.jeecg.common.util
# Entity		ReflectHelper		org.jeecg.common.util
# Entity		DySmsLimit		org.jeecg.common.util
# Entity		MinioUtil		org.jeecg.common.util
# Entity		MyClassLoader		org.jeecg.common.util
# Entity		RestUtil		org.jeecg.common.util
# Entity		AbstractQueryBlackListHandler		org.jeecg.common.util.security
# Entity		JdbcSecurityUtil		org.jeecg.common.util.security
# Entity		SecurityTools		org.jeecg.common.util.security
# Entity		SecurityReq		org.jeecg.common.util.security.entity
# Entity		SecurityResp		org.jeecg.common.util.security.entity
# Entity		SecuritySignResp		org.jeecg.common.util.security.entity
# Entity		MyKeyPair		org.jeecg.common.util.security.entity
# Entity		SecuritySignReq		org.jeecg.common.util.security.entity
# Entity		StrAttackFilter		org.jeecg.common.util.filter
# Entity		SsrfFileTypeFilter		org.jeecg.common.util.filter
# Entity		OssBootUtil		org.jeecg.common.util.oss
# Entity		FreemarkerParseFactory		org.jeecg.common.util.dynamic.db
# Entity		DataSourceCachePool		org.jeecg.common.util.dynamic.db
# Entity		DynamicDBUtil		org.jeecg.common.util.dynamic.db
# Entity		DbTypeUtils		org.jeecg.common.util.dynamic.db
# Entity		EncryptedString		org.jeecg.common.util.encryption
# Entity		AesEncryptUtil		org.jeecg.common.util.encryption
# Entity		QueryStringBuilder		org.jeecg.common.es
# Entity		VxeSocketConst		org.jeecg.common.constant
# Entity		DynamicTableConstant		org.jeecg.common.constant
# Entity		WebsocketConst		org.jeecg.common.constant
# Entity		SymbolConstant		org.jeecg.common.constant
# Entity		FillRuleConstant		org.jeecg.common.constant
# Entity		SensitiveSerialize		org.jeecg.common.desensitization
# Entity		SensitiveInfoUtil		org.jeecg.common.desensitization.util
# Entity		Result		org.jeecg.common.api.vo
# Entity		OnlineAuthDTO		org.jeecg.common.api.dto
# Entity		LogDTO		org.jeecg.common.api.dto
# Entity		DataLogDTO		org.jeecg.common.api.dto
# Entity		FileDownDTO		org.jeecg.common.api.dto
# Entity		FileUploadDTO		org.jeecg.common.api.dto
# Entity		TemplateMessageDTO		org.jeecg.common.api.dto.message
# Entity		TemplateDTO		org.jeecg.common.api.dto.message
# Entity		BusTemplateMessageDTO		org.jeecg.common.api.dto.message
# Entity		MessageDTO		org.jeecg.common.api.dto.message
# Entity		BusMessageDTO		org.jeecg.common.api.dto.message
# Entity		ResourceUtil		org.jeecg.common.system.util
# Entity		SqlConcatUtil		org.jeecg.common.system.util
# Entity		JeecgDataAutorUtils		org.jeecg.common.system.util
# Entity		JwtUtil		org.jeecg.common.system.util
# Entity		ComboModel		org.jeecg.common.system.vo
# Entity		SelectTreeModel		org.jeecg.common.system.vo
# Entity		UserAccountInfo		org.jeecg.common.system.vo
# Entity		SysDepartModel		org.jeecg.common.system.vo
# Entity		SysUserCacheInfo		org.jeecg.common.system.vo
# Entity		SysPermissionDataRuleModel		org.jeecg.common.system.vo
# Entity		DictModel		org.jeecg.common.system.vo
# Entity		DictModelMany		org.jeecg.common.system.vo
# Entity		SysCategoryModel		org.jeecg.common.system.vo
# Entity		SysFilesModel		org.jeecg.common.system.vo
# Entity		DictQuery		org.jeecg.common.system.vo
# Entity		DynamicDataSourceModel		org.jeecg.common.system.vo
# Entity		LoginUser		org.jeecg.common.system.vo
# Entity		QueryGenerator		org.jeecg.common.system.query
# Entity		QueryCondition		org.jeecg.common.system.query
# Entity		JeecgServiceImpl		org.jeecg.common.system.base.service.impl
# Entity		JeecgController		org.jeecg.common.system.base.controller
# Entity		JeecgEntity		org.jeecg.common.system.base.entity
# Entity		JeecgBoot401Exception		org.jeecg.common.exception
# Entity		JeecgBootExceptionHandler		org.jeecg.common.exception
# Entity		JeecgSqlInjectionException		org.jeecg.common.exception
# Entity		JeecgBootAssertException		org.jeecg.common.exception
# Entity		JeecgBootException		org.jeecg.common.exception
# Entity		JeecgBootBizTipException		org.jeecg.common.exception
# Entity		PredicatesVo		org.jeecg.loader.vo
# Entity		GatewayRouteVo		org.jeecg.loader.vo
# Entity		MyRouteDefinition		org.jeecg.loader.vo
# Entity		SentinelConStants		com.alibaba.csp.sentinel.dashboard.constants
# Entity		ParamFlowRuleCorrectEntity		com.alibaba.csp.sentinel.dashboard.rule.nacos.entity
# Entity		AuthorityRuleCorrectEntity		com.alibaba.csp.sentinel.dashboard.rule.nacos.entity
# Entity		BaseRuleController		com.alibaba.csp.sentinel.dashboard.controller.base
# Entity		JacksonUtil		com.xxl.job.admin.core.util
# Entity		LocalCacheUtil		com.xxl.job.admin.core.util
# Entity		FtlUtil		com.xxl.job.admin.core.util
# Entity		CookieUtil		com.xxl.job.admin.core.util
# Entity		I18nUtil		com.xxl.job.admin.core.util
# Entity		XxlJobScheduler		com.xxl.job.admin.core.scheduler
# Entity		ExecutorRouter		com.xxl.job.admin.core.route
# Entity		ExecutorRouteRound		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteFirst		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteLast		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteBusyover		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteFailover		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteConsistentHash		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteLFU		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteRandom		com.xxl.job.admin.core.route.strategy
# Entity		ExecutorRouteLRU		com.xxl.job.admin.core.route.strategy
# Entity		CronExpression		com.xxl.job.admin.core.cron
# Entity		ValueSet		com.xxl.job.admin.core.cron
# Entity		XxlJobLogReport		com.xxl.job.admin.core.model
# Entity		XxlJobGroup		com.xxl.job.admin.core.model
# Entity		XxlJobLogGlue		com.xxl.job.admin.core.model
# Entity		XxlJobUser		com.xxl.job.admin.core.model
# Entity		XxlJobLog		com.xxl.job.admin.core.model
# Entity		XxlJobInfo		com.xxl.job.admin.core.model
# Entity		XxlJobRegistry		com.xxl.job.admin.core.model
# Entity		XxlJobTrigger		com.xxl.job.admin.core.trigger
# Entity		XxlJobCompleter		com.xxl.job.admin.core.complete
# Entity		JobRegistryHelper		com.xxl.job.admin.core.thread
# Entity		JobFailMonitorHelper		com.xxl.job.admin.core.thread
# Entity		JobCompleteHelper		com.xxl.job.admin.core.thread
# Entity		JobLogReportHelper		com.xxl.job.admin.core.thread
# Entity		JobScheduleHelper		com.xxl.job.admin.core.thread
# Entity		JobTriggerPoolHelper		com.xxl.job.admin.core.thread
# Entity		XxlJobException		com.xxl.job.admin.core.exception
# Logic		OnlineBaseExtApiFallbackFactory		org.jeecg.common.online.api.factory
# Logic		SysBaseAPIFallbackFactory		org.jeecg.common.system.api.factory
# Logic		MailHealthIndicator		org.jeecg.modules.monitor.service.impl
# Logic		RedisServiceImpl		org.jeecg.modules.monitor.service.impl
# Logic		ActuatorMemoryController		org.jeecg.modules.monitor.controller
# Logic		ActuatorRedisController		org.jeecg.modules.monitor.controller
# Logic		CustomHttpTraceEndpoint		org.jeecg.modules.monitor.actuator.httptrace
# Logic		CustomUndertowMetricsHandler		org.jeecg.modules.monitor.actuator.undertow
# Logic		TenantPackUserLogAspect		org.jeecg.modules.aop
# Logic		OssFileServiceImpl		org.jeecg.modules.oss.service.impl
# Logic		OssFileController		org.jeecg.modules.oss.controller
# Logic		QuartzJobServiceImpl		org.jeecg.modules.quartz.service.impl
# Logic		QuartzJobController		org.jeecg.modules.quartz.controller
# Logic		OpenApiServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiPermissionServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiAuthServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiLogServiceImpl		org.jeecg.modules.openapi.service.impl
# Logic		OpenApiIndexController		org.jeecg.modules.openapi.controller
# Logic		OpenApiPermissionController		org.jeecg.modules.openapi.controller
# Logic		OpenApiLogController		org.jeecg.modules.openapi.controller
# Logic		OpenApiController		org.jeecg.modules.openapi.controller
# Logic		OpenApiAuthController		org.jeecg.modules.openapi.controller
# Logic		SystemApiController		org.jeecg.modules.api.controller
# Logic		DictQueryBlackListHandler		org.jeecg.modules.system.security
# Logic		SysUserTenantServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPermissionDataRuleImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartServiceImpl		org.jeecg.modules.system.service.impl
# Logic		ImportFileServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPackPermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysFillRuleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDataSourceServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysTenantServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysBaseApiImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysTenantPackServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserRoleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysAnnouncementServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysThirdAccountServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserDepartServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserPositionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysCategoryServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartPermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysRoleIndexServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysUserAgentServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysGatewayRouteServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDictItemServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysTableWhiteListServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysAnnouncementSendServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDataLogServiceImpl		org.jeecg.modules.system.service.impl
# Logic		ThirdAppWechatEnterpriseServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysLogServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartRoleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDictServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysCommentServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysRoleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartRolePermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysCheckRuleServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysRolePermissionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysPositionServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDepartRoleUserServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysThirdAppConfigServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysFormFileServiceImpl		org.jeecg.modules.system.service.impl
# Logic		SysDataSourceController		org.jeecg.modules.system.controller
# Logic		SysUserController		org.jeecg.modules.system.controller
# Logic		LoginController		org.jeecg.modules.system.controller
# Logic		WechatVerifyController		org.jeecg.modules.system.controller
# Logic		SysDepartPermissionController		org.jeecg.modules.system.controller
# Logic		SysAppVersionController		org.jeecg.modules.system.controller
# Logic		SysCheckRuleController		org.jeecg.modules.system.controller
# Logic		SysPermissionController		org.jeecg.modules.system.controller
# Logic		SysRoleController		org.jeecg.modules.system.controller
# Logic		SysDictController		org.jeecg.modules.system.controller
# Logic		SysLogController		org.jeecg.modules.system.controller
# Logic		SysAnnouncementController		org.jeecg.modules.system.controller
# Logic		CommonController		org.jeecg.modules.system.controller
# Logic		SysDepartRoleController		org.jeecg.modules.system.controller
# Logic		SysRoleIndexController		org.jeecg.modules.system.controller
# Logic		SysFormFileController		org.jeecg.modules.system.controller
# Logic		SysDataLogController		org.jeecg.modules.system.controller
# Logic		SysCommentController		org.jeecg.modules.system.controller
# Logic		SysGatewayRouteController		org.jeecg.modules.system.controller
# Logic		SysDepartController		org.jeecg.modules.system.controller
# Logic		SysCategoryController		org.jeecg.modules.system.controller
# Logic		ThirdAppController		org.jeecg.modules.system.controller
# Logic		SysPositionController		org.jeecg.modules.system.controller
# Logic		SysUploadController		org.jeecg.modules.system.controller
# Logic		SysUserAgentController		org.jeecg.modules.system.controller
# Logic		SysAnnouncementSendController		org.jeecg.modules.system.controller
# Logic		DuplicateCheckController		org.jeecg.modules.system.controller
# Logic		SysTenantController		org.jeecg.modules.system.controller
# Logic		SysFillRuleController		org.jeecg.modules.system.controller
# Logic		SysUserOnlineController		org.jeecg.modules.system.controller
# Logic		SysTableWhiteListController		org.jeecg.modules.system.controller
# Logic		SysDictItemController		org.jeecg.modules.system.controller
# Logic		ThirdLoginController		org.jeecg.modules.system.controller
# Logic		CasClientController		org.jeecg.modules.cas.controller
# Logic		SysMessageTemplateServiceImpl		org.jeecg.modules.message.service.impl
# Logic		SysMessageServiceImpl		org.jeecg.modules.message.service.impl
# Logic		PushMsgUtil		org.jeecg.modules.message.util
# Logic		EmailSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		SystemSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		DdSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		QywxSendMsgHandle		org.jeecg.modules.message.handle.impl
# Logic		TestSocketController		org.jeecg.modules.message.controller
# Logic		SysMessageController		org.jeecg.modules.message.controller
# Logic		SysMessageTemplateController		org.jeecg.modules.message.controller
# Logic		SocketHandler		org.jeecg.modules.message.websocket
# Logic		WebSocket		org.jeecg.modules.message.websocket
# Logic		ShiroCacheClearRunner		org.jeecg.config.init
# Logic		SystemInitListener		org.jeecg.config.init
# Logic		CodeTemplateInitListener		org.jeecg.config.init
# Logic		JimuDragExternalServiceImpl		org.jeecg.config.jimureport
# Logic		JimuReportTokenService		org.jeecg.config.jimureport
# Logic		AiragKnowledgeDocServiceImpl		org.jeecg.modules.airag.llm.service.impl
# Logic		AiragKnowledgeServiceImpl		org.jeecg.modules.airag.llm.service.impl
# Logic		AiragModelServiceImpl		org.jeecg.modules.airag.llm.service.impl
# Logic		AiragKnowledgeController		org.jeecg.modules.airag.llm.controller
# Logic		AiragModelController		org.jeecg.modules.airag.llm.controller
# Logic		KnowConfigBean		org.jeecg.modules.airag.llm.config
# Logic		EmbedStoreConfigBean		org.jeecg.modules.airag.llm.config
# Logic		AIChatHandler		org.jeecg.modules.airag.llm.handler
# Logic		EmbeddingHandler		org.jeecg.modules.airag.llm.handler
# Logic		JimuDataReader		org.jeecg.modules.airag.demo
# Logic		TestAiragEnhance		org.jeecg.modules.airag.demo
# Logic		AiOcrController		org.jeecg.modules.airag.ocr.controller
# Logic		AiragAppServiceImpl		org.jeecg.modules.airag.app.service.impl
# Logic		AiragChatServiceImpl		org.jeecg.modules.airag.app.service.impl
# Logic		AiragAppController		org.jeecg.modules.airag.app.controller
# Logic		AiragChatController		org.jeecg.modules.airag.app.controller
# Logic		DlMockController		org.jeecg.modules.dlglong.controller
# Logic		OnlCgformDemoController		org.jeecg.modules.demo.online
# Logic		MockController		org.jeecg.modules.demo.mock
# Logic		VxeMockController		org.jeecg.modules.demo.mock.vxe.controller
# Logic		VxeSocket		org.jeecg.modules.demo.mock.vxe.websocket
# Logic		JcloudDemoServiceImpl		org.jeecg.modules.demo.cloud.service.impl
# Logic		JcloudDemoProviderController		org.jeecg.modules.demo.cloud.controller
# Logic		BaseCommonServiceImpl		org.jeecg.modules.base.service.impl
# Logic		JeecgSmsTemplateConfig		org.jeecg.config
# Logic		JeecgBaseConfig		org.jeecg.config
# Logic		StaticConfig		org.jeecg.config
# Logic		AutoPoiDictConfig		org.jeecg.config
# Logic		ShiroRealm		org.jeecg.config.shiro
# Logic		IgnoreAuthPostProcessor		org.jeecg.config.shiro.ignore
# Logic		MybatisInterceptor		org.jeecg.config.mybatis
# Logic		DynamicTableAspect		org.jeecg.config.mybatis.aspect
# Logic		LowCodeModeInterceptor		org.jeecg.config.firewall.interceptor
# Logic		DictAspect		org.jeecg.common.aspect
# Logic		AutoLogAspect		org.jeecg.common.aspect
# Logic		PermissionDataAspect		org.jeecg.common.aspect
# Logic		PmsUtil		org.jeecg.common.util
# Logic		SpringContextUtils		org.jeecg.common.util
# Logic		JeecgElasticsearchTemplate		org.jeecg.common.es
# Logic		ProvinceCityArea		org.jeecg.common.constant
# Logic		SensitiveDataAspect		org.jeecg.common.desensitization.aspect
# Logic		GlobalAccessTokenFilter		org.jeecg.filter
# Logic		DynamicRouteLoader		org.jeecg.loader
# Logic		MyInMemoryRouteDefinitionRepository		org.jeecg.loader.repository
# Logic		DynamicRouteService		org.jeecg.loader.repository
# Logic		LoderRouderHandler		org.jeecg.handler
# Logic		SwaggerResourceController		org.jeecg.handler.swagger
# Logic		MySwaggerResourceProvider		org.jeecg.handler.swagger
# Logic		NacosConfigProperties		com.alibaba.csp.sentinel.dashboard.rule.nacos
# Logic		ParamFlowRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.paramflow
# Logic		ParamFlowRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.paramflow
# Logic		GateWayApiNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		GateWayFlowRulesNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		GateWayApiNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		GateWayFlowRulesNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.gateway
# Logic		DegradeRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.degrade
# Logic		DegradeRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.degrade
# Logic		SystemRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.system
# Logic		SystemRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.system
# Logic		AuthorityRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.authority
# Logic		AuthorityRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.authority
# Logic		FlowRuleNacosProvider		com.alibaba.csp.sentinel.dashboard.rule.nacos.flow
# Logic		FlowRuleNacosPublisher		com.alibaba.csp.sentinel.dashboard.rule.nacos.flow
# Logic		DegradeController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		SystemController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		ParamFlowRuleController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		AuthorityRuleController		com.alibaba.csp.sentinel.dashboard.controller
# Logic		GatewayApiController		com.alibaba.csp.sentinel.dashboard.controller.gateway
# Logic		GatewayFlowRuleController		com.alibaba.csp.sentinel.dashboard.controller.gateway
# Logic		FlowControllerV2		com.alibaba.csp.sentinel.dashboard.controller.v2
# Logic		AdminBizImpl		com.xxl.job.admin.service.impl
# Logic		XxlJobServiceImpl		com.xxl.job.admin.service.impl
# Logic		XxlJobAdminConfig		com.xxl.job.admin.core.conf
# Logic		JobAlarmer		com.xxl.job.admin.core.alarm
# Logic		EmailJobAlarm		com.xxl.job.admin.core.alarm.impl
# Logic		JobGroupController		com.xxl.job.admin.controller
# Logic		JobCodeController		com.xxl.job.admin.controller
# Logic		IndexController		com.xxl.job.admin.controller
# Logic		UserController		com.xxl.job.admin.controller
# Logic		JobLogController		com.xxl.job.admin.controller
# Logic		JobInfoController		com.xxl.job.admin.controller
# Logic		JobApiController		com.xxl.job.admin.controller
# Logic		WebExceptionResolver		com.xxl.job.admin.controller.resolver
# Logic		CookieInterceptor		com.xxl.job.admin.controller.interceptor
# Logic		PermissionInterceptor		com.xxl.job.admin.controller.interceptor
# Repository (cls)	CustomInMemoryHttpTraceRepository		org.jeecg.modules.monitor.actuator.httptrace
# Interface	IOnlineBaseExtApi		org.jeecg.common.online.api
# Interface	ISysBaseAPI		org.jeecg.common.system.api
# Interface	IOnlineBaseExtApi		org.jeecg.common.online.api
# Interface	ISysBaseAPI		org.jeecg.common.system.api
# Interface	RedisService		org.jeecg.modules.monitor.service
# Interface	IOssFileService		org.jeecg.modules.oss.service
# Interface	OssFileMapper		org.jeecg.modules.oss.mapper
# Interface	IQuartzJobService		org.jeecg.modules.quartz.service
# Interface	QuartzJobMapper		org.jeecg.modules.quartz.mapper
# Interface	OpenApiLogService		org.jeecg.modules.openapi.service
# Interface	OpenApiAuthService		org.jeecg.modules.openapi.service
# Interface	OpenApiService		org.jeecg.modules.openapi.service
# Interface	OpenApiPermissionService		org.jeecg.modules.openapi.service
# Interface	OpenApiMapper		org.jeecg.modules.openapi.mapper
# Interface	OpenApiAuthMapper		org.jeecg.modules.openapi.mapper
# Interface	OpenApiLogMapper		org.jeecg.modules.openapi.mapper
# Interface	OpenApiPermissionMapper		org.jeecg.modules.openapi.mapper
# Interface	ISysDataLogService		org.jeecg.modules.system.service
# Interface	ISysDepartService		org.jeecg.modules.system.service
# Interface	ISysPackPermissionService		org.jeecg.modules.system.service
# Interface	ISysCheckRuleService		org.jeecg.modules.system.service
# Interface	ISysDepartRolePermissionService		org.jeecg.modules.system.service
# Interface	ISysGatewayRouteService		org.jeecg.modules.system.service
# Interface	ISysPermissionService		org.jeecg.modules.system.service
# Interface	ISysFillRuleService		org.jeecg.modules.system.service
# Interface	ISysCategoryService		org.jeecg.modules.system.service
# Interface	ISysDepartPermissionService		org.jeecg.modules.system.service
# Interface	ISysTenantPackService		org.jeecg.modules.system.service
# Interface	ISysDictItemService		org.jeecg.modules.system.service
# Interface	ISysRoleIndexService		org.jeecg.modules.system.service
# Interface	ISysDepartRoleUserService		org.jeecg.modules.system.service
# Interface	ISysPositionService		org.jeecg.modules.system.service
# Interface	ISysCommentService		org.jeecg.modules.system.service
# Interface	IThirdAppService		org.jeecg.modules.system.service
# Interface	ISysUserPositionService		org.jeecg.modules.system.service
# Interface	ISysRoleService		org.jeecg.modules.system.service
# Interface	ISysAnnouncementSendService		org.jeecg.modules.system.service
# Interface	ISysRolePermissionService		org.jeecg.modules.system.service
# Interface	ISysUserService		org.jeecg.modules.system.service
# Interface	ISysLogService		org.jeecg.modules.system.service
# Interface	ISysDepartRoleService		org.jeecg.modules.system.service
# Interface	ISysUserTenantService		org.jeecg.modules.system.service
# Interface	ISysTenantService		org.jeecg.modules.system.service
# Interface	ISysUserAgentService		org.jeecg.modules.system.service
# Interface	ISysFormFileService		org.jeecg.modules.system.service
# Interface	ISysDictService		org.jeecg.modules.system.service
# Interface	ISysTableWhiteListService		org.jeecg.modules.system.service
# Interface	ISysThirdAppConfigService		org.jeecg.modules.system.service
# Interface	ISysDataSourceService		org.jeecg.modules.system.service
# Interface	ISysUserRoleService		org.jeecg.modules.system.service
# Interface	ISysAnnouncementService		org.jeecg.modules.system.service
# Interface	ISysPermissionDataRuleService		org.jeecg.modules.system.service
# Interface	ISysThirdAccountService		org.jeecg.modules.system.service
# Interface	ISysUserDepartService		org.jeecg.modules.system.service
# Interface	DefIndexConst		org.jeecg.modules.system.constant
# Interface	SysCommentMapper		org.jeecg.modules.system.mapper
# Interface	SysUserDepartMapper		org.jeecg.modules.system.mapper
# Interface	SysFormFileMapper		org.jeecg.modules.system.mapper
# Interface	SysUserMapper		org.jeecg.modules.system.mapper
# Interface	SysDictItemMapper		org.jeecg.modules.system.mapper
# Interface	SysDataLogMapper		org.jeecg.modules.system.mapper
# Interface	SysUserPositionMapper		org.jeecg.modules.system.mapper
# Interface	SysTenantMapper		org.jeecg.modules.system.mapper
# Interface	SysThirdAppConfigMapper		org.jeecg.modules.system.mapper
# Interface	SysPermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysAnnouncementMapper		org.jeecg.modules.system.mapper
# Interface	SysTableWhiteListMapper		org.jeecg.modules.system.mapper
# Interface	SysUserAgentMapper		org.jeecg.modules.system.mapper
# Interface	SysCategoryMapper		org.jeecg.modules.system.mapper
# Interface	SysPermissionDataRuleMapper		org.jeecg.modules.system.mapper
# Interface	SysTenantPackUserMapper		org.jeecg.modules.system.mapper
# Interface	SysRoleMapper		org.jeecg.modules.system.mapper
# Interface	SysUserTenantMapper		org.jeecg.modules.system.mapper
# Interface	SysTenantPackMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartRoleUserMapper		org.jeecg.modules.system.mapper
# Interface	SysFillRuleMapper		org.jeecg.modules.system.mapper
# Interface	SysPackPermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartPermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysCheckRuleMapper		org.jeecg.modules.system.mapper
# Interface	SysThirdAccountMapper		org.jeecg.modules.system.mapper
# Interface	SysRolePermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartRolePermissionMapper		org.jeecg.modules.system.mapper
# Interface	SysPositionMapper		org.jeecg.modules.system.mapper
# Interface	SysDataSourceMapper		org.jeecg.modules.system.mapper
# Interface	SysGatewayRouteMapper		org.jeecg.modules.system.mapper
# Interface	SysRoleIndexMapper		org.jeecg.modules.system.mapper
# Interface	SysLogMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartRoleMapper		org.jeecg.modules.system.mapper
# Interface	SysDepartMapper		org.jeecg.modules.system.mapper
# Interface	SysUserRoleMapper		org.jeecg.modules.system.mapper
# Interface	SysAnnouncementSendMapper		org.jeecg.modules.system.mapper
# Interface	SysDictMapper		org.jeecg.modules.system.mapper
# Interface	ISysMessageTemplateService		org.jeecg.modules.message.service
# Interface	ISysMessageService		org.jeecg.modules.message.service
# Interface	ISendMsgHandle		org.jeecg.modules.message.handle
# Interface	SysMessageTemplateMapper		org.jeecg.modules.message.mapper
# Interface	SysMessageMapper		org.jeecg.modules.message.mapper
# Interface	IAiragKnowledgeDocService		org.jeecg.modules.airag.llm.service
# Interface	IAiragKnowledgeService		org.jeecg.modules.airag.llm.service
# Interface	IAiragModelService		org.jeecg.modules.airag.llm.service
# Interface	AiragKnowledgeDocMapper		org.jeecg.modules.airag.llm.mapper
# Interface	AiragModelMapper		org.jeecg.modules.airag.llm.mapper
# Interface	AiragKnowledgeMapper		org.jeecg.modules.airag.llm.mapper
# Interface	IAiragAppService		org.jeecg.modules.airag.app.service
# Interface	IAiragChatService		org.jeecg.modules.airag.app.service
# Interface	AiragAppMapper		org.jeecg.modules.airag.app.mapper
# Interface	JcloudDemoService		org.jeecg.modules.demo.cloud.service
# Interface	BaseCommonService		org.jeecg.modules.base.service
# Interface	BaseCommonMapper		org.jeecg.modules.base.mapper
# Interface	IDictTableWhiteListHandler		org.jeecg.config.firewall.SqlInjection
# Interface	TenantConstant		org.jeecg.common.constant
# Interface	CommonSendStatus		org.jeecg.common.constant
# Interface	ServiceNameConstants		org.jeecg.common.constant
# Interface	DataBaseConstant		org.jeecg.common.constant
# Interface	CommonConstant		org.jeecg.common.constant
# Interface	IFillRuleHandler		org.jeecg.common.handler
# Interface	CommonAPI		org.jeecg.common.api
# Interface	UserFilterEnhance		org.jeecg.common.system.enhance
# Interface	JeecgService		org.jeecg.common.system.base.service
# Interface	XxlJobService		com.xxl.job.admin.service
# Interface	JobAlarm		com.xxl.job.admin.core.alarm
# Interface	XxlJobUserDao		com.xxl.job.admin.dao
# Interface	XxlJobLogDao		com.xxl.job.admin.dao
# Interface	XxlJobLogReportDao		com.xxl.job.admin.dao
# Interface	XxlJobLogGlueDao		com.xxl.job.admin.dao
# Interface	XxlJobRegistryDao		com.xxl.job.admin.dao
# Interface	XxlJobInfoDao		com.xxl.job.admin.dao
# Interface	XxlJobGroupDao		com.xxl.job.admin.dao
# Excluded	JeecgSystemApplication		org.jeecg
# Excluded	FlywayConfig		org.jeecg.config.flyway
# Excluded	CustomActuatorConfig		org.jeecg.modules.monitor.actuator
# Excluded	ApiFilterConfig		org.jeecg.modules.openapi.filter
# Excluded	AuthStateConfiguration		org.jeecg.modules.system.config
# Excluded	UndertowConfiguration		org.jeecg.config.init
# Excluded	CodeGenerateDbConfig		org.jeecg.config.init
# Excluded	DruidConfig		org.jeecg.config
# Excluded	RestTemplateConfig		org.jeecg.config
# Excluded	WebSocketConfig		org.jeecg.config
# Excluded	AutoPoiConfig		org.jeecg.config
# Excluded	WebMvcConfiguration		org.jeecg.config
# Excluded	Swagger3Config		org.jeecg.config
# Excluded	SignAuthConfiguration		org.jeecg.config.sign.interceptor
# Excluded	MinioConfig		org.jeecg.config.oss
# Excluded	OssConfiguration		org.jeecg.config.oss
# Excluded	ShiroConfig		org.jeecg.config.shiro
# Excluded	MybatisPlusSaasConfig		org.jeecg.config.mybatis
# Excluded	LowCodeModeConfiguration		org.jeecg.config.firewall.interceptor
# Excluded	JeecgDemoCloudApplication		org.jeecg
# Excluded	JeecgGatewayApplication		org.jeecg
# Excluded	SentinelFilterContextConfig		org.jeecg.filter
# Excluded	GatewaySentinelExceptionConfig		org.jeecg.fallback.sentinel
# Excluded	RateLimiterConfiguration		org.jeecg.config
# Excluded	GatewayRoutersConfig		org.jeecg.config
# Excluded	JeecgSentinelApplication		com.alibaba.csp.sentinel.dashboard
# Excluded	SentinelConfig		com.alibaba.csp.sentinel.dashboard.rule.nacos
# Excluded	JeecgMonitorApplication		org.jeecg.monitor
# Excluded	SecuritySecureConfig		org.jeecg.monitor.config
# Excluded	XxlJobAdminApplication		com.xxl.job.admin
# Excluded	LoginService		com.xxl.job.admin.service
# Excluded	WebMvcConfig		com.xxl.job.admin.controller.interceptor
# Excluded	JeecgSystemCloudApplication		org.jeecg
# Excluded	JeecgNacosApplication		com.alibaba.nacos

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')
# Out:
# WARNING: QuartzJobMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartPermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleUserMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartPermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysCategoryMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: IDictTableWhiteListHandlerinterface does not have an implementing class!
# WARNING: IDictTableWhiteListHandlerinterface does not have an implementing class!
# WARNING: IDictTableWhiteListHandlerinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleUserMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysPositionMapperinterface does not have an implementing class!
# WARNING: SysPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserDepartMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserRoleMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysTenantPackMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysPackPermissionMapperinterface does not have an implementing class!
# WARNING: SysTenantPackUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysUserPositionMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionDataRuleMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: IDictTableWhiteListHandlerinterface does not have an implementing class!
# WARNING: IDictTableWhiteListHandlerinterface does not have an implementing class!
# WARNING: IDictTableWhiteListHandlerinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysDataLogMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysThirdAppConfigMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysThirdAppConfigMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysTenantMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysUserTenantMapperinterface does not have an implementing class!
# WARNING: SysThirdAccountMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartPermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartPermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysPermissionMapperinterface does not have an implementing class!
# WARNING: SysLogMapperinterface does not have an implementing class!
# WARNING: SysLogMapperinterface does not have an implementing class!
# WARNING: SysLogMapperinterface does not have an implementing class!
# WARNING: SysLogMapperinterface does not have an implementing class!
# WARNING: SysLogMapperinterface does not have an implementing class!
# WARNING: SysDepartRolePermissionMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleUserMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: SysDictItemMapperinterface does not have an implementing class!
# WARNING: SysFormFileMapperinterface does not have an implementing class!
# WARNING: SysFormFileMapperinterface does not have an implementing class!
# WARNING: SysFormFileMapperinterface does not have an implementing class!
# WARNING: SysFormFileMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysRoleMapperinterface does not have an implementing class!
# WARNING: SysDepartRoleMapperinterface does not have an implementing class!
# WARNING: SysThirdAppConfigMapperinterface does not have an implementing class!
# WARNING: SysThirdAppConfigMapperinterface does not have an implementing class!
# WARNING: SysThirdAppConfigMapperinterface does not have an implementing class!
# WARNING: SysMessageTemplateMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysMessageMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementMapperinterface does not have an implementing class!
# WARNING: SysUserMapperinterface does not have an implementing class!
# WARNING: SysAnnouncementSendMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeDocMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeDocMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeDocMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeDocMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeDocMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeDocMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeMapperinterface does not have an implementing class!
# WARNING: AiragKnowledgeMapperinterface does not have an implementing class!
# WARNING: AiragModelMapperinterface does not have an implementing class!
# WARNING: AiragAppMapperinterface does not have an implementing class!
# WARNING: AiragAppMapperinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: CommonAPIinterface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobLogGlueDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobLogReportDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobLogReportDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobRegistryDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobLogGlueDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobLogGlueDaointerface does not have an implementing class!
# WARNING: XxlJobLogGlueDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobUserDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobInfoDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobLogDaointerface does not have an implementing class!
# WARNING: XxlJobGroupDaointerface does not have an implementing class!

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['getMemoryInfo(RedisServiceImpl)', 'Calls', 'equals(RedisServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMapForReport(RedisServiceImpl)', 'Calls', 'equals(RedisServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getFreeSpace(ActuatorRedisController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getFreeSpace(ActuatorRedisController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPageList(OssFileController)', 'Calls', 'page(OssFileServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(OssFileController)', 'Calls', 'getById(OssFileServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryById(OssFileController)', 'Calls', 'getById(OssFileServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPageList(QuartzJobController)', 'Calls', 'page(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatch(QuartzJobController)', 'Calls', 'equals(QuartzJobController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatch(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['pauseJob(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resumeJob(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryById(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['exportXls(QuartzJobController)', 'Calls', 'list(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOpenApi(OpenApiPermissionServiceImpl)', 'Calls', 'list(OpenApiServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOpenApi(OpenApiPermissionServiceImpl)', 'Calls', 'Wrappers(OpenApiPermissionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getQueryTableInfo(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getQueryTableInfo(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTableName(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPermissionDataRules(SysPermissionDataRuleImpl)', 'Calls', 'in(SysPermissionDataRuleImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPermissionDataRules(SysPermissionDataRuleImpl)', 'Calls', 'eq(SysPermissionDataRuleImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deletePermissionDataRule(SysPermissionDataRuleImpl)', 'Calls', 'eq(SysPermissionDataRuleImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTreeListByPid(SysDepartServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteDepart(SysDepartServiceImpl)', 'Calls', 'eq(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDataSource(SysDataSourceServiceImpl)', 'Calls', 'save(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editDataSource(SysDataSourceServiceImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editDataSource(SysDataSourceServiceImpl)', 'Calls', 'updateById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteDataSource(SysDataSourceServiceImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteDataSource(SysDataSourceServiceImpl)', 'Calls', 'removeById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkDbCode(SysDataSourceServiceImpl)', 'Calls', 'count(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeOwenUserTenant(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['leveUserProcess(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'getOne(SysTenantPackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForApply(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForDelete(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForDelete(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForApplyJoinTenant(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForApplyJoinTenant(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForInvitation(SysTenantServiceImpl)', 'Calls', 'sendBusAnnouncement(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMsgForAgreeAndRefuseJoin(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserByPassword(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['verifyCreateTimeAndPassword(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUser(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDepartParentIdsByDepIds(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'lambda(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDatabaseTypeByDataSource(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllDict(SysBaseApiImpl)', 'Calls', 'list(SysDictServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUserBackCombo(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUserBackCombo(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUser(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUser(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUser(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllRole(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllSysDepart(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDynamicDbSourceById(SysBaseApiImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDynamicDbSourceByCode(SysBaseApiImpl)', 'Calls', 'getOne(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDynamicDbSourceByCode(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDeptHeadByDepId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDeptHeadByDepId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUserByIds(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryAllUserByIds(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserByNames(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserByNames(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserById(SysBaseApiImpl)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDeptBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryRoleBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['selectUserIdByTenantId(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['selectAllById(SysBaseApiImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDepartsByOrgcodes(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDepartsByIds(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDeptUserByOrgCode(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDeptUserByOrgCode(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDataLog(SysBaseApiImpl)', 'Calls', 'save(SysDataLogServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateAvatar(SysBaseApiImpl)', 'Calls', 'update(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserIdsByDeptIds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'list(SysRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserIdsByPositionIds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserPositionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOnlinePossiblePaths(SysBaseApiImpl)', 'Calls', 'split(SysBaseApiImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPassword(SysUserServiceImpl)', 'Calls', 'setPassword(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPassword(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithRole(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithRole(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDynamicIndexByUserRole(SysUserServiceImpl)', 'Calls', 'list(SysRoleIndexServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getDynamicIndexByUserRole(SysUserServiceImpl)', 'Calls', 'list(SysRoleIndexServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveThirdUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'equalsIgnoreCase(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveUserTenant(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveUserTenant(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['searchByKeyword(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['searchByKeyword(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUpdateDepartInfo(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUpdateDepartInfo(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateStatus(SysUserServiceImpl)', 'Calls', 'setStatus(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateStatus(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateStatus(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePasswordNotBindPhone(SysUserServiceImpl)', 'Calls', 'setPassword(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePasswordNotBindPhone(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSysTenantPack(SysTenantPackServiceImpl)', 'Calls', 'eq(SysTenantPackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSysTenantPack(SysTenantPackServiceImpl)', 'Calls', 'eq(SysTenantPackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['completeAnnouncementSendInfo(SysAnnouncementServiceImpl)', 'Calls', 'saveBatch(SysAnnouncementSendServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['batchInsertSysAnnouncementSend(SysAnnouncementServiceImpl)', 'Calls', 'saveBatch(SysAnnouncementSendServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDepartIdsOfUser(SysUserDepartServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDepartIdsOfUser(SysUserDepartServiceImpl)', 'Calls', 'convertByUserDepart(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDepartUserPageList(SysUserDepartServiceImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUserInformation(SysUserDepartServiceImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryListByCode(SysCategoryServiceImpl)', 'Calls', 'eq(SysCategoryServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'lambda(SysCategoryServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'in(SysCategoryServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'set(SysCategoryServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'eq(SysDepartPermissionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'eq(SysDepartPermissionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'in(SysDepartPermissionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateAll(SysGatewayRouteServiceImpl)', 'Calls', 'getById(SysGatewayRouteServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyRoute(SysGatewayRouteServiceImpl)', 'Calls', 'eq(SysGatewayRouteServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteDepartRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteDepartRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['syncDepartmentRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'updateById(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['syncLocalUserToThirdApp(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['thirdAccountSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'saveOrUpdate(SysThirdAccountServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUserDepart(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUserDepart(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeThirdAppUser(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysThirdAccountServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['oauth2Login(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysThirdAccountServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSysUserByThird(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'updateById(SysThirdAccountServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userDepartSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'count(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userDepartSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'save(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deletePermRuleByPermId(SysPermissionServiceImpl)', 'Calls', 'count(SysPermissionDataRuleImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deletePermRuleByPermId(SysPermissionServiceImpl)', 'Calls', 'remove(SysPermissionDataRuleImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkPermDuplication(SysPermissionServiceImpl)', 'Calls', 'count(SysPermissionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['duplicateCheckData(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['duplicateCheckData(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTreeList(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTreeList(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryTreeList(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteOneDictPhysically(SysDictServiceImpl)', 'Calls', 'eq(SysDictServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['loadDict(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['loadDict(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['loadDict(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeLogicDeleted(SysDictServiceImpl)', 'Calls', 'in(SysDictServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOne(SysCommentServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteOne(SysCommentServiceImpl)', 'Calls', 'eq(SysCommentServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteOne(SysCommentServiceImpl)', 'Calls', 'eq(SysCommentServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeDeptRoleUser(SysDepartRoleUserServiceImpl)', 'Calls', 'eq(SysDepartRoleUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPageList(SysDataSourceController)', 'Calls', 'page(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryOptions(SysDataSourceController)', 'Calls', 'list(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatch(SysDataSourceController)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBatch(SysDataSourceController)', 'Calls', 'removeByIds(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryById(SysDataSourceController)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryById(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserRole(SysUserController)', 'Calls', 'list(SysUserRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserRole(SysUserController)', 'Calls', 'lambda(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserRole(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkOnlyUser(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changePassword(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changePassword(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryUserByDepId(SysUserController)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['exportXls(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['importExcel(SysUserController)', 'Calls', 'save(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['importExcel(SysUserController)', 'Calls', 'saveBatch(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryByIds(SysUserController)', 'Calls', 'listByIds(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryByNames(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePassword(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePassword(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addSysUserRole(SysUserController)', 'Calls', 'getOne(SysUserRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addSysUserRole(SysUserController)', 'Calls', 'save(SysUserRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserRole(SysUserController)', 'Calls', 'remove(SysUserRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserRoleBatch(SysUserController)', 'Calls', 'remove(SysUserRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editSysDepartWithUser(SysUserController)', 'Calls', 'getOne(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editSysDepartWithUser(SysUserController)', 'Calls', 'save(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'remove(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'list(SysDepartRoleServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'remove(SysDepartRoleUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteUserInDepartBatch(SysUserController)', 'Calls', 'remove(SysUserDepartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['phoneVerification(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['appUserList(SysUserController)', 'Calls', 'page(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['appEdit(SysUserController)', 'Calls', 'count(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['appEdit(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveClientId(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryChildrenByUsername(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['appQueryUser(SysUserController)', 'Calls', 'page(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changMobile(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMultiUser(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userQuitAgent(SysUserController)', 'Calls', 'updateById(SysUserAgentServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userQuitAgent(SysUserController)', 'Calls', 'save(SysUserAgentServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['putCancelQuit(SysUserController)', 'Calls', 'remove(SysUserAgentServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userEdit(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userEdit(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['editTenantUser(SysUserController)', 'Calls', 'getOne(SysUserTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeLoginTenantId(SysUserController)', 'Calls', 'getOne(SysUserTenantServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeLoginTenantId(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changeLoginTenantId(SysUserController)', 'Calls', 'update(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['login(LoginController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['userInfo(LoginController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped since target method is not listed in the nodes file!
# ...
# INFO: Edge ['delete(AiragModelController)', 'Calls', 'getById(AiragModelServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(AiragModelController)', 'Calls', 'removeById(AiragModelServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryById(AiragModelController)', 'Calls', 'getById(AiragModelServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['embeddingDocument(EmbeddingHandler)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['embeddingDocument(EmbeddingHandler)', 'Calls', 'isEnableMinerU(KnowConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['embeddingDocument(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteEmbedDocsByKnowId(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteEmbedDocsByDocIds(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getHost(EmbedStoreConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getPort(EmbedStoreConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getDatabase(EmbedStoreConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getTable(EmbedStoreConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseFile(EmbeddingHandler)', 'Calls', 'parse(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseFile(EmbeddingHandler)', 'Calls', 'contains(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'equalsIgnoreCase(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'equalsIgnoreCase(EmbeddingHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'getCondaEnv(KnowConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'getCondaEnv(KnowConfigBean)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['generatePrompt(AiragAppServiceImpl)', 'Calls', 'equals(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['generatePrompt(AiragAppServiceImpl)', 'Calls', 'equals(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendWithDefault(AiragChatServiceImpl)', 'Calls', 'equals(AiragChatServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendWithDefault(AiragChatServiceImpl)', 'Calls', 'equals(AiragChatServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryPageList(AiragAppController)', 'Calls', 'page(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['edit(AiragAppController)', 'Calls', 'saveOrUpdate(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['release(AiragAppController)', 'Calls', 'updateById(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(AiragAppController)', 'Calls', 'getById(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(AiragAppController)', 'Calls', 'removeById(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryById(AiragAppController)', 'Calls', 'getById(AiragAppServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['readJsonData(DlMockController)', 'Calls', 'getClass(DlMockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getFreeSpace(MockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getFreeSpace(MockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['readJson(MockController)', 'Calls', 'getClass(MockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['readJsonData(VxeMockController)', 'Calls', 'getClass(VxeMockController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUserPool(VxeSocket)', 'Calls', 'computeIfAbsent(VxeSocket)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendMessageToAll(VxeSocket)', 'Calls', 'values(VxeSocket)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onOpen(VxeSocket)', 'Calls', 'put(VxeSocket)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onOpen(VxeSocket)', 'Calls', 'size(VxeSocket)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onClose(VxeSocket)', 'Calls', 'remove(VxeSocket)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onClose(VxeSocket)', 'Calls', 'size(VxeSocket)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doGetAuthenticationInfo(ShiroRealm)', 'Calls', 'getName(ShiroRealm)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preHandle(LowCodeModeInterceptor)', 'Calls', 'equals(LowCodeModeInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translateDictValue(DictAspect)', 'Calls', 'equals(DictAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOnlineLogContent(AutoLogAspect)', 'Calls', 'isInstance(AutoLogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getBaseUrl(JeecgElasticsearchTemplate)', 'Calls', 'append(JeecgElasticsearchTemplate)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filter(GlobalAccessTokenFilter)', 'Calls', 'addOriginalRequestUrl(GlobalAccessTokenFilter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRules(ParamFlowRuleNacosProvider)', 'Calls', 'convert(ParamFlowRuleCorrectEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publish(ParamFlowRuleNacosPublisher)', 'Calls', 'convert(ParamFlowRuleCorrectEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRules(AuthorityRuleNacosProvider)', 'Calls', 'convert(AuthorityRuleCorrectEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publish(AuthorityRuleNacosPublisher)', 'Calls', 'convert(AuthorityRuleCorrectEntity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishRules(DegradeController)', 'Calls', 'delayTime(DegradeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['countNotNullAndNotNegative(SystemController)', 'Calls', 'doubleValue(SystemController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishRules(SystemController)', 'Calls', 'delayTime(SystemController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishRules(ParamFlowRuleController)', 'Calls', 'delayTime(ParamFlowRuleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishRules(AuthorityRuleController)', 'Calls', 'delayTime(AuthorityRuleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishApis(GatewayApiController)', 'Calls', 'delayTime(GatewayApiController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishRules(GatewayFlowRuleController)', 'Calls', 'delayTime(GatewayFlowRuleController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['publishRules(FlowControllerV2)', 'Calls', 'delayTime(FlowControllerV2)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['afterPropertiesSet(XxlJobAdminConfig)', 'Calls', 'init(XxlJobScheduler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['destroy(XxlJobAdminConfig)', 'Calls', 'destroy(XxlJobScheduler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['alarm(JobAlarmer)', 'Calls', 'size(EmailJobAlarm)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['loginDo(IndexController)', 'Calls', 'equals(IndexController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['api(JobApiController)', 'Calls', 'equalsIgnoreCase(JobApiController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['postHandle(CookieInterceptor)', 'Calls', 'getName(CookieInterceptor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['add(CustomInMemoryHttpTraceRepository)', 'Calls', 'equals(CustomInMemoryHttpTraceRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sort(CustomInMemoryHttpTraceRepository)', 'Calls', 'equalsIgnoreCase(CustomInMemoryHttpTraceRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sort(CustomInMemoryHttpTraceRepository)', 'Calls', 'equalsIgnoreCase(CustomInMemoryHttpTraceRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sort(CustomInMemoryHttpTraceRepository)', 'Calls', 'equalsIgnoreCase(CustomInMemoryHttpTraceRepository)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['traces(CustomHttpTraceEndpoint)', 'Uses', 'CustomHttpTraceEndpoint'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['importExcel(QuartzJobController)', 'Uses', 'IQuartzJobService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['importExcel(SysDepartServiceImpl)', 'Uses', 'ISysDepartService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['importSysDepart(SysDepartServiceImpl)', 'Uses', 'ISysDepartService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Uses', 'ISysTenantService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Uses', 'ISysTenantService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['sendEmailMsg(SysBaseApiImpl)', 'Uses', 'EmailSendMsgHandle'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['sendHtmlTemplateEmail(SysBaseApiImpl)', 'Uses', 'EmailSendMsgHandle'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['addDefaultTenantPack(SysTenantPackServiceImpl)', 'Uses', 'ISysTenantPackService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['importExcelCheckRoleCode(SysRoleServiceImpl)', 'Uses', 'ISysRoleService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['importExcel(SysPositionController)', 'Uses', 'ISysPositionService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['sendMsg(EmailSendMsgHandle)', 'Uses', 'StaticConfig'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['sendEmail(EmailSendMsgHandle)', 'Uses', 'StaticConfig'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['isTimeJobSendEmail(EmailSendMsgHandle)', 'Uses', 'StaticConfig'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['sendMsg(SystemSendMsgHandle)', 'Uses', 'ISysBaseAPI'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['sendMessageToAll(VxeSocket)', 'Uses', 'VxeSocket'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['preHandle(LowCodeModeInterceptor)', 'Uses', 'CommonAPI'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['preHandle(LowCodeModeInterceptor)', 'Uses', 'JeecgBaseConfig'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['afterPropertiesSet(JobAlarmer)', 'Uses', 'JobAlarm'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['alarm(JobAlarmer)', 'Uses', 'JobAlarm'] discarded since target entity is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['getMemoryInfo(RedisServiceImpl)', 'Calls', 'equals(RedisServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getMapForReport(RedisServiceImpl)', 'Calls', 'equals(RedisServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getFreeSpace(ActuatorRedisController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getFreeSpace(ActuatorRedisController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPageList(OssFileController)', 'Calls', 'page(OssFileServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(OssFileController)', 'Calls', 'getById(OssFileServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(OssFileController)', 'Calls', 'getById(OssFileServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPageList(QuartzJobController)', 'Calls', 'page(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatch(QuartzJobController)', 'Calls', 'equals(QuartzJobController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatch(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['pauseJob(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resumeJob(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['exportXls(QuartzJobController)', 'Calls', 'list(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOpenApi(OpenApiPermissionServiceImpl)', 'Calls', 'list(OpenApiServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOpenApi(OpenApiPermissionServiceImpl)', 'Calls', 'Wrappers(OpenApiPermissionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getQueryTableInfo(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getQueryTableInfo(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTableName(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPermissionDataRules(SysPermissionDataRuleImpl)', 'Calls', 'in(SysPermissionDataRuleImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPermissionDataRules(SysPermissionDataRuleImpl)', 'Calls', 'eq(SysPermissionDataRuleImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePermissionDataRule(SysPermissionDataRuleImpl)', 'Calls', 'eq(SysPermissionDataRuleImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTreeListByPid(SysDepartServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDepart(SysDepartServiceImpl)', 'Calls', 'eq(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveDataSource(SysDataSourceServiceImpl)', 'Calls', 'save(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editDataSource(SysDataSourceServiceImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editDataSource(SysDataSourceServiceImpl)', 'Calls', 'updateById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDataSource(SysDataSourceServiceImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDataSource(SysDataSourceServiceImpl)', 'Calls', 'removeById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['checkDbCode(SysDataSourceServiceImpl)', 'Calls', 'count(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changeOwenUserTenant(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['leveUserProcess(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'getOne(SysTenantPackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForApply(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForDelete(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForDelete(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForApplyJoinTenant(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForApplyJoinTenant(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForInvitation(SysTenantServiceImpl)', 'Calls', 'sendBusAnnouncement(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['passApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMsgForAgreeAndRefuseJoin(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteUserByPassword(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['verifyCreateTimeAndPassword(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteUser(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDepartParentIdsByDepIds(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'lambda(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDatabaseTypeByDataSource(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllDict(SysBaseApiImpl)', 'Calls', 'list(SysDictServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUserBackCombo(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUserBackCombo(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUser(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUser(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUser(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllRole(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllSysDepart(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDynamicDbSourceById(SysBaseApiImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDynamicDbSourceByCode(SysBaseApiImpl)', 'Calls', 'getOne(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDynamicDbSourceByCode(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDeptHeadByDepId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDeptHeadByDepId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUserByIds(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryAllUserByIds(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserByNames(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserByNames(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserById(SysBaseApiImpl)', 'Calls', 'getOne(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDeptBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryRoleBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysRoleServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['selectUserIdByTenantId(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserTenantServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['selectAllById(SysBaseApiImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDepartsByOrgcodes(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDepartsByIds(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDeptUserByOrgCode(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDeptUserByOrgCode(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveDataLog(SysBaseApiImpl)', 'Calls', 'save(SysDataLogServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateAvatar(SysBaseApiImpl)', 'Calls', 'update(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserIdsByDeptIds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'list(SysRoleServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserRoleServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserIdsByPositionIds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserPositionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOnlinePossiblePaths(SysBaseApiImpl)', 'Calls', 'split(SysBaseApiImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resetPassword(SysUserServiceImpl)', 'Calls', 'setPassword(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resetPassword(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithRole(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithRole(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDynamicIndexByUserRole(SysUserServiceImpl)', 'Calls', 'list(SysRoleIndexServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getDynamicIndexByUserRole(SysUserServiceImpl)', 'Calls', 'list(SysRoleIndexServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveThirdUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'equalsIgnoreCase(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveUserTenant(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveUserTenant(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['searchByKeyword(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['searchByKeyword(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUpdateDepartInfo(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUpdateDepartInfo(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateStatus(SysUserServiceImpl)', 'Calls', 'setStatus(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateStatus(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateStatus(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePasswordNotBindPhone(SysUserServiceImpl)', 'Calls', 'setPassword(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePasswordNotBindPhone(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSysTenantPack(SysTenantPackServiceImpl)', 'Calls', 'eq(SysTenantPackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSysTenantPack(SysTenantPackServiceImpl)', 'Calls', 'eq(SysTenantPackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['completeAnnouncementSendInfo(SysAnnouncementServiceImpl)', 'Calls', 'saveBatch(SysAnnouncementSendServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['batchInsertSysAnnouncementSend(SysAnnouncementServiceImpl)', 'Calls', 'saveBatch(SysAnnouncementSendServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDepartIdsOfUser(SysUserDepartServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDepartIdsOfUser(SysUserDepartServiceImpl)', 'Calls', 'convertByUserDepart(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDepartUserPageList(SysUserDepartServiceImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUserInformation(SysUserDepartServiceImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryListByCode(SysCategoryServiceImpl)', 'Calls', 'eq(SysCategoryServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'lambda(SysCategoryServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'in(SysCategoryServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'set(SysCategoryServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'eq(SysDepartPermissionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'eq(SysDepartPermissionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'in(SysDepartPermissionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateAll(SysGatewayRouteServiceImpl)', 'Calls', 'getById(SysGatewayRouteServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyRoute(SysGatewayRouteServiceImpl)', 'Calls', 'eq(SysGatewayRouteServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDepartRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDepartRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['syncDepartmentRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'updateById(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['syncLocalUserToThirdApp(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['thirdAccountSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'saveOrUpdate(SysThirdAccountServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUserDepart(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUserDepart(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeThirdAppUser(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysThirdAccountServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['oauth2Login(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysThirdAccountServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSysUserByThird(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'updateById(SysThirdAccountServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['userDepartSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'count(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['userDepartSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'save(SysUserDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePermRuleByPermId(SysPermissionServiceImpl)', 'Calls', 'count(SysPermissionDataRuleImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePermRuleByPermId(SysPermissionServiceImpl)', 'Calls', 'remove(SysPermissionDataRuleImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['checkPermDuplication(SysPermissionServiceImpl)', 'Calls', 'count(SysPermissionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['duplicateCheckData(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['duplicateCheckData(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTreeList(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTreeList(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryTreeList(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteOneDictPhysically(SysDictServiceImpl)', 'Calls', 'eq(SysDictServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['loadDict(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['loadDict(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['loadDict(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeLogicDeleted(SysDictServiceImpl)', 'Calls', 'in(SysDictServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveOne(SysCommentServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteOne(SysCommentServiceImpl)', 'Calls', 'eq(SysCommentServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteOne(SysCommentServiceImpl)', 'Calls', 'eq(SysCommentServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeDeptRoleUser(SysDepartRoleUserServiceImpl)', 'Calls', 'eq(SysDepartRoleUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPageList(SysDataSourceController)', 'Calls', 'page(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryOptions(SysDataSourceController)', 'Calls', 'list(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatch(SysDataSourceController)', 'Calls', 'getById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBatch(SysDataSourceController)', 'Calls', 'removeByIds(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(SysDataSourceController)', 'Calls', 'getById(SysDataSourceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserRole(SysUserController)', 'Calls', 'list(SysUserRoleServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserRole(SysUserController)', 'Calls', 'lambda(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserRole(SysUserController)', 'Calls', 'eq(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['checkOnlyUser(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changePassword(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changePassword(SysUserController)', 'Calls', 'eq(SysUserController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryUserByDepId(SysUserController)', 'Calls', 'getById(SysDepartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['exportXls(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['importExcel(SysUserController)', 'Calls', 'save(SysUserServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# ...
# WARNING: unable to recover ['delete(AiragKnowledgeController)', 'Calls', 'removeById(AiragKnowledgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(AiragKnowledgeController)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDocumentPageList(AiragKnowledgeController)', 'Calls', 'page(AiragKnowledgeDocServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDocumentBatch(AiragKnowledgeController)', 'Calls', 'listByIds(AiragKnowledgeDocServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteDocumentAll(AiragKnowledgeController)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryBatchByIds(AiragKnowledgeController)', 'Calls', 'listByIds(AiragKnowledgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPageList(AiragModelController)', 'Calls', 'page(AiragModelServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['add(AiragModelController)', 'Calls', 'save(AiragModelServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(AiragModelController)', 'Calls', 'updateById(AiragModelServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(AiragModelController)', 'Calls', 'getById(AiragModelServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(AiragModelController)', 'Calls', 'removeById(AiragModelServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(AiragModelController)', 'Calls', 'getById(AiragModelServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['embeddingDocument(EmbeddingHandler)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['embeddingDocument(EmbeddingHandler)', 'Calls', 'isEnableMinerU(KnowConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['embeddingDocument(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteEmbedDocsByKnowId(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteEmbedDocsByDocIds(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getHost(EmbedStoreConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getPort(EmbedStoreConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getDatabase(EmbedStoreConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getTable(EmbedStoreConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseFile(EmbeddingHandler)', 'Calls', 'parse(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseFile(EmbeddingHandler)', 'Calls', 'contains(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'equalsIgnoreCase(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'equalsIgnoreCase(EmbeddingHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'getCondaEnv(KnowConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'getCondaEnv(KnowConfigBean)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['generatePrompt(AiragAppServiceImpl)', 'Calls', 'equals(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['generatePrompt(AiragAppServiceImpl)', 'Calls', 'equals(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendWithDefault(AiragChatServiceImpl)', 'Calls', 'equals(AiragChatServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendWithDefault(AiragChatServiceImpl)', 'Calls', 'equals(AiragChatServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryPageList(AiragAppController)', 'Calls', 'page(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['edit(AiragAppController)', 'Calls', 'saveOrUpdate(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['release(AiragAppController)', 'Calls', 'updateById(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(AiragAppController)', 'Calls', 'getById(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(AiragAppController)', 'Calls', 'removeById(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryById(AiragAppController)', 'Calls', 'getById(AiragAppServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readJsonData(DlMockController)', 'Calls', 'getClass(DlMockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(MockController)', 'Calls', 'getFreeSpace(MockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(MockController)', 'Calls', 'getFreeSpace(MockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readJson(MockController)', 'Calls', 'getClass(MockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readJsonData(VxeMockController)', 'Calls', 'getClass(VxeMockController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUserPool(VxeSocket)', 'Calls', 'computeIfAbsent(VxeSocket)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendMessageToAll(VxeSocket)', 'Calls', 'values(VxeSocket)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onOpen(VxeSocket)', 'Calls', 'put(VxeSocket)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onOpen(VxeSocket)', 'Calls', 'size(VxeSocket)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onClose(VxeSocket)', 'Calls', 'remove(VxeSocket)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['onClose(VxeSocket)', 'Calls', 'size(VxeSocket)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doGetAuthenticationInfo(ShiroRealm)', 'Calls', 'getName(ShiroRealm)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['preHandle(LowCodeModeInterceptor)', 'Calls', 'equals(LowCodeModeInterceptor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translateDictValue(DictAspect)', 'Calls', 'equals(DictAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOnlineLogContent(AutoLogAspect)', 'Calls', 'isInstance(AutoLogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getBaseUrl(JeecgElasticsearchTemplate)', 'Calls', 'append(JeecgElasticsearchTemplate)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filter(GlobalAccessTokenFilter)', 'Calls', 'addOriginalRequestUrl(GlobalAccessTokenFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getRules(ParamFlowRuleNacosProvider)', 'Calls', 'convert(ParamFlowRuleCorrectEntity)']: discarding
# WARNING: Unable to recover target method for edge ['publish(ParamFlowRuleNacosPublisher)', 'Calls', 'convert(ParamFlowRuleCorrectEntity)']: discarding
# WARNING: Unable to recover target method for edge ['getRules(AuthorityRuleNacosProvider)', 'Calls', 'convert(AuthorityRuleCorrectEntity)']: discarding
# WARNING: Unable to recover target method for edge ['publish(AuthorityRuleNacosPublisher)', 'Calls', 'convert(AuthorityRuleCorrectEntity)']: discarding
# WARNING: unable to recover ['publishRules(DegradeController)', 'Calls', 'delayTime(DegradeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['countNotNullAndNotNegative(SystemController)', 'Calls', 'doubleValue(SystemController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['publishRules(SystemController)', 'Calls', 'delayTime(SystemController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['publishRules(ParamFlowRuleController)', 'Calls', 'delayTime(ParamFlowRuleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['publishRules(AuthorityRuleController)', 'Calls', 'delayTime(AuthorityRuleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['publishApis(GatewayApiController)', 'Calls', 'delayTime(GatewayApiController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['publishRules(GatewayFlowRuleController)', 'Calls', 'delayTime(GatewayFlowRuleController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['publishRules(FlowControllerV2)', 'Calls', 'delayTime(FlowControllerV2)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['afterPropertiesSet(XxlJobAdminConfig)', 'Calls', 'init(XxlJobScheduler)']: discarding
# WARNING: Unable to recover target method for edge ['destroy(XxlJobAdminConfig)', 'Calls', 'destroy(XxlJobScheduler)']: discarding
# WARNING: unable to recover ['alarm(JobAlarmer)', 'Calls', 'size(EmailJobAlarm)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['loginDo(IndexController)', 'Calls', 'equals(IndexController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['api(JobApiController)', 'Calls', 'equalsIgnoreCase(JobApiController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['postHandle(CookieInterceptor)', 'Calls', 'getName(CookieInterceptor)'] since target method may be from a superclass. (Not implemented yet)

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# Adding new node for method equals(CustomInMemoryHttpTraceRepository)
# Adding new node for method equalsIgnoreCase(CustomInMemoryHttpTraceRepository)
# INFO: Edge ['getMemoryInfo(RedisServiceImpl)', 'Calls', 'equals(RedisServiceImpl)'] skipped
# INFO: Edge ['getMapForReport(RedisServiceImpl)', 'Calls', 'equals(RedisServiceImpl)'] skipped
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getFreeSpace(ActuatorRedisController)'] skipped
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getFreeSpace(ActuatorRedisController)'] skipped
# INFO: Edge ['queryDiskInfo(ActuatorRedisController)', 'Calls', 'getTotalSpace(ActuatorRedisController)'] skipped
# INFO: Edge ['queryPageList(OssFileController)', 'Calls', 'page(OssFileServiceImpl)'] skipped
# INFO: Edge ['delete(OssFileController)', 'Calls', 'getById(OssFileServiceImpl)'] skipped
# INFO: Edge ['queryById(OssFileController)', 'Calls', 'getById(OssFileServiceImpl)'] skipped
# INFO: Edge ['queryPageList(QuartzJobController)', 'Calls', 'page(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['delete(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(QuartzJobController)', 'Calls', 'equals(QuartzJobController)'] skipped
# INFO: Edge ['deleteBatch(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['pauseJob(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['resumeJob(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['queryById(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['exportXls(QuartzJobController)', 'Calls', 'list(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['execute(QuartzJobController)', 'Calls', 'getById(QuartzJobServiceImpl)'] skipped
# INFO: Edge ['getOpenApi(OpenApiPermissionServiceImpl)', 'Calls', 'list(OpenApiServiceImpl)'] skipped
# INFO: Edge ['getOpenApi(OpenApiPermissionServiceImpl)', 'Calls', 'Wrappers(OpenApiPermissionServiceImpl)'] skipped
# INFO: Edge ['getQueryTableInfo(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['getQueryTableInfo(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['getTableName(DictQueryBlackListHandler)', 'Calls', 'trim(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryPermissionDataRules(SysPermissionDataRuleImpl)', 'Calls', 'in(SysPermissionDataRuleImpl)'] skipped
# INFO: Edge ['queryPermissionDataRules(SysPermissionDataRuleImpl)', 'Calls', 'eq(SysPermissionDataRuleImpl)'] skipped
# INFO: Edge ['deletePermissionDataRule(SysPermissionDataRuleImpl)', 'Calls', 'eq(SysPermissionDataRuleImpl)'] skipped
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['deleteBatchWithChildren(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartServiceImpl)', 'Calls', 'in(SysDepartServiceImpl)'] skipped
# INFO: Edge ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] skipped
# INFO: Edge ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] skipped
# INFO: Edge ['getMinLengthNode(SysDepartServiceImpl)', 'Calls', 'length(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryTreeListByPid(SysDepartServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['deleteDepart(SysDepartServiceImpl)', 'Calls', 'eq(SysDepartServiceImpl)'] skipped
# INFO: Edge ['saveDataSource(SysDataSourceServiceImpl)', 'Calls', 'save(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['editDataSource(SysDataSourceServiceImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['editDataSource(SysDataSourceServiceImpl)', 'Calls', 'updateById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['deleteDataSource(SysDataSourceServiceImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['deleteDataSource(SysDataSourceServiceImpl)', 'Calls', 'removeById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['checkDbCode(SysDataSourceServiceImpl)', 'Calls', 'count(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['changeOwenUserTenant(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['leveUserProcess(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['addBatchTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['deleteTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['deleteTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'getOne(SysTenantPackServiceImpl)'] skipped
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['doApplyTenantPackUser(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['sendMsgForApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['sendMsgForApply(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['sendMsgForDelete(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['sendMsgForDelete(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['sendMsgForApplyJoinTenant(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['sendMsgForApplyJoinTenant(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['sendMsgForInvitation(SysTenantServiceImpl)', 'Calls', 'sendBusAnnouncement(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['passApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'eq(SysTenantServiceImpl)'] skipped
# INFO: Edge ['deleteApply(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['sendMsgForAgreeAndRefuseJoin(SysTenantServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['deleteUserByPassword(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['verifyCreateTimeAndPassword(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['deleteUser(SysTenantServiceImpl)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryPermissionDataRule(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['getDepartParentIdsByDepIds(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped
# INFO: Edge ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['updateSysAnnounReadFlag(SysBaseApiImpl)', 'Calls', 'lambda(SysBaseApiImpl)'] skipped
# INFO: Edge ['getDatabaseTypeByDataSource(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllDict(SysBaseApiImpl)', 'Calls', 'list(SysDictServiceImpl)'] skipped
# INFO: Edge ['queryAllUserBackCombo(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllUserBackCombo(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllUser(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllUser(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllUser(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllRole(SysBaseApiImpl)', 'Calls', 'equals(SysBaseApiImpl)'] skipped
# INFO: Edge ['getAllSysDepart(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['getDynamicDbSourceById(SysBaseApiImpl)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['getDynamicDbSourceByCode(SysBaseApiImpl)', 'Calls', 'getOne(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['getDynamicDbSourceByCode(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['getDeptHeadByDepId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['getDeptHeadByDepId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllUserByIds(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryAllUserByIds(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryUserByNames(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryUserByNames(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryUserBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryUserById(SysBaseApiImpl)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryDeptBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryRoleBySuperQuery(SysBaseApiImpl)', 'Calls', 'list(SysRoleServiceImpl)'] skipped
# INFO: Edge ['selectUserIdByTenantId(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserTenantServiceImpl)'] skipped
# INFO: Edge ['selectAllById(SysBaseApiImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'eq(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['queryDeptUsersByUserId(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryDepartsByOrgcodes(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryDepartsByIds(SysBaseApiImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['getDeptUserByOrgCode(SysBaseApiImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['getDeptUserByOrgCode(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped
# INFO: Edge ['saveDataLog(SysBaseApiImpl)', 'Calls', 'save(SysDataLogServiceImpl)'] skipped
# INFO: Edge ['updateAvatar(SysBaseApiImpl)', 'Calls', 'update(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryUserIdsByDeptIds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'in(SysBaseApiImpl)'] skipped
# INFO: Edge ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'list(SysRoleServiceImpl)'] skipped
# INFO: Edge ['queryUserIdsByRoleds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['queryUserIdsByPositionIds(SysBaseApiImpl)', 'Calls', 'listObjs(SysUserPositionServiceImpl)'] skipped
# INFO: Edge ['getOnlinePossiblePaths(SysBaseApiImpl)', 'Calls', 'split(SysBaseApiImpl)'] skipped
# INFO: Edge ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['announcementAutoRelease(SysBaseApiImpl)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['resetPassword(SysUserServiceImpl)', 'Calls', 'setPassword(SysUserServiceImpl)'] skipped
# INFO: Edge ['resetPassword(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithRole(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithRole(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['getDynamicIndexByUserRole(SysUserServiceImpl)', 'Calls', 'list(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['getDynamicIndexByUserRole(SysUserServiceImpl)', 'Calls', 'list(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUserWithDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['removeLogicDeleted(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['saveThirdUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'equalsIgnoreCase(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['editUser(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['saveUserTenant(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['saveUserTenant(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['batchEditUsers(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['searchByKeyword(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] skipped
# INFO: Edge ['searchByKeyword(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] skipped
# INFO: Edge ['getUpdateDepartInfo(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['getUpdateDepartInfo(SysUserServiceImpl)', 'Calls', 'like(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateStatus(SysUserServiceImpl)', 'Calls', 'setStatus(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateStatus(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateStatus(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'lambda(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateTenantDepart(SysUserServiceImpl)', 'Calls', 'in(SysUserServiceImpl)'] skipped
# INFO: Edge ['updatePasswordNotBindPhone(SysUserServiceImpl)', 'Calls', 'setPassword(SysUserServiceImpl)'] skipped
# INFO: Edge ['updatePasswordNotBindPhone(SysUserServiceImpl)', 'Calls', 'eq(SysUserServiceImpl)'] skipped
# INFO: Edge ['getSysTenantPack(SysTenantPackServiceImpl)', 'Calls', 'eq(SysTenantPackServiceImpl)'] skipped
# INFO: Edge ['getSysTenantPack(SysTenantPackServiceImpl)', 'Calls', 'eq(SysTenantPackServiceImpl)'] skipped
# INFO: Edge ['completeAnnouncementSendInfo(SysAnnouncementServiceImpl)', 'Calls', 'saveBatch(SysAnnouncementSendServiceImpl)'] skipped
# INFO: Edge ['batchInsertSysAnnouncementSend(SysAnnouncementServiceImpl)', 'Calls', 'saveBatch(SysAnnouncementSendServiceImpl)'] skipped
# INFO: Edge ['queryDepartIdsOfUser(SysUserDepartServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryDepartIdsOfUser(SysUserDepartServiceImpl)', 'Calls', 'convertByUserDepart(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['queryDepartUserPageList(SysUserDepartServiceImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['getUserInformation(SysUserDepartServiceImpl)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryListByCode(SysCategoryServiceImpl)', 'Calls', 'eq(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'lambda(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'in(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['deleteSysCategory(SysCategoryServiceImpl)', 'Calls', 'set(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'eq(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'eq(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['saveDepartPermission(SysDepartPermissionServiceImpl)', 'Calls', 'in(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['updateAll(SysGatewayRouteServiceImpl)', 'Calls', 'getById(SysGatewayRouteServiceImpl)'] skipped
# INFO: Edge ['copyRoute(SysGatewayRouteServiceImpl)', 'Calls', 'eq(SysGatewayRouteServiceImpl)'] skipped
# INFO: Edge ['deleteDepartRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped
# INFO: Edge ['deleteDepartRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysDepartServiceImpl)'] skipped
# INFO: Edge ['syncDepartmentRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'updateById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysDepartServiceImpl)'] skipped
# INFO: Edge ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped
# INFO: Edge ['syncDepartmentToLocalRecursion(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped
# INFO: Edge ['syncLocalUserToThirdApp(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'equals(ThirdAppWechatEnterpriseServiceImpl)'] skipped
# INFO: Edge ['thirdAccountSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'saveOrUpdate(SysThirdAccountServiceImpl)'] skipped
# INFO: Edge ['getUserDepart(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['getUserDepart(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['removeThirdAppUser(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'list(SysThirdAccountServiceImpl)'] skipped
# INFO: Edge ['oauth2Login(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'getOne(SysThirdAccountServiceImpl)'] skipped
# INFO: Edge ['getSysUserByThird(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'updateById(SysThirdAccountServiceImpl)'] skipped
# INFO: Edge ['userDepartSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'count(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['userDepartSaveOrUpdate(ThirdAppWechatEnterpriseServiceImpl)', 'Calls', 'save(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['deletePermRuleByPermId(SysPermissionServiceImpl)', 'Calls', 'count(SysPermissionDataRuleImpl)'] skipped
# INFO: Edge ['deletePermRuleByPermId(SysPermissionServiceImpl)', 'Calls', 'remove(SysPermissionDataRuleImpl)'] skipped
# INFO: Edge ['checkPermDuplication(SysPermissionServiceImpl)', 'Calls', 'count(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['duplicateCheckData(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['duplicateCheckData(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictItemsByCode(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictItemsByCodeAndFilter(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictTextByKey(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictTextByKeys(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTableDictByKeys(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTreeList(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryTreeList(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryTreeList(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['deleteOneDictPhysically(SysDictServiceImpl)', 'Calls', 'eq(SysDictServiceImpl)'] skipped
# INFO: Edge ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['queryDictTablePageList(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['loadDict(SysDictServiceImpl)', 'Calls', 'dictTableWhiteListCheckByDict(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['loadDict(SysDictServiceImpl)', 'Calls', 'isPass(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['loadDict(SysDictServiceImpl)', 'Calls', 'getError(DictQueryBlackListHandler)'] skipped
# INFO: Edge ['removeLogicDeleted(SysDictServiceImpl)', 'Calls', 'in(SysDictServiceImpl)'] skipped
# INFO: Edge ['saveOne(SysCommentServiceImpl)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['deleteOne(SysCommentServiceImpl)', 'Calls', 'eq(SysCommentServiceImpl)'] skipped
# INFO: Edge ['deleteOne(SysCommentServiceImpl)', 'Calls', 'eq(SysCommentServiceImpl)'] skipped
# INFO: Edge ['removeDeptRoleUser(SysDepartRoleUserServiceImpl)', 'Calls', 'eq(SysDepartRoleUserServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysDataSourceController)', 'Calls', 'page(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['queryOptions(SysDataSourceController)', 'Calls', 'list(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysDataSourceController)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysDataSourceController)', 'Calls', 'removeByIds(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['queryById(SysDataSourceController)', 'Calls', 'getById(SysDataSourceServiceImpl)'] skipped
# INFO: Edge ['edit(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryById(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryUserRole(SysUserController)', 'Calls', 'list(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['queryUserRole(SysUserController)', 'Calls', 'lambda(SysUserController)'] skipped
# INFO: Edge ['queryUserRole(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['checkOnlyUser(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['changePassword(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['changePassword(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['queryUserByDepId(SysUserController)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['exportXls(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] skipped
# INFO: Edge ['importExcel(SysUserController)', 'Calls', 'save(SysUserServiceImpl)'] skipped
# INFO: Edge ['importExcel(SysUserController)', 'Calls', 'saveBatch(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['queryByIds(SysUserController)', 'Calls', 'listByIds(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryByNames(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] skipped
# INFO: Edge ['updatePassword(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['updatePassword(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['addSysUserRole(SysUserController)', 'Calls', 'getOne(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['addSysUserRole(SysUserController)', 'Calls', 'save(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['deleteUserRole(SysUserController)', 'Calls', 'remove(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['deleteUserRoleBatch(SysUserController)', 'Calls', 'remove(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['editSysDepartWithUser(SysUserController)', 'Calls', 'getOne(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['editSysDepartWithUser(SysUserController)', 'Calls', 'save(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'remove(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'list(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['deleteUserInDepart(SysUserController)', 'Calls', 'remove(SysDepartRoleUserServiceImpl)'] skipped
# INFO: Edge ['deleteUserInDepartBatch(SysUserController)', 'Calls', 'remove(SysUserDepartServiceImpl)'] skipped
# INFO: Edge ['phoneVerification(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['passwordChange(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped
# INFO: Edge ['appUserList(SysUserController)', 'Calls', 'page(SysUserServiceImpl)'] skipped
# INFO: Edge ['appEdit(SysUserController)', 'Calls', 'count(SysUserServiceImpl)'] skipped
# INFO: Edge ['appEdit(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped
# INFO: Edge ['saveClientId(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryChildrenByUsername(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['appQueryUser(SysUserController)', 'Calls', 'page(SysUserServiceImpl)'] skipped
# INFO: Edge ['changMobile(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped
# INFO: Edge ['getMultiUser(SysUserController)', 'Calls', 'list(SysUserServiceImpl)'] skipped
# INFO: Edge ['userQuitAgent(SysUserController)', 'Calls', 'updateById(SysUserAgentServiceImpl)'] skipped
# INFO: Edge ['userQuitAgent(SysUserController)', 'Calls', 'save(SysUserAgentServiceImpl)'] skipped
# INFO: Edge ['putCancelQuit(SysUserController)', 'Calls', 'remove(SysUserAgentServiceImpl)'] skipped
# INFO: Edge ['userEdit(SysUserController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['userEdit(SysUserController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped
# INFO: Edge ['editTenantUser(SysUserController)', 'Calls', 'getOne(SysUserTenantServiceImpl)'] skipped
# INFO: Edge ['changeLoginTenantId(SysUserController)', 'Calls', 'getOne(SysUserTenantServiceImpl)'] skipped
# INFO: Edge ['changeLoginTenantId(SysUserController)', 'Calls', 'eq(SysUserController)'] skipped
# INFO: Edge ['changeLoginTenantId(SysUserController)', 'Calls', 'update(SysUserServiceImpl)'] skipped
# INFO: Edge ['login(LoginController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['userInfo(LoginController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['sendSms(LoginController)', 'Calls', 'getOne(SysUserServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysDepartPermissionController)', 'Calls', 'page(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['add(SysDepartPermissionController)', 'Calls', 'save(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['edit(SysDepartPermissionController)', 'Calls', 'updateById(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartPermissionController)', 'Calls', 'removeById(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysDepartPermissionController)', 'Calls', 'removeByIds(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['queryById(SysDepartPermissionController)', 'Calls', 'getById(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['loadDatarule(SysDepartPermissionController)', 'Calls', 'eq(SysDepartPermissionController)'] skipped
# INFO: Edge ['loadDatarule(SysDepartPermissionController)', 'Calls', 'eq(SysDepartPermissionController)'] skipped
# INFO: Edge ['loadDatarule(SysDepartPermissionController)', 'Calls', 'getOne(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['saveDatarule(SysDepartPermissionController)', 'Calls', 'eq(SysDepartPermissionController)'] skipped
# INFO: Edge ['saveDatarule(SysDepartPermissionController)', 'Calls', 'eq(SysDepartPermissionController)'] skipped
# INFO: Edge ['saveDatarule(SysDepartPermissionController)', 'Calls', 'getOne(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['saveDatarule(SysDepartPermissionController)', 'Calls', 'updateById(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['queryDeptRolePermission(SysDepartPermissionController)', 'Calls', 'list(SysDepartRolePermissionServiceImpl)'] skipped
# INFO: Edge ['queryDeptRolePermission(SysDepartPermissionController)', 'Calls', 'lambda(SysDepartPermissionController)'] skipped
# INFO: Edge ['queryDeptRolePermission(SysDepartPermissionController)', 'Calls', 'eq(SysDepartPermissionController)'] skipped
# INFO: Edge ['queryPageList(SysCheckRuleController)', 'Calls', 'page(SysCheckRuleServiceImpl)'] skipped
# INFO: Edge ['add(SysCheckRuleController)', 'Calls', 'save(SysCheckRuleServiceImpl)'] skipped
# INFO: Edge ['edit(SysCheckRuleController)', 'Calls', 'updateById(SysCheckRuleServiceImpl)'] skipped
# INFO: Edge ['delete(SysCheckRuleController)', 'Calls', 'removeById(SysCheckRuleServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysCheckRuleController)', 'Calls', 'removeByIds(SysCheckRuleServiceImpl)'] skipped
# INFO: Edge ['queryById(SysCheckRuleController)', 'Calls', 'getById(SysCheckRuleServiceImpl)'] skipped
# INFO: Edge ['list(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['getSystemMenuList(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['getSystemSubmenu(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['getSystemSubmenuBatch(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['getUserPermissionByToken(SysPermissionController)', 'Calls', 'getOne(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['getUserPermissionByToken(SysPermissionController)', 'Calls', 'select(SysPermissionController)'] skipped
# INFO: Edge ['getUserPermissionByToken(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['getPermCode(SysPermissionController)', 'Calls', 'select(SysPermissionController)'] skipped
# INFO: Edge ['getPermCode(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['queryTreeList(SysPermissionController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['queryRolePermission(SysPermissionController)', 'Calls', 'list(SysRolePermissionServiceImpl)'] skipped
# INFO: Edge ['queryRolePermission(SysPermissionController)', 'Calls', 'lambda(SysPermissionController)'] skipped
# INFO: Edge ['queryRolePermission(SysPermissionController)', 'Calls', 'eq(SysPermissionController)'] skipped
# INFO: Edge ['editPermissionRule(SysPermissionController)', 'Calls', 'saveOrUpdate(SysPermissionDataRuleImpl)'] skipped
# INFO: Edge ['queryDepartPermission(SysPermissionController)', 'Calls', 'list(SysDepartPermissionServiceImpl)'] skipped
# INFO: Edge ['queryDepartPermission(SysPermissionController)', 'Calls', 'lambda(SysPermissionController)'] skipped
# INFO: Edge ['queryDepartPermission(SysPermissionController)', 'Calls', 'eq(SysPermissionController)'] skipped
# INFO: Edge ['listByTenant(SysRoleController)', 'Calls', 'equals(SysRoleController)'] skipped
# INFO: Edge ['listByTenant(SysRoleController)', 'Calls', 'page(SysRoleServiceImpl)'] skipped
# INFO: Edge ['add(SysRoleController)', 'Calls', 'save(SysRoleServiceImpl)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'getById(SysRoleServiceImpl)'] skipped
# INFO: Edge ['edit(SysRoleController)', 'Calls', 'updateById(SysRoleServiceImpl)'] skipped
# INFO: Edge ['queryById(SysRoleController)', 'Calls', 'getById(SysRoleServiceImpl)'] skipped
# INFO: Edge ['queryall(SysRoleController)', 'Calls', 'list(SysRoleServiceImpl)'] skipped
# INFO: Edge ['queryallNoByTenant(SysRoleController)', 'Calls', 'list(SysRoleServiceImpl)'] skipped
# INFO: Edge ['checkUsername(SysRoleController)', 'Calls', 'getById(SysRoleServiceImpl)'] skipped
# INFO: Edge ['exportXls(SysRoleController)', 'Calls', 'list(SysRoleServiceImpl)'] skipped
# INFO: Edge ['loadDatarule(SysRoleController)', 'Calls', 'eq(SysRoleController)'] skipped
# INFO: Edge ['loadDatarule(SysRoleController)', 'Calls', 'isNotNull(SysRoleController)'] skipped
# INFO: Edge ['loadDatarule(SysRoleController)', 'Calls', 'eq(SysRoleController)'] skipped
# INFO: Edge ['loadDatarule(SysRoleController)', 'Calls', 'getOne(SysRolePermissionServiceImpl)'] skipped
# INFO: Edge ['saveDatarule(SysRoleController)', 'Calls', 'eq(SysRoleController)'] skipped
# INFO: Edge ['saveDatarule(SysRoleController)', 'Calls', 'eq(SysRoleController)'] skipped
# INFO: Edge ['saveDatarule(SysRoleController)', 'Calls', 'getOne(SysRolePermissionServiceImpl)'] skipped
# INFO: Edge ['saveDatarule(SysRoleController)', 'Calls', 'updateById(SysRolePermissionServiceImpl)'] skipped
# INFO: Edge ['queryTreeList(SysRoleController)', 'Calls', 'list(SysPermissionServiceImpl)'] skipped
# INFO: Edge ['queryPageRoleCount(SysRoleController)', 'Calls', 'page(SysRoleServiceImpl)'] skipped
# INFO: Edge ['queryPageRoleCount(SysRoleController)', 'Calls', 'count(SysUserRoleServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysDictController)', 'Calls', 'page(SysDictServiceImpl)'] skipped
# INFO: Edge ['treeList(SysDictController)', 'Calls', 'list(SysDictServiceImpl)'] skipped
# INFO: Edge ['add(SysDictController)', 'Calls', 'save(SysDictServiceImpl)'] skipped
# INFO: Edge ['edit(SysDictController)', 'Calls', 'getById(SysDictServiceImpl)'] skipped
# INFO: Edge ['edit(SysDictController)', 'Calls', 'updateById(SysDictServiceImpl)'] skipped
# INFO: Edge ['delete(SysDictController)', 'Calls', 'removeById(SysDictServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysDictController)', 'Calls', 'removeByIds(SysDictServiceImpl)'] skipped
# INFO: Edge ['exportXls(SysDictController)', 'Calls', 'list(SysDictServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysLogController)', 'Calls', 'page(SysLogServiceImpl)'] skipped
# INFO: Edge ['delete(SysLogController)', 'Calls', 'getById(SysLogServiceImpl)'] skipped
# INFO: Edge ['delete(SysLogController)', 'Calls', 'removeById(SysLogServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysLogController)', 'Calls', 'equals(SysLogController)'] skipped
# INFO: Edge ['deleteBatch(SysLogController)', 'Calls', 'removeByIds(SysLogServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysAnnouncementController)', 'Calls', 'page(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['eidt(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['editIzTop(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['editIzTop(SysAnnouncementController)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['delete(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['delete(SysAnnouncementController)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysAnnouncementController)', 'Calls', 'equals(SysAnnouncementController)'] skipped
# INFO: Edge ['deleteBatch(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysAnnouncementController)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['queryById(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['doReleaseData(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['doReleaseData(SysAnnouncementController)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['doReleaseData(SysAnnouncementController)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['doReovkeData(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['doReovkeData(SysAnnouncementController)', 'Calls', 'updateById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['exportXls(SysAnnouncementController)', 'Calls', 'list(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['importExcel(SysAnnouncementController)', 'Calls', 'save(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['syncNotic(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['showContent(SysAnnouncementController)', 'Calls', 'getById(SysAnnouncementServiceImpl)'] skipped
# INFO: Edge ['getLastAnnountTime(SysAnnouncementController)', 'Calls', 'page(SysAnnouncementSendServiceImpl)'] skipped
# INFO: Edge ['extractPathFromPattern(CommonController)', 'Calls', 'extractPathWithinPattern(CommonController)'] skipped
# INFO: Edge ['queryPageList(SysDepartRoleController)', 'Calls', 'page(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['add(SysDepartRoleController)', 'Calls', 'save(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['edit(SysDepartRoleController)', 'Calls', 'updateById(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartRoleController)', 'Calls', 'removeById(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['queryById(SysDepartRoleController)', 'Calls', 'getById(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['getDeptRoleList(SysDepartRoleController)', 'Calls', 'list(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['getDeptRoleList(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['getDeptRoleByUserId(SysDepartRoleController)', 'Calls', 'list(SysDepartRoleServiceImpl)'] skipped
# INFO: Edge ['getDeptRoleByUserId(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['getDeptRoleByUserId(SysDepartRoleController)', 'Calls', 'list(SysDepartRoleUserServiceImpl)'] skipped
# INFO: Edge ['getDeptRoleByUserId(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['getDeptRoleByUserId(SysDepartRoleController)', 'Calls', 'in(SysDepartRoleController)'] skipped
# INFO: Edge ['loadDatarule(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['loadDatarule(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['loadDatarule(SysDepartRoleController)', 'Calls', 'getOne(SysDepartRolePermissionServiceImpl)'] skipped
# INFO: Edge ['saveDatarule(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['saveDatarule(SysDepartRoleController)', 'Calls', 'eq(SysDepartRoleController)'] skipped
# INFO: Edge ['saveDatarule(SysDepartRoleController)', 'Calls', 'getOne(SysDepartRolePermissionServiceImpl)'] skipped
# INFO: Edge ['saveDatarule(SysDepartRoleController)', 'Calls', 'updateById(SysDepartRolePermissionServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysRoleIndexController)', 'Calls', 'page(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['add(SysRoleIndexController)', 'Calls', 'save(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['edit(SysRoleIndexController)', 'Calls', 'updateById(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['delete(SysRoleIndexController)', 'Calls', 'removeById(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysRoleIndexController)', 'Calls', 'removeByIds(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['queryById(SysRoleIndexController)', 'Calls', 'getById(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['queryByCode(SysRoleIndexController)', 'Calls', 'getOne(SysRoleIndexServiceImpl)'] skipped
# INFO: Edge ['queryByCode(SysRoleIndexController)', 'Calls', 'eq(SysRoleIndexController)'] skipped
# INFO: Edge ['queryPageList(SysFormFileController)', 'Calls', 'page(SysFormFileServiceImpl)'] skipped
# INFO: Edge ['add(SysFormFileController)', 'Calls', 'save(SysFormFileServiceImpl)'] skipped
# INFO: Edge ['edit(SysFormFileController)', 'Calls', 'updateById(SysFormFileServiceImpl)'] skipped
# INFO: Edge ['delete(SysFormFileController)', 'Calls', 'removeById(SysFormFileServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysFormFileController)', 'Calls', 'removeByIds(SysFormFileServiceImpl)'] skipped
# INFO: Edge ['queryById(SysFormFileController)', 'Calls', 'getById(SysFormFileServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysDataLogController)', 'Calls', 'page(SysDataLogServiceImpl)'] skipped
# INFO: Edge ['queryCompareList(SysDataLogController)', 'Calls', 'listByIds(SysDataLogServiceImpl)'] skipped
# INFO: Edge ['queryDataVerList(SysDataLogController)', 'Calls', 'list(SysDataLogServiceImpl)'] skipped
# INFO: Edge ['deleteOne(SysCommentController)', 'Calls', 'getById(SysCommentServiceImpl)'] skipped
# INFO: Edge ['deleteOne(SysCommentController)', 'Calls', 'saveDataLog(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryPageList(SysCommentController)', 'Calls', 'page(SysCommentServiceImpl)'] skipped
# INFO: Edge ['add(SysCommentController)', 'Calls', 'save(SysCommentServiceImpl)'] skipped
# INFO: Edge ['edit(SysCommentController)', 'Calls', 'updateById(SysCommentServiceImpl)'] skipped
# INFO: Edge ['delete(SysCommentController)', 'Calls', 'removeById(SysCommentServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysCommentController)', 'Calls', 'removeByIds(SysCommentServiceImpl)'] skipped
# INFO: Edge ['queryById(SysCommentController)', 'Calls', 'getById(SysCommentServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysGatewayRouteController)', 'Calls', 'list(SysGatewayRouteServiceImpl)'] skipped
# INFO: Edge ['edit(SysDepartController)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['delete(SysDepartController)', 'Calls', 'getById(SysDepartServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysDepartController)', 'Calls', 'equals(SysDepartController)'] skipped
# INFO: Edge ['listAll(SysDepartController)', 'Calls', 'list(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryTreeByKeyWord(SysDepartController)', 'Calls', 'list(SysUserServiceImpl)'] skipped
# INFO: Edge ['getDepartName(SysDepartController)', 'Calls', 'getOne(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryByIds(SysDepartController)', 'Calls', 'listByIds(SysDepartServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysCategoryController)', 'Calls', 'list(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['edit(SysCategoryController)', 'Calls', 'getById(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['delete(SysCategoryController)', 'Calls', 'getById(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysCategoryController)', 'Calls', 'equals(SysCategoryController)'] skipped
# INFO: Edge ['queryById(SysCategoryController)', 'Calls', 'getById(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['exportXls(SysCategoryController)', 'Calls', 'list(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['importExcel(SysCategoryController)', 'Calls', 'save(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['importExcel(SysCategoryController)', 'Calls', 'getById(SysCategoryServiceImpl)'] skipped
# INFO: Edge ['importExcel(SysCategoryController)', 'Calls', 'updateById(SysCategoryServiceImpl)'] skipped
# ...
# INFO: Edge ['queryById(SysTenantController)', 'Calls', 'getById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['queryList(SysTenantController)', 'Calls', 'list(SysTenantServiceImpl)'] skipped
# INFO: Edge ['queryPackPageList(SysTenantController)', 'Calls', 'page(SysTenantPackServiceImpl)'] skipped
# INFO: Edge ['leaveTenant(SysTenantController)', 'Calls', 'equals(SysTenantController)'] skipped
# INFO: Edge ['editOwnTenant(SysTenantController)', 'Calls', 'getById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['editOwnTenant(SysTenantController)', 'Calls', 'updateById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['cancelTenant(SysTenantController)', 'Calls', 'getById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['cancelTenant(SysTenantController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['cancelTenant(SysTenantController)', 'Calls', 'removeById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['getTenantStatusCount(SysTenantController)', 'Calls', 'count(SysUserTenantServiceImpl)'] skipped
# INFO: Edge ['exitUserTenant(SysTenantController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['updateApplyStatus(SysTenantController)', 'Calls', 'getById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['updateApplyStatus(SysTenantController)', 'Calls', 'updateById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['getTenantCount(SysTenantController)', 'Calls', 'count(SysDepartServiceImpl)'] skipped
# INFO: Edge ['agreeOrRefuseJoinTenant(SysTenantController)', 'Calls', 'getById(SysTenantServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysFillRuleController)', 'Calls', 'page(SysFillRuleServiceImpl)'] skipped
# INFO: Edge ['add(SysFillRuleController)', 'Calls', 'save(SysFillRuleServiceImpl)'] skipped
# INFO: Edge ['edit(SysFillRuleController)', 'Calls', 'updateById(SysFillRuleServiceImpl)'] skipped
# INFO: Edge ['delete(SysFillRuleController)', 'Calls', 'removeById(SysFillRuleServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysFillRuleController)', 'Calls', 'removeByIds(SysFillRuleServiceImpl)'] skipped
# INFO: Edge ['queryById(SysFillRuleController)', 'Calls', 'getById(SysFillRuleServiceImpl)'] skipped
# INFO: Edge ['list(SysUserOnlineController)', 'Calls', 'equals(SysUserOnlineController)'] skipped
# INFO: Edge ['queryPageList(SysTableWhiteListController)', 'Calls', 'page(SysTableWhiteListServiceImpl)'] skipped
# INFO: Edge ['queryById(SysTableWhiteListController)', 'Calls', 'getById(SysTableWhiteListServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysDictItemController)', 'Calls', 'page(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['add(SysDictItemController)', 'Calls', 'save(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['edit(SysDictItemController)', 'Calls', 'getById(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['edit(SysDictItemController)', 'Calls', 'updateById(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['delete(SysDictItemController)', 'Calls', 'getById(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['delete(SysDictItemController)', 'Calls', 'removeById(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysDictItemController)', 'Calls', 'equals(SysDictItemController)'] skipped
# INFO: Edge ['deleteBatch(SysDictItemController)', 'Calls', 'removeByIds(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['doDictItemCheck(SysDictItemController)', 'Calls', 'count(SysDictItemServiceImpl)'] skipped
# INFO: Edge ['loginThird(ThirdLoginController)', 'Calls', 'list(SysThirdAccountServiceImpl)'] skipped
# INFO: Edge ['loginThird(ThirdLoginController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['thirdUserCreate(ThirdLoginController)', 'Calls', 'getById(SysUserServiceImpl)'] skipped
# INFO: Edge ['checkPassword(ThirdLoginController)', 'Calls', 'updateById(SysUserServiceImpl)'] skipped
# INFO: Edge ['getThirdLoginUser(ThirdLoginController)', 'Calls', 'list(SysThirdAccountServiceImpl)'] skipped
# INFO: Edge ['sendMessage(PushMsgUtil)', 'Calls', 'save(SysMessageServiceImpl)'] skipped
# INFO: Edge ['sendEmailMessage(EmailSendMsgHandle)', 'Calls', 'in(EmailSendMsgHandle)'] skipped
# INFO: Edge ['sendMessageToCopyUser(EmailSendMsgHandle)', 'Calls', 'in(EmailSendMsgHandle)'] skipped
# INFO: Edge ['queryPageList(SysMessageController)', 'Calls', 'page(SysMessageServiceImpl)'] skipped
# INFO: Edge ['add(SysMessageController)', 'Calls', 'save(SysMessageServiceImpl)'] skipped
# INFO: Edge ['edit(SysMessageController)', 'Calls', 'updateById(SysMessageServiceImpl)'] skipped
# INFO: Edge ['delete(SysMessageController)', 'Calls', 'removeById(SysMessageServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysMessageController)', 'Calls', 'removeByIds(SysMessageServiceImpl)'] skipped
# INFO: Edge ['queryById(SysMessageController)', 'Calls', 'getById(SysMessageServiceImpl)'] skipped
# INFO: Edge ['queryPageList(SysMessageTemplateController)', 'Calls', 'page(SysMessageTemplateServiceImpl)'] skipped
# INFO: Edge ['add(SysMessageTemplateController)', 'Calls', 'save(SysMessageTemplateServiceImpl)'] skipped
# INFO: Edge ['edit(SysMessageTemplateController)', 'Calls', 'updateById(SysMessageTemplateServiceImpl)'] skipped
# INFO: Edge ['delete(SysMessageTemplateController)', 'Calls', 'removeById(SysMessageTemplateServiceImpl)'] skipped
# INFO: Edge ['deleteBatch(SysMessageTemplateController)', 'Calls', 'removeByIds(SysMessageTemplateServiceImpl)'] skipped
# INFO: Edge ['queryById(SysMessageTemplateController)', 'Calls', 'getById(SysMessageTemplateServiceImpl)'] skipped
# INFO: Edge ['sendMessage(SysMessageTemplateController)', 'Calls', 'sendTemplateMessage(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['onMessage(WebSocket)', 'Calls', 'equals(WebSocket)'] skipped
# INFO: Edge ['getManyDictItems(JimuDragExternalServiceImpl)', 'Calls', 'getManyDictItems(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['getManyDictItems(JimuDragExternalServiceImpl)', 'Calls', 'queryTableDictItemsByCode(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['getDictItems(JimuDragExternalServiceImpl)', 'Calls', 'getDictItems(SysBaseAPIFallbackFactory)'] skipped
# INFO: Edge ['queryPageList(AiragKnowledgeController)', 'Calls', 'page(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['add(AiragKnowledgeController)', 'Calls', 'save(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['edit(AiragKnowledgeController)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['edit(AiragKnowledgeController)', 'Calls', 'updateById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['delete(AiragKnowledgeController)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['delete(AiragKnowledgeController)', 'Calls', 'removeById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['queryById(AiragKnowledgeController)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['queryDocumentPageList(AiragKnowledgeController)', 'Calls', 'page(AiragKnowledgeDocServiceImpl)'] skipped
# INFO: Edge ['deleteDocumentBatch(AiragKnowledgeController)', 'Calls', 'listByIds(AiragKnowledgeDocServiceImpl)'] skipped
# INFO: Edge ['deleteDocumentAll(AiragKnowledgeController)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['queryBatchByIds(AiragKnowledgeController)', 'Calls', 'listByIds(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['queryPageList(AiragModelController)', 'Calls', 'page(AiragModelServiceImpl)'] skipped
# INFO: Edge ['add(AiragModelController)', 'Calls', 'save(AiragModelServiceImpl)'] skipped
# INFO: Edge ['edit(AiragModelController)', 'Calls', 'updateById(AiragModelServiceImpl)'] skipped
# INFO: Edge ['delete(AiragModelController)', 'Calls', 'getById(AiragModelServiceImpl)'] skipped
# INFO: Edge ['delete(AiragModelController)', 'Calls', 'removeById(AiragModelServiceImpl)'] skipped
# INFO: Edge ['queryById(AiragModelController)', 'Calls', 'getById(AiragModelServiceImpl)'] skipped
# INFO: Edge ['embeddingDocument(EmbeddingHandler)', 'Calls', 'getById(AiragKnowledgeServiceImpl)'] skipped
# INFO: Edge ['embeddingDocument(EmbeddingHandler)', 'Calls', 'isEnableMinerU(KnowConfigBean)'] skipped
# INFO: Edge ['embeddingDocument(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] skipped
# INFO: Edge ['deleteEmbedDocsByKnowId(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] skipped
# INFO: Edge ['deleteEmbedDocsByDocIds(EmbeddingHandler)', 'Calls', 'metadataKey(EmbeddingHandler)'] skipped
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getHost(EmbedStoreConfigBean)'] skipped
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getPort(EmbedStoreConfigBean)'] skipped
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getDatabase(EmbedStoreConfigBean)'] skipped
# INFO: Edge ['getEmbedStore(EmbeddingHandler)', 'Calls', 'getTable(EmbedStoreConfigBean)'] skipped
# INFO: Edge ['parseFile(EmbeddingHandler)', 'Calls', 'parse(EmbeddingHandler)'] skipped
# INFO: Edge ['parseFile(EmbeddingHandler)', 'Calls', 'contains(EmbeddingHandler)'] skipped
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'equalsIgnoreCase(EmbeddingHandler)'] skipped
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'equalsIgnoreCase(EmbeddingHandler)'] skipped
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'getCondaEnv(KnowConfigBean)'] skipped
# INFO: Edge ['parseFileByMinerU(EmbeddingHandler)', 'Calls', 'getCondaEnv(KnowConfigBean)'] skipped
# INFO: Edge ['generatePrompt(AiragAppServiceImpl)', 'Calls', 'equals(AiragAppServiceImpl)'] skipped
# INFO: Edge ['generatePrompt(AiragAppServiceImpl)', 'Calls', 'equals(AiragAppServiceImpl)'] skipped
# INFO: Edge ['sendWithDefault(AiragChatServiceImpl)', 'Calls', 'equals(AiragChatServiceImpl)'] skipped
# INFO: Edge ['sendWithDefault(AiragChatServiceImpl)', 'Calls', 'equals(AiragChatServiceImpl)'] skipped
# INFO: Edge ['queryPageList(AiragAppController)', 'Calls', 'page(AiragAppServiceImpl)'] skipped
# INFO: Edge ['edit(AiragAppController)', 'Calls', 'saveOrUpdate(AiragAppServiceImpl)'] skipped
# INFO: Edge ['release(AiragAppController)', 'Calls', 'updateById(AiragAppServiceImpl)'] skipped
# INFO: Edge ['delete(AiragAppController)', 'Calls', 'getById(AiragAppServiceImpl)'] skipped
# INFO: Edge ['delete(AiragAppController)', 'Calls', 'removeById(AiragAppServiceImpl)'] skipped
# INFO: Edge ['queryById(AiragAppController)', 'Calls', 'getById(AiragAppServiceImpl)'] skipped
# INFO: Edge ['readJsonData(DlMockController)', 'Calls', 'getClass(DlMockController)'] skipped
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] skipped
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] skipped
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getFreeSpace(MockController)'] skipped
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getFreeSpace(MockController)'] skipped
# INFO: Edge ['queryDiskInfo(MockController)', 'Calls', 'getTotalSpace(MockController)'] skipped
# INFO: Edge ['readJson(MockController)', 'Calls', 'getClass(MockController)'] skipped
# INFO: Edge ['readJsonData(VxeMockController)', 'Calls', 'getClass(VxeMockController)'] skipped
# INFO: Edge ['getUserPool(VxeSocket)', 'Calls', 'computeIfAbsent(VxeSocket)'] skipped
# INFO: Edge ['sendMessageToAll(VxeSocket)', 'Calls', 'values(VxeSocket)'] skipped
# INFO: Edge ['onOpen(VxeSocket)', 'Calls', 'put(VxeSocket)'] skipped
# INFO: Edge ['onOpen(VxeSocket)', 'Calls', 'size(VxeSocket)'] skipped
# INFO: Edge ['onClose(VxeSocket)', 'Calls', 'remove(VxeSocket)'] skipped
# INFO: Edge ['onClose(VxeSocket)', 'Calls', 'size(VxeSocket)'] skipped
# INFO: Edge ['doGetAuthenticationInfo(ShiroRealm)', 'Calls', 'getName(ShiroRealm)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['intercept(MybatisInterceptor)', 'Calls', 'equals(MybatisInterceptor)'] skipped
# INFO: Edge ['preHandle(LowCodeModeInterceptor)', 'Calls', 'equals(LowCodeModeInterceptor)'] skipped
# INFO: Edge ['translateDictValue(DictAspect)', 'Calls', 'equals(DictAspect)'] skipped
# INFO: Edge ['getOnlineLogContent(AutoLogAspect)', 'Calls', 'isInstance(AutoLogAspect)'] skipped
# INFO: Edge ['getBaseUrl(JeecgElasticsearchTemplate)', 'Calls', 'append(JeecgElasticsearchTemplate)'] skipped
# INFO: Edge ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped
# INFO: Edge ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped
# INFO: Edge ['saveOrUpdate(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped
# INFO: Edge ['delete(JeecgElasticsearchTemplate)', 'Calls', 'equals(JeecgElasticsearchTemplate)'] skipped
# INFO: Edge ['filter(GlobalAccessTokenFilter)', 'Calls', 'addOriginalRequestUrl(GlobalAccessTokenFilter)'] skipped
# INFO: Edge ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] skipped
# INFO: Edge ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] skipped
# INFO: Edge ['checkRoute(MySwaggerResourceProvider)', 'Calls', 'equals(MySwaggerResourceProvider)'] skipped
# INFO: Edge ['getRules(ParamFlowRuleNacosProvider)', 'Calls', 'convert(ParamFlowRuleCorrectEntity)'] skipped
# INFO: Edge ['publish(ParamFlowRuleNacosPublisher)', 'Calls', 'convert(ParamFlowRuleCorrectEntity)'] skipped
# INFO: Edge ['getRules(AuthorityRuleNacosProvider)', 'Calls', 'convert(AuthorityRuleCorrectEntity)'] skipped
# INFO: Edge ['publish(AuthorityRuleNacosPublisher)', 'Calls', 'convert(AuthorityRuleCorrectEntity)'] skipped
# INFO: Edge ['publishRules(DegradeController)', 'Calls', 'delayTime(DegradeController)'] skipped
# INFO: Edge ['countNotNullAndNotNegative(SystemController)', 'Calls', 'doubleValue(SystemController)'] skipped
# INFO: Edge ['publishRules(SystemController)', 'Calls', 'delayTime(SystemController)'] skipped
# INFO: Edge ['publishRules(ParamFlowRuleController)', 'Calls', 'delayTime(ParamFlowRuleController)'] skipped
# INFO: Edge ['publishRules(AuthorityRuleController)', 'Calls', 'delayTime(AuthorityRuleController)'] skipped
# INFO: Edge ['publishApis(GatewayApiController)', 'Calls', 'delayTime(GatewayApiController)'] skipped
# INFO: Edge ['publishRules(GatewayFlowRuleController)', 'Calls', 'delayTime(GatewayFlowRuleController)'] skipped
# INFO: Edge ['publishRules(FlowControllerV2)', 'Calls', 'delayTime(FlowControllerV2)'] skipped
# INFO: Edge ['afterPropertiesSet(XxlJobAdminConfig)', 'Calls', 'init(XxlJobScheduler)'] skipped
# INFO: Edge ['destroy(XxlJobAdminConfig)', 'Calls', 'destroy(XxlJobScheduler)'] skipped
# INFO: Edge ['alarm(JobAlarmer)', 'Calls', 'size(EmailJobAlarm)'] skipped
# INFO: Edge ['loginDo(IndexController)', 'Calls', 'equals(IndexController)'] skipped
# INFO: Edge ['api(JobApiController)', 'Calls', 'equalsIgnoreCase(JobApiController)'] skipped
# INFO: Edge ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] skipped
# INFO: Edge ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] skipped
# INFO: Edge ['api(JobApiController)', 'Calls', 'equals(JobApiController)'] skipped
# INFO: Edge ['postHandle(CookieInterceptor)', 'Calls', 'getName(CookieInterceptor)'] skipped
# INFO: Added edge ['add(CustomInMemoryHttpTraceRepository)', 'Calls', 'equals(CustomInMemoryHttpTraceRepository)']
# INFO: Added edge ['sort(CustomInMemoryHttpTraceRepository)', 'Calls', 'equalsIgnoreCase(CustomInMemoryHttpTraceRepository)']
# INFO: Added edge ['sort(CustomInMemoryHttpTraceRepository)', 'Calls', 'equalsIgnoreCase(CustomInMemoryHttpTraceRepository)']
# INFO: Added edge ['sort(CustomInMemoryHttpTraceRepository)', 'Calls', 'equalsIgnoreCase(CustomInMemoryHttpTraceRepository)']

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity JeecgOneToMainUtil
# Removed Entity JeecgOneGUI
# Removed Entity RedisConnectException
# Removed Entity AsyncJob
# Removed Entity SampleJob
# Removed Entity SampleParamJob
# Removed Entity SwaggerSchema
# Removed Entity ApiAuthFilter
# Removed Entity PathGenerator
# Removed Entity AKSKGenerator
# Removed Entity AuthStateRedisCache
# Removed Entity PermissionDataUtil
# Removed Entity ImportOldUserUtil
# Removed Entity RandImageUtil
# Removed Entity XssUtils
# Removed Entity FindsDepartsChildrenUtil
# Removed Entity SecurityUtil
# Removed Entity OrgCodeRule
# Removed Entity OrderNumberRule
# Removed Entity CategoryCodeRule
# Removed Entity CasServiceUtil
# Removed Entity XmlUtils
# Removed Entity WxSendMsgHandle
# Removed Entity SmsSendMsgHandle
# Removed Entity SendMsgJob
# Removed Entity CommandExecUtil
# Removed Entity LLMConsts
# Removed Entity Prompts
# Removed Entity AiAppConsts
# Removed Entity MockEntity
# Removed Entity DruidWallConfigRegister
# Removed Entity JeecgCloudCondition
# Removed Entity CorsFilterCondition
# Removed Entity SignUtil
# Removed Entity BodyReaderHttpServletRequestWrapper
# Removed Entity HttpUtils
# Removed Entity SignAuthInterceptor
# Removed Entity WebsocketFilter
# Removed Entity RequestBodyReserveFilter
# Removed Entity InMemoryIgnoreAuth
# Removed Entity ResourceCheckFilter
# Removed Entity JwtFilter
# Removed Entity CustomShiroFilterFactoryBean
# Removed Entity ThreadLocalDataHelper
# Removed Entity DynamicDatasourceInterceptor
# Removed Entity SysDictTableWhite
# Removed Entity ImportExcelUtil
# Removed Entity PasswordUtil
# Removed Entity DateUtils
# Removed Entity BrowserUtils
# Removed Entity Md5Util
# Removed Entity DySmsHelper
# Removed Entity DateRangeUtils
# Removed Entity FileDownloadUtils
# Removed Entity HTMLUtils
# Removed Entity TokenUtils
# Removed Entity RestDesformUtil
# Removed Entity YouBianCodeUtil
# Removed Entity IpUtils
# Removed Entity UUIDGenerator
# Removed Entity AssertUtils
# Removed Entity SqlInjectionUtil
# Removed Entity CommonUtils
# Removed Entity FillRuleUtil
# Removed Entity oConvertUtils
# Removed Entity ReflectHelper
# Removed Entity DySmsLimit
# Removed Entity MinioUtil
# Removed Entity MyClassLoader
# Removed Entity RestUtil
# Removed Entity AbstractQueryBlackListHandler
# Removed Entity JdbcSecurityUtil
# Removed Entity SecurityTools
# Removed Entity SecurityReq
# Removed Entity SecurityResp
# Removed Entity SecuritySignResp
# Removed Entity MyKeyPair
# Removed Entity SecuritySignReq
# Removed Entity StrAttackFilter
# Removed Entity SsrfFileTypeFilter
# Removed Entity OssBootUtil
# Removed Entity FreemarkerParseFactory
# Removed Entity DataSourceCachePool
# Removed Entity DynamicDBUtil
# Removed Entity DbTypeUtils
# Removed Entity EncryptedString
# Removed Entity AesEncryptUtil
# Removed Entity QueryStringBuilder
# Removed Entity VxeSocketConst
# Removed Entity DynamicTableConstant
# Removed Entity WebsocketConst
# Removed Entity SymbolConstant
# Removed Entity FillRuleConstant
# Removed Entity SensitiveSerialize
# Removed Entity SensitiveInfoUtil
# Removed Entity FileDownDTO
# Removed Entity FileUploadDTO
# Removed Entity SqlConcatUtil
# Removed Entity JeecgDataAutorUtils
# Removed Entity JwtUtil
# Removed Entity QueryGenerator
# Removed Entity JeecgServiceImpl
# Removed Entity JeecgController
# Removed Entity JeecgBoot401Exception
# Removed Entity JeecgBootExceptionHandler
# Removed Entity JeecgSqlInjectionException
# Removed Entity GatewayRouteVo
# Removed Entity SentinelConStants
# Removed Entity BaseRuleController
# Removed Entity JacksonUtil
# Removed Entity LocalCacheUtil
# Removed Entity FtlUtil
# Removed Entity CookieUtil
# Removed Entity CronExpression
# Removed Entity ValueSet
# Removed Entity XxlJobTrigger
# Removed Entity XxlJobCompleter
# Removed getRedisInfo (ActuatorMemoryController)
# Removed queryDiskInfo (ActuatorRedisController)
# Removed wrap (CustomUndertowMetricsHandler)
# Removed tenantLogPointCut (TenantPackUserLogAspect)
# Removed afterThrowing (TenantPackUserLogAspect)
# Removed index (OpenApiIndexController)
# Removed getOpenApi (OpenApiPermissionController)
# Removed delete (OpenApiLogController)
# Removed deleteBatch (OpenApiLogController)
# Removed delete (OpenApiController)
# Removed deleteBatch (OpenApiController)
# Removed getToken (OpenApiController)
# Removed genPath (OpenApiController)
# Removed delete (OpenApiAuthController)
# Removed deleteBatch (OpenApiAuthController)
# Removed genAKSK (OpenApiAuthController)
# Removed handleSQLException (SystemApiController)
# Removed getMinLengthNode (SysDepartServiceImpl)
# Removed queryAllParentId (SysDepartServiceImpl)
# Removed updateIzLeaf (SysDepartServiceImpl)
# Removed doUpload (ImportFileServiceImpl)
# Removed removeDynamicDataSource (SysDataSourceServiceImpl)
# Removed countCreateTenantNum (SysTenantServiceImpl)
# Removed tenantIdGenerate (SysTenantServiceImpl)
# Removed deleteTenantPackByTenantId (SysTenantServiceImpl)
# Removed getDatabaseTypeByDataSource (SysBaseApiImpl)
# Removed getRole (SysUserServiceImpl)
# Removed updateNullPhoneEmail (SysUserServiceImpl)
# Removed exitTenant (SysTenantPackServiceImpl)
# Removed getNotSendedAnnouncementlist (SysAnnouncementServiceImpl)
# Removed queryTreeChildIds (SysCategoryServiceImpl)
# Removed getUserIdByThirdCode (ThirdAppWechatEnterpriseServiceImpl)
# Removed getUserByUserTicket (ThirdAppWechatEnterpriseServiceImpl)
# Removed queryPermissionUrlWithStar (SysPermissionServiceImpl)
# Removed generateUserId (SysUserController)
# Removed getEncryptedString (LoginController)
# Removed getLoginQrcode (LoginController)
# Removed scanLoginQrcode (LoginController)
# Removed mpVerify (WechatVerifyController)
# Removed delete (SysDepartPermissionController)
# Removed deleteBatch (SysDepartPermissionController)
# Removed handleFirstLevelMenuHidden (SysPermissionController)
# Removed handleSQLException (SysDictController)
# Removed noauth (CommonController)
# Removed uploadLocal (CommonController)
# Removed pdfPreviewIframe (CommonController)
# Removed delete (SysDepartRoleController)
# Removed delete (SysRoleIndexController)
# Removed getCurrentHome (SysRoleIndexController)
# Removed delete (SysFormFileController)
# Removed deleteBatch (SysFormFileController)
# Removed getFileViewDomain (SysCommentController)
# Removed delete (SysCommentController)
# Removed deleteBatch (SysCommentController)
# Removed delete (SysFillRuleController)
# Removed deleteBatch (SysFillRuleController)
# Removed render (ThirdLoginController)
# Removed isTimeJobSendEmail (EmailSendMsgHandle)
# Removed delete (SysMessageController)
# Removed deleteBatch (SysMessageController)
# Removed delete (SysMessageTemplateController)
# Removed deleteBatch (SysMessageTemplateController)
# Removed setJeecgRedisClient (WebSocket)
# Removed onOpen (WebSocket)
# Removed onClose (WebSocket)
# Removed onMessage (WebSocket)
# Removed onError (WebSocket)
# Removed run (ShiroCacheClearRunner)
# Removed getOrder (SystemInitListener)
# Removed onApplicationEvent (CodeTemplateInitListener)
# Removed initJarConfigCodeGeneratorTemplate (CodeTemplateInitListener)
# Removed getToken (JimuReportTokenService)
# Removed getUsername (JimuReportTokenService)
# Removed verifyToken (JimuReportTokenService)
# Removed importDocumentTaskList (AiragKnowledgeController)
# Removed process (TestAiragEnhance)
# Removed closeSSE (AiragAppServiceImpl)
# Removed upload (AiragChatController)
# Removed mockChange (DlMockController)
# Removed queryDataPage (DlMockController)
# Removed enhanceJavaHttp (OnlCgformDemoController)
# Removed queryDiskInfo (MockController)
# Removed mockChange (VxeMockController)
# Removed queryDataPage (VxeMockController)
# Removed sendMessage (VxeSocket)
# Removed packageMessage (VxeSocket)
# Removed sendMessageTo (VxeSocket)
# Removed sendMessageToAll (VxeSocket)
# Removed onMessage (VxeSocket)
# Removed handleUpdateForm (VxeSocket)
# Removed getCustomResourcePrefixPath (JeecgBaseConfig)
# Removed setCustomResourcePrefixPath (JeecgBaseConfig)
# Removed setSignatureSecret (JeecgBaseConfig)
# Removed getSignUrls (JeecgBaseConfig)
# Removed setSignUrls (JeecgBaseConfig)
# Removed getFileViewDomain (JeecgBaseConfig)
# Removed setFileViewDomain (JeecgBaseConfig)
# Removed getUploadType (JeecgBaseConfig)
# Removed setUploadType (JeecgBaseConfig)
# Removed plugin (MybatisInterceptor)
# Removed setProperties (MybatisInterceptor)
# Removed dynamicTable (DynamicTableAspect)
# Removed around (DynamicTableAspect)
# Removed returnErrorMessage (LowCodeModeInterceptor)
# Removed excudeService (DictAspect)
# Removed doAround (DictAspect)
# Removed listAddAllDeduplicate (DictAspect)
# Removed translateDictValue (DictAspect)
# Removed logPointCut (AutoLogAspect)
# Removed pointCut (PermissionDataAspect)
# Removed moHuContain (PermissionDataAspect)
# Removed setUploadPath (PmsUtil)
# Removed saveErrorTxtByList (PmsUtil)
# Removed setApplicationContext (SpringContextUtils)
# Removed getHttpServletResponse (SpringContextUtils)
# Removed getElasticsearchVersion (JeecgElasticsearchTemplate)
# Removed getBaseUrl (JeecgElasticsearchTemplate)
# Removed getDataById (JeecgElasticsearchTemplate)
# Removed createIndex (JeecgElasticsearchTemplate)
# Removed removeIndex (JeecgElasticsearchTemplate)
# Removed getIndexMapping (JeecgElasticsearchTemplate)
# Removed getIndexMappingFormat (JeecgElasticsearchTemplate)
# Removed save (JeecgElasticsearchTemplate)
# Removed update (JeecgElasticsearchTemplate)
# Removed saveOrUpdate (JeecgElasticsearchTemplate)
# Removed saveBatch (JeecgElasticsearchTemplate)
# Removed delete (JeecgElasticsearchTemplate)
# Removed search (JeecgElasticsearchTemplate)
# Removed buildQuery (JeecgElasticsearchTemplate)
# Removed buildBoolQuery (JeecgElasticsearchTemplate)
# Removed buildQueryString (JeecgElasticsearchTemplate)
# Removed buildRangeQuery (JeecgElasticsearchTemplate)
# Removed initAreaList (ProvinceCityArea)
# Removed jsonRead (ProvinceCityArea)
# Removed sensitivePointCut (SensitiveDataAspect)
# Removed around (SensitiveDataAspect)
# Removed filter (GlobalAccessTokenFilter)
# Removed getOrder (GlobalAccessTokenFilter)
# Removed setApplicationEventPublisher (DynamicRouteLoader)
# Removed getRouteDefinitions (MyInMemoryRouteDefinitionRepository)
# Removed setApplicationEventPublisher (DynamicRouteService)
# Removed securityConfiguration (SwaggerResourceController)
# Removed uiConfiguration (SwaggerResourceController)
# Removed checkRoute (MySwaggerResourceProvider)
# Removed getServerAddr (NacosConfigProperties)
# Removed getRules (GateWayApiNacosProvider)
# Removed publish (GateWayFlowRulesNacosPublisher)
# Removed publish (GateWayApiNacosPublisher)
# Removed getRules (GateWayFlowRulesNacosProvider)
# Removed getRules (DegradeRuleNacosProvider)
# Removed publish (DegradeRuleNacosPublisher)
# Removed getRules (SystemRuleNacosProvider)
# Removed publish (SystemRuleNacosPublisher)
# Removed getRules (FlowRuleNacosProvider)
# Removed publish (FlowRuleNacosPublisher)
# Removed apiQueryMachineRules (DegradeController)
# Removed apiQueryAllRulesForMachine (AuthorityRuleController)
# Removed queryApis (GatewayApiController)
# Removed queryFlowRules (GatewayFlowRuleController)
# Removed apiQueryMachineRules (FlowControllerV2)
# Removed callback (AdminBizImpl)
# Removed registry (AdminBizImpl)
# Removed registryRemove (AdminBizImpl)
# Removed getAdminConfig (XxlJobAdminConfig)
# Removed destroy (XxlJobAdminConfig)
# Removed getI18n (XxlJobAdminConfig)
# Removed getAccessToken (XxlJobAdminConfig)
# Removed getEmailFrom (XxlJobAdminConfig)
# Removed getTriggerPoolFastMax (XxlJobAdminConfig)
# Removed getTriggerPoolSlowMax (XxlJobAdminConfig)
# Removed getLogretentiondays (XxlJobAdminConfig)
# Removed getXxlJobLogDao (XxlJobAdminConfig)
# Removed getXxlJobInfoDao (XxlJobAdminConfig)
# Removed getXxlJobRegistryDao (XxlJobAdminConfig)
# Removed getXxlJobGroupDao (XxlJobAdminConfig)
# Removed getXxlJobLogReportDao (XxlJobAdminConfig)
# Removed getMailSender (XxlJobAdminConfig)
# Removed getDataSource (XxlJobAdminConfig)
# Removed getJobAlarmer (XxlJobAdminConfig)
# Removed setApplicationContext (JobAlarmer)
# Removed afterPropertiesSet (JobAlarmer)
# Removed index (JobGroupController)
# Removed toLogin (IndexController)
# Removed loginDo (IndexController)
# Removed logout (IndexController)
# Removed help (IndexController)
# Removed initBinder (IndexController)
# Removed clearLog (JobLogController)
# Removed api (JobApiController)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
