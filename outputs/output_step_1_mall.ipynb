# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'shopizer-2x' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "mall"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# Entity		DynamicSecurityMetadataSource		com.macro.mall.security.component
# Entity		DynamicSecurityFilter		com.macro.mall.security.component
# Entity		RestfulAccessDeniedHandler		com.macro.mall.security.component
# Entity		JwtAuthenticationTokenFilter		com.macro.mall.security.component
# Entity		RestAuthenticationEntryPoint		com.macro.mall.security.component
# Interface	DynamicSecurityService		com.macro.mall.security.component
# Entity		DynamicAccessDecisionManager		com.macro.mall.security.component
# Logic		RedisCacheAspect		com.macro.mall.security.aspect
# Logic		SpringUtil		com.macro.mall.security.util
# Entity		JwtTokenUtil		com.macro.mall.security.util
# Excluded	SecurityConfig		com.macro.mall.security.config
# Excluded	RedisConfig		com.macro.mall.security.config
# Excluded	CommonSecurityConfig		com.macro.mall.security.config
# Entity		IgnoreUrlsConfig		com.macro.mall.security.config
# Interface	RedisService		com.macro.mall.common.service
# Entity		RedisServiceImpl		com.macro.mall.common.service.impl
# Entity		RequestUtil		com.macro.mall.common.util
# Entity		SwaggerProperties		com.macro.mall.common.domain
# Entity		WebLog		com.macro.mall.common.domain
# Logic		WebLogAspect		com.macro.mall.common.log
# Entity		BaseRedisConfig		com.macro.mall.common.config
# Entity		BaseSwaggerConfig		com.macro.mall.common.config
# Entity		CommonPage		com.macro.mall.common.api
# Interface	IErrorCode		com.macro.mall.common.api
# Entity		CommonResult		com.macro.mall.common.api
# Entity		ApiException		com.macro.mall.common.exception
# Entity		Asserts		com.macro.mall.common.exception
# Excluded	GlobalExceptionHandler		com.macro.mall.common.exception
# Entity		Generator		com.macro.mall
# Entity		CommentGenerator		com.macro.mall
# Entity		SmsHomeRecommendProduct		com.macro.mall.model
# Entity		CmsSubject		com.macro.mall.model
# Entity		OmsOrderReturnReason		com.macro.mall.model
# Entity		PmsAlbumPic		com.macro.mall.model
# Entity		CmsMemberReportExample		com.macro.mall.model
# Entity		UmsRolePermissionRelationExample		com.macro.mall.model
# Entity		CmsHelpExample		com.macro.mall.model
# Entity		UmsResource		com.macro.mall.model
# Entity		OmsOrderSetting		com.macro.mall.model
# Entity		CmsSubjectCategory		com.macro.mall.model
# Entity		UmsMemberTaskExample		com.macro.mall.model
# Entity		OmsOrderReturnReasonExample		com.macro.mall.model
# Entity		SmsCouponProductRelationExample		com.macro.mall.model
# Entity		UmsMemberTagExample		com.macro.mall.model
# Entity		SmsCouponProductCategoryRelationExample		com.macro.mall.model
# Entity		PmsProductCategory		com.macro.mall.model
# Entity		UmsMemberLoginLog		com.macro.mall.model
# Entity		SmsHomeNewProduct		com.macro.mall.model
# Entity		PmsAlbumExample		com.macro.mall.model
# Entity		PmsAlbum		com.macro.mall.model
# Entity		SmsHomeRecommendSubjectExample		com.macro.mall.model
# Entity		SmsFlashPromotionProductRelationExample		com.macro.mall.model
# Entity		UmsMemberExample		com.macro.mall.model
# Entity		UmsMember		com.macro.mall.model
# Entity		CmsPrefrenceArea		com.macro.mall.model
# Entity		UmsMemberProductCategoryRelation		com.macro.mall.model
# Entity		PmsMemberPriceExample		com.macro.mall.model
# Entity		SmsHomeAdvertiseExample		com.macro.mall.model
# Entity		UmsMemberRuleSettingExample		com.macro.mall.model
# Entity		OmsOrderReturnApply		com.macro.mall.model
# Entity		SmsFlashPromotionLogExample		com.macro.mall.model
# Entity		UmsRole		com.macro.mall.model
# Entity		OmsOrderReturnApplyExample		com.macro.mall.model
# Entity		SmsCouponProductCategoryRelation		com.macro.mall.model
# Entity		UmsGrowthChangeHistory		com.macro.mall.model
# Entity		SmsCoupon		com.macro.mall.model
# Entity		UmsMemberReceiveAddress		com.macro.mall.model
# Entity		UmsMemberLoginLogExample		com.macro.mall.model
# Entity		UmsIntegrationChangeHistoryExample		com.macro.mall.model
# Entity		PmsMemberPrice		com.macro.mall.model
# Entity		CmsHelp		com.macro.mall.model
# Entity		UmsMemberLevelExample		com.macro.mall.model
# Entity		CmsTopicCategory		com.macro.mall.model
# Entity		CmsTopicExample		com.macro.mall.model
# Entity		CmsTopic		com.macro.mall.model
# Entity		PmsProductAttributeCategory		com.macro.mall.model
# Entity		CmsPrefrenceAreaProductRelation		com.macro.mall.model
# Entity		CmsTopicCommentExample		com.macro.mall.model
# Entity		CmsSubjectProductRelationExample		com.macro.mall.model
# Entity		UmsResourceCategoryExample		com.macro.mall.model
# Entity		UmsAdminPermissionRelation		com.macro.mall.model
# Entity		SmsCouponHistory		com.macro.mall.model
# Entity		UmsAdminRoleRelation		com.macro.mall.model
# Entity		PmsProductAttributeCategoryExample		com.macro.mall.model
# Entity		UmsRolePermissionRelation		com.macro.mall.model
# Entity		CmsHelpCategoryExample		com.macro.mall.model
# Entity		PmsFeightTemplateExample		com.macro.mall.model
# Entity		PmsSkuStockExample		com.macro.mall.model
# Entity		UmsAdminLoginLog		com.macro.mall.model
# Entity		UmsRoleMenuRelation		com.macro.mall.model
# Entity		UmsAdminLoginLogExample		com.macro.mall.model
# Entity		CmsSubjectCommentExample		com.macro.mall.model
# Entity		CmsTopicCategoryExample		com.macro.mall.model
# Entity		UmsMemberLevel		com.macro.mall.model
# Entity		UmsAdminPermissionRelationExample		com.macro.mall.model
# Entity		PmsProductCategoryAttributeRelation		com.macro.mall.model
# Entity		OmsOrderOperateHistory		com.macro.mall.model
# Entity		UmsRoleMenuRelationExample		com.macro.mall.model
# Entity		OmsOrder		com.macro.mall.model
# Entity		SmsHomeNewProductExample		com.macro.mall.model
# Entity		OmsOrderItemExample		com.macro.mall.model
# Entity		UmsMemberTag		com.macro.mall.model
# Entity		UmsMemberReceiveAddressExample		com.macro.mall.model
# Entity		PmsProductCategoryExample		com.macro.mall.model
# Entity		PmsProductExample		com.macro.mall.model
# Entity		UmsAdmin		com.macro.mall.model
# Entity		OmsCartItem		com.macro.mall.model
# Entity		UmsMemberStatisticsInfo		com.macro.mall.model
# Entity		OmsOrderItem		com.macro.mall.model
# Entity		PmsProductVertifyRecordExample		com.macro.mall.model
# Entity		CmsTopicComment		com.macro.mall.model
# Entity		PmsProductAttribute		com.macro.mall.model
# Entity		PmsFeightTemplate		com.macro.mall.model
# Entity		UmsRoleExample		com.macro.mall.model
# Entity		PmsProductAttributeValueExample		com.macro.mall.model
# Entity		UmsMenuExample		com.macro.mall.model
# Entity		UmsMenu		com.macro.mall.model
# Entity		SmsHomeRecommendSubject		com.macro.mall.model
# Entity		PmsProductLadder		com.macro.mall.model
# Entity		CmsSubjectProductRelation		com.macro.mall.model
# Entity		PmsProductFullReduction		com.macro.mall.model
# Entity		SmsFlashPromotion		com.macro.mall.model
# Entity		PmsAlbumPicExample		com.macro.mall.model
# Entity		UmsMemberMemberTagRelationExample		com.macro.mall.model
# Entity		PmsProductLadderExample		com.macro.mall.model
# Entity		SmsCouponHistoryExample		com.macro.mall.model
# Entity		CmsPrefrenceAreaExample		com.macro.mall.model
# Entity		PmsBrandExample		com.macro.mall.model
# Entity		UmsResourceCategory		com.macro.mall.model
# Entity		PmsCommentReplayExample		com.macro.mall.model
# Entity		CmsMemberReport		com.macro.mall.model
# Entity		UmsIntegrationChangeHistory		com.macro.mall.model
# Entity		PmsProductOperateLog		com.macro.mall.model
# Entity		UmsResourceExample		com.macro.mall.model
# Entity		OmsOrderSettingExample		com.macro.mall.model
# Entity		CmsSubjectExample		com.macro.mall.model
# Entity		SmsCouponProductRelation		com.macro.mall.model
# Entity		UmsRoleResourceRelationExample		com.macro.mall.model
# Entity		PmsProductFullReductionExample		com.macro.mall.model
# Entity		UmsMemberMemberTagRelation		com.macro.mall.model
# Entity		SmsFlashPromotionExample		com.macro.mall.model
# Entity		PmsCommentReplay		com.macro.mall.model
# Entity		PmsProduct		com.macro.mall.model
# Entity		PmsComment		com.macro.mall.model
# Entity		PmsCommentExample		com.macro.mall.model
# Entity		CmsPrefrenceAreaProductRelationExample		com.macro.mall.model
# Entity		UmsAdminRoleRelationExample		com.macro.mall.model
# Entity		SmsFlashPromotionSession		com.macro.mall.model
# Entity		SmsHomeBrand		com.macro.mall.model
# Entity		SmsHomeRecommendProductExample		com.macro.mall.model
# Entity		PmsProductOperateLogExample		com.macro.mall.model
# Entity		UmsIntegrationConsumeSetting		com.macro.mall.model
# Entity		UmsMemberStatisticsInfoExample		com.macro.mall.model
# Entity		UmsAdminExample		com.macro.mall.model
# Entity		OmsCompanyAddressExample		com.macro.mall.model
# Entity		UmsRoleResourceRelation		com.macro.mall.model
# Entity		SmsHomeBrandExample		com.macro.mall.model
# Entity		UmsMemberTask		com.macro.mall.model
# Entity		OmsCompanyAddress		com.macro.mall.model
# Entity		PmsBrand		com.macro.mall.model
# Entity		UmsMemberRuleSetting		com.macro.mall.model
# Entity		UmsMemberProductCategoryRelationExample		com.macro.mall.model
# Entity		PmsProductVertifyRecord		com.macro.mall.model
# Entity		PmsSkuStock		com.macro.mall.model
# Entity		CmsHelpCategory		com.macro.mall.model
# Entity		OmsOrderOperateHistoryExample		com.macro.mall.model
# Entity		OmsCartItemExample		com.macro.mall.model
# Entity		CmsSubjectCategoryExample		com.macro.mall.model
# Entity		PmsProductAttributeExample		com.macro.mall.model
# Entity		SmsFlashPromotionLog		com.macro.mall.model
# Entity		PmsProductAttributeValue		com.macro.mall.model
# Entity		CmsSubjectComment		com.macro.mall.model
# Entity		SmsFlashPromotionProductRelation		com.macro.mall.model
# Entity		UmsIntegrationConsumeSettingExample		com.macro.mall.model
# Entity		SmsFlashPromotionSessionExample		com.macro.mall.model
# Entity		SmsCouponExample		com.macro.mall.model
# Entity		SmsHomeAdvertise		com.macro.mall.model
# Entity		UmsPermissionExample		com.macro.mall.model
# Entity		UmsGrowthChangeHistoryExample		com.macro.mall.model
# Entity		PmsProductCategoryAttributeRelationExample		com.macro.mall.model
# Entity		UmsPermission		com.macro.mall.model
# Entity		OmsOrderExample		com.macro.mall.model
# Interface	PmsAlbumPicMapper		com.macro.mall.mapper
# Interface	UmsMemberTagMapper		com.macro.mall.mapper
# Interface	OmsOrderMapper		com.macro.mall.mapper
# Interface	OmsOrderSettingMapper		com.macro.mall.mapper
# Interface	UmsAdminLoginLogMapper		com.macro.mall.mapper
# Interface	PmsProductCategoryMapper		com.macro.mall.mapper
# Interface	PmsProductFullReductionMapper		com.macro.mall.mapper
# Interface	PmsProductMapper		com.macro.mall.mapper
# Interface	OmsOrderReturnApplyMapper		com.macro.mall.mapper
# Interface	CmsSubjectCategoryMapper		com.macro.mall.mapper
# Interface	CmsMemberReportMapper		com.macro.mall.mapper
# Interface	UmsAdminMapper		com.macro.mall.mapper
# Interface	UmsMemberProductCategoryRelationMapper		com.macro.mall.mapper
# Interface	CmsPrefrenceAreaProductRelationMapper		com.macro.mall.mapper
# Interface	CmsSubjectProductRelationMapper		com.macro.mall.mapper
# Interface	SmsHomeRecommendSubjectMapper		com.macro.mall.mapper
# Interface	OmsOrderItemMapper		com.macro.mall.mapper
# Interface	SmsHomeRecommendProductMapper		com.macro.mall.mapper
# Interface	SmsCouponProductCategoryRelationMapper		com.macro.mall.mapper
# Interface	PmsProductAttributeCategoryMapper		com.macro.mall.mapper
# Interface	PmsFeightTemplateMapper		com.macro.mall.mapper
# Interface	CmsHelpMapper		com.macro.mall.mapper
# Interface	UmsResourceCategoryMapper		com.macro.mall.mapper
# Interface	PmsAlbumMapper		com.macro.mall.mapper
# Interface	SmsHomeNewProductMapper		com.macro.mall.mapper
# Interface	CmsPrefrenceAreaMapper		com.macro.mall.mapper
# Interface	UmsResourceMapper		com.macro.mall.mapper
# Interface	CmsHelpCategoryMapper		com.macro.mall.mapper
# Interface	OmsCompanyAddressMapper		com.macro.mall.mapper
# Interface	PmsBrandMapper		com.macro.mall.mapper
# Interface	SmsCouponHistoryMapper		com.macro.mall.mapper
# Interface	UmsIntegrationConsumeSettingMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionProductRelationMapper		com.macro.mall.mapper
# Interface	PmsMemberPriceMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionLogMapper		com.macro.mall.mapper
# Interface	UmsMemberStatisticsInfoMapper		com.macro.mall.mapper
# Interface	UmsGrowthChangeHistoryMapper		com.macro.mall.mapper
# Interface	UmsMemberTaskMapper		com.macro.mall.mapper
# Interface	UmsAdminRoleRelationMapper		com.macro.mall.mapper
# Interface	PmsProductCategoryAttributeRelationMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionMapper		com.macro.mall.mapper
# Interface	PmsProductLadderMapper		com.macro.mall.mapper
# Interface	CmsSubjectCommentMapper		com.macro.mall.mapper
# Interface	UmsMemberRuleSettingMapper		com.macro.mall.mapper
# Interface	PmsProductOperateLogMapper		com.macro.mall.mapper
# Interface	OmsOrderOperateHistoryMapper		com.macro.mall.mapper
# Interface	PmsProductVertifyRecordMapper		com.macro.mall.mapper
# Interface	PmsCommentMapper		com.macro.mall.mapper
# Interface	UmsRoleMenuRelationMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionSessionMapper		com.macro.mall.mapper
# Interface	CmsTopicCategoryMapper		com.macro.mall.mapper
# Interface	UmsMemberMemberTagRelationMapper		com.macro.mall.mapper
# Interface	UmsMenuMapper		com.macro.mall.mapper
# Interface	UmsAdminPermissionRelationMapper		com.macro.mall.mapper
# Interface	UmsRoleMapper		com.macro.mall.mapper
# Interface	UmsRolePermissionRelationMapper		com.macro.mall.mapper
# Interface	SmsCouponProductRelationMapper		com.macro.mall.mapper
# Interface	PmsProductAttributeMapper		com.macro.mall.mapper
# Interface	CmsTopicMapper		com.macro.mall.mapper
# Interface	UmsMemberMapper		com.macro.mall.mapper
# Interface	UmsPermissionMapper		com.macro.mall.mapper
# Interface	UmsMemberReceiveAddressMapper		com.macro.mall.mapper
# Interface	UmsMemberLevelMapper		com.macro.mall.mapper
# Interface	CmsTopicCommentMapper		com.macro.mall.mapper
# Interface	SmsHomeAdvertiseMapper		com.macro.mall.mapper
# Interface	OmsOrderReturnReasonMapper		com.macro.mall.mapper
# Interface	UmsIntegrationChangeHistoryMapper		com.macro.mall.mapper
# Interface	PmsProductAttributeValueMapper		com.macro.mall.mapper
# Interface	UmsMemberLoginLogMapper		com.macro.mall.mapper
# Interface	UmsRoleResourceRelationMapper		com.macro.mall.mapper
# Interface	SmsCouponMapper		com.macro.mall.mapper
# Interface	OmsCartItemMapper		com.macro.mall.mapper
# Interface	CmsSubjectMapper		com.macro.mall.mapper
# Interface	PmsSkuStockMapper		com.macro.mall.mapper
# Interface	PmsCommentReplayMapper		com.macro.mall.mapper
# Interface	SmsHomeBrandMapper		com.macro.mall.mapper
# Excluded	MallAdminApplication		com.macro.mall
# Interface	OmsOrderService		com.macro.mall.service
# Interface	PmsProductAttributeCategoryService		com.macro.mall.service
# Interface	OmsOrderSettingService		com.macro.mall.service
# Interface	UmsResourceService		com.macro.mall.service
# Interface	SmsFlashPromotionSessionService		com.macro.mall.service
# Interface	UmsResourceCategoryService		com.macro.mall.service
# Interface	PmsProductService		com.macro.mall.service
# Interface	CmsPrefrenceAreaService		com.macro.mall.service
# Interface	SmsHomeRecommendProductService		com.macro.mall.service
# Interface	SmsCouponHistoryService		com.macro.mall.service
# Interface	OssService		com.macro.mall.service
# Interface	PmsSkuStockService		com.macro.mall.service
# Interface	SmsFlashPromotionProductRelationService		com.macro.mall.service
# Interface	PmsProductAttributeService		com.macro.mall.service
# Interface	UmsAdminCacheService		com.macro.mall.service
# Interface	UmsAdminService		com.macro.mall.service
# Interface	SmsHomeAdvertiseService		com.macro.mall.service
# Interface	OmsCompanyAddressService		com.macro.mall.service
# Interface	UmsMenuService		com.macro.mall.service
# Interface	UmsRoleService		com.macro.mall.service
# Interface	OmsOrderReturnReasonService		com.macro.mall.service
# Interface	SmsCouponService		com.macro.mall.service
# Interface	CmsSubjectService		com.macro.mall.service
# Interface	SmsFlashPromotionService		com.macro.mall.service
# Interface	SmsHomeNewProductService		com.macro.mall.service
# Interface	SmsHomeRecommendSubjectService		com.macro.mall.service
# Interface	PmsProductCategoryService		com.macro.mall.service
# Interface	OmsOrderReturnApplyService		com.macro.mall.service
# Interface	SmsHomeBrandService		com.macro.mall.service
# Interface	PmsBrandService		com.macro.mall.service
# Interface	UmsMemberLevelService		com.macro.mall.service
# Logic		OmsOrderReturnReasonServiceImpl		com.macro.mall.service.impl
# Logic		OmsOrderReturnApplyServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeRecommendProductServiceImpl		com.macro.mall.service.impl
# Logic		UmsMemberLevelServiceImpl		com.macro.mall.service.impl
# Logic		UmsMenuServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductCategoryServiceImpl		com.macro.mall.service.impl
# Logic		UmsAdminCacheServiceImpl		com.macro.mall.service.impl
# Logic		PmsBrandServiceImpl		com.macro.mall.service.impl
# Logic		UmsResourceServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductAttributeServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductServiceImpl		com.macro.mall.service.impl
# Logic		SmsFlashPromotionProductRelationServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductAttributeCategoryServiceImpl		com.macro.mall.service.impl
# Logic		CmsPrefrenceAreaServiceImpl		com.macro.mall.service.impl
# Logic		UmsResourceCategoryServiceImpl		com.macro.mall.service.impl
# Logic		PmsSkuStockServiceImpl		com.macro.mall.service.impl
# Logic		OmsOrderSettingServiceImpl		com.macro.mall.service.impl
# Logic		SmsFlashPromotionSessionServiceImpl		com.macro.mall.service.impl
# Logic		OssServiceImpl		com.macro.mall.service.impl
# Logic		UmsRoleServiceImpl		com.macro.mall.service.impl
# Logic		OmsCompanyAddressServiceImpl		com.macro.mall.service.impl
# Logic		CmsSubjectServiceImpl		com.macro.mall.service.impl
# Logic		SmsCouponServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeRecommendSubjectServiceImpl		com.macro.mall.service.impl
# Logic		UmsAdminServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeAdvertiseServiceImpl		com.macro.mall.service.impl
# Logic		OmsOrderServiceImpl		com.macro.mall.service.impl
# Logic		SmsFlashPromotionServiceImpl		com.macro.mall.service.impl
# Logic		SmsCouponHistoryServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeBrandServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeNewProductServiceImpl		com.macro.mall.service.impl
# Entity		OssCallbackResult		com.macro.mall.dto
# Entity		OmsMoneyInfoParam		com.macro.mall.dto
# Entity		ProductAttrInfo		com.macro.mall.dto
# Entity		OssPolicyResult		com.macro.mall.dto
# Entity		UmsMenuNode		com.macro.mall.dto
# Entity		UpdateAdminPasswordParam		com.macro.mall.dto
# Entity		OmsReceiverInfoParam		com.macro.mall.dto
# Entity		UmsAdminParam		com.macro.mall.dto
# Entity		SmsFlashPromotionSessionDetail		com.macro.mall.dto
# Entity		PmsBrandParam		com.macro.mall.dto
# Entity		OmsUpdateStatusParam		com.macro.mall.dto
# Entity		OmsOrderQueryParam		com.macro.mall.dto
# Entity		SmsFlashPromotionProduct		com.macro.mall.dto
# Entity		OmsReturnApplyQueryParam		com.macro.mall.dto
# Entity		BucketPolicyConfigDto		com.macro.mall.dto
# Entity		PmsProductQueryParam		com.macro.mall.dto
# Entity		PmsProductResult		com.macro.mall.dto
# Entity		PmsProductAttributeParam		com.macro.mall.dto
# Entity		OssCallbackParam		com.macro.mall.dto
# Entity		OmsOrderDeliveryParam		com.macro.mall.dto
# Entity		PmsProductAttributeCategoryItem		com.macro.mall.dto
# Entity		OmsOrderReturnApplyResult		com.macro.mall.dto
# Entity		SmsCouponParam		com.macro.mall.dto
# Entity		PmsProductParam		com.macro.mall.dto
# Entity		PmsProductCategoryWithChildrenItem		com.macro.mall.dto
# Entity		MinioUploadDto		com.macro.mall.dto
# Entity		OmsOrderDetail		com.macro.mall.dto
# Entity		PmsProductCategoryParam		com.macro.mall.dto
# Entity		UmsAdminLoginParam		com.macro.mall.dto
# Logic		UmsMemberLevelController		com.macro.mall.controller
# Logic		SmsCouponController		com.macro.mall.controller
# Logic		OmsOrderSettingController		com.macro.mall.controller
# Logic		SmsHomeRecommendSubjectController		com.macro.mall.controller
# Logic		UmsRoleController		com.macro.mall.controller
# Logic		SmsFlashPromotionSessionController		com.macro.mall.controller
# Logic		UmsResourceController		com.macro.mall.controller
# Logic		OmsOrderController		com.macro.mall.controller
# Logic		SmsFlashPromotionController		com.macro.mall.controller
# Logic		CmsPrefrenceAreaController		com.macro.mall.controller
# Logic		SmsCouponHistoryController		com.macro.mall.controller
# Logic		PmsProductAttributeCategoryController		com.macro.mall.controller
# Logic		PmsProductAttributeController		com.macro.mall.controller
# Logic		SmsHomeRecommendProductController		com.macro.mall.controller
# Logic		SmsHomeNewProductController		com.macro.mall.controller
# Logic		UmsMenuController		com.macro.mall.controller
# Logic		PmsProductCategoryController		com.macro.mall.controller
# Logic		MinioController		com.macro.mall.controller
# Logic		OmsOrderReturnApplyController		com.macro.mall.controller
# Logic		CmsSubjectController		com.macro.mall.controller
# Logic		PmsSkuStockController		com.macro.mall.controller
# Logic		PmsProductController		com.macro.mall.controller
# Logic		OssController		com.macro.mall.controller
# Logic		SmsHomeBrandController		com.macro.mall.controller
# Logic		PmsBrandController		com.macro.mall.controller
# Logic		UmsResourceCategoryController		com.macro.mall.controller
# Logic		SmsHomeAdvertiseController		com.macro.mall.controller
# Logic		OmsOrderReturnReasonController		com.macro.mall.controller
# Logic		SmsFlashPromotionProductRelationController		com.macro.mall.controller
# Logic		UmsAdminController		com.macro.mall.controller
# Logic		OmsCompanyAddressController		com.macro.mall.controller
# Entity		FlagValidatorClass		com.macro.mall.validator
# Excluded	SwaggerConfig		com.macro.mall.config
# Excluded	OssConfig		com.macro.mall.config
# Excluded	GlobalCorsConfig		com.macro.mall.config
# Excluded	MyBatisConfig		com.macro.mall.config
# Excluded	MallSecurityConfig		com.macro.mall.config
# Entity		AdminUserDetails		com.macro.mall.bo
# Interface	PmsProductLadderDao		com.macro.mall.dao
# Interface	PmsProductFullReductionDao		com.macro.mall.dao
# Interface	OmsOrderDao		com.macro.mall.dao
# Interface	PmsMemberPriceDao		com.macro.mall.dao
# Interface	PmsSkuStockDao		com.macro.mall.dao
# Interface	UmsAdminRoleRelationDao		com.macro.mall.dao
# Interface	PmsProductAttributeCategoryDao		com.macro.mall.dao
# Interface	PmsProductAttributeValueDao		com.macro.mall.dao
# Interface	SmsFlashPromotionProductRelationDao		com.macro.mall.dao
# Interface	PmsProductVertifyRecordDao		com.macro.mall.dao
# Interface	OmsOrderReturnApplyDao		com.macro.mall.dao
# Interface	PmsProductAttributeDao		com.macro.mall.dao
# Interface	SmsCouponProductRelationDao		com.macro.mall.dao
# Interface	OmsOrderOperateHistoryDao		com.macro.mall.dao
# Interface	SmsCouponDao		com.macro.mall.dao
# Interface	PmsProductCategoryDao		com.macro.mall.dao
# Interface	UmsRoleDao		com.macro.mall.dao
# Interface	SmsCouponProductCategoryRelationDao		com.macro.mall.dao
# Interface	PmsProductDao		com.macro.mall.dao
# Interface	CmsSubjectProductRelationDao		com.macro.mall.dao
# Interface	CmsPrefrenceAreaProductRelationDao		com.macro.mall.dao
# Interface	PmsProductCategoryAttributeRelationDao		com.macro.mall.dao

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)) or "repository" in pkg_name(tree).lower() or "repositories" in pkg_name(tree).lower() or "repository" in decl.name.lower():

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		DynamicSecurityMetadataSource		com.macro.mall.security.component
# Entity		DynamicSecurityFilter		com.macro.mall.security.component
# Entity		RestfulAccessDeniedHandler		com.macro.mall.security.component
# Entity		JwtAuthenticationTokenFilter		com.macro.mall.security.component
# Entity		RestAuthenticationEntryPoint		com.macro.mall.security.component
# Entity		DynamicAccessDecisionManager		com.macro.mall.security.component
# Entity		JwtTokenUtil		com.macro.mall.security.util
# Entity		IgnoreUrlsConfig		com.macro.mall.security.config
# Entity		RedisServiceImpl		com.macro.mall.common.service.impl
# Entity		RequestUtil		com.macro.mall.common.util
# Entity		SwaggerProperties		com.macro.mall.common.domain
# Entity		WebLog		com.macro.mall.common.domain
# Entity		BaseRedisConfig		com.macro.mall.common.config
# Entity		BaseSwaggerConfig		com.macro.mall.common.config
# Entity		CommonPage		com.macro.mall.common.api
# Entity		CommonResult		com.macro.mall.common.api
# Entity		ApiException		com.macro.mall.common.exception
# Entity		Asserts		com.macro.mall.common.exception
# Entity		Generator		com.macro.mall
# Entity		CommentGenerator		com.macro.mall
# Entity		SmsHomeRecommendProduct		com.macro.mall.model
# Entity		CmsSubject		com.macro.mall.model
# Entity		OmsOrderReturnReason		com.macro.mall.model
# Entity		PmsAlbumPic		com.macro.mall.model
# Entity		CmsMemberReportExample		com.macro.mall.model
# Entity		UmsRolePermissionRelationExample		com.macro.mall.model
# Entity		CmsHelpExample		com.macro.mall.model
# Entity		UmsResource		com.macro.mall.model
# Entity		OmsOrderSetting		com.macro.mall.model
# Entity		CmsSubjectCategory		com.macro.mall.model
# Entity		UmsMemberTaskExample		com.macro.mall.model
# Entity		OmsOrderReturnReasonExample		com.macro.mall.model
# Entity		SmsCouponProductRelationExample		com.macro.mall.model
# Entity		UmsMemberTagExample		com.macro.mall.model
# Entity		SmsCouponProductCategoryRelationExample		com.macro.mall.model
# Entity		PmsProductCategory		com.macro.mall.model
# Entity		UmsMemberLoginLog		com.macro.mall.model
# Entity		SmsHomeNewProduct		com.macro.mall.model
# Entity		PmsAlbumExample		com.macro.mall.model
# Entity		PmsAlbum		com.macro.mall.model
# Entity		SmsHomeRecommendSubjectExample		com.macro.mall.model
# Entity		SmsFlashPromotionProductRelationExample		com.macro.mall.model
# Entity		UmsMemberExample		com.macro.mall.model
# Entity		UmsMember		com.macro.mall.model
# Entity		CmsPrefrenceArea		com.macro.mall.model
# Entity		UmsMemberProductCategoryRelation		com.macro.mall.model
# Entity		PmsMemberPriceExample		com.macro.mall.model
# Entity		SmsHomeAdvertiseExample		com.macro.mall.model
# Entity		UmsMemberRuleSettingExample		com.macro.mall.model
# Entity		OmsOrderReturnApply		com.macro.mall.model
# Entity		SmsFlashPromotionLogExample		com.macro.mall.model
# Entity		UmsRole		com.macro.mall.model
# Entity		OmsOrderReturnApplyExample		com.macro.mall.model
# Entity		SmsCouponProductCategoryRelation		com.macro.mall.model
# Entity		UmsGrowthChangeHistory		com.macro.mall.model
# Entity		SmsCoupon		com.macro.mall.model
# Entity		UmsMemberReceiveAddress		com.macro.mall.model
# Entity		UmsMemberLoginLogExample		com.macro.mall.model
# Entity		UmsIntegrationChangeHistoryExample		com.macro.mall.model
# Entity		PmsMemberPrice		com.macro.mall.model
# Entity		CmsHelp		com.macro.mall.model
# Entity		UmsMemberLevelExample		com.macro.mall.model
# Entity		CmsTopicCategory		com.macro.mall.model
# Entity		CmsTopicExample		com.macro.mall.model
# Entity		CmsTopic		com.macro.mall.model
# Entity		PmsProductAttributeCategory		com.macro.mall.model
# Entity		CmsPrefrenceAreaProductRelation		com.macro.mall.model
# Entity		CmsTopicCommentExample		com.macro.mall.model
# Entity		CmsSubjectProductRelationExample		com.macro.mall.model
# Entity		UmsResourceCategoryExample		com.macro.mall.model
# Entity		UmsAdminPermissionRelation		com.macro.mall.model
# Entity		SmsCouponHistory		com.macro.mall.model
# Entity		UmsAdminRoleRelation		com.macro.mall.model
# Entity		PmsProductAttributeCategoryExample		com.macro.mall.model
# Entity		UmsRolePermissionRelation		com.macro.mall.model
# Entity		CmsHelpCategoryExample		com.macro.mall.model
# Entity		PmsFeightTemplateExample		com.macro.mall.model
# Entity		PmsSkuStockExample		com.macro.mall.model
# Entity		UmsAdminLoginLog		com.macro.mall.model
# Entity		UmsRoleMenuRelation		com.macro.mall.model
# Entity		UmsAdminLoginLogExample		com.macro.mall.model
# Entity		CmsSubjectCommentExample		com.macro.mall.model
# Entity		CmsTopicCategoryExample		com.macro.mall.model
# Entity		UmsMemberLevel		com.macro.mall.model
# Entity		UmsAdminPermissionRelationExample		com.macro.mall.model
# Entity		PmsProductCategoryAttributeRelation		com.macro.mall.model
# Entity		OmsOrderOperateHistory		com.macro.mall.model
# Entity		UmsRoleMenuRelationExample		com.macro.mall.model
# Entity		OmsOrder		com.macro.mall.model
# Entity		SmsHomeNewProductExample		com.macro.mall.model
# Entity		OmsOrderItemExample		com.macro.mall.model
# Entity		UmsMemberTag		com.macro.mall.model
# Entity		UmsMemberReceiveAddressExample		com.macro.mall.model
# Entity		PmsProductCategoryExample		com.macro.mall.model
# Entity		PmsProductExample		com.macro.mall.model
# Entity		UmsAdmin		com.macro.mall.model
# Entity		OmsCartItem		com.macro.mall.model
# Entity		UmsMemberStatisticsInfo		com.macro.mall.model
# Entity		OmsOrderItem		com.macro.mall.model
# Entity		PmsProductVertifyRecordExample		com.macro.mall.model
# Entity		CmsTopicComment		com.macro.mall.model
# Entity		PmsProductAttribute		com.macro.mall.model
# Entity		PmsFeightTemplate		com.macro.mall.model
# Entity		UmsRoleExample		com.macro.mall.model
# Entity		PmsProductAttributeValueExample		com.macro.mall.model
# Entity		UmsMenuExample		com.macro.mall.model
# Entity		UmsMenu		com.macro.mall.model
# Entity		SmsHomeRecommendSubject		com.macro.mall.model
# Entity		PmsProductLadder		com.macro.mall.model
# Entity		CmsSubjectProductRelation		com.macro.mall.model
# Entity		PmsProductFullReduction		com.macro.mall.model
# Entity		SmsFlashPromotion		com.macro.mall.model
# Entity		PmsAlbumPicExample		com.macro.mall.model
# Entity		UmsMemberMemberTagRelationExample		com.macro.mall.model
# Entity		PmsProductLadderExample		com.macro.mall.model
# Entity		SmsCouponHistoryExample		com.macro.mall.model
# Entity		CmsPrefrenceAreaExample		com.macro.mall.model
# Entity		PmsBrandExample		com.macro.mall.model
# Entity		UmsResourceCategory		com.macro.mall.model
# Entity		PmsCommentReplayExample		com.macro.mall.model
# Entity		CmsMemberReport		com.macro.mall.model
# Entity		UmsIntegrationChangeHistory		com.macro.mall.model
# Entity		PmsProductOperateLog		com.macro.mall.model
# Entity		UmsResourceExample		com.macro.mall.model
# Entity		OmsOrderSettingExample		com.macro.mall.model
# Entity		CmsSubjectExample		com.macro.mall.model
# Entity		SmsCouponProductRelation		com.macro.mall.model
# Entity		UmsRoleResourceRelationExample		com.macro.mall.model
# Entity		PmsProductFullReductionExample		com.macro.mall.model
# Entity		UmsMemberMemberTagRelation		com.macro.mall.model
# Entity		SmsFlashPromotionExample		com.macro.mall.model
# Entity		PmsCommentReplay		com.macro.mall.model
# Entity		PmsProduct		com.macro.mall.model
# Entity		PmsComment		com.macro.mall.model
# Entity		PmsCommentExample		com.macro.mall.model
# Entity		CmsPrefrenceAreaProductRelationExample		com.macro.mall.model
# Entity		UmsAdminRoleRelationExample		com.macro.mall.model
# Entity		SmsFlashPromotionSession		com.macro.mall.model
# Entity		SmsHomeBrand		com.macro.mall.model
# Entity		SmsHomeRecommendProductExample		com.macro.mall.model
# Entity		PmsProductOperateLogExample		com.macro.mall.model
# Entity		UmsIntegrationConsumeSetting		com.macro.mall.model
# Entity		UmsMemberStatisticsInfoExample		com.macro.mall.model
# Entity		UmsAdminExample		com.macro.mall.model
# Entity		OmsCompanyAddressExample		com.macro.mall.model
# Entity		UmsRoleResourceRelation		com.macro.mall.model
# Entity		SmsHomeBrandExample		com.macro.mall.model
# Entity		UmsMemberTask		com.macro.mall.model
# Entity		OmsCompanyAddress		com.macro.mall.model
# Entity		PmsBrand		com.macro.mall.model
# Entity		UmsMemberRuleSetting		com.macro.mall.model
# Entity		UmsMemberProductCategoryRelationExample		com.macro.mall.model
# Entity		PmsProductVertifyRecord		com.macro.mall.model
# Entity		PmsSkuStock		com.macro.mall.model
# Entity		CmsHelpCategory		com.macro.mall.model
# Entity		OmsOrderOperateHistoryExample		com.macro.mall.model
# Entity		OmsCartItemExample		com.macro.mall.model
# Entity		CmsSubjectCategoryExample		com.macro.mall.model
# Entity		PmsProductAttributeExample		com.macro.mall.model
# Entity		SmsFlashPromotionLog		com.macro.mall.model
# Entity		PmsProductAttributeValue		com.macro.mall.model
# Entity		CmsSubjectComment		com.macro.mall.model
# Entity		SmsFlashPromotionProductRelation		com.macro.mall.model
# Entity		UmsIntegrationConsumeSettingExample		com.macro.mall.model
# Entity		SmsFlashPromotionSessionExample		com.macro.mall.model
# Entity		SmsCouponExample		com.macro.mall.model
# Entity		SmsHomeAdvertise		com.macro.mall.model
# Entity		UmsPermissionExample		com.macro.mall.model
# Entity		UmsGrowthChangeHistoryExample		com.macro.mall.model
# Entity		PmsProductCategoryAttributeRelationExample		com.macro.mall.model
# Entity		UmsPermission		com.macro.mall.model
# Entity		OmsOrderExample		com.macro.mall.model
# Entity		OssCallbackResult		com.macro.mall.dto
# Entity		OmsMoneyInfoParam		com.macro.mall.dto
# Entity		ProductAttrInfo		com.macro.mall.dto
# Entity		OssPolicyResult		com.macro.mall.dto
# Entity		UmsMenuNode		com.macro.mall.dto
# Entity		UpdateAdminPasswordParam		com.macro.mall.dto
# Entity		OmsReceiverInfoParam		com.macro.mall.dto
# Entity		UmsAdminParam		com.macro.mall.dto
# Entity		SmsFlashPromotionSessionDetail		com.macro.mall.dto
# Entity		PmsBrandParam		com.macro.mall.dto
# Entity		OmsUpdateStatusParam		com.macro.mall.dto
# Entity		OmsOrderQueryParam		com.macro.mall.dto
# Entity		SmsFlashPromotionProduct		com.macro.mall.dto
# Entity		OmsReturnApplyQueryParam		com.macro.mall.dto
# Entity		BucketPolicyConfigDto		com.macro.mall.dto
# Entity		PmsProductQueryParam		com.macro.mall.dto
# Entity		PmsProductResult		com.macro.mall.dto
# Entity		PmsProductAttributeParam		com.macro.mall.dto
# Entity		OssCallbackParam		com.macro.mall.dto
# Entity		OmsOrderDeliveryParam		com.macro.mall.dto
# Entity		PmsProductAttributeCategoryItem		com.macro.mall.dto
# Entity		OmsOrderReturnApplyResult		com.macro.mall.dto
# Entity		SmsCouponParam		com.macro.mall.dto
# Entity		PmsProductParam		com.macro.mall.dto
# Entity		PmsProductCategoryWithChildrenItem		com.macro.mall.dto
# Entity		MinioUploadDto		com.macro.mall.dto
# Entity		OmsOrderDetail		com.macro.mall.dto
# Entity		PmsProductCategoryParam		com.macro.mall.dto
# Entity		UmsAdminLoginParam		com.macro.mall.dto
# Entity		FlagValidatorClass		com.macro.mall.validator
# Entity		AdminUserDetails		com.macro.mall.bo
# Logic		RedisCacheAspect		com.macro.mall.security.aspect
# Logic		SpringUtil		com.macro.mall.security.util
# Logic		WebLogAspect		com.macro.mall.common.log
# Logic		OmsOrderReturnReasonServiceImpl		com.macro.mall.service.impl
# Logic		OmsOrderReturnApplyServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeRecommendProductServiceImpl		com.macro.mall.service.impl
# Logic		UmsMemberLevelServiceImpl		com.macro.mall.service.impl
# Logic		UmsMenuServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductCategoryServiceImpl		com.macro.mall.service.impl
# Logic		UmsAdminCacheServiceImpl		com.macro.mall.service.impl
# Logic		PmsBrandServiceImpl		com.macro.mall.service.impl
# Logic		UmsResourceServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductAttributeServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductServiceImpl		com.macro.mall.service.impl
# Logic		SmsFlashPromotionProductRelationServiceImpl		com.macro.mall.service.impl
# Logic		PmsProductAttributeCategoryServiceImpl		com.macro.mall.service.impl
# Logic		CmsPrefrenceAreaServiceImpl		com.macro.mall.service.impl
# Logic		UmsResourceCategoryServiceImpl		com.macro.mall.service.impl
# Logic		PmsSkuStockServiceImpl		com.macro.mall.service.impl
# Logic		OmsOrderSettingServiceImpl		com.macro.mall.service.impl
# Logic		SmsFlashPromotionSessionServiceImpl		com.macro.mall.service.impl
# Logic		OssServiceImpl		com.macro.mall.service.impl
# Logic		UmsRoleServiceImpl		com.macro.mall.service.impl
# Logic		OmsCompanyAddressServiceImpl		com.macro.mall.service.impl
# Logic		CmsSubjectServiceImpl		com.macro.mall.service.impl
# Logic		SmsCouponServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeRecommendSubjectServiceImpl		com.macro.mall.service.impl
# Logic		UmsAdminServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeAdvertiseServiceImpl		com.macro.mall.service.impl
# Logic		OmsOrderServiceImpl		com.macro.mall.service.impl
# Logic		SmsFlashPromotionServiceImpl		com.macro.mall.service.impl
# Logic		SmsCouponHistoryServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeBrandServiceImpl		com.macro.mall.service.impl
# Logic		SmsHomeNewProductServiceImpl		com.macro.mall.service.impl
# Logic		UmsMemberLevelController		com.macro.mall.controller
# Logic		SmsCouponController		com.macro.mall.controller
# Logic		OmsOrderSettingController		com.macro.mall.controller
# Logic		SmsHomeRecommendSubjectController		com.macro.mall.controller
# Logic		UmsRoleController		com.macro.mall.controller
# Logic		SmsFlashPromotionSessionController		com.macro.mall.controller
# Logic		UmsResourceController		com.macro.mall.controller
# Logic		OmsOrderController		com.macro.mall.controller
# Logic		SmsFlashPromotionController		com.macro.mall.controller
# Logic		CmsPrefrenceAreaController		com.macro.mall.controller
# Logic		SmsCouponHistoryController		com.macro.mall.controller
# Logic		PmsProductAttributeCategoryController		com.macro.mall.controller
# Logic		PmsProductAttributeController		com.macro.mall.controller
# Logic		SmsHomeRecommendProductController		com.macro.mall.controller
# Logic		SmsHomeNewProductController		com.macro.mall.controller
# Logic		UmsMenuController		com.macro.mall.controller
# Logic		PmsProductCategoryController		com.macro.mall.controller
# Logic		MinioController		com.macro.mall.controller
# Logic		OmsOrderReturnApplyController		com.macro.mall.controller
# Logic		CmsSubjectController		com.macro.mall.controller
# Logic		PmsSkuStockController		com.macro.mall.controller
# Logic		PmsProductController		com.macro.mall.controller
# Logic		OssController		com.macro.mall.controller
# Logic		SmsHomeBrandController		com.macro.mall.controller
# Logic		PmsBrandController		com.macro.mall.controller
# Logic		UmsResourceCategoryController		com.macro.mall.controller
# Logic		SmsHomeAdvertiseController		com.macro.mall.controller
# Logic		OmsOrderReturnReasonController		com.macro.mall.controller
# Logic		SmsFlashPromotionProductRelationController		com.macro.mall.controller
# Logic		UmsAdminController		com.macro.mall.controller
# Logic		OmsCompanyAddressController		com.macro.mall.controller
# Interface	DynamicSecurityService		com.macro.mall.security.component
# Interface	RedisService		com.macro.mall.common.service
# Interface	IErrorCode		com.macro.mall.common.api
# Interface	PmsAlbumPicMapper		com.macro.mall.mapper
# Interface	UmsMemberTagMapper		com.macro.mall.mapper
# Interface	OmsOrderMapper		com.macro.mall.mapper
# Interface	OmsOrderSettingMapper		com.macro.mall.mapper
# Interface	UmsAdminLoginLogMapper		com.macro.mall.mapper
# Interface	PmsProductCategoryMapper		com.macro.mall.mapper
# Interface	PmsProductFullReductionMapper		com.macro.mall.mapper
# Interface	PmsProductMapper		com.macro.mall.mapper
# Interface	OmsOrderReturnApplyMapper		com.macro.mall.mapper
# Interface	CmsSubjectCategoryMapper		com.macro.mall.mapper
# Interface	CmsMemberReportMapper		com.macro.mall.mapper
# Interface	UmsAdminMapper		com.macro.mall.mapper
# Interface	UmsMemberProductCategoryRelationMapper		com.macro.mall.mapper
# Interface	CmsPrefrenceAreaProductRelationMapper		com.macro.mall.mapper
# Interface	CmsSubjectProductRelationMapper		com.macro.mall.mapper
# Interface	SmsHomeRecommendSubjectMapper		com.macro.mall.mapper
# Interface	OmsOrderItemMapper		com.macro.mall.mapper
# Interface	SmsHomeRecommendProductMapper		com.macro.mall.mapper
# Interface	SmsCouponProductCategoryRelationMapper		com.macro.mall.mapper
# Interface	PmsProductAttributeCategoryMapper		com.macro.mall.mapper
# Interface	PmsFeightTemplateMapper		com.macro.mall.mapper
# Interface	CmsHelpMapper		com.macro.mall.mapper
# Interface	UmsResourceCategoryMapper		com.macro.mall.mapper
# Interface	PmsAlbumMapper		com.macro.mall.mapper
# Interface	SmsHomeNewProductMapper		com.macro.mall.mapper
# Interface	CmsPrefrenceAreaMapper		com.macro.mall.mapper
# Interface	UmsResourceMapper		com.macro.mall.mapper
# Interface	CmsHelpCategoryMapper		com.macro.mall.mapper
# Interface	OmsCompanyAddressMapper		com.macro.mall.mapper
# Interface	PmsBrandMapper		com.macro.mall.mapper
# Interface	SmsCouponHistoryMapper		com.macro.mall.mapper
# Interface	UmsIntegrationConsumeSettingMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionProductRelationMapper		com.macro.mall.mapper
# Interface	PmsMemberPriceMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionLogMapper		com.macro.mall.mapper
# Interface	UmsMemberStatisticsInfoMapper		com.macro.mall.mapper
# Interface	UmsGrowthChangeHistoryMapper		com.macro.mall.mapper
# Interface	UmsMemberTaskMapper		com.macro.mall.mapper
# Interface	UmsAdminRoleRelationMapper		com.macro.mall.mapper
# Interface	PmsProductCategoryAttributeRelationMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionMapper		com.macro.mall.mapper
# Interface	PmsProductLadderMapper		com.macro.mall.mapper
# Interface	CmsSubjectCommentMapper		com.macro.mall.mapper
# Interface	UmsMemberRuleSettingMapper		com.macro.mall.mapper
# Interface	PmsProductOperateLogMapper		com.macro.mall.mapper
# Interface	OmsOrderOperateHistoryMapper		com.macro.mall.mapper
# Interface	PmsProductVertifyRecordMapper		com.macro.mall.mapper
# Interface	PmsCommentMapper		com.macro.mall.mapper
# Interface	UmsRoleMenuRelationMapper		com.macro.mall.mapper
# Interface	SmsFlashPromotionSessionMapper		com.macro.mall.mapper
# Interface	CmsTopicCategoryMapper		com.macro.mall.mapper
# Interface	UmsMemberMemberTagRelationMapper		com.macro.mall.mapper
# Interface	UmsMenuMapper		com.macro.mall.mapper
# Interface	UmsAdminPermissionRelationMapper		com.macro.mall.mapper
# Interface	UmsRoleMapper		com.macro.mall.mapper
# Interface	UmsRolePermissionRelationMapper		com.macro.mall.mapper
# Interface	SmsCouponProductRelationMapper		com.macro.mall.mapper
# Interface	PmsProductAttributeMapper		com.macro.mall.mapper
# Interface	CmsTopicMapper		com.macro.mall.mapper
# Interface	UmsMemberMapper		com.macro.mall.mapper
# Interface	UmsPermissionMapper		com.macro.mall.mapper
# Interface	UmsMemberReceiveAddressMapper		com.macro.mall.mapper
# Interface	UmsMemberLevelMapper		com.macro.mall.mapper
# Interface	CmsTopicCommentMapper		com.macro.mall.mapper
# Interface	SmsHomeAdvertiseMapper		com.macro.mall.mapper
# Interface	OmsOrderReturnReasonMapper		com.macro.mall.mapper
# Interface	UmsIntegrationChangeHistoryMapper		com.macro.mall.mapper
# Interface	PmsProductAttributeValueMapper		com.macro.mall.mapper
# Interface	UmsMemberLoginLogMapper		com.macro.mall.mapper
# Interface	UmsRoleResourceRelationMapper		com.macro.mall.mapper
# Interface	SmsCouponMapper		com.macro.mall.mapper
# Interface	OmsCartItemMapper		com.macro.mall.mapper
# Interface	CmsSubjectMapper		com.macro.mall.mapper
# Interface	PmsSkuStockMapper		com.macro.mall.mapper
# Interface	PmsCommentReplayMapper		com.macro.mall.mapper
# Interface	SmsHomeBrandMapper		com.macro.mall.mapper
# Interface	OmsOrderService		com.macro.mall.service
# Interface	PmsProductAttributeCategoryService		com.macro.mall.service
# Interface	OmsOrderSettingService		com.macro.mall.service
# Interface	UmsResourceService		com.macro.mall.service
# Interface	SmsFlashPromotionSessionService		com.macro.mall.service
# Interface	UmsResourceCategoryService		com.macro.mall.service
# Interface	PmsProductService		com.macro.mall.service
# Interface	CmsPrefrenceAreaService		com.macro.mall.service
# Interface	SmsHomeRecommendProductService		com.macro.mall.service
# Interface	SmsCouponHistoryService		com.macro.mall.service
# Interface	OssService		com.macro.mall.service
# Interface	PmsSkuStockService		com.macro.mall.service
# Interface	SmsFlashPromotionProductRelationService		com.macro.mall.service
# Interface	PmsProductAttributeService		com.macro.mall.service
# Interface	UmsAdminCacheService		com.macro.mall.service
# Interface	UmsAdminService		com.macro.mall.service
# Interface	SmsHomeAdvertiseService		com.macro.mall.service
# Interface	OmsCompanyAddressService		com.macro.mall.service
# Interface	UmsMenuService		com.macro.mall.service
# Interface	UmsRoleService		com.macro.mall.service
# Interface	OmsOrderReturnReasonService		com.macro.mall.service
# Interface	SmsCouponService		com.macro.mall.service
# Interface	CmsSubjectService		com.macro.mall.service
# Interface	SmsFlashPromotionService		com.macro.mall.service
# Interface	SmsHomeNewProductService		com.macro.mall.service
# Interface	SmsHomeRecommendSubjectService		com.macro.mall.service
# Interface	PmsProductCategoryService		com.macro.mall.service
# Interface	OmsOrderReturnApplyService		com.macro.mall.service
# Interface	SmsHomeBrandService		com.macro.mall.service
# Interface	PmsBrandService		com.macro.mall.service
# Interface	UmsMemberLevelService		com.macro.mall.service
# Interface	PmsProductLadderDao		com.macro.mall.dao
# Interface	PmsProductFullReductionDao		com.macro.mall.dao
# Interface	OmsOrderDao		com.macro.mall.dao
# Interface	PmsMemberPriceDao		com.macro.mall.dao
# Interface	PmsSkuStockDao		com.macro.mall.dao
# Interface	UmsAdminRoleRelationDao		com.macro.mall.dao
# Interface	PmsProductAttributeCategoryDao		com.macro.mall.dao
# Interface	PmsProductAttributeValueDao		com.macro.mall.dao
# Interface	SmsFlashPromotionProductRelationDao		com.macro.mall.dao
# Interface	PmsProductVertifyRecordDao		com.macro.mall.dao
# Interface	OmsOrderReturnApplyDao		com.macro.mall.dao
# Interface	PmsProductAttributeDao		com.macro.mall.dao
# Interface	SmsCouponProductRelationDao		com.macro.mall.dao
# Interface	OmsOrderOperateHistoryDao		com.macro.mall.dao
# Interface	SmsCouponDao		com.macro.mall.dao
# Interface	PmsProductCategoryDao		com.macro.mall.dao
# Interface	UmsRoleDao		com.macro.mall.dao
# Interface	SmsCouponProductCategoryRelationDao		com.macro.mall.dao
# Interface	PmsProductDao		com.macro.mall.dao
# Interface	CmsSubjectProductRelationDao		com.macro.mall.dao
# Interface	CmsPrefrenceAreaProductRelationDao		com.macro.mall.dao
# Interface	PmsProductCategoryAttributeRelationDao		com.macro.mall.dao
# Excluded	SecurityConfig		com.macro.mall.security.config
# Excluded	RedisConfig		com.macro.mall.security.config
# Excluded	CommonSecurityConfig		com.macro.mall.security.config
# Excluded	GlobalExceptionHandler		com.macro.mall.common.exception
# Excluded	MallAdminApplication		com.macro.mall
# Excluded	SwaggerConfig		com.macro.mall.config
# Excluded	OssConfig		com.macro.mall.config
# Excluded	GlobalCorsConfig		com.macro.mall.config
# Excluded	MyBatisConfig		com.macro.mall.config
# Excluded	MallSecurityConfig		com.macro.mall.config

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')
# Out:
# WARNING: OmsOrderReturnReasonMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnReasonMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnReasonMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnReasonMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnReasonMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnReasonMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnApplyDaointerface does not have an implementing class!
# WARNING: OmsOrderReturnApplyMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnApplyMapperinterface does not have an implementing class!
# WARNING: OmsOrderReturnApplyDaointerface does not have an implementing class!
# WARNING: SmsHomeRecommendProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendProductMapperinterface does not have an implementing class!
# WARNING: UmsMemberLevelMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: UmsMenuMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryAttributeRelationDaointerface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryAttributeRelationMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryAttributeRelationMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductCategoryDaointerface does not have an implementing class!
# WARNING: PmsProductCategoryMapperinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: UmsAdminRoleRelationMapperinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: UmsAdminRoleRelationMapperinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: UmsAdminRoleRelationDaointerface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: RedisServiceinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: PmsBrandMapperinterface does not have an implementing class!
# WARNING: UmsResourceMapperinterface does not have an implementing class!
# WARNING: UmsResourceMapperinterface does not have an implementing class!
# WARNING: UmsResourceMapperinterface does not have an implementing class!
# WARNING: UmsResourceMapperinterface does not have an implementing class!
# WARNING: UmsResourceMapperinterface does not have an implementing class!
# WARNING: UmsResourceMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeDaointerface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductDaointerface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsMemberPriceMapperinterface does not have an implementing class!
# WARNING: PmsProductLadderMapperinterface does not have an implementing class!
# WARNING: PmsProductFullReductionMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeValueMapperinterface does not have an implementing class!
# WARNING: CmsSubjectProductRelationMapperinterface does not have an implementing class!
# WARNING: CmsPrefrenceAreaProductRelationMapperinterface does not have an implementing class!
# WARNING: PmsSkuStockMapperinterface does not have an implementing class!
# WARNING: PmsSkuStockMapperinterface does not have an implementing class!
# WARNING: PmsSkuStockMapperinterface does not have an implementing class!
# WARNING: PmsSkuStockMapperinterface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductVertifyRecordDaointerface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: PmsProductMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionProductRelationMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionProductRelationMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionProductRelationMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionProductRelationMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionProductRelationDaointerface does not have an implementing class!
# WARNING: SmsFlashPromotionProductRelationMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryMapperinterface does not have an implementing class!
# WARNING: PmsProductAttributeCategoryDaointerface does not have an implementing class!
# WARNING: CmsPrefrenceAreaMapperinterface does not have an implementing class!
# WARNING: UmsResourceCategoryMapperinterface does not have an implementing class!
# WARNING: UmsResourceCategoryMapperinterface does not have an implementing class!
# WARNING: UmsResourceCategoryMapperinterface does not have an implementing class!
# WARNING: UmsResourceCategoryMapperinterface does not have an implementing class!
# WARNING: PmsSkuStockMapperinterface does not have an implementing class!
# WARNING: PmsSkuStockDaointerface does not have an implementing class!
# WARNING: OmsOrderSettingMapperinterface does not have an implementing class!
# WARNING: OmsOrderSettingMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionSessionMapperinterface does not have an implementing class!
# WARNING: UmsRoleMapperinterface does not have an implementing class!
# WARNING: UmsRoleMapperinterface does not have an implementing class!
# WARNING: UmsRoleMapperinterface does not have an implementing class!
# WARNING: UmsRoleMapperinterface does not have an implementing class!
# WARNING: UmsRoleDaointerface does not have an implementing class!
# WARNING: UmsRoleDaointerface does not have an implementing class!
# WARNING: UmsRoleDaointerface does not have an implementing class!
# WARNING: UmsRoleMenuRelationMapperinterface does not have an implementing class!
# WARNING: UmsRoleMenuRelationMapperinterface does not have an implementing class!
# WARNING: UmsRoleResourceRelationMapperinterface does not have an implementing class!
# WARNING: UmsRoleResourceRelationMapperinterface does not have an implementing class!
# WARNING: OmsCompanyAddressMapperinterface does not have an implementing class!
# WARNING: CmsSubjectMapperinterface does not have an implementing class!
# WARNING: CmsSubjectMapperinterface does not have an implementing class!
# WARNING: SmsCouponMapperinterface does not have an implementing class!
# WARNING: SmsCouponProductRelationDaointerface does not have an implementing class!
# WARNING: SmsCouponProductCategoryRelationDaointerface does not have an implementing class!
# WARNING: SmsCouponMapperinterface does not have an implementing class!
# WARNING: SmsCouponProductCategoryRelationMapperinterface does not have an implementing class!
# WARNING: SmsCouponProductRelationMapperinterface does not have an implementing class!
# WARNING: SmsCouponMapperinterface does not have an implementing class!
# WARNING: SmsCouponProductRelationDaointerface does not have an implementing class!
# WARNING: SmsCouponProductCategoryRelationDaointerface does not have an implementing class!
# WARNING: SmsCouponMapperinterface does not have an implementing class!
# WARNING: SmsCouponDaointerface does not have an implementing class!
# WARNING: SmsHomeRecommendSubjectMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendSubjectMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendSubjectMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendSubjectMapperinterface does not have an implementing class!
# WARNING: SmsHomeRecommendSubjectMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminLoginLogMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminRoleRelationMapperinterface does not have an implementing class!
# WARNING: UmsAdminRoleRelationDaointerface does not have an implementing class!
# WARNING: UmsAdminRoleRelationDaointerface does not have an implementing class!
# WARNING: UmsAdminRoleRelationDaointerface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: UmsAdminMapperinterface does not have an implementing class!
# WARNING: SmsHomeAdvertiseMapperinterface does not have an implementing class!
# WARNING: SmsHomeAdvertiseMapperinterface does not have an implementing class!
# WARNING: SmsHomeAdvertiseMapperinterface does not have an implementing class!
# WARNING: SmsHomeAdvertiseMapperinterface does not have an implementing class!
# WARNING: SmsHomeAdvertiseMapperinterface does not have an implementing class!
# WARNING: SmsHomeAdvertiseMapperinterface does not have an implementing class!
# WARNING: OmsOrderDaointerface does not have an implementing class!
# WARNING: OmsOrderDaointerface does not have an implementing class!
# WARNING: OmsOrderOperateHistoryDaointerface does not have an implementing class!
# WARNING: OmsOrderMapperinterface does not have an implementing class!
# WARNING: OmsOrderOperateHistoryDaointerface does not have an implementing class!
# WARNING: OmsOrderMapperinterface does not have an implementing class!
# WARNING: OmsOrderDaointerface does not have an implementing class!
# WARNING: OmsOrderMapperinterface does not have an implementing class!
# WARNING: OmsOrderOperateHistoryMapperinterface does not have an implementing class!
# WARNING: OmsOrderMapperinterface does not have an implementing class!
# WARNING: OmsOrderOperateHistoryMapperinterface does not have an implementing class!
# WARNING: OmsOrderMapperinterface does not have an implementing class!
# WARNING: OmsOrderOperateHistoryMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionMapperinterface does not have an implementing class!
# WARNING: SmsFlashPromotionMapperinterface does not have an implementing class!
# WARNING: SmsCouponHistoryMapperinterface does not have an implementing class!
# WARNING: SmsHomeBrandMapperinterface does not have an implementing class!
# WARNING: SmsHomeBrandMapperinterface does not have an implementing class!
# WARNING: SmsHomeBrandMapperinterface does not have an implementing class!
# WARNING: SmsHomeBrandMapperinterface does not have an implementing class!
# WARNING: SmsHomeBrandMapperinterface does not have an implementing class!
# WARNING: SmsHomeNewProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeNewProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeNewProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeNewProductMapperinterface does not have an implementing class!
# WARNING: SmsHomeNewProductMapperinterface does not have an implementing class!

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['getParameter(WebLogAspect)', 'Calls', 'getAnnotation(WebLogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getParameter(WebLogAspect)', 'Calls', 'getAnnotation(WebLogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getParameter(WebLogAspect)', 'Calls', 'getName(WebLogAspect)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['login(UmsAdminServiceImpl)', 'Calls', 'generateToken(JwtTokenUtil)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refreshToken(UmsAdminServiceImpl)', 'Calls', 'refreshHeadToken(JwtTokenUtil)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['create(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['update(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCacheService(UmsAdminServiceImpl)', 'Uses', 'UmsAdminCacheService'] discarded since target entity is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['getParameter(WebLogAspect)', 'Calls', 'getAnnotation(WebLogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getParameter(WebLogAspect)', 'Calls', 'getAnnotation(WebLogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getParameter(WebLogAspect)', 'Calls', 'getName(WebLogAspect)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['login(UmsAdminServiceImpl)', 'Calls', 'generateToken(JwtTokenUtil)']: discarding
# WARNING: Unable to recover target method for edge ['refreshToken(UmsAdminServiceImpl)', 'Calls', 'refreshHeadToken(JwtTokenUtil)']: discarding
# WARNING: Unable to recover target method for edge ['create(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)']: discarding
# WARNING: Unable to recover target method for edge ['update(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)']: discarding
# WARNING: Unable to recover target method for edge ['delete(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)']: discarding

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# INFO: Edge ['getParameter(WebLogAspect)', 'Calls', 'getAnnotation(WebLogAspect)'] skipped
# INFO: Edge ['getParameter(WebLogAspect)', 'Calls', 'getAnnotation(WebLogAspect)'] skipped
# INFO: Edge ['getParameter(WebLogAspect)', 'Calls', 'getName(WebLogAspect)'] skipped
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped
# INFO: Edge ['callback(OssServiceImpl)', 'Calls', 'concat(OssServiceImpl)'] skipped
# INFO: Edge ['login(UmsAdminServiceImpl)', 'Calls', 'generateToken(JwtTokenUtil)'] skipped
# INFO: Edge ['refreshToken(UmsAdminServiceImpl)', 'Calls', 'refreshHeadToken(JwtTokenUtil)'] skipped
# INFO: Edge ['create(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)'] skipped
# INFO: Edge ['update(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)'] skipped
# INFO: Edge ['delete(UmsResourceController)', 'Calls', 'clearDataSource(DynamicSecurityMetadataSource)'] skipped

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity RestfulAccessDeniedHandler
# Removed Entity RestAuthenticationEntryPoint
# Removed Entity DynamicAccessDecisionManager
# Removed Entity RedisServiceImpl
# Removed Entity RequestUtil
# Removed Entity SwaggerProperties
# Removed Entity BaseRedisConfig
# Removed Entity BaseSwaggerConfig
# Removed Entity CommonPage
# Removed Entity ApiException
# Removed Entity Asserts
# Removed Entity Generator
# Removed Entity CommentGenerator
# Removed Entity PmsAlbumPic
# Removed Entity CmsMemberReportExample
# Removed Entity UmsRolePermissionRelationExample
# Removed Entity CmsHelpExample
# Removed Entity CmsSubjectCategory
# Removed Entity UmsMemberTaskExample
# Removed Entity UmsMemberTagExample
# Removed Entity UmsMemberLoginLog
# Removed Entity PmsAlbumExample
# Removed Entity PmsAlbum
# Removed Entity UmsMemberExample
# Removed Entity UmsMember
# Removed Entity UmsMemberProductCategoryRelation
# Removed Entity UmsMemberRuleSettingExample
# Removed Entity SmsFlashPromotionLogExample
# Removed Entity UmsGrowthChangeHistory
# Removed Entity UmsMemberReceiveAddress
# Removed Entity UmsMemberLoginLogExample
# Removed Entity UmsIntegrationChangeHistoryExample
# Removed Entity CmsHelp
# Removed Entity CmsTopicCategory
# Removed Entity CmsTopicExample
# Removed Entity CmsTopic
# Removed Entity CmsTopicCommentExample
# Removed Entity UmsAdminPermissionRelation
# Removed Entity UmsRolePermissionRelation
# Removed Entity CmsHelpCategoryExample
# Removed Entity PmsFeightTemplateExample
# Removed Entity UmsAdminLoginLogExample
# Removed Entity CmsSubjectCommentExample
# Removed Entity CmsTopicCategoryExample
# Removed Entity UmsAdminPermissionRelationExample
# Removed Entity OmsOrderItemExample
# Removed Entity UmsMemberTag
# Removed Entity UmsMemberReceiveAddressExample
# Removed Entity OmsCartItem
# Removed Entity UmsMemberStatisticsInfo
# Removed Entity PmsProductVertifyRecordExample
# Removed Entity CmsTopicComment
# Removed Entity PmsFeightTemplate
# Removed Entity PmsAlbumPicExample
# Removed Entity UmsMemberMemberTagRelationExample
# Removed Entity PmsCommentReplayExample
# Removed Entity CmsMemberReport
# Removed Entity UmsIntegrationChangeHistory
# Removed Entity PmsProductOperateLog
# Removed Entity OmsOrderSettingExample
# Removed Entity UmsMemberMemberTagRelation
# Removed Entity PmsCommentReplay
# Removed Entity PmsComment
# Removed Entity PmsCommentExample
# Removed Entity PmsProductOperateLogExample
# Removed Entity UmsIntegrationConsumeSetting
# Removed Entity UmsMemberStatisticsInfoExample
# Removed Entity UmsMemberTask
# Removed Entity UmsMemberRuleSetting
# Removed Entity UmsMemberProductCategoryRelationExample
# Removed Entity CmsHelpCategory
# Removed Entity OmsOrderOperateHistoryExample
# Removed Entity OmsCartItemExample
# Removed Entity CmsSubjectCategoryExample
# Removed Entity SmsFlashPromotionLog
# Removed Entity CmsSubjectComment
# Removed Entity UmsIntegrationConsumeSettingExample
# Removed Entity UmsPermissionExample
# Removed Entity UmsGrowthChangeHistoryExample
# Removed Entity UmsPermission
# Removed Entity PmsProductQueryParam
# Removed Entity FlagValidatorClass
# Removed cacheAspect (RedisCacheAspect)
# Removed doAround (RedisCacheAspect)
# Removed setApplicationContext (SpringUtil)
# Removed webLog (WebLogAspect)
# Removed doBefore (WebLogAspect)
# Removed doAfterReturning (WebLogAspect)
# Removed delResourceList (UmsAdminCacheServiceImpl)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
