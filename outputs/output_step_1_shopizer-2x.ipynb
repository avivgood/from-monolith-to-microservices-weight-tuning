# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'shopizer-2x' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "shopizer-2x"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# Entity		MavenWrapperDownloader		default
# Entity		ServiceException		com.salesmanager.core.business.exception
# Entity		ConversionException		com.salesmanager.core.business.exception
# Entity		SchemaConstant		com.salesmanager.core.constants
# Entity		CloneUtils		com.salesmanager.core.utils
# Entity		Secrets		com.salesmanager.core.model.security
# Entity		Country		com.salesmanager.core.model.reference.country
# Entity		CountryDescription		com.salesmanager.core.model.reference.country
# Entity		Language		com.salesmanager.core.model.reference.language
# Entity		Currency		com.salesmanager.core.model.reference.currency
# Entity		ZoneDescription		com.salesmanager.core.model.reference.zone
# Entity		Zone		com.salesmanager.core.model.reference.zone
# Entity		GeoZone		com.salesmanager.core.model.reference.geozone
# Entity		GeoZoneDescription		com.salesmanager.core.model.reference.geozone
# Entity		PermissionList		com.salesmanager.core.model.user
# Entity		PermissionCriteria		com.salesmanager.core.model.user
# Entity		Permission		com.salesmanager.core.model.user
# Entity		User		com.salesmanager.core.model.user
# Entity		Group		com.salesmanager.core.model.user
# Entity		UserCriteria		com.salesmanager.core.model.user
# Entity		ShoppingCart		com.salesmanager.core.model.shoppingcart
# Entity		ShoppingCartAttributeItem		com.salesmanager.core.model.shoppingcart
# Entity		ShoppingCartItem		com.salesmanager.core.model.shoppingcart
# Entity		InputContentFile		com.salesmanager.core.model.content
# Entity		ContentDescription		com.salesmanager.core.model.content
# Entity		Content		com.salesmanager.core.model.content
# Entity		ImageContentFile		com.salesmanager.core.model.content
# Entity		OutputContentFile		com.salesmanager.core.model.content
# Entity		ContentFile		com.salesmanager.core.model.content
# Entity		StaticContentFile		com.salesmanager.core.model.content
# Entity		TaxConfiguration		com.salesmanager.core.model.tax
# Entity		TaxItem		com.salesmanager.core.model.tax
# Entity		TaxRateDescription		com.salesmanager.core.model.tax.taxrate
# Entity		TaxRate		com.salesmanager.core.model.tax.taxrate
# Entity		TaxClass		com.salesmanager.core.model.tax.taxclass
# Entity		CreditCardPayment		com.salesmanager.core.model.payments
# Entity		BasicPayment		com.salesmanager.core.model.payments
# Entity		Payment		com.salesmanager.core.model.payments
# Entity		PaymentMethod		com.salesmanager.core.model.payments
# Entity		PaypalPayment		com.salesmanager.core.model.payments
# Entity		Transaction		com.salesmanager.core.model.payments
# Entity		GenericEntityList		com.salesmanager.core.model.common
# Entity		UserContext		com.salesmanager.core.model.common
# Entity		Delivery		com.salesmanager.core.model.common
# Entity		Criteria		com.salesmanager.core.model.common
# Entity		Billing		com.salesmanager.core.model.common
# Entity		Address		com.salesmanager.core.model.common
# Entity		EntityList		com.salesmanager.core.model.common
# Entity		AuditListener		com.salesmanager.core.model.common.audit
# Interface	Auditable		com.salesmanager.core.model.common.audit
# Entity		AuditSection		com.salesmanager.core.model.common.audit
# Entity		Description		com.salesmanager.core.model.common.description
# Entity		ShippingProduct		com.salesmanager.core.model.shipping
# Entity		ShippingOrigin		com.salesmanager.core.model.shipping
# Entity		ShippingSummary		com.salesmanager.core.model.shipping
# Entity		ShippingConfiguration		com.salesmanager.core.model.shipping
# Entity		PackageDetails		com.salesmanager.core.model.shipping
# Entity		Package		com.salesmanager.core.model.shipping
# Entity		ShippingOption		com.salesmanager.core.model.shipping
# Entity		ShippingMetaData		com.salesmanager.core.model.shipping
# Entity		Quote		com.salesmanager.core.model.shipping
# Entity		ShippingQuote		com.salesmanager.core.model.shipping
# Entity		OrderSummary		com.salesmanager.core.model.order
# Entity		OrderList		com.salesmanager.core.model.order
# Entity		OrderTotalVariation		com.salesmanager.core.model.order
# Entity		Order		com.salesmanager.core.model.order
# Entity		OrderCriteria		com.salesmanager.core.model.order
# Entity		OrderTotalSummary		com.salesmanager.core.model.order
# Entity		RebatesOrderTotalVariation		com.salesmanager.core.model.order
# Entity		OrderTotalItem		com.salesmanager.core.model.order
# Entity		OrderTotal		com.salesmanager.core.model.order
# Entity		FileHistory		com.salesmanager.core.model.order.filehistory
# Entity		OrderProductAttribute		com.salesmanager.core.model.order.orderproduct
# Entity		OrderProductDownload		com.salesmanager.core.model.order.orderproduct
# Entity		OrderProduct		com.salesmanager.core.model.order.orderproduct
# Entity		OrderProductPrice		com.salesmanager.core.model.order.orderproduct
# Entity		OrderAccount		com.salesmanager.core.model.order.orderaccount
# Entity		OrderAccountProduct		com.salesmanager.core.model.order.orderaccount
# Entity		CreditCard		com.salesmanager.core.model.order.payment
# Entity		OrderAttribute		com.salesmanager.core.model.order.attributes
# Entity		OrderStatusHistory		com.salesmanager.core.model.order.orderstatus
# Entity		MerchantStore		com.salesmanager.core.model.merchant
# Entity		MerchantStoreCriteria		com.salesmanager.core.model.merchant
# Entity		SearchEntry		com.salesmanager.core.model.search
# Entity		SearchResponse		com.salesmanager.core.model.search
# Entity		IndexProduct		com.salesmanager.core.model.search
# Entity		SearchKeywords		com.salesmanager.core.model.search
# Entity		SearchFacet		com.salesmanager.core.model.search
# Entity		IntegrationConfiguration		com.salesmanager.core.model.system
# Entity		ModuleConfig		com.salesmanager.core.model.system
# Entity		MerchantLog		com.salesmanager.core.model.system
# Entity		SystemConfiguration		com.salesmanager.core.model.system
# Entity		MerchantConfig		com.salesmanager.core.model.system
# Interface	CustomIntegrationConfiguration		com.salesmanager.core.model.system
# Entity		SystemNotification		com.salesmanager.core.model.system
# Entity		MerchantConfiguration		com.salesmanager.core.model.system
# Entity		IntegrationModule		com.salesmanager.core.model.system
# Entity		Optin		com.salesmanager.core.model.system.optin
# Entity		CustomerOptin		com.salesmanager.core.model.system.optin
# Entity		Credentials		com.salesmanager.core.model.system.credentials
# Entity		DbCredentials		com.salesmanager.core.model.system.credentials
# Entity		CustomerList		com.salesmanager.core.model.customer
# Entity		CustomerCriteria		com.salesmanager.core.model.customer
# Entity		Customer		com.salesmanager.core.model.customer
# Entity		CustomerAttribute		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionSet		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionValue		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionValueDescription		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionDescription		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOption		com.salesmanager.core.model.customer.attribute
# Entity		CustomerReview		com.salesmanager.core.model.customer.review
# Entity		CustomerReviewDescription		com.salesmanager.core.model.customer.review
# Interface	RemoteUser		com.salesmanager.core.model.customer.connection
# Entity		UserConnection		com.salesmanager.core.model.customer.connection
# Entity		AbstractUserConnectionWithCompositeKey		com.salesmanager.core.model.customer.connection
# Entity		AbstractUserConnection		com.salesmanager.core.model.customer.connection
# Entity		UserConnectionPK		com.salesmanager.core.model.customer.connection
# Entity		ProductCriteria		com.salesmanager.core.model.catalog.product
# Entity		Product		com.salesmanager.core.model.catalog.product
# Entity		ProductList		com.salesmanager.core.model.catalog.product
# Entity		DigitalProduct		com.salesmanager.core.model.catalog.product.file
# Entity		ProductOption		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductAttribute		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionSet		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductVariant		com.salesmanager.core.model.catalog.product.attribute
# Entity		AttributeCriteria		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionDescription		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionValue		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionValueDescription		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductAvailability		com.salesmanager.core.model.catalog.product.availability
# Entity		Manufacturer		com.salesmanager.core.model.catalog.product.manufacturer
# Entity		ManufacturerDescription		com.salesmanager.core.model.catalog.product.manufacturer
# Entity		ProductReviewDescription		com.salesmanager.core.model.catalog.product.review
# Entity		ProductReview		com.salesmanager.core.model.catalog.product.review
# Entity		ProductRelationship		com.salesmanager.core.model.catalog.product.relationship
# Entity		ProductPriceDescription		com.salesmanager.core.model.catalog.product.price
# Entity		FinalPrice		com.salesmanager.core.model.catalog.product.price
# Entity		ProductPrice		com.salesmanager.core.model.catalog.product.price
# Entity		ProductType		com.salesmanager.core.model.catalog.product.type
# Entity		ProductTypeDescription		com.salesmanager.core.model.catalog.product.type
# Entity		ProductDescription		com.salesmanager.core.model.catalog.product.description
# Entity		ProductImageDescription		com.salesmanager.core.model.catalog.product.image
# Entity		ProductImage		com.salesmanager.core.model.catalog.product.image
# Entity		CatalogDescription		com.salesmanager.core.model.catalog.marketplace
# Entity		MarketPlace		com.salesmanager.core.model.catalog.marketplace
# Entity		Catalog		com.salesmanager.core.model.catalog.marketplace
# Entity		Category		com.salesmanager.core.model.catalog.category
# Entity		CategoryDescription		com.salesmanager.core.model.catalog.category
# Entity		CatalogCategoryEntry		com.salesmanager.core.model.catalog.catalog
# Entity		Catalog		com.salesmanager.core.model.catalog.catalog
# Entity		SalesManagerEntity		com.salesmanager.core.model.generic
# Entity		MavenWrapperDownloader		default
# Entity		AdminFilter		com.salesmanager.shop.filter
# Entity		StoreFilter		com.salesmanager.shop.filter
# Entity		CorsFilter		com.salesmanager.shop.filter
# Excluded	ShopApplication		com.salesmanager.shop.application
# Entity		ShopServletContextListener		com.salesmanager.shop.application.config
# Excluded	WebConfig		com.salesmanager.shop.application.config
# Excluded	DocumentationConfiguration		com.salesmanager.shop.application.config
# Excluded	LocationImageConfig		com.salesmanager.shop.application.config
# Excluded	MethodSecurityConfig		com.salesmanager.shop.application.config
# Excluded	ShopApplicationConfiguration		com.salesmanager.shop.application.config
# Logic		LanguageArgumentResolver		com.salesmanager.shop.application.config
# Logic		MerchantStoreArgumentResolver		com.salesmanager.shop.application.config
# Excluded	AsyncConfig		com.salesmanager.shop.application.config
# Excluded	ShopizerPropertiesConfig		com.salesmanager.shop.application.config
# Excluded	MultipleEntryPointsSecurityConfig		com.salesmanager.shop.application.config
# Entity		ApplicationConstants		com.salesmanager.shop.constants
# Entity		Constants		com.salesmanager.shop.constants
# Entity		EmailConstants		com.salesmanager.shop.constants
# Logic		InitializationLoader		com.salesmanager.shop.init.data
# Interface	InitData		com.salesmanager.shop.init.data
# Excluded	PersistableAuditAspect		com.salesmanager.shop.populator
# Entity		ReadableShoppingCartPopulator		com.salesmanager.shop.populator.shoppingCart
# Logic		ShoppingCartModelPopulator		com.salesmanager.shop.populator.shoppingCart
# Entity		ShoppingCartDataPopulator		com.salesmanager.shop.populator.shoppingCart
# Entity		ReadablePermissionPopulator		com.salesmanager.shop.populator.security
# Entity		ReadableUserPopulator		com.salesmanager.shop.populator.user
# Logic		PersistableUserPopulator		com.salesmanager.shop.populator.user
# Entity		PersistableManufacturerPopulator		com.salesmanager.shop.populator.manufacturer
# Entity		ReadableManufacturerPopulator		com.salesmanager.shop.populator.manufacturer
# Entity		ReadableCountryPopulator		com.salesmanager.shop.populator.references
# Entity		ReadableZonePopulator		com.salesmanager.shop.populator.references
# Entity		ReadableMerchantStorePopulatorWithDetails		com.salesmanager.shop.populator.store
# Entity		ReadableMerchantStorePopulator		com.salesmanager.shop.populator.store
# Logic		PersistableMerchantStorePopulator		com.salesmanager.shop.populator.store
# Entity		ReadableShopOrderPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableShippingSummaryPopulator		com.salesmanager.shop.populator.order
# Entity		PersistableOrderPopulator		com.salesmanager.shop.populator.order
# Entity		OrderProductPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderSummaryPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderTotalPopulator		com.salesmanager.shop.populator.order
# Logic		PersistableOrderApiPopulator		com.salesmanager.shop.populator.order
# Logic		ReadableOrderPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderProductPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderProductDownloadPopulator		com.salesmanager.shop.populator.order
# Entity		PersistableOrderProductPopulator		com.salesmanager.shop.populator.order
# Entity		ShoppingCartItemPopulator		com.salesmanager.shop.populator.order
# Entity		PersistableTransactionPopulator		com.salesmanager.shop.populator.order.transaction
# Entity		PersistablePaymentPopulator		com.salesmanager.shop.populator.order.transaction
# Entity		ReadableTransactionPopulator		com.salesmanager.shop.populator.order.transaction
# Entity		ReadableOptinPopulator		com.salesmanager.shop.populator.system
# Entity		PersistableCustomerReviewPopulator		com.salesmanager.shop.populator.customer
# Logic		CustomerPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerOptionPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerDeliveryAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerShippingAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerOptionPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerOptionValuePopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerOptionPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerBillingAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerEntityPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerBillingAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerDeliveryAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerList		com.salesmanager.shop.populator.customer
# Entity		ReadableProductReviewPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerReviewPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableProductOptionValuePopulator		com.salesmanager.shop.populator.catalog
# Logic		PersistableProductPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableCategoryPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableFinalPricePopulator		com.salesmanager.shop.populator.catalog
# Entity		PersistableProductOptionPopulator		com.salesmanager.shop.populator.catalog
# Logic		PersistableCategoryPopulator		com.salesmanager.shop.populator.catalog
# Entity		PersistableProductReviewPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableProductReviewPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableProductPricePopulator		com.salesmanager.shop.populator.catalog
# Entity		PersistableProductImagePopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableProductPopulator		com.salesmanager.shop.populator.catalog
# Logic		FilesController		com.salesmanager.shop.controller
# Logic		ImagesController		com.salesmanager.shop.controller
# Logic		ReferenceController		com.salesmanager.shop.controller
# Logic		WebApplicationCacheUtils		com.salesmanager.shop.utils
# Entity		LocaleUtils		com.salesmanager.shop.utils
# Entity		MerchantUtils		com.salesmanager.shop.utils
# Entity		PageBuilderUtils		com.salesmanager.shop.utils
# Entity		BeanUtils		com.salesmanager.shop.utils
# Logic		EmailTemplatesUtils		com.salesmanager.shop.utils
# Entity		SessionUtil		com.salesmanager.shop.utils
# Logic		AppConfiguration		com.salesmanager.shop.utils
# Logic		ImageFilePathUtils		com.salesmanager.shop.utils
# Logic		AuthorizationUtils		com.salesmanager.shop.utils
# Entity		DateUtil		com.salesmanager.shop.utils
# Logic		EmailUtils		com.salesmanager.shop.utils
# Entity		LabelUtils		com.salesmanager.shop.utils
# Logic		LocalImageFilePathUtils		com.salesmanager.shop.utils
# Entity		AdminAccessDeniedHandler		com.salesmanager.shop.utils
# Entity		CategoryUtils		com.salesmanager.shop.utils
# Logic		CaptchaRequestUtils		com.salesmanager.shop.utils
# Interface	ImageFilePath		com.salesmanager.shop.utils
# Logic		CloudFilePathUtils		com.salesmanager.shop.utils
# Entity		ServiceRequestCriteriaBuilderUtils		com.salesmanager.shop.utils
# Logic		LanguageUtils		com.salesmanager.shop.utils
# Entity		GeoLocationUtils		com.salesmanager.shop.utils
# Logic		BreadcrumbsUtils		com.salesmanager.shop.utils
# Entity		TokenizeTool		com.salesmanager.shop.utils
# Logic		FilePathUtils		com.salesmanager.shop.utils
# Entity		AbstractimageFilePath		com.salesmanager.shop.utils
# Entity		FieldMatchValidator		com.salesmanager.shop.utils
# Entity		UserUtils		com.salesmanager.shop.utils
# Entity		EnumValidator		com.salesmanager.shop.utils
# Entity		ShopProductImageUrlTag		com.salesmanager.shop.tags
# Entity		ContentImageUrlTag		com.salesmanager.shop.tags
# Entity		ShopProductRelationshipTag		com.salesmanager.shop.tags
# Entity		OrderProductDownloadUrlTag		com.salesmanager.shop.tags
# Entity		ShopProductPriceFormatTag		com.salesmanager.shop.tags
# Entity		ProductImageUrlTag		com.salesmanager.shop.tags
# Entity		ActiveLinkTag		com.salesmanager.shop.tags
# Entity		ConfigurationTag		com.salesmanager.shop.tags
# Entity		PageContentTag		com.salesmanager.shop.tags
# Entity		StoreLogoUrlTag		com.salesmanager.shop.tags
# Entity		ProductDescriptionUrlTag		com.salesmanager.shop.tags
# Entity		StoreBreadcrumbsTag		com.salesmanager.shop.tags
# Entity		AdminProductDownloadUrlTag		com.salesmanager.shop.tags
# Entity		ManufacturerImageUrlTag		com.salesmanager.shop.tags
# Entity		StoreFooterlTag		com.salesmanager.shop.tags
# Entity		PageInformation		com.salesmanager.shop.model.shop
# Entity		Breadcrumb		com.salesmanager.shop.model.shop
# Entity		BreadcrumbItem		com.salesmanager.shop.model.shop
# Entity		ContactForm		com.salesmanager.shop.model.shop
# Interface	Mapper		com.salesmanager.shop.mapper
# Logic		ReadableOptinMapper		com.salesmanager.shop.mapper.optin
# Logic		PersistableOptinMapper		com.salesmanager.shop.mapper.optin
# Logic		ReadableTaxRateMapper		com.salesmanager.shop.mapper.tax
# Logic		PersistableTaxRateMapper		com.salesmanager.shop.mapper.tax
# Logic		PersistableTaxClassMapper		com.salesmanager.shop.mapper.tax
# Logic		ReadableTaxClassMapper		com.salesmanager.shop.mapper.tax
# Logic		PersistableInventoryMapper		com.salesmanager.shop.mapper.inventory
# Logic		ReadableInventoryMapper		com.salesmanager.shop.mapper.inventory
# Logic		PersistableProductAttributeMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductOptionSetMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableCatalogCategoryEntryMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableCatalogCategoryEntryMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductOptionMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableCatalogMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductOptionValueMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductOptionValueMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductOptionSetMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableCategoryMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductTypeMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductAttributeMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductOptionMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableCatalogMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableManufacturerMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductTypeMapper		com.salesmanager.shop.mapper.catalog
# Entity		PasswordRequest		com.salesmanager.shop.store.security
# Logic		JWTTokenUtil		com.salesmanager.shop.store.security
# Entity		ServicesAuthenticationEntryPoint		com.salesmanager.shop.store.security
# Logic		RestAuthenticationEntryPoint		com.salesmanager.shop.store.security
# Entity		AuthenticationRequest		com.salesmanager.shop.store.security
# Logic		CustomerServicesImpl		com.salesmanager.shop.store.security
# Entity		ServicesAuthenticationSuccessHandler		com.salesmanager.shop.store.security
# Entity		AuthenticationTokenFilter		com.salesmanager.shop.store.security
# Entity		AbstractCustomerServices		com.salesmanager.shop.store.security
# Entity		ResetPasswordRequest		com.salesmanager.shop.store.security
# Entity		AuthenticationResponse		com.salesmanager.shop.store.security
# Logic		SocialCustomerServicesImpl		com.salesmanager.shop.store.security
# Entity		JWTUser		com.salesmanager.shop.store.security.user
# Entity		CustomerDetails		com.salesmanager.shop.store.security.user
# Entity		CustomAuthenticationManager		com.salesmanager.shop.store.security.common
# Entity		CustomAuthenticationException		com.salesmanager.shop.store.security.common
# Entity		JWTAdminAuthenticationProvider		com.salesmanager.shop.store.security.admin
# Logic		JWTAdminAuthenticationManager		com.salesmanager.shop.store.security.admin
# Logic		JWTAdminServicesImpl		com.salesmanager.shop.store.security.admin
# Entity		AdminAccessDeniedHandler		com.salesmanager.shop.store.security.admin
# Entity		JWTCustomerAuthenticationProvider		com.salesmanager.shop.store.security.customer
# Logic		JWTCustomerServicesImpl		com.salesmanager.shop.store.security.customer
# Logic		JWTCustomerAuthenticationManager		com.salesmanager.shop.store.security.customer
# Logic		LandingController		com.salesmanager.shop.store.controller
# Interface	ControllerConstants		com.salesmanager.shop.store.controller
# Entity		AbstractController		com.salesmanager.shop.store.controller
# Logic		MiniCartController		com.salesmanager.shop.store.controller.shoppingCart
# Logic		ShoppingCartController		com.salesmanager.shop.store.controller.shoppingCart
# Logic		ShoppingCartFacadeImpl		com.salesmanager.shop.store.controller.shoppingCart.facade
# Interface	ShoppingCartFacade		com.salesmanager.shop.store.controller.shoppingCart.facade
# Logic		SecurityFacadeImpl		com.salesmanager.shop.store.controller.security.facade
# Interface	SecurityFacade		com.salesmanager.shop.store.controller.security.facade
# Interface	CountryFacade		com.salesmanager.shop.store.controller.country.facade
# Logic		CountryFacadeImpl		com.salesmanager.shop.store.controller.country.facade
# Logic		ShopProductController		com.salesmanager.shop.store.controller.product
# Logic		UserFacadeImpl		com.salesmanager.shop.store.controller.user.facade
# Interface	LanguageFacade		com.salesmanager.shop.store.controller.language.facade
# Logic		LanguageFacadeImpl		com.salesmanager.shop.store.controller.language.facade
# Logic		ShopContentController		com.salesmanager.shop.store.controller.content
# Interface	MarketPlaceFacade		com.salesmanager.shop.store.controller.marketplace.facade
# Logic		MarketPlaceFacadeImpl		com.salesmanager.shop.store.controller.marketplace.facade
# Logic		OptinFacadeImpl		com.salesmanager.shop.store.controller.optin
# Interface	OptinFacade		com.salesmanager.shop.store.controller.optin
# Logic		ListItemsController		com.salesmanager.shop.store.controller.items
# Interface	CurrencyFacade		com.salesmanager.shop.store.controller.currency.facade
# Logic		CurrencyFacadeImpl		com.salesmanager.shop.store.controller.currency.facade
# Logic		ContactController		com.salesmanager.shop.store.controller.store
# Interface	StoreFacade		com.salesmanager.shop.store.controller.store.facade
# Logic		StoreFacadeImpl		com.salesmanager.shop.store.controller.store.facade
# Excluded	AdminErrorController		com.salesmanager.shop.store.controller.error
# Excluded	ShopErrorController		com.salesmanager.shop.store.controller.error
# Logic		ShippingFacadeImpl		com.salesmanager.shop.store.controller.shipping.facade
# Logic		ShoppingCategoryController		com.salesmanager.shop.store.controller.category
# Logic		ShoppingOrderController		com.salesmanager.shop.store.controller.order
# Logic		ShoppingOrderConfirmationController		com.salesmanager.shop.store.controller.order
# Logic		ShoppingOrderPaymentController		com.salesmanager.shop.store.controller.order
# Logic		ShoppingOrderDownloadController		com.salesmanager.shop.store.controller.order
# Logic		OrderFacadeImpl		com.salesmanager.shop.store.controller.order.facade
# Interface	OrderFacade		com.salesmanager.shop.store.controller.order.facade
# Logic		SearchController		com.salesmanager.shop.store.controller.search
# Logic		SearchFacadeImpl		com.salesmanager.shop.store.controller.search.facade
# Interface	SearchFacade		com.salesmanager.shop.store.controller.search.facade
# Interface	MerchantConfigurationFacade		com.salesmanager.shop.store.controller.system
# Logic		MerchantConfigurationFacadeImpl		com.salesmanager.shop.store.controller.system
# Interface	ZoneFacade		com.salesmanager.shop.store.controller.zone.facade
# Logic		ZoneFacadeImpl		com.salesmanager.shop.store.controller.zone.facade
# Logic		CustomerLoginController		com.salesmanager.shop.store.controller.customer
# Logic		CustomerProductReviewController		com.salesmanager.shop.store.controller.customer
# Logic		CustomerAccountController		com.salesmanager.shop.store.controller.customer
# Logic		CustomerRegistrationController		com.salesmanager.shop.store.controller.customer
# Logic		CustomerOrdersController		com.salesmanager.shop.store.controller.customer
# Logic		CustomerDashboardController		com.salesmanager.shop.store.controller.customer
# Interface	CustomerFacade		com.salesmanager.shop.store.controller.customer.facade
# Logic		CustomerFacadeImpl		com.salesmanager.shop.store.controller.customer.facade
# Logic		ProductOptionFacadeImpl		com.salesmanager.shop.store.facade.product
# Logic		ProductTypeFacadeImpl		com.salesmanager.shop.store.facade.product
# Logic		ProductInventoryFacadeImpl		com.salesmanager.shop.store.facade.product
# Logic		ProductOptionSetFacadeImpl		com.salesmanager.shop.store.facade.product
# Logic		ProductFacadeImpl		com.salesmanager.shop.store.facade.product
# Logic		ContentFacadeImpl		com.salesmanager.shop.store.facade.content
# Logic		ManufacturerFacadeImpl		com.salesmanager.shop.store.facade.manufacturer
# Logic		PaymentConfigurationFacadeImpl		com.salesmanager.shop.store.facade.payment
# Logic		TaxFacadeImpl		com.salesmanager.shop.store.facade.tax
# Logic		ProductItemsFacadeImpl		com.salesmanager.shop.store.facade.items
# Entity		AbstractConfigurationFacadeImpl		com.salesmanager.shop.store.facade.configuration
# Logic		ShippingConfigurationFacadeImpl		com.salesmanager.shop.store.facade.shipping
# Logic		CategoryFacadeImpl		com.salesmanager.shop.store.facade.category
# Logic		CatalogFacadeImpl		com.salesmanager.shop.store.facade.catalog
# Entity		PaginationData		com.salesmanager.shop.store.model.paging
# Entity		QueryFilter		com.salesmanager.shop.store.model.filter
# Entity		AutoCompleteRequest		com.salesmanager.shop.store.model.search
# Entity		Attribute		com.salesmanager.shop.store.model.catalog
# Entity		AttributeValue		com.salesmanager.shop.store.model.catalog
# Logic		ProductItemsRESTController		com.salesmanager.shop.store.api.v0.product
# Logic		ShopProductRESTController		com.salesmanager.shop.store.api.v0.product
# Logic		StoreContactRESTController		com.salesmanager.shop.store.api.v0.store
# Logic		ShoppingCategoryRESTController		com.salesmanager.shop.store.api.v0.category
# Logic		OrderRESTController		com.salesmanager.shop.store.api.v0.order
# Logic		SearchRESTController		com.salesmanager.shop.store.api.v0.search
# Logic		SystemRESTController		com.salesmanager.shop.store.api.v0.system
# Logic		CustomerRESTController		com.salesmanager.shop.store.api.v0.customer
# Logic		ShoppingCartApi		com.salesmanager.shop.store.api.v1.shoppingCart
# Logic		SecurityApi		com.salesmanager.shop.store.api.v1.security
# Logic		ConfigurationsApi		com.salesmanager.shop.store.api.v1.configurations
# Logic		CacheApi		com.salesmanager.shop.store.api.v1.configurations
# Logic		ProductImageApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductTypeApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductReviewApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductVariantApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductGroupApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductInventoryApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductOptionSetApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductOptionApi		com.salesmanager.shop.store.api.v1.product
# Logic		ManufacturerApi		com.salesmanager.shop.store.api.v1.product
# Logic		ProductRelationshipApi		com.salesmanager.shop.store.api.v1.product
# Logic		AuthenticateUserApi		com.salesmanager.shop.store.api.v1.user
# Logic		ResetUserPasswordApi		com.salesmanager.shop.store.api.v1.user
# Logic		UserApi		com.salesmanager.shop.store.api.v1.user
# Logic		ContentAdministrationApi		com.salesmanager.shop.store.api.v1.content
# Logic		ContentApi		com.salesmanager.shop.store.api.v1.content
# Logic		ReferencesApi		com.salesmanager.shop.store.api.v1.references
# Logic		PaymentApi		com.salesmanager.shop.store.api.v1.payment
# Logic		MarketPlaceApi		com.salesmanager.shop.store.api.v1.marketplace
# Logic		TaxRatesApi		com.salesmanager.shop.store.api.v1.tax
# Logic		TaxClassApi		com.salesmanager.shop.store.api.v1.tax
# Logic		MerchantStoreApi		com.salesmanager.shop.store.api.v1.store
# Logic		ShippingConfigurationApi		com.salesmanager.shop.store.api.v1.shipping
# Logic		ShippingExpeditionApi		com.salesmanager.shop.store.api.v1.shipping
# Logic		CategoryApi		com.salesmanager.shop.store.api.v1.category
# Logic		OrderTotalApi		com.salesmanager.shop.store.api.v1.order
# Logic		OrderShippingApi		com.salesmanager.shop.store.api.v1.order
# Logic		OrderApi		com.salesmanager.shop.store.api.v1.order
# Logic		OrderStatusHistoryApi		com.salesmanager.shop.store.api.v1.order
# Logic		OrderPaymentApi		com.salesmanager.shop.store.api.v1.order
# Logic		SearchApi		com.salesmanager.shop.store.api.v1.search
# Logic		PublicConfigsApi		com.salesmanager.shop.store.api.v1.system
# Logic		ModulesApi		com.salesmanager.shop.store.api.v1.system
# Logic		OptinApi		com.salesmanager.shop.store.api.v1.system
# Logic		ContactApi		com.salesmanager.shop.store.api.v1.system
# Logic		CustomerReviewApi		com.salesmanager.shop.store.api.v1.customer
# Logic		CustomerApi		com.salesmanager.shop.store.api.v1.customer
# Logic		AuthenticateCustomerApi		com.salesmanager.shop.store.api.v1.customer
# Logic		CustomerNewsletterApi		com.salesmanager.shop.store.api.v1.customer
# Logic		CatalogApi		com.salesmanager.shop.store.api.v1.catalog
# Entity		ServiceRuntimeException		com.salesmanager.shop.store.api.exception
# Entity		ErrorEntity		com.salesmanager.shop.store.api.exception
# Entity		OperationNotAllowedException		com.salesmanager.shop.store.api.exception
# Entity		UnauthorizedException		com.salesmanager.shop.store.api.exception
# Entity		RestApiException		com.salesmanager.shop.store.api.exception
# Entity		GenericRuntimeException		com.salesmanager.shop.store.api.exception
# Entity		ConversionRuntimeException		com.salesmanager.shop.store.api.exception
# Entity		ResourceNotFoundException		com.salesmanager.shop.store.api.exception
# Excluded	RestErrorHandler		com.salesmanager.shop.store.api.exception
# Entity		ApiUserAuthenticationSuccessHandler		com.salesmanager.shop.admin.security
# Entity		SecurityQuestion		com.salesmanager.shop.admin.security
# Entity		SecurityDataAccessException		com.salesmanager.shop.admin.security
# Entity		UserAuthenticationSuccessHandler		com.salesmanager.shop.admin.security
# Entity		AbstractAuthenticatinSuccessHandler		com.salesmanager.shop.admin.security
# Logic		UserServicesImpl		com.salesmanager.shop.admin.security
# Interface	WebUserServices		com.salesmanager.shop.admin.security
# Interface	ControllerConstants		com.salesmanager.shop.admin.controller
# Logic		AdminController		com.salesmanager.shop.admin.controller
# Logic		ConfigurationController		com.salesmanager.shop.admin.controller.configurations
# Logic		SystemConfigurationController		com.salesmanager.shop.admin.controller.configurations
# Logic		CacheController		com.salesmanager.shop.admin.controller.configurations
# Logic		SecurityController		com.salesmanager.shop.admin.controller.user
# Logic		LoginController		com.salesmanager.shop.admin.controller.user
# Logic		GroupsController		com.salesmanager.shop.admin.controller.user
# Logic		UserController		com.salesmanager.shop.admin.controller.user
# Logic		PermissionController		com.salesmanager.shop.admin.controller.user
# Logic		ContentBoxesController		com.salesmanager.shop.admin.controller.content
# Logic		ContentImageController		com.salesmanager.shop.admin.controller.content
# Logic		StaticContentController		com.salesmanager.shop.admin.controller.content
# Logic		ContentPagesController		com.salesmanager.shop.admin.controller.content
# Logic		ProductAttributeController		com.salesmanager.shop.admin.controller.products
# Logic		RelatedItemsController		com.salesmanager.shop.admin.controller.products
# Logic		ProductReviewController		com.salesmanager.shop.admin.controller.products
# Logic		FeaturedItemsController		com.salesmanager.shop.admin.controller.products
# Logic		CustomProductGroupsController		com.salesmanager.shop.admin.controller.products
# Logic		ProductsController		com.salesmanager.shop.admin.controller.products
# Logic		DigitalProductController		com.salesmanager.shop.admin.controller.products
# Logic		ManufacturerController		com.salesmanager.shop.admin.controller.products
# Logic		ProductController		com.salesmanager.shop.admin.controller.products
# Logic		OptionsValueController		com.salesmanager.shop.admin.controller.products
# Logic		ProductPriceController		com.salesmanager.shop.admin.controller.products
# Logic		OptionsController		com.salesmanager.shop.admin.controller.products
# Logic		ProductImagesController		com.salesmanager.shop.admin.controller.products
# Logic		ProductKeywordsController		com.salesmanager.shop.admin.controller.products
# Logic		CategoryController		com.salesmanager.shop.admin.controller.categories
# Logic		TaxRatesController		com.salesmanager.shop.admin.controller.tax
# Logic		TaxConfigurationController		com.salesmanager.shop.admin.controller.tax
# Logic		TaxClassController		com.salesmanager.shop.admin.controller.tax
# Logic		PaymentsController		com.salesmanager.shop.admin.controller.payments
# Logic		OrderActionsControler		com.salesmanager.shop.admin.controller.orders
# Logic		OrdersController		com.salesmanager.shop.admin.controller.orders
# Logic		OrderControler		com.salesmanager.shop.admin.controller.orders
# Logic		ShippingPackagingController		com.salesmanager.shop.admin.controller.shipping
# Logic		CustomShippingMethodsController		com.salesmanager.shop.admin.controller.shipping
# Logic		ShippingConfigsController		com.salesmanager.shop.admin.controller.shipping
# Logic		ShippingMethodsController		com.salesmanager.shop.admin.controller.shipping
# Logic		ShippingOriginController		com.salesmanager.shop.admin.controller.shipping
# Logic		ShippingOptionsController		com.salesmanager.shop.admin.controller.shipping
# Logic		StoreLandingController		com.salesmanager.shop.admin.controller.merchant
# Logic		MerchantStoreController		com.salesmanager.shop.admin.controller.merchant
# Logic		StoreBrandingController		com.salesmanager.shop.admin.controller.merchant
# Logic		CustomerOptionsSetController		com.salesmanager.shop.admin.controller.customers
# Logic		CustomerOptionsValueController		com.salesmanager.shop.admin.controller.customers
# Logic		CustomerOptionsController		com.salesmanager.shop.admin.controller.customers
# Logic		CustomerController		com.salesmanager.shop.admin.controller.customers
# Entity		Password		com.salesmanager.shop.admin.model.secutity
# Entity		Weight		com.salesmanager.shop.admin.model.reference
# Entity		Size		com.salesmanager.shop.admin.model.reference
# Entity		ProductImages		com.salesmanager.shop.admin.model.content
# Entity		ContentFiles		com.salesmanager.shop.admin.model.content
# Entity		ProductFiles		com.salesmanager.shop.admin.model.digital
# Entity		GroupDetails		com.salesmanager.shop.admin.model.permission
# Entity		ShopGroup		com.salesmanager.shop.admin.model.permission
# Entity		ShopPermission		com.salesmanager.shop.admin.model.permission
# Entity		Permissions		com.salesmanager.shop.admin.model.permission
# Entity		Order		com.salesmanager.shop.admin.model.orders
# Entity		Refund		com.salesmanager.shop.admin.model.orders
# Entity		UserReset		com.salesmanager.shop.admin.model.userpassword
# Entity		StoreLandingDescription		com.salesmanager.shop.admin.model.merchant
# Entity		StoreLanding		com.salesmanager.shop.admin.model.merchant
# Entity		Menu		com.salesmanager.shop.admin.model.web
# Entity		ConfigListWrapper		com.salesmanager.shop.admin.model.web
# Entity		CustomerOptionValue		com.salesmanager.shop.admin.model.customer.attribute
# Entity		CustomerOption		com.salesmanager.shop.admin.model.customer.attribute
# Entity		CustomerAttributes		com.salesmanager.shop.admin.model.customer.attribute
# Entity		Manufacturer		com.salesmanager.shop.admin.model.catalog
# Entity		Category		com.salesmanager.shop.admin.model.catalog
# Entity		ProductPrice		com.salesmanager.shop.admin.model.catalog
# Entity		Product		com.salesmanager.shop.admin.model.catalog
# Entity		Keyword		com.salesmanager.shop.admin.model.catalog
# Entity		MavenWrapperDownloader		default
# Entity		IntegrationException		com.salesmanager.core.business.modules.integration
# Entity		BeanStreamPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		StripePayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		PayPalExpressCheckoutPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		BraintreePayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		MoneyOrderPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		PayPalRestPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		Stripe3Payment		com.salesmanager.core.business.modules.integration.payment.impl
# Logic		ShippingDistancePreProcessorImpl		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		UPSShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		UPSParsedElements		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		CustomWeightBasedShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		StorePickupShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		DecisionResponse		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		ShippingDecisionPreProcessorImpl		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		ShippingInputParameters		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		DefaultPackagingImpl		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		PackingBox		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		PriceByDistanceShippingQuoteRules		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		USPSShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		USPSParsedElements		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		CustomShippingQuoteRules		com.salesmanager.core.business.modules.integration.shipping.impl
# Interface	HtmlEmailSender		com.salesmanager.core.business.modules.email
# Logic		EmailComponent		com.salesmanager.core.business.modules.email
# Interface	EmailModule		com.salesmanager.core.business.modules.email
# Entity		EmailConfig		com.salesmanager.core.business.modules.email
# Logic		SESEmailSenderImpl		com.salesmanager.core.business.modules.email
# Logic		DefaultEmailSenderImpl		com.salesmanager.core.business.modules.email
# Entity		Email		com.salesmanager.core.business.modules.email
# Entity		EncryptionImpl		com.salesmanager.core.business.modules.utils
# Entity		GeoLocationImpl		com.salesmanager.core.business.modules.utils
# Interface	ShoppingCartProcessor		com.salesmanager.core.business.modules.cart
# Logic		IndexShoppingCartProcessor		com.salesmanager.core.business.modules.cart
# Interface	FunctionProcessor		com.salesmanager.core.business.modules.common
# Entity		IndexEntityProcessor		com.salesmanager.core.business.modules.common
# Entity		ProductFileManagerImpl		com.salesmanager.core.business.modules.cms.product
# Entity		ProductFileManager		com.salesmanager.core.business.modules.cms.product
# Interface	ProductImagePut		com.salesmanager.core.business.modules.cms.product
# Interface	ProductAssetsManager		com.salesmanager.core.business.modules.cms.product
# Interface	ProductImageGet		com.salesmanager.core.business.modules.cms.product
# Interface	ProductImageRemove		com.salesmanager.core.business.modules.cms.product
# Logic		GCPProductContentFileManager		com.salesmanager.core.business.modules.cms.product.gcp
# Entity		CmsImageFileManagerImpl		com.salesmanager.core.business.modules.cms.product.infinispan
# Entity		CmsImageFileManagerImpl		com.salesmanager.core.business.modules.cms.product.local
# Entity		S3ProductContentFileManager		com.salesmanager.core.business.modules.cms.product.aws
# Interface	CMSManager		com.salesmanager.core.business.modules.cms.impl
# Entity		DownloadCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		VendorCacheManager		com.salesmanager.core.business.modules.cms.impl
# Logic		GCPCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		StoreCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Interface	CacheManager		com.salesmanager.core.business.modules.cms.impl
# Entity		StaticContentCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		S3CacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		CacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		LocalCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Interface	FileGet		com.salesmanager.core.business.modules.cms.content
# Entity		StaticContentFileManagerImpl		com.salesmanager.core.business.modules.cms.content
# Interface	FileRemove		com.salesmanager.core.business.modules.cms.content
# Interface	FolderRemove		com.salesmanager.core.business.modules.cms.content
# Interface	FolderPut		com.salesmanager.core.business.modules.cms.content
# Interface	FolderList		com.salesmanager.core.business.modules.cms.content
# Interface	ContentAssetsManager		com.salesmanager.core.business.modules.cms.content
# Interface	ContentImageGet		com.salesmanager.core.business.modules.cms.content
# Interface	ImagePut		com.salesmanager.core.business.modules.cms.content
# Entity		StaticContentFileManager		com.salesmanager.core.business.modules.cms.content
# Interface	ContentImageRemove		com.salesmanager.core.business.modules.cms.content
# Interface	FilePut		com.salesmanager.core.business.modules.cms.content
# Logic		GCPStaticContentAssetsManagerImpl		com.salesmanager.core.business.modules.cms.content.gcp
# Logic		GCPDownloadsManagerImpl		com.salesmanager.core.business.modules.cms.content.gcp
# Entity		CmsStaticContentFileManagerImpl		com.salesmanager.core.business.modules.cms.content.infinispan
# Entity		CmsStaticContentFileManagerImpl		com.salesmanager.core.business.modules.cms.content.local
# Entity		S3StaticContentAssetsManagerImpl		com.salesmanager.core.business.modules.cms.content.aws
# Interface	ImageRemove		com.salesmanager.core.business.modules.cms.common
# Interface	AssetsManager		com.salesmanager.core.business.modules.cms.common
# Interface	ImageGet		com.salesmanager.core.business.modules.cms.common
# Entity		StaticContentData		com.salesmanager.core.business.modules.cms.common
# Entity		ODSInvoiceModule		com.salesmanager.core.business.modules.order
# Interface	OrderProcessor		com.salesmanager.core.business.modules.order
# Interface	InvoiceModule		com.salesmanager.core.business.modules.order
# Logic		IndexOrderProcessor		com.salesmanager.core.business.modules.order
# Logic		PromoCodeCalculatorModule		com.salesmanager.core.business.modules.order.total
# Entity		OrderTotalInputParameters		com.salesmanager.core.business.modules.order.total
# Entity		OrderTotalResponse		com.salesmanager.core.business.modules.order.total
# Logic		ManufacturerShippingCodeOrderTotalModuleImpl		com.salesmanager.core.business.modules.order.total
# Entity		ShippingConstants		com.salesmanager.core.business.constants
# Entity		Constants		com.salesmanager.core.business.constants
# Entity		SystemConstants		com.salesmanager.core.business.constants
# Interface	CountryRepository		com.salesmanager.core.business.repositories.reference.country
# Interface	LanguageRepository		com.salesmanager.core.business.repositories.reference.language
# Interface	CurrencyRepository		com.salesmanager.core.business.repositories.reference.currency
# Interface	ZoneRepository		com.salesmanager.core.business.repositories.reference.zone
# Interface	PermissionRepository		com.salesmanager.core.business.repositories.user
# Interface	GroupRepository		com.salesmanager.core.business.repositories.user
# Interface	PermissionRepositoryCustom		com.salesmanager.core.business.repositories.user
# Interface	PageableUserRepository		com.salesmanager.core.business.repositories.user
# Interface	UserRepository		com.salesmanager.core.business.repositories.user
# Entity		UserRepositoryImpl		com.salesmanager.core.business.repositories.user
# Interface	UserRepositoryCustom		com.salesmanager.core.business.repositories.user
# Entity		PermissionRepositoryImpl		com.salesmanager.core.business.repositories.user
# Interface	ShoppingCartItemRepository		com.salesmanager.core.business.repositories.shoppingcart
# Interface	ShoppingCartAttributeRepository		com.salesmanager.core.business.repositories.shoppingcart
# Interface	ShoppingCartRepository		com.salesmanager.core.business.repositories.shoppingcart
# Entity		ContentRepositoryImpl		com.salesmanager.core.business.repositories.content
# Interface	ContentRepositoryCustom		com.salesmanager.core.business.repositories.content
# Interface	ContentRepository		com.salesmanager.core.business.repositories.content
# Interface	TaxRateRepository		com.salesmanager.core.business.repositories.tax
# Interface	TaxClassRepository		com.salesmanager.core.business.repositories.tax
# Interface	TransactionRepository		com.salesmanager.core.business.repositories.payments
# Interface	ShippingOriginRepository		com.salesmanager.core.business.repositories.shipping
# Interface	ShippingQuoteRepository		com.salesmanager.core.business.repositories.shipping
# Interface	OrderRepositoryCustom		com.salesmanager.core.business.repositories.order
# Entity		OrderRepositoryImpl		com.salesmanager.core.business.repositories.order
# Interface	OrderTotalRepository		com.salesmanager.core.business.repositories.order
# Interface	OrderRepository		com.salesmanager.core.business.repositories.order
# Interface	OrderProductRepository		com.salesmanager.core.business.repositories.order.orderproduct
# Interface	OrderProductDownloadRepository		com.salesmanager.core.business.repositories.order.orderproduct
# Interface	OrderAccountRepository		com.salesmanager.core.business.repositories.order.orderaccount
# Interface	MerchantRepository		com.salesmanager.core.business.repositories.merchant
# Interface	PageableMerchantRepository		com.salesmanager.core.business.repositories.merchant
# Interface	MerchantRepositoryCustom		com.salesmanager.core.business.repositories.merchant
# Entity		MerchantRepositoryImpl		com.salesmanager.core.business.repositories.merchant
# Interface	SystemConfigurationRepository		com.salesmanager.core.business.repositories.system
# ...
# Entity		ReadableTaxRateDescription		com.salesmanager.shop.model.tax
# Entity		PersistableTaxClass		com.salesmanager.shop.model.tax
# Entity		ReadableTaxClass		com.salesmanager.shop.model.tax
# Entity		PersistableTaxRate		com.salesmanager.shop.model.tax
# Entity		ReadableTaxRateFull		com.salesmanager.shop.model.tax
# Entity		ReadableTaxRate		com.salesmanager.shop.model.tax
# Entity		TaxRateEntity		com.salesmanager.shop.model.tax
# Entity		TaxClassEntity		com.salesmanager.shop.model.tax
# Entity		MerchantStoreBrand		com.salesmanager.shop.model.store
# Entity		PersistableMerchantStore		com.salesmanager.shop.model.store
# Entity		MerchantStoreEntity		com.salesmanager.shop.model.store
# Entity		ReadableBrand		com.salesmanager.shop.model.store
# Entity		PersistableBrand		com.salesmanager.shop.model.store
# Entity		ReadableMerchantStore		com.salesmanager.shop.model.store
# Entity		ReadableMerchantStoreList		com.salesmanager.shop.model.store
# Entity		MerchantConfigEntity		com.salesmanager.shop.model.store
# Entity		ShopEntity		com.salesmanager.shop.model.entity
# Entity		ValueList		com.salesmanager.shop.model.entity
# Entity		ListCriteria		com.salesmanager.shop.model.entity
# Interface	ResourceUrlAccess		com.salesmanager.shop.model.entity
# Entity		ReadableEntityList		com.salesmanager.shop.model.entity
# Entity		ReadableList		com.salesmanager.shop.model.entity
# Interface	ReadableAuditable		com.salesmanager.shop.model.entity
# Entity		UniqueEntity		com.salesmanager.shop.model.entity
# Entity		Entity		com.salesmanager.shop.model.entity
# Entity		EntityExists		com.salesmanager.shop.model.entity
# Entity		ReadableEntity		com.salesmanager.shop.model.entity
# Entity		ReadableAudit		com.salesmanager.shop.model.entity
# Entity		ServiceEntity		com.salesmanager.shop.model.entity
# Entity		PersistableConfiguration		com.salesmanager.shop.model.configuration
# Entity		ConfigurationEntity		com.salesmanager.shop.model.configuration
# Entity		ReadableConfiguration		com.salesmanager.shop.model.configuration
# Entity		BoxConfiguration		com.salesmanager.shop.model.shipping
# Entity		ExpeditionConfiguration		com.salesmanager.shop.model.shipping
# Entity		ShippingConfiguration		com.salesmanager.shop.model.shipping
# Entity		OrderProductEntity		com.salesmanager.shop.model.order
# Entity		ShopOrder		com.salesmanager.shop.model.order
# Entity		PersistableOrderProduct		com.salesmanager.shop.model.order
# Entity		ReadableOrderProduct		com.salesmanager.shop.model.order
# Entity		OrderAttribute		com.salesmanager.shop.model.order
# Entity		ReadableOrderProductAttribute		com.salesmanager.shop.model.order
# Entity		ReadableShopOrder		com.salesmanager.shop.model.order
# Entity		OrderEntity		com.salesmanager.shop.model.order
# Entity		ReadableOrderProductDownload		com.salesmanager.shop.model.order
# Entity		OrderProduct		com.salesmanager.shop.model.order
# Entity		ReadableOrderTotalSummary		com.salesmanager.shop.model.order
# Entity		Order		com.salesmanager.shop.model.order.v0
# Entity		ReadableOrderList		com.salesmanager.shop.model.order.v0
# Entity		PersistableOrder		com.salesmanager.shop.model.order.v0
# Entity		ReadableOrder		com.salesmanager.shop.model.order.v0
# Entity		ReadableTotal		com.salesmanager.shop.model.order.total
# Entity		ReadableOrderTotal		com.salesmanager.shop.model.order.total
# Entity		OrderTotal		com.salesmanager.shop.model.order.total
# Entity		ReadableOrderStatusHistory		com.salesmanager.shop.model.order.history
# Entity		OrderStatusHistory		com.salesmanager.shop.model.order.history
# Entity		PersistableOrderStatusHistory		com.salesmanager.shop.model.order.history
# Entity		PersistableAnonymousOrder		com.salesmanager.shop.model.order.v1
# Entity		Order		com.salesmanager.shop.model.order.v1
# Entity		ReadableOrderList		com.salesmanager.shop.model.order.v1
# Entity		PersistableOrder		com.salesmanager.shop.model.order.v1
# Entity		ReadableOrder		com.salesmanager.shop.model.order.v1
# Entity		ReadableShippingSummary		com.salesmanager.shop.model.order.shipping
# Entity		TransactionEntity		com.salesmanager.shop.model.order.transaction
# Entity		PersistablePayment		com.salesmanager.shop.model.order.transaction
# Entity		ReadablePayment		com.salesmanager.shop.model.order.transaction
# Entity		PaymentEntity		com.salesmanager.shop.model.order.transaction
# Entity		PersistableTransaction		com.salesmanager.shop.model.order.transaction
# Entity		ReadableTransaction		com.salesmanager.shop.model.order.transaction
# Entity		OptinEntity		com.salesmanager.shop.model.system
# Entity		Optin		com.salesmanager.shop.model.system
# Entity		IntegrationModuleEntity		com.salesmanager.shop.model.system
# Entity		Configs		com.salesmanager.shop.model.system
# Entity		PersistableOptin		com.salesmanager.shop.model.system
# Entity		ReadableOptin		com.salesmanager.shop.model.system
# Entity		PersistableCustomerReview		com.salesmanager.shop.model.customer
# Entity		ReadableDelivery		com.salesmanager.shop.model.customer
# Entity		DeliveryEntity		com.salesmanager.shop.model.customer
# Entity		CustomerEntity		com.salesmanager.shop.model.customer
# Entity		CustomerPassword		com.salesmanager.shop.model.customer
# Entity		PersistableCustomer		com.salesmanager.shop.model.customer
# Entity		ReadableCustomer		com.salesmanager.shop.model.customer
# Entity		AnonymousCustomer		com.salesmanager.shop.model.customer
# Entity		BillingEntity		com.salesmanager.shop.model.customer
# Entity		SecuredShopPersistableCustomer		com.salesmanager.shop.model.customer
# Entity		CustomerReviewEntity		com.salesmanager.shop.model.customer
# Entity		Customer		com.salesmanager.shop.model.customer
# Entity		ReadableCustomerReview		com.salesmanager.shop.model.customer
# Entity		ReadableBilling		com.salesmanager.shop.model.customer
# Entity		SecuredCustomer		com.salesmanager.shop.model.customer
# Entity		UserAlreadyExistException		com.salesmanager.shop.model.customer
# Entity		CustomerOptionValueEntity		com.salesmanager.shop.model.customer.attribute
# Entity		ReadableCustomerOptionValue		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerAttribute		com.salesmanager.shop.model.customer.attribute
# Entity		PersistableCustomerOptionValue		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionValue		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionValueDescription		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionDescription		com.salesmanager.shop.model.customer.attribute
# Entity		ReadableCustomerOption		com.salesmanager.shop.model.customer.attribute
# Entity		PersistableCustomerAttribute		com.salesmanager.shop.model.customer.attribute
# Entity		ReadableCustomerAttribute		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionEntity		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOption		com.salesmanager.shop.model.customer.attribute
# Entity		PersistableCustomerOption		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerAttributeEntity		com.salesmanager.shop.model.customer.attribute
# Entity		AddressLocation		com.salesmanager.shop.model.customer.address
# Entity		Address		com.salesmanager.shop.model.customer.address
# Entity		CustomerOptinEntity		com.salesmanager.shop.model.customer.optin
# Entity		CustomerOptin		com.salesmanager.shop.model.customer.optin
# Entity		PersistableCustomerOptin		com.salesmanager.shop.model.customer.optin
# Entity		SearchProductList		com.salesmanager.shop.model.catalog
# Entity		NamedEntity		com.salesmanager.shop.model.catalog
# Entity		SearchProductRequest		com.salesmanager.shop.model.catalog
# Entity		ProductList		com.salesmanager.shop.model.catalog
# Entity		PersistableProductPrice		com.salesmanager.shop.model.catalog.product
# Entity		PersistableProductReview		com.salesmanager.shop.model.catalog.product
# Entity		ProductPriceEntity		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductFull		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductList		com.salesmanager.shop.model.catalog.product
# Entity		ReadableImage		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProduct		com.salesmanager.shop.model.catalog.product
# Entity		RentalOwner		com.salesmanager.shop.model.catalog.product
# Entity		LightPersistableProduct		com.salesmanager.shop.model.catalog.product
# Entity		RelatedProduct		com.salesmanager.shop.model.catalog.product
# Entity		ProductPriceDescription		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductPrice		com.salesmanager.shop.model.catalog.product
# Entity		ProductSpecification		com.salesmanager.shop.model.catalog.product
# Entity		ProductReviewEntity		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductPriceFull		com.salesmanager.shop.model.catalog.product
# Entity		ProductPrice		com.salesmanager.shop.model.catalog.product
# Entity		Product		com.salesmanager.shop.model.catalog.product
# Entity		PersistableImage		com.salesmanager.shop.model.catalog.product
# Entity		ProductEntity		com.salesmanager.shop.model.catalog.product
# Entity		ProductDescription		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductReview		com.salesmanager.shop.model.catalog.product
# Entity		PersistableProduct		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductName		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductAttributeValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductOptionValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionEntity		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOption		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductAttribute		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductAttribute		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductOption		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductVariantValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableSelectedProductVariant		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductVariant		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductAttribute		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductAttributeValueDescription		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductOptionValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductOption		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionDescription		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionValueDescription		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductOptionSet		com.salesmanager.shop.model.catalog.product.attribute.optionset
# Entity		ProductOptionSetEntity		com.salesmanager.shop.model.catalog.product.attribute.optionset
# Entity		ReadableProductOptionSet		com.salesmanager.shop.model.catalog.product.attribute.optionset
# Entity		PersistableProductOptionValueEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionFull		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductAttributeList		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductAttributeEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionValueFull		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		PersistableProductOptionEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionValueEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ProductAttributeEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ProductOptionValueEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionList		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionValueList		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductTypeList		com.salesmanager.shop.model.catalog.product.type
# Entity		ProductTypeEntity		com.salesmanager.shop.model.catalog.product.type
# Entity		ReadableProductType		com.salesmanager.shop.model.catalog.product.type
# Entity		PersistableProductType		com.salesmanager.shop.model.catalog.product.type
# Entity		ProductGroup		com.salesmanager.shop.model.catalog.product.group
# Entity		ReadableInventoryList		com.salesmanager.shop.model.catalog.product.inventory
# Entity		InventoryEntity		com.salesmanager.shop.model.catalog.product.inventory
# Entity		PersistableInventory		com.salesmanager.shop.model.catalog.product.inventory
# Entity		ReadableInventory		com.salesmanager.shop.model.catalog.product.inventory
# Entity		Manufacturer		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableManufacturerList		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ManufacturerDescription		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableManufacturerFull		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableManufacturer		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ManufacturerEntity		com.salesmanager.shop.model.catalog.manufacturer
# Entity		PersistableManufacturer		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableCategoryList		com.salesmanager.shop.model.catalog.category
# Entity		ReadableCategoryName		com.salesmanager.shop.model.catalog.category
# Entity		Category		com.salesmanager.shop.model.catalog.category
# Entity		CategoryDescription		com.salesmanager.shop.model.catalog.category
# Entity		CategoryEntity		com.salesmanager.shop.model.catalog.category
# Entity		ReadableCategoryFull		com.salesmanager.shop.model.catalog.category
# Entity		ReadableCategory		com.salesmanager.shop.model.catalog.category
# Entity		PersistableCategory		com.salesmanager.shop.model.catalog.category
# Entity		CatalogEntryEntity		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalog		com.salesmanager.shop.model.catalog.catalog
# Entity		CatalogEntity		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogCategoryEntry		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogCategoryEntryList		com.salesmanager.shop.model.catalog.catalog
# Entity		PersistableCatalogCategoryEntry		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogName		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogList		com.salesmanager.shop.model.catalog.catalog
# Entity		PersistableCatalog		com.salesmanager.shop.model.catalog.catalog
# Interface	ConfigurationsFacade		com.salesmanager.shop.store.controller.configurations
# Interface	ProductOptionSetFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductTypeFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductInventoryFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductOptionFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	UserFacade		com.salesmanager.shop.store.controller.user.facade
# Interface	ContentFacade		com.salesmanager.shop.store.controller.content.facade
# Interface	ManufacturerFacade		com.salesmanager.shop.store.controller.manufacturer.facade
# Interface	TaxFacade		com.salesmanager.shop.store.controller.tax.facade
# Interface	ProductItemsFacade		com.salesmanager.shop.store.controller.items.facade
# Interface	ShippingFacade		com.salesmanager.shop.store.controller.shipping.facade
# Interface	ShippingModuleConfigurationFacade		com.salesmanager.shop.store.controller.shipping.facade
# Interface	CategoryFacade		com.salesmanager.shop.store.controller.category.facade
# Interface	CatalogFacade		com.salesmanager.shop.store.controller.catalog.facade
# Entity		BeanUtils		com.salesmanager.shop.validation
# Entity		FieldMatchValidator		com.salesmanager.shop.validation
# Entity		EnumValidator		com.salesmanager.shop.validation

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		MavenWrapperDownloader		default
# Entity		ServiceException		com.salesmanager.core.business.exception
# Entity		ConversionException		com.salesmanager.core.business.exception
# Entity		SchemaConstant		com.salesmanager.core.constants
# Entity		CloneUtils		com.salesmanager.core.utils
# Entity		Secrets		com.salesmanager.core.model.security
# Entity		Country		com.salesmanager.core.model.reference.country
# Entity		CountryDescription		com.salesmanager.core.model.reference.country
# Entity		Language		com.salesmanager.core.model.reference.language
# Entity		Currency		com.salesmanager.core.model.reference.currency
# Entity		ZoneDescription		com.salesmanager.core.model.reference.zone
# Entity		Zone		com.salesmanager.core.model.reference.zone
# Entity		GeoZone		com.salesmanager.core.model.reference.geozone
# Entity		GeoZoneDescription		com.salesmanager.core.model.reference.geozone
# Entity		PermissionList		com.salesmanager.core.model.user
# Entity		PermissionCriteria		com.salesmanager.core.model.user
# Entity		Permission		com.salesmanager.core.model.user
# Entity		User		com.salesmanager.core.model.user
# Entity		Group		com.salesmanager.core.model.user
# Entity		UserCriteria		com.salesmanager.core.model.user
# Entity		ShoppingCart		com.salesmanager.core.model.shoppingcart
# Entity		ShoppingCartAttributeItem		com.salesmanager.core.model.shoppingcart
# Entity		ShoppingCartItem		com.salesmanager.core.model.shoppingcart
# Entity		InputContentFile		com.salesmanager.core.model.content
# Entity		ContentDescription		com.salesmanager.core.model.content
# Entity		Content		com.salesmanager.core.model.content
# Entity		ImageContentFile		com.salesmanager.core.model.content
# Entity		OutputContentFile		com.salesmanager.core.model.content
# Entity		ContentFile		com.salesmanager.core.model.content
# Entity		StaticContentFile		com.salesmanager.core.model.content
# Entity		TaxConfiguration		com.salesmanager.core.model.tax
# Entity		TaxItem		com.salesmanager.core.model.tax
# Entity		TaxRateDescription		com.salesmanager.core.model.tax.taxrate
# Entity		TaxRate		com.salesmanager.core.model.tax.taxrate
# Entity		TaxClass		com.salesmanager.core.model.tax.taxclass
# Entity		CreditCardPayment		com.salesmanager.core.model.payments
# Entity		BasicPayment		com.salesmanager.core.model.payments
# Entity		Payment		com.salesmanager.core.model.payments
# Entity		PaymentMethod		com.salesmanager.core.model.payments
# Entity		PaypalPayment		com.salesmanager.core.model.payments
# Entity		Transaction		com.salesmanager.core.model.payments
# Entity		GenericEntityList		com.salesmanager.core.model.common
# Entity		UserContext		com.salesmanager.core.model.common
# Entity		Delivery		com.salesmanager.core.model.common
# Entity		Criteria		com.salesmanager.core.model.common
# Entity		Billing		com.salesmanager.core.model.common
# Entity		Address		com.salesmanager.core.model.common
# Entity		EntityList		com.salesmanager.core.model.common
# Entity		AuditListener		com.salesmanager.core.model.common.audit
# Entity		AuditSection		com.salesmanager.core.model.common.audit
# Entity		Description		com.salesmanager.core.model.common.description
# Entity		ShippingProduct		com.salesmanager.core.model.shipping
# Entity		ShippingOrigin		com.salesmanager.core.model.shipping
# Entity		ShippingSummary		com.salesmanager.core.model.shipping
# Entity		ShippingConfiguration		com.salesmanager.core.model.shipping
# Entity		PackageDetails		com.salesmanager.core.model.shipping
# Entity		Package		com.salesmanager.core.model.shipping
# Entity		ShippingOption		com.salesmanager.core.model.shipping
# Entity		ShippingMetaData		com.salesmanager.core.model.shipping
# Entity		Quote		com.salesmanager.core.model.shipping
# Entity		ShippingQuote		com.salesmanager.core.model.shipping
# Entity		OrderSummary		com.salesmanager.core.model.order
# Entity		OrderList		com.salesmanager.core.model.order
# Entity		OrderTotalVariation		com.salesmanager.core.model.order
# Entity		Order		com.salesmanager.core.model.order
# Entity		OrderCriteria		com.salesmanager.core.model.order
# Entity		OrderTotalSummary		com.salesmanager.core.model.order
# Entity		RebatesOrderTotalVariation		com.salesmanager.core.model.order
# Entity		OrderTotalItem		com.salesmanager.core.model.order
# Entity		OrderTotal		com.salesmanager.core.model.order
# Entity		FileHistory		com.salesmanager.core.model.order.filehistory
# Entity		OrderProductAttribute		com.salesmanager.core.model.order.orderproduct
# Entity		OrderProductDownload		com.salesmanager.core.model.order.orderproduct
# Entity		OrderProduct		com.salesmanager.core.model.order.orderproduct
# Entity		OrderProductPrice		com.salesmanager.core.model.order.orderproduct
# Entity		OrderAccount		com.salesmanager.core.model.order.orderaccount
# Entity		OrderAccountProduct		com.salesmanager.core.model.order.orderaccount
# Entity		CreditCard		com.salesmanager.core.model.order.payment
# Entity		OrderAttribute		com.salesmanager.core.model.order.attributes
# Entity		OrderStatusHistory		com.salesmanager.core.model.order.orderstatus
# Entity		MerchantStore		com.salesmanager.core.model.merchant
# Entity		MerchantStoreCriteria		com.salesmanager.core.model.merchant
# Entity		SearchEntry		com.salesmanager.core.model.search
# Entity		SearchResponse		com.salesmanager.core.model.search
# Entity		IndexProduct		com.salesmanager.core.model.search
# Entity		SearchKeywords		com.salesmanager.core.model.search
# Entity		SearchFacet		com.salesmanager.core.model.search
# Entity		IntegrationConfiguration		com.salesmanager.core.model.system
# Entity		ModuleConfig		com.salesmanager.core.model.system
# Entity		MerchantLog		com.salesmanager.core.model.system
# Entity		SystemConfiguration		com.salesmanager.core.model.system
# Entity		MerchantConfig		com.salesmanager.core.model.system
# Entity		SystemNotification		com.salesmanager.core.model.system
# Entity		MerchantConfiguration		com.salesmanager.core.model.system
# Entity		IntegrationModule		com.salesmanager.core.model.system
# Entity		Optin		com.salesmanager.core.model.system.optin
# Entity		CustomerOptin		com.salesmanager.core.model.system.optin
# Entity		Credentials		com.salesmanager.core.model.system.credentials
# Entity		DbCredentials		com.salesmanager.core.model.system.credentials
# Entity		CustomerList		com.salesmanager.core.model.customer
# Entity		CustomerCriteria		com.salesmanager.core.model.customer
# Entity		Customer		com.salesmanager.core.model.customer
# Entity		CustomerAttribute		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionSet		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionValue		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionValueDescription		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOptionDescription		com.salesmanager.core.model.customer.attribute
# Entity		CustomerOption		com.salesmanager.core.model.customer.attribute
# Entity		CustomerReview		com.salesmanager.core.model.customer.review
# Entity		CustomerReviewDescription		com.salesmanager.core.model.customer.review
# Entity		UserConnection		com.salesmanager.core.model.customer.connection
# Entity		AbstractUserConnectionWithCompositeKey		com.salesmanager.core.model.customer.connection
# Entity		AbstractUserConnection		com.salesmanager.core.model.customer.connection
# Entity		UserConnectionPK		com.salesmanager.core.model.customer.connection
# Entity		ProductCriteria		com.salesmanager.core.model.catalog.product
# Entity		Product		com.salesmanager.core.model.catalog.product
# Entity		ProductList		com.salesmanager.core.model.catalog.product
# Entity		DigitalProduct		com.salesmanager.core.model.catalog.product.file
# Entity		ProductOption		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductAttribute		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionSet		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductVariant		com.salesmanager.core.model.catalog.product.attribute
# Entity		AttributeCriteria		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionDescription		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionValue		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductOptionValueDescription		com.salesmanager.core.model.catalog.product.attribute
# Entity		ProductAvailability		com.salesmanager.core.model.catalog.product.availability
# Entity		Manufacturer		com.salesmanager.core.model.catalog.product.manufacturer
# Entity		ManufacturerDescription		com.salesmanager.core.model.catalog.product.manufacturer
# Entity		ProductReviewDescription		com.salesmanager.core.model.catalog.product.review
# Entity		ProductReview		com.salesmanager.core.model.catalog.product.review
# Entity		ProductRelationship		com.salesmanager.core.model.catalog.product.relationship
# Entity		ProductPriceDescription		com.salesmanager.core.model.catalog.product.price
# Entity		FinalPrice		com.salesmanager.core.model.catalog.product.price
# Entity		ProductPrice		com.salesmanager.core.model.catalog.product.price
# Entity		ProductType		com.salesmanager.core.model.catalog.product.type
# Entity		ProductTypeDescription		com.salesmanager.core.model.catalog.product.type
# Entity		ProductDescription		com.salesmanager.core.model.catalog.product.description
# Entity		ProductImageDescription		com.salesmanager.core.model.catalog.product.image
# Entity		ProductImage		com.salesmanager.core.model.catalog.product.image
# Entity		CatalogDescription		com.salesmanager.core.model.catalog.marketplace
# Entity		MarketPlace		com.salesmanager.core.model.catalog.marketplace
# Entity		Catalog		com.salesmanager.core.model.catalog.marketplace
# Entity		Category		com.salesmanager.core.model.catalog.category
# Entity		CategoryDescription		com.salesmanager.core.model.catalog.category
# Entity		CatalogCategoryEntry		com.salesmanager.core.model.catalog.catalog
# Entity		Catalog		com.salesmanager.core.model.catalog.catalog
# Entity		SalesManagerEntity		com.salesmanager.core.model.generic
# Entity		MavenWrapperDownloader		default
# Entity		AdminFilter		com.salesmanager.shop.filter
# Entity		StoreFilter		com.salesmanager.shop.filter
# Entity		CorsFilter		com.salesmanager.shop.filter
# Entity		ShopServletContextListener		com.salesmanager.shop.application.config
# Entity		ApplicationConstants		com.salesmanager.shop.constants
# Entity		Constants		com.salesmanager.shop.constants
# Entity		EmailConstants		com.salesmanager.shop.constants
# Entity		ReadableShoppingCartPopulator		com.salesmanager.shop.populator.shoppingCart
# Entity		ShoppingCartDataPopulator		com.salesmanager.shop.populator.shoppingCart
# Entity		ReadablePermissionPopulator		com.salesmanager.shop.populator.security
# Entity		ReadableUserPopulator		com.salesmanager.shop.populator.user
# Entity		PersistableManufacturerPopulator		com.salesmanager.shop.populator.manufacturer
# Entity		ReadableManufacturerPopulator		com.salesmanager.shop.populator.manufacturer
# Entity		ReadableCountryPopulator		com.salesmanager.shop.populator.references
# Entity		ReadableZonePopulator		com.salesmanager.shop.populator.references
# Entity		ReadableMerchantStorePopulatorWithDetails		com.salesmanager.shop.populator.store
# Entity		ReadableMerchantStorePopulator		com.salesmanager.shop.populator.store
# Entity		ReadableShopOrderPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableShippingSummaryPopulator		com.salesmanager.shop.populator.order
# Entity		PersistableOrderPopulator		com.salesmanager.shop.populator.order
# Entity		OrderProductPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderSummaryPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderTotalPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderProductPopulator		com.salesmanager.shop.populator.order
# Entity		ReadableOrderProductDownloadPopulator		com.salesmanager.shop.populator.order
# Entity		PersistableOrderProductPopulator		com.salesmanager.shop.populator.order
# Entity		ShoppingCartItemPopulator		com.salesmanager.shop.populator.order
# Entity		PersistableTransactionPopulator		com.salesmanager.shop.populator.order.transaction
# Entity		PersistablePaymentPopulator		com.salesmanager.shop.populator.order.transaction
# Entity		ReadableTransactionPopulator		com.salesmanager.shop.populator.order.transaction
# Entity		ReadableOptinPopulator		com.salesmanager.shop.populator.system
# Entity		PersistableCustomerReviewPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerOptionPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerDeliveryAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerShippingAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerOptionPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerOptionValuePopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerOptionPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableCustomerBillingAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerEntityPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerBillingAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerPopulator		com.salesmanager.shop.populator.customer
# Entity		CustomerDeliveryAddressPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerList		com.salesmanager.shop.populator.customer
# Entity		ReadableProductReviewPopulator		com.salesmanager.shop.populator.customer
# Entity		ReadableCustomerReviewPopulator		com.salesmanager.shop.populator.customer
# Entity		PersistableProductOptionValuePopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableCategoryPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableFinalPricePopulator		com.salesmanager.shop.populator.catalog
# Entity		PersistableProductOptionPopulator		com.salesmanager.shop.populator.catalog
# Entity		PersistableProductReviewPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableProductReviewPopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableProductPricePopulator		com.salesmanager.shop.populator.catalog
# Entity		PersistableProductImagePopulator		com.salesmanager.shop.populator.catalog
# Entity		ReadableProductPopulator		com.salesmanager.shop.populator.catalog
# Entity		LocaleUtils		com.salesmanager.shop.utils
# Entity		MerchantUtils		com.salesmanager.shop.utils
# Entity		PageBuilderUtils		com.salesmanager.shop.utils
# Entity		BeanUtils		com.salesmanager.shop.utils
# Entity		SessionUtil		com.salesmanager.shop.utils
# Entity		DateUtil		com.salesmanager.shop.utils
# Entity		LabelUtils		com.salesmanager.shop.utils
# Entity		AdminAccessDeniedHandler		com.salesmanager.shop.utils
# Entity		CategoryUtils		com.salesmanager.shop.utils
# Entity		ServiceRequestCriteriaBuilderUtils		com.salesmanager.shop.utils
# Entity		GeoLocationUtils		com.salesmanager.shop.utils
# Entity		TokenizeTool		com.salesmanager.shop.utils
# Entity		AbstractimageFilePath		com.salesmanager.shop.utils
# Entity		FieldMatchValidator		com.salesmanager.shop.utils
# Entity		UserUtils		com.salesmanager.shop.utils
# Entity		EnumValidator		com.salesmanager.shop.utils
# Entity		ShopProductImageUrlTag		com.salesmanager.shop.tags
# Entity		ContentImageUrlTag		com.salesmanager.shop.tags
# Entity		ShopProductRelationshipTag		com.salesmanager.shop.tags
# Entity		OrderProductDownloadUrlTag		com.salesmanager.shop.tags
# Entity		ShopProductPriceFormatTag		com.salesmanager.shop.tags
# Entity		ProductImageUrlTag		com.salesmanager.shop.tags
# Entity		ActiveLinkTag		com.salesmanager.shop.tags
# Entity		ConfigurationTag		com.salesmanager.shop.tags
# Entity		PageContentTag		com.salesmanager.shop.tags
# Entity		StoreLogoUrlTag		com.salesmanager.shop.tags
# Entity		ProductDescriptionUrlTag		com.salesmanager.shop.tags
# Entity		StoreBreadcrumbsTag		com.salesmanager.shop.tags
# Entity		AdminProductDownloadUrlTag		com.salesmanager.shop.tags
# Entity		ManufacturerImageUrlTag		com.salesmanager.shop.tags
# Entity		StoreFooterlTag		com.salesmanager.shop.tags
# Entity		PageInformation		com.salesmanager.shop.model.shop
# Entity		Breadcrumb		com.salesmanager.shop.model.shop
# Entity		BreadcrumbItem		com.salesmanager.shop.model.shop
# Entity		ContactForm		com.salesmanager.shop.model.shop
# Entity		PasswordRequest		com.salesmanager.shop.store.security
# Entity		ServicesAuthenticationEntryPoint		com.salesmanager.shop.store.security
# Entity		AuthenticationRequest		com.salesmanager.shop.store.security
# Entity		ServicesAuthenticationSuccessHandler		com.salesmanager.shop.store.security
# Entity		AuthenticationTokenFilter		com.salesmanager.shop.store.security
# Entity		AbstractCustomerServices		com.salesmanager.shop.store.security
# Entity		ResetPasswordRequest		com.salesmanager.shop.store.security
# Entity		AuthenticationResponse		com.salesmanager.shop.store.security
# Entity		JWTUser		com.salesmanager.shop.store.security.user
# Entity		CustomerDetails		com.salesmanager.shop.store.security.user
# Entity		CustomAuthenticationManager		com.salesmanager.shop.store.security.common
# Entity		CustomAuthenticationException		com.salesmanager.shop.store.security.common
# Entity		JWTAdminAuthenticationProvider		com.salesmanager.shop.store.security.admin
# Entity		AdminAccessDeniedHandler		com.salesmanager.shop.store.security.admin
# Entity		JWTCustomerAuthenticationProvider		com.salesmanager.shop.store.security.customer
# Entity		AbstractController		com.salesmanager.shop.store.controller
# Entity		AbstractConfigurationFacadeImpl		com.salesmanager.shop.store.facade.configuration
# Entity		PaginationData		com.salesmanager.shop.store.model.paging
# Entity		QueryFilter		com.salesmanager.shop.store.model.filter
# Entity		AutoCompleteRequest		com.salesmanager.shop.store.model.search
# Entity		Attribute		com.salesmanager.shop.store.model.catalog
# Entity		AttributeValue		com.salesmanager.shop.store.model.catalog
# Entity		ServiceRuntimeException		com.salesmanager.shop.store.api.exception
# Entity		ErrorEntity		com.salesmanager.shop.store.api.exception
# Entity		OperationNotAllowedException		com.salesmanager.shop.store.api.exception
# Entity		UnauthorizedException		com.salesmanager.shop.store.api.exception
# Entity		RestApiException		com.salesmanager.shop.store.api.exception
# Entity		GenericRuntimeException		com.salesmanager.shop.store.api.exception
# Entity		ConversionRuntimeException		com.salesmanager.shop.store.api.exception
# Entity		ResourceNotFoundException		com.salesmanager.shop.store.api.exception
# Entity		ApiUserAuthenticationSuccessHandler		com.salesmanager.shop.admin.security
# Entity		SecurityQuestion		com.salesmanager.shop.admin.security
# Entity		SecurityDataAccessException		com.salesmanager.shop.admin.security
# Entity		UserAuthenticationSuccessHandler		com.salesmanager.shop.admin.security
# Entity		AbstractAuthenticatinSuccessHandler		com.salesmanager.shop.admin.security
# Entity		Password		com.salesmanager.shop.admin.model.secutity
# Entity		Weight		com.salesmanager.shop.admin.model.reference
# Entity		Size		com.salesmanager.shop.admin.model.reference
# Entity		ProductImages		com.salesmanager.shop.admin.model.content
# Entity		ContentFiles		com.salesmanager.shop.admin.model.content
# Entity		ProductFiles		com.salesmanager.shop.admin.model.digital
# Entity		GroupDetails		com.salesmanager.shop.admin.model.permission
# Entity		ShopGroup		com.salesmanager.shop.admin.model.permission
# Entity		ShopPermission		com.salesmanager.shop.admin.model.permission
# Entity		Permissions		com.salesmanager.shop.admin.model.permission
# Entity		Order		com.salesmanager.shop.admin.model.orders
# Entity		Refund		com.salesmanager.shop.admin.model.orders
# Entity		UserReset		com.salesmanager.shop.admin.model.userpassword
# Entity		StoreLandingDescription		com.salesmanager.shop.admin.model.merchant
# Entity		StoreLanding		com.salesmanager.shop.admin.model.merchant
# Entity		Menu		com.salesmanager.shop.admin.model.web
# Entity		ConfigListWrapper		com.salesmanager.shop.admin.model.web
# Entity		CustomerOptionValue		com.salesmanager.shop.admin.model.customer.attribute
# Entity		CustomerOption		com.salesmanager.shop.admin.model.customer.attribute
# Entity		CustomerAttributes		com.salesmanager.shop.admin.model.customer.attribute
# Entity		Manufacturer		com.salesmanager.shop.admin.model.catalog
# Entity		Category		com.salesmanager.shop.admin.model.catalog
# Entity		ProductPrice		com.salesmanager.shop.admin.model.catalog
# Entity		Product		com.salesmanager.shop.admin.model.catalog
# Entity		Keyword		com.salesmanager.shop.admin.model.catalog
# Entity		MavenWrapperDownloader		default
# Entity		IntegrationException		com.salesmanager.core.business.modules.integration
# Entity		BeanStreamPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		StripePayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		PayPalExpressCheckoutPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		BraintreePayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		MoneyOrderPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		PayPalRestPayment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		Stripe3Payment		com.salesmanager.core.business.modules.integration.payment.impl
# Entity		UPSShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		UPSParsedElements		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		CustomWeightBasedShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		StorePickupShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		DecisionResponse		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		ShippingDecisionPreProcessorImpl		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		ShippingInputParameters		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		DefaultPackagingImpl		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		PackingBox		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		PriceByDistanceShippingQuoteRules		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		USPSShippingQuote		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		USPSParsedElements		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		CustomShippingQuoteRules		com.salesmanager.core.business.modules.integration.shipping.impl
# Entity		EmailConfig		com.salesmanager.core.business.modules.email
# Entity		Email		com.salesmanager.core.business.modules.email
# Entity		EncryptionImpl		com.salesmanager.core.business.modules.utils
# Entity		GeoLocationImpl		com.salesmanager.core.business.modules.utils
# Entity		IndexEntityProcessor		com.salesmanager.core.business.modules.common
# Entity		ProductFileManagerImpl		com.salesmanager.core.business.modules.cms.product
# Entity		ProductFileManager		com.salesmanager.core.business.modules.cms.product
# Entity		CmsImageFileManagerImpl		com.salesmanager.core.business.modules.cms.product.infinispan
# Entity		CmsImageFileManagerImpl		com.salesmanager.core.business.modules.cms.product.local
# Entity		S3ProductContentFileManager		com.salesmanager.core.business.modules.cms.product.aws
# Entity		DownloadCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		VendorCacheManager		com.salesmanager.core.business.modules.cms.impl
# Entity		StoreCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		StaticContentCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		S3CacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		CacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		LocalCacheManagerImpl		com.salesmanager.core.business.modules.cms.impl
# Entity		StaticContentFileManagerImpl		com.salesmanager.core.business.modules.cms.content
# Entity		StaticContentFileManager		com.salesmanager.core.business.modules.cms.content
# Entity		CmsStaticContentFileManagerImpl		com.salesmanager.core.business.modules.cms.content.infinispan
# Entity		CmsStaticContentFileManagerImpl		com.salesmanager.core.business.modules.cms.content.local
# Entity		S3StaticContentAssetsManagerImpl		com.salesmanager.core.business.modules.cms.content.aws
# Entity		StaticContentData		com.salesmanager.core.business.modules.cms.common
# Entity		ODSInvoiceModule		com.salesmanager.core.business.modules.order
# Entity		OrderTotalInputParameters		com.salesmanager.core.business.modules.order.total
# Entity		OrderTotalResponse		com.salesmanager.core.business.modules.order.total
# Entity		ShippingConstants		com.salesmanager.core.business.constants
# Entity		Constants		com.salesmanager.core.business.constants
# Entity		SystemConstants		com.salesmanager.core.business.constants
# Entity		UserRepositoryImpl		com.salesmanager.core.business.repositories.user
# Entity		PermissionRepositoryImpl		com.salesmanager.core.business.repositories.user
# Entity		ContentRepositoryImpl		com.salesmanager.core.business.repositories.content
# Entity		OrderRepositoryImpl		com.salesmanager.core.business.repositories.order
# Entity		MerchantRepositoryImpl		com.salesmanager.core.business.repositories.merchant
# Entity		CustomerRepositoryImpl		com.salesmanager.core.business.repositories.customer
# Entity		ProductRepositoryImpl		com.salesmanager.core.business.repositories.catalog.product
# Entity		ProductRelationshipRepositoryImpl		com.salesmanager.core.business.repositories.catalog.product.relationship
# Entity		CategoryRepositoryImpl		com.salesmanager.core.business.repositories.catalog.category
# Entity		PageableCategoryRepositoryImpl		com.salesmanager.core.business.repositories.catalog.category
# Entity		SecurityGroupsBuilder		com.salesmanager.core.business.utils
# Entity		ApplicationContextListenerUtils		com.salesmanager.core.business.utils
# Entity		CatalogServiceHelper		com.salesmanager.core.business.utils
# Entity		ProductUtils		com.salesmanager.core.business.utils
# Entity		DataUtils		com.salesmanager.core.business.utils
# Entity		ProductImageCropUtils		com.salesmanager.core.business.utils
# Entity		CreditCardUtils		com.salesmanager.core.business.utils
# Entity		ProductImageSizeUtils		com.salesmanager.core.business.utils
# Entity		AbstractDataPopulator		com.salesmanager.core.business.utils
# Entity		RepositoryHelper		com.salesmanager.core.business.utils
# Entity		AjaxResponse		com.salesmanager.core.business.utils.ajax
# Entity		AjaxPageableResponse		com.salesmanager.core.business.utils.ajax
# Entity		ProductQueryBuilder		com.salesmanager.core.business.utils.query
# Entity		VaultConfiguration		com.salesmanager.core.business.configuration
# Entity		DbConfig		com.salesmanager.core.business.configuration.db
# Entity		ConfigurationModulesLoader		com.salesmanager.core.business.services.reference.loader
# Entity		ZoneTransient		com.salesmanager.core.business.services.reference.zone
# Entity		UserServiceImpl		com.salesmanager.core.business.services.user
# Entity		SalesManagerEntityServiceImpl		com.salesmanager.core.business.services.common.generic
# Entity		MavenWrapperDownloader		default
# Entity		ReadablePermission		com.salesmanager.shop.model.security
# Entity		PermissionEntity		com.salesmanager.shop.model.security
# Entity		GroupEntity		com.salesmanager.shop.model.security
# Entity		PersistableGroup		com.salesmanager.shop.model.security
# Entity		ReadableGroup		com.salesmanager.shop.model.security
# Entity		UserNameEntity		com.salesmanager.shop.model.user
# Entity		PersistableUser		com.salesmanager.shop.model.user
# Entity		User		com.salesmanager.shop.model.user
# Entity		UserEntity		com.salesmanager.shop.model.user
# Entity		UserPassword		com.salesmanager.shop.model.user
# Entity		ReadableUserList		com.salesmanager.shop.model.user
# Entity		ReadableUser		com.salesmanager.shop.model.user
# Entity		PersistableShoppingCartItem		com.salesmanager.shop.model.shoppingcart
# Entity		ReadableShoppingCartAttributeOptionValue		com.salesmanager.shop.model.shoppingcart
# Entity		ReadableShoppingCartItem		com.salesmanager.shop.model.shoppingcart
# Entity		ReadableShoppingCartAttributeOption		com.salesmanager.shop.model.shoppingcart
# Entity		ShoppingCartEntity		com.salesmanager.shop.model.shoppingcart
# Entity		ReadableShoppingCart		com.salesmanager.shop.model.shoppingcart
# Entity		ShoppingCartAttribute		com.salesmanager.shop.model.shoppingcart
# Entity		ReadableShoppingCartAttribute		com.salesmanager.shop.model.shoppingcart
# Entity		CartModificationException		com.salesmanager.shop.model.shoppingcart
# Entity		ShoppingCartItem		com.salesmanager.shop.model.shoppingcart
# Entity		PersistableContentEntity		com.salesmanager.shop.model.content
# Entity		ContentDescriptionEntity		com.salesmanager.shop.model.content
# Entity		ReadableContentFull		com.salesmanager.shop.model.content
# Entity		ContentPath		com.salesmanager.shop.model.content
# Entity		ReadableContentObject		com.salesmanager.shop.model.content
# Entity		PersistableContent		com.salesmanager.shop.model.content
# Entity		ContentImage		com.salesmanager.shop.model.content
# Entity		ReadableContentEntity		com.salesmanager.shop.model.content
# Entity		ReadableImage		com.salesmanager.shop.model.content
# Entity		ObjectContent		com.salesmanager.shop.model.content
# Entity		Content		com.salesmanager.shop.model.content
# Entity		ContentName		com.salesmanager.shop.model.content
# Entity		ReadableContentPage		com.salesmanager.shop.model.content
# Entity		ReadableContentBox		com.salesmanager.shop.model.content
# Entity		ReadableContent		com.salesmanager.shop.model.content
# Entity		ContentFolder		com.salesmanager.shop.model.content
# Entity		ContentSettings		com.salesmanager.shop.model.content
# Entity		PersistableContentPage		com.salesmanager.shop.model.content
# Entity		ContentFile		com.salesmanager.shop.model.content
# Entity		ContentEntity		com.salesmanager.shop.model.content
# Entity		PersistableAddress		com.salesmanager.shop.model.references
# Entity		ZoneEntity		com.salesmanager.shop.model.references
# Entity		ReadableZone		com.salesmanager.shop.model.references
# Entity		ReadableAddress		com.salesmanager.shop.model.references
# Entity		SizeReferences		com.salesmanager.shop.model.references
# Entity		CountryEntity		com.salesmanager.shop.model.references
# Entity		Address		com.salesmanager.shop.model.references
# Entity		ReadableCountry		com.salesmanager.shop.model.references
# Entity		PersistableMerchantStore		com.salesmanager.shop.model.shop
# Entity		MarketPlaceEntity		com.salesmanager.shop.model.marketplace
# Entity		ReadableMarketPlace		com.salesmanager.shop.model.marketplace
# Entity		TaxRateDescription		com.salesmanager.shop.model.tax
# Entity		ReadableTaxRateDescription		com.salesmanager.shop.model.tax
# Entity		PersistableTaxClass		com.salesmanager.shop.model.tax
# Entity		ReadableTaxClass		com.salesmanager.shop.model.tax
# Entity		PersistableTaxRate		com.salesmanager.shop.model.tax
# Entity		ReadableTaxRateFull		com.salesmanager.shop.model.tax
# Entity		ReadableTaxRate		com.salesmanager.shop.model.tax
# Entity		TaxRateEntity		com.salesmanager.shop.model.tax
# Entity		TaxClassEntity		com.salesmanager.shop.model.tax
# Entity		MerchantStoreBrand		com.salesmanager.shop.model.store
# Entity		PersistableMerchantStore		com.salesmanager.shop.model.store
# Entity		MerchantStoreEntity		com.salesmanager.shop.model.store
# Entity		ReadableBrand		com.salesmanager.shop.model.store
# Entity		PersistableBrand		com.salesmanager.shop.model.store
# Entity		ReadableMerchantStore		com.salesmanager.shop.model.store
# Entity		ReadableMerchantStoreList		com.salesmanager.shop.model.store
# Entity		MerchantConfigEntity		com.salesmanager.shop.model.store
# Entity		ShopEntity		com.salesmanager.shop.model.entity
# Entity		ValueList		com.salesmanager.shop.model.entity
# Entity		ListCriteria		com.salesmanager.shop.model.entity
# Entity		ReadableEntityList		com.salesmanager.shop.model.entity
# Entity		ReadableList		com.salesmanager.shop.model.entity
# Entity		UniqueEntity		com.salesmanager.shop.model.entity
# Entity		Entity		com.salesmanager.shop.model.entity
# Entity		EntityExists		com.salesmanager.shop.model.entity
# Entity		ReadableEntity		com.salesmanager.shop.model.entity
# Entity		ReadableAudit		com.salesmanager.shop.model.entity
# Entity		ServiceEntity		com.salesmanager.shop.model.entity
# Entity		PersistableConfiguration		com.salesmanager.shop.model.configuration
# Entity		ConfigurationEntity		com.salesmanager.shop.model.configuration
# Entity		ReadableConfiguration		com.salesmanager.shop.model.configuration
# Entity		BoxConfiguration		com.salesmanager.shop.model.shipping
# Entity		ExpeditionConfiguration		com.salesmanager.shop.model.shipping
# Entity		ShippingConfiguration		com.salesmanager.shop.model.shipping
# Entity		OrderProductEntity		com.salesmanager.shop.model.order
# Entity		ShopOrder		com.salesmanager.shop.model.order
# Entity		PersistableOrderProduct		com.salesmanager.shop.model.order
# Entity		ReadableOrderProduct		com.salesmanager.shop.model.order
# Entity		OrderAttribute		com.salesmanager.shop.model.order
# Entity		ReadableOrderProductAttribute		com.salesmanager.shop.model.order
# Entity		ReadableShopOrder		com.salesmanager.shop.model.order
# Entity		OrderEntity		com.salesmanager.shop.model.order
# Entity		ReadableOrderProductDownload		com.salesmanager.shop.model.order
# Entity		OrderProduct		com.salesmanager.shop.model.order
# Entity		ReadableOrderTotalSummary		com.salesmanager.shop.model.order
# Entity		Order		com.salesmanager.shop.model.order.v0
# Entity		ReadableOrderList		com.salesmanager.shop.model.order.v0
# Entity		PersistableOrder		com.salesmanager.shop.model.order.v0
# Entity		ReadableOrder		com.salesmanager.shop.model.order.v0
# Entity		ReadableTotal		com.salesmanager.shop.model.order.total
# Entity		ReadableOrderTotal		com.salesmanager.shop.model.order.total
# Entity		OrderTotal		com.salesmanager.shop.model.order.total
# Entity		ReadableOrderStatusHistory		com.salesmanager.shop.model.order.history
# Entity		OrderStatusHistory		com.salesmanager.shop.model.order.history
# Entity		PersistableOrderStatusHistory		com.salesmanager.shop.model.order.history
# Entity		PersistableAnonymousOrder		com.salesmanager.shop.model.order.v1
# Entity		Order		com.salesmanager.shop.model.order.v1
# Entity		ReadableOrderList		com.salesmanager.shop.model.order.v1
# Entity		PersistableOrder		com.salesmanager.shop.model.order.v1
# Entity		ReadableOrder		com.salesmanager.shop.model.order.v1
# Entity		ReadableShippingSummary		com.salesmanager.shop.model.order.shipping
# Entity		TransactionEntity		com.salesmanager.shop.model.order.transaction
# Entity		PersistablePayment		com.salesmanager.shop.model.order.transaction
# Entity		ReadablePayment		com.salesmanager.shop.model.order.transaction
# Entity		PaymentEntity		com.salesmanager.shop.model.order.transaction
# Entity		PersistableTransaction		com.salesmanager.shop.model.order.transaction
# Entity		ReadableTransaction		com.salesmanager.shop.model.order.transaction
# Entity		OptinEntity		com.salesmanager.shop.model.system
# Entity		Optin		com.salesmanager.shop.model.system
# Entity		IntegrationModuleEntity		com.salesmanager.shop.model.system
# Entity		Configs		com.salesmanager.shop.model.system
# Entity		PersistableOptin		com.salesmanager.shop.model.system
# Entity		ReadableOptin		com.salesmanager.shop.model.system
# Entity		PersistableCustomerReview		com.salesmanager.shop.model.customer
# Entity		ReadableDelivery		com.salesmanager.shop.model.customer
# Entity		DeliveryEntity		com.salesmanager.shop.model.customer
# Entity		CustomerEntity		com.salesmanager.shop.model.customer
# Entity		CustomerPassword		com.salesmanager.shop.model.customer
# Entity		PersistableCustomer		com.salesmanager.shop.model.customer
# Entity		ReadableCustomer		com.salesmanager.shop.model.customer
# Entity		AnonymousCustomer		com.salesmanager.shop.model.customer
# Entity		BillingEntity		com.salesmanager.shop.model.customer
# Entity		SecuredShopPersistableCustomer		com.salesmanager.shop.model.customer
# Entity		CustomerReviewEntity		com.salesmanager.shop.model.customer
# Entity		Customer		com.salesmanager.shop.model.customer
# Entity		ReadableCustomerReview		com.salesmanager.shop.model.customer
# Entity		ReadableBilling		com.salesmanager.shop.model.customer
# Entity		SecuredCustomer		com.salesmanager.shop.model.customer
# Entity		UserAlreadyExistException		com.salesmanager.shop.model.customer
# Entity		CustomerOptionValueEntity		com.salesmanager.shop.model.customer.attribute
# Entity		ReadableCustomerOptionValue		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerAttribute		com.salesmanager.shop.model.customer.attribute
# Entity		PersistableCustomerOptionValue		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionValue		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionValueDescription		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionDescription		com.salesmanager.shop.model.customer.attribute
# Entity		ReadableCustomerOption		com.salesmanager.shop.model.customer.attribute
# Entity		PersistableCustomerAttribute		com.salesmanager.shop.model.customer.attribute
# Entity		ReadableCustomerAttribute		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOptionEntity		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerOption		com.salesmanager.shop.model.customer.attribute
# Entity		PersistableCustomerOption		com.salesmanager.shop.model.customer.attribute
# Entity		CustomerAttributeEntity		com.salesmanager.shop.model.customer.attribute
# Entity		AddressLocation		com.salesmanager.shop.model.customer.address
# Entity		Address		com.salesmanager.shop.model.customer.address
# Entity		CustomerOptinEntity		com.salesmanager.shop.model.customer.optin
# Entity		CustomerOptin		com.salesmanager.shop.model.customer.optin
# Entity		PersistableCustomerOptin		com.salesmanager.shop.model.customer.optin
# Entity		SearchProductList		com.salesmanager.shop.model.catalog
# Entity		NamedEntity		com.salesmanager.shop.model.catalog
# Entity		SearchProductRequest		com.salesmanager.shop.model.catalog
# Entity		ProductList		com.salesmanager.shop.model.catalog
# Entity		PersistableProductPrice		com.salesmanager.shop.model.catalog.product
# Entity		PersistableProductReview		com.salesmanager.shop.model.catalog.product
# Entity		ProductPriceEntity		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductFull		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductList		com.salesmanager.shop.model.catalog.product
# Entity		ReadableImage		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProduct		com.salesmanager.shop.model.catalog.product
# Entity		RentalOwner		com.salesmanager.shop.model.catalog.product
# Entity		LightPersistableProduct		com.salesmanager.shop.model.catalog.product
# Entity		RelatedProduct		com.salesmanager.shop.model.catalog.product
# Entity		ProductPriceDescription		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductPrice		com.salesmanager.shop.model.catalog.product
# Entity		ProductSpecification		com.salesmanager.shop.model.catalog.product
# Entity		ProductReviewEntity		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductPriceFull		com.salesmanager.shop.model.catalog.product
# Entity		ProductPrice		com.salesmanager.shop.model.catalog.product
# Entity		Product		com.salesmanager.shop.model.catalog.product
# Entity		PersistableImage		com.salesmanager.shop.model.catalog.product
# Entity		ProductEntity		com.salesmanager.shop.model.catalog.product
# Entity		ProductDescription		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductReview		com.salesmanager.shop.model.catalog.product
# Entity		PersistableProduct		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductName		com.salesmanager.shop.model.catalog.product
# Entity		ReadableProductAttributeValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductOptionValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionEntity		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOption		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductAttribute		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductAttribute		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductOption		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductVariantValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableSelectedProductVariant		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductVariant		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ReadableProductAttribute		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductAttributeValueDescription		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductOptionValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductOption		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionDescription		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionValue		com.salesmanager.shop.model.catalog.product.attribute
# Entity		ProductOptionValueDescription		com.salesmanager.shop.model.catalog.product.attribute
# Entity		PersistableProductOptionSet		com.salesmanager.shop.model.catalog.product.attribute.optionset
# Entity		ProductOptionSetEntity		com.salesmanager.shop.model.catalog.product.attribute.optionset
# Entity		ReadableProductOptionSet		com.salesmanager.shop.model.catalog.product.attribute.optionset
# Entity		PersistableProductOptionValueEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionFull		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductAttributeList		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductAttributeEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionValueFull		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		PersistableProductOptionEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionValueEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ProductAttributeEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ProductOptionValueEntity		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionList		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductOptionValueList		com.salesmanager.shop.model.catalog.product.attribute.api
# Entity		ReadableProductTypeList		com.salesmanager.shop.model.catalog.product.type
# Entity		ProductTypeEntity		com.salesmanager.shop.model.catalog.product.type
# Entity		ReadableProductType		com.salesmanager.shop.model.catalog.product.type
# Entity		PersistableProductType		com.salesmanager.shop.model.catalog.product.type
# Entity		ProductGroup		com.salesmanager.shop.model.catalog.product.group
# Entity		ReadableInventoryList		com.salesmanager.shop.model.catalog.product.inventory
# Entity		InventoryEntity		com.salesmanager.shop.model.catalog.product.inventory
# Entity		PersistableInventory		com.salesmanager.shop.model.catalog.product.inventory
# Entity		ReadableInventory		com.salesmanager.shop.model.catalog.product.inventory
# Entity		Manufacturer		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableManufacturerList		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ManufacturerDescription		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableManufacturerFull		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableManufacturer		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ManufacturerEntity		com.salesmanager.shop.model.catalog.manufacturer
# Entity		PersistableManufacturer		com.salesmanager.shop.model.catalog.manufacturer
# Entity		ReadableCategoryList		com.salesmanager.shop.model.catalog.category
# Entity		ReadableCategoryName		com.salesmanager.shop.model.catalog.category
# Entity		Category		com.salesmanager.shop.model.catalog.category
# Entity		CategoryDescription		com.salesmanager.shop.model.catalog.category
# Entity		CategoryEntity		com.salesmanager.shop.model.catalog.category
# Entity		ReadableCategoryFull		com.salesmanager.shop.model.catalog.category
# Entity		ReadableCategory		com.salesmanager.shop.model.catalog.category
# Entity		PersistableCategory		com.salesmanager.shop.model.catalog.category
# Entity		CatalogEntryEntity		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalog		com.salesmanager.shop.model.catalog.catalog
# Entity		CatalogEntity		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogCategoryEntry		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogCategoryEntryList		com.salesmanager.shop.model.catalog.catalog
# Entity		PersistableCatalogCategoryEntry		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogName		com.salesmanager.shop.model.catalog.catalog
# Entity		ReadableCatalogList		com.salesmanager.shop.model.catalog.catalog
# Entity		PersistableCatalog		com.salesmanager.shop.model.catalog.catalog
# Entity		BeanUtils		com.salesmanager.shop.validation
# Entity		FieldMatchValidator		com.salesmanager.shop.validation
# Entity		EnumValidator		com.salesmanager.shop.validation
# Logic		LanguageArgumentResolver		com.salesmanager.shop.application.config
# Logic		MerchantStoreArgumentResolver		com.salesmanager.shop.application.config
# Logic		InitializationLoader		com.salesmanager.shop.init.data
# Logic		ShoppingCartModelPopulator		com.salesmanager.shop.populator.shoppingCart
# Logic		PersistableUserPopulator		com.salesmanager.shop.populator.user
# Logic		PersistableMerchantStorePopulator		com.salesmanager.shop.populator.store
# Logic		PersistableOrderApiPopulator		com.salesmanager.shop.populator.order
# Logic		ReadableOrderPopulator		com.salesmanager.shop.populator.order
# Logic		CustomerPopulator		com.salesmanager.shop.populator.customer
# Logic		PersistableProductPopulator		com.salesmanager.shop.populator.catalog
# Logic		PersistableCategoryPopulator		com.salesmanager.shop.populator.catalog
# Logic		FilesController		com.salesmanager.shop.controller
# Logic		ImagesController		com.salesmanager.shop.controller
# Logic		ReferenceController		com.salesmanager.shop.controller
# Logic		WebApplicationCacheUtils		com.salesmanager.shop.utils
# Logic		EmailTemplatesUtils		com.salesmanager.shop.utils
# Logic		AppConfiguration		com.salesmanager.shop.utils
# Logic		ImageFilePathUtils		com.salesmanager.shop.utils
# Logic		AuthorizationUtils		com.salesmanager.shop.utils
# Logic		EmailUtils		com.salesmanager.shop.utils
# Logic		LocalImageFilePathUtils		com.salesmanager.shop.utils
# Logic		CaptchaRequestUtils		com.salesmanager.shop.utils
# Logic		CloudFilePathUtils		com.salesmanager.shop.utils
# Logic		LanguageUtils		com.salesmanager.shop.utils
# Logic		BreadcrumbsUtils		com.salesmanager.shop.utils
# Logic		FilePathUtils		com.salesmanager.shop.utils
# Logic		ReadableOptinMapper		com.salesmanager.shop.mapper.optin
# Logic		PersistableOptinMapper		com.salesmanager.shop.mapper.optin
# Logic		ReadableTaxRateMapper		com.salesmanager.shop.mapper.tax
# Logic		PersistableTaxRateMapper		com.salesmanager.shop.mapper.tax
# Logic		PersistableTaxClassMapper		com.salesmanager.shop.mapper.tax
# Logic		ReadableTaxClassMapper		com.salesmanager.shop.mapper.tax
# Logic		PersistableInventoryMapper		com.salesmanager.shop.mapper.inventory
# Logic		ReadableInventoryMapper		com.salesmanager.shop.mapper.inventory
# Logic		PersistableProductAttributeMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductOptionSetMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableCatalogCategoryEntryMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableCatalogCategoryEntryMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductOptionMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableCatalogMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductOptionValueMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductOptionValueMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductOptionSetMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableCategoryMapper		com.salesmanager.shop.mapper.catalog
# Logic		PersistableProductTypeMapper		com.salesmanager.shop.mapper.catalog
# Logic		ReadableProductAttributeMapper		com.salesmanager.shop.mapper.catalog
# ...
# Interface	ProductImagePut		com.salesmanager.core.business.modules.cms.product
# Interface	ProductAssetsManager		com.salesmanager.core.business.modules.cms.product
# Interface	ProductImageGet		com.salesmanager.core.business.modules.cms.product
# Interface	ProductImageRemove		com.salesmanager.core.business.modules.cms.product
# Interface	CMSManager		com.salesmanager.core.business.modules.cms.impl
# Interface	CacheManager		com.salesmanager.core.business.modules.cms.impl
# Interface	FileGet		com.salesmanager.core.business.modules.cms.content
# Interface	FileRemove		com.salesmanager.core.business.modules.cms.content
# Interface	FolderRemove		com.salesmanager.core.business.modules.cms.content
# Interface	FolderPut		com.salesmanager.core.business.modules.cms.content
# Interface	FolderList		com.salesmanager.core.business.modules.cms.content
# Interface	ContentAssetsManager		com.salesmanager.core.business.modules.cms.content
# Interface	ContentImageGet		com.salesmanager.core.business.modules.cms.content
# Interface	ImagePut		com.salesmanager.core.business.modules.cms.content
# Interface	ContentImageRemove		com.salesmanager.core.business.modules.cms.content
# Interface	FilePut		com.salesmanager.core.business.modules.cms.content
# Interface	ImageRemove		com.salesmanager.core.business.modules.cms.common
# Interface	AssetsManager		com.salesmanager.core.business.modules.cms.common
# Interface	ImageGet		com.salesmanager.core.business.modules.cms.common
# Interface	OrderProcessor		com.salesmanager.core.business.modules.order
# Interface	InvoiceModule		com.salesmanager.core.business.modules.order
# Interface	CountryRepository		com.salesmanager.core.business.repositories.reference.country
# Interface	LanguageRepository		com.salesmanager.core.business.repositories.reference.language
# Interface	CurrencyRepository		com.salesmanager.core.business.repositories.reference.currency
# Interface	ZoneRepository		com.salesmanager.core.business.repositories.reference.zone
# Interface	PermissionRepository		com.salesmanager.core.business.repositories.user
# Interface	GroupRepository		com.salesmanager.core.business.repositories.user
# Interface	PermissionRepositoryCustom		com.salesmanager.core.business.repositories.user
# Interface	PageableUserRepository		com.salesmanager.core.business.repositories.user
# Interface	UserRepository		com.salesmanager.core.business.repositories.user
# Interface	UserRepositoryCustom		com.salesmanager.core.business.repositories.user
# Interface	ShoppingCartItemRepository		com.salesmanager.core.business.repositories.shoppingcart
# Interface	ShoppingCartAttributeRepository		com.salesmanager.core.business.repositories.shoppingcart
# Interface	ShoppingCartRepository		com.salesmanager.core.business.repositories.shoppingcart
# Interface	ContentRepositoryCustom		com.salesmanager.core.business.repositories.content
# Interface	ContentRepository		com.salesmanager.core.business.repositories.content
# Interface	TaxRateRepository		com.salesmanager.core.business.repositories.tax
# Interface	TaxClassRepository		com.salesmanager.core.business.repositories.tax
# Interface	TransactionRepository		com.salesmanager.core.business.repositories.payments
# Interface	ShippingOriginRepository		com.salesmanager.core.business.repositories.shipping
# Interface	ShippingQuoteRepository		com.salesmanager.core.business.repositories.shipping
# Interface	OrderRepositoryCustom		com.salesmanager.core.business.repositories.order
# Interface	OrderTotalRepository		com.salesmanager.core.business.repositories.order
# Interface	OrderRepository		com.salesmanager.core.business.repositories.order
# Interface	OrderProductRepository		com.salesmanager.core.business.repositories.order.orderproduct
# Interface	OrderProductDownloadRepository		com.salesmanager.core.business.repositories.order.orderproduct
# Interface	OrderAccountRepository		com.salesmanager.core.business.repositories.order.orderaccount
# Interface	MerchantRepository		com.salesmanager.core.business.repositories.merchant
# Interface	PageableMerchantRepository		com.salesmanager.core.business.repositories.merchant
# Interface	MerchantRepositoryCustom		com.salesmanager.core.business.repositories.merchant
# Interface	SystemConfigurationRepository		com.salesmanager.core.business.repositories.system
# Interface	OptinRepository		com.salesmanager.core.business.repositories.system
# Interface	MerchantConfigurationRepository		com.salesmanager.core.business.repositories.system
# Interface	MerchantLogRepository		com.salesmanager.core.business.repositories.system
# Interface	ModuleConfigurationRepository		com.salesmanager.core.business.repositories.system
# Interface	SystemNotificationRepository		com.salesmanager.core.business.repositories.system
# Interface	CustomerRepository		com.salesmanager.core.business.repositories.customer
# Interface	CustomerRepositoryCustom		com.salesmanager.core.business.repositories.customer
# Interface	CustomerAttributeRepository		com.salesmanager.core.business.repositories.customer.attribute
# Interface	CustomerOptionValueRepository		com.salesmanager.core.business.repositories.customer.attribute
# Interface	CustomerOptionRepository		com.salesmanager.core.business.repositories.customer.attribute
# Interface	CustomerOptionSetRepository		com.salesmanager.core.business.repositories.customer.attribute
# Interface	CustomerReviewRepository		com.salesmanager.core.business.repositories.customer.review
# Interface	CustomerOptinRepository		com.salesmanager.core.business.repositories.customer.optin
# Interface	ProductRepositoryCustom		com.salesmanager.core.business.repositories.catalog.product
# Interface	ProductRepository		com.salesmanager.core.business.repositories.catalog.product
# Interface	DigitalProductRepository		com.salesmanager.core.business.repositories.catalog.product.file
# Interface	PageableProductOptionRepository		com.salesmanager.core.business.repositories.catalog.product.attribute
# Interface	ProductAttributeRepository		com.salesmanager.core.business.repositories.catalog.product.attribute
# Interface	ProductOptionSetRepository		com.salesmanager.core.business.repositories.catalog.product.attribute
# Interface	ProductOptionValueRepository		com.salesmanager.core.business.repositories.catalog.product.attribute
# Interface	PageableProductOptionValueRepository		com.salesmanager.core.business.repositories.catalog.product.attribute
# Interface	ProductOptionRepository		com.salesmanager.core.business.repositories.catalog.product.attribute
# Interface	PageableProductAvailabilityRepository		com.salesmanager.core.business.repositories.catalog.product.availability
# Interface	ProductAvailabilityRepository		com.salesmanager.core.business.repositories.catalog.product.availability
# Interface	PageableManufacturerRepository		com.salesmanager.core.business.repositories.catalog.product.manufacturer
# Interface	ManufacturerRepository		com.salesmanager.core.business.repositories.catalog.product.manufacturer
# Interface	ProductReviewRepository		com.salesmanager.core.business.repositories.catalog.product.review
# Interface	ProductRelationshipRepository		com.salesmanager.core.business.repositories.catalog.product.relationship
# Interface	ProductRelationshipRepositoryCustom		com.salesmanager.core.business.repositories.catalog.product.relationship
# Interface	ProductPriceRepository		com.salesmanager.core.business.repositories.catalog.product.price
# Interface	ProductTypeRepository		com.salesmanager.core.business.repositories.catalog.product.type
# Interface	PageableProductTypeRepository		com.salesmanager.core.business.repositories.catalog.product.type
# Interface	ProductImageRepository		com.salesmanager.core.business.repositories.catalog.product.image
# Interface	CategoryRepository		com.salesmanager.core.business.repositories.catalog.category
# Interface	PageableCategoryRepositoryCustom		com.salesmanager.core.business.repositories.catalog.category
# Interface	CategoryDescriptionRepository		com.salesmanager.core.business.repositories.catalog.category
# Interface	CategoryRepositoryCustom		com.salesmanager.core.business.repositories.catalog.category
# Interface	PageableCategoryRepository		com.salesmanager.core.business.repositories.catalog.category
# Interface	PageableCatalogEntryRepository		com.salesmanager.core.business.repositories.catalog.catalog
# Interface	PageableCatalogRepository		com.salesmanager.core.business.repositories.catalog.catalog
# Interface	CatalogRepository		com.salesmanager.core.business.repositories.catalog.catalog
# Interface	CatalogEntryRepository		com.salesmanager.core.business.repositories.catalog.catalog
# Interface	EntityPopulator		com.salesmanager.core.business.utils
# Interface	DataPopulator		com.salesmanager.core.business.utils
# Interface	CountryService		com.salesmanager.core.business.services.reference.country
# Interface	LanguageService		com.salesmanager.core.business.services.reference.language
# Interface	InitializationDatabase		com.salesmanager.core.business.services.reference.init
# Interface	CurrencyService		com.salesmanager.core.business.services.reference.currency
# Interface	ZoneService		com.salesmanager.core.business.services.reference.zone
# Interface	GroupService		com.salesmanager.core.business.services.user
# Interface	PermissionService		com.salesmanager.core.business.services.user
# Interface	UserService		com.salesmanager.core.business.services.user
# Interface	ShoppingCartService		com.salesmanager.core.business.services.shoppingcart
# Interface	ShoppingCartCalculationService		com.salesmanager.core.business.services.shoppingcart
# Interface	ContentService		com.salesmanager.core.business.services.content
# Interface	TaxClassService		com.salesmanager.core.business.services.tax
# Interface	TaxService		com.salesmanager.core.business.services.tax
# Interface	TaxRateService		com.salesmanager.core.business.services.tax
# Interface	TransactionService		com.salesmanager.core.business.services.payments
# Interface	PaymentService		com.salesmanager.core.business.services.payments
# Interface	SalesManagerEntityService		com.salesmanager.core.business.services.common.generic
# Interface	TransactionalAspectAwareService		com.salesmanager.core.business.services.common.generic
# Interface	ShippingQuoteService		com.salesmanager.core.business.services.shipping
# Interface	ShippingService		com.salesmanager.core.business.services.shipping
# Interface	ShippingOriginService		com.salesmanager.core.business.services.shipping
# Interface	OrderService		com.salesmanager.core.business.services.order
# Interface	OrderProductDownloadService		com.salesmanager.core.business.services.order.orderproduct
# Interface	OrderTotalService		com.salesmanager.core.business.services.order.ordertotal
# Interface	MerchantStoreService		com.salesmanager.core.business.services.merchant
# Interface	SearchService		com.salesmanager.core.business.services.search
# Interface	MerchantConfigurationService		com.salesmanager.core.business.services.system
# Interface	ModuleConfigurationService		com.salesmanager.core.business.services.system
# Interface	SystemConfigurationService		com.salesmanager.core.business.services.system
# Interface	MerchantLogService		com.salesmanager.core.business.services.system
# Interface	EmailService		com.salesmanager.core.business.services.system
# Interface	OptinService		com.salesmanager.core.business.services.system.optin
# Interface	CustomerService		com.salesmanager.core.business.services.customer
# Interface	CustomerAttributeService		com.salesmanager.core.business.services.customer.attribute
# Interface	CustomerOptionSetService		com.salesmanager.core.business.services.customer.attribute
# Interface	CustomerOptionValueService		com.salesmanager.core.business.services.customer.attribute
# Interface	CustomerOptionService		com.salesmanager.core.business.services.customer.attribute
# Interface	CustomerReviewService		com.salesmanager.core.business.services.customer.review
# Interface	CustomerOptinService		com.salesmanager.core.business.services.customer.optin
# Interface	PricingService		com.salesmanager.core.business.services.catalog.product
# Interface	ProductService		com.salesmanager.core.business.services.catalog.product
# Interface	DigitalProductService		com.salesmanager.core.business.services.catalog.product.file
# Interface	ProductOptionSetService		com.salesmanager.core.business.services.catalog.product.attribute
# Interface	ProductOptionValueService		com.salesmanager.core.business.services.catalog.product.attribute
# Interface	ProductOptionService		com.salesmanager.core.business.services.catalog.product.attribute
# Interface	ProductAttributeService		com.salesmanager.core.business.services.catalog.product.attribute
# Interface	ProductAvailabilityService		com.salesmanager.core.business.services.catalog.product.availability
# Interface	ManufacturerService		com.salesmanager.core.business.services.catalog.product.manufacturer
# Interface	ProductReviewService		com.salesmanager.core.business.services.catalog.product.review
# Interface	ProductRelationshipService		com.salesmanager.core.business.services.catalog.product.relationship
# Interface	ProductPriceService		com.salesmanager.core.business.services.catalog.product.price
# Interface	ProductTypeService		com.salesmanager.core.business.services.catalog.product.type
# Interface	ProductImageService		com.salesmanager.core.business.services.catalog.product.image
# Interface	MarketPlaceService		com.salesmanager.core.business.services.catalog.marketplace
# Interface	CategoryService		com.salesmanager.core.business.services.catalog.category
# Interface	CatalogEntryService		com.salesmanager.core.business.services.catalog.catalog
# Interface	CatalogService		com.salesmanager.core.business.services.catalog.catalog
# Interface	ResourceUrlAccess		com.salesmanager.shop.model.entity
# Interface	ReadableAuditable		com.salesmanager.shop.model.entity
# Interface	ConfigurationsFacade		com.salesmanager.shop.store.controller.configurations
# Interface	ProductOptionSetFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductTypeFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductInventoryFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	ProductOptionFacade		com.salesmanager.shop.store.controller.product.facade
# Interface	UserFacade		com.salesmanager.shop.store.controller.user.facade
# Interface	ContentFacade		com.salesmanager.shop.store.controller.content.facade
# Interface	ManufacturerFacade		com.salesmanager.shop.store.controller.manufacturer.facade
# Interface	TaxFacade		com.salesmanager.shop.store.controller.tax.facade
# Interface	ProductItemsFacade		com.salesmanager.shop.store.controller.items.facade
# Interface	ShippingFacade		com.salesmanager.shop.store.controller.shipping.facade
# Interface	ShippingModuleConfigurationFacade		com.salesmanager.shop.store.controller.shipping.facade
# Interface	CategoryFacade		com.salesmanager.shop.store.controller.category.facade
# Interface	CatalogFacade		com.salesmanager.shop.store.controller.catalog.facade
# Excluded	ShopApplication		com.salesmanager.shop.application
# Excluded	WebConfig		com.salesmanager.shop.application.config
# Excluded	DocumentationConfiguration		com.salesmanager.shop.application.config
# Excluded	LocationImageConfig		com.salesmanager.shop.application.config
# Excluded	MethodSecurityConfig		com.salesmanager.shop.application.config
# Excluded	ShopApplicationConfiguration		com.salesmanager.shop.application.config
# Excluded	AsyncConfig		com.salesmanager.shop.application.config
# Excluded	ShopizerPropertiesConfig		com.salesmanager.shop.application.config
# Excluded	MultipleEntryPointsSecurityConfig		com.salesmanager.shop.application.config
# Excluded	PersistableAuditAspect		com.salesmanager.shop.populator
# Excluded	AdminErrorController		com.salesmanager.shop.store.controller.error
# Excluded	ShopErrorController		com.salesmanager.shop.store.controller.error
# Excluded	RestErrorHandler		com.salesmanager.shop.store.api.exception
# Excluded	ProcessorsConfiguration		com.salesmanager.core.business.configuration
# Excluded	DataConfiguration		com.salesmanager.core.business.configuration
# Excluded	CoreApplicationConfiguration		com.salesmanager.core.business.configuration

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')
# Out:
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: ImageFilePathinterface does not have an implementing class!
# WARNING: UserServiceinterface does not have an implementing class!
# WARNING: CountryRepositoryinterface does not have an implementing class!
# WARNING: CountryRepositoryinterface does not have an implementing class!
# WARNING: CountryRepositoryinterface does not have an implementing class!
# WARNING: LanguageRepositoryinterface does not have an implementing class!
# WARNING: CurrencyRepositoryinterface does not have an implementing class!
# WARNING: ZoneRepositoryinterface does not have an implementing class!
# WARNING: ZoneRepositoryinterface does not have an implementing class!
# WARNING: GroupRepositoryinterface does not have an implementing class!
# WARNING: GroupRepositoryinterface does not have an implementing class!
# WARNING: GroupRepositoryinterface does not have an implementing class!
# WARNING: GroupRepositoryinterface does not have an implementing class!
# WARNING: PermissionRepositoryinterface does not have an implementing class!
# WARNING: PermissionRepositoryinterface does not have an implementing class!
# WARNING: PermissionRepositoryinterface does not have an implementing class!
# WARNING: PermissionRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartAttributeRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartItemRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartItemRepositoryinterface does not have an implementing class!
# WARNING: ShoppingCartItemRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: ContentRepositoryinterface does not have an implementing class!
# WARNING: TaxRateRepositoryinterface does not have an implementing class!
# WARNING: TaxRateRepositoryinterface does not have an implementing class!
# WARNING: TaxRateRepositoryinterface does not have an implementing class!
# WARNING: TaxRateRepositoryinterface does not have an implementing class!
# WARNING: TaxRateRepositoryinterface does not have an implementing class!
# WARNING: TaxRateRepositoryinterface does not have an implementing class!
# WARNING: TaxClassRepositoryinterface does not have an implementing class!
# WARNING: TaxClassRepositoryinterface does not have an implementing class!
# WARNING: TaxClassRepositoryinterface does not have an implementing class!
# WARNING: TaxClassRepositoryinterface does not have an implementing class!
# WARNING: TransactionRepositoryinterface does not have an implementing class!
# WARNING: TransactionRepositoryinterface does not have an implementing class!
# WARNING: TransactionRepositoryinterface does not have an implementing class!
# WARNING: TransactionRepositoryinterface does not have an implementing class!
# WARNING: ShippingQuoteRepositoryinterface does not have an implementing class!
# WARNING: ShippingQuoteRepositoryinterface does not have an implementing class!
# WARNING: ShippingOriginRepositoryinterface does not have an implementing class!
# WARNING: InvoiceModuleinterface does not have an implementing class!
# WARNING: OrderRepositoryinterface does not have an implementing class!
# WARNING: OrderRepositoryinterface does not have an implementing class!
# WARNING: OrderRepositoryinterface does not have an implementing class!
# WARNING: OrderProductDownloadRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: PageableMerchantRepositoryinterface does not have an implementing class!
# WARNING: PageableMerchantRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: PageableMerchantRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: PageableMerchantRepositoryinterface does not have an implementing class!
# WARNING: MerchantRepositoryinterface does not have an implementing class!
# WARNING: SystemConfigurationRepositoryinterface does not have an implementing class!
# WARNING: MerchantConfigurationRepositoryinterface does not have an implementing class!
# WARNING: MerchantConfigurationRepositoryinterface does not have an implementing class!
# WARNING: MerchantConfigurationRepositoryinterface does not have an implementing class!
# WARNING: MerchantConfigurationRepositoryinterface does not have an implementing class!
# WARNING: MerchantConfigurationRepositoryinterface does not have an implementing class!
# WARNING: MerchantConfigurationRepositoryinterface does not have an implementing class!
# WARNING: ModuleConfigurationRepositoryinterface does not have an implementing class!
# WARNING: ModuleConfigurationRepositoryinterface does not have an implementing class!
# WARNING: OptinRepositoryinterface does not have an implementing class!
# WARNING: OptinRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: CustomerRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionValueRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionValueRepositoryinterface does not have an implementing class!
# WARNING: CustomerAttributeRepositoryinterface does not have an implementing class!
# WARNING: CustomerAttributeRepositoryinterface does not have an implementing class!
# WARNING: CustomerAttributeRepositoryinterface does not have an implementing class!
# WARNING: CustomerAttributeRepositoryinterface does not have an implementing class!
# WARNING: CustomerAttributeRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionSetRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionSetRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionSetRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptionSetRepositoryinterface does not have an implementing class!
# WARNING: CustomerReviewRepositoryinterface does not have an implementing class!
# WARNING: CustomerReviewRepositoryinterface does not have an implementing class!
# WARNING: CustomerReviewRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptinRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptinRepositoryinterface does not have an implementing class!
# WARNING: CustomerOptinRepositoryinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: SearchServiceinterface does not have an implementing class!
# WARNING: ProductRepositoryinterface does not have an implementing class!
# WARNING: DigitalProductRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionValueRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionValueRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionValueRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionValueRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionValueRepositoryinterface does not have an implementing class!
# WARNING: PageableProductOptionValueRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionSetRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionSetRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionSetRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionSetRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionRepositoryinterface does not have an implementing class!
# WARNING: ProductOptionRepositoryinterface does not have an implementing class!
# WARNING: PageableProductOptionRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAttributeRepositoryinterface does not have an implementing class!
# WARNING: ProductAvailabilityRepositoryinterface does not have an implementing class!
# WARNING: PageableProductAvailabilityRepositoryinterface does not have an implementing class!
# WARNING: ProductAvailabilityRepositoryinterface does not have an implementing class!
# WARNING: ProductAvailabilityRepositoryinterface does not have an implementing class!
# WARNING: ProductAvailabilityRepositoryinterface does not have an implementing class!
# WARNING: ManufacturerRepositoryinterface does not have an implementing class!
# WARNING: PageableManufacturerRepositoryinterface does not have an implementing class!
# WARNING: ManufacturerRepositoryinterface does not have an implementing class!
# WARNING: ManufacturerRepositoryinterface does not have an implementing class!
# WARNING: ManufacturerRepositoryinterface does not have an implementing class!
# WARNING: ManufacturerRepositoryinterface does not have an implementing class!
# WARNING: ManufacturerRepositoryinterface does not have an implementing class!
# WARNING: ProductReviewRepositoryinterface does not have an implementing class!
# WARNING: ProductReviewRepositoryinterface does not have an implementing class!
# WARNING: ProductReviewRepositoryinterface does not have an implementing class!
# WARNING: ProductReviewRepositoryinterface does not have an implementing class!
# WARNING: ProductRelationshipRepositoryinterface does not have an implementing class!
# WARNING: ProductRelationshipRepositoryinterface does not have an implementing class!
# WARNING: ProductRelationshipRepositoryinterface does not have an implementing class!
# WARNING: ProductRelationshipRepositoryinterface does not have an implementing class!
# WARNING: ProductRelationshipRepositoryinterface does not have an implementing class!
# WARNING: ProductRelationshipRepositoryinterface does not have an implementing class!
# WARNING: ProductTypeRepositoryinterface does not have an implementing class!
# WARNING: ProductTypeRepositoryinterface does not have an implementing class!
# WARNING: ProductTypeRepositoryinterface does not have an implementing class!
# WARNING: PageableProductTypeRepositoryinterface does not have an implementing class!
# WARNING: ProductTypeRepositoryinterface does not have an implementing class!
# WARNING: ProductTypeRepositoryinterface does not have an implementing class!
# WARNING: ProductImageRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CategoryRepositoryinterface does not have an implementing class!
# WARNING: CatalogRepositoryinterface does not have an implementing class!
# WARNING: PageableCatalogRepositoryinterface does not have an implementing class!
# WARNING: CatalogRepositoryinterface does not have an implementing class!
# WARNING: CatalogRepositoryinterface does not have an implementing class!
# WARNING: CatalogRepositoryinterface does not have an implementing class!
# WARNING: CatalogRepositoryinterface does not have an implementing class!
# WARNING: CatalogEntryRepositoryinterface does not have an implementing class!
# WARNING: PageableCatalogEntryRepositoryinterface does not have an implementing class!
# WARNING: CatalogEntryRepositoryinterface does not have an implementing class!

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['resolveArgument(MerchantStoreArgumentResolver)', 'Calls', 'isBlank(MerchantStoreArgumentResolver)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'getId(Customer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'create(ShoppingCartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'getId(Customer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'create(ShoppingCartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'update(ShoppingCartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(CustomerPopulator)', 'Calls', 'getById(CustomerOptionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(CustomerPopulator)', 'Calls', 'getById(CustomerOptionValueServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'toString(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'toString(PersistableCategoryPopulator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'toString(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'toString(FilesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'toString(ImagesController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'toString(EmailTemplatesUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'toString(EmailTemplatesUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getContextPath(ImageFilePathUtils)', 'Calls', 'getProperty(ImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getContextPath(LocalImageFilePathUtils)', 'Calls', 'getProperty(LocalImageFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getContextPath(CloudFilePathUtils)', 'Calls', 'getProperty(CloudFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildCategoryBreadcrumb(BreadcrumbsUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildProductBreadcrumb(BreadcrumbsUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseBreadCrumb(BreadcrumbsUtils)', 'Calls', 'split(BreadcrumbsUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['afterPropertiesSet(RestAuthenticationEntryPoint)', 'Calls', 'equals(RestAuthenticationEntryPoint)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attemptAuthentication(JWTAdminAuthenticationManager)', 'Calls', 'ofNullable(JWTAdminAuthenticationManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attemptAuthentication(JWTAdminAuthenticationManager)', 'Calls', 'buildDetails(JWTAdminAuthenticationManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attemptAuthentication(JWTCustomerAuthenticationManager)', 'Calls', 'buildDetails(JWTCustomerAuthenticationManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayLanding(LandingController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayLanding(LandingController)', 'Calls', 'append(LandingController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayLanding(LandingController)', 'Calls', 'append(LandingController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayMiniCart(MiniCartController)', 'Calls', 'getSessionAttribute(MiniCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createCartModel(ShoppingCartFacadeImpl)', 'Calls', 'create(ShoppingCartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveShoppingCart(ShoppingCartFacadeImpl)', 'Calls', 'save(ShoppingCartServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOptin(OptinFacadeImpl)', 'Calls', 'create(OptinServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getList(CurrencyFacadeImpl)', 'Calls', 'list(CurrencyServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['display(ContactController)', 'Calls', 'append(ContactController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['display(ContactController)', 'Calls', 'append(ContactController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['display(ContactController)', 'Calls', 'append(ContactController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendEmail(ContactController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMerchantStore(StoreFacadeImpl)', 'Calls', 'create(MerchantStoreServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateMerchantStore(StoreFacadeImpl)', 'Calls', 'update(MerchantStoreServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['delete(StoreFacadeImpl)', 'Calls', 'delete(MerchantStoreServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveMerchantStore(StoreFacadeImpl)', 'Calls', 'save(MerchantStoreServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveShippingOrigin(ShippingFacadeImpl)', 'Calls', 'save(ShippingOriginServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'toString(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getManufacturers(ShoppingCategoryController)', 'Calls', 'populate(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getProducts(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getProducts(ShoppingCategoryController)', 'Calls', 'toString(ShoppingCategoryController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getSessionAttribute(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getSessionAttribute(ShoppingOrderController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'toString(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getById(OrderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'toString(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'getSessionAttribute(ShoppingOrderPaymentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadFile(ShoppingOrderDownloadController)', 'Calls', 'getById(OrderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['downloadFile(ShoppingOrderDownloadController)', 'Calls', 'getById(OrderProductDownloadServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processOrder(OrderFacadeImpl)', 'Calls', 'equals(OrderFacadeImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'equals(OrderFacadeImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# ...
# INFO: Edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['pageImages(ContentImageController)', 'Calls', 'append(ContentImageController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['pageImages(ContentImageController)', 'Calls', 'append(ContentImageController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['pageImages(ContentImageController)', 'Calls', 'toString(ContentImageController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'save(ProductOptionValueServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductPrice(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkAttributeType(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['checkAttributeType(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeItem(RelatedItemsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductReview(ProductReviewController)', 'Calls', 'getById(ProductReviewServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductReview(ProductReviewController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductReview(ProductReviewController)', 'Calls', 'delete(ProductReviewServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeItem(FeaturedItemsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['pageCustomGroups(CustomProductGroupsController)', 'Calls', 'equals(CustomProductGroupsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveCustomProductGroup(CustomProductGroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['activateProductGroup(CustomProductGroupsController)', 'Calls', 'equals(CustomProductGroupsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeItem(CustomProductGroupsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProduct(ProductsController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeFile(DigitalProductController)', 'Calls', 'getById(DigitalProductServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['displayProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['duplicateProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeImage(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductFromCategory(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductFromCategory(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteOptionValue(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeImage(OptionsValueController)', 'Calls', 'update(ProductOptionValueServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductPrice(ProductPriceController)', 'Calls', 'getById(ProductPriceServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveOption(OptionsController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteOption(OptionsController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductImages(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductImages(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductImagesUrl(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveProductImagesUrl(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setDefaultImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setDefaultImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addKeyword(ProductKeywordsController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteCategory(CategoryController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveTaxRate(TaxRatesController)', 'Calls', 'create(TaxRateServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTaxRate(TaxRatesController)', 'Calls', 'update(TaxRateServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getById(ZoneServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['saveTaxClass(TaxClassController)', 'Calls', 'create(TaxClassServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTaxClass(TaxClassController)', 'Calls', 'update(TaxClassServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['savePaymentMethod(PaymentsController)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['captureOrder(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['captureOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['captureOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['printInvoice(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] skipped since target method is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['resolveArgument(MerchantStoreArgumentResolver)', 'Calls', 'isBlank(MerchantStoreArgumentResolver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'getId(Customer)']: discarding
# WARNING: unable to recover ['populate(ShoppingCartModelPopulator)', 'Calls', 'create(ShoppingCartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'getId(Customer)']: discarding
# WARNING: unable to recover ['populate(ShoppingCartModelPopulator)', 'Calls', 'create(ShoppingCartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(ShoppingCartModelPopulator)', 'Calls', 'update(ShoppingCartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(CustomerPopulator)', 'Calls', 'getById(CustomerOptionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(CustomerPopulator)', 'Calls', 'getById(CustomerOptionValueServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'toString(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populate(PersistableCategoryPopulator)', 'Calls', 'toString(PersistableCategoryPopulator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadFile(FilesController)', 'Calls', 'toString(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadProduct(FilesController)', 'Calls', 'toString(FilesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['printImage(ImagesController)', 'Calls', 'toString(ImagesController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'toString(EmailTemplatesUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'toString(EmailTemplatesUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['getContextPath(ImageFilePathUtils)', 'Calls', 'getProperty(ImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getContextPath(LocalImageFilePathUtils)', 'Calls', 'getProperty(LocalImageFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getContextPath(CloudFilePathUtils)', 'Calls', 'getProperty(CloudFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['buildCategoryBreadcrumb(BreadcrumbsUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['buildProductBreadcrumb(BreadcrumbsUtils)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['parseBreadCrumb(BreadcrumbsUtils)', 'Calls', 'split(BreadcrumbsUtils)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['afterPropertiesSet(RestAuthenticationEntryPoint)', 'Calls', 'equals(RestAuthenticationEntryPoint)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attemptAuthentication(JWTAdminAuthenticationManager)', 'Calls', 'ofNullable(JWTAdminAuthenticationManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attemptAuthentication(JWTAdminAuthenticationManager)', 'Calls', 'buildDetails(JWTAdminAuthenticationManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attemptAuthentication(JWTCustomerAuthenticationManager)', 'Calls', 'buildDetails(JWTCustomerAuthenticationManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['displayLanding(LandingController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['displayLanding(LandingController)', 'Calls', 'append(LandingController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayLanding(LandingController)', 'Calls', 'append(LandingController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayMiniCart(MiniCartController)', 'Calls', 'getSessionAttribute(MiniCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayShoppingCart(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['shoppingCart(ShoppingCartController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createCartModel(ShoppingCartFacadeImpl)', 'Calls', 'create(ShoppingCartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveShoppingCart(ShoppingCartFacadeImpl)', 'Calls', 'save(ShoppingCartServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createOptin(OptinFacadeImpl)', 'Calls', 'create(OptinServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getList(CurrencyFacadeImpl)', 'Calls', 'list(CurrencyServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['display(ContactController)', 'Calls', 'append(ContactController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['display(ContactController)', 'Calls', 'append(ContactController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['display(ContactController)', 'Calls', 'append(ContactController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['sendEmail(ContactController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['createMerchantStore(StoreFacadeImpl)', 'Calls', 'create(MerchantStoreServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateMerchantStore(StoreFacadeImpl)', 'Calls', 'update(MerchantStoreServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['delete(StoreFacadeImpl)', 'Calls', 'delete(MerchantStoreServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveMerchantStore(StoreFacadeImpl)', 'Calls', 'save(MerchantStoreServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveShippingOrigin(ShippingFacadeImpl)', 'Calls', 'save(ShippingOriginServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCategory(ShoppingCategoryController)', 'Calls', 'toString(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getManufacturers(ShoppingCategoryController)', 'Calls', 'populate(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getProducts(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getProducts(ShoppingCategoryController)', 'Calls', 'toString(ShoppingCategoryController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['calculateShipping(ShoppingOrderController)', 'Calls', 'getSessionAttribute(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getSessionAttribute(ShoppingOrderController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'toString(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getById(OrderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'toString(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'getSessionAttribute(ShoppingOrderPaymentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadFile(ShoppingOrderDownloadController)', 'Calls', 'getById(OrderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadFile(ShoppingOrderDownloadController)', 'Calls', 'getById(OrderProductDownloadServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['processOrder(OrderFacadeImpl)', 'Calls', 'equals(OrderFacadeImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)']: discarding
# ...
# WARNING: Unable to recover target method for edge ['removeUser(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['removeUser(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['pageImages(ContentImageController)', 'Calls', 'append(ContentImageController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['pageImages(ContentImageController)', 'Calls', 'append(ContentImageController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['pageImages(ContentImageController)', 'Calls', 'toString(ContentImageController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['saveAttribute(ProductAttributeController)', 'Calls', 'save(ProductOptionValueServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteProductPrice(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['checkAttributeType(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['checkAttributeType(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['removeItem(RelatedItemsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteProductReview(ProductReviewController)', 'Calls', 'getById(ProductReviewServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteProductReview(ProductReviewController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['deleteProductReview(ProductReviewController)', 'Calls', 'delete(ProductReviewServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeItem(FeaturedItemsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['pageCustomGroups(CustomProductGroupsController)', 'Calls', 'equals(CustomProductGroupsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveCustomProductGroup(CustomProductGroupsController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['activateProductGroup(CustomProductGroupsController)', 'Calls', 'equals(CustomProductGroupsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeItem(CustomProductGroupsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteProduct(ProductsController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['removeFile(DigitalProductController)', 'Calls', 'getById(DigitalProductServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['displayProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['saveProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['duplicateProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['removeImage(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteProductFromCategory(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteProductFromCategory(ProductController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteOptionValue(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['removeImage(OptionsValueController)', 'Calls', 'update(ProductOptionValueServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['deleteProductPrice(ProductPriceController)', 'Calls', 'getById(ProductPriceServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveOption(OptionsController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteOption(OptionsController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductImages(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductImages(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductImagesUrl(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveProductImagesUrl(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['setDefaultImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['setDefaultImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['addKeyword(ProductKeywordsController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['deleteCategory(CategoryController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['saveTaxRate(TaxRatesController)', 'Calls', 'create(TaxRateServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateTaxRate(TaxRatesController)', 'Calls', 'update(TaxRateServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['validateTaxRate(TaxRatesController)', 'Calls', 'getById(ZoneServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['saveTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['saveTaxClass(TaxClassController)', 'Calls', 'create(TaxClassServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['updateTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['updateTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['updateTaxClass(TaxClassController)', 'Calls', 'update(TaxClassServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['savePaymentMethod(PaymentsController)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['captureOrder(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['captureOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['captureOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['refundOrder(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: Unable to recover target method for edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)']: discarding
# WARNING: unable to recover ['printInvoice(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# INFO: Edge ['resolveArgument(MerchantStoreArgumentResolver)', 'Calls', 'isBlank(MerchantStoreArgumentResolver)'] skipped
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'getId(Customer)'] skipped
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'create(ShoppingCartServiceImpl)'] skipped
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'getId(Customer)'] skipped
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'create(ShoppingCartServiceImpl)'] skipped
# INFO: Edge ['populate(ShoppingCartModelPopulator)', 'Calls', 'update(ShoppingCartServiceImpl)'] skipped
# INFO: Edge ['populate(CustomerPopulator)', 'Calls', 'getById(CustomerOptionServiceImpl)'] skipped
# INFO: Edge ['populate(CustomerPopulator)', 'Calls', 'getById(CustomerOptionValueServiceImpl)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'toString(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'append(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['populate(PersistableCategoryPopulator)', 'Calls', 'toString(PersistableCategoryPopulator)'] skipped
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] skipped
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] skipped
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'append(FilesController)'] skipped
# INFO: Edge ['downloadFile(FilesController)', 'Calls', 'toString(FilesController)'] skipped
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] skipped
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] skipped
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'append(FilesController)'] skipped
# INFO: Edge ['downloadProduct(FilesController)', 'Calls', 'toString(FilesController)'] skipped
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] skipped
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] skipped
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'append(ImagesController)'] skipped
# INFO: Edge ['printImage(ImagesController)', 'Calls', 'toString(ImagesController)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'toString(EmailTemplatesUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'append(EmailTemplatesUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'toString(EmailTemplatesUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendRegistrationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendContactEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendUpdateOrderStatusEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['sendOrderDownloadEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePasswordNotificationEmail(EmailTemplatesUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['getContextPath(ImageFilePathUtils)', 'Calls', 'getProperty(ImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStaticimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildManufacturerimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildLargeProductimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildStoreLogoFilePath(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'append(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['buildProductPropertyimageUtils(LocalImageFilePathUtils)', 'Calls', 'toString(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['getContextPath(LocalImageFilePathUtils)', 'Calls', 'getProperty(LocalImageFilePathUtils)'] skipped
# INFO: Edge ['getContextPath(CloudFilePathUtils)', 'Calls', 'getProperty(CloudFilePathUtils)'] skipped
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped
# INFO: Edge ['buildStaticImageUtils(CloudFilePathUtils)', 'Calls', 'append(CloudFilePathUtils)'] skipped
# INFO: Edge ['buildCategoryBreadcrumb(BreadcrumbsUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['buildProductBreadcrumb(BreadcrumbsUtils)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['parseBreadCrumb(BreadcrumbsUtils)', 'Calls', 'split(BreadcrumbsUtils)'] skipped
# INFO: Edge ['afterPropertiesSet(RestAuthenticationEntryPoint)', 'Calls', 'equals(RestAuthenticationEntryPoint)'] skipped
# INFO: Edge ['attemptAuthentication(JWTAdminAuthenticationManager)', 'Calls', 'ofNullable(JWTAdminAuthenticationManager)'] skipped
# INFO: Edge ['attemptAuthentication(JWTAdminAuthenticationManager)', 'Calls', 'buildDetails(JWTAdminAuthenticationManager)'] skipped
# INFO: Edge ['attemptAuthentication(JWTCustomerAuthenticationManager)', 'Calls', 'buildDetails(JWTCustomerAuthenticationManager)'] skipped
# INFO: Edge ['displayLanding(LandingController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayLanding(LandingController)', 'Calls', 'append(LandingController)'] skipped
# INFO: Edge ['displayLanding(LandingController)', 'Calls', 'append(LandingController)'] skipped
# INFO: Edge ['displayMiniCart(MiniCartController)', 'Calls', 'getSessionAttribute(MiniCartController)'] skipped
# INFO: Edge ['addShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['addShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['displayShoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['shoppingCart(ShoppingCartController)', 'Calls', 'append(ShoppingCartController)'] skipped
# INFO: Edge ['removeShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['removeShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['updateShoppingCartItem(ShoppingCartController)', 'Calls', 'getSessionAttribute(ShoppingCartController)'] skipped
# INFO: Edge ['createCartModel(ShoppingCartFacadeImpl)', 'Calls', 'create(ShoppingCartServiceImpl)'] skipped
# INFO: Edge ['saveShoppingCart(ShoppingCartFacadeImpl)', 'Calls', 'save(ShoppingCartServiceImpl)'] skipped
# INFO: Edge ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] skipped
# INFO: Edge ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] skipped
# INFO: Edge ['display(ShopProductController)', 'Calls', 'append(ShopProductController)'] skipped
# INFO: Edge ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] skipped
# INFO: Edge ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] skipped
# INFO: Edge ['displayContent(ShopContentController)', 'Calls', 'append(ShopContentController)'] skipped
# INFO: Edge ['createOptin(OptinFacadeImpl)', 'Calls', 'create(OptinServiceImpl)'] skipped
# INFO: Edge ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] skipped
# INFO: Edge ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] skipped
# INFO: Edge ['displayListingPage(ListItemsController)', 'Calls', 'append(ListItemsController)'] skipped
# INFO: Edge ['getList(CurrencyFacadeImpl)', 'Calls', 'list(CurrencyServiceImpl)'] skipped
# INFO: Edge ['display(ContactController)', 'Calls', 'append(ContactController)'] skipped
# INFO: Edge ['display(ContactController)', 'Calls', 'append(ContactController)'] skipped
# INFO: Edge ['display(ContactController)', 'Calls', 'append(ContactController)'] skipped
# INFO: Edge ['sendEmail(ContactController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['createMerchantStore(StoreFacadeImpl)', 'Calls', 'create(MerchantStoreServiceImpl)'] skipped
# INFO: Edge ['updateMerchantStore(StoreFacadeImpl)', 'Calls', 'update(MerchantStoreServiceImpl)'] skipped
# INFO: Edge ['delete(StoreFacadeImpl)', 'Calls', 'delete(MerchantStoreServiceImpl)'] skipped
# INFO: Edge ['saveMerchantStore(StoreFacadeImpl)', 'Calls', 'save(MerchantStoreServiceImpl)'] skipped
# INFO: Edge ['saveShippingOrigin(ShippingFacadeImpl)', 'Calls', 'save(ShippingOriginServiceImpl)'] skipped
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'toString(ShoppingCategoryController)'] skipped
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped
# INFO: Edge ['displayCategory(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped
# INFO: Edge ['getManufacturers(ShoppingCategoryController)', 'Calls', 'populate(ShoppingCategoryController)'] skipped
# INFO: Edge ['getProducts(ShoppingCategoryController)', 'Calls', 'append(ShoppingCategoryController)'] skipped
# INFO: Edge ['getProducts(ShoppingCategoryController)', 'Calls', 'toString(ShoppingCategoryController)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['displayCheckout(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitPreAuthorizedOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['commitOrder(ShoppingOrderController)', 'Calls', 'append(ShoppingOrderController)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getSessionAttribute(ShoppingOrderController)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateShipping(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getSessionAttribute(ShoppingOrderController)'] skipped
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['calculateOrderTotal(ShoppingOrderController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'toString(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getById(OrderServiceImpl)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'toString(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['displayConfirmation(ShoppingOrderConfirmationController)', 'Calls', 'append(ShoppingOrderConfirmationController)'] skipped
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'getSessionAttribute(ShoppingOrderPaymentController)'] skipped
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped
# INFO: Edge ['paymentAction(ShoppingOrderPaymentController)', 'Calls', 'append(ShoppingOrderPaymentController)'] skipped
# INFO: Edge ['downloadFile(ShoppingOrderDownloadController)', 'Calls', 'getById(OrderServiceImpl)'] skipped
# INFO: Edge ['downloadFile(ShoppingOrderDownloadController)', 'Calls', 'getById(OrderProductDownloadServiceImpl)'] skipped
# INFO: Edge ['processOrder(OrderFacadeImpl)', 'Calls', 'equals(OrderFacadeImpl)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'equals(OrderFacadeImpl)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateOrder(OrderFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateOrderList(OrderFacadeImpl)', 'Calls', 'setLocale(ReadableOrderPopulator)'] skipped
# INFO: Edge ['getCapturableOrderList(OrderFacadeImpl)', 'Calls', 'setLocale(ReadableOrderPopulator)'] skipped
# INFO: Edge ['displaySearch(SearchController)', 'Calls', 'append(SearchController)'] skipped
# INFO: Edge ['displaySearch(SearchController)', 'Calls', 'append(SearchController)'] skipped
# INFO: Edge ['displaySearch(SearchController)', 'Calls', 'append(SearchController)'] skipped
# INFO: Edge ['displayProductReview(CustomerProductReviewController)', 'Calls', 'getSessionAttribute(CustomerProductReviewController)'] skipped
# INFO: Edge ['displayProductReview(CustomerProductReviewController)', 'Calls', 'append(CustomerProductReviewController)'] skipped
# INFO: Edge ['displayProductReview(CustomerProductReviewController)', 'Calls', 'append(CustomerProductReviewController)'] skipped
# INFO: Edge ['displayProductReview(CustomerProductReviewController)', 'Calls', 'append(CustomerProductReviewController)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'getSessionAttribute(CustomerProductReviewController)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'getLanguage(CustomerProductReviewController)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'append(CustomerProductReviewController)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'append(CustomerProductReviewController)'] skipped
# INFO: Edge ['submitProductReview(CustomerProductReviewController)', 'Calls', 'append(CustomerProductReviewController)'] skipped
# INFO: Edge ['displayLogon(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayLogon(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayLogon(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayLogon(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['customerInformation(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerAccount(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerAccount(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerAccount(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerAccount(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerChangePassword(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerChangePassword(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerChangePassword(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerChangePassword(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['changePassword(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['changePassword(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['changePassword(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['changePassword(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['changePassword(CustomerAccountController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveCustomerAttributes(CustomerAccountController)', 'Calls', 'getById(CustomerOptionServiceImpl)'] skipped
# INFO: Edge ['saveCustomerAttributes(CustomerAccountController)', 'Calls', 'getById(CustomerOptionValueServiceImpl)'] skipped
# INFO: Edge ['saveCustomerAttributes(CustomerAccountController)', 'Calls', 'getById(CustomerOptionServiceImpl)'] skipped
# INFO: Edge ['saveCustomerAttributes(CustomerAccountController)', 'Calls', 'getById(CustomerOptionValueServiceImpl)'] skipped
# INFO: Edge ['saveCustomerAttributes(CustomerAccountController)', 'Calls', 'update(CustomerAttributeServiceImpl)'] skipped
# INFO: Edge ['saveCustomerAttributes(CustomerAccountController)', 'Calls', 'save(CustomerAttributeServiceImpl)'] skipped
# INFO: Edge ['displayCustomerBillingAddress(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerBillingAddress(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerBillingAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerBillingAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['displayCustomerBillingAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['editAddress(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['editAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['editAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['editAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['updateCustomerAddress(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['updateCustomerAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['updateCustomerAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['updateCustomerAddress(CustomerAccountController)', 'Calls', 'append(CustomerAccountController)'] skipped
# INFO: Edge ['updateCustomerAddress(CustomerAccountController)', 'Calls', 'getSessionAttribute(CustomerAccountController)'] skipped
# INFO: Edge ['displayRegistration(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['displayRegistration(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['displayRegistration(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['registerCustomer(CustomerRegistrationController)', 'Calls', 'append(CustomerRegistrationController)'] skipped
# INFO: Edge ['getZones(CustomerRegistrationController)', 'Calls', 'list(ZoneServiceImpl)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'getSessionAttribute(CustomerOrdersController)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'getSessionAttribute(CustomerOrdersController)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'createPaginaionData(CustomerOrdersController)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'calculatePaginaionData(CustomerOrdersController)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'append(CustomerOrdersController)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'append(CustomerOrdersController)'] skipped
# INFO: Edge ['listOrders(CustomerOrdersController)', 'Calls', 'append(CustomerOrdersController)'] skipped
# INFO: Edge ['orderDetails(CustomerOrdersController)', 'Calls', 'getSessionAttribute(CustomerOrdersController)'] skipped
# INFO: Edge ['orderDetails(CustomerOrdersController)', 'Calls', 'append(CustomerOrdersController)'] skipped
# INFO: Edge ['orderDetails(CustomerOrdersController)', 'Calls', 'append(CustomerOrdersController)'] skipped
# INFO: Edge ['orderDetails(CustomerOrdersController)', 'Calls', 'append(CustomerOrdersController)'] skipped
# INFO: Edge ['displayCustomerDashboard(CustomerDashboardController)', 'Calls', 'getSessionAttribute(CustomerDashboardController)'] skipped
# INFO: Edge ['displayCustomerDashboard(CustomerDashboardController)', 'Calls', 'append(CustomerDashboardController)'] skipped
# INFO: Edge ['displayCustomerDashboard(CustomerDashboardController)', 'Calls', 'append(CustomerDashboardController)'] skipped
# INFO: Edge ['displayCustomerDashboard(CustomerDashboardController)', 'Calls', 'append(CustomerDashboardController)'] skipped
# INFO: Edge ['saveCustomer(CustomerFacadeImpl)', 'Calls', 'save(CustomerServiceImpl)'] skipped
# INFO: Edge ['deleteCustomerReview(CustomerFacadeImpl)', 'Calls', 'delete(CustomerReviewServiceImpl)'] skipped
# INFO: Edge ['getCustomerReviewById(CustomerFacadeImpl)', 'Calls', 'getById(CustomerReviewServiceImpl)'] skipped
# INFO: Edge ['saveCustomerOption(CustomerFacadeImpl)', 'Calls', 'save(CustomerOptinServiceImpl)'] skipped
# INFO: Edge ['resetPassword(CustomerFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(CustomerFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(CustomerFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(CustomerFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(CustomerFacadeImpl)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(CustomerFacadeImpl)', 'Calls', 'update(CustomerServiceImpl)'] skipped
# INFO: Edge ['delete(ProductTypeFacadeImpl)', 'Calls', 'delete(ProductTypeServiceImpl)'] skipped
# INFO: Edge ['delete(ProductInventoryFacadeImpl)', 'Calls', 'delete(ProductAvailabilityServiceImpl)'] skipped
# INFO: Edge ['create(ProductOptionSetFacadeImpl)', 'Calls', 'create(ProductOptionSetServiceImpl)'] skipped
# INFO: Edge ['update(ProductOptionSetFacadeImpl)', 'Calls', 'save(ProductOptionSetServiceImpl)'] skipped
# INFO: Edge ['delete(ProductOptionSetFacadeImpl)', 'Calls', 'delete(ProductOptionSetServiceImpl)'] skipped
# INFO: Edge ['getProductListsByCriterias(ProductFacadeImpl)', 'Calls', 'append(ProductFacadeImpl)'] skipped
# INFO: Edge ['getProductListsByCriterias(ProductFacadeImpl)', 'Calls', 'append(ProductFacadeImpl)'] skipped
# INFO: Edge ['getProductListsByCriterias(ProductFacadeImpl)', 'Calls', 'toString(ProductFacadeImpl)'] skipped
# INFO: Edge ['deleteReview(ProductFacadeImpl)', 'Calls', 'delete(ProductReviewServiceImpl)'] skipped
# INFO: Edge ['update(ProductFacadeImpl)', 'Calls', 'save(ProductServiceImpl)'] skipped
# INFO: Edge ['absolutePath(ContentFacadeImpl)', 'Calls', 'append(ContentFacadeImpl)'] skipped
# INFO: Edge ['absolutePath(ContentFacadeImpl)', 'Calls', 'append(ContentFacadeImpl)'] skipped
# INFO: Edge ['absolutePath(ContentFacadeImpl)', 'Calls', 'toString(ContentFacadeImpl)'] skipped
# INFO: Edge ['removeItemFromGroup(ProductItemsFacadeImpl)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped
# INFO: Edge ['listProductGroups(ProductItemsFacadeImpl)', 'Calls', 'equals(ProductItemsFacadeImpl)'] skipped
# INFO: Edge ['saveCategory(CategoryFacadeImpl)', 'Calls', 'append(CategoryFacadeImpl)'] skipped
# INFO: Edge ['saveCategory(CategoryFacadeImpl)', 'Calls', 'toString(CategoryFacadeImpl)'] skipped
# INFO: Edge ['getCatalogEntry(CatalogFacadeImpl)', 'Calls', 'getById(CatalogEntryServiceImpl)'] skipped
# INFO: Edge ['removeCatalogEntry(CatalogFacadeImpl)', 'Calls', 'getById(CatalogEntryServiceImpl)'] skipped
# INFO: Edge ['removeCatalogEntry(CatalogFacadeImpl)', 'Calls', 'delete(CatalogEntryServiceImpl)'] skipped
# INFO: Edge ['createManufacturer(ShopProductRESTController)', 'Calls', 'save(ManufacturerServiceImpl)'] skipped
# INFO: Edge ['createProductOptionValue(ShopProductRESTController)', 'Calls', 'save(ProductOptionValueServiceImpl)'] skipped
# INFO: Edge ['createProductOption(ShopProductRESTController)', 'Calls', 'save(ProductOptionServiceImpl)'] skipped
# INFO: Edge ['getProducts(ShopProductRESTController)', 'Calls', 'append(ShopProductRESTController)'] skipped
# INFO: Edge ['getProducts(ShopProductRESTController)', 'Calls', 'append(ShopProductRESTController)'] skipped
# INFO: Edge ['getProducts(ShopProductRESTController)', 'Calls', 'append(ShopProductRESTController)'] skipped
# INFO: Edge ['getProducts(ShopProductRESTController)', 'Calls', 'toString(ShopProductRESTController)'] skipped
# INFO: Edge ['createOrder(OrderRESTController)', 'Calls', 'save(CustomerServiceImpl)'] skipped
# INFO: Edge ['createOrder(OrderRESTController)', 'Calls', 'save(OrderServiceImpl)'] skipped
# INFO: Edge ['createCustomerOptionValue(CustomerRESTController)', 'Calls', 'save(CustomerOptionValueServiceImpl)'] skipped
# INFO: Edge ['createCustomerOption(CustomerRESTController)', 'Calls', 'save(CustomerOptionServiceImpl)'] skipped
# INFO: Edge ['createCustomer(CustomerRESTController)', 'Calls', 'save(CustomerServiceImpl)'] skipped
# INFO: Edge ['permissions(SecurityApi)', 'Calls', 'list(PermissionServiceImpl)'] skipped
# INFO: Edge ['groups(SecurityApi)', 'Calls', 'list(GroupServiceImpl)'] skipped
# INFO: Edge ['clearCache(CacheApi)', 'Calls', 'append(CacheApi)'] skipped
# INFO: Edge ['clearCache(CacheApi)', 'Calls', 'append(CacheApi)'] skipped
# INFO: Edge ['clearCache(CacheApi)', 'Calls', 'append(CacheApi)'] skipped
# INFO: Edge ['deleteImage(ProductImageApi)', 'Calls', 'delete(ProductImageServiceImpl)'] skipped
# INFO: Edge ['update(ProductReviewApi)', 'Calls', 'getById(ProductReviewServiceImpl)'] skipped
# INFO: Edge ['delete(ProductReviewApi)', 'Calls', 'getById(ProductReviewServiceImpl)'] skipped
# INFO: Edge ['refreshAndGetAuthenticationToken(AuthenticateUserApi)', 'Calls', 'length(AuthenticateUserApi)'] skipped
# INFO: Edge ['shipping(OrderShippingApi)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['shipping(OrderShippingApi)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['shipping(OrderShippingApi)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayDenied(LoginController)', 'Calls', 'logout(LoginController)'] skipped
# INFO: Edge ['delete(GroupsController)', 'Calls', 'getById(GroupServiceImpl)'] skipped
# INFO: Edge ['delete(GroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['delete(GroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['delete(GroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['delete(GroupsController)', 'Calls', 'delete(GroupServiceImpl)'] skipped
# INFO: Edge ['save(GroupsController)', 'Calls', 'getById(GroupServiceImpl)'] skipped
# INFO: Edge ['save(GroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['save(GroupsController)', 'Calls', 'save(GroupServiceImpl)'] skipped
# INFO: Edge ['pageGroups(GroupsController)', 'Calls', 'list(GroupServiceImpl)'] skipped
# INFO: Edge ['pageGroups(GroupsController)', 'Calls', 'append(GroupsController)'] skipped
# INFO: Edge ['pageGroups(GroupsController)', 'Calls', 'append(GroupsController)'] skipped
# INFO: Edge ['pageGroups(GroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'toString(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'toString(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'append(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'toString(UserController)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['changePassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'list(MerchantStoreServiceImpl)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['populateUserObjects(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getById(LanguageServiceImpl)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeUser(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPassword(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['resetPasswordSecurityQtn(UserController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['pageImages(ContentImageController)', 'Calls', 'append(ContentImageController)'] skipped
# INFO: Edge ['pageImages(ContentImageController)', 'Calls', 'append(ContentImageController)'] skipped
# INFO: Edge ['pageImages(ContentImageController)', 'Calls', 'toString(ContentImageController)'] skipped
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'save(ProductOptionValueServiceImpl)'] skipped
# INFO: Edge ['saveAttribute(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteProductPrice(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['checkAttributeType(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['checkAttributeType(ProductAttributeController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeItem(RelatedItemsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped
# INFO: Edge ['deleteProductReview(ProductReviewController)', 'Calls', 'getById(ProductReviewServiceImpl)'] skipped
# INFO: Edge ['deleteProductReview(ProductReviewController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteProductReview(ProductReviewController)', 'Calls', 'delete(ProductReviewServiceImpl)'] skipped
# INFO: Edge ['removeItem(FeaturedItemsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped
# INFO: Edge ['pageCustomGroups(CustomProductGroupsController)', 'Calls', 'equals(CustomProductGroupsController)'] skipped
# INFO: Edge ['saveCustomProductGroup(CustomProductGroupsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['activateProductGroup(CustomProductGroupsController)', 'Calls', 'equals(CustomProductGroupsController)'] skipped
# INFO: Edge ['removeItem(CustomProductGroupsController)', 'Calls', 'delete(ProductRelationshipServiceImpl)'] skipped
# INFO: Edge ['deleteProduct(ProductsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeFile(DigitalProductController)', 'Calls', 'getById(DigitalProductServiceImpl)'] skipped
# INFO: Edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteManufacturer(ManufacturerController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['displayProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProduct(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['duplicateProduct(ProductController)', 'Calls', 'list(ProductTypeServiceImpl)'] skipped
# INFO: Edge ['removeImage(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteProductFromCategory(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteProductFromCategory(ProductController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveOption(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteOptionValue(OptionsValueController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeImage(OptionsValueController)', 'Calls', 'update(ProductOptionValueServiceImpl)'] skipped
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteProductPrice(ProductPriceController)', 'Calls', 'getById(ProductPriceServiceImpl)'] skipped
# INFO: Edge ['deleteProductPrice(ProductPriceController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveOption(OptionsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteOption(OptionsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductImages(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductImages(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductImagesUrl(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveProductImagesUrl(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['setDefaultImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['setDefaultImage(ProductImagesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['addKeyword(ProductKeywordsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['deleteCategory(CategoryController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveTaxRate(TaxRatesController)', 'Calls', 'create(TaxRateServiceImpl)'] skipped
# INFO: Edge ['updateTaxRate(TaxRatesController)', 'Calls', 'update(TaxRateServiceImpl)'] skipped
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['validateTaxRate(TaxRatesController)', 'Calls', 'getById(ZoneServiceImpl)'] skipped
# INFO: Edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeTaxRate(TaxRatesController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['saveTaxClass(TaxClassController)', 'Calls', 'create(TaxClassServiceImpl)'] skipped
# INFO: Edge ['updateTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['updateTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['updateTaxClass(TaxClassController)', 'Calls', 'update(TaxClassServiceImpl)'] skipped
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['removeTaxClass(TaxClassController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['savePaymentMethod(PaymentsController)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['captureOrder(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] skipped
# INFO: Edge ['captureOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['captureOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] skipped
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['refundOrder(OrderActionsControler)', 'Calls', 'getMessage(LabelUtils)'] skipped
# INFO: Edge ['printInvoice(OrderActionsControler)', 'Calls', 'getById(OrderServiceImpl)'] skipped

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity MavenWrapperDownloader
# Removed Entity SchemaConstant
# Removed Entity CloneUtils
# Removed Entity Secrets
# Removed Entity User
# Removed Entity ShoppingCartItem
# Removed Entity Content
# Removed Entity ContentFile
# Removed Entity TaxRateDescription
# Removed Entity Address
# Removed Entity AuditListener
# Removed Entity ShippingConfiguration
# Removed Entity Package
# Removed Entity Order
# Removed Entity OrderTotal
# Removed Entity OrderProduct
# Removed Entity OrderAttribute
# Removed Entity OrderStatusHistory
# Removed Entity Optin
# Removed Entity CustomerOptin
# Removed Entity Customer
# Removed Entity CustomerAttribute
# Removed Entity CustomerOptionValue
# Removed Entity CustomerOptionValueDescription
# Removed Entity CustomerOptionDescription
# Removed Entity CustomerOption
# Removed Entity AbstractUserConnection
# Removed Entity Product
# Removed Entity ProductList
# Removed Entity ProductOption
# Removed Entity ProductAttribute
# Removed Entity ProductOptionDescription
# Removed Entity ProductOptionValue
# Removed Entity ProductOptionValueDescription
# Removed Entity Manufacturer
# Removed Entity ManufacturerDescription
# Removed Entity ProductPriceDescription
# Removed Entity ProductPrice
# Removed Entity ProductDescription
# Removed Entity Catalog
# Removed Entity Category
# Removed Entity CategoryDescription
# Removed Entity SalesManagerEntity
# Removed Entity MavenWrapperDownloader
# Removed Entity AdminFilter
# Removed Entity CorsFilter
# Removed Entity ShopServletContextListener
# Removed Entity ApplicationConstants
# Removed Entity Constants
# Removed Entity EmailConstants
# Removed Entity ReadableProductReviewPopulator
# Removed Entity LocaleUtils
# Removed Entity MerchantUtils
# Removed Entity PageBuilderUtils
# Removed Entity BeanUtils
# Removed Entity SessionUtil
# Removed Entity DateUtil
# Removed Entity AdminAccessDeniedHandler
# Removed Entity CategoryUtils
# Removed Entity ServiceRequestCriteriaBuilderUtils
# Removed Entity GeoLocationUtils
# Removed Entity TokenizeTool
# Removed Entity AbstractimageFilePath
# Removed Entity FieldMatchValidator
# Removed Entity UserUtils
# Removed Entity EnumValidator
# Removed Entity ShopProductImageUrlTag
# Removed Entity ShopProductRelationshipTag
# Removed Entity ActiveLinkTag
# Removed Entity ConfigurationTag
# Removed Entity PageContentTag
# Removed Entity StoreLogoUrlTag
# Removed Entity StoreBreadcrumbsTag
# Removed Entity StoreFooterlTag
# Removed Entity ServicesAuthenticationEntryPoint
# Removed Entity ServicesAuthenticationSuccessHandler
# Removed Entity AbstractCustomerServices
# Removed Entity ResetPasswordRequest
# Removed Entity JWTAdminAuthenticationProvider
# Removed Entity AdminAccessDeniedHandler
# Removed Entity JWTCustomerAuthenticationProvider
# Removed Entity AbstractController
# Removed Entity AbstractConfigurationFacadeImpl
# Removed Entity ErrorEntity
# Removed Entity Order
# Removed Entity CustomerOptionValue
# Removed Entity CustomerOption
# Removed Entity Manufacturer
# Removed Entity Category
# Removed Entity ProductPrice
# Removed Entity Product
# Removed Entity MavenWrapperDownloader
# Removed Entity BeanStreamPayment
# Removed Entity StripePayment
# Removed Entity BraintreePayment
# Removed Entity MoneyOrderPayment
# Removed Entity PayPalRestPayment
# Removed Entity UPSShippingQuote
# Removed Entity CustomWeightBasedShippingQuote
# Removed Entity StorePickupShippingQuote
# Removed Entity DecisionResponse
# Removed Entity ShippingDecisionPreProcessorImpl
# Removed Entity ShippingInputParameters
# Removed Entity DefaultPackagingImpl
# Removed Entity PackingBox
# Removed Entity PriceByDistanceShippingQuoteRules
# Removed Entity USPSShippingQuote
# Removed Entity CustomShippingQuoteRules
# Removed Entity EncryptionImpl
# Removed Entity GeoLocationImpl
# Removed Entity IndexEntityProcessor
# Removed Entity CmsImageFileManagerImpl
# Removed Entity S3CacheManagerImpl
# Removed Entity CmsStaticContentFileManagerImpl
# Removed Entity StaticContentData
# Removed Entity ODSInvoiceModule
# Removed Entity ShippingConstants
# Removed Entity SystemConstants
# Removed Entity UserRepositoryImpl
# Removed Entity PermissionRepositoryImpl
# Removed Entity ContentRepositoryImpl
# Removed Entity OrderRepositoryImpl
# Removed Entity MerchantRepositoryImpl
# Removed Entity CustomerRepositoryImpl
# Removed Entity ProductRepositoryImpl
# Removed Entity ProductRelationshipRepositoryImpl
# Removed Entity CategoryRepositoryImpl
# Removed Entity PageableCategoryRepositoryImpl
# Removed Entity ApplicationContextListenerUtils
# Removed Entity CatalogServiceHelper
# Removed Entity ProductUtils
# Removed Entity DataUtils
# Removed Entity ProductImageCropUtils
# Removed Entity CreditCardUtils
# Removed Entity ProductImageSizeUtils
# Removed Entity AbstractDataPopulator
# Removed Entity RepositoryHelper
# Removed Entity ProductQueryBuilder
# Removed Entity VaultConfiguration
# Removed Entity DbConfig
# Removed Entity ConfigurationModulesLoader
# Removed Entity ZoneTransient
# Removed Entity SalesManagerEntityServiceImpl
# Removed Entity MavenWrapperDownloader
# Removed Entity ReadableImage
# Removed Entity ContentSettings
# Removed Entity Address
# Removed Entity PersistableMerchantStore
# Removed Entity ServiceEntity
# Removed Entity Order
# Removed Entity ReadableOrderList
# Removed Entity PersistableOrder
# Removed Entity ReadableOrder
# Removed Entity EnumValidator
# Removed supportsParameter (LanguageArgumentResolver)
# Removed supportsParameter (MerchantStoreArgumentResolver)
# Removed getShoppingCartService (ShoppingCartModelPopulator)
# Removed setShoppingCartService (ShoppingCartModelPopulator)
# Removed getProductService (ShoppingCartModelPopulator)
# Removed setProductService (ShoppingCartModelPopulator)
# Removed getProductAttributeService (ShoppingCartModelPopulator)
# Removed setProductAttributeService (ShoppingCartModelPopulator)
# Removed getZoneService (PersistableMerchantStorePopulator)
# Removed setZoneService (PersistableMerchantStorePopulator)
# Removed getCountryService (PersistableMerchantStorePopulator)
# Removed setCountryService (PersistableMerchantStorePopulator)
# Removed getLanguageService (PersistableMerchantStorePopulator)
# Removed setLanguageService (PersistableMerchantStorePopulator)
# Removed getCurrencyService (PersistableMerchantStorePopulator)
# Removed setCurrencyService (PersistableMerchantStorePopulator)
# Removed setCategoryService (PersistableProductPopulator)
# Removed getCategoryService (PersistableProductPopulator)
# Removed setManufacturerService (PersistableProductPopulator)
# Removed getManufacturerService (PersistableProductPopulator)
# Removed setTaxClassService (PersistableProductPopulator)
# Removed getTaxClassService (PersistableProductPopulator)
# Removed getLanguageService (PersistableProductPopulator)
# Removed setLanguageService (PersistableProductPopulator)
# Removed getProductOptionService (PersistableProductPopulator)
# Removed setProductOptionService (PersistableProductPopulator)
# Removed getProductOptionValueService (PersistableProductPopulator)
# Removed setProductOptionValueService (PersistableProductPopulator)
# Removed getCustomerService (PersistableProductPopulator)
# Removed setCustomerService (PersistableProductPopulator)
# Removed setCategoryService (PersistableCategoryPopulator)
# Removed getCategoryService (PersistableCategoryPopulator)
# Removed setLanguageService (PersistableCategoryPopulator)
# Removed getLanguageService (PersistableCategoryPopulator)
# Removed init (ImagesController)
# Removed getProperties (AppConfiguration)
# Removed setProperties (AppConfiguration)
# Removed getProperty (AppConfiguration)
# Removed getBasePath (ImageFilePathUtils)
# Removed setBasePath (ImageFilePathUtils)
# Removed getContextPath (ImageFilePathUtils)
# Removed setBasePath (LocalImageFilePathUtils)
# Removed getContextPath (LocalImageFilePathUtils)
# Removed setBasePath (CloudFilePathUtils)
# Removed getContextPath (CloudFilePathUtils)
# Removed getContextPath (FilePathUtils)
# Removed commence (RestAuthenticationEntryPoint)
# Removed getOrder (RestAuthenticationEntryPoint)
# Removed afterPropertiesSet (RestAuthenticationEntryPoint)
# Removed loadUserByUsername (SocialCustomerServicesImpl)
# Removed successfullAuthentication (JWTAdminAuthenticationManager)
# Removed unSuccessfullAuthentication (JWTAdminAuthenticationManager)
# Removed successfullAuthentication (JWTCustomerAuthenticationManager)
# Removed unSuccessfullAuthentication (JWTCustomerAuthenticationManager)
# Removed displayHomeStub (LandingController)
# Removed getKeyValue (ShoppingCartFacadeImpl)
# Removed displayCategoryWithReference (ShoppingCategoryController)
# Removed displayCategoryNoReference (ShoppingCategoryController)
# Removed returnPayPalPayment (ShoppingOrderPaymentController)
# Removed validatePostalCode (OrderFacadeImpl)
# Removed convertToFolder (ContentAdministrationApi)
# Removed delete (CustomerNewsletterApi)
# Removed displayStoreLanding (AdminController)
# Removed displayLogin (LoginController)
# Removed displayDenied (LoginController)
# Removed unauthorized (LoginController)
# Removed displayPermissions (PermissionController)
# Removed boxPositions (ContentBoxesController)
# Removed displayFileBrowser (ContentImageController)
# Removed getContentImages (ContentImageController)
# Removed displayContentImagesCreate (ContentImageController)
# Removed getContentImages (StaticContentController)
# Removed getManufacturers (ManufacturerController)
# Removed saveCustomWeightBasedShippingMethod (ShippingMethodsController)
# Removed displayCustomers (CustomerController)
# Removed getAllowedZonesCodes (ShippingDistancePreProcessorImpl)
# Removed setAllowedZonesCodes (ShippingDistancePreProcessorImpl)
# Removed getModuleCode (ShippingDistancePreProcessorImpl)
# Removed getFreemarkerMailConfiguration (DefaultEmailSenderImpl)
# Removed setFreemarkerMailConfiguration (DefaultEmailSenderImpl)
# Removed getMailSender (DefaultEmailSenderImpl)
# Removed setMailSender (DefaultEmailSenderImpl)
# Removed bucketExists (GCPProductContentFileManager)
# Removed getBucketName (GCPCacheManagerImpl)
# Removed getLocation (GCPCacheManagerImpl)
# Removed setBucketName (GCPCacheManagerImpl)
# Removed getCmsManager (GCPStaticContentAssetsManagerImpl)
# Removed setCmsManager (GCPStaticContentAssetsManagerImpl)
# Removed addFolder (GCPStaticContentAssetsManagerImpl)
# Removed removeFolder (GCPStaticContentAssetsManagerImpl)
# Removed listFolders (GCPStaticContentAssetsManagerImpl)
# Removed getName (PromoCodeCalculatorModule)
# Removed setName (PromoCodeCalculatorModule)
# Removed getCode (PromoCodeCalculatorModule)
# Removed setCode (PromoCodeCalculatorModule)
# Removed getPricingService (ManufacturerShippingCodeOrderTotalModuleImpl)
# Removed setPricingService (ManufacturerShippingCodeOrderTotalModuleImpl)
# Removed getName (ManufacturerShippingCodeOrderTotalModuleImpl)
# Removed setName (ManufacturerShippingCodeOrderTotalModuleImpl)
# Removed getCode (ManufacturerShippingCodeOrderTotalModuleImpl)
# Removed setCode (ManufacturerShippingCodeOrderTotalModuleImpl)
# Removed shutDownCache (CacheUtils)
# Removed getProperties (CoreConfiguration)
# Removed setProperties (CoreConfiguration)
# Removed getDrlFromExcel (DroolsBeanFactory)
# Removed loadFileContent (ZonesLoader)
# Removed getShoppingCartService (ShoppingCartCalculationServiceImpl)
# Removed removeFiles (ContentServiceImpl)
# Removed isValidLinuxDirectory (ContentServiceImpl)
# Removed existByCode (MerchantStoreServiceImpl)
# Removed initService (SearchServiceImpl)
# Removed calculatePriceQuantity (PricingServiceImpl)
# Removed getMessage (ShoppingCartData)
# Removed setMessage (ShoppingCartData)
# Removed getCode (ShoppingCartData)
# Removed setCode (ShoppingCartData)
# Removed getQuantity (ShoppingCartData)
# Removed setQuantity (ShoppingCartData)
# Removed getTotal (ShoppingCartData)
# Removed setTotal (ShoppingCartData)
# Removed getSubTotal (ShoppingCartData)
# Removed setSubTotal (ShoppingCartData)
# Removed getOrderId (ShoppingCartData)
# Removed setOrderId (ShoppingCartData)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
