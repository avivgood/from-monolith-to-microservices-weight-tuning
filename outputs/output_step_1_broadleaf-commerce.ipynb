# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'shopizer-2x' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "broadleaf-commerce"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# Logic		PostUpdateCustomerExtensionManager		org.broadleafcommerce.profile.core.extension
# Entity		AbstractPostUpdateCustomerExtensionHandler		org.broadleafcommerce.profile.core.extension
# Interface	PostUpdateCustomerExtensionHandler		org.broadleafcommerce.profile.core.extension
# Logic		CountryServiceImpl		org.broadleafcommerce.profile.core.service
# Interface	AddressService		org.broadleafcommerce.profile.core.service
# Logic		AddressServiceImpl		org.broadleafcommerce.profile.core.service
# Logic		PhoneServiceImpl		org.broadleafcommerce.profile.core.service
# Logic		CustomerPaymentServiceImpl		org.broadleafcommerce.profile.core.service
# Logic		ChallengeQuestionServiceImpl		org.broadleafcommerce.profile.core.service
# Logic		UserDetailsServiceImpl		org.broadleafcommerce.profile.core.service
# Logic		CustomerAddressServiceImpl		org.broadleafcommerce.profile.core.service
# Interface	AddressVerificationProvider		org.broadleafcommerce.profile.core.service
# Logic		CustomerPhoneServiceImpl		org.broadleafcommerce.profile.core.service
# Entity		CustomerUserDetails		org.broadleafcommerce.profile.core.service
# Interface	CustomerService		org.broadleafcommerce.profile.core.service
# Interface	RoleService		org.broadleafcommerce.profile.core.service
# Interface	StateService		org.broadleafcommerce.profile.core.service
# Interface	PhoneService		org.broadleafcommerce.profile.core.service
# Logic		RoleServiceImpl		org.broadleafcommerce.profile.core.service
# Interface	CountrySubdivisionService		org.broadleafcommerce.profile.core.service
# Interface	CustomerPaymentService		org.broadleafcommerce.profile.core.service
# Interface	CountryService		org.broadleafcommerce.profile.core.service
# Interface	CustomerAddressService		org.broadleafcommerce.profile.core.service
# Logic		StateServiceImpl		org.broadleafcommerce.profile.core.service
# Logic		CountrySubdivisionServiceImpl		org.broadleafcommerce.profile.core.service
# Interface	CustomerPhoneService		org.broadleafcommerce.profile.core.service
# Logic		CustomerServiceImpl		org.broadleafcommerce.profile.core.service
# Interface	ChallengeQuestionService		org.broadleafcommerce.profile.core.service
# Interface	PostRegistrationObserver		org.broadleafcommerce.profile.core.service.listener
# Entity		LocaleType		org.broadleafcommerce.profile.core.service.type
# Entity		CustomerAddressType		org.broadleafcommerce.profile.core.service.type
# Entity		BaseResponse		org.broadleafcommerce.profile.core.service.validator
# Logic		RegistrationValidator		org.broadleafcommerce.profile.core.service.validator
# Logic		ResetPasswordValidator		org.broadleafcommerce.profile.core.service.validator
# Interface	PasswordUpdatedHandler		org.broadleafcommerce.profile.core.service.handler
# Entity		EmailNotificationPasswordUpdatedHandler		org.broadleafcommerce.profile.core.service.handler
# Entity		AddressVerificationException		org.broadleafcommerce.profile.core.service.exception
# Entity		CustomerPhoneImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerAddressPersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Interface	CountrySubdivision		org.broadleafcommerce.profile.core.domain
# Interface	Country		org.broadleafcommerce.profile.core.domain
# Interface	CustomerPaymentAdminPresentation		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPaymentImpl		org.broadleafcommerce.profile.core.domain
# Interface	CustomerAttribute		org.broadleafcommerce.profile.core.domain
# Interface	CountrySubdivisionCategory		org.broadleafcommerce.profile.core.domain
# Interface	CustomerForgotPasswordSecurityToken		org.broadleafcommerce.profile.core.domain
# Interface	CustomerPayment		org.broadleafcommerce.profile.core.domain
# Interface	Role		org.broadleafcommerce.profile.core.domain
# Entity		CustomerForgotPasswordSecurityTokenImpl		org.broadleafcommerce.profile.core.domain
# Interface	ChallengeQuestion		org.broadleafcommerce.profile.core.domain
# Entity		CustomerRoleImpl		org.broadleafcommerce.profile.core.domain
# Entity		PhoneImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPaymentPersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Entity		CustomerAttributeImpl		org.broadleafcommerce.profile.core.domain
# Interface	CustomerRole		org.broadleafcommerce.profile.core.domain
# Entity		StateImpl		org.broadleafcommerce.profile.core.domain
# Interface	CustomerAddress		org.broadleafcommerce.profile.core.domain
# Entity		CountrySubdivisionImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPhonePersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Interface	CustomerPhoneAdminPresentation		org.broadleafcommerce.profile.core.domain
# Entity		RoleImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPersistedEvent		org.broadleafcommerce.profile.core.domain
# Entity		ChallengeQuestionImpl		org.broadleafcommerce.profile.core.domain
# Interface	Phone		org.broadleafcommerce.profile.core.domain
# Interface	State		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Entity		LastPaymentStatus		org.broadleafcommerce.profile.core.domain
# Entity		CustomerImpl		org.broadleafcommerce.profile.core.domain
# Interface	Address		org.broadleafcommerce.profile.core.domain
# Entity		CountryImpl		org.broadleafcommerce.profile.core.domain
# Interface	CustomerAdminPresentation		org.broadleafcommerce.profile.core.domain
# Interface	CustomerPhone		org.broadleafcommerce.profile.core.domain
# Interface	Customer		org.broadleafcommerce.profile.core.domain
# Entity		CustomerAddressImpl		org.broadleafcommerce.profile.core.domain
# Entity		CountrySubdivisionCategoryImpl		org.broadleafcommerce.profile.core.domain
# Entity		AddressImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerRuleHolder		org.broadleafcommerce.profile.core.dto
# Excluded	ImportSQLConfig		org.broadleafcommerce.profile.core.demo
# Excluded	ProfileConfig		org.broadleafcommerce.profile.core.config
# Logic		NotificationRegisterCustomerEventListener		org.broadleafcommerce.profile.core.event
# Logic		NotificationForgotPasswordEventListener		org.broadleafcommerce.profile.core.event
# Entity		RegisterCustomerEvent		org.broadleafcommerce.profile.core.event
# Logic		NotificationForgotUsernameEventListener		org.broadleafcommerce.profile.core.event
# Entity		ForgotUsernameEvent		org.broadleafcommerce.profile.core.event
# Entity		ForgotPasswordEvent		org.broadleafcommerce.profile.core.event
# Interface	CustomerDao		org.broadleafcommerce.profile.core.dao
# Interface	PhoneDao		org.broadleafcommerce.profile.core.dao
# Interface	CustomerPaymentDao		org.broadleafcommerce.profile.core.dao
# Repository		CountryDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		CustomerPaymentDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		CustomerPhoneDaoImpl		org.broadleafcommerce.profile.core.dao
# Interface	CustomerForgotPasswordSecurityTokenDao		org.broadleafcommerce.profile.core.dao
# Repository		CustomerDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		ChallengeQuestionDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		CustomerForgotPasswordSecurityTokenDaoImpl		org.broadleafcommerce.profile.core.dao
# Interface	CustomerAddressDao		org.broadleafcommerce.profile.core.dao
# Repository		AddressDaoImpl		org.broadleafcommerce.profile.core.dao
# Interface	ChallengeQuestionDao		org.broadleafcommerce.profile.core.dao
# Interface	CountrySubdivisionDao		org.broadleafcommerce.profile.core.dao
# Interface	CountryDao		org.broadleafcommerce.profile.core.dao
# Repository		StateDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		CountrySubdivisionDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		PhoneDaoImpl		org.broadleafcommerce.profile.core.dao
# Interface	StateDao		org.broadleafcommerce.profile.core.dao
# Interface	AddressDao		org.broadleafcommerce.profile.core.dao
# Repository		RoleDaoImpl		org.broadleafcommerce.profile.core.dao
# Repository		CustomerAddressDaoImpl		org.broadleafcommerce.profile.core.dao
# Interface	RoleDao		org.broadleafcommerce.profile.core.dao
# Interface	CustomerPhoneDao		org.broadleafcommerce.profile.core.dao
# Entity		CategoryMediaMap		org.broadleafcommerce.core.media.domain
# Logic		ShippingRateServiceImpl		org.broadleafcommerce.core.pricing.service
# Logic		PricingServiceImpl		org.broadleafcommerce.core.pricing.service
# Interface	ShippingRateService		org.broadleafcommerce.core.pricing.service
# Interface	FulfillmentPricingService		org.broadleafcommerce.core.pricing.service
# Logic		FulfillmentPricingServiceImpl		org.broadleafcommerce.core.pricing.service
# Logic		TaxServiceImpl		org.broadleafcommerce.core.pricing.service
# Interface	ShippingService		org.broadleafcommerce.core.pricing.service
# Entity		ShippingServiceImpl		org.broadleafcommerce.core.pricing.service
# Interface	TaxService		org.broadleafcommerce.core.pricing.service
# Interface	PricingService		org.broadleafcommerce.core.pricing.service
# Entity		SimpleFulfillmentLocationResolver		org.broadleafcommerce.core.pricing.service.fulfillment
# Interface	FulfillmentLocationResolver		org.broadleafcommerce.core.pricing.service.fulfillment
# Entity		FixedPriceFulfillmentPricingProvider		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Entity		FulfillmentEstimationResponse		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Entity		BandedFulfillmentPricingProvider		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Interface	FulfillmentPricingProvider		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Interface	TaxProvider		org.broadleafcommerce.core.pricing.service.tax.provider
# Entity		SimpleTaxProvider		org.broadleafcommerce.core.pricing.service.tax.provider
# Entity		BandedShippingModule		org.broadleafcommerce.core.pricing.service.module
# Interface	ShippingModule		org.broadleafcommerce.core.pricing.service.module
# Interface	TaxModule		org.broadleafcommerce.core.pricing.service.module
# Entity		PricingException		org.broadleafcommerce.core.pricing.service.exception
# Entity		TaxException		org.broadleafcommerce.core.pricing.service.exception
# Logic		TaxActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		AutoBundleActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		OfferActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		TotalActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		FulfillmentItemPricingActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		FulfillmentGroupMerchandiseTotalActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		ShippingActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		CompositeActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		PricingProcessContextFactory		org.broadleafcommerce.core.pricing.service.workflow
# Logic		ShippingOfferActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		CountTotalOffersActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		ConsolidateFulfillmentFeesActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		AdjustOrderPaymentsActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		FulfillmentGroupPricingActivity		org.broadleafcommerce.core.pricing.service.workflow
# Logic		DetermineOfferChangeActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		ShippingServiceType		org.broadleafcommerce.core.pricing.service.workflow.type
# Interface	ShippingRate		org.broadleafcommerce.core.pricing.domain
# Entity		ShippingRateImpl		org.broadleafcommerce.core.pricing.domain
# Repository		ShippingRateDaoImpl		org.broadleafcommerce.core.pricing.dao
# Interface	ShippingRateDao		org.broadleafcommerce.core.pricing.dao
# Logic		GeolocationServiceImpl		org.broadleafcommerce.core.geolocation
# Interface	GeolocationAPI		org.broadleafcommerce.core.geolocation
# Entity		GeolocationDTO		org.broadleafcommerce.core.geolocation
# Interface	GeolocationService		org.broadleafcommerce.core.geolocation
# Entity		EntityIdentifierUtil		org.broadleafcommerce.core.util
# Entity		ThirdPartyInteractionLatencySimulationActivity		org.broadleafcommerce.core.util
# Entity		ZookeeperUtil		org.broadleafcommerce.core.util
# Interface	DeleteStatementGenerator		org.broadleafcommerce.core.util.service
# Logic		CodeTypeServiceImpl		org.broadleafcommerce.core.util.service
# Logic		ResourcePurgeExtensionManager		org.broadleafcommerce.core.util.service
# Logic		ResourcePurgeServiceImpl		org.broadleafcommerce.core.util.service
# Interface	SiteMapExtensionHandler		org.broadleafcommerce.core.util.service
# Entity		BroadleafSitemapUtils		org.broadleafcommerce.core.util.service
# Interface	ResourcePurgeExtensionHandler		org.broadleafcommerce.core.util.service
# Logic		DeleteStatementGeneratorImpl		org.broadleafcommerce.core.util.service
# Logic		SiteMapExtensionManager		org.broadleafcommerce.core.util.service
# Entity		AbstractResourcePurgeExtensionHandler		org.broadleafcommerce.core.util.service
# Interface	CodeTypeService		org.broadleafcommerce.core.util.service
# Entity		AbstractSiteMapExtensionHandler		org.broadleafcommerce.core.util.service
# Interface	ResourcePurgeService		org.broadleafcommerce.core.util.service
# Interface	CodeType		org.broadleafcommerce.core.util.domain
# Entity		CodeTypeImpl		org.broadleafcommerce.core.util.domain
# Interface	DistributedLock		org.broadleafcommerce.core.util.lock
# Entity		ReentrantDistributedZookeeperLock		org.broadleafcommerce.core.util.lock
# Entity		ZookeeperDistributedQueue		org.broadleafcommerce.core.util.queue
# Interface	DistributedBlockingQueue		org.broadleafcommerce.core.util.queue
# Repository		CodeTypeDaoImpl		org.broadleafcommerce.core.util.dao
# Interface	ResourcePurgeDao		org.broadleafcommerce.core.util.dao
# Interface	CodeTypeDao		org.broadleafcommerce.core.util.dao
# Repository		ResourcePurgeDaoImpl		org.broadleafcommerce.core.util.dao
# Interface	OfferAuditService		org.broadleafcommerce.core.offer.service
# Logic		OfferServiceUtilitiesImpl		org.broadleafcommerce.core.offer.service
# Entity		AbstractOfferValueModifierExtensionHandler		org.broadleafcommerce.core.offer.service
# Interface	OfferService		org.broadleafcommerce.core.offer.service
# Logic		ShippingOfferServiceImpl		org.broadleafcommerce.core.offer.service
# Logic		OfferServiceImpl		org.broadleafcommerce.core.offer.service
# Logic		OfferAuditServiceImpl		org.broadleafcommerce.core.offer.service
# Interface	OfferValueModifierExtensionHandler		org.broadleafcommerce.core.offer.service
# Interface	OfferServiceExtensionHandler		org.broadleafcommerce.core.offer.service
# Logic		OfferDuplicateModifier		org.broadleafcommerce.core.offer.service
# Interface	ShippingOfferService		org.broadleafcommerce.core.offer.service
# Logic		OfferValueModifierExtensionManager		org.broadleafcommerce.core.offer.service
# Entity		AbstractOfferServiceExtensionHandler		org.broadleafcommerce.core.offer.service
# Entity		OfferContext		org.broadleafcommerce.core.offer.service
# Interface	OfferServiceUtilities		org.broadleafcommerce.core.offer.service
# Logic		OfferServiceExtensionManager		org.broadleafcommerce.core.offer.service
# Entity		ItemOfferQtyOneComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotionDiscount		org.broadleafcommerce.core.offer.service.discount
# Entity		FulfillmentGroupOfferPotential		org.broadleafcommerce.core.offer.service.discount
# Entity		ItemOfferWeightedPercentComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotionQualifierWrapper		org.broadleafcommerce.core.offer.service.discount
# Entity		CandidatePromotionItems		org.broadleafcommerce.core.offer.service.discount
# Entity		OrderItemPriceComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotionQualifier		org.broadleafcommerce.core.offer.service.discount
# Entity		ItemOfferComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		OrderOfferComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotableOrderItemPriceDetailWrapper		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableOrderItem		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableCandidateItemOffer		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableOrderAdjustment		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableCandidateOrderOfferImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotionRounding		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	OfferHolder		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderItemPriceDetailImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableCandidateFulfillmentGroupOfferImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableFulfillmentGroup		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableItemFactory		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableOrder		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableOrderItemPriceDetail		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableOrderItemPriceDetailAdjustment		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableFulfillmentGroupAdjustmentImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderAdjustmentImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableCandidateOrderOffer		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableFulfillmentGroupAdjustment		org.broadleafcommerce.core.offer.service.discount.domain
# Logic		PromotableItemFactoryImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableCandidateItemOfferImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableOfferUtility		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		AbstractPromotionRounding		org.broadleafcommerce.core.offer.service.discount.domain
# Logic		PromotableOfferUtilityImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderItemPriceDetailAdjustmentImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableFulfillmentGroupImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Interface	PromotableCandidateFulfillmentGroupOffer		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderItemImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		OfferAdjustmentType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferTimeZoneType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferType		org.broadleafcommerce.core.offer.service.type
# Entity		StackabilityType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferItemRestrictionRuleType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferRuleType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferProrationType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferPriceDataIdentifierType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferDiscountType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferOptionalDirectCopyTransformTypes		org.broadleafcommerce.core.offer.service.type
# Entity		CustomerMaxUsesStrategyType		org.broadleafcommerce.core.offer.service.type
# Logic		FulfillmentGroupOfferProcessorImpl		org.broadleafcommerce.core.offer.service.processor
# Interface	ItemOfferProcessor		org.broadleafcommerce.core.offer.service.processor
# Logic		ItemOfferProcessorImpl		org.broadleafcommerce.core.offer.service.processor
# Logic		OfferTimeZoneProcessorImpl		org.broadleafcommerce.core.offer.service.processor
# Interface	ItemOfferMarkTargets		org.broadleafcommerce.core.offer.service.processor
# Interface	OrderOfferProcessor		org.broadleafcommerce.core.offer.service.processor
# Interface	OfferTimeZoneProcessor		org.broadleafcommerce.core.offer.service.processor
# Interface	FulfillmentGroupOfferProcessor		org.broadleafcommerce.core.offer.service.processor
# Interface	BaseProcessor		org.broadleafcommerce.core.offer.service.processor
# Entity		AbstractBaseProcessor		org.broadleafcommerce.core.offer.service.processor
# Logic		OrderOfferProcessorImpl		org.broadleafcommerce.core.offer.service.processor
# Entity		OfferMaxUseExceededException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferExpiredException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferAlreadyAddedException		org.broadleafcommerce.core.offer.service.exception
# Logic		VerifyCustomerMaxOfferUsesActivity		org.broadleafcommerce.core.offer.service.workflow
# Logic		RecordOfferUsageActivity		org.broadleafcommerce.core.offer.service.workflow
# Logic		RecordOfferUsageRollbackHandler		org.broadleafcommerce.core.offer.service.workflow
# Interface	OrderAdjustment		org.broadleafcommerce.core.offer.domain
# Interface	OfferPriceData		org.broadleafcommerce.core.offer.domain
# Interface	AdvancedOfferPromotionMessageXref		org.broadleafcommerce.core.offer.domain
# Entity		OfferRuleImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferCodeImpl		org.broadleafcommerce.core.offer.domain
# Interface	Adjustment		org.broadleafcommerce.core.offer.domain
# Entity		LegacyOfferUsesImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferTargetCriteriaXrefImpl		org.broadleafcommerce.core.offer.domain
# Interface	OfferAdminPresentation		org.broadleafcommerce.core.offer.domain
# Interface	OfferItemCriteria		org.broadleafcommerce.core.offer.domain
# Interface	OfferInfo		org.broadleafcommerce.core.offer.domain
# Entity		OfferItemCriteriaImpl		org.broadleafcommerce.core.offer.domain
# Entity		ProratedOrderItemAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Interface	OfferRule		org.broadleafcommerce.core.offer.domain
# Interface	OrderItemPriceDetailAdjustment		org.broadleafcommerce.core.offer.domain
# Interface	OfferCode		org.broadleafcommerce.core.offer.domain
# Entity		OfferPriceDataImpl		org.broadleafcommerce.core.offer.domain
# Interface	CandidateFulfillmentGroupOffer		org.broadleafcommerce.core.offer.domain
# Interface	OfferTargetCriteriaXref		org.broadleafcommerce.core.offer.domain
# Entity		FulfillmentGroupAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		CustomerOfferImpl		org.broadleafcommerce.core.offer.domain
# Interface	MinimumTargetsRequired		org.broadleafcommerce.core.offer.domain
# Entity		OrderItemAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Interface	AdvancedOffer		org.broadleafcommerce.core.offer.domain
# Interface	CustomerOffer		org.broadleafcommerce.core.offer.domain
# Entity		OfferOfferRuleXrefImpl		org.broadleafcommerce.core.offer.domain
# Interface	Offer		org.broadleafcommerce.core.offer.domain
# Interface	CandidateOrderOffer		org.broadleafcommerce.core.offer.domain
# Entity		OfferImpl		org.broadleafcommerce.core.offer.domain
# Interface	OfferAudit		org.broadleafcommerce.core.offer.domain
# Entity		OfferQualifyingCriteriaXrefImpl		org.broadleafcommerce.core.offer.domain
# Entity		CandidateItemOfferImpl		org.broadleafcommerce.core.offer.domain
# Entity		CandidateOrderOfferImpl		org.broadleafcommerce.core.offer.domain
# Interface	ProratedOrderItemAdjustment		org.broadleafcommerce.core.offer.domain
# Entity		OfferAuditImpl		org.broadleafcommerce.core.offer.domain
# Interface	OfferOfferRuleXref		org.broadleafcommerce.core.offer.domain
# Entity		OfferInfoImpl		org.broadleafcommerce.core.offer.domain
# Interface	OrderItemAdjustment		org.broadleafcommerce.core.offer.domain
# Interface	FulfillmentGroupAdjustment		org.broadleafcommerce.core.offer.domain
# Entity		CandidateFulfillmentGroupOfferImpl		org.broadleafcommerce.core.offer.domain
# Interface	CandidateItemOffer		org.broadleafcommerce.core.offer.domain
# Interface	OfferQualifyingCriteriaXref		org.broadleafcommerce.core.offer.domain
# Interface	OfferTier		org.broadleafcommerce.core.offer.domain
# Entity		OrderItemPriceDetailAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		OrderAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Interface	CandidateOffer		org.broadleafcommerce.core.offer.domain
# Interface	LegacyOfferUses		org.broadleafcommerce.core.offer.weave
# Entity		WeaveLegacyOfferUses		org.broadleafcommerce.core.offer.weave
# Interface	OfferAuditDao		org.broadleafcommerce.core.offer.dao
# Repository		OfferCodeDaoImpl		org.broadleafcommerce.core.offer.dao
# Entity		DefaultOfferCodeDaoExtensionHandler		org.broadleafcommerce.core.offer.dao
# Interface	OfferCodeDao		org.broadleafcommerce.core.offer.dao
# Repository		OfferAuditDaoImpl		org.broadleafcommerce.core.offer.dao
# Repository		OfferDaoImpl		org.broadleafcommerce.core.offer.dao
# Repository		CustomerOfferDaoImpl		org.broadleafcommerce.core.offer.dao
# Interface	CustomerOfferDao		org.broadleafcommerce.core.offer.dao
# Interface	OfferDao		org.broadleafcommerce.core.offer.dao
# Interface	OfferCodeDaoExtensionHandler		org.broadleafcommerce.core.offer.dao
# Logic		OfferCodeDaoExtensionManager		org.broadleafcommerce.core.offer.dao
# Interface	PromotionMessageGenerator		org.broadleafcommerce.core.promotionMessage.service
# Entity		BLCPromotionMessageUtils		org.broadleafcommerce.core.promotionMessage.util
# Entity		PromotionMessageImpl		org.broadleafcommerce.core.promotionMessage.domain
# Interface	PromotionMessage		org.broadleafcommerce.core.promotionMessage.domain
# Interface	PromotionMessageAdminPresentation		org.broadleafcommerce.core.promotionMessage.domain
# Entity		PromotionMessageType		org.broadleafcommerce.core.promotionMessage.domain.type
# Entity		PromotionMessagePlacementType		org.broadleafcommerce.core.promotionMessage.domain.type
# Entity		PromotionMessageDTO		org.broadleafcommerce.core.promotionMessage.dto
# Interface	PromotionMessageDTOService		org.broadleafcommerce.core.promotionMessage.dto.service
# Logic		PromotionMessageDTOServiceImpl		org.broadleafcommerce.core.promotionMessage.dto.service
# Logic		OrderToPaymentRequestDTOServiceImpl		org.broadleafcommerce.core.payment.service
# Interface	SecureOrderPaymentService		org.broadleafcommerce.core.payment.service
# Logic		SecureOrderPaymentServiceImpl		org.broadleafcommerce.core.payment.service
# Interface	OrderPaymentService		org.broadleafcommerce.core.payment.service
# Interface	OrderPaymentStatusService		org.broadleafcommerce.core.payment.service
# Logic		PaymentResponseDTOToEntityServiceImpl		org.broadleafcommerce.core.payment.service
# Interface	PaymentResponseDTOToEntityService		org.broadleafcommerce.core.payment.service
# Logic		DefaultCustomerPaymentGatewayService		org.broadleafcommerce.core.payment.service
# Interface	OrderToPaymentRequestDTOService		org.broadleafcommerce.core.payment.service
# Logic		PaymentRequestDTOServiceImpl		org.broadleafcommerce.core.payment.service
# Logic		OrderPaymentServiceImpl		org.broadleafcommerce.core.payment.service
# Logic		OrderPaymentStatusServiceImpl		org.broadleafcommerce.core.payment.service
# Logic		DefaultPaymentGatewayCheckoutService		org.broadleafcommerce.core.payment.service
# Interface	PaymentRequestDTOService		org.broadleafcommerce.core.payment.service
# Entity		OrderPaymentStatus		org.broadleafcommerce.core.payment.service.type
# Entity		PaymentProcessorException		org.broadleafcommerce.core.payment.service.exception
# Entity		InsufficientFundsException		org.broadleafcommerce.core.payment.service.exception
# Entity		PaymentException		org.broadleafcommerce.core.payment.service.exception
# Entity		OrderPaymentImpl		org.broadleafcommerce.core.payment.domain
# Entity		PaymentLogImpl		org.broadleafcommerce.core.payment.domain
# Interface	PaymentTransaction		org.broadleafcommerce.core.payment.domain
# Entity		PaymentTransactionImpl		org.broadleafcommerce.core.payment.domain
# Interface	OrderPayment		org.broadleafcommerce.core.payment.domain
# Interface	PaymentLog		org.broadleafcommerce.core.payment.domain
# Interface	PaymentResponseItem		org.broadleafcommerce.core.payment.domain
# Interface	CreditCardPayment		org.broadleafcommerce.core.payment.domain.secure
# Entity		GiftCardPaymentImpl		org.broadleafcommerce.core.payment.domain.secure
# Entity		CreditCardPaymentInfoImpl		org.broadleafcommerce.core.payment.domain.secure
# Interface	GiftCardPayment		org.broadleafcommerce.core.payment.domain.secure
# Interface	Referenced		org.broadleafcommerce.core.payment.domain.secure
# Entity		BankAccountPaymentImpl		org.broadleafcommerce.core.payment.domain.secure
# Interface	BankAccountPayment		org.broadleafcommerce.core.payment.domain.secure
# Repository		OrderPaymentDaoImpl		org.broadleafcommerce.core.payment.dao
# Interface	OrderPaymentDao		org.broadleafcommerce.core.payment.dao
# Interface	SecureOrderPaymentDao		org.broadleafcommerce.core.payment.dao
# Repository		SecureOrderPaymentDaoImpl		org.broadleafcommerce.core.payment.dao
# Entity		RuleDTOConfig		org.broadleafcommerce.core.rule
# Logic		RatingServiceImpl		org.broadleafcommerce.core.rating.service
# Interface	RatingService		org.broadleafcommerce.core.rating.service
# Entity		RatingType		org.broadleafcommerce.core.rating.service.type
# Entity		ReviewStatusType		org.broadleafcommerce.core.rating.service.type
# Entity		RatingSortType		org.broadleafcommerce.core.rating.service.type
# Interface	ReviewFeedback		org.broadleafcommerce.core.rating.domain
# Entity		ReviewDetailImpl		org.broadleafcommerce.core.rating.domain
# Entity		RatingSummaryImpl		org.broadleafcommerce.core.rating.domain
# Interface	RatingDetail		org.broadleafcommerce.core.rating.domain
# Interface	RatingSummary		org.broadleafcommerce.core.rating.domain
# Interface	ReviewDetail		org.broadleafcommerce.core.rating.domain
# Entity		RatingDetailImpl		org.broadleafcommerce.core.rating.domain
# Entity		ReviewFeedbackImpl		org.broadleafcommerce.core.rating.domain
# Repository		ReviewDetailDaoImpl		org.broadleafcommerce.core.rating.dao
# Interface	ReviewDetailDao		org.broadleafcommerce.core.rating.dao
# Repository		RatingSummaryDaoImpl		org.broadleafcommerce.core.rating.dao
# Interface	RatingSummaryDao		org.broadleafcommerce.core.rating.dao
# Logic		CheckoutServiceImpl		org.broadleafcommerce.core.checkout.service
# Interface	CheckoutService		org.broadleafcommerce.core.checkout.service
# Logic		PassthroughPaymentConfigurationImpl		org.broadleafcommerce.core.checkout.service.gateway
# Logic		PassthroughPaymentConfigurationServiceImpl		org.broadleafcommerce.core.checkout.service.gateway
# Logic		PassthroughPaymentRollbackServiceImpl		org.broadleafcommerce.core.checkout.service.gateway
# Entity		PassthroughPaymentConstants		org.broadleafcommerce.core.checkout.service.gateway
# Logic		OrderPaymentConfirmationStrategyImpl		org.broadleafcommerce.core.checkout.service.strategy
# Interface	OrderPaymentConfirmationStrategy		org.broadleafcommerce.core.checkout.service.strategy
# Entity		CheckoutException		org.broadleafcommerce.core.checkout.service.exception
# Logic		CompleteOrderRollbackHandler		org.broadleafcommerce.core.checkout.service.workflow
# Logic		ConfirmPaymentsRollbackHandler		org.broadleafcommerce.core.checkout.service.workflow
# Logic		DecrementInventoryActivity		org.broadleafcommerce.core.checkout.service.workflow
# Interface	CheckoutResponse		org.broadleafcommerce.core.checkout.service.workflow
# Logic		ValidateProductOptionsActivity		org.broadleafcommerce.core.checkout.service.workflow
# Logic		DecrementInventoryRollbackHandler		org.broadleafcommerce.core.checkout.service.workflow
# Entity		PricingServiceActivity		org.broadleafcommerce.core.checkout.service.workflow
# Logic		CommitTaxActivity		org.broadleafcommerce.core.checkout.service.workflow
# Entity		CheckoutProcessContextFactory		org.broadleafcommerce.core.checkout.service.workflow
# Logic		CommitTaxRollbackHandler		org.broadleafcommerce.core.checkout.service.workflow
# Logic		CompleteOrderActivity		org.broadleafcommerce.core.checkout.service.workflow
# Entity		CompositeActivity		org.broadleafcommerce.core.checkout.service.workflow
# Logic		ValidateCheckoutActivity		org.broadleafcommerce.core.checkout.service.workflow
# Logic		ValidateAvailabilityActivity		org.broadleafcommerce.core.checkout.service.workflow
# Logic		ValidateAndConfirmPaymentActivity		org.broadleafcommerce.core.checkout.service.workflow
# Entity		CheckoutSeed		org.broadleafcommerce.core.checkout.service.workflow
# Interface	ValidateCheckoutActivityExtensionHandler		org.broadleafcommerce.core.checkout.service.workflow.extension
# Logic		ValidateCheckoutActivityExtensionManager		org.broadleafcommerce.core.checkout.service.workflow.extension
# Entity		AbstractValidateCheckoutActivityExtensionHandler		org.broadleafcommerce.core.checkout.service.workflow.extension
# Logic		MergeOrdersByEmailPostRegistrationObserver		org.broadleafcommerce.core.registration
# Excluded	ImportSQLConfig		org.broadleafcommerce.core.demo
# Excluded	FrameworkConfig		org.broadleafcommerce.core.config
# Excluded	FrameworkCacheConfiguration		org.broadleafcommerce.core.config
# Logic		ZipCodeServiceImpl		org.broadleafcommerce.core.store.service
# Logic		StoreServiceImpl		org.broadleafcommerce.core.store.service
# Interface	ZipCodeService		org.broadleafcommerce.core.store.service
# Interface	StoreService		org.broadleafcommerce.core.store.service
# Interface	Store		org.broadleafcommerce.core.store.domain
# Entity		StoreImpl		org.broadleafcommerce.core.store.domain
# Interface	ZipCode		org.broadleafcommerce.core.store.domain
# Entity		ZipCodeImpl		org.broadleafcommerce.core.store.domain
# Interface	StoreDao		org.broadleafcommerce.core.store.dao
# Repository		StoreDaoImpl		org.broadleafcommerce.core.store.dao
# Interface	ZipCodeDao		org.broadleafcommerce.core.store.dao
# Repository		ZipCodeDaoImpl		org.broadleafcommerce.core.store.dao
# Entity		FulfillmentBandImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		FulfillmentPriceBandImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		BandedWeightFulfillmentOptionImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	FixedPriceFulfillmentOption		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	BandedWeightFulfillmentOption		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		FulfillmentWeightBandImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	FulfillmentBand		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		FixedPriceFulfillmentOptionImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		BandedPriceFulfillmentOptionImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	BandedPriceFulfillmentOption		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	FulfillmentPriceBand		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	FulfillmentWeightBand		org.broadleafcommerce.core.order.fulfillment.domain
# Interface	PostUpdateOrderExtensionHandler		org.broadleafcommerce.core.order.extension
# Logic		PostUpdateOrderExtensionManager		org.broadleafcommerce.core.order.extension
# Entity		AbstractPostUpdateOrderExtensionHandler		org.broadleafcommerce.core.order.extension
# Logic		OrderServiceImpl		org.broadleafcommerce.core.order.service
# Interface	ProductOptionValidationService		org.broadleafcommerce.core.order.service
# Logic		CartMessageOrderItemServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Logic		FulfillmentOptionServiceImpl		org.broadleafcommerce.core.order.service
# Interface	FulfillmentOptionService		org.broadleafcommerce.core.order.service
# Entity		StructuredContentCartRuleProcessor		org.broadleafcommerce.core.order.service
# Entity		AbstractOrderServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Logic		ProductOptionValidationServiceImpl		org.broadleafcommerce.core.order.service
# Entity		AbstractMergeCartServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Entity		PageCartRuleProcessor		org.broadleafcommerce.core.order.service
# Logic		OrderMultishipOptionServiceImpl		org.broadleafcommerce.core.order.service
# Logic		MergeCartServiceExtensionManager		org.broadleafcommerce.core.order.service
# Logic		FulfillmentGroupServiceImpl		org.broadleafcommerce.core.order.service
# Logic		OrderItemServiceImpl		org.broadleafcommerce.core.order.service
# Interface	OrderLockManager		org.broadleafcommerce.core.order.service
# Logic		MergeCartServiceImpl		org.broadleafcommerce.core.order.service
# Entity		AbstractCartRuleProcessor		org.broadleafcommerce.core.order.service
# Interface	FulfillmentGroupService		org.broadleafcommerce.core.order.service
# Interface	OrderMultishipOptionService		org.broadleafcommerce.core.order.service
# Interface	OrderServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Logic		OrderServiceExtensionManager		org.broadleafcommerce.core.order.service
# Interface	MergeCartServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Interface	OrderService		org.broadleafcommerce.core.order.service
# Interface	MergeCartService		org.broadleafcommerce.core.order.service
# Interface	OrderItemService		org.broadleafcommerce.core.order.service
# Interface	OrderItemServiceExtensionHandler		org.broadleafcommerce.core.order.service.extension
# Entity		AbstractOrderItemServiceExtensionHandler		org.broadleafcommerce.core.order.service.extension
# Logic		OrderItemServiceExtensionManager		org.broadleafcommerce.core.order.service.extension
# Entity		FulfillmentBandResultAmountType		org.broadleafcommerce.core.order.service.type
# Entity		MessageType		org.broadleafcommerce.core.order.service.type
# Entity		OrderStatus		org.broadleafcommerce.core.order.service.type
# Entity		FulfillmentGroupStatusType		org.broadleafcommerce.core.order.service.type
# Entity		OrderItemType		org.broadleafcommerce.core.order.service.type
# Entity		FulfillmentType		org.broadleafcommerce.core.order.service.type
# Entity		AbstractOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		FulfillmentGroupItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		AddToCartItems		org.broadleafcommerce.core.order.service.call
# Entity		ConfigurableOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		FulfillmentGroupRequest		org.broadleafcommerce.core.order.service.call
# Entity		ProductBundleOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		ReconstructCartResponse		org.broadleafcommerce.core.order.service.call
# Entity		OrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		NonDiscreteOrderItemRequestDTO		org.broadleafcommerce.core.order.service.call
# Entity		DiscreteOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		BundleOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		GiftWrapOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		AddToCartItem		org.broadleafcommerce.core.order.service.call
# Entity		MergeCartResponse		org.broadleafcommerce.core.order.service.call
# Entity		UpdateCartResponse		org.broadleafcommerce.core.order.service.call
# Entity		OrderMultishipOptionDTO		org.broadleafcommerce.core.order.service.call
# Entity		ActivityMessageDTO		org.broadleafcommerce.core.order.service.call
# Entity		OrderItemRequestDTO		org.broadleafcommerce.core.order.service.call
# Entity		LegacyOrderServiceImpl		org.broadleafcommerce.core.order.service.legacy
# Entity		LegacyCartServiceImpl		org.broadleafcommerce.core.order.service.legacy
# Interface	LegacyOrderService		org.broadleafcommerce.core.order.service.legacy
# Interface	LegacyCartService		org.broadleafcommerce.core.order.service.legacy
# Entity		LegacyMergeCartServiceImpl		org.broadleafcommerce.core.order.service.legacy
# Entity		UpdateCartException		org.broadleafcommerce.core.order.service.exception
# Entity		MinQuantityNotFulfilledException		org.broadleafcommerce.core.order.service.exception
# Entity		ItemNotFoundException		org.broadleafcommerce.core.order.service.exception
# Entity		IllegalCartOperationException		org.broadleafcommerce.core.order.service.exception
# Entity		RemoveFromCartException		org.broadleafcommerce.core.order.service.exception
# Entity		RequiredAttributeNotProvidedException		org.broadleafcommerce.core.order.service.exception
# Entity		ProductOptionValidationException		org.broadleafcommerce.core.order.service.exception
# Entity		OrderServiceException		org.broadleafcommerce.core.order.service.exception
# Entity		AddToCartException		org.broadleafcommerce.core.order.service.exception
# Entity		CartOperationProcessContextFactory		org.broadleafcommerce.core.order.service.workflow
# Logic		AddWorkflowVerifyFulfillmentGroupItemsActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		RemoveWorkflowPriceOrderIfNecessaryActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		UpdateWorkflowPriceOrderIfNecessaryActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		CheckAddAvailabilityActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		UpdateWorkflowVerifyFulfillmentGroupItemsActivity		org.broadleafcommerce.core.order.service.workflow
# Entity		AbstractCheckAvailabilityActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		RemoveWorkflowVerifyFulfillmentGroupItemsActivity		org.broadleafcommerce.core.order.service.workflow
# Entity		CartOperationRequest		org.broadleafcommerce.core.order.service.workflow
# Logic		CheckUpdateAvailabilityActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		AddWorkflowPriceOrderIfNecessaryActivity		org.broadleafcommerce.core.order.service.workflow
# Logic		ValidateRemoveRequestActivity		org.broadleafcommerce.core.order.service.workflow.remove
# Logic		RemoveOrderMultishipOptionActivity		org.broadleafcommerce.core.order.service.workflow.remove
# Logic		RemoveFulfillmentGroupItemActivity		org.broadleafcommerce.core.order.service.workflow.remove
# Logic		RemoveOrderItemActivity		org.broadleafcommerce.core.order.service.workflow.remove
# Interface	OrderItemRequestValidationService		org.broadleafcommerce.core.order.service.workflow.service
# Logic		OrderItemRequestValidationServiceImpl		org.broadleafcommerce.core.order.service.workflow.service
# Logic		AddOrderItemActivity		org.broadleafcommerce.core.order.service.workflow.add
# Logic		AddFulfillmentGroupItemActivity		org.broadleafcommerce.core.order.service.workflow.add
# Logic		ValidateAddRequestActivity		org.broadleafcommerce.core.order.service.workflow.add
# Interface	ValidateAddRequestActivityExtensionHandler		org.broadleafcommerce.core.order.service.workflow.add.extension
# Logic		ValidateAddRequestActivityExtensionManager		org.broadleafcommerce.core.order.service.workflow.add.extension
# Entity		AbstractValidateAddRequestActivityExtensionHandler		org.broadleafcommerce.core.order.service.workflow.add.extension
# Logic		ValidateUpdateRequestActivity		org.broadleafcommerce.core.order.service.workflow.update
# Logic		UpdateFulfillmentGroupItemActivity		org.broadleafcommerce.core.order.service.workflow.update
# Logic		UpdateOrderMultishipOptionActivity		org.broadleafcommerce.core.order.service.workflow.update
# Logic		UpdateOrderItemActivity		org.broadleafcommerce.core.order.service.workflow.update
# Logic		ValidateUpdateProductOptionsRequestActivity		org.broadleafcommerce.core.order.service.workflow.update.options
# Logic		UpdateProductOptionsOrderItemActivity		org.broadleafcommerce.core.order.service.workflow.update.options
# Entity		OrderItemSplitContainer		org.broadleafcommerce.core.order.service.manipulation
# Entity		OrderItemVisitorAdapter		org.broadleafcommerce.core.order.service.manipulation
# Interface	OrderItemVisitor		org.broadleafcommerce.core.order.service.manipulation
# Entity		BundleOrderItemSplitContainer		org.broadleafcommerce.core.order.service.manipulation
# Entity		OrderAttributeImpl		org.broadleafcommerce.core.order.domain
# Entity		DiscreteOrderItemImpl		org.broadleafcommerce.core.order.domain
# Interface	DynamicPriceDiscreteOrderItem		org.broadleafcommerce.core.order.domain
# Interface	DiscreteOrderItem		org.broadleafcommerce.core.order.domain
# Interface	FulfillmentGroup		org.broadleafcommerce.core.order.domain
# Entity		GiftWrapOrderItemImpl		org.broadleafcommerce.core.order.domain
# Interface	SkuAccessor		org.broadleafcommerce.core.order.domain
# Entity		BundleOrderItemFeePriceImpl		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentOptionImpl		org.broadleafcommerce.core.order.domain
# Interface	OrderAdminPresentation		org.broadleafcommerce.core.order.domain
# Interface	BundleOrderItem		org.broadleafcommerce.core.order.domain
# Entity		TaxType		org.broadleafcommerce.core.order.domain
# Interface	OrderLock		org.broadleafcommerce.core.order.domain
# Interface	OrderAttribute		org.broadleafcommerce.core.order.domain
# Entity		OrderItemAttributeImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderPersistedEvent		org.broadleafcommerce.core.order.domain
# Interface	FulfillmentGroupFee		org.broadleafcommerce.core.order.domain
# Interface	GiftWrapOrderItem		org.broadleafcommerce.core.order.domain
# Entity		BundleOrderItemImpl		org.broadleafcommerce.core.order.domain
# Interface	NullOrderFactory		org.broadleafcommerce.core.order.domain
# Logic		NullOrderFactoryImpl		org.broadleafcommerce.core.order.domain
# Interface	Order		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentGroupItemImpl		org.broadleafcommerce.core.order.domain
# Entity		TaxDetailImpl		org.broadleafcommerce.core.order.domain
# Interface	TaxDetail		org.broadleafcommerce.core.order.domain
# Interface	OrderItemPriceDetail		org.broadleafcommerce.core.order.domain
# Interface	PersonalMessage		org.broadleafcommerce.core.order.domain
# Entity		OrderImpl		org.broadleafcommerce.core.order.domain
# Entity		PersonalMessageImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderMultishipOptionImpl		org.broadleafcommerce.core.order.domain
# Entity		NullOrderImpl		org.broadleafcommerce.core.order.domain
# Interface	OrderItemAttribute		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentGroupFeeImpl		org.broadleafcommerce.core.order.domain
# Entity		DynamicPriceDiscreteOrderItemImpl		org.broadleafcommerce.core.order.domain
# Interface	DiscreteOrderItemFeePrice		org.broadleafcommerce.core.order.domain
# Entity		OrderPersistedEntityListener		org.broadleafcommerce.core.order.domain
# Interface	FulfillmentGroupItem		org.broadleafcommerce.core.order.domain
# Interface	OrderMultishipOption		org.broadleafcommerce.core.order.domain
# Interface	FulfillmentOption		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentGroupImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderLockImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderItemImpl		org.broadleafcommerce.core.order.domain
# Interface	OrderItemQualifier		org.broadleafcommerce.core.order.domain
# Interface	OrderItem		org.broadleafcommerce.core.order.domain
# Entity		OrderItemQualifierImpl		org.broadleafcommerce.core.order.domain
# Entity		DiscreteOrderItemFeePriceImpl		org.broadleafcommerce.core.order.domain
# Interface	BundleOrderItemFeePrice		org.broadleafcommerce.core.order.domain
# Interface	OrderItemContainer		org.broadleafcommerce.core.order.domain
# Entity		OrderItemPriceDetailImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderItemHolder		org.broadleafcommerce.core.order.domain.dto
# Entity		OptionalEnterpriseBandedPriceFulfillmentOptionTemplate		org.broadleafcommerce.core.order.domain.weave
# Entity		OptionalEnterpriseBandedWeightFulfillmentOptionTemplate		org.broadleafcommerce.core.order.domain.weave
# Entity		NullFulfillmentGroupItemStrategyImpl		org.broadleafcommerce.core.order.strategy
# Logic		FulfillmentGroupItemStrategyImpl		org.broadleafcommerce.core.order.strategy
# Interface	FulfillmentGroupItemStrategy		org.broadleafcommerce.core.order.strategy
# Logic		NotificationOrderSubmittedEventListener		org.broadleafcommerce.core.order.event
# Repository		FulfillmentGroupItemDaoImpl		org.broadleafcommerce.core.order.dao
# Repository		FulfillmentOptionDaoImpl		org.broadleafcommerce.core.order.dao
# Interface	OrderDaoExtensionHandler		org.broadleafcommerce.core.order.dao
# Interface	OrderDao		org.broadleafcommerce.core.order.dao
# Interface	FulfillmentOptionDao		org.broadleafcommerce.core.order.dao
# Repository		OrderMultishipOptionDaoImpl		org.broadleafcommerce.core.order.dao
# Interface	FulfillmentGroupItemDao		org.broadleafcommerce.core.order.dao
# Logic		OrderDaoExtensionManager		org.broadleafcommerce.core.order.dao
# Repository		OrderDaoImpl		org.broadleafcommerce.core.order.dao
# Repository		OrderItemDaoImpl		org.broadleafcommerce.core.order.dao
# ...
# Interface	EntityInformationService		org.broadleafcommerce.common.entity.service
# Logic		EntityInformationServiceImpl		org.broadleafcommerce.common.entity.service
# Entity		AbstractEntityInformationServiceExtensionHandler		org.broadleafcommerce.common.entity.service
# Interface	EntityInformationServiceExtensionHandler		org.broadleafcommerce.common.entity.service
# Logic		EntityInformationServiceExtensionManager		org.broadleafcommerce.common.entity.service
# Entity		EntityInformationDto		org.broadleafcommerce.common.entity.dto
# Entity		MapElementWrapper		org.broadleafcommerce.common.rest.api.wrapper
# Entity		BaseWrapper		org.broadleafcommerce.common.rest.api.wrapper
# Interface	APIUnwrapper		org.broadleafcommerce.common.rest.api.wrapper
# Interface	WrapperAdditionalFields		org.broadleafcommerce.common.rest.api.wrapper
# Interface	APIWrapper		org.broadleafcommerce.common.rest.api.wrapper
# Entity		PageDTO		org.broadleafcommerce.common.page.dto
# Entity		NullPageDTO		org.broadleafcommerce.common.page.dto
# Interface	CrossAppAdminAuthService		org.broadleafcommerce.common.crossapp.service
# Interface	CrossAppAuthService		org.broadleafcommerce.common.crossapp.service
# Entity		PassthroughEncryptionModule		org.broadleafcommerce.common.encryption
# Interface	EncryptionModule		org.broadleafcommerce.common.encryption
# Interface	AtomicMove		org.broadleafcommerce.common.io
# Interface	ConcurrentFileOutputStream		org.broadleafcommerce.common.io
# Entity		AtomicMoveImpl		org.broadleafcommerce.common.io
# Logic		ConcurrentFileOutputStreamImpl		org.broadleafcommerce.common.io
# Entity		ItemsFulfilledEvent		org.broadleafcommerce.common.event
# Entity		AbstractBroadleafApplicationEventListener		org.broadleafcommerce.common.event
# Interface	BroadleafApplicationEventPublisher		org.broadleafcommerce.common.event
# Entity		BroadleafApplicationEvent		org.broadleafcommerce.common.event
# Entity		ReindexEvent		org.broadleafcommerce.common.event
# Logic		BroadleafApplicationEventPublisherImpl		org.broadleafcommerce.common.event
# Entity		BroadleafSystemEventDetail		org.broadleafcommerce.common.event
# Entity		ItemsReturnedEvent		org.broadleafcommerce.common.event
# Entity		BroadleafApplicationEventMulticaster		org.broadleafcommerce.common.event
# Entity		OrderSubmittedEvent		org.broadleafcommerce.common.event
# Interface	BroadleafApplicationListener		org.broadleafcommerce.common.event
# Entity		ItemsCancelledEvent		org.broadleafcommerce.common.event
# Entity		BroadleafSystemEvent		org.broadleafcommerce.common.event
# Logic		TranslationServiceExtensionManager		org.broadleafcommerce.common.i18n.service
# Interface	TranslationSupport		org.broadleafcommerce.common.i18n.service
# Entity		TranslationConsiderationContext		org.broadleafcommerce.common.i18n.service
# Interface	ISOService		org.broadleafcommerce.common.i18n.service
# Interface	TranslationService		org.broadleafcommerce.common.i18n.service
# Logic		SparseTranslationOverrideStrategy		org.broadleafcommerce.common.i18n.service
# Entity		DynamicTranslationProvider		org.broadleafcommerce.common.i18n.service
# Interface	TranslationOverrideStrategy		org.broadleafcommerce.common.i18n.service
# Logic		ISOServiceImpl		org.broadleafcommerce.common.i18n.service
# Logic		ThresholdCacheTranslationOverrideStrategy		org.broadleafcommerce.common.i18n.service
# Entity		TranslationBatchReadCache		org.broadleafcommerce.common.i18n.service
# Entity		LocalePair		org.broadleafcommerce.common.i18n.service
# Logic		TranslationServiceImpl		org.broadleafcommerce.common.i18n.service
# Entity		ISOCodeStatusType		org.broadleafcommerce.common.i18n.service.type
# Interface	ISOCountry		org.broadleafcommerce.common.i18n.domain
# Entity		TranslatedEntity		org.broadleafcommerce.common.i18n.domain
# Entity		TranslationImpl		org.broadleafcommerce.common.i18n.domain
# Interface	Translation		org.broadleafcommerce.common.i18n.domain
# Entity		ISOCountryImpl		org.broadleafcommerce.common.i18n.domain
# Repository		TranslationDaoImpl		org.broadleafcommerce.common.i18n.dao
# Repository		ISODaoImpl		org.broadleafcommerce.common.i18n.dao
# Logic		TranslationDaoExtensionManager		org.broadleafcommerce.common.i18n.dao
# Interface	ISODao		org.broadleafcommerce.common.i18n.dao
# Interface	TranslationDaoExtensionHandler		org.broadleafcommerce.common.i18n.dao
# Interface	TranslationDao		org.broadleafcommerce.common.i18n.dao
# Interface	BroadleafExpressionParser		org.broadleafcommerce.common.expression
# Logic		BroadleafExpressionParserImpl		org.broadleafcommerce.common.expression
# Interface	NotificationService		org.broadleafcommerce.common.notification.service
# Logic		DefaultSMSNotificationServiceImpl		org.broadleafcommerce.common.notification.service
# Interface	NotificationDispatcher		org.broadleafcommerce.common.notification.service
# Logic		DefaultEmailNotificationServiceImpl		org.broadleafcommerce.common.notification.service
# Logic		NotificationDispatcherImpl		org.broadleafcommerce.common.notification.service
# Entity		EmailNotification		org.broadleafcommerce.common.notification.service.type
# Entity		SMSNotification		org.broadleafcommerce.common.notification.service.type
# Logic		NotificationEventType		org.broadleafcommerce.common.notification.service.type
# Entity		Notification		org.broadleafcommerce.common.notification.service.type
# Logic		BroadleafRequestFilter		org.broadleafcommerce.common.web
# Interface	Locatable		org.broadleafcommerce.common.web
# Interface	BroadleafThemeResolver		org.broadleafcommerce.common.web
# Entity		BLCAbstractHandlerMapping		org.broadleafcommerce.common.web
# Entity		AbstractBroadleafTemplateResolverExtensionHandler		org.broadleafcommerce.common.web
# Logic		BroadleafTimeZoneResolverImpl		org.broadleafcommerce.common.web
# Entity		BroadleafCookieLocaleResolver		org.broadleafcommerce.common.web
# Entity		JsonResponse		org.broadleafcommerce.common.web
# Interface	BroadleafTimeZoneResolver		org.broadleafcommerce.common.web
# Interface	TemplateTypeAware		org.broadleafcommerce.common.web
# Entity		BroadleafRequestContext		org.broadleafcommerce.common.web
# Entity		NullBroadleafThemeResolver		org.broadleafcommerce.common.web
# Logic		BroadleafThemeProcessor		org.broadleafcommerce.common.web
# Entity		BroadleafRequestInterceptor		org.broadleafcommerce.common.web
# Interface	BroadleafSiteResolver		org.broadleafcommerce.common.web
# Interface	BroadleafCurrencyResolver		org.broadleafcommerce.common.web
# Interface	BroadleafLocaleResolver		org.broadleafcommerce.common.web
# Logic		BroadleafSandBoxResolverImpl		org.broadleafcommerce.common.web
# Entity		BaseUrlResolverImpl		org.broadleafcommerce.common.web
# Interface	BaseUrlResolver		org.broadleafcommerce.common.web
# Logic		ThemeUrlEncodingFilter		org.broadleafcommerce.common.web
# Logic		BroadleafThemeResolverFilter		org.broadleafcommerce.common.web
# Entity		SandBoxContext		org.broadleafcommerce.common.web
# Logic		BroadleafRequestCustomerResolverImpl		org.broadleafcommerce.common.web
# Logic		BroadleafRequestProcessor		org.broadleafcommerce.common.web
# Interface	BroadleafSandBoxResolver		org.broadleafcommerce.common.web
# Interface	BroadleafRequestCustomerResolver		org.broadleafcommerce.common.web
# Interface	BroadleafWebRequestProcessor		org.broadleafcommerce.common.web
# Logic		BroadleafLocaleResolverImpl		org.broadleafcommerce.common.web
# Interface	BroadleafTemplateViewResolverExtensionHandler		org.broadleafcommerce.common.web
# Entity		NullBroadleafSiteResolver		org.broadleafcommerce.common.web
# Logic		BroadleafTemplateViewResolverExtensionManager		org.broadleafcommerce.common.web
# Entity		AbstractBroadleafWebRequestProcessor		org.broadleafcommerce.common.web
# Logic		BroadleafCurrencyResolverImpl		org.broadleafcommerce.common.web
# Interface	BLCICacheExtensionHandler		org.broadleafcommerce.common.web.cache
# Entity		AbstractBLCICacheExtensionHandler		org.broadleafcommerce.common.web.cache
# Logic		BLCICacheExtensionManager		org.broadleafcommerce.common.web.cache
# Entity		DeepLink		org.broadleafcommerce.common.web.deeplink
# Entity		DeepLinkService		org.broadleafcommerce.common.web.deeplink
# Entity		BroadleafBootServletContextInitializer		org.broadleafcommerce.common.web.boot.support
# Entity		SpringBootBootstrappingServletContextListener		org.broadleafcommerce.common.web.boot.support
# Entity		TranslationInterceptor		org.broadleafcommerce.common.web.filter
# Logic		SecurityBasedIgnoreFilter		org.broadleafcommerce.common.web.filter
# Entity		IgnorableOpenEntityManagerInViewFilter		org.broadleafcommerce.common.web.filter
# Entity		FilterOrdered		org.broadleafcommerce.common.web.filter
# Entity		AbstractIgnorableOncePerRequestFilter		org.broadleafcommerce.common.web.filter
# Entity		AbstractIgnorableFilter		org.broadleafcommerce.common.web.filter
# Logic		TranslationFilter		org.broadleafcommerce.common.web.filter
# Entity		SessionlessHttpServletRequestWrapper		org.broadleafcommerce.common.web.filter
# Logic		TranslationRequestProcessor		org.broadleafcommerce.common.web.filter
# Entity		EntityManagerFindValidationFilter		org.broadleafcommerce.common.web.filter
# Logic		HtmlMinifyFilter		org.broadleafcommerce.common.web.util
# Entity		StatusExposingServletResponse		org.broadleafcommerce.common.web.util
# Entity		RepeatSubmitProtectionFilter		org.broadleafcommerce.common.web.util
# Entity		ServletOutputStreamWrapper		org.broadleafcommerce.common.web.util
# Entity		BroadleafUrlParamUtils		org.broadleafcommerce.common.web.util
# Entity		CacheAwareResponseHandler		org.broadleafcommerce.common.web.util
# Logic		CachingCompressedResponseFilter		org.broadleafcommerce.common.web.util
# Entity		PrecompressedArtifactFilter		org.broadleafcommerce.common.web.util
# Entity		FileSystemResponseWrapper		org.broadleafcommerce.common.web.util
# Entity		CustomerPaymentGatewayAbstractController		org.broadleafcommerce.common.web.payment.controller
# Entity		PaymentGatewayAbstractController		org.broadleafcommerce.common.web.payment.controller
# Logic		CreditCardTypesExtensionManager		org.broadleafcommerce.common.web.payment.processor
# Interface	CreditCardTypesExtensionHandler		org.broadleafcommerce.common.web.payment.processor
# Logic		TRCreditCardExtensionManager		org.broadleafcommerce.common.web.payment.processor
# Entity		AbstractTRCreditCardExtensionHandler		org.broadleafcommerce.common.web.payment.processor
# Entity		AbstractCreditCardTypesExtensionHandler		org.broadleafcommerce.common.web.payment.processor
# Logic		TransparentRedirectCreditCardFormProcessor		org.broadleafcommerce.common.web.payment.processor
# Logic		CreditCardTypesProcessor		org.broadleafcommerce.common.web.payment.processor
# Interface	TRCreditCardExtensionHandler		org.broadleafcommerce.common.web.payment.processor
# Interface	PaymentGatewayFieldExtensionHandler		org.broadleafcommerce.common.web.payment.expression
# Entity		AbstractPaymentGatewayFieldExtensionHandler		org.broadleafcommerce.common.web.payment.expression
# Logic		PaymentGatewayFieldVariableExpression		org.broadleafcommerce.common.web.payment.expression
# Logic		PaymentGatewayFieldExtensionManager		org.broadleafcommerce.common.web.payment.expression
# Entity		WebRequestDeviceType		org.broadleafcommerce.common.web.device
# Logic		FrameworkControllerHandlerMapping		org.broadleafcommerce.common.web.controller
# Entity		FrameworkMvcUriComponentsBuilder		org.broadleafcommerce.common.web.controller
# Entity		BroadleafRedirectController		org.broadleafcommerce.common.web.controller
# Entity		BroadleafAbstractController		org.broadleafcommerce.common.web.controller
# Entity		BroadleafControllerUtility		org.broadleafcommerce.common.web.controller
# Excluded	BroadleafSiteServletConfig		org.broadleafcommerce.common.web.config
# Logic		BroadleafContextUtil		org.broadleafcommerce.common.web.resource
# Entity		AbstractGeneratedResourceHandler		org.broadleafcommerce.common.web.resource
# Entity		AbstractResourceRequestExtensionHandler		org.broadleafcommerce.common.web.resource
# Entity		BroadleafDefaultResourceResolverChain		org.broadleafcommerce.common.web.resource
# Interface	ResourceRequestExtensionHandler		org.broadleafcommerce.common.web.resource
# Logic		ResourceRequestExtensionManager		org.broadleafcommerce.common.web.resource
# Entity		BroadleafResourceHttpRequestHandler		org.broadleafcommerce.common.web.resource
# Logic		BroadleafPathResourceResolver		org.broadleafcommerce.common.web.resource.resolver
# Entity		BroadleafResourceTransformerOrder		org.broadleafcommerce.common.web.resource.resolver
# Logic		BroadleafVersionResourceResolver		org.broadleafcommerce.common.web.resource.resolver
# Logic		BLCSystemPropertyResourceResolver		org.broadleafcommerce.common.web.resource.resolver
# Logic		BundleResourceResolver		org.broadleafcommerce.common.web.resource.resolver
# Logic		BLVersionResourceResolverDefaultStrategyMap		org.broadleafcommerce.common.web.resource.resolver
# Logic		BLCJSUrlPathResolver		org.broadleafcommerce.common.web.resource.resolver
# Entity		BroadleafResourceResolverOrder		org.broadleafcommerce.common.web.resource.resolver
# Logic		BroadleafCachingResourceResolver		org.broadleafcommerce.common.web.resource.resolver
# Logic		BLCJSResourceResolver		org.broadleafcommerce.common.web.resource.resolver
# Logic		BroadleafCachingResourceTransformer		org.broadleafcommerce.common.web.resource.transformer
# Logic		MinifyResourceTransformer		org.broadleafcommerce.common.web.resource.transformer
# Logic		DataDrivenEnumerationProcessor		org.broadleafcommerce.common.web.processor
# Logic		FormProcessor		org.broadleafcommerce.common.web.processor
# Logic		ResourcePreloadProcessor		org.broadleafcommerce.common.web.processor
# Entity		AbstractResourceProcessor		org.broadleafcommerce.common.web.processor
# Logic		ConfigVariableProcessor		org.broadleafcommerce.common.web.processor
# Logic		ResourceBundleProcessor		org.broadleafcommerce.common.web.processor
# Entity		ResourceTagAttributes		org.broadleafcommerce.common.web.processor.attributes
# Logic		DataDrivenEnumVariableExpression		org.broadleafcommerce.common.web.expression
# Logic		NullBroadleafVariableExpression		org.broadleafcommerce.common.web.expression
# Logic		PropertiesVariableExpression		org.broadleafcommerce.common.web.expression
# Interface	BroadleafVariableExpression		org.broadleafcommerce.common.web.expression
# Logic		BreadcrumbVariableExpression		org.broadleafcommerce.common.web.expression
# Logic		ModuleVariableExpression		org.broadleafcommerce.common.web.expression
# Logic		AssetURLVariableExpression		org.broadleafcommerce.common.web.expression
# Logic		BRCVariableExpression		org.broadleafcommerce.common.web.expression
# Entity		BroadleafFormType		org.broadleafcommerce.common.web.form
# Entity		HaltFilterChainException		org.broadleafcommerce.common.web.exception
# Entity		ResourcesRequestBundle		org.broadleafcommerce.common.web.request
# Logic		ResourcesRequest		org.broadleafcommerce.common.web.request
# Entity		ModulePresentUtil		org.broadleafcommerce.common.module
# Interface	BroadleafModuleRegistration		org.broadleafcommerce.common.module
# Interface	TypedEntity		org.broadleafcommerce.common.admin.domain
# Interface	AdminMainEntity		org.broadleafcommerce.common.admin.domain
# Entity		OptimisticLockInvalidStateException		org.broadleafcommerce.common.exception
# Entity		ProxyDetectionException		org.broadleafcommerce.common.exception
# Entity		BroadleafException		org.broadleafcommerce.common.exception
# Entity		ServiceException		org.broadleafcommerce.common.exception
# Excluded	FileUploadExceptionAdvice		org.broadleafcommerce.common.exception
# Entity		NoPossibleResultsException		org.broadleafcommerce.common.exception
# Logic		BroadleafSimpleMappingExceptionResolver		org.broadleafcommerce.common.exception
# Entity		OptimisticLockMaxRetryException		org.broadleafcommerce.common.exception
# Entity		SecurityServiceException		org.broadleafcommerce.common.exception
# Entity		SiteNotFoundException		org.broadleafcommerce.common.exception
# Entity		TranslatableException		org.broadleafcommerce.common.exception
# Interface	RootCauseAccessor		org.broadleafcommerce.common.exception
# Entity		ExceptionHelper		org.broadleafcommerce.common.exception
# Interface	GenericEntityDao		org.broadleafcommerce.common.dao
# Repository		GenericEntityDaoImpl		org.broadleafcommerce.common.dao
# Logic		StatelessSessionFilter		org.broadleafcommerce.api.common.web.filter

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)) or "repository" in pkg_name(tree).lower() or "repositories" in pkg_name(tree).lower() or "repository" in decl.name.lower():

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		AbstractPostUpdateCustomerExtensionHandler		org.broadleafcommerce.profile.core.extension
# Entity		CustomerUserDetails		org.broadleafcommerce.profile.core.service
# Entity		LocaleType		org.broadleafcommerce.profile.core.service.type
# Entity		CustomerAddressType		org.broadleafcommerce.profile.core.service.type
# Entity		BaseResponse		org.broadleafcommerce.profile.core.service.validator
# Entity		EmailNotificationPasswordUpdatedHandler		org.broadleafcommerce.profile.core.service.handler
# Entity		AddressVerificationException		org.broadleafcommerce.profile.core.service.exception
# Entity		CustomerPhoneImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerAddressPersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPaymentImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerForgotPasswordSecurityTokenImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerRoleImpl		org.broadleafcommerce.profile.core.domain
# Entity		PhoneImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPaymentPersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Entity		CustomerAttributeImpl		org.broadleafcommerce.profile.core.domain
# Entity		StateImpl		org.broadleafcommerce.profile.core.domain
# Entity		CountrySubdivisionImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPhonePersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Entity		RoleImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPersistedEvent		org.broadleafcommerce.profile.core.domain
# Entity		ChallengeQuestionImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerPersistedEntityListener		org.broadleafcommerce.profile.core.domain
# Entity		LastPaymentStatus		org.broadleafcommerce.profile.core.domain
# Entity		CustomerImpl		org.broadleafcommerce.profile.core.domain
# Entity		CountryImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerAddressImpl		org.broadleafcommerce.profile.core.domain
# Entity		CountrySubdivisionCategoryImpl		org.broadleafcommerce.profile.core.domain
# Entity		AddressImpl		org.broadleafcommerce.profile.core.domain
# Entity		CustomerRuleHolder		org.broadleafcommerce.profile.core.dto
# Entity		RegisterCustomerEvent		org.broadleafcommerce.profile.core.event
# Entity		ForgotUsernameEvent		org.broadleafcommerce.profile.core.event
# Entity		ForgotPasswordEvent		org.broadleafcommerce.profile.core.event
# Entity		CategoryMediaMap		org.broadleafcommerce.core.media.domain
# Entity		ShippingServiceImpl		org.broadleafcommerce.core.pricing.service
# Entity		SimpleFulfillmentLocationResolver		org.broadleafcommerce.core.pricing.service.fulfillment
# Entity		FixedPriceFulfillmentPricingProvider		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Entity		FulfillmentEstimationResponse		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Entity		BandedFulfillmentPricingProvider		org.broadleafcommerce.core.pricing.service.fulfillment.provider
# Entity		SimpleTaxProvider		org.broadleafcommerce.core.pricing.service.tax.provider
# Entity		BandedShippingModule		org.broadleafcommerce.core.pricing.service.module
# Entity		PricingException		org.broadleafcommerce.core.pricing.service.exception
# Entity		TaxException		org.broadleafcommerce.core.pricing.service.exception
# Entity		AutoBundleActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		ShippingActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		CompositeActivity		org.broadleafcommerce.core.pricing.service.workflow
# Entity		PricingProcessContextFactory		org.broadleafcommerce.core.pricing.service.workflow
# Entity		ShippingServiceType		org.broadleafcommerce.core.pricing.service.workflow.type
# Entity		ShippingRateImpl		org.broadleafcommerce.core.pricing.domain
# Entity		GeolocationDTO		org.broadleafcommerce.core.geolocation
# Entity		EntityIdentifierUtil		org.broadleafcommerce.core.util
# Entity		ThirdPartyInteractionLatencySimulationActivity		org.broadleafcommerce.core.util
# Entity		ZookeeperUtil		org.broadleafcommerce.core.util
# Entity		BroadleafSitemapUtils		org.broadleafcommerce.core.util.service
# Entity		AbstractResourcePurgeExtensionHandler		org.broadleafcommerce.core.util.service
# Entity		AbstractSiteMapExtensionHandler		org.broadleafcommerce.core.util.service
# Entity		CodeTypeImpl		org.broadleafcommerce.core.util.domain
# Entity		ReentrantDistributedZookeeperLock		org.broadleafcommerce.core.util.lock
# Entity		ZookeeperDistributedQueue		org.broadleafcommerce.core.util.queue
# Entity		AbstractOfferValueModifierExtensionHandler		org.broadleafcommerce.core.offer.service
# Entity		AbstractOfferServiceExtensionHandler		org.broadleafcommerce.core.offer.service
# Entity		OfferContext		org.broadleafcommerce.core.offer.service
# Entity		ItemOfferQtyOneComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotionDiscount		org.broadleafcommerce.core.offer.service.discount
# Entity		FulfillmentGroupOfferPotential		org.broadleafcommerce.core.offer.service.discount
# Entity		ItemOfferWeightedPercentComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotionQualifierWrapper		org.broadleafcommerce.core.offer.service.discount
# Entity		CandidatePromotionItems		org.broadleafcommerce.core.offer.service.discount
# Entity		OrderItemPriceComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotionQualifier		org.broadleafcommerce.core.offer.service.discount
# Entity		ItemOfferComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		OrderOfferComparator		org.broadleafcommerce.core.offer.service.discount
# Entity		PromotableOrderItemPriceDetailWrapper		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableCandidateOrderOfferImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderItemPriceDetailImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableCandidateFulfillmentGroupOfferImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableFulfillmentGroupAdjustmentImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderAdjustmentImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableCandidateItemOfferImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		AbstractPromotionRounding		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderItemPriceDetailAdjustmentImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableFulfillmentGroupImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderItemImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		PromotableOrderImpl		org.broadleafcommerce.core.offer.service.discount.domain
# Entity		OfferAdjustmentType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferTimeZoneType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferType		org.broadleafcommerce.core.offer.service.type
# Entity		StackabilityType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferItemRestrictionRuleType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferRuleType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferProrationType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferPriceDataIdentifierType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferDiscountType		org.broadleafcommerce.core.offer.service.type
# Entity		OfferOptionalDirectCopyTransformTypes		org.broadleafcommerce.core.offer.service.type
# Entity		CustomerMaxUsesStrategyType		org.broadleafcommerce.core.offer.service.type
# Entity		AbstractBaseProcessor		org.broadleafcommerce.core.offer.service.processor
# Entity		OfferMaxUseExceededException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferExpiredException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferAlreadyAddedException		org.broadleafcommerce.core.offer.service.exception
# Entity		OfferRuleImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferCodeImpl		org.broadleafcommerce.core.offer.domain
# Entity		LegacyOfferUsesImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferTargetCriteriaXrefImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferItemCriteriaImpl		org.broadleafcommerce.core.offer.domain
# Entity		ProratedOrderItemAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferPriceDataImpl		org.broadleafcommerce.core.offer.domain
# Entity		FulfillmentGroupAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		CustomerOfferImpl		org.broadleafcommerce.core.offer.domain
# Entity		OrderItemAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferOfferRuleXrefImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferQualifyingCriteriaXrefImpl		org.broadleafcommerce.core.offer.domain
# Entity		CandidateItemOfferImpl		org.broadleafcommerce.core.offer.domain
# Entity		CandidateOrderOfferImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferAuditImpl		org.broadleafcommerce.core.offer.domain
# Entity		OfferInfoImpl		org.broadleafcommerce.core.offer.domain
# Entity		CandidateFulfillmentGroupOfferImpl		org.broadleafcommerce.core.offer.domain
# Entity		OrderItemPriceDetailAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		OrderAdjustmentImpl		org.broadleafcommerce.core.offer.domain
# Entity		WeaveLegacyOfferUses		org.broadleafcommerce.core.offer.weave
# Entity		DefaultOfferCodeDaoExtensionHandler		org.broadleafcommerce.core.offer.dao
# Entity		BLCPromotionMessageUtils		org.broadleafcommerce.core.promotionMessage.util
# Entity		PromotionMessageImpl		org.broadleafcommerce.core.promotionMessage.domain
# Entity		PromotionMessageType		org.broadleafcommerce.core.promotionMessage.domain.type
# Entity		PromotionMessagePlacementType		org.broadleafcommerce.core.promotionMessage.domain.type
# Entity		PromotionMessageDTO		org.broadleafcommerce.core.promotionMessage.dto
# Entity		OrderPaymentStatus		org.broadleafcommerce.core.payment.service.type
# Entity		PaymentProcessorException		org.broadleafcommerce.core.payment.service.exception
# Entity		InsufficientFundsException		org.broadleafcommerce.core.payment.service.exception
# Entity		PaymentException		org.broadleafcommerce.core.payment.service.exception
# Entity		OrderPaymentImpl		org.broadleafcommerce.core.payment.domain
# Entity		PaymentLogImpl		org.broadleafcommerce.core.payment.domain
# Entity		PaymentTransactionImpl		org.broadleafcommerce.core.payment.domain
# Entity		GiftCardPaymentImpl		org.broadleafcommerce.core.payment.domain.secure
# Entity		CreditCardPaymentInfoImpl		org.broadleafcommerce.core.payment.domain.secure
# Entity		BankAccountPaymentImpl		org.broadleafcommerce.core.payment.domain.secure
# Entity		RuleDTOConfig		org.broadleafcommerce.core.rule
# Entity		RatingType		org.broadleafcommerce.core.rating.service.type
# Entity		ReviewStatusType		org.broadleafcommerce.core.rating.service.type
# Entity		RatingSortType		org.broadleafcommerce.core.rating.service.type
# Entity		ReviewDetailImpl		org.broadleafcommerce.core.rating.domain
# Entity		RatingSummaryImpl		org.broadleafcommerce.core.rating.domain
# Entity		RatingDetailImpl		org.broadleafcommerce.core.rating.domain
# Entity		ReviewFeedbackImpl		org.broadleafcommerce.core.rating.domain
# Entity		PassthroughPaymentConstants		org.broadleafcommerce.core.checkout.service.gateway
# Entity		CheckoutException		org.broadleafcommerce.core.checkout.service.exception
# Entity		PricingServiceActivity		org.broadleafcommerce.core.checkout.service.workflow
# Entity		CheckoutProcessContextFactory		org.broadleafcommerce.core.checkout.service.workflow
# Entity		CompositeActivity		org.broadleafcommerce.core.checkout.service.workflow
# Entity		CheckoutSeed		org.broadleafcommerce.core.checkout.service.workflow
# Entity		AbstractValidateCheckoutActivityExtensionHandler		org.broadleafcommerce.core.checkout.service.workflow.extension
# Entity		StoreImpl		org.broadleafcommerce.core.store.domain
# Entity		ZipCodeImpl		org.broadleafcommerce.core.store.domain
# Entity		FulfillmentBandImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		FulfillmentPriceBandImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		BandedWeightFulfillmentOptionImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		FulfillmentWeightBandImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		FixedPriceFulfillmentOptionImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		BandedPriceFulfillmentOptionImpl		org.broadleafcommerce.core.order.fulfillment.domain
# Entity		AbstractPostUpdateOrderExtensionHandler		org.broadleafcommerce.core.order.extension
# Entity		StructuredContentCartRuleProcessor		org.broadleafcommerce.core.order.service
# Entity		AbstractOrderServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Entity		AbstractMergeCartServiceExtensionHandler		org.broadleafcommerce.core.order.service
# Entity		PageCartRuleProcessor		org.broadleafcommerce.core.order.service
# Entity		AbstractCartRuleProcessor		org.broadleafcommerce.core.order.service
# Entity		AbstractOrderItemServiceExtensionHandler		org.broadleafcommerce.core.order.service.extension
# Entity		FulfillmentBandResultAmountType		org.broadleafcommerce.core.order.service.type
# Entity		MessageType		org.broadleafcommerce.core.order.service.type
# Entity		OrderStatus		org.broadleafcommerce.core.order.service.type
# Entity		FulfillmentGroupStatusType		org.broadleafcommerce.core.order.service.type
# Entity		OrderItemType		org.broadleafcommerce.core.order.service.type
# Entity		FulfillmentType		org.broadleafcommerce.core.order.service.type
# Entity		AbstractOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		FulfillmentGroupItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		AddToCartItems		org.broadleafcommerce.core.order.service.call
# Entity		ConfigurableOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		FulfillmentGroupRequest		org.broadleafcommerce.core.order.service.call
# Entity		ProductBundleOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		ReconstructCartResponse		org.broadleafcommerce.core.order.service.call
# Entity		OrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		NonDiscreteOrderItemRequestDTO		org.broadleafcommerce.core.order.service.call
# Entity		DiscreteOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		BundleOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		GiftWrapOrderItemRequest		org.broadleafcommerce.core.order.service.call
# Entity		AddToCartItem		org.broadleafcommerce.core.order.service.call
# Entity		MergeCartResponse		org.broadleafcommerce.core.order.service.call
# Entity		UpdateCartResponse		org.broadleafcommerce.core.order.service.call
# Entity		OrderMultishipOptionDTO		org.broadleafcommerce.core.order.service.call
# Entity		ActivityMessageDTO		org.broadleafcommerce.core.order.service.call
# Entity		OrderItemRequestDTO		org.broadleafcommerce.core.order.service.call
# Entity		LegacyOrderServiceImpl		org.broadleafcommerce.core.order.service.legacy
# Entity		LegacyCartServiceImpl		org.broadleafcommerce.core.order.service.legacy
# Entity		LegacyMergeCartServiceImpl		org.broadleafcommerce.core.order.service.legacy
# Entity		UpdateCartException		org.broadleafcommerce.core.order.service.exception
# Entity		MinQuantityNotFulfilledException		org.broadleafcommerce.core.order.service.exception
# Entity		ItemNotFoundException		org.broadleafcommerce.core.order.service.exception
# Entity		IllegalCartOperationException		org.broadleafcommerce.core.order.service.exception
# Entity		RemoveFromCartException		org.broadleafcommerce.core.order.service.exception
# Entity		RequiredAttributeNotProvidedException		org.broadleafcommerce.core.order.service.exception
# Entity		ProductOptionValidationException		org.broadleafcommerce.core.order.service.exception
# Entity		OrderServiceException		org.broadleafcommerce.core.order.service.exception
# Entity		AddToCartException		org.broadleafcommerce.core.order.service.exception
# Entity		CartOperationProcessContextFactory		org.broadleafcommerce.core.order.service.workflow
# Entity		AbstractCheckAvailabilityActivity		org.broadleafcommerce.core.order.service.workflow
# Entity		CartOperationRequest		org.broadleafcommerce.core.order.service.workflow
# Entity		AbstractValidateAddRequestActivityExtensionHandler		org.broadleafcommerce.core.order.service.workflow.add.extension
# Entity		OrderItemSplitContainer		org.broadleafcommerce.core.order.service.manipulation
# Entity		OrderItemVisitorAdapter		org.broadleafcommerce.core.order.service.manipulation
# Entity		BundleOrderItemSplitContainer		org.broadleafcommerce.core.order.service.manipulation
# Entity		OrderAttributeImpl		org.broadleafcommerce.core.order.domain
# Entity		DiscreteOrderItemImpl		org.broadleafcommerce.core.order.domain
# Entity		GiftWrapOrderItemImpl		org.broadleafcommerce.core.order.domain
# Entity		BundleOrderItemFeePriceImpl		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentOptionImpl		org.broadleafcommerce.core.order.domain
# Entity		TaxType		org.broadleafcommerce.core.order.domain
# Entity		OrderItemAttributeImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderPersistedEvent		org.broadleafcommerce.core.order.domain
# Entity		BundleOrderItemImpl		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentGroupItemImpl		org.broadleafcommerce.core.order.domain
# Entity		TaxDetailImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderImpl		org.broadleafcommerce.core.order.domain
# Entity		PersonalMessageImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderMultishipOptionImpl		org.broadleafcommerce.core.order.domain
# Entity		NullOrderImpl		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentGroupFeeImpl		org.broadleafcommerce.core.order.domain
# Entity		DynamicPriceDiscreteOrderItemImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderPersistedEntityListener		org.broadleafcommerce.core.order.domain
# Entity		FulfillmentGroupImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderLockImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderItemImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderItemQualifierImpl		org.broadleafcommerce.core.order.domain
# Entity		DiscreteOrderItemFeePriceImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderItemPriceDetailImpl		org.broadleafcommerce.core.order.domain
# Entity		OrderItemHolder		org.broadleafcommerce.core.order.domain.dto
# Entity		OptionalEnterpriseBandedPriceFulfillmentOptionTemplate		org.broadleafcommerce.core.order.domain.weave
# Entity		OptionalEnterpriseBandedWeightFulfillmentOptionTemplate		org.broadleafcommerce.core.order.domain.weave
# Entity		NullFulfillmentGroupItemStrategyImpl		org.broadleafcommerce.core.order.strategy
# Entity		AbstractOrderDaoExtensionHandler		org.broadleafcommerce.core.order.dao
# Entity		SolrConfiguration		org.broadleafcommerce.core.search.service.solr
# Entity		SearchContextDTO		org.broadleafcommerce.core.search.service.solr
# Entity		BroadleafCloudSolrClient		org.broadleafcommerce.core.search.service.solr
# Entity		AbstractSolrSearchServiceExtensionHandler		org.broadleafcommerce.core.search.service.solr
# Entity		SolrJSONFacet		org.broadleafcommerce.core.search.service.solr
# Entity		FileSystemSolrIndexStatusProviderImpl		org.broadleafcommerce.core.search.service.solr
# Entity		SolrSearchServiceImpl		org.broadleafcommerce.core.search.service.solr
# Entity		DelegatingHttpSolrClient		org.broadleafcommerce.core.search.service.solr
# Entity		FullReindexCommand		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		IncrementalUpdateCommand		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		CatalogReindexCommand		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		SiteReindexCommand		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		AbstractSolrIndexUpdateServiceImpl		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		SolrUpdateCommand		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		AbstractSolrIndexUpdateCommandHandlerImpl		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		ReindexStateHolder		org.broadleafcommerce.core.search.service.solr.indexer
# Entity		SolrIndexCachedOperation		org.broadleafcommerce.core.search.service.solr.index
# Entity		GlobalSolrFullReIndexOperation		org.broadleafcommerce.core.search.service.solr.index
# Entity		IndexStatusInfoImpl		org.broadleafcommerce.core.search.service.solr.index
# Entity		AbstractSolrIndexServiceExtensionHandler		org.broadleafcommerce.core.search.service.solr.index
# Entity		CategorySearchFacetImpl		org.broadleafcommerce.core.search.domain
# Entity		CategoryExcludedSearchFacetImpl		org.broadleafcommerce.core.search.domain
# Entity		SearchFacetImpl		org.broadleafcommerce.core.search.domain
# Entity		SearchCriteria		org.broadleafcommerce.core.search.domain
# Entity		SearchQuery		org.broadleafcommerce.core.search.domain
# Entity		SearchResult		org.broadleafcommerce.core.search.domain
# Entity		IndexFieldImpl		org.broadleafcommerce.core.search.domain
# Entity		SearchInterceptImpl		org.broadleafcommerce.core.search.domain
# Entity		RequiredFacetImpl		org.broadleafcommerce.core.search.domain
# Entity		SearchFacetRangeImpl		org.broadleafcommerce.core.search.domain
# Entity		SearchFacetResultDTO		org.broadleafcommerce.core.search.domain
# Entity		SearchFacetDTO		org.broadleafcommerce.core.search.domain
# Entity		IndexFieldTypeImpl		org.broadleafcommerce.core.search.domain
# Entity		FieldEntity		org.broadleafcommerce.core.search.domain
# Entity		SearchSynonymImpl		org.broadleafcommerce.core.search.domain
# Entity		FieldImpl		org.broadleafcommerce.core.search.domain
# Entity		FieldType		org.broadleafcommerce.core.search.domain.solr
# Entity		SearchRedirectImpl		org.broadleafcommerce.core.search.redirect.domain
# Entity		ParentCategoryByProduct		org.broadleafcommerce.core.search.dao
# Entity		ProductsByCategoryWithOrder		org.broadleafcommerce.core.search.dao
# Entity		ParentCategoryByCategory		org.broadleafcommerce.core.search.dao
# Entity		CatalogStructure		org.broadleafcommerce.core.search.dao
# Entity		AbstractInventoryServiceExtensionHandler		org.broadleafcommerce.core.inventory.service
# Entity		InventoryUnavailableException		org.broadleafcommerce.core.inventory.service
# Entity		InventoryType		org.broadleafcommerce.core.inventory.service.type
# Entity		AvailabilityStatusType		org.broadleafcommerce.core.inventory.service.type
# Entity		SkuAvailabilityImpl		org.broadleafcommerce.core.inventory.domain
# Entity		UserConnectionImpl		org.broadleafcommerce.core.social.domain
# Entity		CatalogContextDTO		org.broadleafcommerce.core.catalog.service
# Entity		AbstractCatalogServiceExtensionHandler		org.broadleafcommerce.core.catalog.service
# Entity		AbstractProductProcessorExtensionHandler		org.broadleafcommerce.core.catalog.service.extension
# Entity		SkuPricingConsiderationContext		org.broadleafcommerce.core.catalog.service.dynamic
# Entity		DynamicSkuPrices		org.broadleafcommerce.core.catalog.service.dynamic
# Entity		DefaultDynamicSkuPricingInvocationHandler		org.broadleafcommerce.core.catalog.service.dynamic
# Entity		SkuActiveDateConsiderationContext		org.broadleafcommerce.core.catalog.service.dynamic
# Entity		ProductOptionType		org.broadleafcommerce.core.catalog.service.type
# Entity		ProductOptionValidationStrategyType		org.broadleafcommerce.core.catalog.service.type
# Entity		ProductType		org.broadleafcommerce.core.catalog.service.type
# Entity		SkuFeeType		org.broadleafcommerce.core.catalog.service.type
# Entity		ProductOptionValidationType		org.broadleafcommerce.core.catalog.service.type
# Entity		ProductBundlePricingModelType		org.broadleafcommerce.core.catalog.service.type
# Entity		UpSaleProductImpl		org.broadleafcommerce.core.catalog.domain
# Entity		FeaturedProductImpl		org.broadleafcommerce.core.catalog.domain
# Entity		Dimension		org.broadleafcommerce.core.catalog.domain
# Entity		ProductBundleImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuImpl		org.broadleafcommerce.core.catalog.domain
# Entity		ProductOptionImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuBundleItemImpl		org.broadleafcommerce.core.catalog.domain
# Entity		CategoryImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuAttributeImpl		org.broadleafcommerce.core.catalog.domain
# Entity		WeaveSkuMinOrderQuantity		org.broadleafcommerce.core.catalog.domain
# Entity		Weight		org.broadleafcommerce.core.catalog.domain
# Entity		CrossSaleProductImpl		org.broadleafcommerce.core.catalog.domain
# Entity		CategoryAttributeImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuMediaXrefImpl		org.broadleafcommerce.core.catalog.domain
# Entity		CategoryXrefImpl		org.broadleafcommerce.core.catalog.domain
# Entity		WeaveProductSkuUsage		org.broadleafcommerce.core.catalog.domain
# Entity		ProductOptionXrefImpl		org.broadleafcommerce.core.catalog.domain
# Entity		CategoryProductXrefImpl		org.broadleafcommerce.core.catalog.domain
# Entity		ProductOptionValueImpl		org.broadleafcommerce.core.catalog.domain
# Entity		ProductAttributeImpl		org.broadleafcommerce.core.catalog.domain
# Entity		RelatedProductTypeEnum		org.broadleafcommerce.core.catalog.domain
# Entity		ProductImpl		org.broadleafcommerce.core.catalog.domain
# Entity		CategoryMediaXrefImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuProductOptionValueXrefImpl		org.broadleafcommerce.core.catalog.domain
# Entity		RelatedProductDTO		org.broadleafcommerce.core.catalog.domain
# Entity		ProductBundleComparator		org.broadleafcommerce.core.catalog.domain
# Entity		CategorySiteMapGeneratorConfigurationImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuFeeImpl		org.broadleafcommerce.core.catalog.domain
# Entity		SkuPriceWrapper		org.broadleafcommerce.core.catalog.domain.pricing
# Entity		AssignedProductOptionDTO		org.broadleafcommerce.core.catalog.domain.dto
# Entity		AbstractCategoryDaoExtensionHandler		org.broadleafcommerce.core.catalog.dao
# Entity		AbstractProductDaoExtensionHandler		org.broadleafcommerce.core.catalog.dao
# Entity		AbstractSkuDaoExtensionHandler		org.broadleafcommerce.core.catalog.dao
# Entity		BaseExtensionActivity		org.broadleafcommerce.core.workflow
# Entity		ExplicitPrioritySequenceProcessor		org.broadleafcommerce.core.workflow
# Entity		BaseActivity		org.broadleafcommerce.core.workflow
# Entity		PassThroughActivity		org.broadleafcommerce.core.workflow
# Entity		WorkflowException		org.broadleafcommerce.core.workflow
# Entity		EmptySequenceProcessor		org.broadleafcommerce.core.workflow
# Entity		BaseProcessor		org.broadleafcommerce.core.workflow
# Entity		SequenceProcessor		org.broadleafcommerce.core.workflow
# Entity		DefaultProcessContextImpl		org.broadleafcommerce.core.workflow
# Entity		RollbackStateLocal		org.broadleafcommerce.core.workflow.state
# Entity		RollbackFailureException		org.broadleafcommerce.core.workflow.state
# Entity		CustomerStateInterceptor		org.broadleafcommerce.profile.web.site.security
# Entity		SessionFixationProtectionCookie		org.broadleafcommerce.profile.web.site.security
# Entity		AbstractAnonymousCustomerExtensionHandler		org.broadleafcommerce.profile.web.core.security
# Entity		DefaultCustomerMergeExtensionHandler		org.broadleafcommerce.profile.web.core.security
# Entity		CustomerLoggedInEvent		org.broadleafcommerce.profile.web.core.security
# Entity		RestApiCustomerStateFilter		org.broadleafcommerce.profile.web.core.security
# Entity		CustomerAuthenticatedFromCookieEvent		org.broadleafcommerce.profile.web.core.security
# Entity		PhoneNameForm		org.broadleafcommerce.profile.web.core.model
# Entity		RegisterCustomerForm		org.broadleafcommerce.profile.web.core.form
# Entity		EmailClickTrackingFilter		org.broadleafcommerce.profile.web.email
# Entity		EmailOpenTrackingServlet		org.broadleafcommerce.profile.web.email
# Entity		CustomChallengeQuestionEditor		org.broadleafcommerce.profile.web.controller
# Entity		WrappingViewResolver		org.broadleafcommerce.core.web
# Entity		XssRequestWrapper		org.broadleafcommerce.core.web.security
# Entity		AbstractBreadcrumbServiceExtensionHandler		org.broadleafcommerce.core.web.breadcrumbs
# Entity		AbstractUpdateCartServiceExtensionHandler		org.broadleafcommerce.core.web.service
# Entity		AbstractCacheKeyResolverExtensionHandler		org.broadleafcommerce.core.web.service
# Entity		ProcessorUtils		org.broadleafcommerce.core.web.util
# Entity		CookieRuleRequestProcessor		org.broadleafcommerce.core.web.cookie
# Entity		CookieRuleFilter		org.broadleafcommerce.core.web.cookie
# Entity		AbstractLinkedDataGeneratorExtensionHandler		org.broadleafcommerce.core.web.linkeddata.generator
# Entity		AbstractLinkedDataGenerator		org.broadleafcommerce.core.web.linkeddata.generator
# Entity		AbstractCurrencyConversionPricingFilter		org.broadleafcommerce.core.web.money
# Entity		AbstractCartController		org.broadleafcommerce.core.web.controller.cart
# Entity		BroadleafCartController		org.broadleafcommerce.core.web.controller.cart
# Entity		BroadleafPaymentInfoController		org.broadleafcommerce.core.web.controller.checkout
# Entity		BroadleafShippingInfoController		org.broadleafcommerce.core.web.controller.checkout
# Entity		BroadleafOrderConfirmationController		org.broadleafcommerce.core.web.controller.checkout
# Entity		AbstractCheckoutControllerExtensionHandler		org.broadleafcommerce.core.web.controller.checkout
# Entity		BroadleafBillingInfoController		org.broadleafcommerce.core.web.controller.checkout
# Entity		BroadleafCheckoutController		org.broadleafcommerce.core.web.controller.checkout
# Entity		AbstractCheckoutController		org.broadleafcommerce.core.web.controller.checkout
# Entity		AbstractConfirmationControllerExtensionHandler		org.broadleafcommerce.core.web.controller.checkout
# Entity		BroadleafContactUsController		org.broadleafcommerce.core.web.controller.contact
# Entity		ResetPasswordForm		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafUpdateAccountController		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafManageCustomerAddressesController		org.broadleafcommerce.core.web.controller.account
# Entity		ChangePasswordForm		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafSocialRegisterController		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafLoginController		org.broadleafcommerce.core.web.controller.account
# Entity		CustomerAddressForm		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafRegisterController		org.broadleafcommerce.core.web.controller.account
# Entity		AbstractAccountController		org.broadleafcommerce.core.web.controller.account
# Entity		UpdateAccountForm		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafManageCustomerPaymentsController		org.broadleafcommerce.core.web.controller.account
# Entity		AbstractCustomerAddressController		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafChangePasswordController		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafManageWishlistController		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafOrderHistoryController		org.broadleafcommerce.core.web.controller.account
# Entity		BroadleafSearchController		org.broadleafcommerce.core.web.controller.catalog
# Entity		ReviewForm		org.broadleafcommerce.core.web.controller.catalog
# Entity		BroadleafRatingsController		org.broadleafcommerce.core.web.controller.catalog
# Entity		AbstractCatalogController		org.broadleafcommerce.core.web.controller.catalog
# Entity		BroadleafCategoryController		org.broadleafcommerce.core.web.controller.catalog
# Entity		BroadleafSkuController		org.broadleafcommerce.core.web.controller.catalog
# Entity		BroadleafProductController		org.broadleafcommerce.core.web.controller.catalog
# Entity		AbstractSeoPropertyGenerator		org.broadleafcommerce.core.web.seo
# Entity		CheckoutStageType		org.broadleafcommerce.core.web.checkout.stage
# Entity		OrderInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		GiftCardInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		BillingInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		OrderMultishipOptionForm		org.broadleafcommerce.core.web.checkout.model
# Entity		CheckoutForm		org.broadleafcommerce.core.web.checkout.model
# Entity		CustomerCreditInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		MultiShipInstructionForm		org.broadleafcommerce.core.web.checkout.model
# Entity		ShippingInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		CreditCardInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		PaymentInfoForm		org.broadleafcommerce.core.web.checkout.model
# Entity		CheckoutSectionDTO		org.broadleafcommerce.core.web.checkout.section
# Entity		CheckoutSectionViewType		org.broadleafcommerce.core.web.checkout.section
# Entity		CheckoutSectionStateType		org.broadleafcommerce.core.web.checkout.section
# Entity		FrameworkWebProperties		org.broadleafcommerce.core.web.config
# Entity		OrderVariableExpression		org.broadleafcommerce.core.web.expression
# Entity		DatabaseOrderLockManager		org.broadleafcommerce.core.web.order
# Entity		OrderStateAOP		org.broadleafcommerce.core.web.order
# Entity		SessionOrderLockManager		org.broadleafcommerce.core.web.order
# Entity		OrderState		org.broadleafcommerce.core.web.order
# Entity		AbstractCartStateRequestProcessorExtensionHandler		org.broadleafcommerce.core.web.order.security
# Entity		BroadleafAuthenticationSuccessHandler		org.broadleafcommerce.core.web.order.security
# Entity		CartStateInterceptor		org.broadleafcommerce.core.web.order.security
# Entity		AbstractAuthSuccessHandlerExtensionHandler		org.broadleafcommerce.core.web.order.security.extension
# Entity		OrderLockAcquisitionFailureException		org.broadleafcommerce.core.web.order.security.exception
# Entity		SearchFilterUtil		org.broadleafcommerce.core.web.search
# Entity		DynamicSkuPricingInterceptor		org.broadleafcommerce.core.web.catalog
# Entity		ProductHandlerMapping		org.broadleafcommerce.core.web.catalog
# Entity		DefaultDynamicSkuPricingFilter		org.broadleafcommerce.core.web.catalog
# Entity		SkuHandlerMapping		org.broadleafcommerce.core.web.catalog
# Entity		AbstractDynamicSkuPricingFilter		org.broadleafcommerce.core.web.catalog
# Entity		CategoryHandlerMapping		org.broadleafcommerce.core.web.catalog
# Entity		AbstractCommonAddressValidatorExtensionHandler		org.broadleafcommerce.common.web.validator
# Entity		BroadleafCommonAddressValidator		org.broadleafcommerce.common.web.validator
# Entity		AbstractDatabaseResourceResolverExtensionHandler		org.broadleafcommerce.core.web.resolver
# Entity		TimeDTO		org.broadleafcommerce.common
# Entity		RequestDTOImpl		org.broadleafcommerce.common
# Entity		FrameworkXmlBeanDefinitionReader		org.broadleafcommerce.common.extensibility
# Entity		InstrumentationRuntimeFactory		org.broadleafcommerce.common.extensibility
# Entity		MergeXmlBeanDefinitionReader		org.broadleafcommerce.common.extensibility
# Entity		JCacheRegionConfiguration		org.broadleafcommerce.common.extensibility.cache
# Entity		OnEhCacheMissingCondition		org.broadleafcommerce.common.extensibility.cache
# Entity		TimedValueHolder		org.broadleafcommerce.common.extensibility.cache
# Entity		InfiniteExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		NoOpCache		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		NoOpCacheManager		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		OneMinuteExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		OnEhCacheCondition		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		TwentyFourHourExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		TwelveHourExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		DefaultExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		ThirtyMinuteExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		OneHourExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		TenMinuteExpiryPolicy		org.broadleafcommerce.common.extensibility.cache.ehcache
# Entity		MergeJCacheManagerFactoryBean		org.broadleafcommerce.common.extensibility.cache.jcache
# Entity		AbstractRemoveBeanPostProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		ImportProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		EarlyStageRemoveBeanPostProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		AbstractMergeBeanPostProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		MergeManager		org.broadleafcommerce.common.extensibility.context.merge
# Entity		ResourceInputStream		org.broadleafcommerce.common.extensibility.context.merge
# Entity		EarlyStageMergeBeanPostProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		LateStageRemoveBeanPostProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		DynamicResourceIterator		org.broadleafcommerce.common.extensibility.context.merge
# Entity		MergePoint		org.broadleafcommerce.common.extensibility.context.merge
# Entity		MergeXmlConfigResource		org.broadleafcommerce.common.extensibility.context.merge
# Entity		LateStageMergeBeanPostProcessor		org.broadleafcommerce.common.extensibility.context.merge
# Entity		MergeException		org.broadleafcommerce.common.extensibility.context.merge.exceptions
# Entity		MergeManagerSetupException		org.broadleafcommerce.common.extensibility.context.merge.exceptions
# Entity		NodeReplaceInsert		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		NonEmptyNodeReplaceInsert		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		SpaceDelimitedNodeValueMerge		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		SchemaLocationNodeValueMerge		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		NodeValueMerge		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		MergeHandlerAdapter		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		InsertChildrenOf		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		AttributePreserveInsert		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		LiberalNodeReplaceInsert		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		CommaDelimitedNodeValueMerge		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		BaseHandler		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		InsertItems		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		NodeReplace		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		MetadataOverrideNodeReplaceInsert		org.broadleafcommerce.common.extensibility.context.merge.handlers
# Entity		PropertyConfigurer		org.broadleafcommerce.common.extensibility.config
# Entity		JPAPropertiesPersistenceUnitPostProcessor		org.broadleafcommerce.common.extensibility.jpa
# Entity		MergePersistenceUnitManager		org.broadleafcommerce.common.extensibility.jpa
# Entity		AutoDDLCreateStatusTestBeanImpl		org.broadleafcommerce.common.extensibility.jpa
# Entity		QueryConfigurationClassTransformer		org.broadleafcommerce.common.extensibility.jpa
# Entity		EntityClassNotFoundException		org.broadleafcommerce.common.extensibility.jpa
# Entity		MergeJPAPersistenceResource		org.broadleafcommerce.common.extensibility.jpa
# Entity		ConfigurationOnlyState		org.broadleafcommerce.common.extensibility.jpa
# Entity		ORMConfigDto		org.broadleafcommerce.common.extensibility.jpa
# Entity		JCachePersistenceUnitPostProcessor		org.broadleafcommerce.common.extensibility.jpa
# Entity		ORMConfigPersistenceUnitPostProcessor		org.broadleafcommerce.common.extensibility.jpa
# Entity		RemoveCacheClassTransformer		org.broadleafcommerce.common.extensibility.jpa.cache
# Entity		DirectCopyIgnorePattern		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		DirectCopyTransformTypes		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		ConditionalFieldAnnotationsClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		OptionalDirectCopyClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		RemoveAnnotationClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		AnnotationsCopyClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		AbstractClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		NullClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		DirectCopyClassTransformer		org.broadleafcommerce.common.extensibility.jpa.copy
# Entity		AlterTableNameClassTransformer		org.broadleafcommerce.common.extensibility.jpa.convert
# Entity		EntityMarkerClassTransformer		org.broadleafcommerce.common.extensibility.jpa.convert
# Entity		SingleTableInheritanceClassTransformer		org.broadleafcommerce.common.extensibility.jpa.convert.inheritance
# Entity		SingleTableInheritanceInfo		org.broadleafcommerce.common.extensibility.jpa.convert.inheritance
# Entity		AbstractCacheMissAware		org.broadleafcommerce.common.cache
# Entity		NoOpStatisticsServiceLogAdapter		org.broadleafcommerce.common.cache
# Entity		CacheStat		org.broadleafcommerce.common.cache
# Entity		HydratedSetup		org.broadleafcommerce.common.cache
# Entity		Log4j2StatisticsServiceLogAdapter		org.broadleafcommerce.common.cache
# Entity		HydrationDescriptor		org.broadleafcommerce.common.cache.engine
# Entity		EhcacheHydratedCacheManagerImpl		org.broadleafcommerce.common.cache.engine
# Entity		HydrationScanner		org.broadleafcommerce.common.cache.engine
# Entity		EhcacheHydratedCacheEventListener		org.broadleafcommerce.common.cache.engine
# Entity		AbstractHydratedCacheManager		org.broadleafcommerce.common.cache.engine
# Entity		HydrationItemDescriptor		org.broadleafcommerce.common.cache.engine
# Entity		BigMemoryHydratedCacheEventListener		org.broadleafcommerce.common.cache.engine
# Entity		BigMemoryHydratedCacheManagerImpl		org.broadleafcommerce.common.cache.engine
# Entity		EhcacheHydratedCacheJcacheEventListener		org.broadleafcommerce.common.cache.engine
# Entity		CacheFactoryException		org.broadleafcommerce.common.cache.engine
# Entity		BigMemoryHydratedCacheJcacheEventListener		org.broadleafcommerce.common.cache.engine
# Entity		MediaImpl		org.broadleafcommerce.common.media.domain
# Entity		MediaDto		org.broadleafcommerce.common.media.domain
# Entity		AbstractSiteServiceExtensionHandler		org.broadleafcommerce.common.site.service
# Entity		NonPersistentSiteThreadLocalCache		org.broadleafcommerce.common.site.service
# Entity		SiteResolutionType		org.broadleafcommerce.common.site.service.type
# Entity		SiteCatalogXrefImpl		org.broadleafcommerce.common.site.domain
# Entity		SiteImpl		org.broadleafcommerce.common.site.domain
# Entity		CatalogImpl		org.broadleafcommerce.common.site.domain
# Entity		ThemeDTO		org.broadleafcommerce.common.site.domain
# Entity		RandomGenerator		org.broadleafcommerce.common.security
# Entity		BroadleafExternalAuthenticationUserDetails		org.broadleafcommerce.common.security
# Entity		LocalRedirectStrategy		org.broadleafcommerce.common.security
# Entity		BroadleafAuthenticationFailureHandler		org.broadleafcommerce.common.security
# Entity		ProtoInsecureChannelProcessor		org.broadleafcommerce.common.security.channel
# Entity		ProtoChannelBeanPostProcessor		org.broadleafcommerce.common.security.channel
# Entity		ProtoSecureChannelProcessor		org.broadleafcommerce.common.security.channel
# Entity		CleanStringException		org.broadleafcommerce.common.security.service
# Entity		StaleStateServiceException		org.broadleafcommerce.common.security.service
# Entity		ServerCookie		org.broadleafcommerce.common.security.util
# Entity		PasswordChange		org.broadleafcommerce.common.security.util
# Entity		PasswordReset		org.broadleafcommerce.common.security.util
# Entity		PasswordUtils		org.broadleafcommerce.common.security.util
# Entity		BroadleafActiveDirectoryUserDetailsMapper		org.broadleafcommerce.common.security.ldap
# Entity		SecurityFilter		org.broadleafcommerce.common.security.handler
# Entity		CsrfFilter		org.broadleafcommerce.common.security.handler
# Entity		NullBroadleafEnumerationType		org.broadleafcommerce.common.presentation
# Entity		RuleIdentifier		org.broadleafcommerce.common.presentation
# Entity		RuleOperatorType		org.broadleafcommerce.common.presentation
# Entity		RuleOptionType		org.broadleafcommerce.common.presentation
# Entity		DynamicSupportedFieldType		org.broadleafcommerce.common.presentation.client
# Entity		PropertyType		org.broadleafcommerce.common.presentation.override
# Entity		FileServiceException		org.broadleafcommerce.common.file
# Entity		GloballySharedInputStream		org.broadleafcommerce.common.file.service
# Entity		BroadleafFileUtils		org.broadleafcommerce.common.file.service
# Entity		FileApplicationType		org.broadleafcommerce.common.file.service.type
# Entity		FileWorkArea		org.broadleafcommerce.common.file.domain
# Entity		Auditable		org.broadleafcommerce.common.audit
# Entity		AuditableListener		org.broadleafcommerce.common.audit
# Entity		AbstractAuditableListener		org.broadleafcommerce.common.audit
# Entity		MetadataMBeanInfoAssembler		org.broadleafcommerce.common.jmx
# Entity		ExplicitNameFactoryBean		org.broadleafcommerce.common.jmx
# Entity		AnnotationJmxAttributeSource		org.broadleafcommerce.common.jmx
# Entity		MetadataNamingStrategy		org.broadleafcommerce.common.jmx
# Entity		AspectUtil		org.broadleafcommerce.common.jmx
# Entity		SupportLogger		org.broadleafcommerce.common.logging
# Entity		SystemSupportLoggerAdapter		org.broadleafcommerce.common.logging
# Entity		Log4j2ManagementBean		org.broadleafcommerce.common.logging
# Entity		AbstractSupportLoggerAdapter		org.broadleafcommerce.common.logging
# Entity		SLF4JSupportLoggerAdapter		org.broadleafcommerce.common.logging
# Entity		Log4jManagementBean		org.broadleafcommerce.common.logging
# Entity		DisableSupportLoggerAdapter		org.broadleafcommerce.common.logging
# Entity		SupportLogManager		org.broadleafcommerce.common.logging
# Entity		ModuleLifecycleLoggingBean		org.broadleafcommerce.common.logging
# Entity		ProcessDetailLogger		org.broadleafcommerce.common.logging
# Entity		ThreadLocalManager		org.broadleafcommerce.common.classloader.release
# Entity		TemplateType		org.broadleafcommerce.common.template
# Entity		AbstractTemplateOverrideExtensionHandler		org.broadleafcommerce.common.template
# Entity		LocaleUtil		org.broadleafcommerce.common.locale.util
# Entity		LocaleConverter		org.broadleafcommerce.common.locale.util
# Entity		LocaleImpl		org.broadleafcommerce.common.locale.domain
# Entity		BreadcrumbHandlerDefaultPriorities		org.broadleafcommerce.common.breadcrumbs.service
# Entity		BreadcrumbDTO		org.broadleafcommerce.common.breadcrumbs.dto
# Entity		BreadcrumbDTOType		org.broadleafcommerce.common.breadcrumbs.dto
# Entity		ExtensionManager		org.broadleafcommerce.common.extension
# Entity		ExtensionResultHolder		org.broadleafcommerce.common.extension
# Entity		AbstractExtensionHandler		org.broadleafcommerce.common.extension
# Entity		StandardCacheItem		org.broadleafcommerce.common.extension
# Entity		FilterDefinition		org.broadleafcommerce.common.filter
# Entity		Filter		org.broadleafcommerce.common.filter
# Entity		FilterParameter		org.broadleafcommerce.common.filter
# Entity		PropertyFilter		org.broadleafcommerce.common.filter
# Entity		CreateResponse		org.broadleafcommerce.common.copy
# Entity		MultiTenantCopier		org.broadleafcommerce.common.copy
# Entity		MultiTenantCopyContext		org.broadleafcommerce.common.copy
# Entity		AbstractMultiTenantCopierExtensionHandler		org.broadleafcommerce.common.copy
# Entity		GenericResponse		org.broadleafcommerce.common.service
# Entity		ReflectiveWorkOnChange		org.broadleafcommerce.common.util
# Entity		StatCalc		org.broadleafcommerce.common.util
# Entity		EnvironmentFactoryBean		org.broadleafcommerce.common.util
# Entity		BLCFileSystemUtils		org.broadleafcommerce.common.util
# Entity		Tuple		org.broadleafcommerce.common.util
# Entity		InvocationHandlerForUnitTestingByteWeavedClasses		org.broadleafcommerce.common.util
# Entity		TableCreator		org.broadleafcommerce.common.util
# Entity		GenericOperationUtil		org.broadleafcommerce.common.util
# ...
# Interface	SiteConfigProvider		org.broadleafcommerce.common.site.service.provider
# Interface	SiteAdminPresentation		org.broadleafcommerce.common.site.domain
# Interface	SiteCatalogXref		org.broadleafcommerce.common.site.domain
# Interface	Catalog		org.broadleafcommerce.common.site.domain
# Interface	Site		org.broadleafcommerce.common.site.domain
# Interface	Theme		org.broadleafcommerce.common.site.domain
# Interface	SiteDao		org.broadleafcommerce.common.site.dao
# Interface	MergeCartProcessor		org.broadleafcommerce.common.security
# Interface	StaleStateProtectionService		org.broadleafcommerce.common.security.service
# Interface	ExploitProtectionService		org.broadleafcommerce.common.security.service
# Interface	CookieUtils		org.broadleafcommerce.common.security.util
# Interface	BroadleafStaticAssetExtensionHandler		org.broadleafcommerce.common.file.service
# Interface	FileServiceProvider		org.broadleafcommerce.common.file.service
# Interface	BroadleafFileService		org.broadleafcommerce.common.file.service
# Interface	BroadleafFileServiceExtensionHandler		org.broadleafcommerce.common.file.service
# Interface	StaticAssetPathService		org.broadleafcommerce.common.file.service
# Interface	CrossAppAuditable		org.broadleafcommerce.common.audit
# Interface	SupportLoggerAdapter		org.broadleafcommerce.common.logging
# Interface	TemplateOverrideExtensionHandler		org.broadleafcommerce.common.template
# Interface	TemplatePathContainer		org.broadleafcommerce.common.template
# Interface	LocaleService		org.broadleafcommerce.common.locale.service
# Interface	Locale		org.broadleafcommerce.common.locale.domain
# Interface	LocaleDao		org.broadleafcommerce.common.locale.dao
# Interface	BreadcrumbServiceExtensionHandler		org.broadleafcommerce.common.breadcrumbs.service
# Interface	BreadcrumbService		org.broadleafcommerce.common.breadcrumbs.service
# Interface	QueryExtensionHandler		org.broadleafcommerce.common.extension
# Interface	ExtensionHandler		org.broadleafcommerce.common.extension
# Interface	ExtensionManagerOperation		org.broadleafcommerce.common.extension
# Interface	SparselyPopulatedQueryExtensionHandler		org.broadleafcommerce.common.extension
# Interface	TemplateCacheExtensionHandler		org.broadleafcommerce.common.extension
# Interface	TemplateOnlyQueryExtensionHandler		org.broadleafcommerce.common.extension
# Interface	NativeMethodEntityExtensionHandler		org.broadleafcommerce.common.extension
# Interface	MultiTenantCopierExtensionHandler		org.broadleafcommerce.common.copy
# Interface	DeferredOperation		org.broadleafcommerce.common.copy
# Interface	MultiTenantCloneable		org.broadleafcommerce.common.copy
# Interface	CopyOperation		org.broadleafcommerce.common.copy
# Interface	PersistenceService		org.broadleafcommerce.common.service
# Interface	GenericEntityService		org.broadleafcommerce.common.service
# Interface	ParentCategoryLegacyModeService		org.broadleafcommerce.common.service
# Interface	TypedClosure		org.broadleafcommerce.common.util
# Interface	TypedTransformer		org.broadleafcommerce.common.util
# Interface	GenericOperation		org.broadleafcommerce.common.util
# Interface	StreamingTransactionCapable		org.broadleafcommerce.common.util
# Interface	BroadleafMergeResourceExtensionHandler		org.broadleafcommerce.common.util
# Interface	TransactionalOperation		org.broadleafcommerce.common.util
# Interface	Wrappable		org.broadleafcommerce.common.util
# Interface	WorkOnChange		org.broadleafcommerce.common.util
# Interface	StreamCapableTransactionalOperation		org.broadleafcommerce.common.util
# Interface	IdentityOperation		org.broadleafcommerce.common.util.tenant
# Interface	DynamicDaoHelper		org.broadleafcommerce.common.util.dao
# Interface	AdditionalFields		org.broadleafcommerce.common.domain
# Interface	ValueAssignable		org.broadleafcommerce.common.value
# Interface	PaymentGatewayConfiguration		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayFraudService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayConfigurationServiceProvider		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayWebResponseService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayCreditCardService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayTransactionService		org.broadleafcommerce.common.payment.service
# Interface	CurrentCustomerPaymentRequestService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayConfigurationService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayResolver		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewaySubscriptionService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayCheckoutService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayTamperProofSealService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayHostedService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayRollbackService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayReportingService		org.broadleafcommerce.common.payment.service
# Interface	CurrentOrderPaymentRequestService		org.broadleafcommerce.common.payment.service
# Interface	CustomerPaymentGatewayService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayClientTokenService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayCustomerService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayWebResponsePrintService		org.broadleafcommerce.common.payment.service
# Interface	FailureCountExposable		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayTransparentRedirectService		org.broadleafcommerce.common.payment.service
# Interface	PaymentGatewayTransactionConfirmationService		org.broadleafcommerce.common.payment.service
# Interface	CurrencyDeterminationService		org.broadleafcommerce.common.money
# Interface	CurrencyConversionService		org.broadleafcommerce.common.money
# Interface	EmailService		org.broadleafcommerce.common.email.service
# Interface	EmailTrackingManager		org.broadleafcommerce.common.email.service
# Interface	JMSEmailServiceProducer		org.broadleafcommerce.common.email.service.jms
# Interface	EmailServiceProducer		org.broadleafcommerce.common.email.service.message
# Interface	EmailTracking		org.broadleafcommerce.common.email.domain
# Interface	EmailTrackingOpens		org.broadleafcommerce.common.email.domain
# Interface	EmailTrackingClicks		org.broadleafcommerce.common.email.domain
# Interface	EmailTarget		org.broadleafcommerce.common.email.domain
# Interface	EmailReportingDao		org.broadleafcommerce.common.email.dao
# Interface	SMSMessageCreator		org.broadleafcommerce.common.sms.service
# Interface	DataDrivenEnumerationService		org.broadleafcommerce.common.enumeration.service
# Interface	DataDrivenEnumeration		org.broadleafcommerce.common.enumeration.domain
# Interface	DataDrivenEnumerationValue		org.broadleafcommerce.common.enumeration.domain
# Interface	DataDrivenEnumerationDao		org.broadleafcommerce.common.enumeration.dao
# Interface	QuantityBasedRule		org.broadleafcommerce.common.rule
# Interface	SimpleRule		org.broadleafcommerce.common.rule
# Interface	RuleProcessor		org.broadleafcommerce.common.rule
# Interface	TimeSource		org.broadleafcommerce.common.time
# Interface	BroadleafSharedOverrideProfileAwarePropertySource		org.broadleafcommerce.common.config
# Interface	FrameworkCommonClasspathPropertySource		org.broadleafcommerce.common.config
# Interface	SystemPropertyServiceExtensionHandler		org.broadleafcommerce.common.config.service
# Interface	ModuleConfigurationService		org.broadleafcommerce.common.config.service
# Interface	SystemPropertiesService		org.broadleafcommerce.common.config.service
# Interface	ModuleProvider		org.broadleafcommerce.common.config.service
# Interface	SystemPropertyAdminPresentation		org.broadleafcommerce.common.config.domain
# Interface	AbstractModuleConfigurationAdminPresentation		org.broadleafcommerce.common.config.domain
# Interface	ModuleConfiguration		org.broadleafcommerce.common.config.domain
# Interface	SystemProperty		org.broadleafcommerce.common.config.domain
# Interface	SystemPropertiesDao		org.broadleafcommerce.common.config.dao
# Interface	ModuleConfigurationDao		org.broadleafcommerce.common.config.dao
# Interface	ConditionalDirectCopyTransformersManager		org.broadleafcommerce.common.weave
# Interface	ConditionalFieldAnnotationCopyTransformersManager		org.broadleafcommerce.common.weave
# Interface	IdGenerationService		org.broadleafcommerce.common.id.service
# Interface	IdGeneration		org.broadleafcommerce.common.id.domain
# Interface	IdGenerationDao		org.broadleafcommerce.common.id.dao
# Interface	StatusHandler		org.broadleafcommerce.common.vendor.service.monitor
# Interface	ServiceStatusDetectable		org.broadleafcommerce.common.vendor.service.monitor
# Interface	CacheRequest		org.broadleafcommerce.common.vendor.service.cache
# Interface	ServiceResponseCacheable		org.broadleafcommerce.common.vendor.service.cache
# Interface	CacheItemRequest		org.broadleafcommerce.common.vendor.service.cache
# Interface	CacheResponse		org.broadleafcommerce.common.vendor.service.cache
# Interface	TaxResponse		org.broadleafcommerce.common.vendor.service.message
# Interface	FulfillmentPriceExceptionResponse		org.broadleafcommerce.common.vendor.service.message
# Interface	BroadleafCurrencyService		org.broadleafcommerce.common.currency.service
# Interface	CurrencyCodeIdentifiable		org.broadleafcommerce.common.currency.util
# Interface	BroadleafCurrency		org.broadleafcommerce.common.currency.domain
# Interface	BroadleafCurrencyDao		org.broadleafcommerce.common.currency.dao
# Interface	EntityDuplicatorExtensionHandler		org.broadleafcommerce.common.persistence
# Interface	EntityDuplicationHelper		org.broadleafcommerce.common.persistence
# Interface	Previewable		org.broadleafcommerce.common.persistence
# Interface	EntityDuplicator		org.broadleafcommerce.common.persistence
# Interface	QueryHelper		org.broadleafcommerce.common.persistence
# Interface	PostLoaderDao		org.broadleafcommerce.common.persistence
# Interface	EntityParentIdServiceExtensionHandler		org.broadleafcommerce.common.persistence
# Interface	EntityDuplicateModifier		org.broadleafcommerce.common.persistence
# Interface	Status		org.broadleafcommerce.common.persistence
# Interface	SqlStatementLoggable		org.broadleafcommerce.common.persistence.transaction
# Interface	TransactionInfoCustomModifier		org.broadleafcommerce.common.persistence.transaction
# Interface	SiteMapService		org.broadleafcommerce.common.sitemap.service
# Interface	SiteMapGenerator		org.broadleafcommerce.common.sitemap.service
# Interface	CustomUrlSiteMapGeneratorConfiguration		org.broadleafcommerce.common.sitemap.domain
# Interface	SiteMapGeneratorConfiguration		org.broadleafcommerce.common.sitemap.domain
# Interface	SiteMapUrlEntry		org.broadleafcommerce.common.sitemap.domain
# Interface	SiteMapConfiguration		org.broadleafcommerce.common.sitemap.domain
# Interface	SandBoxHelper		org.broadleafcommerce.common.sandbox
# Interface	SandBoxNonProductionSkip		org.broadleafcommerce.common.sandbox
# Interface	ProductionOnlyRequest		org.broadleafcommerce.common.sandbox
# Interface	SandBoxService		org.broadleafcommerce.common.sandbox.service
# Interface	SandBoxManagement		org.broadleafcommerce.common.sandbox.domain
# Interface	SandboxAdminPresentation		org.broadleafcommerce.common.sandbox.domain
# Interface	SandBox		org.broadleafcommerce.common.sandbox.domain
# Interface	SandBoxDao		org.broadleafcommerce.common.sandbox.dao
# Interface	ResourceMinificationService		org.broadleafcommerce.common.resource.service
# Interface	CssMinificationService		org.broadleafcommerce.common.resource.service
# Interface	ResourceBundlingService		org.broadleafcommerce.common.resource.service
# Interface	JavascriptMinificationService		org.broadleafcommerce.common.resource.service
# Interface	EntityInformationService		org.broadleafcommerce.common.entity.service
# Interface	EntityInformationServiceExtensionHandler		org.broadleafcommerce.common.entity.service
# Interface	APIUnwrapper		org.broadleafcommerce.common.rest.api.wrapper
# Interface	WrapperAdditionalFields		org.broadleafcommerce.common.rest.api.wrapper
# Interface	APIWrapper		org.broadleafcommerce.common.rest.api.wrapper
# Interface	CrossAppAdminAuthService		org.broadleafcommerce.common.crossapp.service
# Interface	CrossAppAuthService		org.broadleafcommerce.common.crossapp.service
# Interface	EncryptionModule		org.broadleafcommerce.common.encryption
# Interface	AtomicMove		org.broadleafcommerce.common.io
# Interface	ConcurrentFileOutputStream		org.broadleafcommerce.common.io
# Interface	BroadleafApplicationEventPublisher		org.broadleafcommerce.common.event
# Interface	BroadleafApplicationListener		org.broadleafcommerce.common.event
# Interface	TranslationSupport		org.broadleafcommerce.common.i18n.service
# Interface	ISOService		org.broadleafcommerce.common.i18n.service
# Interface	TranslationService		org.broadleafcommerce.common.i18n.service
# Interface	TranslationOverrideStrategy		org.broadleafcommerce.common.i18n.service
# Interface	ISOCountry		org.broadleafcommerce.common.i18n.domain
# Interface	Translation		org.broadleafcommerce.common.i18n.domain
# Interface	ISODao		org.broadleafcommerce.common.i18n.dao
# Interface	TranslationDaoExtensionHandler		org.broadleafcommerce.common.i18n.dao
# Interface	TranslationDao		org.broadleafcommerce.common.i18n.dao
# Interface	BroadleafExpressionParser		org.broadleafcommerce.common.expression
# Interface	NotificationService		org.broadleafcommerce.common.notification.service
# Interface	NotificationDispatcher		org.broadleafcommerce.common.notification.service
# Interface	Locatable		org.broadleafcommerce.common.web
# Interface	BroadleafThemeResolver		org.broadleafcommerce.common.web
# Interface	BroadleafTimeZoneResolver		org.broadleafcommerce.common.web
# Interface	TemplateTypeAware		org.broadleafcommerce.common.web
# Interface	BroadleafSiteResolver		org.broadleafcommerce.common.web
# Interface	BroadleafCurrencyResolver		org.broadleafcommerce.common.web
# Interface	BroadleafLocaleResolver		org.broadleafcommerce.common.web
# Interface	BaseUrlResolver		org.broadleafcommerce.common.web
# Interface	BroadleafSandBoxResolver		org.broadleafcommerce.common.web
# Interface	BroadleafRequestCustomerResolver		org.broadleafcommerce.common.web
# Interface	BroadleafWebRequestProcessor		org.broadleafcommerce.common.web
# Interface	BroadleafTemplateViewResolverExtensionHandler		org.broadleafcommerce.common.web
# Interface	BLCICacheExtensionHandler		org.broadleafcommerce.common.web.cache
# Interface	CreditCardTypesExtensionHandler		org.broadleafcommerce.common.web.payment.processor
# Interface	TRCreditCardExtensionHandler		org.broadleafcommerce.common.web.payment.processor
# Interface	PaymentGatewayFieldExtensionHandler		org.broadleafcommerce.common.web.payment.expression
# Interface	ResourceRequestExtensionHandler		org.broadleafcommerce.common.web.resource
# Interface	BroadleafVariableExpression		org.broadleafcommerce.common.web.expression
# Interface	BroadleafModuleRegistration		org.broadleafcommerce.common.module
# Interface	TypedEntity		org.broadleafcommerce.common.admin.domain
# Interface	AdminMainEntity		org.broadleafcommerce.common.admin.domain
# Interface	RootCauseAccessor		org.broadleafcommerce.common.exception
# Interface	GenericEntityDao		org.broadleafcommerce.common.dao
# Excluded	ImportSQLConfig		org.broadleafcommerce.profile.core.demo
# Excluded	ProfileConfig		org.broadleafcommerce.profile.core.config
# Excluded	ImportSQLConfig		org.broadleafcommerce.core.demo
# Excluded	FrameworkConfig		org.broadleafcommerce.core.config
# Excluded	FrameworkCacheConfiguration		org.broadleafcommerce.core.config
# Excluded	ProfileWebConfig		org.broadleafcommerce.profile.web.core.config
# Excluded	FrameworkWebConfig		org.broadleafcommerce.core.web.config
# Excluded	ImportSQLConfig		org.broadleafcommerce.common.demo
# Excluded	BroadleafCommonConfig		org.broadleafcommerce.common.config
# Excluded	CommonCacheConfiguration		org.broadleafcommerce.common.config
# Excluded	BroadleafSiteServletConfig		org.broadleafcommerce.common.web.config
# Excluded	FileUploadExceptionAdvice		org.broadleafcommerce.common.exception

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')
# Out:
# WARNING: AddressVerificationProviderinterface does not have an implementing class!
# WARNING: Processorinterface does not have an implementing class!
# WARNING: TaxProviderinterface does not have an implementing class!
# WARNING: TaxProviderinterface does not have an implementing class!
# WARNING: TaxModuleinterface does not have an implementing class!
# WARNING: GeolocationAPIinterface does not have an implementing class!
# WARNING: Processorinterface does not have an implementing class!
# WARNING: Processorinterface does not have an implementing class!
# WARNING: Processorinterface does not have an implementing class!
# WARNING: Processorinterface does not have an implementing class!
# WARNING: Processorinterface does not have an implementing class!
# WARNING: EncryptionModuleinterface does not have an implementing class!
# WARNING: EncryptionModuleinterface does not have an implementing class!
# WARNING: BroadleafWebRequestProcessorinterface does not have an implementing class!
# WARNING: BroadleafWebRequestProcessorinterface does not have an implementing class!
# WARNING: BroadleafWebRequestProcessorinterface does not have an implementing class!
# WARNING: BroadleafWebRequestProcessorinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: BaseUrlResolverinterface does not have an implementing class!
# WARNING: BaseUrlResolverinterface does not have an implementing class!
# WARNING: InventoryServiceinterface does not have an implementing class!
# WARNING: InventoryServiceinterface does not have an implementing class!
# WARNING: CrossAppAuthServiceinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: OrderLockManagerinterface does not have an implementing class!
# WARNING: EmailServiceProducerinterface does not have an implementing class!
# WARNING: BaseUrlResolverinterface does not have an implementing class!
# WARNING: DynamicDaoHelperinterface does not have an implementing class!
# WARNING: DynamicDaoHelperinterface does not have an implementing class!
# WARNING: BroadleafThemeResolverinterface does not have an implementing class!
# WARNING: CrossAppAuthServiceinterface does not have an implementing class!
# WARNING: CrossAppAuthServiceinterface does not have an implementing class!
# WARNING: BroadleafSiteResolverinterface does not have an implementing class!
# WARNING: BroadleafThemeResolverinterface does not have an implementing class!
# WARNING: BaseUrlResolverinterface does not have an implementing class!
# WARNING: AtomicMoveinterface does not have an implementing class!
# WARNING: BroadleafSiteResolverinterface does not have an implementing class!
# WARNING: BroadleafThemeResolverinterface does not have an implementing class!
# WARNING: BaseUrlResolverinterface does not have an implementing class!
# WARNING: CrossAppAuthServiceinterface does not have an implementing class!
# WARNING: CrossAppAuthServiceinterface does not have an implementing class!
# WARNING: DynamicDaoHelperinterface does not have an implementing class!

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['loadUserByUsername(UserDetailsServiceImpl)', 'Calls', 'isAssignableFrom(UserDetailsServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addPostRegisterListener(CustomerServiceImpl)', 'Calls', 'add(MergeOrdersByEmailPostRegistrationObserver)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removePostRegisterListener(CustomerServiceImpl)', 'Calls', 'contains(MergeOrdersByEmailPostRegistrationObserver)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removePostRegisterListener(CustomerServiceImpl)', 'Calls', 'remove(MergeOrdersByEmailPostRegistrationObserver)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['notifyPostRegisterListeners(CustomerServiceImpl)', 'Calls', 'iterator(MergeOrdersByEmailPostRegistrationObserver)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findNextCustomerId(CustomerServiceImpl)', 'Calls', 'getCanonicalName(CustomerServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(OfferActivity)', 'Calls', 'getProxy(OfferValueModifierExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUnitAmount(FulfillmentItemPricingActivity)', 'Calls', 'divide(FulfillmentItemPricingActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['purgeCarts(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['notifyCarts(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['purgeOrderHistory(ResourcePurgeServiceImpl)', 'Calls', 'getProxy(ResourcePurgeExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['purgeOrderHistory(ResourcePurgeServiceImpl)', 'Calls', 'getProxy(ResourcePurgeExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['purgeCustomers(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'referencedColumnName(DeleteStatementGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'name(DeleteStatementGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isAddOnOrderItem(OfferServiceUtilitiesImpl)', 'Calls', 'isAssignableFrom(OfferServiceUtilitiesImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildOfferListForOrder(OfferServiceImpl)', 'Calls', 'getProxy(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAndSaveOffersToOrder(OfferServiceImpl)', 'Calls', 'filterOffers(OrderOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAndSaveFulfillmentGroupOffersToOrder(OfferServiceImpl)', 'Calls', 'filterOffers(OrderOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getOffersRetrievedFromCodes(OfferServiceImpl)', 'Calls', 'getProxy(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['canHandle(OfferDuplicateModifier)', 'Calls', 'isAssignableFrom(OfferDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyInitialDuplicateState(OfferDuplicateModifier)', 'Calls', 'getCopySuffix(OfferDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAdditionalFilters(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildOfferCodeListForCustomer(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['calculatePotentialSavings(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resetPriceDetails(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyItemOffer(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['synchronizeAdjustmentsAndPrices(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['chooseSaleOrRetailAdjustments(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrderItemPriceDetailAdjustment(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAdditionalRuleVariablesForItemOfferEvaluation(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addAdditionalOffersForCode(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeOfferCodeFromOrder(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(FulfillmentGroupOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(FulfillmentGroupOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(FulfillmentGroupOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(FulfillmentGroupOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['couldOfferApplyToFulfillmentGroup(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'executeExpression(FulfillmentGroupOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyItemQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'splitDetailsIfNecessary(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterOffers(ItemOfferProcessorImpl)', 'Calls', 'filterOrderLevelOffer(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['markQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'finalizeQuantities(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['markQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'clearAllNonFinalizedQuantities(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'applyAllOrderOffers(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'applyAllOrderOffers(ItemOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterOrderLevelOffer(OrderOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(OrderOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['couldOfferApplyToOrder(OrderOfferProcessorImpl)', 'Calls', 'executeExpression(OrderOfferProcessorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translateOrder(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderId(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'paymentType(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'transactionTotal(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderSubtotal(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'shippingTotal(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'taxTotal(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderCurrencyCode(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderId(OrderToPaymentRequestDTOServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['performCheckout(CheckoutServiceImpl)', 'Calls', 'doActivities(CheckoutSeed)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'rawResponse(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'successful(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'paymentTransactionType(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'amount(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'rawResponse(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'successful(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'paymentTransactionType(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'amount(PassthroughPaymentRollbackServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getRollbackHandler(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getAutomaticallyRegisterRollbackHandler(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getRollbackHandler(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getAutomaticallyRegisterRollbackHandler(DecrementInventoryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['determineOrderNumber(CompleteOrderActivity)', 'Calls', 'format(CompleteOrderActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(ValidateCheckoutActivity)', 'Calls', 'getProxy(ValidateCheckoutActivityExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processRegistrationEvent(MergeOrdersByEmailPostRegistrationObserver)', 'Calls', 'getHandlers(PostUpdateOrderExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['processRegistrationEvent(MergeOrdersByEmailPostRegistrationObserver)', 'Calls', 'shouldContinue(PostUpdateOrderExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createNamedOrderForCustomer(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['save(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addOfferCodes(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preValidateCartOperation(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preValidateUpdateQuantityOperation(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'isEnabled(CartMessageOrderItemServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'registerHandler(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['gatherProductCartMessages(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'isAssignableFrom(CartMessageOrderItemServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildOrderItemRequestDTOFromOrderItem(OrderItemServiceImpl)', 'Calls', 'append(OrderItemServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildOrderItemRequestDTOFromOrderItem(OrderItemServiceImpl)', 'Calls', 'toComparison(OrderItemServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['priceOrderItem(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['applyAdditionalOrderItemProperties(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyOrderItemRequest(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['mergeOrderItemRequest(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setNewCartOwnership(MergeCartServiceImpl)', 'Calls', 'getProxy(MergeCartServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachAdditionalDataToNewNamedCart(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preValidateCartOperation(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preValidateUpdateQuantityOperation(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachAdditionalDataToOrder(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addOfferCodes(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findCartForCustomerWithEnhancements(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(CheckAddAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckAddAvailabilityActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(CheckUpdateAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckUpdateAvailabilityActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(CheckUpdateAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckUpdateAvailabilityActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(AddWorkflowPriceOrderIfNecessaryActivity)', 'Calls', 'intValue(AddWorkflowPriceOrderIfNecessaryActivity)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(ValidateAddRequestActivity)', 'Calls', 'getProxy(ValidateAddRequestActivityExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['execute(ValidateAddRequestActivity)', 'Calls', 'getProxy(ValidateAddRequestActivityExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resolveJSONFacetResponse(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resolveJSONFacet(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['resolveJSONFacet(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategoryIds(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'replace(MvelToSearchCriteriaConversionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['convertRuleToFilters(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'equals(MvelToSearchCriteriaConversionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['convertFieldName(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'length(MvelToSearchCriteriaConversionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseMethod(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'replaceFirst(MvelToSearchCriteriaConversionServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['swapActiveCores(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['swapActiveCores(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyNameForIndexField(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategoryId(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getIndexableId(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCurrentProductId(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getProductForIndexable(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'toString(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setFacetResults(SolrHelperServiceImpl)', 'Calls', 'intValue(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setFacetResults(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachFacets(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachFacets(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachSortClause(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSortOrder(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSortOrder(SolrHelperServiceImpl)', 'Calls', 'equals(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'contains(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'substring(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'indexOf(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'indexOf(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'equals(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyPropertyToCollection(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyPropertyToCollection(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSearchableIndexFields(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCategoryFilterIds(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(I18nSolrSearchServiceExtensionHandler)', 'Calls', 'getHandlers(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(I18nSolrSearchServiceExtensionHandler)', 'Calls', 'getHandlers(SolrSearchServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildDocument(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachIndexableDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachAdditionalDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachBasicDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getNamespace(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachBasicDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyValues(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(I18nSolrIndexServiceExtensionHandler)', 'Calls', 'registerHandler(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['startBatchEvent(I18nSolrIndexServiceExtensionHandler)', 'Calls', 'isAssignableFrom(I18nSolrIndexServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['afterPropertiesSet(SolrIndexServiceImpl)', 'Calls', 'isSiteCollections(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['preBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'isSingleCoreMode(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getReindexOperation(SolrIndexServiceImpl)', 'Calls', 'getSolrCollectionForIndexing(SolrIndexServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getReindexOperation(SolrIndexServiceImpl)', 'Calls', 'getSolrServerForIndexing(SolrIndexServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAllReindexCoreDocuments(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteAllReindexCoreDocuments(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['buildDocument(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachIndexableDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachAdditionalDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachBasicDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getNamespace(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['attachBasicDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPropertyValues(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['convertToMappedProperty(SolrIndexServiceImpl)', 'Calls', 'equals(SolrIndexServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteByQuery(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteByQuery(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addDocuments(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['retrieveQuantitiesAvailable(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['decrementInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['incrementInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['reconcileChangeOrderInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addSiteMapEntries(CategorySiteMapGenerator)', 'Calls', 'isAssignableFrom(CategorySiteMapGenerator)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['canHandle(ProductDuplicateModifier)', 'Calls', 'isAssignableFrom(ProductDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'equalsIgnoreCase(ProductDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'getName(ProductDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'getName(ProductDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setNameAndUrl(ProductDuplicateModifier)', 'Calls', 'getCopySuffix(ProductDuplicateModifier)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setNameAndUrl(ProductDuplicateModifier)', 'Calls', 'getProxy(ProductUrlDuplicatorExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findCategoryByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findProductByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['findSkuByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doFilterInternalUnlessIgnored(CustomerStateFilter)', 'Calls', 'postProcess(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'equals(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'equals(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['copyAnonymousCustomerInfoToCustomer(CustomerStateRequestProcessor)', 'Calls', 'getProxy(CustomerMergeExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAnonymousCustomer(CustomerStateRequestProcessor)', 'Calls', 'getProxy(AnonymousCustomerExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(SimpleSearchBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyBreadcrumbList(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'buildLink(SimpleSearchBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateContextMap(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'equals(SimpleSearchBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(CategoryBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(CategoryBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(CategoryBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(ProductBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['modifyBreadcrumbList(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'buildLink(ProductBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(HomePageBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(HomePageBreadcrumbServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(HomePageBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['validateAddToCartRequest(UpdateCartServiceImpl)', 'Calls', 'getProxy(UpdateCartServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateAndValidateCart(UpdateCartServiceImpl)', 'Calls', 'getProxy(UpdateCartServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(i18nUpdateCartServiceExtensionHandler)', 'Calls', 'isEnabled(i18nUpdateCartServiceExtensionHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(i18nUpdateCartServiceExtensionHandler)', 'Calls', 'getHandlers(UpdateCartServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doFilterInternalUnlessIgnored(GeolocationFilter)', 'Calls', 'postProcess(GeolocationRequestProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(DefaultLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getRequestUri(DefaultLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getRequestParams(DefaultLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(DefaultLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addOrganizationData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(HomepageLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addOrganizationData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addWebSiteData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getLogoUrl(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addPotentialActions(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['init(DefaultLinkedDataGeneratorExtensionHandler)', 'Calls', 'registerHandler(LinkedDataGeneratorExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getLinkedDataJsonInternal(CategoryLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(CategoryLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addReviewData(ProductLinkedDataGeneratorImpl)', 'Calls', 'put(ProductLinkedDataGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterForSeoProperties(BasicSeoPropertyGeneratorImpl)', 'Calls', 'equals(BasicSeoPropertyGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['filterForSeoProperties(BasicSeoPropertyGeneratorImpl)', 'Calls', 'equals(BasicSeoPropertyGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['gatherSeoProperties(BasicSeoPropertyGeneratorImpl)', 'Calls', 'getSimpleProperties(BasicSeoPropertyGeneratorImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getReplacementModel(GoogleUniversalAnalyticsProcessor)', 'Calls', 'equals(GoogleUniversalAnalyticsProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getReplacementModel(GoogleUniversalAnalyticsProcessor)', 'Calls', 'equals(GoogleUniversalAnalyticsProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getItemJs(GoogleUniversalAnalyticsProcessor)', 'Calls', 'isAssignableFrom(GoogleUniversalAnalyticsProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addProductInventoryData(UncacheableDataProcessor)', 'Calls', 'getProxy(UncacheableDataProcessorExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['defineOutOfStockProducts(UncacheableDataProcessor)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isBlockingAvailabilityOfProduct(UncacheableDataProcessor)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isBundle(UncacheableDataProcessor)', 'Calls', 'isAssignableFrom(UncacheableDataProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isBundle(UncacheableDataProcessor)', 'Calls', 'equals(UncacheableDataProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getModifiedAttributes(AddSortLinkProcessor)', 'Calls', 'equals(AddSortLinkProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createPricingDto(ProductOptionsProcessor)', 'Calls', 'getProxy(ProductOptionsProcessorExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['populateModelVariables(CategoriesProcessor)', 'Calls', 'getProxy(CategoriesProcessorExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['process(CartStateRequestProcessor)', 'Calls', 'getProxy(CartStateRequestProcessorExtensionManager)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doFilterUnlessIgnored(EstablishSessionFilter)', 'Calls', 'isAssignableFrom(EstablishSessionFilter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getJCacheUri(DefaultJCacheUriProvider)', 'Calls', 'getClass(DefaultJCacheUriProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createCache(DefaultEhCacheUtil)', 'Calls', 'getCacheManager(DefaultEhCacheUtil)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createCache(DefaultEhCacheUtil)', 'Calls', 'enableManagement(DefaultEhCacheUtil)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createCache(DefaultEhCacheUtil)', 'Calls', 'enableStatistics(DefaultEhCacheUtil)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['postProcessBeanDefinitionRegistry(MergeAnnotationAwareBeanDefinitionRegistryPostProcessor)', 'Calls', 'getName(MergeAnnotationAwareBeanDefinitionRegistryPostProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['transform(MaterializedClobTypeClassTransformer)', 'Calls', 'isAssignableFrom(MaterializedClobTypeClassTransformer)'] skipped since target method is not listed in the nodes file!
# ...
# INFO: Edge ['create(SkuDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findSkuByURI(SkuDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllActiveSkusInternal(SkuDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getCriteriaForActiveSkus(SkuDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCategoriesByIds(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCategoryByExternalId(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCategoryByName(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCategoriesByName(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCategoriesByNames(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllCategories(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllProducts(CategoryDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllSubCategories(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readActiveSubCategoriesByCategory(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['delete(CategoryDaoImpl)', 'Persists', 'Status'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['create(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findCategoryByURI(CategoryDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findXrefByCategoryWithDefaultReference(CategoryDaoImpl)', 'Persists', 'CategoryProductXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readProductByExternalId(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readProductsByIds(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readProductsByName(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readActiveProductsByCategoryInternal(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readFilteredActiveProductsByQueryInternal(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readFilteredActiveProductsByQueryInternal(ProductDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readFilteredActiveProductsByCategoryInternal(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readFilteredActiveProductsByCategoryInternal(ProductDaoImpl)', 'Persists', 'CategoryProductXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readFilteredActiveProductsByCategoryInternal(ProductDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readFilteredActiveProductsByCategoryInternal(ProductDaoImpl)', 'Persists', 'Category'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['attachOrderBy(ProductDaoImpl)', 'Persists', 'Order'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readProductsByCategory(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['delete(ProductDaoImpl)', 'Persists', 'Status'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['create(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAutomaticProductBundles(ProductDaoImpl)', 'Persists', 'ProductBundle'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findProductByURI(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllActiveProductsForSiteMap(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllActiveProductIds(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllActiveProductIds(ProductDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllActiveProductsInternal(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCountAllActiveProductsInternal(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readCountAllActiveProductsInternal(ProductDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getCriteriaForActiveProducts(ProductDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getCriteriaForActiveProducts(ProductDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllProductOptions(ProductOptionDaoImpl)', 'Persists', 'ProductOption'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readSkuIdsForProductOptionValues(ProductOptionDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['filterCandidateSkusForArchivedStatus(ProductOptionDaoImpl)', 'Persists', 'Sku'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['filterCandidateSkusForArchivedStatus(ProductOptionDaoImpl)', 'Persists', 'Status'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['attachArchivalConditionIfPossible(ProductOptionDaoImpl)', 'Persists', 'Status'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getProductIdsUsingProductOptionByIdQuery(ProductOptionDaoImpl)', 'Persists', 'ProductOptionXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getProductIdsUsingProductOptionByIdQuery(ProductOptionDaoImpl)', 'Persists', 'Product'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getProductIdsUsingProductOptionByIdQuery(ProductOptionDaoImpl)', 'Persists', 'ProductOption'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readXrefsByCategoryId(CategoryXrefDaoImpl)', 'Persists', 'CategoryXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readXrefsBySubCategoryId(CategoryXrefDaoImpl)', 'Persists', 'CategoryXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readXrefByIds(CategoryXrefDaoImpl)', 'Persists', 'CategoryXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readSkuMediaBySkuId(SkuMediaDaoImpl)', 'Persists', 'SkuMediaXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['create(SiteDaoImpl)', 'Persists', 'Site'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveCatalogByName(SiteDaoImpl)', 'Persists', 'Catalog'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createCatalog(SiteDaoImpl)', 'Persists', 'Catalog'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createSiteCatalog(SiteDaoImpl)', 'Persists', 'SiteCatalogXref'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllActiveSites(SiteDaoImpl)', 'Persists', 'Site'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSiteByDomainOrDomainPrefix(SiteDaoImpl)', 'Persists', 'Site'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSiteByIdentifier(SiteDaoImpl)', 'Persists', 'Site'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSitesByPotentialIdentifiers(SiteDaoImpl)', 'Persists', 'Site'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveAllCatalogs(SiteDaoImpl)', 'Persists', 'Catalog'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findLocaleByCode(LocaleDaoImpl)', 'Persists', 'Locale'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findDefaultLocale(LocaleDaoImpl)', 'Persists', 'Locale'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findAllLocales(LocaleDaoImpl)', 'Persists', 'Locale'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createTracking(EmailReportingDaoImpl)', 'Persists', 'EmailTracking'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createTarget(EmailReportingDaoImpl)', 'Persists', 'EmailTarget'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveTracking(EmailReportingDaoImpl)', 'Persists', 'EmailTracking'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['recordOpen(EmailReportingDaoImpl)', 'Persists', 'EmailTrackingOpens'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['recordClick(EmailReportingDaoImpl)', 'Persists', 'EmailTrackingClicks'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readEnumByKey(DataDrivenEnumerationDaoImpl)', 'Persists', 'DataDrivenEnumeration'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readEnumValueByKey(DataDrivenEnumerationDaoImpl)', 'Persists', 'DataDrivenEnumerationValue'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Persists', 'SystemProperty'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Persists', 'Order'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Persists', 'SystemProperty'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Persists', 'SiteDiscriminator'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['removeFromCache(SystemPropertiesDaoImpl)', 'Persists', 'SiteDiscriminator'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createNewSystemProperty(SystemPropertiesDaoImpl)', 'Persists', 'SystemProperty'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['delete(ModuleConfigurationDaoImpl)', 'Persists', 'Status'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findNextId(IdGenerationDaoImpl)', 'Persists', 'IdGeneration'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findDefaultBroadleafCurrency(BroadleafCurrencyDaoImpl)', 'Persists', 'BroadleafCurrency'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findCurrencyByCode(BroadleafCurrencyDaoImpl)', 'Persists', 'BroadleafCurrency'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['create(BroadleafCurrencyDaoImpl)', 'Persists', 'BroadleafCurrency'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['patchSequenceGeneratorInconsistencies(SequenceGeneratorCorruptionDetection)', 'Persists', 'Field'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveAllSandBoxes(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSandBoxesByType(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['merge(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveChildSandBoxesByParentId(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveUserSandBoxForParent(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSandBoxManagementById(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveNamedSandBox(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSandboxNamesForSandBoxes(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['retrieveSandBoxesForAuthor(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createSandBox(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createSandBox(SandBoxDaoImpl)', 'Persists', 'SandBoxManagement'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createUserSandBox(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createUserSandBox(SandBoxDaoImpl)', 'Persists', 'SandBoxManagement'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createDefaultSandBox(SandBoxDaoImpl)', 'Persists', 'SandBox'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['createDefaultSandBox(SandBoxDaoImpl)', 'Persists', 'SandBoxManagement'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['create(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readTranslations(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readTranslation(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readAllTranslationEntries(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['readConvertedTranslationEntries(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getUpdatedEntityId(TranslationDaoImpl)', 'Persists', 'SandBoxHelper'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findBestTranslation(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findSpecificTranslation(TranslationDaoImpl)', 'Persists', 'Translation'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['findISOCountryByAlpha2Code(ISODaoImpl)', 'Persists', 'ISOCountry'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getGenericEntityDao(GenericEntityDaoImpl)', 'Persists', 'GenericEntityDaoImpl'] discarded since target entity is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['loadUserByUsername(UserDetailsServiceImpl)', 'Calls', 'isAssignableFrom(UserDetailsServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addPostRegisterListener(CustomerServiceImpl)', 'Calls', 'add(MergeOrdersByEmailPostRegistrationObserver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removePostRegisterListener(CustomerServiceImpl)', 'Calls', 'contains(MergeOrdersByEmailPostRegistrationObserver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removePostRegisterListener(CustomerServiceImpl)', 'Calls', 'remove(MergeOrdersByEmailPostRegistrationObserver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['notifyPostRegisterListeners(CustomerServiceImpl)', 'Calls', 'iterator(MergeOrdersByEmailPostRegistrationObserver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findNextCustomerId(CustomerServiceImpl)', 'Calls', 'getCanonicalName(CustomerServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(OfferActivity)', 'Calls', 'getProxy(OfferValueModifierExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUnitAmount(FulfillmentItemPricingActivity)', 'Calls', 'divide(FulfillmentItemPricingActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['purgeCarts(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['notifyCarts(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['purgeOrderHistory(ResourcePurgeServiceImpl)', 'Calls', 'getProxy(ResourcePurgeExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['purgeOrderHistory(ResourcePurgeServiceImpl)', 'Calls', 'getProxy(ResourcePurgeExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['purgeCustomers(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)']: discarding
# WARNING: unable to recover ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'referencedColumnName(DeleteStatementGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'name(DeleteStatementGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['isAddOnOrderItem(OfferServiceUtilitiesImpl)', 'Calls', 'isAssignableFrom(OfferServiceUtilitiesImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildOfferListForOrder(OfferServiceImpl)', 'Calls', 'getProxy(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAndSaveOffersToOrder(OfferServiceImpl)', 'Calls', 'filterOffers(OrderOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAndSaveFulfillmentGroupOffersToOrder(OfferServiceImpl)', 'Calls', 'filterOffers(OrderOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getOffersRetrievedFromCodes(OfferServiceImpl)', 'Calls', 'getProxy(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['canHandle(OfferDuplicateModifier)', 'Calls', 'isAssignableFrom(OfferDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyInitialDuplicateState(OfferDuplicateModifier)', 'Calls', 'getCopySuffix(OfferDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAdditionalFilters(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildOfferCodeListForCustomer(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['calculatePotentialSavings(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resetPriceDetails(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyItemOffer(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['synchronizeAdjustmentsAndPrices(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['chooseSaleOrRetailAdjustments(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createOrderItemPriceDetailAdjustment(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAdditionalRuleVariablesForItemOfferEvaluation(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addAdditionalOffersForCode(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['removeOfferCodeFromOrder(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(FulfillmentGroupOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(FulfillmentGroupOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(FulfillmentGroupOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(FulfillmentGroupOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['couldOfferApplyToFulfillmentGroup(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'executeExpression(FulfillmentGroupOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyItemQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'splitDetailsIfNecessary(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterOffers(ItemOfferProcessorImpl)', 'Calls', 'filterOrderLevelOffer(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['markQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'finalizeQuantities(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['markQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'clearAllNonFinalizedQuantities(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'applyAllOrderOffers(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'applyAllOrderOffers(ItemOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['filterOrderLevelOffer(OrderOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(OrderOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['couldOfferApplyToOrder(OrderOfferProcessorImpl)', 'Calls', 'executeExpression(OrderOfferProcessorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translateOrder(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderId(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'paymentType(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'transactionTotal(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderSubtotal(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'shippingTotal(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'taxTotal(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderCurrencyCode(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderId(OrderToPaymentRequestDTOServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['performCheckout(CheckoutServiceImpl)', 'Calls', 'doActivities(CheckoutSeed)']: discarding
# WARNING: unable to recover ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'rawResponse(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'successful(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'paymentTransactionType(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'amount(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'rawResponse(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'successful(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'paymentTransactionType(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'amount(PassthroughPaymentRollbackServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getRollbackHandler(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getAutomaticallyRegisterRollbackHandler(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getRollbackHandler(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(DecrementInventoryActivity)', 'Calls', 'getAutomaticallyRegisterRollbackHandler(DecrementInventoryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['determineOrderNumber(CompleteOrderActivity)', 'Calls', 'format(CompleteOrderActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(ValidateCheckoutActivity)', 'Calls', 'getProxy(ValidateCheckoutActivityExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['processRegistrationEvent(MergeOrdersByEmailPostRegistrationObserver)', 'Calls', 'getHandlers(PostUpdateOrderExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['processRegistrationEvent(MergeOrdersByEmailPostRegistrationObserver)', 'Calls', 'shouldContinue(PostUpdateOrderExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createNamedOrderForCustomer(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['save(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addOfferCodes(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['preValidateCartOperation(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['preValidateUpdateQuantityOperation(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'isEnabled(CartMessageOrderItemServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'registerHandler(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['gatherProductCartMessages(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'isAssignableFrom(CartMessageOrderItemServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildOrderItemRequestDTOFromOrderItem(OrderItemServiceImpl)', 'Calls', 'append(OrderItemServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildOrderItemRequestDTOFromOrderItem(OrderItemServiceImpl)', 'Calls', 'toComparison(OrderItemServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['priceOrderItem(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['applyAdditionalOrderItemProperties(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyOrderItemRequest(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['mergeOrderItemRequest(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setNewCartOwnership(MergeCartServiceImpl)', 'Calls', 'getProxy(MergeCartServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachAdditionalDataToNewNamedCart(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['preValidateCartOperation(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['preValidateUpdateQuantityOperation(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachAdditionalDataToOrder(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addOfferCodes(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCartForCustomerWithEnhancements(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(CheckAddAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckAddAvailabilityActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(CheckUpdateAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckUpdateAvailabilityActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(CheckUpdateAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckUpdateAvailabilityActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(AddWorkflowPriceOrderIfNecessaryActivity)', 'Calls', 'intValue(AddWorkflowPriceOrderIfNecessaryActivity)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(ValidateAddRequestActivity)', 'Calls', 'getProxy(ValidateAddRequestActivityExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['execute(ValidateAddRequestActivity)', 'Calls', 'getProxy(ValidateAddRequestActivityExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resolveJSONFacetResponse(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resolveJSONFacet(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['resolveJSONFacet(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategoryIds(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'replace(MvelToSearchCriteriaConversionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['convertRuleToFilters(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'equals(MvelToSearchCriteriaConversionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['convertFieldName(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'length(MvelToSearchCriteriaConversionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseMethod(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'replaceFirst(MvelToSearchCriteriaConversionServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['swapActiveCores(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['swapActiveCores(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyNameForIndexField(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategoryId(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getIndexableId(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCurrentProductId(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getProductForIndexable(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'toString(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setFacetResults(SolrHelperServiceImpl)', 'Calls', 'intValue(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setFacetResults(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachFacets(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachFacets(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachSortClause(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSortOrder(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSortOrder(SolrHelperServiceImpl)', 'Calls', 'equals(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'contains(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'substring(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'indexOf(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'indexOf(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'equals(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyPropertyToCollection(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyPropertyToCollection(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSearchableIndexFields(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCategoryFilterIds(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(I18nSolrSearchServiceExtensionHandler)', 'Calls', 'getHandlers(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(I18nSolrSearchServiceExtensionHandler)', 'Calls', 'getHandlers(SolrSearchServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildDocument(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachIndexableDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachAdditionalDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['attachBasicDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getNamespace(SolrConfiguration)']: discarding
# WARNING: unable to recover ['attachBasicDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyValues(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(I18nSolrIndexServiceExtensionHandler)', 'Calls', 'registerHandler(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['startBatchEvent(I18nSolrIndexServiceExtensionHandler)', 'Calls', 'isAssignableFrom(I18nSolrIndexServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['afterPropertiesSet(SolrIndexServiceImpl)', 'Calls', 'isSiteCollections(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['preBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['preBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'isSingleCoreMode(SolrConfiguration)']: discarding
# WARNING: unable to recover ['getReindexOperation(SolrIndexServiceImpl)', 'Calls', 'getSolrCollectionForIndexing(SolrIndexServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getReindexOperation(SolrIndexServiceImpl)', 'Calls', 'getSolrServerForIndexing(SolrIndexServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteAllReindexCoreDocuments(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['deleteAllReindexCoreDocuments(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)']: discarding
# WARNING: unable to recover ['buildDocument(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachIndexableDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['attachAdditionalDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['attachBasicDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getNamespace(SolrConfiguration)']: discarding
# WARNING: unable to recover ['attachBasicDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPropertyValues(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['convertToMappedProperty(SolrIndexServiceImpl)', 'Calls', 'equals(SolrIndexServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deleteByQuery(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['deleteByQuery(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)']: discarding
# WARNING: Unable to recover target method for edge ['addDocuments(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)']: discarding
# WARNING: unable to recover ['retrieveQuantitiesAvailable(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['decrementInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['incrementInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['reconcileChangeOrderInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addSiteMapEntries(CategorySiteMapGenerator)', 'Calls', 'isAssignableFrom(CategorySiteMapGenerator)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['canHandle(ProductDuplicateModifier)', 'Calls', 'isAssignableFrom(ProductDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'equalsIgnoreCase(ProductDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'getName(ProductDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'getName(ProductDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setNameAndUrl(ProductDuplicateModifier)', 'Calls', 'getCopySuffix(ProductDuplicateModifier)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setNameAndUrl(ProductDuplicateModifier)', 'Calls', 'getProxy(ProductUrlDuplicatorExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCategoryByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findProductByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findSkuByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doFilterInternalUnlessIgnored(CustomerStateFilter)', 'Calls', 'postProcess(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['process(CustomerStateRequestProcessor)', 'Calls', 'equals(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['process(CustomerStateRequestProcessor)', 'Calls', 'equals(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['copyAnonymousCustomerInfoToCustomer(CustomerStateRequestProcessor)', 'Calls', 'getProxy(CustomerMergeExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAnonymousCustomer(CustomerStateRequestProcessor)', 'Calls', 'getProxy(AnonymousCustomerExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(SimpleSearchBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyBreadcrumbList(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'buildLink(SimpleSearchBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateContextMap(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'equals(SimpleSearchBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(CategoryBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(CategoryBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(CategoryBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(ProductBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['modifyBreadcrumbList(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'buildLink(ProductBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(HomePageBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(HomePageBreadcrumbServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(HomePageBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['validateAddToCartRequest(UpdateCartServiceImpl)', 'Calls', 'getProxy(UpdateCartServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateAndValidateCart(UpdateCartServiceImpl)', 'Calls', 'getProxy(UpdateCartServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(i18nUpdateCartServiceExtensionHandler)', 'Calls', 'isEnabled(i18nUpdateCartServiceExtensionHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['init(i18nUpdateCartServiceExtensionHandler)', 'Calls', 'getHandlers(UpdateCartServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doFilterInternalUnlessIgnored(GeolocationFilter)', 'Calls', 'postProcess(GeolocationRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(DefaultLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getRequestUri(DefaultLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getRequestParams(DefaultLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(DefaultLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addOrganizationData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(HomepageLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addOrganizationData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addWebSiteData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] since target method may be from a superclass. (Not implemented yet)
# ...
# WARNING: unable to recover ['setType(NotificationEventType)', 'Calls', 'containsKey(NotificationEventType)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setType(NotificationEventType)', 'Calls', 'put(NotificationEventType)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['equals(NotificationEventType)', 'Calls', 'getClass(NotificationEventType)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doFilterInternalUnlessIgnored(BroadleafRequestFilter)', 'Calls', 'getClass(BroadleafRequestFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doFilterInternalUnlessIgnored(BroadleafThemeResolverFilter)', 'Calls', 'getClass(BroadleafThemeResolverFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doFilterUnlessIgnored(TranslationFilter)', 'Calls', 'postProcess(TranslationRequestProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initFilterBean(CachingCompressedResponseFilter)', 'Calls', 'equals(CachingCompressedResponseFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['processStatic(CachingCompressedResponseFilter)', 'Calls', 'setHeaders(CacheAwareResponseHandler)']: discarding
# WARNING: unable to recover ['prepareTargetFile(CachingCompressedResponseFilter)', 'Calls', 'equals(CachingCompressedResponseFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['useGzipCompression(CachingCompressedResponseFilter)', 'Calls', 'equals(CachingCompressedResponseFilter)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInjectedModelAndTagAttributes(TransparentRedirectCreditCardFormProcessor)', 'Calls', 'length(TransparentRedirectCreditCardFormProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInjectedModelAndTagAttributes(TransparentRedirectCreditCardFormProcessor)', 'Calls', 'getProxy(TRCreditCardExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInjectedModelAndTagAttributes(TransparentRedirectCreditCardFormProcessor)', 'Calls', 'getProxy(TRCreditCardExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInjectedModelAndTagAttributes(TransparentRedirectCreditCardFormProcessor)', 'Calls', 'getProxy(TRCreditCardExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['populateModelVariables(CreditCardTypesProcessor)', 'Calls', 'getProxy(CreditCardTypesExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['mapName(PaymentGatewayFieldVariableExpression)', 'Calls', 'getProxy(PaymentGatewayFieldExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initIt(BroadleafVersionResourceResolver)', 'Calls', 'getStrategyMap(BroadleafVersionResourceResolver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initIt(BroadleafVersionResourceResolver)', 'Calls', 'getStrategyMap(BroadleafVersionResourceResolver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['initIt(BroadleafVersionResourceResolver)', 'Calls', 'setStrategyMap(BroadleafVersionResourceResolver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInjectedModelAndTagAttributes(FormProcessor)', 'Calls', 'equalsIgnoreCase(FormProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getInjectedModelAndTagAttributes(FormProcessor)', 'Calls', 'equalsIgnoreCase(FormProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelBundled(ResourcePreloadProcessor)', 'Calls', 'getBundlePath(ResourcePreloadProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelBundled(ResourcePreloadProcessor)', 'Calls', 'getBundleUrl(ResourcePreloadProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelUnbundled(ResourcePreloadProcessor)', 'Calls', 'postProcessUnbundledFileList(ResourcePreloadProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelUnbundled(ResourceBundleProcessor)', 'Calls', 'postProcessUnbundledFileList(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelUnbundled(ResourceBundleProcessor)', 'Calls', 'src(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelUnbundled(ResourceBundleProcessor)', 'Calls', 'src(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelBundled(ResourceBundleProcessor)', 'Calls', 'getBundlePath(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildModelBundled(ResourceBundleProcessor)', 'Calls', 'getBundleUrl(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addDependentBundleRestrictionToModel(ResourceBundleProcessor)', 'Calls', 'src(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addDependentBundleRestrictionToModel(ResourceBundleProcessor)', 'Calls', 'async(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addDependentBundleRestrictionToModel(ResourceBundleProcessor)', 'Calls', 'defer(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addDependentBundleRestrictionToModel(ResourceBundleProcessor)', 'Calls', 'bundleDependencyEvent(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addDependencyRestrictionToModel(ResourceBundleProcessor)', 'Calls', 'getBundleEnabled(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addDependencyRestrictionToModel(ResourceBundleProcessor)', 'Calls', 'getBundleAppendText(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getScriptAttributes(ResourceBundleProcessor)', 'Calls', 'getBundleEnabled(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getLinkAttributes(ResourceBundleProcessor)', 'Calls', 'src(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['useAsyncJavaScript(ResourceBundleProcessor)', 'Calls', 'getBundleEnabled(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['validateTagAttributes(ResourceBundleProcessor)', 'Calls', 'getBundleEnabled(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildUnbundledSyncCompletedEventElement(ResourceBundleProcessor)', 'Calls', 'getBundleEnabled(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['buildUnbundledSyncCompletedEventElement(ResourceBundleProcessor)', 'Calls', 'getBundleCompleteEventJavaScript(ResourceBundleProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getForceShowIdColumns(PropertiesVariableExpression)', 'Calls', 'equals(PropertiesVariableExpression)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['saveBundle(ResourcesRequest)', 'Calls', 'add(ResourcesRequestBundle)']: discarding
# WARNING: unable to recover ['doResolveException(BroadleafSimpleMappingExceptionResolver)', 'Calls', 'applyStatusCodeIfPossible(BroadleafSimpleMappingExceptionResolver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doResolveException(BroadleafSimpleMappingExceptionResolver)', 'Calls', 'getModelAndView(BroadleafSimpleMappingExceptionResolver)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readOfferCodesQuery(OfferCodeDaoImpl)', 'Calls', 'getProxy(OfferCodeDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createNewCartForCustomer(OrderDaoImpl)', 'Calls', 'getProxy(OrderDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createNewCartForCustomer(OrderDaoImpl)', 'Calls', 'getProxy(OrderDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readNamedOrderForCustomer(OrderDaoImpl)', 'Calls', 'getProxy(OrderDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['readSkusByIds(SkuDaoImpl)', 'Calls', 'warn(SupportLogger)']: discarding
# WARNING: unable to recover ['findSkuByURI(SkuDaoImpl)', 'Calls', 'getProxy(SkuDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['findCategoryByURI(CategoryDaoImpl)', 'Calls', 'getProxy(CategoryDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['readProductsByIds(ProductDaoImpl)', 'Calls', 'warn(SupportLogger)']: discarding
# WARNING: unable to recover ['findProductByURI(ProductDaoImpl)', 'Calls', 'getProxy(ProductDaoExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCriteriaForActiveProducts(ProductDaoImpl)', 'Calls', 'getProxy(SiteMapExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['readConvertedTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['readGenericEntity(GenericEntityDaoImpl)', 'Calls', 'getIdMetadata(DynamicDaoHelperImpl)']: discarding
# WARNING: Unable to recover target method for edge ['getCeilingImplClass(GenericEntityDaoImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)']: discarding
# WARNING: Unable to recover target method for edge ['getCeilingImplClass(GenericEntityDaoImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)']: discarding
# WARNING: Unable to recover target method for edge ['getIdentifier(GenericEntityDaoImpl)', 'Calls', 'getIdentifier(DynamicDaoHelperImpl)']: discarding
# WARNING: Unable to recover target method for edge ['getIdField(GenericEntityDaoImpl)', 'Calls', 'getIdField(DynamicDaoHelperImpl)']: discarding

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# Adding new node for method getName(CustomerPaymentDaoImpl)
# Adding new node for method getName(CustomerPhoneDaoImpl)
# Adding new node for method getName(CustomerDaoImpl)
# Adding new node for method addRestriction(CustomerForgotPasswordSecurityTokenDaoImpl)
# Adding new node for method toQuery(CustomerForgotPasswordSecurityTokenDaoImpl)
# Adding new node for method getName(AddressDaoImpl)
# Adding new node for method getName(StateDaoImpl)
# Adding new node for method addRestriction(CountrySubdivisionDaoImpl)
# Adding new node for method toQuery(CountrySubdivisionDaoImpl)
# Adding new node for method getName(CountrySubdivisionDaoImpl)
# Adding new node for method getName(PhoneDaoImpl)
# Adding new node for method getName(CustomerAddressDaoImpl)
# Adding new node for method getName(ShippingRateDaoImpl)
# Adding new node for method getName(CodeTypeDaoImpl)
# Adding new node for method equals(ResourcePurgeDaoImpl)
# Adding new node for method getName(OfferCodeDaoImpl)
# Adding new node for method getName(OfferAuditDaoImpl)
# Adding new node for method addRestriction(OfferAuditDaoImpl)
# Adding new node for method toCountQuery(OfferAuditDaoImpl)
# Adding new node for method root(OfferAuditDaoImpl)
# Adding new node for method toQuery(OfferAuditDaoImpl)
# Adding new node for method getName(OfferDaoImpl)
# Adding new node for method getName(CustomerOfferDaoImpl)
# Adding new node for method getName(OrderPaymentDaoImpl)
# Adding new node for method getName(SecureOrderPaymentDaoImpl)
# Adding new node for method getName(ReviewDetailDaoImpl)
# Adding new node for method batchExecuteReadQuery(RatingSummaryDaoImpl)
# Adding new node for method equals(ZipCodeDaoImpl)
# Adding new node for method getName(OrderMultishipOptionDaoImpl)
# Adding new node for method addRestriction(OrderDaoImpl)
# Adding new node for method toQuery(OrderDaoImpl)
# Adding new node for method equals(OrderDaoImpl)
# Adding new node for method order(OrderDaoImpl)
# Adding new node for method getName(OrderDaoImpl)
# Adding new node for method isAssignableFrom(OrderItemDaoImpl)
# Adding new node for method getName(OrderItemDaoImpl)
# Adding new node for method order(OrderItemDaoImpl)
# Adding new node for method redirect(SearchRedirectDaoImpl)
# Adding new node for method length(SearchFacetDaoImpl)
# Adding new node for method isAssignableFrom(SearchFacetDaoImpl)
# Adding new node for method addRestriction(SkuDaoImpl)
# Adding new node for method toQuery(SkuDaoImpl)
# Adding new node for method getName(SkuDaoImpl)
# Adding new node for method addRestriction(CategoryDaoImpl)
# Adding new node for method toQuery(CategoryDaoImpl)
# Adding new node for method getName(CategoryDaoImpl)
# Adding new node for method addRestriction(ProductDaoImpl)
# Adding new node for method toQuery(ProductDaoImpl)
# Adding new node for method toLowerCase(ProductDaoImpl)
# Adding new node for method contains(ProductDaoImpl)
# Adding new node for method length(ProductDaoImpl)
# Adding new node for method equals(ProductDaoImpl)
# Adding new node for method product(ProductDaoImpl)
# Adding new node for method isAssignableFrom(ProductOptionDaoImpl)
# Adding new node for method addRestriction(SkuMediaDaoImpl)
# Adding new node for method toQuery(SkuMediaDaoImpl)
# Adding new node for method getName(SiteDaoImpl)
# Adding new node for method addRestriction(SiteDaoImpl)
# Adding new node for method toQuery(SiteDaoImpl)
# Adding new node for method addRestriction(DataDrivenEnumerationDaoImpl)
# Adding new node for method toQuery(DataDrivenEnumerationDaoImpl)
# Adding new node for method getCachedObject(SystemPropertiesDaoImpl)
# Adding new node for method isAssignableFrom(SystemPropertiesDaoImpl)
# Adding new node for method getName(SystemPropertiesDaoImpl)
# Adding new node for method getName(BroadleafCurrencyDaoImpl)
# Adding new node for method addRestriction(SandBoxDaoImpl)
# Adding new node for method toQuery(SandBoxDaoImpl)
# Adding new node for method getName(TranslationDaoImpl)
# Adding new node for method toCountQuery(GenericEntityDaoImpl)
# Adding new node for method toQuery(GenericEntityDaoImpl)
# INFO: Edge ['loadUserByUsername(UserDetailsServiceImpl)', 'Calls', 'isAssignableFrom(UserDetailsServiceImpl)'] skipped
# INFO: Edge ['addPostRegisterListener(CustomerServiceImpl)', 'Calls', 'add(MergeOrdersByEmailPostRegistrationObserver)'] skipped
# INFO: Edge ['removePostRegisterListener(CustomerServiceImpl)', 'Calls', 'contains(MergeOrdersByEmailPostRegistrationObserver)'] skipped
# INFO: Edge ['removePostRegisterListener(CustomerServiceImpl)', 'Calls', 'remove(MergeOrdersByEmailPostRegistrationObserver)'] skipped
# INFO: Edge ['notifyPostRegisterListeners(CustomerServiceImpl)', 'Calls', 'iterator(MergeOrdersByEmailPostRegistrationObserver)'] skipped
# INFO: Edge ['findNextCustomerId(CustomerServiceImpl)', 'Calls', 'getCanonicalName(CustomerServiceImpl)'] skipped
# INFO: Edge ['execute(OfferActivity)', 'Calls', 'getProxy(OfferValueModifierExtensionManager)'] skipped
# INFO: Edge ['getUnitAmount(FulfillmentItemPricingActivity)', 'Calls', 'divide(FulfillmentItemPricingActivity)'] skipped
# INFO: Edge ['purgeCarts(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] skipped
# INFO: Edge ['notifyCarts(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] skipped
# INFO: Edge ['purgeOrderHistory(ResourcePurgeServiceImpl)', 'Calls', 'getProxy(ResourcePurgeExtensionManager)'] skipped
# INFO: Edge ['purgeOrderHistory(ResourcePurgeServiceImpl)', 'Calls', 'getProxy(ResourcePurgeExtensionManager)'] skipped
# INFO: Edge ['purgeCustomers(ResourcePurgeServiceImpl)', 'Calls', 'invoke(ResourcePurgeServiceImpl)'] skipped
# INFO: Edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)'] skipped
# INFO: Edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'referencedColumnName(DeleteStatementGeneratorImpl)'] skipped
# INFO: Edge ['diveDeep(DeleteStatementGeneratorImpl)', 'Calls', 'name(DeleteStatementGeneratorImpl)'] skipped
# INFO: Edge ['isAddOnOrderItem(OfferServiceUtilitiesImpl)', 'Calls', 'isAssignableFrom(OfferServiceUtilitiesImpl)'] skipped
# INFO: Edge ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] skipped
# INFO: Edge ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] skipped
# INFO: Edge ['buildItemDetailAdjustmentMap(OfferServiceUtilitiesImpl)', 'Calls', 'append(OfferServiceUtilitiesImpl)'] skipped
# INFO: Edge ['buildOfferListForOrder(OfferServiceImpl)', 'Calls', 'getProxy(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['applyAndSaveOffersToOrder(OfferServiceImpl)', 'Calls', 'filterOffers(OrderOfferProcessorImpl)'] skipped
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped
# INFO: Edge ['verifyAdjustments(OfferServiceImpl)', 'Calls', 'append(OfferServiceImpl)'] skipped
# INFO: Edge ['applyAndSaveFulfillmentGroupOffersToOrder(OfferServiceImpl)', 'Calls', 'filterOffers(OrderOfferProcessorImpl)'] skipped
# INFO: Edge ['getOffersRetrievedFromCodes(OfferServiceImpl)', 'Calls', 'getProxy(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['canHandle(OfferDuplicateModifier)', 'Calls', 'isAssignableFrom(OfferDuplicateModifier)'] skipped
# INFO: Edge ['modifyInitialDuplicateState(OfferDuplicateModifier)', 'Calls', 'getCopySuffix(OfferDuplicateModifier)'] skipped
# INFO: Edge ['applyAdditionalFilters(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['buildOfferCodeListForCustomer(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['calculatePotentialSavings(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['resetPriceDetails(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['applyItemOffer(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['synchronizeAdjustmentsAndPrices(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['chooseSaleOrRetailAdjustments(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['createOrderItemPriceDetailAdjustment(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['applyAdditionalRuleVariablesForItemOfferEvaluation(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['addAdditionalOffersForCode(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['removeOfferCodeFromOrder(OfferServiceExtensionManager)', 'Calls', 'execute(OfferServiceExtensionManager)'] skipped
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(FulfillmentGroupOfferProcessorImpl)'] skipped
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(FulfillmentGroupOfferProcessorImpl)'] skipped
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(FulfillmentGroupOfferProcessorImpl)'] skipped
# INFO: Edge ['filterFulfillmentGroupLevelOffer(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(FulfillmentGroupOfferProcessorImpl)'] skipped
# INFO: Edge ['couldOfferApplyToFulfillmentGroup(FulfillmentGroupOfferProcessorImpl)', 'Calls', 'executeExpression(FulfillmentGroupOfferProcessorImpl)'] skipped
# INFO: Edge ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['filterItemLevelOffer(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['applyItemQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'splitDetailsIfNecessary(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['filterOffers(ItemOfferProcessorImpl)', 'Calls', 'filterOrderLevelOffer(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['markQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'finalizeQuantities(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['markQualifiersAndTargets(ItemOfferProcessorImpl)', 'Calls', 'clearAllNonFinalizedQuantities(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'applyAllOrderOffers(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrder(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['applyAndCompareOrderAndItemOffers(ItemOfferProcessorImpl)', 'Calls', 'applyAllOrderOffers(ItemOfferProcessorImpl)'] skipped
# INFO: Edge ['filterOrderLevelOffer(OrderOfferProcessorImpl)', 'Calls', 'couldOfferApplyToOrderItems(OrderOfferProcessorImpl)'] skipped
# INFO: Edge ['couldOfferApplyToOrder(OrderOfferProcessorImpl)', 'Calls', 'executeExpression(OrderOfferProcessorImpl)'] skipped
# INFO: Edge ['translateOrder(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderId(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'paymentType(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'transactionTotal(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderSubtotal(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'shippingTotal(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'taxTotal(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderCurrencyCode(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['translatePaymentTransaction(OrderToPaymentRequestDTOServiceImpl)', 'Calls', 'orderId(OrderToPaymentRequestDTOServiceImpl)'] skipped
# INFO: Edge ['performCheckout(CheckoutServiceImpl)', 'Calls', 'doActivities(CheckoutSeed)'] skipped
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'rawResponse(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'successful(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'paymentTransactionType(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorize(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'amount(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'rawResponse(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'successful(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'paymentTransactionType(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['rollbackAuthorizeAndCapture(PassthroughPaymentRollbackServiceImpl)', 'Calls', 'amount(PassthroughPaymentRollbackServiceImpl)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getRollbackHandler(DecrementInventoryActivity)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getAutomaticallyRegisterRollbackHandler(DecrementInventoryActivity)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getStateConfiguration(DecrementInventoryActivity)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getRollbackHandler(DecrementInventoryActivity)'] skipped
# INFO: Edge ['execute(DecrementInventoryActivity)', 'Calls', 'getAutomaticallyRegisterRollbackHandler(DecrementInventoryActivity)'] skipped
# INFO: Edge ['determineOrderNumber(CompleteOrderActivity)', 'Calls', 'format(CompleteOrderActivity)'] skipped
# INFO: Edge ['execute(ValidateCheckoutActivity)', 'Calls', 'getProxy(ValidateCheckoutActivityExtensionManager)'] skipped
# INFO: Edge ['processRegistrationEvent(MergeOrdersByEmailPostRegistrationObserver)', 'Calls', 'getHandlers(PostUpdateOrderExtensionManager)'] skipped
# INFO: Edge ['processRegistrationEvent(MergeOrdersByEmailPostRegistrationObserver)', 'Calls', 'shouldContinue(PostUpdateOrderExtensionManager)'] skipped
# INFO: Edge ['createNamedOrderForCustomer(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['save(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['addOfferCodes(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['preValidateCartOperation(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['preValidateUpdateQuantityOperation(OrderServiceImpl)', 'Calls', 'getProxy(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['init(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'isEnabled(CartMessageOrderItemServiceExtensionHandler)'] skipped
# INFO: Edge ['init(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'registerHandler(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['gatherProductCartMessages(CartMessageOrderItemServiceExtensionHandler)', 'Calls', 'isAssignableFrom(CartMessageOrderItemServiceExtensionHandler)'] skipped
# INFO: Edge ['buildOrderItemRequestDTOFromOrderItem(OrderItemServiceImpl)', 'Calls', 'append(OrderItemServiceImpl)'] skipped
# INFO: Edge ['buildOrderItemRequestDTOFromOrderItem(OrderItemServiceImpl)', 'Calls', 'toComparison(OrderItemServiceImpl)'] skipped
# INFO: Edge ['priceOrderItem(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped
# INFO: Edge ['applyAdditionalOrderItemProperties(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped
# INFO: Edge ['modifyOrderItemRequest(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped
# INFO: Edge ['mergeOrderItemRequest(OrderItemServiceImpl)', 'Calls', 'getProxy(OrderItemServiceExtensionManager)'] skipped
# INFO: Edge ['setNewCartOwnership(MergeCartServiceImpl)', 'Calls', 'getProxy(MergeCartServiceExtensionManager)'] skipped
# INFO: Edge ['attachAdditionalDataToNewNamedCart(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['preValidateCartOperation(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['preValidateUpdateQuantityOperation(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['attachAdditionalDataToOrder(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['addOfferCodes(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['findCartForCustomerWithEnhancements(OrderServiceExtensionManager)', 'Calls', 'execute(OrderServiceExtensionManager)'] skipped
# INFO: Edge ['execute(CheckAddAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckAddAvailabilityActivity)'] skipped
# INFO: Edge ['execute(CheckUpdateAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckUpdateAvailabilityActivity)'] skipped
# INFO: Edge ['execute(CheckUpdateAvailabilityActivity)', 'Calls', 'checkSkuAvailability(CheckUpdateAvailabilityActivity)'] skipped
# INFO: Edge ['execute(AddWorkflowPriceOrderIfNecessaryActivity)', 'Calls', 'intValue(AddWorkflowPriceOrderIfNecessaryActivity)'] skipped
# INFO: Edge ['execute(ValidateAddRequestActivity)', 'Calls', 'getProxy(ValidateAddRequestActivityExtensionManager)'] skipped
# INFO: Edge ['execute(ValidateAddRequestActivity)', 'Calls', 'getProxy(ValidateAddRequestActivityExtensionManager)'] skipped
# INFO: Edge ['resolveJSONFacetResponse(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] skipped
# INFO: Edge ['resolveJSONFacet(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] skipped
# INFO: Edge ['resolveJSONFacet(SolrJSONFacetServiceImpl)', 'Calls', 'isAssignableFrom(SolrJSONFacetServiceImpl)'] skipped
# INFO: Edge ['getCategoryIds(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'replace(MvelToSearchCriteriaConversionServiceImpl)'] skipped
# INFO: Edge ['convertRuleToFilters(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'equals(MvelToSearchCriteriaConversionServiceImpl)'] skipped
# INFO: Edge ['convertFieldName(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'length(MvelToSearchCriteriaConversionServiceImpl)'] skipped
# INFO: Edge ['parseMethod(MvelToSearchCriteriaConversionServiceImpl)', 'Calls', 'replaceFirst(MvelToSearchCriteriaConversionServiceImpl)'] skipped
# INFO: Edge ['swapActiveCores(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['swapActiveCores(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getPropertyNameForIndexField(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['getCategoryId(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['getIndexableId(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['getCurrentProductId(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getProductForIndexable(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getCategorySortFieldName(SolrHelperServiceImpl)', 'Calls', 'toString(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['setFacetResults(SolrHelperServiceImpl)', 'Calls', 'intValue(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['setFacetResults(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['attachFacets(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['attachFacets(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['attachSortClause(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['getSortOrder(SolrHelperServiceImpl)', 'Calls', 'append(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getSortOrder(SolrHelperServiceImpl)', 'Calls', 'equals(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'contains(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'substring(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'indexOf(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'indexOf(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'equals(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['attachActiveFacetFilters(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getPropertyValueInternal(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['copyPropertyToCollection(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['copyPropertyToCollection(SolrHelperServiceImpl)', 'Calls', 'isAssignableFrom(SolrHelperServiceImpl)'] skipped
# INFO: Edge ['getSearchableIndexFields(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['getCategoryFilterIds(SolrHelperServiceImpl)', 'Calls', 'getProxy(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['init(I18nSolrSearchServiceExtensionHandler)', 'Calls', 'getHandlers(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['init(I18nSolrSearchServiceExtensionHandler)', 'Calls', 'getHandlers(SolrSearchServiceExtensionManager)'] skipped
# INFO: Edge ['buildDocument(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['attachIndexableDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['attachAdditionalDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['attachBasicDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getNamespace(SolrConfiguration)'] skipped
# INFO: Edge ['attachBasicDocumentFields(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['getPropertyValues(CatalogDocumentBuilderImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['init(I18nSolrIndexServiceExtensionHandler)', 'Calls', 'registerHandler(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['startBatchEvent(I18nSolrIndexServiceExtensionHandler)', 'Calls', 'isAssignableFrom(I18nSolrIndexServiceExtensionHandler)'] skipped
# INFO: Edge ['afterPropertiesSet(SolrIndexServiceImpl)', 'Calls', 'isSiteCollections(SolrConfiguration)'] skipped
# INFO: Edge ['preBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)'] skipped
# INFO: Edge ['preBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)'] skipped
# INFO: Edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)'] skipped
# INFO: Edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)'] skipped
# INFO: Edge ['postBuildIndex(SolrIndexServiceImpl)', 'Calls', 'isSingleCoreMode(SolrConfiguration)'] skipped
# INFO: Edge ['getReindexOperation(SolrIndexServiceImpl)', 'Calls', 'getSolrCollectionForIndexing(SolrIndexServiceImpl)'] skipped
# INFO: Edge ['getReindexOperation(SolrIndexServiceImpl)', 'Calls', 'getSolrServerForIndexing(SolrIndexServiceImpl)'] skipped
# INFO: Edge ['deleteAllReindexCoreDocuments(SolrIndexServiceImpl)', 'Calls', 'getReindexCollectionName(SolrConfiguration)'] skipped
# INFO: Edge ['deleteAllReindexCoreDocuments(SolrIndexServiceImpl)', 'Calls', 'getReindexServer(SolrConfiguration)'] skipped
# INFO: Edge ['buildDocument(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['attachIndexableDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['attachAdditionalDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['attachBasicDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getNamespace(SolrConfiguration)'] skipped
# INFO: Edge ['attachBasicDocumentFields(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['getPropertyValues(SolrIndexServiceImpl)', 'Calls', 'getProxy(SolrIndexServiceExtensionManager)'] skipped
# INFO: Edge ['convertToMappedProperty(SolrIndexServiceImpl)', 'Calls', 'equals(SolrIndexServiceImpl)'] skipped
# INFO: Edge ['deleteByQuery(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)'] skipped
# INFO: Edge ['deleteByQuery(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)'] skipped
# INFO: Edge ['addDocuments(SolrIndexServiceImpl)', 'Calls', 'getServer(SolrConfiguration)'] skipped
# INFO: Edge ['retrieveQuantitiesAvailable(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped
# INFO: Edge ['decrementInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped
# INFO: Edge ['incrementInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped
# INFO: Edge ['reconcileChangeOrderInventory(InventoryServiceImpl)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped
# INFO: Edge ['addSiteMapEntries(CategorySiteMapGenerator)', 'Calls', 'isAssignableFrom(CategorySiteMapGenerator)'] skipped
# INFO: Edge ['canHandle(ProductDuplicateModifier)', 'Calls', 'isAssignableFrom(ProductDuplicateModifier)'] skipped
# INFO: Edge ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'equalsIgnoreCase(ProductDuplicateModifier)'] skipped
# INFO: Edge ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'getName(ProductDuplicateModifier)'] skipped
# INFO: Edge ['modifyInitialDuplicateState(ProductDuplicateModifier)', 'Calls', 'getName(ProductDuplicateModifier)'] skipped
# INFO: Edge ['setNameAndUrl(ProductDuplicateModifier)', 'Calls', 'getCopySuffix(ProductDuplicateModifier)'] skipped
# INFO: Edge ['setNameAndUrl(ProductDuplicateModifier)', 'Calls', 'getProxy(ProductUrlDuplicatorExtensionManager)'] skipped
# INFO: Edge ['findCategoryByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] skipped
# INFO: Edge ['findProductByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] skipped
# INFO: Edge ['findSkuByURI(CatalogServiceImpl)', 'Calls', 'getProxy(CatalogServiceExtensionManager)'] skipped
# INFO: Edge ['doFilterInternalUnlessIgnored(CustomerStateFilter)', 'Calls', 'postProcess(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'equals(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'equals(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['process(CustomerStateRequestProcessor)', 'Calls', 'getName(CustomerStateRequestProcessor)'] skipped
# INFO: Edge ['copyAnonymousCustomerInfoToCustomer(CustomerStateRequestProcessor)', 'Calls', 'getProxy(CustomerMergeExtensionManager)'] skipped
# INFO: Edge ['getAnonymousCustomer(CustomerStateRequestProcessor)', 'Calls', 'getProxy(AnonymousCustomerExtensionManager)'] skipped
# INFO: Edge ['init(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(SimpleSearchBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['init(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped
# INFO: Edge ['modifyBreadcrumbList(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'buildLink(SimpleSearchBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['updateContextMap(SimpleSearchBreadcrumbServiceExtensionHandler)', 'Calls', 'equals(SimpleSearchBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['init(CategoryBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(CategoryBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['init(CategoryBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped
# INFO: Edge ['init(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(ProductBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['init(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped
# INFO: Edge ['modifyBreadcrumbList(ProductBreadcrumbServiceExtensionHandler)', 'Calls', 'buildLink(ProductBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['init(HomePageBreadcrumbServiceExtensionHandler)', 'Calls', 'isEnabled(HomePageBreadcrumbServiceExtensionHandler)'] skipped
# INFO: Edge ['init(HomePageBreadcrumbServiceExtensionHandler)', 'Calls', 'registerHandler(BreadcrumbServiceExtensionManager)'] skipped
# INFO: Edge ['validateAddToCartRequest(UpdateCartServiceImpl)', 'Calls', 'getProxy(UpdateCartServiceExtensionManager)'] skipped
# INFO: Edge ['updateAndValidateCart(UpdateCartServiceImpl)', 'Calls', 'getProxy(UpdateCartServiceExtensionManager)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['configAddressInitBinder(InitBinderServiceImpl)', 'Calls', 'setValue(InitBinderServiceImpl)'] skipped
# INFO: Edge ['init(i18nUpdateCartServiceExtensionHandler)', 'Calls', 'isEnabled(i18nUpdateCartServiceExtensionHandler)'] skipped
# INFO: Edge ['init(i18nUpdateCartServiceExtensionHandler)', 'Calls', 'getHandlers(UpdateCartServiceExtensionManager)'] skipped
# INFO: Edge ['doFilterInternalUnlessIgnored(GeolocationFilter)', 'Calls', 'postProcess(GeolocationRequestProcessor)'] skipped
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(DefaultLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getRequestUri(DefaultLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getRequestParams(DefaultLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addBreadcrumbData(DefaultLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(DefaultLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addOrganizationData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(HomepageLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addOrganizationData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addWebSiteData(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['getLogoUrl(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addPotentialActions(HomepageLinkedDataGeneratorImpl)', 'Calls', 'getSiteBaseUrl(HomepageLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['init(DefaultLinkedDataGeneratorExtensionHandler)', 'Calls', 'registerHandler(LinkedDataGeneratorExtensionManager)'] skipped
# INFO: Edge ['getLinkedDataJsonInternal(CategoryLinkedDataGeneratorImpl)', 'Calls', 'getStructuredDataContext(CategoryLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['addReviewData(ProductLinkedDataGeneratorImpl)', 'Calls', 'put(ProductLinkedDataGeneratorImpl)'] skipped
# INFO: Edge ['filterForSeoProperties(BasicSeoPropertyGeneratorImpl)', 'Calls', 'equals(BasicSeoPropertyGeneratorImpl)'] skipped
# INFO: Edge ['filterForSeoProperties(BasicSeoPropertyGeneratorImpl)', 'Calls', 'equals(BasicSeoPropertyGeneratorImpl)'] skipped
# INFO: Edge ['gatherSeoProperties(BasicSeoPropertyGeneratorImpl)', 'Calls', 'getSimpleProperties(BasicSeoPropertyGeneratorImpl)'] skipped
# INFO: Edge ['getReplacementModel(GoogleUniversalAnalyticsProcessor)', 'Calls', 'equals(GoogleUniversalAnalyticsProcessor)'] skipped
# INFO: Edge ['getReplacementModel(GoogleUniversalAnalyticsProcessor)', 'Calls', 'equals(GoogleUniversalAnalyticsProcessor)'] skipped
# INFO: Edge ['getItemJs(GoogleUniversalAnalyticsProcessor)', 'Calls', 'isAssignableFrom(GoogleUniversalAnalyticsProcessor)'] skipped
# INFO: Edge ['addProductInventoryData(UncacheableDataProcessor)', 'Calls', 'getProxy(UncacheableDataProcessorExtensionManager)'] skipped
# INFO: Edge ['defineOutOfStockProducts(UncacheableDataProcessor)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped
# INFO: Edge ['isBlockingAvailabilityOfProduct(UncacheableDataProcessor)', 'Calls', 'getProxy(InventoryServiceExtensionManager)'] skipped
# INFO: Edge ['isBundle(UncacheableDataProcessor)', 'Calls', 'isAssignableFrom(UncacheableDataProcessor)'] skipped
# INFO: Edge ['isBundle(UncacheableDataProcessor)', 'Calls', 'equals(UncacheableDataProcessor)'] skipped
# INFO: Edge ['getModifiedAttributes(AddSortLinkProcessor)', 'Calls', 'equals(AddSortLinkProcessor)'] skipped
# INFO: Edge ['createPricingDto(ProductOptionsProcessor)', 'Calls', 'getProxy(ProductOptionsProcessorExtensionManager)'] skipped
# INFO: Edge ['populateModelVariables(CategoriesProcessor)', 'Calls', 'getProxy(CategoriesProcessorExtensionManager)'] skipped
# INFO: Edge ['process(CartStateRequestProcessor)', 'Calls', 'getProxy(CartStateRequestProcessorExtensionManager)'] skipped
# INFO: Edge ['doFilterUnlessIgnored(EstablishSessionFilter)', 'Calls', 'isAssignableFrom(EstablishSessionFilter)'] skipped
# INFO: Edge ['getJCacheUri(DefaultJCacheUriProvider)', 'Calls', 'getClass(DefaultJCacheUriProvider)'] skipped
# INFO: Edge ['createCache(DefaultEhCacheUtil)', 'Calls', 'getCacheManager(DefaultEhCacheUtil)'] skipped
# INFO: Edge ['createCache(DefaultEhCacheUtil)', 'Calls', 'enableManagement(DefaultEhCacheUtil)'] skipped
# INFO: Edge ['createCache(DefaultEhCacheUtil)', 'Calls', 'enableStatistics(DefaultEhCacheUtil)'] skipped
# INFO: Edge ['postProcessBeanDefinitionRegistry(MergeAnnotationAwareBeanDefinitionRegistryPostProcessor)', 'Calls', 'getName(MergeAnnotationAwareBeanDefinitionRegistryPostProcessor)'] skipped
# INFO: Edge ['transform(MaterializedClobTypeClassTransformer)', 'Calls', 'isAssignableFrom(MaterializedClobTypeClassTransformer)'] skipped
# INFO: Edge ['transform(MaterializedClobTypeClassTransformer)', 'Calls', 'isAssignableFrom(MaterializedClobTypeClassTransformer)'] skipped
# INFO: Edge ['transform(MaterializedClobTypeClassTransformer)', 'Calls', 'getName(MaterializedClobTypeClassTransformer)'] skipped
# INFO: Edge ['transform(MaterializedClobTypeClassTransformer)', 'Calls', 'getName(MaterializedClobTypeClassTransformer)'] skipped
# INFO: Edge ['transform(MaterializedClobTypeClassTransformer)', 'Calls', 'getName(MaterializedClobTypeClassTransformer)'] skipped
# INFO: Edge ['getCacheStat(StatisticsServiceImpl)', 'Calls', 'containsKey(CacheStat)'] skipped
# INFO: Edge ['getCacheStat(StatisticsServiceImpl)', 'Calls', 'put(CacheStat)'] skipped
# INFO: Edge ['getCacheStat(StatisticsServiceImpl)', 'Calls', 'get(CacheStat)'] skipped
# INFO: Edge ['getAttributes(StatisticsServiceImpl)', 'Calls', 'entrySet(CacheStat)'] skipped
# INFO: Edge ['getMBeanInfo(StatisticsServiceImpl)', 'Calls', 'entrySet(CacheStat)'] skipped
# INFO: Edge ['getNonPersistentSite(SiteServiceImpl)', 'Calls', 'getProxy(SiteServiceExtensionManager)'] skipped
# INFO: Edge ['getAntiSamyPolicy(ExploitProtectionServiceImpl)', 'Calls', 'getInputStream(ExploitProtectionServiceImpl)'] skipped
# INFO: Edge ['lookupResourceOnClassPath(BroadleafFileServiceImpl)', 'Calls', 'equals(BroadleafFileServiceImpl)'] skipped
# INFO: Edge ['getResource(FileSystemFileServiceProvider)', 'Calls', 'getProxy(BroadleafFileServiceExtensionManager)'] skipped
# INFO: Edge ['convertAssetPath(StaticAssetPathServiceImpl)', 'Calls', 'equals(StaticAssetPathServiceImpl)'] skipped
# INFO: Edge ['fixEnvironmentUrlPrefix(StaticAssetPathServiceImpl)', 'Calls', 'equals(StaticAssetPathServiceImpl)'] skipped
# INFO: Edge ['addThemeContextIfNeeded(StaticAssetPathServiceImpl)', 'Calls', 'addParameter(StaticAssetPathServiceImpl)'] skipped
# INFO: Edge ['addThemeContextIfNeeded(StaticAssetPathServiceImpl)', 'Calls', 'build(StaticAssetPathServiceImpl)'] skipped
# INFO: Edge ['addThemeContextIfNeeded(StaticAssetPathServiceImpl)', 'Calls', 'toString(StaticAssetPathServiceImpl)'] skipped
# INFO: Edge ['sortHandlers(BreadcrumbServiceExtensionManager)', 'Calls', 'getHandlers(BreadcrumbServiceExtensionManager)'] skipped
# INFO: Edge ['buildBreadcrumbDTOs(BreadcrumbServiceImpl)', 'Calls', 'getProxy(BreadcrumbServiceExtensionManager)'] skipped
# INFO: Edge ['getTemplateCacheKey(TemplateCacheExtensionManager)', 'Calls', 'execute(TemplateCacheExtensionManager)'] skipped
# INFO: Edge ['getTemplateName(TemplateCacheExtensionManager)', 'Calls', 'execute(TemplateCacheExtensionManager)'] skipped
# INFO: Edge ['refineParameterRetrieve(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['refineQuery(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['setup(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['breakdown(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['refineOrder(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['isValidState(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['buildStatus(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['filterResults(TemplateOnlyQueryExtensionManager)', 'Calls', 'execute(TemplateOnlyQueryExtensionManager)'] skipped
# INFO: Edge ['getCeilingImplClassFromEntityManagers(PersistenceServiceImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)'] skipped
# INFO: Edge ['runStreamingTransactionalOperation(StreamingTransactionCapableUtil)', 'Calls', 'isFinalPage(StreamingTransactionCapableUtil)'] skipped
# INFO: Edge ['authorize(PassthroughPaymentTransactionService)', 'Calls', 'paymentTransactionType(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['authorize(PassthroughPaymentTransactionService)', 'Calls', 'amount(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['authorize(PassthroughPaymentTransactionService)', 'Calls', 'successful(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['capture(PassthroughPaymentTransactionService)', 'Calls', 'paymentTransactionType(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['capture(PassthroughPaymentTransactionService)', 'Calls', 'amount(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['capture(PassthroughPaymentTransactionService)', 'Calls', 'successful(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['authorizeAndCapture(PassthroughPaymentTransactionService)', 'Calls', 'paymentTransactionType(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['authorizeAndCapture(PassthroughPaymentTransactionService)', 'Calls', 'amount(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['authorizeAndCapture(PassthroughPaymentTransactionService)', 'Calls', 'successful(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['reverseAuthorize(PassthroughPaymentTransactionService)', 'Calls', 'paymentTransactionType(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['reverseAuthorize(PassthroughPaymentTransactionService)', 'Calls', 'amount(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['reverseAuthorize(PassthroughPaymentTransactionService)', 'Calls', 'successful(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['refund(PassthroughPaymentTransactionService)', 'Calls', 'paymentTransactionType(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['refund(PassthroughPaymentTransactionService)', 'Calls', 'amount(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['refund(PassthroughPaymentTransactionService)', 'Calls', 'successful(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['voidPayment(PassthroughPaymentTransactionService)', 'Calls', 'paymentTransactionType(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['voidPayment(PassthroughPaymentTransactionService)', 'Calls', 'amount(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['voidPayment(PassthroughPaymentTransactionService)', 'Calls', 'successful(PassthroughPaymentTransactionService)'] skipped
# INFO: Edge ['sendBasicEmail(EmailServiceImpl)', 'Calls', 'sendMessage(MessageCreator)'] skipped
# INFO: Edge ['resolveSystemProperty(SystemPropertiesServiceImpl)', 'Calls', 'getProxy(SystemPropertyServiceExtensionManager)'] skipped
# INFO: Edge ['resolveSystemProperty(SystemPropertiesServiceImpl)', 'Calls', 'equals(SystemPropertiesServiceImpl)'] skipped
# INFO: Edge ['init(ConditionalFieldAnnotationCopyTransformersManagerImpl)', 'Calls', 'entrySet(ConditionalFieldAnnotationCopyTransformMemberDTO)'] skipped
# INFO: Edge ['init(ConditionalFieldAnnotationCopyTransformersManagerImpl)', 'Calls', 'put(ConditionalFieldAnnotationCopyTransformMemberDTO)'] skipped
# INFO: Edge ['isEntityEnabled(ConditionalFieldAnnotationCopyTransformersManagerImpl)', 'Calls', 'containsKey(ConditionalFieldAnnotationCopyTransformMemberDTO)'] skipped
# INFO: Edge ['getTransformMember(ConditionalFieldAnnotationCopyTransformersManagerImpl)', 'Calls', 'get(ConditionalFieldAnnotationCopyTransformMemberDTO)'] skipped
# INFO: Edge ['init(ConditionalDirectCopyTransformersManagerImpl)', 'Calls', 'entrySet(ConditionalDirectCopyTransformMemberDto)'] skipped
# INFO: Edge ['init(ConditionalDirectCopyTransformersManagerImpl)', 'Calls', 'put(ConditionalDirectCopyTransformMemberDto)'] skipped
# INFO: Edge ['init(ConditionalDirectCopyTransformersManagerImpl)', 'Calls', 'put(ConditionalDirectCopyTransformMemberDto)'] skipped
# INFO: Edge ['isEntityEnabled(ConditionalDirectCopyTransformersManagerImpl)', 'Calls', 'containsKey(ConditionalDirectCopyTransformMemberDto)'] skipped
# INFO: Edge ['getTransformMember(ConditionalDirectCopyTransformersManagerImpl)', 'Calls', 'get(ConditionalDirectCopyTransformMemberDto)'] skipped
# INFO: Edge ['performCopy(EntityDuplicatorImpl)', 'Calls', 'persistCopyObjectTree(EntityDuplicatorImpl)'] skipped
# INFO: Edge ['validateDuplicate(EntityDuplicatorExtensionManager)', 'Calls', 'execute(EntityDuplicatorExtensionManager)'] skipped
# INFO: Edge ['setupDuplicate(EntityDuplicatorExtensionManager)', 'Calls', 'execute(EntityDuplicatorExtensionManager)'] skipped
# INFO: Edge ['addToSandbox(EntityDuplicatorExtensionManager)', 'Calls', 'execute(EntityDuplicatorExtensionManager)'] skipped
# INFO: Edge ['tearDownDuplicate(EntityDuplicatorExtensionManager)', 'Calls', 'execute(EntityDuplicatorExtensionManager)'] skipped
# INFO: Edge ['getCatalogsForPropagation(EntityDuplicatorExtensionManager)', 'Calls', 'execute(EntityDuplicatorExtensionManager)'] skipped
# INFO: Edge ['getClonesByCatalogs(EntityDuplicatorExtensionManager)', 'Calls', 'execute(EntityDuplicatorExtensionManager)'] skipped
# INFO: Edge ['stop(TransactionLifecycleMonitor)', 'Calls', 'isEmpty(TransactionInfo)'] skipped
# INFO: Edge ['stop(TransactionLifecycleMonitor)', 'Calls', 'support(SupportLogger)'] skipped
# INFO: Edge ['stop(TransactionLifecycleMonitor)', 'Calls', 'entrySet(TransactionInfo)'] skipped
# INFO: Edge ['stop(TransactionLifecycleMonitor)', 'Calls', 'support(SupportLogger)'] skipped
# INFO: Edge ['onApplicationEvent(TransactionLifecycleMonitor)', 'Calls', 'size(TransactionInfo)'] skipped
# INFO: Edge ['onApplicationEvent(TransactionLifecycleMonitor)', 'Calls', 'put(TransactionInfo)'] skipped
# INFO: Edge ['onApplicationEvent(TransactionLifecycleMonitor)', 'Calls', 'debug(SupportLogger)'] skipped
# INFO: Edge ['groomInProgressTransactionInfos(TransactionLifecycleMonitor)', 'Calls', 'remove(TransactionInfo)'] skipped
# INFO: Edge ['detectLeakage(TransactionLifecycleMonitor)', 'Calls', 'support(SupportLogger)'] skipped
# INFO: Edge ['detectExpiry(TransactionLifecycleMonitor)', 'Calls', 'support(SupportLogger)'] skipped
# INFO: Edge ['detectExpiry(TransactionLifecycleMonitor)', 'Calls', 'support(SupportLogger)'] skipped
# INFO: Edge ['finalizeTransaction(TransactionLifecycleMonitor)', 'Calls', 'get(TransactionInfo)'] skipped
# INFO: Edge ['finalizeTransaction(TransactionLifecycleMonitor)', 'Calls', 'support(SupportLogger)'] skipped
# INFO: Edge ['finalizeTransaction(TransactionLifecycleMonitor)', 'Calls', 'remove(TransactionInfo)'] skipped
# ...
# INFO: Added edge ['readUnusedTokensByCustomerId(CustomerForgotPasswordSecurityTokenDaoImpl)', 'Calls', 'toQuery(CustomerForgotPasswordSecurityTokenDaoImpl)']
# INFO: Added edge ['create(AddressDaoImpl)', 'Calls', 'getName(AddressDaoImpl)']
# INFO: Added edge ['create(StateDaoImpl)', 'Calls', 'getName(StateDaoImpl)']
# INFO: Added edge ['findSubdivisionByCountryAndAltAbbreviation(CountrySubdivisionDaoImpl)', 'Calls', 'addRestriction(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['findSubdivisionByCountryAndAltAbbreviation(CountrySubdivisionDaoImpl)', 'Calls', 'addRestriction(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['findSubdivisionByCountryAndAltAbbreviation(CountrySubdivisionDaoImpl)', 'Calls', 'toQuery(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['findSubdivisionByCountryAndName(CountrySubdivisionDaoImpl)', 'Calls', 'addRestriction(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['findSubdivisionByCountryAndName(CountrySubdivisionDaoImpl)', 'Calls', 'addRestriction(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['findSubdivisionByCountryAndName(CountrySubdivisionDaoImpl)', 'Calls', 'toQuery(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['create(CountrySubdivisionDaoImpl)', 'Calls', 'getName(CountrySubdivisionDaoImpl)']
# INFO: Added edge ['create(PhoneDaoImpl)', 'Calls', 'getName(PhoneDaoImpl)']
# INFO: Added edge ['create(CustomerAddressDaoImpl)', 'Calls', 'getName(CustomerAddressDaoImpl)']
# INFO: Added edge ['create(ShippingRateDaoImpl)', 'Calls', 'getName(ShippingRateDaoImpl)']
# INFO: Added edge ['create(CodeTypeDaoImpl)', 'Calls', 'getName(CodeTypeDaoImpl)']
# INFO: Added edge ['readCodeTypeById(CodeTypeDaoImpl)', 'Calls', 'getName(CodeTypeDaoImpl)']
# INFO: Added edge ['buildCustomerQuery(ResourcePurgeDaoImpl)', 'Calls', 'equals(ResourcePurgeDaoImpl)']
# INFO: Added edge ['buildCartQuery(ResourcePurgeDaoImpl)', 'Calls', 'equals(ResourcePurgeDaoImpl)']
# INFO: Added edge ['create(OfferCodeDaoImpl)', 'Calls', 'getName(OfferCodeDaoImpl)']
# INFO: Added edge ['readOfferCodesByIds(OfferCodeDaoImpl)', 'Calls', 'getName(OfferCodeDaoImpl)']
# INFO: Edge ['readOfferCodesQuery(OfferCodeDaoImpl)', 'Calls', 'getProxy(OfferCodeDaoExtensionManager)'] skipped
# INFO: Added edge ['create(OfferAuditDaoImpl)', 'Calls', 'getName(OfferAuditDaoImpl)']
# INFO: Added edge ['countUsesByCustomer(OfferAuditDaoImpl)', 'Calls', 'addRestriction(OfferAuditDaoImpl)']
# INFO: Added edge ['countUsesByCustomer(OfferAuditDaoImpl)', 'Calls', 'addRestriction(OfferAuditDaoImpl)']
# INFO: Added edge ['countUsesByCustomer(OfferAuditDaoImpl)', 'Calls', 'toCountQuery(OfferAuditDaoImpl)']
# INFO: Added edge ['countUsesByAccountOrCustomer(OfferAuditDaoImpl)', 'Calls', 'root(OfferAuditDaoImpl)']
# INFO: Added edge ['countOfferCodeUses(OfferAuditDaoImpl)', 'Calls', 'addRestriction(OfferAuditDaoImpl)']
# INFO: Added edge ['countOfferCodeUses(OfferAuditDaoImpl)', 'Calls', 'toCountQuery(OfferAuditDaoImpl)']
# INFO: Added edge ['readOfferAuditsByOrderId(OfferAuditDaoImpl)', 'Calls', 'addRestriction(OfferAuditDaoImpl)']
# INFO: Added edge ['readOfferAuditsByOrderId(OfferAuditDaoImpl)', 'Calls', 'toQuery(OfferAuditDaoImpl)']
# INFO: Added edge ['create(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createOfferInfo(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createCandidateOrderOffer(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createCandidateItemOffer(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createCandidateFulfillmentGroupOffer(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createOrderItemAdjustment(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createOrderItemPriceDetailAdjustment(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createOrderAdjustment(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['createFulfillmentGroupAdjustment(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['delete(OfferDaoImpl)', 'Calls', 'getName(OfferDaoImpl)']
# INFO: Added edge ['create(CustomerOfferDaoImpl)', 'Calls', 'getName(CustomerOfferDaoImpl)']
# INFO: Added edge ['create(OrderPaymentDaoImpl)', 'Calls', 'getName(OrderPaymentDaoImpl)']
# INFO: Added edge ['createTransaction(OrderPaymentDaoImpl)', 'Calls', 'getName(OrderPaymentDaoImpl)']
# INFO: Added edge ['createLog(OrderPaymentDaoImpl)', 'Calls', 'getName(OrderPaymentDaoImpl)']
# INFO: Added edge ['createBankAccountPayment(SecureOrderPaymentDaoImpl)', 'Calls', 'getName(SecureOrderPaymentDaoImpl)']
# INFO: Added edge ['createGiftCardPayment(SecureOrderPaymentDaoImpl)', 'Calls', 'getName(SecureOrderPaymentDaoImpl)']
# INFO: Added edge ['createCreditCardPayment(SecureOrderPaymentDaoImpl)', 'Calls', 'getName(SecureOrderPaymentDaoImpl)']
# INFO: Added edge ['create(ReviewDetailDaoImpl)', 'Calls', 'getName(ReviewDetailDaoImpl)']
# INFO: Added edge ['createFeedback(ReviewDetailDaoImpl)', 'Calls', 'getName(ReviewDetailDaoImpl)']
# INFO: Added edge ['readRatingSummaries(RatingSummaryDaoImpl)', 'Calls', 'batchExecuteReadQuery(RatingSummaryDaoImpl)']
# INFO: Added edge ['findBestZipCode(ZipCodeDaoImpl)', 'Calls', 'equals(ZipCodeDaoImpl)']
# INFO: Added edge ['create(OrderMultishipOptionDaoImpl)', 'Calls', 'getName(OrderMultishipOptionDaoImpl)']
# INFO: Added edge ['readOrderByExternalId(OrderDaoImpl)', 'Calls', 'addRestriction(OrderDaoImpl)']
# INFO: Added edge ['readOrderByExternalId(OrderDaoImpl)', 'Calls', 'toQuery(OrderDaoImpl)']
# INFO: Edge ['createNewCartForCustomer(OrderDaoImpl)', 'Calls', 'getProxy(OrderDaoExtensionManager)'] skipped
# INFO: Edge ['createNewCartForCustomer(OrderDaoImpl)', 'Calls', 'getProxy(OrderDaoExtensionManager)'] skipped
# INFO: Edge ['readNamedOrderForCustomer(OrderDaoImpl)', 'Calls', 'getProxy(OrderDaoExtensionManager)'] skipped
# INFO: Added edge ['readOrderByOrderNumber(OrderDaoImpl)', 'Calls', 'equals(OrderDaoImpl)']
# INFO: Added edge ['readOrdersByDateRange(OrderDaoImpl)', 'Calls', 'order(OrderDaoImpl)']
# INFO: Added edge ['readOrdersForCustomersInDateRange(OrderDaoImpl)', 'Calls', 'order(OrderDaoImpl)']
# INFO: Added edge ['acquireLock(OrderDaoImpl)', 'Calls', 'getName(OrderDaoImpl)']
# INFO: Added edge ['delete(OrderItemDaoImpl)', 'Calls', 'isAssignableFrom(OrderItemDaoImpl)']
# INFO: Added edge ['createPersonalMessage(OrderItemDaoImpl)', 'Calls', 'getName(OrderItemDaoImpl)']
# INFO: Added edge ['createOrderItemPriceDetail(OrderItemDaoImpl)', 'Calls', 'getName(OrderItemDaoImpl)']
# INFO: Added edge ['createOrderItemQualifier(OrderItemDaoImpl)', 'Calls', 'getName(OrderItemDaoImpl)']
# INFO: Added edge ['readOrderItemsForCustomersInDateRange(OrderItemDaoImpl)', 'Calls', 'order(OrderItemDaoImpl)']
# INFO: Added edge ['buildFindSearchRedirectBySearchTermCriteria(SearchRedirectDaoImpl)', 'Calls', 'redirect(SearchRedirectDaoImpl)']
# INFO: Added edge ['readDistinctValuesForField(SearchFacetDaoImpl)', 'Calls', 'length(SearchFacetDaoImpl)']
# INFO: Added edge ['readDistinctValuesForField(SearchFacetDaoImpl)', 'Calls', 'length(SearchFacetDaoImpl)']
# INFO: Added edge ['readDistinctValuesForField(SearchFacetDaoImpl)', 'Calls', 'length(SearchFacetDaoImpl)']
# INFO: Added edge ['isSearchFacetRangeArchivable(SearchFacetDaoImpl)', 'Calls', 'isAssignableFrom(SearchFacetDaoImpl)']
# INFO: Added edge ['readSkuByExternalId(SkuDaoImpl)', 'Calls', 'addRestriction(SkuDaoImpl)']
# INFO: Added edge ['readSkuByExternalId(SkuDaoImpl)', 'Calls', 'toQuery(SkuDaoImpl)']
# INFO: Added edge ['readSkuByUpc(SkuDaoImpl)', 'Calls', 'addRestriction(SkuDaoImpl)']
# INFO: Added edge ['readSkuByUpc(SkuDaoImpl)', 'Calls', 'toQuery(SkuDaoImpl)']
# INFO: Edge ['readSkusByIds(SkuDaoImpl)', 'Calls', 'warn(SupportLogger)'] skipped
# INFO: Added edge ['create(SkuDaoImpl)', 'Calls', 'getName(SkuDaoImpl)']
# INFO: Edge ['findSkuByURI(SkuDaoImpl)', 'Calls', 'getProxy(SkuDaoExtensionManager)'] skipped
# INFO: Added edge ['readCategoryByExternalId(CategoryDaoImpl)', 'Calls', 'addRestriction(CategoryDaoImpl)']
# INFO: Added edge ['readCategoryByExternalId(CategoryDaoImpl)', 'Calls', 'toQuery(CategoryDaoImpl)']
# INFO: Added edge ['create(CategoryDaoImpl)', 'Calls', 'getName(CategoryDaoImpl)']
# INFO: Edge ['findCategoryByURI(CategoryDaoImpl)', 'Calls', 'getProxy(CategoryDaoExtensionManager)'] skipped
# INFO: Added edge ['readProductByExternalId(ProductDaoImpl)', 'Calls', 'addRestriction(ProductDaoImpl)']
# INFO: Added edge ['readProductByExternalId(ProductDaoImpl)', 'Calls', 'toQuery(ProductDaoImpl)']
# INFO: Edge ['readProductsByIds(ProductDaoImpl)', 'Calls', 'warn(SupportLogger)'] skipped
# INFO: Added edge ['attachOrderBy(ProductDaoImpl)', 'Calls', 'toLowerCase(ProductDaoImpl)']
# INFO: Added edge ['attachOrderBy(ProductDaoImpl)', 'Calls', 'contains(ProductDaoImpl)']
# INFO: Added edge ['attachOrderBy(ProductDaoImpl)', 'Calls', 'length(ProductDaoImpl)']
# INFO: Added edge ['attachOrderBy(ProductDaoImpl)', 'Calls', 'length(ProductDaoImpl)']
# INFO: Added edge ['attachSearchCriteria(ProductDaoImpl)', 'Calls', 'length(ProductDaoImpl)']
# INFO: Added edge ['attachSearchCriteria(ProductDaoImpl)', 'Calls', 'length(ProductDaoImpl)']
# INFO: Added edge ['attachSearchCriteria(ProductDaoImpl)', 'Calls', 'length(ProductDaoImpl)']
# INFO: Added edge ['attachSearchCriteria(ProductDaoImpl)', 'Calls', 'equals(ProductDaoImpl)']
# INFO: Edge ['findProductByURI(ProductDaoImpl)', 'Calls', 'getProxy(ProductDaoExtensionManager)'] skipped
# INFO: Added edge ['readAllActiveProductIds(ProductDaoImpl)', 'Calls', 'product(ProductDaoImpl)']
# INFO: Edge ['getCriteriaForActiveProducts(ProductDaoImpl)', 'Calls', 'getProxy(SiteMapExtensionManager)'] skipped
# INFO: Added edge ['filterCandidateSkusForArchivedStatus(ProductOptionDaoImpl)', 'Calls', 'isAssignableFrom(ProductOptionDaoImpl)']
# INFO: Added edge ['attachArchivalConditionIfPossible(ProductOptionDaoImpl)', 'Calls', 'isAssignableFrom(ProductOptionDaoImpl)']
# INFO: Added edge ['readSkuMediaBySkuId(SkuMediaDaoImpl)', 'Calls', 'addRestriction(SkuMediaDaoImpl)']
# INFO: Added edge ['readSkuMediaBySkuId(SkuMediaDaoImpl)', 'Calls', 'toQuery(SkuMediaDaoImpl)']
# INFO: Added edge ['create(SiteDaoImpl)', 'Calls', 'getName(SiteDaoImpl)']
# INFO: Added edge ['retrieveCatalogByName(SiteDaoImpl)', 'Calls', 'addRestriction(SiteDaoImpl)']
# INFO: Added edge ['retrieveCatalogByName(SiteDaoImpl)', 'Calls', 'toQuery(SiteDaoImpl)']
# INFO: Added edge ['createCatalog(SiteDaoImpl)', 'Calls', 'getName(SiteDaoImpl)']
# INFO: Added edge ['createSiteCatalog(SiteDaoImpl)', 'Calls', 'getName(SiteDaoImpl)']
# INFO: Added edge ['retrieveAllCatalogs(SiteDaoImpl)', 'Calls', 'toQuery(SiteDaoImpl)']
# INFO: Added edge ['readEnumByKey(DataDrivenEnumerationDaoImpl)', 'Calls', 'addRestriction(DataDrivenEnumerationDaoImpl)']
# INFO: Added edge ['readEnumByKey(DataDrivenEnumerationDaoImpl)', 'Calls', 'toQuery(DataDrivenEnumerationDaoImpl)']
# INFO: Added edge ['readEnumValueByKey(DataDrivenEnumerationDaoImpl)', 'Calls', 'addRestriction(DataDrivenEnumerationDaoImpl)']
# INFO: Added edge ['readEnumValueByKey(DataDrivenEnumerationDaoImpl)', 'Calls', 'addRestriction(DataDrivenEnumerationDaoImpl)']
# INFO: Added edge ['readEnumValueByKey(DataDrivenEnumerationDaoImpl)', 'Calls', 'toQuery(DataDrivenEnumerationDaoImpl)']
# INFO: Edge ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Edge ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Edge ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Edge ['readAllSystemProperties(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Added edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getCachedObject(SystemPropertiesDaoImpl)']
# INFO: Edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Added edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'isAssignableFrom(SystemPropertiesDaoImpl)']
# INFO: Edge ['readSystemPropertyByName(SystemPropertiesDaoImpl)', 'Calls', 'getProxy(SystemPropertyDaoQueryExtensionManager)'] skipped
# INFO: Added edge ['createNewSystemProperty(SystemPropertiesDaoImpl)', 'Calls', 'getName(SystemPropertiesDaoImpl)']
# INFO: Added edge ['create(BroadleafCurrencyDaoImpl)', 'Calls', 'getName(BroadleafCurrencyDaoImpl)']
# INFO: Added edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Calls', 'addRestriction(SandBoxDaoImpl)']
# INFO: Added edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Calls', 'addRestriction(SandBoxDaoImpl)']
# INFO: Added edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Calls', 'addRestriction(SandBoxDaoImpl)']
# INFO: Added edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Calls', 'addRestriction(SandBoxDaoImpl)']
# INFO: Added edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Calls', 'addRestriction(SandBoxDaoImpl)']
# INFO: Added edge ['retrieveAllUserSandBoxes(SandBoxDaoImpl)', 'Calls', 'toQuery(SandBoxDaoImpl)']
# INFO: Added edge ['create(TranslationDaoImpl)', 'Calls', 'getName(TranslationDaoImpl)']
# INFO: Edge ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readTranslation(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['countTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readAllTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readConvertedTranslationEntries(TranslationDaoImpl)', 'Calls', 'getProxy(TranslationServiceExtensionManager)'] skipped
# INFO: Edge ['readGenericEntity(GenericEntityDaoImpl)', 'Calls', 'getIdMetadata(DynamicDaoHelperImpl)'] skipped
# INFO: Added edge ['readCountGenericEntity(GenericEntityDaoImpl)', 'Calls', 'toCountQuery(GenericEntityDaoImpl)']
# INFO: Added edge ['readAllGenericEntity(GenericEntityDaoImpl)', 'Calls', 'toQuery(GenericEntityDaoImpl)']
# INFO: Edge ['getCeilingImplClass(GenericEntityDaoImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)'] skipped
# INFO: Edge ['getCeilingImplClass(GenericEntityDaoImpl)', 'Calls', 'getAllPolymorphicEntitiesFromCeiling(DynamicDaoHelperImpl)'] skipped
# INFO: Edge ['getIdentifier(GenericEntityDaoImpl)', 'Calls', 'getIdentifier(DynamicDaoHelperImpl)'] skipped
# INFO: Edge ['getIdField(GenericEntityDaoImpl)', 'Calls', 'getIdField(DynamicDaoHelperImpl)'] skipped
# INFO: Added edge [ 'batchExecuteReadQuery(RatingSummaryDaoImpl)', 'Persists', 'BatchRetrieveDao']

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity BaseResponse
# Removed Entity EmailNotificationPasswordUpdatedHandler
# Removed Entity CustomerAddressPersistedEntityListener
# Removed Entity CustomerPaymentPersistedEntityListener
# Removed Entity CustomerPhonePersistedEntityListener
# Removed Entity RoleImpl
# Removed Entity ChallengeQuestionImpl
# Removed Entity CustomerPersistedEntityListener
# Removed Entity CountrySubdivisionCategoryImpl
# Removed Entity CategoryMediaMap
# Removed Entity ShippingServiceImpl
# Removed Entity SimpleFulfillmentLocationResolver
# Removed Entity FixedPriceFulfillmentPricingProvider
# Removed Entity BandedFulfillmentPricingProvider
# Removed Entity SimpleTaxProvider
# Removed Entity BandedShippingModule
# Removed Entity TaxException
# Removed Entity AutoBundleActivity
# Removed Entity ShippingActivity
# Removed Entity CompositeActivity
# Removed Entity PricingProcessContextFactory
# Removed Entity EntityIdentifierUtil
# Removed Entity ThirdPartyInteractionLatencySimulationActivity
# Removed Entity ZookeeperUtil
# Removed Entity BroadleafSitemapUtils
# Removed Entity ReentrantDistributedZookeeperLock
# Removed Entity ZookeeperDistributedQueue
# Removed Entity OrderItemPriceComparator
# Removed Entity PromotableOrderItemPriceDetailWrapper
# Removed Entity OfferOptionalDirectCopyTransformTypes
# Removed Entity AbstractBaseProcessor
# Removed Entity OfferRuleImpl
# Removed Entity OfferTargetCriteriaXrefImpl
# Removed Entity OfferItemCriteriaImpl
# Removed Entity ProratedOrderItemAdjustmentImpl
# Removed Entity FulfillmentGroupAdjustmentImpl
# Removed Entity OfferOfferRuleXrefImpl
# Removed Entity OfferQualifyingCriteriaXrefImpl
# Removed Entity CandidateItemOfferImpl
# Removed Entity CandidateOrderOfferImpl
# Removed Entity OfferInfoImpl
# Removed Entity CandidateFulfillmentGroupOfferImpl
# Removed Entity OrderAdjustmentImpl
# Removed Entity BLCPromotionMessageUtils
# Removed Entity PaymentException
# Removed Entity PaymentLogImpl
# Removed Entity GiftCardPaymentImpl
# Removed Entity CreditCardPaymentInfoImpl
# Removed Entity BankAccountPaymentImpl
# Removed Entity RatingDetailImpl
# Removed Entity ReviewFeedbackImpl
# Removed Entity PassthroughPaymentConstants
# Removed Entity CheckoutProcessContextFactory
# Removed Entity ZipCodeImpl
# Removed Entity AbstractCartRuleProcessor
# Removed Entity LegacyMergeCartServiceImpl
# Removed Entity OrderServiceException
# Removed Entity CartOperationProcessContextFactory
# Removed Entity OrderItemSplitContainer
# Removed Entity OrderItemVisitorAdapter
# Removed Entity BundleOrderItemSplitContainer
# Removed Entity BundleOrderItemFeePriceImpl
# Removed Entity TaxDetailImpl
# Removed Entity PersonalMessageImpl
# Removed Entity FulfillmentGroupFeeImpl
# Removed Entity OrderPersistedEntityListener
# Removed Entity OrderLockImpl
# Removed Entity OrderItemQualifierImpl
# Removed Entity DiscreteOrderItemFeePriceImpl
# Removed Entity OrderItemPriceDetailImpl
# Removed Entity OptionalEnterpriseBandedPriceFulfillmentOptionTemplate
# Removed Entity OptionalEnterpriseBandedWeightFulfillmentOptionTemplate
# Removed Entity NullFulfillmentGroupItemStrategyImpl
# Removed Entity SearchContextDTO
# Removed Entity DelegatingHttpSolrClient
# Removed Entity AbstractSolrIndexUpdateCommandHandlerImpl
# Removed Entity CategorySearchFacetImpl
# Removed Entity CategoryExcludedSearchFacetImpl
# Removed Entity SearchQuery
# Removed Entity SearchInterceptImpl
# Removed Entity RequiredFacetImpl
# Removed Entity SearchSynonymImpl
# Removed Entity ProductsByCategoryWithOrder
# Removed Entity SkuAvailabilityImpl
# Removed Entity UserConnectionImpl
# Removed Entity UpSaleProductImpl
# Removed Entity FeaturedProductImpl
# Removed Entity SkuAttributeImpl
# Removed Entity WeaveSkuMinOrderQuantity
# Removed Entity CrossSaleProductImpl
# Removed Entity CategoryAttributeImpl
# Removed Entity SkuMediaXrefImpl
# Removed Entity CategoryXrefImpl
# Removed Entity WeaveProductSkuUsage
# Removed Entity ProductAttributeImpl
# Removed Entity CategoryMediaXrefImpl
# Removed Entity SkuFeeImpl
# Removed Entity BaseExtensionActivity
# Removed Entity BaseActivity
# Removed Entity PassThroughActivity
# Removed Entity CustomerStateInterceptor
# Removed Entity SessionFixationProtectionCookie
# Removed Entity RestApiCustomerStateFilter
# Removed Entity EmailClickTrackingFilter
# Removed Entity EmailOpenTrackingServlet
# Removed Entity WrappingViewResolver
# Removed Entity AbstractBreadcrumbServiceExtensionHandler
# Removed Entity ProcessorUtils
# Removed Entity AbstractLinkedDataGenerator
# Removed Entity AbstractCurrencyConversionPricingFilter
# Removed Entity ResetPasswordForm
# Removed Entity ChangePasswordForm
# Removed Entity UpdateAccountForm
# Removed Entity ReviewForm
# Removed Entity BroadleafRatingsController
# Removed Entity AbstractSeoPropertyGenerator
# Removed Entity CustomerCreditInfoForm
# Removed Entity MultiShipInstructionForm
# Removed Entity FrameworkWebProperties
# Removed Entity OrderVariableExpression
# Removed Entity DatabaseOrderLockManager
# Removed Entity OrderStateAOP
# Removed Entity SessionOrderLockManager
# Removed Entity OrderState
# Removed Entity BroadleafAuthenticationSuccessHandler
# Removed Entity CartStateInterceptor
# Removed Entity SearchFilterUtil
# Removed Entity DynamicSkuPricingInterceptor
# Removed Entity BroadleafCommonAddressValidator
# Removed Entity TimeDTO
# Removed Entity InstrumentationRuntimeFactory
# Removed Entity TimedValueHolder
# Removed Entity ImportProcessor
# Removed Entity MergeManager
# Removed Entity MergePoint
# Removed Entity MergeException
# Removed Entity MergeManagerSetupException
# Removed Entity MergeHandlerAdapter
# Removed Entity PropertyConfigurer
# Removed Entity JPAPropertiesPersistenceUnitPostProcessor
# Removed Entity AutoDDLCreateStatusTestBeanImpl
# Removed Entity QueryConfigurationClassTransformer
# Removed Entity EntityClassNotFoundException
# Removed Entity JCachePersistenceUnitPostProcessor
# Removed Entity DirectCopyTransformTypes
# Removed Entity NullClassTransformer
# Removed Entity AbstractCacheMissAware
# Removed Entity NoOpStatisticsServiceLogAdapter
# Removed Entity HydratedSetup
# Removed Entity Log4j2StatisticsServiceLogAdapter
# Removed Entity CacheFactoryException
# Removed Entity MediaImpl
# Removed Entity MediaDto
# Removed Entity SiteCatalogXrefImpl
# Removed Entity ThemeDTO
# Removed Entity RandomGenerator
# Removed Entity BroadleafExternalAuthenticationUserDetails
# Removed Entity LocalRedirectStrategy
# Removed Entity BroadleafAuthenticationFailureHandler
# Removed Entity ProtoInsecureChannelProcessor
# Removed Entity ProtoChannelBeanPostProcessor
# Removed Entity ProtoSecureChannelProcessor
# Removed Entity ServerCookie
# Removed Entity PasswordUtils
# Removed Entity BroadleafActiveDirectoryUserDetailsMapper
# Removed Entity SecurityFilter
# Removed Entity CsrfFilter
# Removed Entity NullBroadleafEnumerationType
# Removed Entity RuleIdentifier
# Removed Entity RuleOperatorType
# Removed Entity RuleOptionType
# Removed Entity PropertyType
# Removed Entity BroadleafFileUtils
# Removed Entity MetadataMBeanInfoAssembler
# Removed Entity ExplicitNameFactoryBean
# Removed Entity AnnotationJmxAttributeSource
# Removed Entity MetadataNamingStrategy
# Removed Entity AspectUtil
# Removed Entity Log4j2ManagementBean
# Removed Entity Log4jManagementBean
# Removed Entity DisableSupportLoggerAdapter
# Removed Entity SupportLogManager
# Removed Entity ModuleLifecycleLoggingBean
# Removed Entity LocaleUtil
# Removed Entity LocaleConverter
# Removed Entity BreadcrumbHandlerDefaultPriorities
# Removed Entity ExtensionManager
# Removed Entity CreateResponse
# Removed Entity MultiTenantCopier
# Removed Entity ReflectiveWorkOnChange
# Removed Entity StatCalc
# Removed Entity EnvironmentFactoryBean
# Removed Entity BLCFileSystemUtils
# Removed Entity Tuple
# Removed Entity InvocationHandlerForUnitTestingByteWeavedClasses
# Removed Entity GenericOperationUtil
# Removed Entity BLCArrayUtils
# Removed Entity BLCPaymentMethodUtils
# Removed Entity UrlUtil
# Removed Entity OptimisticLockUtils
# Removed Entity PomEvaluator
# Removed Entity NodeUtil
# Removed Entity UpdateExecutor
# Removed Entity UnknownUnwrapTypeException
# Removed Entity BLCNumberUtils
# Removed Entity BLCCronUtils
# Removed Entity EntityManagerAwareRunnable
# Removed Entity TransactionUtils
# Removed Entity DateUtil
# Removed Entity BLCMapUtils
# Removed Entity BLCMoneyFormatUtils
# Removed Entity BLCAnnotationUtils
# Removed Entity BLCDateUtils
# Removed Entity HibernateUtils
# Removed Entity EfficientLRUMap
# Removed Entity UnitOfMeasureUtil
# Removed Entity ResourceBundleExtensionPoint
# Removed Entity NullFactoryBean
# Removed Entity ContextVariableNames
# Removed Entity PropertyDrivenBeanFactory
# Removed Entity BLResourceBundleMessageSource
# Removed Entity BLCFieldUtils
# Removed Entity FormatUtil
# Removed Entity SortedListFactoryBean
# Removed Entity IgnorableItem
# Removed Entity Mod43CheckDigitUtil
# Removed Entity TypedPredicate
# Removed Entity StringUtil
# Removed Entity BLCRequestUtils
# Removed Entity BroadleafMergeResourceBundleMessageSource
# Removed Entity ThreadUtils
# Removed Entity ValidationUtil
# Removed Entity SpringAppContext
# Removed Entity BLCCollectionUtils
# Removed Entity IdentityExecutionUtils
# Removed Entity ISO8601DateAdapter
# Removed Entity BigDecimalRoundingAdapter
# Removed Entity DynamicDaoHelperImpl
# Removed Entity HibernateMappingProvider
# Removed Entity CreditCardTypeCheck
# Removed Entity TransparentRedirectConstants
# Removed Entity AbstractPaymentGatewayTransactionConfirmationService
# Removed Entity AbstractPaymentGatewayFraudService
# Removed Entity AbstractPaymentGatewayConfiguration
# Removed Entity AbstractPaymentGatewaySubscriptionService
# Removed Entity AbstractPaymentGatewayTransactionService
# Removed Entity AbstractPaymentGatewayTransparentRedirectService
# Removed Entity AbstractPaymentGatewayClientTokenService
# Removed Entity AbstractPaymentGatewayWebResponseService
# Removed Entity AbstractPaymentGatewayHostedService
# Removed Entity AbstractPaymentGatewayRollbackService
# Removed Entity AbstractExternalPaymentGatewayCall
# Removed Entity AbstractPaymentGatewayReportingService
# Removed Entity AbstractPaymentGatewayCreditCardService
# Removed Entity AbstractPaymentGatewayCustomerService
# Removed Entity AbstractPaymentGatewayConfigurationService
# Removed Entity AddressDTO
# Removed Entity GatewayCustomerDTO
# Removed Entity SubscriptionDTO
# Removed Entity CreditCardDTO
# Removed Entity GiftCardDTO
# Removed Entity CustomerCreditDTO
# Removed Entity BankersRounding
# Removed Entity CurrencyConsiderationContext
# Removed Entity CurrencyConversionContext
# Removed Entity CurrencyAdapter
# Removed Entity LoggingMailSender
# Removed Entity NullEmailServiceImpl
# Removed Entity JMSEmailServiceProducerImpl
# Removed Entity EmailTrackingOpensImpl
# Removed Entity EmailTargetImpl
# Removed Entity EmailTrackingImpl
# Removed Entity EmailTrackingClicksImpl
# Removed Entity DataDrivenEnumerationValueImpl
# Removed Entity DataDrivenEnumerationImpl
# Removed Entity AbstractRuleProcessor
# Removed Entity MvelHelper
# Removed Entity SelectizeCollectionUtils
# Removed Entity DefaultTimeSource
# Removed Entity SystemTime
# Removed Entity TemporalTimestampListener
# Removed Entity AutoImportPersistenceUnit
# Removed Entity AutoImportStage
# Removed Entity ImportCondition
# Removed Entity DemoCondition
# Removed Entity MTCondition
# Removed Entity BroadleafCommonPropertySource
# Removed Entity BroadleafBeanNameGenerator
# Removed Entity PostAutoConfigurationDefferedImportSelector
# Removed Entity DefaultOrderFrameworkCommonClasspathPropertySource
# Removed Entity AdminOnlyTarget
# Removed Entity DefaultRuntimeEnvironmentProfileAwarePropertySource
# Removed Entity IdGenerationImpl
# Removed Entity AbstractVendorService
# Removed Entity LogStatusHandler
# Removed Entity CompositeStatusHandler
# Removed Entity ServiceResponseCache
# Removed Entity BroadleafCurrencyUtils
# Removed Entity BroadleafCurrencyImpl
# Removed Entity NullBroadleafCurrency
# Removed Entity HibernateBridgingQueryHints
# Removed Entity QueryHelperHints
# Removed Entity IdOverrideTableGenerator
# Removed Entity AbstractEntityDuplicationHelper
# Removed Entity OracleSessionIdTransactionInfoModifier
# Removed Entity TransactionLifecycleAwareSqlStatementLogger
# Removed Entity LifecycleAwareJDBCServices
# Removed Entity BroadleafCommonServiceContributor
# Removed Entity Broadleaf2CompatibilityMySQL5InnoDBDialect
# Removed Entity BroadleafPostgreSQLDialect
# Removed Entity DemoHSQLDialect
# Removed Entity PostgreSQLClobTypeDescriptor
# Removed Entity SiteMapUrlEntryImpl
# Removed Entity OptionalEnterpriseSiteMapConfigurationSiteMapGeneratorConfigurationTemplate
# Removed Entity BroadleafSiteMapController
# Removed Entity SiteMapException
# Removed Entity OnBroadleafModuleCondition
# Removed Entity OnMissingBroadleafModuleCondition
# Removed Entity MapElementWrapper
# Removed Entity BaseWrapper
# Removed Entity PassthroughEncryptionModule
# Removed Entity AtomicMoveImpl
# Removed Entity AbstractBroadleafApplicationEventListener
# Removed Entity BroadleafApplicationEventMulticaster
# Removed Entity DynamicTranslationProvider
# Removed Entity TranslationBatchReadCache
# Removed Entity BroadleafCookieLocaleResolver
# Removed Entity JsonResponse
# Removed Entity NullBroadleafThemeResolver
# Removed Entity BroadleafRequestInterceptor
# Removed Entity BaseUrlResolverImpl
# Removed Entity NullBroadleafSiteResolver
# Removed Entity DeepLink
# Removed Entity DeepLinkService
# Removed Entity BroadleafBootServletContextInitializer
# Removed Entity SpringBootBootstrappingServletContextListener
# Removed Entity TranslationInterceptor
# Removed Entity IgnorableOpenEntityManagerInViewFilter
# Removed Entity FilterOrdered
# Removed Entity AbstractIgnorableFilter
# Removed Entity EntityManagerFindValidationFilter
# Removed Entity StatusExposingServletResponse
# Removed Entity RepeatSubmitProtectionFilter
# Removed Entity ServletOutputStreamWrapper
# Removed Entity BroadleafUrlParamUtils
# Removed Entity PrecompressedArtifactFilter
# Removed Entity FrameworkMvcUriComponentsBuilder
# Removed Entity BroadleafRedirectController
# Removed Entity BroadleafControllerUtility
# Removed Entity AbstractGeneratedResourceHandler
# Removed Entity BroadleafResourceTransformerOrder
# Removed Entity BroadleafResourceResolverOrder
# Removed Entity AbstractResourceProcessor
# Removed Entity ModulePresentUtil
# Removed Entity OptimisticLockInvalidStateException
# Removed Entity ProxyDetectionException
# Removed Entity NoPossibleResultsException
# Removed Entity OptimisticLockMaxRetryException
# Removed Entity SiteNotFoundException
# Removed Entity TranslatableException
# Removed Entity ExceptionHelper
# Removed setMustValidateAddresses (AddressServiceImpl)
# Removed generateSecurePassword (CustomerServiceImpl)
# Removed removePostRegisterListener (CustomerServiceImpl)
# Removed setCustomerDao (CustomerServiceImpl)
# Removed getPasswordResetHandlers (CustomerServiceImpl)
# Removed setPasswordResetHandlers (CustomerServiceImpl)
# Removed getPasswordChangedHandlers (CustomerServiceImpl)
# Removed setPasswordChangedHandlers (CustomerServiceImpl)
# Removed getTokenExpiredMinutes (CustomerServiceImpl)
# Removed setTokenExpiredMinutes (CustomerServiceImpl)
# Removed setPasswordTokenLength (CustomerServiceImpl)
# Removed validate (RegistrationValidator)
# Removed getValidNameRegex (RegistrationValidator)
# Removed getValidPasswordRegex (RegistrationValidator)
# Removed supports (RegistrationValidator)
# Removed validate (ResetPasswordValidator)
# Removed supports (ResetPasswordValidator)
# Removed isAsynchronous (NotificationRegisterCustomerEventListener)
# Removed isAsynchronous (NotificationForgotPasswordEventListener)
# Removed isAsynchronous (NotificationForgotUsernameEventListener)
# Removed getProviders (FulfillmentPricingServiceImpl)
# Removed setProviders (FulfillmentPricingServiceImpl)
# Removed setTaxProviders (TaxServiceImpl)
# Removed setMustCalculate (TaxServiceImpl)
# Removed setTaxModule (TaxActivity)
# Removed setTaxService (TaxActivity)
# Removed getCurrency (FulfillmentItemPricingActivity)
# Removed setFulfillmentPricingService (FulfillmentGroupPricingActivity)
# Removed continueOnHandled (ResourcePurgeExtensionManager)
# Removed findRelatedQualifierRoot (OfferServiceUtilitiesImpl)
# Removed itemOfferCanBeApplied (OfferServiceUtilitiesImpl)
# Removed markTargetsForCriteria (OfferServiceUtilitiesImpl)
# Removed markTargetsForOfferPriceData (OfferServiceUtilitiesImpl)
# Removed getPromotableItemFactory (OfferServiceUtilitiesImpl)
# Removed setPromotableItemFactory (OfferServiceUtilitiesImpl)
# Removed getOfferDao (OfferServiceUtilitiesImpl)
# Removed setOfferDao (OfferServiceUtilitiesImpl)
# Removed getGenericEntityService (OfferServiceUtilitiesImpl)
# Removed setGenericEntityService (OfferServiceUtilitiesImpl)
# Removed getCustomerOfferDao (OfferServiceImpl)
# Removed setCustomerOfferDao (OfferServiceImpl)
# Removed getOfferCodeDao (OfferServiceImpl)
# Removed setOfferCodeDao (OfferServiceImpl)
# Removed getOfferDao (OfferServiceImpl)
# Removed setOfferDao (OfferServiceImpl)
# Removed getOrderOfferProcessor (OfferServiceImpl)
# Removed setOrderOfferProcessor (OfferServiceImpl)
# Removed getItemOfferProcessor (OfferServiceImpl)
# Removed setItemOfferProcessor (OfferServiceImpl)
# Removed getFulfillmentGroupOfferProcessor (OfferServiceImpl)
# Removed setFulfillmentGroupOfferProcessor (OfferServiceImpl)
# Removed getPromotableItemFactory (OfferServiceImpl)
# Removed setPromotableItemFactory (OfferServiceImpl)
# Removed getOrderService (OfferServiceImpl)
# Removed setOrderService (OfferServiceImpl)
# Removed canHandle (OfferDuplicateModifier)
# Removed calculatePotentialSavings (OfferServiceExtensionManager)
# Removed resetPriceDetails (OfferServiceExtensionManager)
# Removed applyItemOffer (OfferServiceExtensionManager)
# Removed synchronizeAdjustmentsAndPrices (OfferServiceExtensionManager)
# Removed chooseSaleOrRetailAdjustments (OfferServiceExtensionManager)
# Removed applyAdditionalRuleVariablesForItemOfferEvaluation (OfferServiceExtensionManager)
# Removed addAdditionalOffersForCode (OfferServiceExtensionManager)
# Removed isEnabled (OfferServiceExtensionManager)
# Removed init (PromotableItemFactoryImpl)
# Removed isTotalitarianOfferAppliedToAnyItem (ItemOfferProcessorImpl)
# Removed restPriceDetails (ItemOfferProcessorImpl)
# Removed removeTrailingNotCombinableOrderOffers (OrderOfferProcessorImpl)
# Removed getPromotableItemFactory (OrderOfferProcessorImpl)
# Removed setPromotableItemFactory (OrderOfferProcessorImpl)
# Removed setOfferDao (OrderOfferProcessorImpl)
# Removed setOrderItemDao (OrderOfferProcessorImpl)
# Removed getOfferServiceUtilities (OrderOfferProcessorImpl)
# Removed setOfferServiceUtilities (OrderOfferProcessorImpl)
# Removed setUseBillingAddressFromGateway (DefaultPaymentGatewayCheckoutService)
# Removed isPerformAuthorizeAndCapture (PassthroughPaymentConfigurationImpl)
# Removed setPerformAuthorizeAndCapture (PassthroughPaymentConfigurationImpl)
# Removed getFailureReportingThreshold (PassthroughPaymentConfigurationImpl)
# Removed setFailureReportingThreshold (PassthroughPaymentConfigurationImpl)
# Removed handlesAuthorize (PassthroughPaymentConfigurationImpl)
# Removed handlesCapture (PassthroughPaymentConfigurationImpl)
# Removed handlesAuthorizeAndCapture (PassthroughPaymentConfigurationImpl)
# Removed handlesReverseAuthorize (PassthroughPaymentConfigurationImpl)
# Removed handlesVoid (PassthroughPaymentConfigurationImpl)
# Removed handlesRefund (PassthroughPaymentConfigurationImpl)
# Removed handlesPartialCapture (PassthroughPaymentConfigurationImpl)
# Removed handlesMultipleShipment (PassthroughPaymentConfigurationImpl)
# Removed handlesRecurringPayment (PassthroughPaymentConfigurationImpl)
# Removed handlesSavedCustomerPayment (PassthroughPaymentConfigurationImpl)
# Removed handlesMultiplePayments (PassthroughPaymentConfigurationImpl)
# Removed getConfiguration (PassthroughPaymentConfigurationServiceImpl)
# Removed getTransactionService (PassthroughPaymentConfigurationServiceImpl)
# Removed transactionIsDetachedCreditRequest (OrderPaymentConfirmationStrategyImpl)
# Removed determineSubmitDate (CompleteOrderActivity)
# Removed determineOrderNumber (CompleteOrderActivity)
# Removed setDeleteEmptyNamedOrders (OrderServiceImpl)
# Removed findLastMatchingItem (OrderServiceImpl)
# Removed setAutomaticallyMergeLikeItems (OrderServiceImpl)
# Removed isMoveNamedOrderItems (OrderServiceImpl)
# Removed setMoveNamedOrderItems (OrderServiceImpl)
# Removed isDeleteEmptyNamedOrders (OrderServiceImpl)
# Removed init (CartMessageOrderItemServiceExtensionHandler)
# Removed getPriority (CartMessageOrderItemServiceExtensionHandler)
# Removed continueOnHandled (MergeCartServiceExtensionManager)
# Removed getFulfillmentGroupItemsForOrderItem (FulfillmentGroupServiceImpl)
# Removed continueOnHandled (OrderServiceExtensionManager)
# Removed attachAdditionalDataToNewNamedCart (OrderServiceExtensionManager)
# Removed attachAdditionalDataToOrder (OrderServiceExtensionManager)
# Removed addOfferCodes (OrderServiceExtensionManager)
# Removed isEnabled (OrderServiceExtensionManager)
# Removed shouldValidateWithException (OrderItemRequestValidationServiceImpl)
# Removed shouldValidateWithException (ValidateAddRequestActivity)
# Removed setRemoveEmptyFulfillmentGroups (FulfillmentGroupItemStrategyImpl)
# Removed isAsynchronous (NotificationOrderSubmittedEventListener)
# Removed continueOnHandled (OrderDaoExtensionManager)
# Removed isActive (DatabaseSearchServiceImpl)
# Removed isCustomFieldIndexed (MvelToSearchCriteriaConversionServiceImpl)
# Removed getGlobalFacetTagField (SolrHelperServiceImpl)
# Removed getProductForIndexable (SolrHelperServiceImpl)
# Removed getCatalogOverridesFieldName (SolrHelperServiceImpl)
# Removed getSandBoxFieldName (SolrHelperServiceImpl)
# Removed getSandBoxPriorityFieldName (SolrHelperServiceImpl)
# Removed getSandBoxChangeTypeFieldName (SolrHelperServiceImpl)
# Removed sanitizeQuery (SolrHelperServiceImpl)
# Removed getResponseDocuments (SolrHelperServiceImpl)
# Removed init (I18nSolrSearchServiceExtensionHandler)
# Removed getPriority (I18nSolrSearchServiceExtensionHandler)
# Removed init (I18nSolrIndexServiceExtensionHandler)
# Removed endBatchEvent (I18nSolrIndexServiceExtensionHandler)
# Removed getPriority (I18nSolrIndexServiceExtensionHandler)
# Removed afterPropertiesSet (SolrIndexServiceImpl)
# Removed convertToMappedProperty (SolrIndexServiceImpl)
# Removed useLegacyIndexer (SolrIndexServiceImpl)
# Removed canHandleSiteMapConfiguration (CategorySiteMapGenerator)
# Removed getCategoryDao (CategorySiteMapGenerator)
# Removed setCategoryDao (CategorySiteMapGenerator)
# Removed getRowLimit (CategorySiteMapGenerator)
# Removed setRowLimit (CategorySiteMapGenerator)
# Removed canHandleSiteMapConfiguration (SkuSiteMapGenerator)
# Removed getSkuDao (SkuSiteMapGenerator)
# Removed setSkuDao (SkuSiteMapGenerator)
# Removed getPageSize (SkuSiteMapGenerator)
# Removed setPageSize (SkuSiteMapGenerator)
# Removed canHandleSiteMapConfiguration (ProductSiteMapGenerator)
# Removed getProductDao (ProductSiteMapGenerator)
# Removed setProductDao (ProductSiteMapGenerator)
# Removed getPageSize (ProductSiteMapGenerator)
# Removed setPageSize (ProductSiteMapGenerator)
# Removed canHandle (ProductDuplicateModifier)
# Removed init (DuplicationValidatorExtensionHandlerImpl)
# Removed getPriority (DuplicationValidatorExtensionHandlerImpl)
# Removed isEnabled (DuplicationValidatorExtensionHandlerImpl)
# Removed validateDuplicate (DuplicationValidatorExtensionHandlerImpl)
# Removed addToSandbox (DuplicationValidatorExtensionHandlerImpl)
# Removed tearDownDuplicate (DuplicationValidatorExtensionHandlerImpl)
# Removed setProductDao (CatalogServiceImpl)
# Removed setSkuDao (CatalogServiceImpl)
# Removed setCategoryDao (CatalogServiceImpl)
# Removed setBeanName (DefaultErrorHandler)
# Removed getUnloggedExceptionClasses (DefaultErrorHandler)
# Removed setUnloggedExceptionClasses (DefaultErrorHandler)
# Removed setBeanName (SilentErrorHandler)
# Removed getStateManager (ActivityStateManagerImpl)
# Removed init (ActivityStateManagerImpl)
# Removed isIgnored (CustomerStateFilter)
# Removed getOrder (CustomerStateFilter)
# Removed shouldNotFilterErrorDispatch (CustomerStateFilter)
# Removed setCustomer (CustomerState)
# Removed setApplicationEventPublisher (CustomerStateRequestProcessor)
# Removed getCustomerRequestAttributeName (CustomerStateRequestProcessor)
# Removed getName (CustomerVariableExpression)
# Removed getCurrent (CustomerVariableExpression)
# Removed setCustomerPhoneService (CustomerPhoneController)
# Removed setCustomerPhoneValidator (CustomerPhoneController)
# Removed setCustomerState (CustomerPhoneController)
# Removed setdeletePhoneSuccessView (CustomerPhoneController)
# Removed setEntityConfiguration (CustomerPhoneController)
# Removed setmakePhoneDefaultSuccessView (CustomerPhoneController)
# Removed setPhoneFormatter (CustomerPhoneController)
# Removed setPhoneValidator (CustomerPhoneController)
# Removed setsavePhoneErrorView (CustomerPhoneController)
# Removed setsavePhoneSuccessView (CustomerPhoneController)
# Removed setviewPhoneErrorView (CustomerPhoneController)
# Removed setviewPhoneSuccessView (CustomerPhoneController)
# Removed registerCustomerSuccess (RegisterCustomerController)
# Removed setRegistrationErrorView (RegisterCustomerController)
# Removed setRegistrationSuccessView (RegisterCustomerController)
# Removed getRegisterCustomerValidator (RegisterCustomerController)
# Removed setRegisterCustomerValidator (RegisterCustomerController)
# Removed getDisplayRegistrationFormView (RegisterCustomerController)
# Removed setDisplayRegistrationFormView (RegisterCustomerController)
# Removed getValidatePasswordExpression (RegisterCustomerValidator)
# Removed setValidatePasswordExpression (RegisterCustomerValidator)
# Removed supports (CustomerPhoneValidator)
# Removed supports (PhoneValidator)
# Removed destroy (XssFilter)
# Removed init (XssFilter)
# Removed getOrder (XssFilter)
# Removed init (SimpleSearchBreadcrumbServiceExtensionHandler)
# Removed getDefaultPriority (SimpleSearchBreadcrumbServiceExtensionHandler)
# Removed init (CategoryBreadcrumbServiceExtensionHandler)
# Removed getDefaultPriority (CategoryBreadcrumbServiceExtensionHandler)
# Removed init (ProductBreadcrumbServiceExtensionHandler)
# Removed getDefaultPriority (ProductBreadcrumbServiceExtensionHandler)
# Removed init (HomePageBreadcrumbServiceExtensionHandler)
# Removed getDefaultPriority (HomePageBreadcrumbServiceExtensionHandler)
# Removed init (i18nUpdateCartServiceExtensionHandler)
# Removed getOrder (GeolocationFilter)
# Removed canHandle (DefaultLinkedDataGeneratorImpl)
# Removed canHandle (HomepageLinkedDataGeneratorImpl)
# Removed init (DefaultLinkedDataGeneratorExtensionHandler)
# Removed getPriority (DefaultLinkedDataGeneratorExtensionHandler)
# Removed canHandle (CategoryLinkedDataGeneratorImpl)
# Removed canHandle (ProductLinkedDataGeneratorImpl)
# Removed getName (LinkedDataProcessor)
# Removed continueOnHandled (ConfirmationControllerExtensionManager)
# Removed continueOnHandled (BroadleafCheckoutControllerExtensionManager)
# Removed supports (USCustomerAddressValidator)
# Removed validate (USCustomerAddressValidator)
# Removed validate (ChangePasswordValidator)
# Removed getValidPasswordRegex (ChangePasswordValidator)
# Removed supports (ChangePasswordValidator)
# Removed validate (AccountPaymentInfoFormValidator)
# Removed validate (UpdateAccountValidator)
# Removed supports (UpdateAccountValidator)
# Removed supports (CustomerAddressValidator)
# Removed filterForSeoProperties (BasicSeoPropertyGeneratorImpl)
# Removed getProductTitlePattern (SeoDefaultPropertyServiceImpl)
# Removed getCategoryTitlePattern (SeoDefaultPropertyServiceImpl)
# Removed getProductDescriptionPattern (SeoDefaultPropertyServiceImpl)
# Removed getCategoryDescriptionPattern (SeoDefaultPropertyServiceImpl)
# Removed validate (CreditCardInfoFormValidator)
# Removed validate (USShippingInfoFormValidator)
# Removed validate (USBillingInfoFormValidator)
# Removed validate (USMultishipAddAddressFormValidator)
# Removed getName (PaginationSortLinkProcessor)
# Removed getPrecedence (PaginationSortLinkProcessor)
# Removed getModifiedAttributes (PaginationSortLinkProcessor)
# Removed getName (GoogleEndTagManagerProcessor)
# Removed getPrecedence (GoogleEndTagManagerProcessor)
# Removed getName (OnePageCheckoutProcessor)
# Removed getPrecedence (OnePageCheckoutProcessor)
# Removed useGlobalScope (OnePageCheckoutProcessor)
# Removed getName (GoogleUniversalAnalyticsProcessor)
# Removed getPrecedence (GoogleUniversalAnalyticsProcessor)
# Removed setMasterWebPropertyId (GoogleUniversalAnalyticsProcessor)
# Removed getName (ProductOptionDisplayProcessor)
# Removed getPrecedence (ProductOptionDisplayProcessor)
# Removed useGlobalScope (ProductOptionDisplayProcessor)
# Removed populateModelVariables (ProductOptionDisplayProcessor)
# Removed getName (UncacheableDataProcessor)
# Removed getPrecedence (UncacheableDataProcessor)
# Removed defineOutOfStockProducts (UncacheableDataProcessor)
# Removed isBlockingAvailabilityOfProduct (UncacheableDataProcessor)
# Removed isBundle (UncacheableDataProcessor)
# Removed setDefaultCallbackFunction (UncacheableDataProcessor)
# Removed getName (NamedOrderProcessor)
# Removed getPrecedence (NamedOrderProcessor)
# Removed getName (PaginationPageLinkProcessor)
# Removed getPrecedence (PaginationPageLinkProcessor)
# Removed getName (AddSortLinkProcessor)
# Removed getPrecedence (AddSortLinkProcessor)
# Removed getName (ProductOptionsProcessor)
# Removed getPrecedence (ProductOptionsProcessor)
# Removed getName (CatalogRelativeHrefProcessor)
# Removed getPrecedence (CatalogRelativeHrefProcessor)
# Removed getName (RatingsProcessor)
# Removed getPrecedence (RatingsProcessor)
# Removed getName (ToggleFacetLinkProcessor)
# Removed getPrecedence (ToggleFacetLinkProcessor)
# Removed getName (GoogleTagManagerProcessor)
# Removed getPrecedence (GoogleTagManagerProcessor)
# Removed getName (CategoriesProcessor)
# Removed getPrecedence (CategoriesProcessor)
# Removed getName (PaginationSizeLinkProcessor)
# Removed getPrecedence (PaginationSizeLinkProcessor)
# Removed getModifiedAttributes (PaginationSizeLinkProcessor)
# Removed getName (PriceTextDisplayProcessor)
# Removed getPrecedence (PriceTextDisplayProcessor)
# Removed getName (ProductOptionValueProcessor)
# Removed getPrecedence (ProductOptionValueProcessor)
# Removed getModifiedAttributes (ProductOptionValueProcessor)
# Removed useSingleQuotes (ProductOptionValueProcessor)
# Removed getName (RemoveFacetValuesLinkProcessor)
# Removed getPrecedence (RemoveFacetValuesLinkProcessor)
# Removed getName (SeoElementVariableExpression)
# Removed getTitle (SeoElementVariableExpression)
# Removed getDescription (SeoElementVariableExpression)
# Removed getName (PromotionMessageVariableExpression)
# Removed getName (SeoVariableExpression)
# Removed getName (RelatedProductsVariableExpression)
# Removed getName (BLCVariableExpression)
# Removed getName (BasicAddressVariableExpression)
# Removed getName (CheckoutFormVariableExpression)
# Removed getName (FulfillmentVariableExpression)
# Removed getName (PaymentMethodVariableExpression)
# Removed getExpirationMonthOptions (PaymentMethodVariableExpression)
# Removed getExpirationYearOptions (PaymentMethodVariableExpression)
# Removed getName (CheckoutStageVariableExpression)
# Removed getCart (CartState)
# Removed setCart (CartState)
# Removed getCartRequestAttributeName (CartStateRequestProcessor)
# Removed setCartRequestAttributeName (CartStateRequestProcessor)
# Removed getOrder (CartStateFilter)
# Removed getExcludedOrderLockRequestPatterns (CartStateFilter)
# Removed setExcludedOrderLockRequestPatterns (CartStateFilter)
# Removed shouldNotFilterErrorDispatch (CartStateFilter)
# Removed getMergeCartResponseKey (MergeCartProcessorImpl)
# Removed setMergeCartResponseKey (MergeCartProcessorImpl)
# Removed continueOnHandled (AuthSuccessHandlerExtensionManager)
# Removed signIn (BroadleafSocialSignInAdapter)
# Removed updateLoginErrorUrlForAjax (BroadleafAuthenticationSuccessRedirectStrategy)
# Removed setRedirectPath (BroadleafAuthenticationSuccessRedirectStrategy)
# Removed setRedirectStrategy (BroadleafAuthenticationSuccessRedirectStrategy)
# Removed getRedirectStrategy (BroadleafAuthenticationFailureRedirectStrategy)
# Removed setRedirectStrategy (BroadleafAuthenticationFailureRedirectStrategy)
# Removed continueOnHandled (BroadleafCommonAddressValidatorExtensionManager)
# Removed doFilterUnlessIgnored (EstablishSessionFilter)
# Removed isIgnored (EstablishSessionFilter)
# Removed getOrder (EstablishSessionFilter)
# Removed continueOnHandled (DatabaseResourceResolverExtensionManager)
# Removed getJCacheUri (DefaultJCacheUriProvider)
# Removed getCache (DefaultEhCacheUtil)
# Removed createCache (DefaultEhCacheUtil)
# Removed setApplicationContext (DefaultEhCacheUriProvider)
# Removed setConfigLocations (DefaultEhCacheUriProvider)
# Removed isProcessingEnabled (MultiTenantMergeBeanStatusProvider)
# Removed postProcessBeanFactory (MergeAnnotationAwareBeanDefinitionRegistryPostProcessor)
# Removed compileJPAProperties (MaterializedClobTypeClassTransformer)
# Removed groomCacheBySiteOverride (DefaultOverridePreCacheServiceImpl)
# Removed groomCacheByTargetEntity (DefaultOverridePreCacheServiceImpl)
# Removed refreshCache (DefaultOverridePreCacheServiceImpl)
# Removed getAppName (StatisticsServiceImpl)
# Removed setAppName (StatisticsServiceImpl)
# Removed getAttributes (StatisticsServiceImpl)
# Removed getObjectName (StatisticsServiceImpl)
# Removed getMBeanInfo (StatisticsServiceImpl)
# Removed setAdapter (StatisticsServiceImpl)
# Removed sendRedirectOnStateChange (StaleStateProtectionServiceImpl)
# Removed hasHTMLTags (ExploitProtectionServiceImpl)
# Removed htmlDecode (ExploitProtectionServiceImpl)
# Removed setXssProtectionEnabled (ExploitProtectionServiceImpl)
# Removed shouldUseSecureCookieIfApplicable (GenericCookieUtilsImpl)
# Removed getTempFileSystemBaseDirectory (BroadleafFileServiceImpl)
# Removed setTempFileSystemBaseDirectory (BroadleafFileServiceImpl)
# Removed getFileServiceProviders (BroadleafFileServiceImpl)
# Removed setFileServiceProviders (BroadleafFileServiceImpl)
# Removed getMaxGeneratedDirectoryDepth (BroadleafFileServiceImpl)
# Removed setMaxGeneratedDirectoryDepth (BroadleafFileServiceImpl)
# Removed getDefaultFileServiceProvider (BroadleafFileServiceImpl)
# Removed setDefaultFileServiceProvider (BroadleafFileServiceImpl)
# Removed setStaticAssetUrlPrefix (StaticAssetPathServiceImpl)
# Removed setStaticAssetEnvironmentUrlPrefix (StaticAssetPathServiceImpl)
# Removed setStaticAssetEnvironmentSecureUrlPrefix (StaticAssetPathServiceImpl)
# Removed continueOnHandled (TemplateOverrideExtensionManager)
# Removed sortHandlers (BreadcrumbServiceExtensionManager)
# Removed getName (BreadcrumbProcessor)
# Removed getPrecedence (BreadcrumbProcessor)
# Removed isEnabled (TemplateCacheExtensionManager)
# Removed getTemplateCacheKey (TemplateCacheExtensionManager)
# Removed getTemplateName (TemplateCacheExtensionManager)
# Removed isEnabled (TemplateOnlyQueryExtensionManager)
# Removed refineOrder (TemplateOnlyQueryExtensionManager)
# Removed isValidState (TemplateOnlyQueryExtensionManager)
# Removed continueOnHandled (MultiTenantCopierExtensionManager)
# Removed isAutoStartup (PersistenceServiceImpl)
# Removed stop (PersistenceServiceImpl)
# Removed isRunning (PersistenceServiceImpl)
# Removed getPhase (PersistenceServiceImpl)
# Removed setApplicationContext (ParentCategoryLegacyModeServiceImpl)
# Removed isLegacyMode (ParentCategoryLegacyModeServiceImpl)
# Removed getLegacyModeService (ParentCategoryLegacyModeServiceImpl)
# Removed getPageSize (StreamingTransactionCapableUtil)
# Removed setPageSize (StreamingTransactionCapableUtil)
# Removed getRetryMax (StreamingTransactionCapableUtil)
# Removed setRetryMax (StreamingTransactionCapableUtil)
# Removed setApplicationContext (BLCMessageUtils)
# Removed getApplicationContext (ApplicationContextHolder)
# Removed setApplicationContext (ApplicationContextHolder)
# Removed setApplicationContext (BLCSystemProperty)
# Removed printRequest (PaymentGatewayWebResponsePrintServiceImpl)
# Removed setGatewayConfigurationServices (PaymentGatewayConfigurationServiceProviderImpl)
# Removed getEmailTrackingManager (EmailServiceImpl)
# Removed setEmailTrackingManager (EmailServiceImpl)
# Removed getEmailServiceProducer (EmailServiceImpl)
# Removed setEmailServiceProducer (EmailServiceImpl)
# Removed continueOnHandled (SystemPropertyServiceExtensionManager)
# Removed registerSystemPropertySource (SystemPropertiesPropertySourceRegistrar)
# Removed isEntityEnabled (ConditionalFieldAnnotationCopyTransformersManagerImpl)
# Removed setBeanFactory (ConditionalFieldAnnotationCopyTransformersManagerImpl)
# Removed setBeanFactory (ConditionalDirectCopyTransformersManagerImpl)
# Removed isEntityEnabled (ConditionalDirectCopyTransformersManagerImpl)
# Removed setApplicationContext (EntityConfiguration)
# Removed configureMergedItems (EntityConfiguration)
# Removed getEntityBeanNames (EntityConfiguration)
# Removed getEntityContexts (EntityConfiguration)
# Removed setEntityContexts (EntityConfiguration)
# Removed getPostLoaderDao (DefaultPostLoaderDao)
# Removed setApplicationContext (DefaultPostLoaderDao)
# Removed addToSandbox (EntityDuplicatorExtensionManager)
# Removed isEnabled (EntityDuplicatorExtensionManager)
# Removed getSingleton (QueryHelperImpl)
# Removed setApplicationContext (QueryHelperImpl)
# Removed getInstance (TransactionLifecycleMonitor)
# Removed setApplicationContext (TransactionLifecycleMonitor)
# Removed isAutoStartup (TransactionLifecycleMonitor)
# Removed start (TransactionLifecycleMonitor)
# Removed isRunning (TransactionLifecycleMonitor)
# Removed getPhase (TransactionLifecycleMonitor)
# Removed isAsynchronous (TransactionLifecycleMonitor)
# Removed decompressLogLine (TransactionLifecycleMonitor)
# Removed getLoggingThreshold (TransactionLifecycleMonitor)
# Removed setLoggingThreshold (TransactionLifecycleMonitor)
# Removed getStuckThreshold (TransactionLifecycleMonitor)
# Removed setStuckThreshold (TransactionLifecycleMonitor)
# Removed getLoggingPollingResolution (TransactionLifecycleMonitor)
# Removed setLoggingPollingResolution (TransactionLifecycleMonitor)
# Removed getLoggingReportingLagThreshold (TransactionLifecycleMonitor)
# Removed setLoggingReportingLagThreshold (TransactionLifecycleMonitor)
# Removed getCountMax (TransactionLifecycleMonitor)
# Removed setCountMax (TransactionLifecycleMonitor)
# Removed isUseCompression (TransactionLifecycleMonitor)
# Removed setUseCompression (TransactionLifecycleMonitor)
# Removed canHandleSiteMapConfiguration (CustomUrlSiteMapGenerator)
# Removed getSiteMapGenerators (SiteMapServiceImpl)
# Removed setSiteMapGenerators (SiteMapServiceImpl)
# Removed getModuleConfigurationService (SiteMapServiceImpl)
# Removed setModuleConfigurationService (SiteMapServiceImpl)
# Removed setGzipSiteMapFiles (SiteMapServiceImpl)
# Removed getCascadedProductionStateId (DefaultSandBoxHelper)
# Removed retrieveCascadedState (DefaultSandBoxHelper)
# Removed isRelatedToParentCatalogIds (DefaultSandBoxHelper)
# Removed getTopmostProductionOriginalId (DefaultSandBoxHelper)
# Removed isSandBoxable (DefaultSandBoxHelper)
# Removed isPromote (DefaultSandBoxHelper)
# Removed isReject (DefaultSandBoxHelper)
# Removed isReplayOperation (DefaultSandBoxHelper)
# Removed optionallyIncludeDeletedItemsInQueriesAndCollections (DefaultSandBoxHelper)
# Removed getProductionRecordIdIfApplicable (DefaultSandBoxHelper)
# Removed getTopMostOriginalRecord (DefaultSandBoxHelper)
# Removed ignoreCloneCache (DefaultSandBoxHelper)
# Removed initializeResources (ResourceBundlingServiceImpl)
# Removed getCacheKey (ResourceBundlingServiceImpl)
# Removed getBundleName (ResourceBundlingServiceImpl)
# Removed getAdditionalBundleFiles (ResourceBundlingServiceImpl)
# Removed setAdditionalBundleFiles (ResourceBundlingServiceImpl)
# Removed getEnabled (ResourceMinificationServiceImpl)
# Removed getFileType (ResourceMinificationServiceImpl)
# Removed isPreviouslyMinifiedFile (ResourceMinificationServiceImpl)
# Removed getChildSiteIdsForProfile (EntityInformationServiceImpl)
# Removed isEnabled (EntityInformationServiceExtensionManager)
# Removed getChildSiteIdsForProfile (EntityInformationServiceExtensionManager)
# Removed isOverrideQualified (SparseTranslationOverrideStrategy)
# Removed validateTemplateProcessing (SparseTranslationOverrideStrategy)
# Removed getOrder (SparseTranslationOverrideStrategy)
# Removed isTemplateEnabled (SparseTranslationOverrideStrategy)
# Removed setTemplateEnabled (SparseTranslationOverrideStrategy)
# Removed isRestrictAssociation (SparseTranslationOverrideStrategy)
# Removed setRestrictAssociation (SparseTranslationOverrideStrategy)
# Removed validateTemplateProcessing (ThresholdCacheTranslationOverrideStrategy)
# Removed getOrder (ThresholdCacheTranslationOverrideStrategy)
# Removed setThresholdForFullCache (TranslationServiceImpl)
# Removed setTemplateThresholdForFullCache (TranslationServiceImpl)
# Removed continueOnHandled (TranslationDaoExtensionManager)
# Removed getParserContext (BroadleafExpressionParserImpl)
# Removed getInstance (NotificationEventType)
# Removed getType (NotificationEventType)
# Removed getFriendlyType (NotificationEventType)
# Removed setType (NotificationEventType)
# Removed hashCode (NotificationEventType)
# Removed equals (NotificationEventType)
# Removed getIgnoreSuffixes (BroadleafRequestFilter)
# Removed shouldNotFilterErrorDispatch (BroadleafRequestFilter)
# Removed getOrder (BroadleafRequestFilter)
# Removed getSandBoxPreviewEnabled (BroadleafSandBoxResolverImpl)
# Removed setSandBoxPreviewEnabled (BroadleafSandBoxResolverImpl)
# Removed doFilter (ThemeUrlEncodingFilter)
# Removed getIgnoreSuffixes (BroadleafThemeResolverFilter)
# Removed shouldNotFilterErrorDispatch (BroadleafThemeResolverFilter)
# Removed getOrder (BroadleafThemeResolverFilter)
# Removed setCustomerRequestAttributeName (BroadleafRequestCustomerResolverImpl)
# Removed setApplicationContext (BroadleafRequestCustomerResolverImpl)
# Removed getRequestCustomerResolver (BroadleafRequestCustomerResolverImpl)
# Removed getHandlers (BroadleafTemplateViewResolverExtensionManager)
# Removed continueOnHandled (BroadleafTemplateViewResolverExtensionManager)
# Removed init (SecurityBasedIgnoreFilter)
# Removed doFilter (SecurityBasedIgnoreFilter)
# Removed getOrder (SecurityBasedIgnoreFilter)
# Removed getOrder (TranslationFilter)
# Removed getOrder (HtmlMinifyFilter)
# Removed initFilterBean (HtmlMinifyFilter)
# Removed getOrder (CachingCompressedResponseFilter)
# Removed continueOnHandled (CreditCardTypesExtensionManager)
# Removed continueOnHandled (TRCreditCardExtensionManager)
# Removed getExtensionManager (TransparentRedirectCreditCardFormProcessor)
# Removed setExtensionManager (TransparentRedirectCreditCardFormProcessor)
# Removed getName (TransparentRedirectCreditCardFormProcessor)
# Removed getPrecedence (TransparentRedirectCreditCardFormProcessor)
# Removed reprocessModel (TransparentRedirectCreditCardFormProcessor)
# Removed getName (CreditCardTypesProcessor)
# Removed getPrecedence (CreditCardTypesProcessor)
# Removed useGlobalScope (CreditCardTypesProcessor)
# Removed populateModelVariables (CreditCardTypesProcessor)
# Removed getName (PaymentGatewayFieldVariableExpression)
# Removed mapName (PaymentGatewayFieldVariableExpression)
# Removed getExtensionManager (PaymentGatewayFieldVariableExpression)
# Removed setExtensionManager (PaymentGatewayFieldVariableExpression)
# Removed continueOnHandled (PaymentGatewayFieldExtensionManager)
# Removed isHandler (FrameworkControllerHandlerMapping)
# Removed clearThinRequestContext (BroadleafContextUtil)
# Removed getContextName (BroadleafContextUtil)
# Removed continueOnHandled (ResourceRequestExtensionManager)
# Removed getOrder (BroadleafPathResourceResolver)
# Removed setOrder (BroadleafPathResourceResolver)
# Removed getOrder (BroadleafVersionResourceResolver)
# Removed setOrder (BroadleafVersionResourceResolver)
# Removed initIt (BroadleafVersionResourceResolver)
# Removed resolveUrlPathInternal (BLCSystemPropertyResourceResolver)
# Removed addVersion (BLCSystemPropertyResourceResolver)
# Removed getOrder (BLCSystemPropertyResourceResolver)
# Removed setOrder (BLCSystemPropertyResourceResolver)
# Removed getOrder (BundleResourceResolver)
# Removed setOrder (BundleResourceResolver)
# Removed initIt (BLVersionResourceResolverDefaultStrategyMap)
# Removed resolveResourceInternal (BLCJSUrlPathResolver)
# Removed getOrder (BLCJSUrlPathResolver)
# Removed setOrder (BLCJSUrlPathResolver)
# Removed getOrder (BroadleafCachingResourceResolver)
# Removed setOrder (BroadleafCachingResourceResolver)
# Removed resolveUrlPathInternal (BLCJSResourceResolver)
# Removed addVersion (BLCJSResourceResolver)
# Removed getOrder (BLCJSResourceResolver)
# Removed setOrder (BLCJSResourceResolver)
# Removed transform (BroadleafCachingResourceTransformer)
# Removed getOrder (BroadleafCachingResourceTransformer)
# Removed setOrder (BroadleafCachingResourceTransformer)
# Removed getOrder (MinifyResourceTransformer)
# Removed setOrder (MinifyResourceTransformer)
# Removed getName (DataDrivenEnumerationProcessor)
# Removed getPrecedence (DataDrivenEnumerationProcessor)
# Removed getName (FormProcessor)
# Removed getPrecedence (FormProcessor)
# Removed reprocessModel (FormProcessor)
# Removed getName (ResourcePreloadProcessor)
# Removed getPrecedence (ResourcePreloadProcessor)
# Removed getName (ConfigVariableProcessor)
# Removed getPrecedence (ConfigVariableProcessor)
# Removed populateModelVariables (ConfigVariableProcessor)
# Removed getName (ResourceBundleProcessor)
# Removed getPrecedence (ResourceBundleProcessor)
# Removed getName (DataDrivenEnumVariableExpression)
# Removed getName (NullBroadleafVariableExpression)
# Removed getName (PropertiesVariableExpression)
# Removed get (PropertiesVariableExpression)
# Removed getAsInt (PropertiesVariableExpression)
# Removed getAsBoolean (PropertiesVariableExpression)
# Removed getAsLong (PropertiesVariableExpression)
# Removed getForceShowIdColumns (PropertiesVariableExpression)
# Removed getName (BreadcrumbVariableExpression)
# Removed getName (ModuleVariableExpression)
# Removed isPresent (ModuleVariableExpression)
# Removed getName (AssetURLVariableExpression)
# Removed getName (BRCVariableExpression)
# Removed getCurrentTime (BRCVariableExpression)
# Removed isCsrMode (BRCVariableExpression)
# Removed isQuoteMode (BRCVariableExpression)
# Removed getOrder (StatelessSessionFilter)
# Removed saveChallengeQuestion (ChallengeQuestionDaoImpl)
# Removed findCountries (StateDaoImpl)
# Removed setCurrentDateResolution (OfferAuditDaoImpl)
# Removed setCurrentDateResolution (OfferDaoImpl)
# Removed save (CustomerOfferDaoImpl)
# Removed readFulfillmentGroupItemsForFulfillmentGroup (FulfillmentGroupItemDaoImpl)
# Removed setCurrentDateResolution (SearchRedirectDaoImpl)
# Removed save (SearchFacetDaoImpl)
# Removed findInterceptByTerm (SearchInterceptDaoImpl)
# Removed findAllIntercepts (SearchInterceptDaoImpl)
# Removed createIntercept (SearchInterceptDaoImpl)
# Removed deleteIntercept (SearchInterceptDaoImpl)
# Removed updateIntercept (SearchInterceptDaoImpl)
# Removed getAllSynonyms (SearchSynonymDaoImpl)
# Removed createSynonym (SearchSynonymDaoImpl)
# Removed deleteSynonym (SearchSynonymDaoImpl)
# Removed updateSynonym (SearchSynonymDaoImpl)
# Removed save (FieldDaoImpl)
# Removed readFirstSku (SkuDaoImpl)
# Removed setCurrentDateResolution (SkuDaoImpl)
# Removed readCategoriesByNames (CategoryDaoImpl)
# Removed setCurrentDateResolution (CategoryDaoImpl)
# Removed findXrefByCategoryWithDefaultReference (CategoryDaoImpl)
# Removed setCurrentDateResolution (ProductDaoImpl)
# Removed readXrefsByCategoryId (CategoryXrefDaoImpl)
# Removed readXrefsBySubCategoryId (CategoryXrefDaoImpl)
# Removed save (CategoryXrefDaoImpl)
# Removed clearAllRecordsOlderThan (EmailReportingDaoImpl)
# Removed saveSystemProperty (SystemPropertiesDaoImpl)
# Removed deleteSystemProperty (SystemPropertiesDaoImpl)
# Removed getLogger (SystemPropertiesDaoImpl)
# Removed setCurrentDateResolution (ModuleConfigurationDaoImpl)
# Removed setDefaultBatchSize (IdGenerationDaoImpl)
# Removed setDefaultBatchStart (IdGenerationDaoImpl)
# Removed save (TranslationDaoImpl)
# Removed getDynamicDaoHelper (TranslationDaoImpl)
# Removed setDynamicDaoHelper (TranslationDaoImpl)
# Removed getGenericEntityDao (GenericEntityDaoImpl)
# Removed setApplicationContext (GenericEntityDaoImpl)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
