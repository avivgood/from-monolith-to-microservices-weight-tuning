# %%
#!/usr/bin/env python

import os, sys, csv, json
import networkx as nx
import pygraphviz as pygv
from IPython.display import Image, display

# Import javalang from local directory
sys.path.append("./")
import javalang

# %% [markdown]
# ## 1. Project selection

# %% [markdown]
# ### _Configuration!_
#
# Set the project to be analyzed in the _project_ variable
#
# Set to **True** the _read_from_file_ variable to read from an existing exclusions file.\
# If the the refinement file need to be updated or created, set to **True** the _update_refinement_ variable

# %%
# CONFIGURATION:

project = 'shopizer-2x' # <-- Set this variable!

read_from_file = True # <-- Set this variable!
update_refinement = False  # <-- Set this variable!
headless = False

# %%
# Parameters
project = "airsonic-advanced-106"
read_from_file = False
update_refinement = False
headless = True

# %%
with open('projects.json', 'r') as projects:
    project_found = False
    for data in json.load(projects):
        if data['name'] == project:
            source_basedir = data['source_basedir']
            analysis_results_basedir = data['analysis_results_basedir']
            project_found = True
    if not project_found:
        print('ERROR: project ' + project + ' does not appear in project.json')

# %%
# Extract all the Java files from the project direcotry
avoid_directories = ['.git', '.ipynb_checkpoints', 'test', 'resources']
avoid_files = ['package-info.java']

java_files = []

for dirname, dirnames, filenames in os.walk(source_basedir):
    for avoid_dir in avoid_directories:
        if avoid_dir in dirnames:
            # don't go into any .git directories.
            dirnames.remove(avoid_dir)
    # print path to all filenames.
    for filename in filenames:
        if filename.endswith('.java') and filename not in avoid_files:
            java_files.append(os.path.join(dirname, filename))

if not java_files:
    print('ERROR: no Java files found in selected path')

# %% [markdown]
# ## 2. Project scan
#
# Classes will be listed in order to preview their inferred role in the application (if entity, if from the logic/controller layer, if from the repository layer)

# %%
# Build nodes.csv file for the project (need for cleaning?)
exclude_annotations = ['Configuration', 'SpringBootApplication', 'Aspect', 'ControllerAdvice'] # List of annotations to exclude
logic_annotations = ['Service', 'Component', 'Controller', 'RestController', 'Path'] # List of annotations for logic classes
repository_annotations = ['Repository']

compilation_units = []

def pkg_name(tree):
    return getattr(getattr(tree, "package", None), "name", "default")


for file in java_files:
    with open(file, 'r') as javafile:
        try:
            tree = javalang.parse.parse(javafile.read())
            compilation_units.append(tree)
        except Exception as e:
            print("ERROR: Exception {} raised while parsing {}: {} ".format(type(e), file, e))


for tree in compilation_units:
    for decl in tree.types:
        # Go through all classes in order to list them
        if isinstance(decl, javalang.tree.ClassDeclaration):
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in logic_annotations consider the class as logic
                print('Logic\t\t' + decl.name + '\t\t' + pkg_name(tree))

            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If the class annotations are listed in repository_annotations consider the class as repository
                print('Repository\t\t' + decl.name + '\t\t' + pkg_name(tree))
            
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                # If annotations are not listed as logic (from the if guard) AND there are no annotations that have to be excluded consider as entities
                print('Entity\t\t' + decl.name + '\t\t' + pkg_name(tree))

            else:
                # If annotations are excluded:
                print('Excluded\t' + decl.name + '\t\t' + pkg_name(tree))

        elif isinstance(decl, javalang.tree.InterfaceDeclaration):
            # List interfaces
            print('Interface\t' + decl.name + '\t\t' + pkg_name(tree))
# Out:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/airsonic-advanced-106/source/airsonic-main/src/main/java/org/airsonic/player/service/MediaScannerService.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/airsonic-advanced-106/source/airsonic-main/src/main/java/org/airsonic/player/service/search/IndexType.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/airsonic-advanced-106/source/airsonic-main/src/main/java/org/airsonic/player/service/search/QueryFactory.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/airsonic-advanced-106/source/airsonic-main/src/main/java/org/airsonic/player/service/search/DocumentFactory.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/airsonic-advanced-106/source/airsonic-main/src/main/java/org/airsonic/player/service/search/SearchServiceUtilities.java:
# ERROR: Exception <class 'javalang.parser.JavaSyntaxError'> raised while parsing applications/airsonic-advanced-106/source/airsonic-main/src/main/java/org/airsonic/player/controller/PlayerSettingsController.java:
# Excluded	Application		org.airsonic.player
# Entity		TomcatApplication		org.airsonic.player
# Logic		MetricsManager		org.airsonic.player.monitor
# Entity		HexPasswordEncoder		org.airsonic.player.security
# Entity		JWTAuthenticationToken		org.airsonic.player.security
# Logic		CustomUserDetailsContextMapper		org.airsonic.player.security
# Interface	PasswordDecoder		org.airsonic.player.security
# Entity		SaltedTokenPasswordEncoder		org.airsonic.player.security
# Entity		PasswordEncoderDecoderWrapper		org.airsonic.player.security
# Entity		RESTRequestParameterProcessingFilter		org.airsonic.player.security
# Excluded	GlobalSecurityConfig		org.airsonic.player.security
# Entity		AesGcmPasswordEncoder		org.airsonic.player.security
# Logic		CsrfSecurityRequestMatcher		org.airsonic.player.security
# Logic		MultipleCredsMatchingAuthenticationProvider		org.airsonic.player.security
# Entity		JWTAuthenticationProvider		org.airsonic.player.security
# Entity		SaltToken		org.airsonic.player.security
# Entity		JWTRequestParameterProcessingFilter		org.airsonic.player.security
# Logic		ArtistWSController		org.airsonic.player.ajax
# Entity		LyricsInfo		org.airsonic.player.ajax
# Logic		TagWSController		org.airsonic.player.ajax
# Logic		PlayQueueWSController		org.airsonic.player.ajax
# Logic		MediaFileWSController		org.airsonic.player.ajax
# Entity		PlayQueueInfo		org.airsonic.player.ajax
# Logic		LyricsWSController		org.airsonic.player.ajax
# Logic		PlaylistWSController		org.airsonic.player.ajax
# Entity		ArtistInfo		org.airsonic.player.ajax
# Entity		UploadInfo		org.airsonic.player.ajax
# Logic		CoverArtWSController		org.airsonic.player.ajax
# Entity		SimilarArtist		org.airsonic.player.ajax
# Logic		NowPlayingWSController		org.airsonic.player.ajax
# Logic		UserSettingsWSController		org.airsonic.player.ajax
# Entity		NowPlayingInfo		org.airsonic.player.ajax
# Logic		StarWSController		org.airsonic.player.ajax
# Entity		MediaFileEntry		org.airsonic.player.ajax
# Entity		RESTFilter		org.airsonic.player.filter
# Entity		ParameterDecodingFilter		org.airsonic.player.filter
# Entity		BootstrapVerificationFilter		org.airsonic.player.filter
# Entity		RequestEncodingFilter		org.airsonic.player.filter
# Entity		MetricsFilter		org.airsonic.player.filter
# Entity		ResponseHeaderFilter		org.airsonic.player.filter
# Logic		PodcastService		org.airsonic.player.service
# Logic		NetworkService		org.airsonic.player.service
# Logic		SecurityService		org.airsonic.player.service
# Logic		StatusService		org.airsonic.player.service
# Logic		BookmarkService		org.airsonic.player.service
# Logic		SettingsService		org.airsonic.player.service
# Logic		PlaylistService		org.airsonic.player.service
# Logic		JukeboxLegacySubsonicService		org.airsonic.player.service
# Logic		ShareService		org.airsonic.player.service
# Logic		JWTSecurityService		org.airsonic.player.service
# Logic		JukeboxJavaService		org.airsonic.player.service
# Logic		JukeboxService		org.airsonic.player.service
# Entity		LastFmCache		org.airsonic.player.service
# Logic		AudioScrobblerService		org.airsonic.player.service
# Logic		VersionService		org.airsonic.player.service
# Entity		ConfigurationPropertiesService		org.airsonic.player.service
# Logic		RatingService		org.airsonic.player.service
# Logic		PlayerService		org.airsonic.player.service
# Logic		PlayQueueService		org.airsonic.player.service
# Logic		UPnPService		org.airsonic.player.service
# Logic		SonosService		org.airsonic.player.service
# Logic		MusicIndexService		org.airsonic.player.service
# Logic		TranscodingService		org.airsonic.player.service
# Logic		InternetRadioService		org.airsonic.player.service
# Interface	SearchService		org.airsonic.player.service
# Logic		LastFmService		org.airsonic.player.service
# Logic		MediaFileService		org.airsonic.player.service
# Entity		SonosServiceRegistration		org.airsonic.player.service.sonos
# Logic		SonosHelper		org.airsonic.player.service.sonos
# Entity		AlbumList		org.airsonic.player.service.sonos
# Entity		SonosSoapFault		org.airsonic.player.service.sonos
# Logic		SonosFaultInterceptor		org.airsonic.player.service.sonos
# Logic		DefaultPlaylistImportHandler		org.airsonic.player.service.playlist
# Logic		DefaultPlaylistExportHandler		org.airsonic.player.service.playlist
# Interface	PlaylistImportHandler		org.airsonic.player.service.playlist
# Logic		XspfPlaylistImportHandler		org.airsonic.player.service.playlist
# Logic		XspfPlaylistExportHandler		org.airsonic.player.service.playlist
# Interface	PlaylistExportHandler		org.airsonic.player.service.playlist
# Logic		GenreUpnpProcessor		org.airsonic.player.service.upnp
# Logic		MediaFileUpnpProcessor		org.airsonic.player.service.upnp
# Logic		AlbumUpnpProcessor		org.airsonic.player.service.upnp
# Entity		CustomContentDirectory		org.airsonic.player.service.upnp
# Logic		DispatchingContentDirectory		org.airsonic.player.service.upnp
# Logic		FolderBasedContentDirectory		org.airsonic.player.service.upnp
# Entity		UpnpContentProcessor		org.airsonic.player.service.upnp
# Interface	Router		org.airsonic.player.service.upnp
# Logic		PlaylistUpnpProcessor		org.airsonic.player.service.upnp
# Entity		NATPMPRouter		org.airsonic.player.service.upnp
# Logic		RootUpnpProcessor		org.airsonic.player.service.upnp
# Logic		RecentAlbumUpnpProcessor		org.airsonic.player.service.upnp
# Logic		ArtistUpnpProcessor		org.airsonic.player.service.upnp
# Entity		MSMediaReceiverRegistrarService		org.airsonic.player.service.upnp
# Entity		LastFMScrobbler		org.airsonic.player.service.scrobbler
# Entity		ListenBrainzScrobbler		org.airsonic.player.service.scrobbler
# Logic		IndexManager		org.airsonic.player.service.search
# Entity		FieldNames		org.airsonic.player.service.search
# Logic		AnalyzerFactory		org.airsonic.player.service.search
# Logic		SearchServiceImpl		org.airsonic.player.service.search
# Entity		MetaDataParser		org.airsonic.player.service.metadata
# Logic		FFmpegParser		org.airsonic.player.service.metadata
# Logic		JaudiotaggerParser		org.airsonic.player.service.metadata
# Logic		DefaultMetaDataParser		org.airsonic.player.service.metadata
# Entity		MetaData		org.airsonic.player.service.metadata
# Logic		MetaDataParserFactory		org.airsonic.player.service.metadata
# Logic		AudioPlayerFactory		org.airsonic.player.service.jukebox
# Logic		JavaPlayerFactory		org.airsonic.player.service.jukebox
# Entity		AudioPlayer		org.airsonic.player.service.jukebox
# Entity		PlayerTest		org.airsonic.player.service.jukebox
# Entity		LambdaUtils		org.airsonic.player.util
# Entity		Util		org.airsonic.player.util
# Entity		FileUtil		org.airsonic.player.util
# Entity		StringUtil		org.airsonic.player.util
# Entity		XMLUtil		org.airsonic.player.util
# Entity		ArtistBio		org.airsonic.player.domain
# Entity		PodcastChannel		org.airsonic.player.domain
# Entity		MediaFile		org.airsonic.player.domain
# Entity		PlayStatus		org.airsonic.player.domain
# Entity		PodcastEpisode		org.airsonic.player.domain
# Entity		InternetRadio		org.airsonic.player.domain
# Entity		MediaLibraryStatistics		org.airsonic.player.domain
# Entity		MusicIndex		org.airsonic.player.domain
# Entity		TransferStatus		org.airsonic.player.domain
# Entity		SearchCriteria		org.airsonic.player.domain
# Entity		Version		org.airsonic.player.domain
# Entity		Player		org.airsonic.player.domain
# Entity		SearchResult		org.airsonic.player.domain
# Entity		Genres		org.airsonic.player.domain
# Entity		UserCredential		org.airsonic.player.domain
# Entity		PlayQueue		org.airsonic.player.domain
# Entity		MusicFolderContent		org.airsonic.player.domain
# Entity		Transcoding		org.airsonic.player.domain
# Entity		AlbumNotes		org.airsonic.player.domain
# Entity		SavedPlayQueue		org.airsonic.player.domain
# Entity		VideoTranscodingSettings		org.airsonic.player.domain
# Entity		RandomSearchCriteria		org.airsonic.player.domain
# Entity		User		org.airsonic.player.domain
# Entity		Playlist		org.airsonic.player.domain
# Entity		MediaFileWithUrlInfo		org.airsonic.player.domain
# Entity		Bookmark		org.airsonic.player.domain
# Entity		InternetRadioSource		org.airsonic.player.domain
# Entity		UserSettings		org.airsonic.player.domain
# Entity		LastFmCoverArt		org.airsonic.player.domain
# Entity		Artist		org.airsonic.player.domain
# Entity		Avatar		org.airsonic.player.domain
# Entity		Share		org.airsonic.player.domain
# Entity		MediaFileComparator		org.airsonic.player.domain
# Entity		Album		org.airsonic.player.domain
# Entity		MusicFolder		org.airsonic.player.domain
# Entity		ParamSearchResult		org.airsonic.player.domain
# Entity		Genre		org.airsonic.player.domain
# Entity		Theme		org.airsonic.player.domain
# Entity		DbmsVersionPrecondition		org.airsonic.player.spring
# Excluded	CacheConfiguration		org.airsonic.player.spring
# Logic		RegisterPrecompiledJSPInitializer		org.airsonic.player.spring
# Entity		CustomPropertySourceConfigurer		org.airsonic.player.spring
# Entity		KnownLengthInputStreamResource		org.airsonic.player.spring
# Entity		LoggingFileOverrideListener		org.airsonic.player.spring
# Excluded	WebsocketConfiguration		org.airsonic.player.spring
# Excluded	ServletConfiguration		org.airsonic.player.spring
# Excluded	SonosConfiguration		org.airsonic.player.spring
# Excluded	DatabaseConfiguration		org.airsonic.player.spring
# Entity		HsqlDatabase		org.airsonic.player.spring
# Logic		LoggingExceptionResolver		org.airsonic.player.spring
# Entity		WebApp		org.airsonic.player.spring.webxmldomain
# Entity		ServletDef		org.airsonic.player.spring.webxmldomain
# Entity		ServletMappingDef		org.airsonic.player.spring.webxmldomain
# Entity		PersonalSettingsCommand		org.airsonic.player.command
# Entity		EnumHolder		org.airsonic.player.command
# Entity		DatabaseSettingsCommand		org.airsonic.player.command
# Entity		UserSettingsCommand		org.airsonic.player.command
# Entity		PodcastSettingsCommand		org.airsonic.player.command
# Entity		CredentialsManagementCommand		org.airsonic.player.command
# Entity		AdvancedSettingsCommand		org.airsonic.player.command
# Entity		SearchCommand		org.airsonic.player.command
# Entity		GeneralSettingsCommand		org.airsonic.player.command
# Entity		PlayerSettingsCommand		org.airsonic.player.command
# Entity		MusicFolderSettingsCommand		org.airsonic.player.command
# Logic		CustomThemeSource		org.airsonic.player.theme
# Logic		CustomThemeResolver		org.airsonic.player.theme
# Logic		PlaylistsController		org.airsonic.player.controller
# Logic		VideoPlayerController		org.airsonic.player.controller
# Logic		NotFoundController		org.airsonic.player.controller
# Logic		StreamController		org.airsonic.player.controller
# Logic		ImportPlaylistController		org.airsonic.player.controller
# Logic		RatingJspController		org.airsonic.player.controller
# Logic		UserSettingsController		org.airsonic.player.controller
# Logic		LoginController		org.airsonic.player.controller
# Logic		ShareSettingsController		org.airsonic.player.controller
# Logic		ChangeCoverArtController		org.airsonic.player.controller
# Logic		DLNASettingsController		org.airsonic.player.controller
# Logic		StarredController		org.airsonic.player.controller
# Logic		MusicFolderSettingsController		org.airsonic.player.controller
# Logic		ExternalPlayerController		org.airsonic.player.controller
# Logic		PodcastSettingsController		org.airsonic.player.controller
# Logic		PodcastReceiverAdminController		org.airsonic.player.controller
# Logic		CoverArtController		org.airsonic.player.controller
# Logic		PodcastController		org.airsonic.player.controller
# Logic		SettingsController		org.airsonic.player.controller
# Logic		MainController		org.airsonic.player.controller
# Logic		RightController		org.airsonic.player.controller
# Logic		StatusChartController		org.airsonic.player.controller
# Logic		PlaylistController		org.airsonic.player.controller
# Logic		AllmusicController		org.airsonic.player.controller
# Logic		IndexController		org.airsonic.player.controller
# Logic		ShareManagementController		org.airsonic.player.controller
# Entity		AbstractChartController		org.airsonic.player.controller
# Logic		HomeController		org.airsonic.player.controller
# Logic		M3UController		org.airsonic.player.controller
# Logic		LeftController		org.airsonic.player.controller
# Logic		StatusController		org.airsonic.player.controller
# Logic		InternetRadioSettingsController		org.airsonic.player.controller
# Logic		UserChartController		org.airsonic.player.controller
# Logic		UploadController		org.airsonic.player.controller
# Logic		SearchController		org.airsonic.player.controller
# Logic		CoverArtJspController		org.airsonic.player.controller
# Entity		ControllerUtils		org.airsonic.player.controller
# Logic		SetRatingController		org.airsonic.player.controller
# Logic		TopController		org.airsonic.player.controller
# Logic		AvatarController		org.airsonic.player.controller
# Logic		HLSController		org.airsonic.player.controller
# Logic		LyricsController		org.airsonic.player.controller
# Entity		JAXBWriter		org.airsonic.player.controller
# Logic		AccessDeniedController		org.airsonic.player.controller
# Logic		DownloadController		org.airsonic.player.controller
# Logic		AvatarUploadController		org.airsonic.player.controller
# Logic		PodcastChannelController		org.airsonic.player.controller
# Logic		PodcastChannelsController		org.airsonic.player.controller
# Logic		EditTagsController		org.airsonic.player.controller
# Logic		PlayQueueController		org.airsonic.player.controller
# Logic		RandomPlayQueueController		org.airsonic.player.controller
# Logic		SonosSettingsController		org.airsonic.player.controller
# Logic		ExportPlayListController		org.airsonic.player.controller
# Logic		ProxyController		org.airsonic.player.controller
# Logic		TranscodingSettingsController		org.airsonic.player.controller
# Logic		AdvancedSettingsController		org.airsonic.player.controller
# Logic		PersonalSettingsController		org.airsonic.player.controller
# Logic		MoreController		org.airsonic.player.controller
# Logic		CredentialsManagementController		org.airsonic.player.controller
# Logic		RecoverController		org.airsonic.player.controller
# Logic		SubsonicRESTController		org.airsonic.player.controller
# Logic		GettingStartedController		org.airsonic.player.controller
# Logic		NowPlayingController		org.airsonic.player.controller
# Logic		GeneralSettingsController		org.airsonic.player.controller
# Logic		SetMusicFileInfoController		org.airsonic.player.controller
# Logic		DatabaseSettingsController		org.airsonic.player.controller
# Logic		HelpController		org.airsonic.player.controller
# Entity		ParamTag		org.airsonic.player.taglib
# Entity		FormatBytesTag		org.airsonic.player.taglib
# Entity		EscapeJavaScriptTag		org.airsonic.player.taglib
# Entity		UrlTag		org.airsonic.player.taglib
# Entity		UserSettingsValidator		org.airsonic.player.validator
# Entity		CredentialsManagementValidators		org.airsonic.player.validator
# Entity		MonitoredOutputStream		org.airsonic.player.upload
# Entity		MonitoredDiskFileItemFactory		org.airsonic.player.upload
# Interface	UploadListener		org.airsonic.player.upload
# Entity		MonitoredDiskFileItem		org.airsonic.player.upload
# Entity		InputStreamReaderThread		org.airsonic.player.io
# Entity		PipeStreams		org.airsonic.player.io
# Entity		TranscodeInputStream		org.airsonic.player.io
# Entity		PlayQueueInputStream		org.airsonic.player.io
# Entity		ShoutCastOutputStream		org.airsonic.player.io
# Logic		LocaleResolver		org.airsonic.player.i18n
# Repository		RatingDao		org.airsonic.player.dao
# Repository		PlaylistDao		org.airsonic.player.dao
# Repository		UserDao		org.airsonic.player.dao
# Repository		PlayerDao		org.airsonic.player.dao
# Repository		AlbumDao		org.airsonic.player.dao
# Repository		ArtistDao		org.airsonic.player.dao
# Repository		PlayQueueDao		org.airsonic.player.dao
# Entity		AbstractDao		org.airsonic.player.dao
# Repository		MediaFileDao		org.airsonic.player.dao
# Repository		InternetRadioDao		org.airsonic.player.dao
# Repository		AvatarDao		org.airsonic.player.dao
# Logic		PlayerDaoPlayQueueFactory		org.airsonic.player.dao
# Repository		ShareDao		org.airsonic.player.dao
# Repository		BookmarkDao		org.airsonic.player.dao
# Excluded	GenericDaoHelper		org.airsonic.player.dao
# Repository		MusicFolderDao		org.airsonic.player.dao
# Interface	DaoHelper		org.airsonic.player.dao
# Repository		PodcastDao		org.airsonic.player.dao
# Repository		TranscodingDao		org.airsonic.player.dao
# Excluded	LegacyHsqlDaoHelper		org.airsonic.player.dao

# %% [markdown]
# ## 3. Layer refinement

# %% [markdown]
# ### _User input required!_
#
# #### List
# - Packages and Classes to be excluded
# - Entities, Logic and Repository Classes or Packages that have not been automatically listed as entities, logic and repository classes
# - Interface of the repository layer that rely on Spring Data JPA framework, thus not having an implementing class (if needed)
#
# #### Otherwise
# Set to **True** the read_from_file variable to read from an existing refinement file.\
# If the refinement file needs to be updated or created, set to **True** the update_refinement variable

# %%
# Set those variable if needed

# Exclude packages
# Exclude classes
# Force entity packages
# Force entity classes
# Force logic packages
# Force logic classes
# Force repository packages
# Force repository classes
# Force repository interfaces

exclude_packages = []
exclude_classes = []

force_entity_packages = []
force_entity_classes = []

force_logic_packages = []
force_logic_classes = []

force_repository_packages = []
force_repository_classes = []

force_repository_interface_package = []
force_repository_interface_class = []

# %%
if update_refinement:
    with open(analysis_results_basedir + project + '_refinement.json', 'w') as refinement_file:
        data = dict()
        data['exclude_packages'] = exclude_packages
        data['exclude_classes'] = exclude_classes
        data['force_entity_packages'] = force_entity_packages
        data['force_entity_classes'] = force_entity_classes
        data['force_logic_packages'] = force_logic_packages
        data['force_logic_classes'] = force_logic_classes
        data['force_repository_packages'] = force_repository_packages
        data['force_repository_classes'] = force_repository_classes
        data['force_repository_interface_package'] = force_repository_interface_package
        data['force_repository_interface_class'] = force_repository_interface_class
        json.dump(data, exclusions_file)

if read_from_file:
    with open(analysis_results_basedir + project + '_refinement.json', 'r') as refinement_file:
        refinement = json.load(refinement_file)
        exclude_packages = refinement['exclude_packages']
        exclude_classes = refinement['exclude_classes']
        force_entity_packages = refinement['force_entity_packages']
        force_entity_classes = refinement['force_entity_classes']
        force_logic_packages = refinement['force_logic_packages']
        force_logic_classes = refinement['force_logic_classes']
        force_repository_packages = refinement['force_repository_packages']
        force_repository_classes = refinement['force_repository_classes']
        force_repository_interface_package = refinement['force_repository_interface_package']
        force_repository_interface_class = refinement['force_repository_interface_class']

# %%
logic_classes = []
entity_classes = []
repository_classes = []
repository_interfaces = []
excluded_classes = []
interfaces = []

for tree in compilation_units:
    for decl in tree.types:
        # If it is a class declaration...
        if isinstance(decl, javalang.tree.ClassDeclaration):

            # If considered logic...
            if any(annotation in logic_annotations for annotation in map(lambda a: a.name, decl.annotations)):

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as repository class
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        logic_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If considered repository...
            elif any(annotation in repository_annotations for annotation in map(lambda a: a.name, decl.annotations)) or "repository" in pkg_name(tree).lower() or "repositories" in pkg_name(tree).lower() or "repository" in decl.name.lower():

                # and not in excluded packages and classes:
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                    # ..and if this class or package has been forced as entity
                    if (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                        entity_classes.append((decl, pkg_name(tree)))

                    # ..and if this class or package has been forced as logic class
                    elif (decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages):
                        logic_classes.append((decl, pkg_name(tree)))

                    else:
                        repository_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

            # If not considered to be excluded...
            elif not any(annotation in exclude_annotations for annotation in map(lambda a: a.name, decl.annotations)):
                
                # and not explictly excluded...
                if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):
                    
                    # and explicitly listed as logic
                    if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                        logic_classes.append((decl, pkg_name(tree)))

                    # and explictly listed as repository
                    elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                        # ..and if this class or package has been forced as repository class
                        repository_classes.append((decl, pkg_name(tree)))

                    else:
                        entity_classes.append((decl, pkg_name(tree)))

                else:
                    excluded_classes.append((decl, pkg_name(tree)))
            
            # If in automatically excluded packages or class, but:
            else:
                # forced as logic
                if decl.name in force_logic_classes or pkg_name(tree) in force_logic_packages:
                    logic_classes.append((decl, pkg_name(tree)))

                # forced as entity
                elif (decl.name in force_entity_classes or pkg_name(tree) in force_entity_packages):
                    entity_classes.append((decl, pkg_name(tree)))

                # forced as repository class
                elif (decl.name in force_repository_classes or pkg_name(tree) in force_repository_packages):
                    repository_classes.append((decl, pkg_name(tree)))                          

                else:
                    excluded_classes.append((decl, pkg_name(tree)))

        # If it is an interface declaration:
        elif isinstance(decl, javalang.tree.InterfaceDeclaration):

            # If not explicitly excluded...
            if (decl.name not in exclude_classes and pkg_name(tree) not in exclude_packages):

                # and forced as repository
                if decl.name in force_repository_interface_class or pkg_name(tree) in force_repository_interface_package:
                    repository_interfaces.append((decl, pkg_name(tree)))

                else:
                    interfaces.append((decl, pkg_name(tree)))
            else:
                excluded_classes.append((decl, pkg_name(tree)))

for (decl, package_name) in entity_classes:
     print('Entity\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in logic_classes:
     print('Logic\t\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_classes:
     print('Repository (cls)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in repository_interfaces:
     print('Repository (int)\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in interfaces:
     print('Interface\t' + decl.name + '\t\t' + package_name)
for (decl, package_name) in excluded_classes:
     print('Excluded\t' + decl.name + '\t\t' + package_name)
# Out:
# Entity		TomcatApplication		org.airsonic.player
# Entity		HexPasswordEncoder		org.airsonic.player.security
# Entity		JWTAuthenticationToken		org.airsonic.player.security
# Entity		SaltedTokenPasswordEncoder		org.airsonic.player.security
# Entity		PasswordEncoderDecoderWrapper		org.airsonic.player.security
# Entity		RESTRequestParameterProcessingFilter		org.airsonic.player.security
# Entity		AesGcmPasswordEncoder		org.airsonic.player.security
# Entity		JWTAuthenticationProvider		org.airsonic.player.security
# Entity		SaltToken		org.airsonic.player.security
# Entity		JWTRequestParameterProcessingFilter		org.airsonic.player.security
# Entity		LyricsInfo		org.airsonic.player.ajax
# Entity		PlayQueueInfo		org.airsonic.player.ajax
# Entity		ArtistInfo		org.airsonic.player.ajax
# Entity		UploadInfo		org.airsonic.player.ajax
# Entity		SimilarArtist		org.airsonic.player.ajax
# Entity		NowPlayingInfo		org.airsonic.player.ajax
# Entity		MediaFileEntry		org.airsonic.player.ajax
# Entity		RESTFilter		org.airsonic.player.filter
# Entity		ParameterDecodingFilter		org.airsonic.player.filter
# Entity		BootstrapVerificationFilter		org.airsonic.player.filter
# Entity		RequestEncodingFilter		org.airsonic.player.filter
# Entity		MetricsFilter		org.airsonic.player.filter
# Entity		ResponseHeaderFilter		org.airsonic.player.filter
# Entity		LastFmCache		org.airsonic.player.service
# Entity		ConfigurationPropertiesService		org.airsonic.player.service
# Entity		SonosServiceRegistration		org.airsonic.player.service.sonos
# Entity		AlbumList		org.airsonic.player.service.sonos
# Entity		SonosSoapFault		org.airsonic.player.service.sonos
# Entity		CustomContentDirectory		org.airsonic.player.service.upnp
# Entity		UpnpContentProcessor		org.airsonic.player.service.upnp
# Entity		NATPMPRouter		org.airsonic.player.service.upnp
# Entity		MSMediaReceiverRegistrarService		org.airsonic.player.service.upnp
# Entity		LastFMScrobbler		org.airsonic.player.service.scrobbler
# Entity		ListenBrainzScrobbler		org.airsonic.player.service.scrobbler
# Entity		FieldNames		org.airsonic.player.service.search
# Entity		MetaDataParser		org.airsonic.player.service.metadata
# Entity		MetaData		org.airsonic.player.service.metadata
# Entity		AudioPlayer		org.airsonic.player.service.jukebox
# Entity		PlayerTest		org.airsonic.player.service.jukebox
# Entity		LambdaUtils		org.airsonic.player.util
# Entity		Util		org.airsonic.player.util
# Entity		FileUtil		org.airsonic.player.util
# Entity		StringUtil		org.airsonic.player.util
# Entity		XMLUtil		org.airsonic.player.util
# Entity		ArtistBio		org.airsonic.player.domain
# Entity		PodcastChannel		org.airsonic.player.domain
# Entity		MediaFile		org.airsonic.player.domain
# Entity		PlayStatus		org.airsonic.player.domain
# Entity		PodcastEpisode		org.airsonic.player.domain
# Entity		InternetRadio		org.airsonic.player.domain
# Entity		MediaLibraryStatistics		org.airsonic.player.domain
# Entity		MusicIndex		org.airsonic.player.domain
# Entity		TransferStatus		org.airsonic.player.domain
# Entity		SearchCriteria		org.airsonic.player.domain
# Entity		Version		org.airsonic.player.domain
# Entity		Player		org.airsonic.player.domain
# Entity		SearchResult		org.airsonic.player.domain
# Entity		Genres		org.airsonic.player.domain
# Entity		UserCredential		org.airsonic.player.domain
# Entity		PlayQueue		org.airsonic.player.domain
# Entity		MusicFolderContent		org.airsonic.player.domain
# Entity		Transcoding		org.airsonic.player.domain
# Entity		AlbumNotes		org.airsonic.player.domain
# Entity		SavedPlayQueue		org.airsonic.player.domain
# Entity		VideoTranscodingSettings		org.airsonic.player.domain
# Entity		RandomSearchCriteria		org.airsonic.player.domain
# Entity		User		org.airsonic.player.domain
# Entity		Playlist		org.airsonic.player.domain
# Entity		MediaFileWithUrlInfo		org.airsonic.player.domain
# Entity		Bookmark		org.airsonic.player.domain
# Entity		InternetRadioSource		org.airsonic.player.domain
# Entity		UserSettings		org.airsonic.player.domain
# Entity		LastFmCoverArt		org.airsonic.player.domain
# Entity		Artist		org.airsonic.player.domain
# Entity		Avatar		org.airsonic.player.domain
# Entity		Share		org.airsonic.player.domain
# Entity		MediaFileComparator		org.airsonic.player.domain
# Entity		Album		org.airsonic.player.domain
# Entity		MusicFolder		org.airsonic.player.domain
# Entity		ParamSearchResult		org.airsonic.player.domain
# Entity		Genre		org.airsonic.player.domain
# Entity		Theme		org.airsonic.player.domain
# Entity		DbmsVersionPrecondition		org.airsonic.player.spring
# Entity		CustomPropertySourceConfigurer		org.airsonic.player.spring
# Entity		KnownLengthInputStreamResource		org.airsonic.player.spring
# Entity		LoggingFileOverrideListener		org.airsonic.player.spring
# Entity		HsqlDatabase		org.airsonic.player.spring
# Entity		WebApp		org.airsonic.player.spring.webxmldomain
# Entity		ServletDef		org.airsonic.player.spring.webxmldomain
# Entity		ServletMappingDef		org.airsonic.player.spring.webxmldomain
# Entity		PersonalSettingsCommand		org.airsonic.player.command
# Entity		EnumHolder		org.airsonic.player.command
# Entity		DatabaseSettingsCommand		org.airsonic.player.command
# Entity		UserSettingsCommand		org.airsonic.player.command
# Entity		PodcastSettingsCommand		org.airsonic.player.command
# Entity		CredentialsManagementCommand		org.airsonic.player.command
# Entity		AdvancedSettingsCommand		org.airsonic.player.command
# Entity		SearchCommand		org.airsonic.player.command
# Entity		GeneralSettingsCommand		org.airsonic.player.command
# Entity		PlayerSettingsCommand		org.airsonic.player.command
# Entity		MusicFolderSettingsCommand		org.airsonic.player.command
# Entity		AbstractChartController		org.airsonic.player.controller
# Entity		ControllerUtils		org.airsonic.player.controller
# Entity		JAXBWriter		org.airsonic.player.controller
# Entity		ParamTag		org.airsonic.player.taglib
# Entity		FormatBytesTag		org.airsonic.player.taglib
# Entity		EscapeJavaScriptTag		org.airsonic.player.taglib
# Entity		UrlTag		org.airsonic.player.taglib
# Entity		UserSettingsValidator		org.airsonic.player.validator
# Entity		CredentialsManagementValidators		org.airsonic.player.validator
# Entity		MonitoredOutputStream		org.airsonic.player.upload
# Entity		MonitoredDiskFileItemFactory		org.airsonic.player.upload
# Entity		MonitoredDiskFileItem		org.airsonic.player.upload
# Entity		InputStreamReaderThread		org.airsonic.player.io
# Entity		PipeStreams		org.airsonic.player.io
# Entity		TranscodeInputStream		org.airsonic.player.io
# Entity		PlayQueueInputStream		org.airsonic.player.io
# Entity		ShoutCastOutputStream		org.airsonic.player.io
# Entity		AbstractDao		org.airsonic.player.dao
# Logic		MetricsManager		org.airsonic.player.monitor
# Logic		CustomUserDetailsContextMapper		org.airsonic.player.security
# Logic		CsrfSecurityRequestMatcher		org.airsonic.player.security
# Logic		MultipleCredsMatchingAuthenticationProvider		org.airsonic.player.security
# Logic		ArtistWSController		org.airsonic.player.ajax
# Logic		TagWSController		org.airsonic.player.ajax
# Logic		PlayQueueWSController		org.airsonic.player.ajax
# Logic		MediaFileWSController		org.airsonic.player.ajax
# Logic		LyricsWSController		org.airsonic.player.ajax
# Logic		PlaylistWSController		org.airsonic.player.ajax
# Logic		CoverArtWSController		org.airsonic.player.ajax
# Logic		NowPlayingWSController		org.airsonic.player.ajax
# Logic		UserSettingsWSController		org.airsonic.player.ajax
# Logic		StarWSController		org.airsonic.player.ajax
# Logic		PodcastService		org.airsonic.player.service
# Logic		NetworkService		org.airsonic.player.service
# Logic		SecurityService		org.airsonic.player.service
# Logic		StatusService		org.airsonic.player.service
# Logic		BookmarkService		org.airsonic.player.service
# Logic		SettingsService		org.airsonic.player.service
# Logic		PlaylistService		org.airsonic.player.service
# Logic		JukeboxLegacySubsonicService		org.airsonic.player.service
# Logic		ShareService		org.airsonic.player.service
# Logic		JWTSecurityService		org.airsonic.player.service
# Logic		JukeboxJavaService		org.airsonic.player.service
# Logic		JukeboxService		org.airsonic.player.service
# Logic		AudioScrobblerService		org.airsonic.player.service
# Logic		VersionService		org.airsonic.player.service
# Logic		RatingService		org.airsonic.player.service
# Logic		PlayerService		org.airsonic.player.service
# Logic		PlayQueueService		org.airsonic.player.service
# Logic		UPnPService		org.airsonic.player.service
# Logic		SonosService		org.airsonic.player.service
# Logic		MusicIndexService		org.airsonic.player.service
# Logic		TranscodingService		org.airsonic.player.service
# Logic		InternetRadioService		org.airsonic.player.service
# Logic		LastFmService		org.airsonic.player.service
# Logic		MediaFileService		org.airsonic.player.service
# Logic		SonosHelper		org.airsonic.player.service.sonos
# Logic		SonosFaultInterceptor		org.airsonic.player.service.sonos
# Logic		DefaultPlaylistImportHandler		org.airsonic.player.service.playlist
# Logic		DefaultPlaylistExportHandler		org.airsonic.player.service.playlist
# Logic		XspfPlaylistImportHandler		org.airsonic.player.service.playlist
# Logic		XspfPlaylistExportHandler		org.airsonic.player.service.playlist
# Logic		GenreUpnpProcessor		org.airsonic.player.service.upnp
# Logic		MediaFileUpnpProcessor		org.airsonic.player.service.upnp
# Logic		AlbumUpnpProcessor		org.airsonic.player.service.upnp
# Logic		DispatchingContentDirectory		org.airsonic.player.service.upnp
# Logic		FolderBasedContentDirectory		org.airsonic.player.service.upnp
# Logic		PlaylistUpnpProcessor		org.airsonic.player.service.upnp
# Logic		RootUpnpProcessor		org.airsonic.player.service.upnp
# Logic		RecentAlbumUpnpProcessor		org.airsonic.player.service.upnp
# Logic		ArtistUpnpProcessor		org.airsonic.player.service.upnp
# Logic		IndexManager		org.airsonic.player.service.search
# Logic		AnalyzerFactory		org.airsonic.player.service.search
# Logic		SearchServiceImpl		org.airsonic.player.service.search
# Logic		FFmpegParser		org.airsonic.player.service.metadata
# Logic		JaudiotaggerParser		org.airsonic.player.service.metadata
# Logic		DefaultMetaDataParser		org.airsonic.player.service.metadata
# Logic		MetaDataParserFactory		org.airsonic.player.service.metadata
# Logic		AudioPlayerFactory		org.airsonic.player.service.jukebox
# Logic		JavaPlayerFactory		org.airsonic.player.service.jukebox
# Logic		RegisterPrecompiledJSPInitializer		org.airsonic.player.spring
# Logic		LoggingExceptionResolver		org.airsonic.player.spring
# Logic		CustomThemeSource		org.airsonic.player.theme
# Logic		CustomThemeResolver		org.airsonic.player.theme
# Logic		PlaylistsController		org.airsonic.player.controller
# Logic		VideoPlayerController		org.airsonic.player.controller
# Logic		NotFoundController		org.airsonic.player.controller
# Logic		StreamController		org.airsonic.player.controller
# Logic		ImportPlaylistController		org.airsonic.player.controller
# Logic		RatingJspController		org.airsonic.player.controller
# Logic		UserSettingsController		org.airsonic.player.controller
# Logic		LoginController		org.airsonic.player.controller
# Logic		ShareSettingsController		org.airsonic.player.controller
# Logic		ChangeCoverArtController		org.airsonic.player.controller
# Logic		DLNASettingsController		org.airsonic.player.controller
# Logic		StarredController		org.airsonic.player.controller
# Logic		MusicFolderSettingsController		org.airsonic.player.controller
# Logic		ExternalPlayerController		org.airsonic.player.controller
# Logic		PodcastSettingsController		org.airsonic.player.controller
# Logic		PodcastReceiverAdminController		org.airsonic.player.controller
# Logic		CoverArtController		org.airsonic.player.controller
# Logic		PodcastController		org.airsonic.player.controller
# Logic		SettingsController		org.airsonic.player.controller
# Logic		MainController		org.airsonic.player.controller
# Logic		RightController		org.airsonic.player.controller
# Logic		StatusChartController		org.airsonic.player.controller
# Logic		PlaylistController		org.airsonic.player.controller
# Logic		AllmusicController		org.airsonic.player.controller
# Logic		IndexController		org.airsonic.player.controller
# Logic		ShareManagementController		org.airsonic.player.controller
# Logic		HomeController		org.airsonic.player.controller
# Logic		M3UController		org.airsonic.player.controller
# Logic		LeftController		org.airsonic.player.controller
# Logic		StatusController		org.airsonic.player.controller
# Logic		InternetRadioSettingsController		org.airsonic.player.controller
# Logic		UserChartController		org.airsonic.player.controller
# Logic		UploadController		org.airsonic.player.controller
# Logic		SearchController		org.airsonic.player.controller
# Logic		CoverArtJspController		org.airsonic.player.controller
# Logic		SetRatingController		org.airsonic.player.controller
# Logic		TopController		org.airsonic.player.controller
# Logic		AvatarController		org.airsonic.player.controller
# Logic		HLSController		org.airsonic.player.controller
# Logic		LyricsController		org.airsonic.player.controller
# Logic		AccessDeniedController		org.airsonic.player.controller
# Logic		DownloadController		org.airsonic.player.controller
# Logic		AvatarUploadController		org.airsonic.player.controller
# Logic		PodcastChannelController		org.airsonic.player.controller
# Logic		PodcastChannelsController		org.airsonic.player.controller
# Logic		EditTagsController		org.airsonic.player.controller
# Logic		PlayQueueController		org.airsonic.player.controller
# Logic		RandomPlayQueueController		org.airsonic.player.controller
# Logic		SonosSettingsController		org.airsonic.player.controller
# Logic		ExportPlayListController		org.airsonic.player.controller
# Logic		ProxyController		org.airsonic.player.controller
# Logic		TranscodingSettingsController		org.airsonic.player.controller
# Logic		AdvancedSettingsController		org.airsonic.player.controller
# Logic		PersonalSettingsController		org.airsonic.player.controller
# Logic		MoreController		org.airsonic.player.controller
# Logic		CredentialsManagementController		org.airsonic.player.controller
# Logic		RecoverController		org.airsonic.player.controller
# Logic		SubsonicRESTController		org.airsonic.player.controller
# Logic		GettingStartedController		org.airsonic.player.controller
# Logic		NowPlayingController		org.airsonic.player.controller
# Logic		GeneralSettingsController		org.airsonic.player.controller
# Logic		SetMusicFileInfoController		org.airsonic.player.controller
# Logic		DatabaseSettingsController		org.airsonic.player.controller
# Logic		HelpController		org.airsonic.player.controller
# Logic		LocaleResolver		org.airsonic.player.i18n
# Logic		PlayerDaoPlayQueueFactory		org.airsonic.player.dao
# Repository (cls)	RatingDao		org.airsonic.player.dao
# Repository (cls)	PlaylistDao		org.airsonic.player.dao
# Repository (cls)	UserDao		org.airsonic.player.dao
# Repository (cls)	PlayerDao		org.airsonic.player.dao
# Repository (cls)	AlbumDao		org.airsonic.player.dao
# Repository (cls)	ArtistDao		org.airsonic.player.dao
# Repository (cls)	PlayQueueDao		org.airsonic.player.dao
# Repository (cls)	MediaFileDao		org.airsonic.player.dao
# Repository (cls)	InternetRadioDao		org.airsonic.player.dao
# Repository (cls)	AvatarDao		org.airsonic.player.dao
# Repository (cls)	ShareDao		org.airsonic.player.dao
# Repository (cls)	BookmarkDao		org.airsonic.player.dao
# Repository (cls)	MusicFolderDao		org.airsonic.player.dao
# Repository (cls)	PodcastDao		org.airsonic.player.dao
# Repository (cls)	TranscodingDao		org.airsonic.player.dao
# Interface	PasswordDecoder		org.airsonic.player.security
# Interface	SearchService		org.airsonic.player.service
# Interface	PlaylistImportHandler		org.airsonic.player.service.playlist
# Interface	PlaylistExportHandler		org.airsonic.player.service.playlist
# Interface	Router		org.airsonic.player.service.upnp
# Interface	UploadListener		org.airsonic.player.upload
# Interface	DaoHelper		org.airsonic.player.dao
# Excluded	Application		org.airsonic.player
# Excluded	GlobalSecurityConfig		org.airsonic.player.security
# Excluded	CacheConfiguration		org.airsonic.player.spring
# Excluded	WebsocketConfiguration		org.airsonic.player.spring
# Excluded	ServletConfiguration		org.airsonic.player.spring
# Excluded	SonosConfiguration		org.airsonic.player.spring
# Excluded	DatabaseConfiguration		org.airsonic.player.spring
# Excluded	GenericDaoHelper		org.airsonic.player.dao
# Excluded	LegacyHsqlDaoHelper		org.airsonic.player.dao

# %% [markdown]
# ## 4. Collect relationships between Entities

# %%
# List entities and build relationships
# ASSUMPTION: THERE ARE NO ENTITY CLASSES WITH SAME NAME - THERE ARE NO METHODS WITH SAME NAME INTO LOGIC/REPOSITORY CLASSES WITH SAME NAME

# Generic function for all the ReferenceType occurrences
def get_referenced_types(t, include_types):
    types = [] # check REFERENCE TYPES and TYPE ARGUMENTS
    if t.arguments is not None:
        for argument in t.arguments:
            if isinstance(argument.type, javalang.tree.ReferenceType):
                types.extend(get_referenced_types(argument.type, include_types))
    elif t.name in include_types:
        types.append(t.name)
    return types

# Collects references in field declaration of a class
def collect_references(decl_body, include_types):
    referenced_types = []
    for cd in decl_body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            if isinstance(cd.type, javalang.tree.ReferenceType):
                referenced_types.extend(get_referenced_types(cd.type, include_types))
    return referenced_types

def collect_inheritance(decl, entity_names):
    if decl.extends is not None:
        return get_referenced_types(decl.extends, entity_names)
    else:
        return []
    

entity_names = [decl.name for (decl, n) in entity_classes]
entities_relationships_dictionary = dict() # <- RESULT NEEDED TO BUILD THE GRAPH!

for (decl, package_name) in entity_classes:
    # Collect dependencies from the entity (references):
    references = collect_references(decl.body, entity_names) # <- OK, IT WORKS
    extends = collect_inheritance(decl, entity_names) # <- OK, IT WORKS
    entities_relationships_dictionary[decl.name] = {'type': 'Entity', 'references': references, 'extends': extends}

# %% [markdown]
# ## 5. Get list of classes that implement interfaces

# %%
# Build a dictionary that associates the implementation class to each interface
interface_names = [decl.name for (decl, n) in interfaces]

implementations_dict = dict()
        
for (decl, package_name) in logic_classes + repository_classes:
    class_implements = []
    if isinstance(decl, javalang.tree.ClassDeclaration) and decl.implements is not None:
        for impl in decl.implements:
            class_implements.extend(get_referenced_types(impl, interface_names))
    implementations_dict[decl.name] = {'implements': class_implements}
#print(implementations_dict)

implemented_by_dict = dict()

implementing_classes = implementations_dict.keys()
for impl in implementing_classes:
    ints = implementations_dict[impl]
    for interface in ints['implements']:
        if interface not in implemented_by_dict:
            implemented_by_dict[interface] = []
        implemented_by_dict[interface].append(impl)

# %% [markdown]
# ## 6. Get list of class declarations
#
# Class member declarations are collected in order to track references between variable name and referenced types

# %%
# List logic classes and track type references

# Returns a tuple with the list of the declared variables and the types (there are multiple types if it is like Map<A, B>)
def get_field_declarations_with_varnames(f_decl, include_types):
    variables_names = []
    var_types = []
    if isinstance(f_decl.type, javalang.tree.ReferenceType):
        var_types = get_referenced_types(f_decl.type, referenceable_names)
        if len(var_types) > 0:
            for declarator in f_decl.declarators:
                variables_names.append(declarator.name)
    return (variables_names, var_types)


logic_classes_names = [decl.name for (decl, n) in logic_classes + repository_classes]
repository_interfaces_names = [decl.name for (decl, n) in repository_interfaces]
interfaces_names = [decl.name for (decl, n) in interfaces]

referenceable_names = entity_names + logic_classes_names + interfaces_names + repository_interfaces_names

class_variables_types_dict = dict()

# Build a dictionary for each class with the type of each class member
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    if class_name not in class_variables_types_dict:
        class_variables_types_dict[class_name] = dict()
    for cd in decl.body:
        if isinstance(cd, javalang.tree.FieldDeclaration):
            (variables_names, var_types) = get_field_declarations_with_varnames(cd, referenceable_names)
            if len(var_types) > 0:
                for var_name in variables_names:
                    class_variables_types_dict[class_name][var_name] = var_types

# %% [markdown]
# ## 7. Get the references for each method

# %%
# Go into methods: build a dictionary for the references of each method (both with entities and called methods)

def inspect_method_invocation(invocation, class_variables, referenceable_names, class_name):
    references = []
    method_calls = []

    # If there is no qualifier, then a method from the same class is invoked
    if invocation.qualifier is not None and invocation.qualifier != '':

        # If the qualifier is not a class variable, avoid (but inspect the arguments)
        if invocation.qualifier in class_variables:
            called_class = class_variables[invocation.qualifier][0]
            method_calls.append((invocation.member, called_class))
            
    else:
        method_calls.append((invocation.member, class_name))
    
    # Go inside arguments
    (refs, mcalls) = inspect_and_get_references(invocation.arguments, class_variables, referenceable_names, class_name)
    references.extend(refs)
    method_calls.extend(mcalls)
    
    return (references, method_calls)

def inspect_this(this, class_variables, referenceable_names, class_name):
    # Consider expressions with the form "this.member.method()"
    if len(this.selectors) == 2 and isinstance(this.selectors[0], javalang.tree.MemberReference) and isinstance(this.selectors[1], javalang.tree.MethodInvocation):
        # Do a trick: insert the member reference as qualifier of the method invocation
        member_reference = this.selectors[0]
        invocation = this.selectors[1]

        setattr(invocation, 'qualifier', member_reference.member)

        return inspect_method_invocation(invocation, class_variables, referenceable_names, class_name)
    
    return ([], [])

def inspect_and_get_references(code_element, class_variables, referenceable_names, class_name):
    
    references = []
    method_calls = []
    
    # Check if the code_element is a list: if so, iterate inspect on each list element
    if isinstance(code_element, list):
        for e in code_element:
            (refs, mcalls) = inspect_and_get_references(e, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    # Discard all none elements and all elements that are not a node of the AST
    elif code_element == None or not isinstance(code_element, javalang.tree.Node):
        return (references, method_calls)

    # Get referenced types
    elif isinstance(code_element, javalang.tree.ReferenceType):
        references.extend(get_referenced_types(code_element, referenceable_names))

    # Check "this" expressions in search of this.member.method() expressions
    elif isinstance(code_element, javalang.tree.This):
        (refs, mcalls) = inspect_this(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)
    
    # Get method invocation
    elif isinstance(code_element, javalang.tree.MethodInvocation):
        (refs, mcalls) = inspect_method_invocation(code_element, class_variables, referenceable_names, class_name)
        references.extend(refs)
        method_calls.extend(mcalls)

    else:
        for attribute_name in code_element.attrs:
            new_el = getattr(code_element, attribute_name)
            (refs, mcalls) = inspect_and_get_references(new_el, class_variables, referenceable_names, class_name)
            references.extend(refs)
            method_calls.extend(mcalls)

    return (references, method_calls)


methods_usage_dict = dict()

# Collect references of repository interfaces
for (decl, package_name) in repository_interfaces:
    interface_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, interface_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, interface_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, interface_name)]['parameters'] = parameter_references

# Collect references of logic and repository classes
for (decl, package_name) in logic_classes + repository_classes:
    class_name = decl.name
    for cd in decl.body:
        if isinstance(cd, javalang.tree.MethodDeclaration):
            method_name = cd.name
            methods_usage_dict[(method_name, class_name)] = dict()
            # GET THE RETURN TYPE
            if cd.return_type is not None and isinstance(cd.return_type, javalang.tree.ReferenceType):
                return_reference = get_referenced_types(cd.return_type, entity_names)
                methods_usage_dict[(method_name, class_name)]['return'] = return_reference

            # GET PARAMETERS TYPE
            if cd.parameters is not None:
                parameter_references = []
                for par in cd.parameters:
                    if isinstance(par.type, javalang.tree.ReferenceType):
                        parameter_references.extend(get_referenced_types(par.type, entity_names))
                methods_usage_dict[(method_name, class_name)]['parameters'] = parameter_references

            # GET METHOD BODY REFERENCES
            # First get the class variables dictionary (it is needed to track the method calls or references to class members)
            class_variables = class_variables_types_dict[class_name]
            # Go inside
            method_body_references = inspect_and_get_references(cd.body, class_variables, referenceable_names, class_name)
            methods_usage_dict[(method_name, class_name)]['references'] = method_body_references[0]
            methods_usage_dict[(method_name, class_name)]['calls'] = method_body_references[1]

# %% [markdown]
# ## 8. Build nodes.csv file
#
# The _nodes.csv_ files contains the list of all the nodes of the gragh: key, type, name, name of the class (if nodes of type 'Method')

# %%
# Last step: clean the data and build the csv files

# Nodes: entities and methods... entities are taken from the entity_names list, methods are taken from the keys of the reference dictionary
with open(analysis_results_basedir + project + '_nodes.csv', 'w') as nodes_file:
    counter = 0
    # Entities
    for entity_name in entity_names:
        nodes_file.write(str(counter) + ',' + 'Entity,' + entity_name + '\n')
        counter += 1
    # Methods
    for (method_name, class_name) in methods_usage_dict:
        # if the class_name is actually an interface, substitute with its implementing class
        if class_name in interfaces_names:
            if class_name in implemented_by_dict:
                nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + implemented_by_dict[class_name][0] + '\n')
                counter += 1
            else:
                print('WARNING: ' + class_name + 'interface does not have an implementing class!')
        else:
            nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
            counter += 1

# %% [markdown]
# ## 9. Write all _raw_ edges on a .csv file
#
# The _edges_written.csv_ file contains the list of all the edges by using the method/entity name as endpoints, without any reference with the node list

# %%
# Edges: take only the method calls in the 
repository_names = [decl.name for (decl, package_name) in repository_classes + repository_interfaces]

with open (analysis_results_basedir + project + '_edges_written.csv', 'w') as edges_written_file:
    # Add method calls edges
    for (calling_method, calling_class) in methods_usage_dict:
        if 'calls' in methods_usage_dict[(calling_method, calling_class)].keys():
            called_methods = methods_usage_dict[(calling_method, calling_class)]['calls']
            for (called_method, called_class) in called_methods:
                # if called_class is actually an interface, substitute with its implementing class
                if called_class in interfaces_names:
                    if called_class in implemented_by_dict:
                        # Add method reference to the file
                        edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + implemented_by_dict[called_class][0] + ')\n')
                    else:
                        print('WARNING: ' + called_class + 'interface does not have an implementing class!')
                else:
                    # Add method reference to the file
                    edges_written_file.write(calling_method + '(' + calling_class + '),Calls,' + called_method + '(' + called_class + ')\n')
    
    # Add usage relationships edges
    for (calling_method, calling_class) in methods_usage_dict:
        method_relationships = methods_usage_dict[(calling_method, calling_class)]
        usages = method_relationships['parameters']\
                + (method_relationships['references'] if 'references' in method_relationships.keys() else [])\
                + (method_relationships['return'] if 'return' in method_relationships.keys() else [])
        usages = list(dict.fromkeys(usages))
        for usage in usages:
            if calling_class in repository_names:
                edges_written_file.write(calling_method + '(' + calling_class + '),Persists,' + usage + '\n')
            else:
                edges_written_file.write(calling_method + '(' + calling_class + '),Uses,' + usage + '\n')
                #pass
    
    # Add entity relationships edges
    for entity in entities_relationships_dictionary:
        for referenced_entity in entities_relationships_dictionary[entity]['references']:
            edges_written_file.write(entity + ',References,' + referenced_entity + '\n')
        for extended_entity in entities_relationships_dictionary[entity]['extends']:
            edges_written_file.write(entity + ',Extends,' + extended_entity + '\n')

# %% [markdown]
# ## 10. Write edges.csv file
#
# The _edges.csv_ file contains the list of all the edges whose entities are listed in the nodes file. It references the key of the node (from _nodes.csv_) and the relationship type.\
# Edges from nodes that are not in _nodes.csv_ (that have not been detected during the code analysis) are discarded.

# %%
# Writing edges.csv

node_dict = dict()

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    for node in nodes_csv:
        if node[1] == 'Method':
            node_dict[(node[2], node[3])] = (node[0], node[1])
        elif node[1] == 'Entity':
            node_dict[node[2]] = (node[0], node[1])

discarded_edges = []
with open(analysis_results_basedir + project + '_edges_written.csv', 'r') as written_edges_file, open(analysis_results_basedir + project + '_edges.csv', 'w') as edges_file:
    edges_csv = csv.reader(written_edges_file, delimiter=',')

    for edge in edges_csv:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' skipped since target method is not listed in the nodes file!')
                discarded_edges.append(edge)

        elif edge[1] == 'Persists' or edge[1] == 'Uses':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_name = edge[2]

            if (in_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',' + edge[1] + ',' + node_dict[in_name][0] + '\n')
            else:
                print('INFO: Edge ' + str(edge) + ' discarded since target entity is not listed in the nodes file!')

        else:
            edges_file.write(node_dict[edge[0]][0] + ',' + edge[1] + ',' + node_dict[edge[2]][0] + '\n')
# Out:
# INFO: Edge ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'isAssignableFrom(MultipleCredsMatchingAuthenticationProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'equals(MultipleCredsMatchingAuthenticationProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'getPasswordEncoder(MultipleCredsMatchingAuthenticationProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseSearchResult(LyricsWSController)', 'Calls', 'createSAXBuilder(LyricsWSController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['doRefreshChannel(PodcastService)', 'Calls', 'createSAXBuilder(PodcastService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCurrentUsername(SecurityService)', 'Calls', 'getRemoteUser(SecurityService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeStreamStatus(StatusService)', 'Calls', 'compute(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeStreamStatus(StatusService)', 'Calls', 'remove(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllStreamStatuses(StatusService)', 'Calls', 'values(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStreamStatusesForPlayer(StatusService)', 'Calls', 'parallelStream(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInactiveStreamStatusForPlayer(StatusService)', 'Calls', 'get(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeDownloadStatus(StatusService)', 'Calls', 'remove(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeUploadStatus(StatusService)', 'Calls', 'remove(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cleanupRemotePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['cleanupRemotePlays(StatusService)', 'Calls', 'remove(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addRemotePlay(StatusService)', 'Calls', 'add(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addActiveLocalPlay(StatusService)', 'Calls', 'add(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['removeActiveLocalPlay(StatusService)', 'Calls', 'remove(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getActivePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInactivePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInactivePlays(StatusService)', 'Calls', 'values(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'getResourceAsStream(SettingsService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'toArray(Theme)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'size(Theme)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAvailableLocales(SettingsService)', 'Calls', 'getResourceAsStream(SettingsService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllMusicFolders(SettingsService)', 'Calls', 'parallelStream(MusicFolder)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setMusicFoldersForUser(SettingsService)', 'Calls', 'remove(MusicFolder)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['clearMusicFolderCache(SettingsService)', 'Calls', 'clear(MusicFolder)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createPlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createPlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addPlaylistUser(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deletePlaylistUser(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deletePlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getImportHandler(PlaylistService)', 'Calls', 'stream(DefaultPlaylistImportHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getExportHandler(PlaylistService)', 'Calls', 'stream(DefaultPlaylistExportHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'pause(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'getState(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'play(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'close(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'setGain(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'play(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPosition(JukeboxLegacySubsonicService)', 'Calls', 'getPosition(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'setFile(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'addBytesTransferred(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getId(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getPlayer(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getMillisSinceLastUpdate(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongEnd(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['scrobble(JukeboxLegacySubsonicService)', 'Calls', 'getClientId(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['scrobble(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setGain(JukeboxLegacySubsonicService)', 'Calls', 'setGain(AudioPlayer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'setFile(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'addBytesTransferred(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getId(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getPlayer(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getMillisSinceLastUpdate(TransferStatus)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['play(JukeboxJavaService)', 'Calls', 'getCurrentAudioFile(JukeboxJavaService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['register(AudioScrobblerService)', 'Calls', 'register(LastFMScrobbler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['register(AudioScrobblerService)', 'Calls', 'register(ListenBrainzScrobbler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['start(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['stop(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['skip(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['toggleRepeat(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setJukeboxGain(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setJukeboxPosition(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['broadcastPlayQueue(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'getClass(UPnPService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setMusicServiceEnabled(SonosService)', 'Calls', 'setEnabled(SonosService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSessionId(SonosService)', 'Calls', 'authenticate(MultipleCredsMatchingAuthenticationProvider)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getUsername(SonosService)', 'Calls', 'getContext(SonosService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isDownsamplingSupported(TranscodingService)', 'Calls', 'equalsIgnoreCase(TranscodingService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['clearInternetRadioSourceCache(InternetRadioService)', 'Calls', 'remove(InternetRadioSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'containsKey(InternetRadioSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'get(InternetRadioSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'put(InternetRadioSource)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['isExcluded(MediaFileService)', 'Calls', 'equals(MediaFileService)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMediaFile(MediaFileService)', 'Calls', 'getMetaData(JaudiotaggerParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMediaFile(MediaFileService)', 'Calls', 'getMetaData(JaudiotaggerParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCoverArtUrl(SonosHelper)', 'Calls', 'getBaseUrl(SonosHelper)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['canHandle(XspfPlaylistImportHandler)', 'Calls', 'equals(XspfPlaylistImportHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['canHandle(XspfPlaylistExportHandler)', 'Calls', 'equals(XspfPlaylistExportHandler)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(GenreUpnpProcessor)', 'Calls', 'createBrowseResult(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(GenreUpnpProcessor)', 'Calls', 'getRootId(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(GenreUpnpProcessor)', 'Calls', 'getRootId(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getChildren(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getChildren(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addChild(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseObjectMetadata(MediaFileUpnpProcessor)', 'Calls', 'createBrowseResult(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMediaFileService(MediaFileUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(MediaFileUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'addItem(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'createBrowseResult(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getChildren(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getChildren(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItemsSize(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addChild(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumArtURI(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMediaFileDao(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createItem(DispatchingContentDirectory)', 'Calls', 'createResourceForSong(DispatchingContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumArtUrl(DispatchingContentDirectory)', 'Calls', 'getBaseUrl(DispatchingContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRootMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browsePlaylistRootMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browsePlaylistRoot(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browsePlaylistMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browsePlaylist(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseMediaFileMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseMediaFile(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createItem(FolderBasedContentDirectory)', 'Calls', 'createResourceForSong(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumArtUrl(FolderBasedContentDirectory)', 'Calls', 'getBaseUrl(FolderBasedContentDirectory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(PlaylistUpnpProcessor)', 'Calls', 'getRootId(PlaylistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(PlaylistUpnpProcessor)', 'Calls', 'getRootId(PlaylistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getItemById(PlaylistUpnpProcessor)', 'Calls', 'getDispatcher(PlaylistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['addChild(PlaylistUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(PlaylistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(RecentAlbumUpnpProcessor)', 'Calls', 'addItem(RecentAlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['browseRoot(RecentAlbumUpnpProcessor)', 'Calls', 'createBrowseResult(RecentAlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RecentAlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RecentAlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(RecentAlbumUpnpProcessor)', 'Calls', 'getAlbumDao(RecentAlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItemsSize(RecentAlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RecentAlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItemsSize(RecentAlbumUpnpProcessor)', 'Calls', 'getAlbumDao(RecentAlbumUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(ArtistUpnpProcessor)', 'Calls', 'getRootId(ArtistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createContainer(ArtistUpnpProcessor)', 'Calls', 'getRootId(ArtistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllItems(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getChildren(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumProcessor(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAnalyzer(AnalyzerFactory)', 'Calls', 'isEmpty(AnalyzerFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getQueryAnalyzer(AnalyzerFactory)', 'Calls', 'isEmpty(AnalyzerFactory)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRandomSongs(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRandomAlbums(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRandomAlbumsId3(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setMetaData(FFmpegParser)', 'Calls', 'getClass(FFmpegParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessArtist(DefaultMetaDataParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessAlbum(DefaultMetaDataParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessTitle(DefaultMetaDataParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getParser(MetaDataParserFactory)', 'Calls', 'stream(MetaDataParser)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Calls', 'getResourceAsStream(RegisterPrecompiledJSPInitializer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Calls', 'getContext(RegisterPrecompiledJSPInitializer)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequest(StreamController)', 'Calls', 'equals(StreamController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getShoutcastDetails(StreamController)', 'Calls', 'start(StreamController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handlePost(ImportPlaylistController)', 'Calls', 'equals(ImportPlaylistController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['expunge(MusicFolderSettingsController)', 'Calls', 'checkpoint(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['sendFallback(CoverArtController)', 'Calls', 'getClass(CoverArtController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'getBackground(StatusChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'getForeground(StatusChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getIntParameter(HomeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getStringParameter(HomeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getIntParameter(HomeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getStringParameter(HomeController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createChart(UserChartController)', 'Calls', 'getBackground(UserChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createChart(UserChartController)', 'Calls', 'getForeground(UserChartController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(UploadController)', 'Calls', 'equals(UploadController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(UploadController)', 'Calls', 'equals(UploadController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unzip(UploadController)', 'Calls', 'createArchiveInputStream(UploadController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['prepareResponse(DownloadController)', 'Calls', 'start(DownloadController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'getDisplayName(PersonalSettingsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'equals(PersonalSettingsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'getId(PersonalSettingsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'equals(PersonalSettingsController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['ping(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getLicense(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getLicense(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicFolders(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getGenres(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtists(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createJaxbArtist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtist(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createJaxbAlbum(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createJaxbAlbum(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createJaxbPlaylist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createJaxbPlaylist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbum(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbum(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSong(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSong(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPlaylists(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPlaylist(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredFloatParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createPlaylist(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createPlaylist(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deletePlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped since target method is not listed in the nodes file!
# ...
# INFO: Edge ['createOrUpdateMediaFile(MediaFileDao)', 'Calls', 'update(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrUpdateMediaFile(MediaFileDao)', 'Calls', 'questionMarks(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrUpdateMediaFile(MediaFileDao)', 'Calls', 'queryForInt(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicFileInfo(MediaFileDao)', 'Calls', 'queryOne(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteMediaFiles(MediaFileDao)', 'Calls', 'batchedUpdate(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getGenres(MediaFileDao)', 'Calls', 'query(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateGenres(MediaFileDao)', 'Calls', 'update(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateGenres(MediaFileDao)', 'Calls', 'batchedUpdate(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMostFrequentlyPlayedAlbums(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMostRecentlyPlayedAlbums(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getNewestAlbums(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlphabeticalAlbums(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumsByYear(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumsByYear(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumsByGenre(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByGenre(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongsByArtist(MediaFileDao)', 'Calls', 'query(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongByArtistAndTitle(MediaFileDao)', 'Calls', 'namedQueryOne(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredAlbums(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredAlbums(MediaFileDao)', 'Calls', 'prefix(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredDirectories(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredDirectories(MediaFileDao)', 'Calls', 'prefix(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredFiles(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredFiles(MediaFileDao)', 'Calls', 'prefix(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRandomSongs(MediaFileDao)', 'Calls', 'prefix(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getRandomSongs(MediaFileDao)', 'Calls', 'namedQuery(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumCount(MediaFileDao)', 'Calls', 'namedQueryForInt(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPlayedAlbumCount(MediaFileDao)', 'Calls', 'namedQueryForInt(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getStarredAlbumCount(MediaFileDao)', 'Calls', 'namedQueryForInt(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['starMediaFile(MediaFileDao)', 'Calls', 'update(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['unstarMediaFile(MediaFileDao)', 'Calls', 'update(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMediaFileStarredDate(MediaFileDao)', 'Calls', 'queryForInstant(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['markNonPresent(MediaFileDao)', 'Calls', 'update(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getArtistExpungeCandidates(MediaFileDao)', 'Calls', 'queryForInts(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAlbumExpungeCandidates(MediaFileDao)', 'Calls', 'queryForInts(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSongExpungeCandidates(MediaFileDao)', 'Calls', 'queryForInts(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['expunge(MediaFileDao)', 'Calls', 'update(MediaFileDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getInternetRadioById(InternetRadioDao)', 'Calls', 'queryOne(InternetRadioDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllInternetRadios(InternetRadioDao)', 'Calls', 'query(InternetRadioDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createInternetRadio(InternetRadioDao)', 'Calls', 'update(InternetRadioDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteInternetRadio(InternetRadioDao)', 'Calls', 'update(InternetRadioDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateInternetRadio(InternetRadioDao)', 'Calls', 'update(InternetRadioDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllSystemAvatars(AvatarDao)', 'Calls', 'query(AvatarDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSystemAvatar(AvatarDao)', 'Calls', 'queryOne(AvatarDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getCustomAvatar(AvatarDao)', 'Calls', 'queryOne(AvatarDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setCustomAvatar(AvatarDao)', 'Calls', 'update(AvatarDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setCustomAvatar(AvatarDao)', 'Calls', 'update(AvatarDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setCustomAvatar(AvatarDao)', 'Calls', 'questionMarks(AvatarDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createShare(ShareDao)', 'Calls', 'questionMarks(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createShare(ShareDao)', 'Calls', 'update(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createShare(ShareDao)', 'Calls', 'queryForInt(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllShares(ShareDao)', 'Calls', 'query(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getShareByName(ShareDao)', 'Calls', 'queryOne(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getShareById(ShareDao)', 'Calls', 'queryOne(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateShare(ShareDao)', 'Calls', 'update(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createSharedFiles(ShareDao)', 'Calls', 'update(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getSharedFiles(ShareDao)', 'Calls', 'namedQuery(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteShare(ShareDao)', 'Calls', 'update(ShareDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getBookmarks(BookmarkDao)', 'Calls', 'query(BookmarkDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrUpdateBookmark(BookmarkDao)', 'Calls', 'update(BookmarkDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrUpdateBookmark(BookmarkDao)', 'Calls', 'update(BookmarkDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrUpdateBookmark(BookmarkDao)', 'Calls', 'questionMarks(BookmarkDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createOrUpdateBookmark(BookmarkDao)', 'Calls', 'queryForInt(BookmarkDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteBookmark(BookmarkDao)', 'Calls', 'update(BookmarkDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllMusicFolders(MusicFolderDao)', 'Calls', 'query(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicFolderForPath(MusicFolderDao)', 'Calls', 'queryOne(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMusicFolder(MusicFolderDao)', 'Calls', 'update(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMusicFolder(MusicFolderDao)', 'Calls', 'queryForInt(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createMusicFolder(MusicFolderDao)', 'Calls', 'update(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteMusicFolder(MusicFolderDao)', 'Calls', 'update(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateMusicFolder(MusicFolderDao)', 'Calls', 'update(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicFoldersForUser(MusicFolderDao)', 'Calls', 'prefix(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getMusicFoldersForUser(MusicFolderDao)', 'Calls', 'query(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setMusicFoldersForUser(MusicFolderDao)', 'Calls', 'update(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setMusicFoldersForUser(MusicFolderDao)', 'Calls', 'update(MusicFolderDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createChannel(PodcastDao)', 'Calls', 'questionMarks(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createChannel(PodcastDao)', 'Calls', 'update(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createChannel(PodcastDao)', 'Calls', 'queryForInt(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllChannels(PodcastDao)', 'Calls', 'query(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getChannel(PodcastDao)', 'Calls', 'queryOne(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateChannel(PodcastDao)', 'Calls', 'update(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteChannel(PodcastDao)', 'Calls', 'update(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createEpisode(PodcastDao)', 'Calls', 'questionMarks(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createEpisode(PodcastDao)', 'Calls', 'update(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEpisodes(PodcastDao)', 'Calls', 'query(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getNewestEpisodes(PodcastDao)', 'Calls', 'query(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEpisode(PodcastDao)', 'Calls', 'queryOne(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getEpisodeByUrl(PodcastDao)', 'Calls', 'queryOne(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateEpisode(PodcastDao)', 'Calls', 'update(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteEpisode(PodcastDao)', 'Calls', 'update(PodcastDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getAllTranscodings(TranscodingDao)', 'Calls', 'query(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getTranscodingsForPlayer(TranscodingDao)', 'Calls', 'query(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setTranscodingsForPlayer(TranscodingDao)', 'Calls', 'update(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['setTranscodingsForPlayer(TranscodingDao)', 'Calls', 'update(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createTranscoding(TranscodingDao)', 'Calls', 'queryForInt(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createTranscoding(TranscodingDao)', 'Calls', 'questionMarks(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['createTranscoding(TranscodingDao)', 'Calls', 'update(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['deleteTranscoding(TranscodingDao)', 'Calls', 'update(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['updateTranscoding(TranscodingDao)', 'Calls', 'update(TranscodingDao)'] skipped since target method is not listed in the nodes file!
# INFO: Edge ['getPlaylist(PlaylistWSController)', 'Uses', 'PlaylistService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['updateCredentials(SecurityService)', 'Uses', 'PasswordDecoder'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Uses', 'SettingsService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getAvailableLocales(SettingsService)', 'Uses', 'SettingsService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['importPlaylist(PlaylistService)', 'Uses', 'PlaylistImportHandler'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['exportPlaylist(PlaylistService)', 'Uses', 'PlaylistExportHandler'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Uses', 'TranscodingService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['decode(AudioScrobblerService)', 'Uses', 'PasswordDecoder'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getChildren(AlbumUpnpProcessor)', 'Uses', 'ArtistUpnpProcessor'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Uses', 'RegisterPrecompiledJSPInitializer'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleRequest(StreamController)', 'Uses', 'TranscodingService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['getImageInputStreamForVideo(CoverArtController)', 'Uses', 'TranscodingService'] discarded since target entity is not listed in the nodes file!
# INFO: Edge ['handleRequestInternal(UploadController)', 'Uses', 'UploadListener'] discarded since target entity is not listed in the nodes file!

# %% [markdown]
# ## 11. Add nodes for the not-implemented persistence methods
#
# Methods from the persistence layer are often owned by a framework. E.g., _save()_ or _findAll()_ methods are not defined neither in a persistence class nor in an interface.\
# These methods will be automatically detected and added into the graph.
#
#
# The _nodes.csv_ and _edges.csv_ are updated as a consequence. (_edges_written.csv_ already contains edges towards these methods)

# %%
# Update the graph by adding the discarded edges from a repository interface - or class

methods_to_add = dict() # index is (name, class_name), value is ([(called_by_bame, called_by_class)], [persisting_etities])

for edge in discarded_edges:

    # If a method call is discarded
    if edge[1] == 'Calls':
        out_names = edge[0].split('(')
        out_method_name = out_names[0]
        out_class_name = out_names[1].replace(')', '')

        in_names = edge[2].split('(')
        in_method_name = in_names[0]
        in_class_name = in_names[1].replace(')', '')
    
        # If the class of the called method is from a repository layer...
        if in_class_name in repository_interfaces_names + [decl.name for (decl, n) in repository_classes]:

            # Iterate over the list of repository interfaces and classes and get the interface definition
            for (decl, package_name) in repository_interfaces + repository_classes:

                # Once found it
                if decl.name == in_class_name:

                    # For repository interfaces, most of the time they rely on a specific framework (e.g., Spring Data) that has default method definition...
                    # ...they do not need to be redefined, it is just needed to extend a base (parametrical) interface.
                    # The method can be added directly without any other checking.
                    #
                    # For repository classes, usually there is a "BaseDAO" with a parametrical Type which implements the crud operations.
                    # The method has already been added from the superclass. In order to bind it with the actual entity parameter, it will be copied...
                    # ...but references inside its implementation will be discarded, keeping only the "persists" relationship.
                    # Methods from the superclass will be removed at the end of the graph building process.
                    #
                    # In order to get which entity is persisted, let's get the referenced type in the interface or class "extends" definition
                    references = inspect_and_get_references(decl.extends, [], entity_names, in_class_name)[0]
                    if ((in_method_name, in_class_name)) not in methods_to_add:
                        methods_to_add[(in_method_name, in_class_name)] = ([(out_method_name, out_class_name)], references)
                    else:
                        m = methods_to_add[(in_method_name, in_class_name)]
                        m[0].append((in_method_name, in_class_name))
                        m[1].extend(references)

        # If the class of the called method is from a logic class (not in the repository layer)...
        elif in_class_name in logic_classes_names:
            print('WARNING: unable to recover ' + str(edge) + ' since target method may be from a superclass. (Not implemented yet)')
        else:
            print('WARNING: Unable to recover target method for edge ' + str(edge) + ': discarding')
# Out:
# WARNING: unable to recover ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'isAssignableFrom(MultipleCredsMatchingAuthenticationProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'equals(MultipleCredsMatchingAuthenticationProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'getPasswordEncoder(MultipleCredsMatchingAuthenticationProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseSearchResult(LyricsWSController)', 'Calls', 'createSAXBuilder(LyricsWSController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['doRefreshChannel(PodcastService)', 'Calls', 'createSAXBuilder(PodcastService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCurrentUsername(SecurityService)', 'Calls', 'getRemoteUser(SecurityService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['removeStreamStatus(StatusService)', 'Calls', 'compute(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['removeStreamStatus(StatusService)', 'Calls', 'remove(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['getAllStreamStatuses(StatusService)', 'Calls', 'values(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['getStreamStatusesForPlayer(StatusService)', 'Calls', 'parallelStream(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['getInactiveStreamStatusForPlayer(StatusService)', 'Calls', 'get(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['removeDownloadStatus(StatusService)', 'Calls', 'remove(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['removeUploadStatus(StatusService)', 'Calls', 'remove(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['cleanupRemotePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['cleanupRemotePlays(StatusService)', 'Calls', 'remove(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['addRemotePlay(StatusService)', 'Calls', 'add(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['addActiveLocalPlay(StatusService)', 'Calls', 'add(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['removeActiveLocalPlay(StatusService)', 'Calls', 'remove(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['getActivePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['getInactivePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)']: discarding
# WARNING: Unable to recover target method for edge ['getInactivePlays(StatusService)', 'Calls', 'values(TransferStatus)']: discarding
# WARNING: unable to recover ['getAvailableThemes(SettingsService)', 'Calls', 'getResourceAsStream(SettingsService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)']: discarding
# WARNING: Unable to recover target method for edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)']: discarding
# WARNING: Unable to recover target method for edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)']: discarding
# WARNING: Unable to recover target method for edge ['getAvailableThemes(SettingsService)', 'Calls', 'toArray(Theme)']: discarding
# WARNING: Unable to recover target method for edge ['getAvailableThemes(SettingsService)', 'Calls', 'size(Theme)']: discarding
# WARNING: unable to recover ['getAvailableLocales(SettingsService)', 'Calls', 'getResourceAsStream(SettingsService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getAllMusicFolders(SettingsService)', 'Calls', 'parallelStream(MusicFolder)']: discarding
# WARNING: Unable to recover target method for edge ['setMusicFoldersForUser(SettingsService)', 'Calls', 'remove(MusicFolder)']: discarding
# WARNING: Unable to recover target method for edge ['clearMusicFolderCache(SettingsService)', 'Calls', 'clear(MusicFolder)']: discarding
# WARNING: unable to recover ['createPlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createPlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addPlaylistUser(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePlaylistUser(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updatePlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getImportHandler(PlaylistService)', 'Calls', 'stream(DefaultPlaylistImportHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getExportHandler(PlaylistService)', 'Calls', 'stream(DefaultPlaylistExportHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)']: discarding
# WARNING: Unable to recover target method for edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)']: discarding
# WARNING: Unable to recover target method for edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)']: discarding
# WARNING: Unable to recover target method for edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)']: discarding
# WARNING: Unable to recover target method for edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'pause(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'getState(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'play(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'close(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'setGain(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'play(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)']: discarding
# WARNING: Unable to recover target method for edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)']: discarding
# WARNING: Unable to recover target method for edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)']: discarding
# WARNING: Unable to recover target method for edge ['getPosition(JukeboxLegacySubsonicService)', 'Calls', 'getPosition(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'setFile(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'addBytesTransferred(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getId(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getPlayer(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getMillisSinceLastUpdate(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongEnd(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)']: discarding
# WARNING: Unable to recover target method for edge ['scrobble(JukeboxLegacySubsonicService)', 'Calls', 'getClientId(Player)']: discarding
# WARNING: Unable to recover target method for edge ['scrobble(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)']: discarding
# WARNING: Unable to recover target method for edge ['setGain(JukeboxLegacySubsonicService)', 'Calls', 'setGain(AudioPlayer)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxJavaService)', 'Calls', 'setFile(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxJavaService)', 'Calls', 'addBytesTransferred(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getId(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getPlayer(TransferStatus)']: discarding
# WARNING: Unable to recover target method for edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getMillisSinceLastUpdate(TransferStatus)']: discarding
# WARNING: unable to recover ['play(JukeboxJavaService)', 'Calls', 'getCurrentAudioFile(JukeboxJavaService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['register(AudioScrobblerService)', 'Calls', 'register(LastFMScrobbler)']: discarding
# WARNING: Unable to recover target method for edge ['register(AudioScrobblerService)', 'Calls', 'register(ListenBrainzScrobbler)']: discarding
# WARNING: unable to recover ['start(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['stop(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['skip(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['toggleRepeat(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setJukeboxGain(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setJukeboxPosition(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['broadcastPlayQueue(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createMediaServerDevice(UPnPService)', 'Calls', 'getClass(UPnPService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setMusicServiceEnabled(SonosService)', 'Calls', 'setEnabled(SonosService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSessionId(SonosService)', 'Calls', 'authenticate(MultipleCredsMatchingAuthenticationProvider)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUsername(SonosService)', 'Calls', 'getContext(SonosService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['isDownsamplingSupported(TranscodingService)', 'Calls', 'equalsIgnoreCase(TranscodingService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['clearInternetRadioSourceCache(InternetRadioService)', 'Calls', 'remove(InternetRadioSource)']: discarding
# WARNING: Unable to recover target method for edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'containsKey(InternetRadioSource)']: discarding
# WARNING: Unable to recover target method for edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'get(InternetRadioSource)']: discarding
# WARNING: Unable to recover target method for edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'put(InternetRadioSource)']: discarding
# WARNING: unable to recover ['isExcluded(MediaFileService)', 'Calls', 'equals(MediaFileService)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createMediaFile(MediaFileService)', 'Calls', 'getMetaData(JaudiotaggerParser)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createMediaFile(MediaFileService)', 'Calls', 'getMetaData(JaudiotaggerParser)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getCoverArtUrl(SonosHelper)', 'Calls', 'getBaseUrl(SonosHelper)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['canHandle(XspfPlaylistImportHandler)', 'Calls', 'equals(XspfPlaylistImportHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['canHandle(XspfPlaylistExportHandler)', 'Calls', 'equals(XspfPlaylistExportHandler)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(GenreUpnpProcessor)', 'Calls', 'createBrowseResult(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(GenreUpnpProcessor)', 'Calls', 'getRootId(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(GenreUpnpProcessor)', 'Calls', 'getRootId(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getChildren(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getChildren(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addChild(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseObjectMetadata(MediaFileUpnpProcessor)', 'Calls', 'createBrowseResult(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getMediaFileService(MediaFileUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(MediaFileUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'addItem(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'createBrowseResult(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getChildren(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getChildren(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItemsSize(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addChild(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAlbumArtURI(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getMediaFileDao(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createItem(DispatchingContentDirectory)', 'Calls', 'createResourceForSong(DispatchingContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAlbumArtUrl(DispatchingContentDirectory)', 'Calls', 'getBaseUrl(DispatchingContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRootMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browsePlaylistRootMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browsePlaylistRoot(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browsePlaylistMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browsePlaylist(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseMediaFileMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseMediaFile(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createItem(FolderBasedContentDirectory)', 'Calls', 'createResourceForSong(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAlbumArtUrl(FolderBasedContentDirectory)', 'Calls', 'getBaseUrl(FolderBasedContentDirectory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(PlaylistUpnpProcessor)', 'Calls', 'getRootId(PlaylistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(PlaylistUpnpProcessor)', 'Calls', 'getRootId(PlaylistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getItemById(PlaylistUpnpProcessor)', 'Calls', 'getDispatcher(PlaylistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['addChild(PlaylistUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(PlaylistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(RecentAlbumUpnpProcessor)', 'Calls', 'addItem(RecentAlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['browseRoot(RecentAlbumUpnpProcessor)', 'Calls', 'createBrowseResult(RecentAlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RecentAlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RecentAlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(RecentAlbumUpnpProcessor)', 'Calls', 'getAlbumDao(RecentAlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItemsSize(RecentAlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RecentAlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItemsSize(RecentAlbumUpnpProcessor)', 'Calls', 'getAlbumDao(RecentAlbumUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(ArtistUpnpProcessor)', 'Calls', 'getRootId(ArtistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createContainer(ArtistUpnpProcessor)', 'Calls', 'getRootId(ArtistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAllItems(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getChildren(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAlbumProcessor(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getAnalyzer(AnalyzerFactory)', 'Calls', 'isEmpty(AnalyzerFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getQueryAnalyzer(AnalyzerFactory)', 'Calls', 'isEmpty(AnalyzerFactory)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getRandomSongs(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getRandomAlbums(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getRandomAlbumsId3(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setMetaData(FFmpegParser)', 'Calls', 'getClass(FFmpegParser)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessArtist(DefaultMetaDataParser)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessAlbum(DefaultMetaDataParser)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessTitle(DefaultMetaDataParser)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getParser(MetaDataParserFactory)', 'Calls', 'stream(MetaDataParser)']: discarding
# WARNING: unable to recover ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Calls', 'getResourceAsStream(RegisterPrecompiledJSPInitializer)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Calls', 'getContext(RegisterPrecompiledJSPInitializer)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequest(StreamController)', 'Calls', 'equals(StreamController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getShoutcastDetails(StreamController)', 'Calls', 'start(StreamController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handlePost(ImportPlaylistController)', 'Calls', 'equals(ImportPlaylistController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['sendFallback(CoverArtController)', 'Calls', 'getClass(CoverArtController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequest(StatusChartController)', 'Calls', 'getBackground(StatusChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequest(StatusChartController)', 'Calls', 'getForeground(StatusChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(HomeController)', 'Calls', 'getIntParameter(HomeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(HomeController)', 'Calls', 'getStringParameter(HomeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(HomeController)', 'Calls', 'getIntParameter(HomeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(HomeController)', 'Calls', 'getStringParameter(HomeController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createChart(UserChartController)', 'Calls', 'getBackground(UserChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createChart(UserChartController)', 'Calls', 'getForeground(UserChartController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(UploadController)', 'Calls', 'equals(UploadController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(UploadController)', 'Calls', 'equals(UploadController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['unzip(UploadController)', 'Calls', 'createArchiveInputStream(UploadController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['prepareResponse(DownloadController)', 'Calls', 'start(DownloadController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['formBackingObject(PersonalSettingsController)', 'Calls', 'getDisplayName(PersonalSettingsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['formBackingObject(PersonalSettingsController)', 'Calls', 'equals(PersonalSettingsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['formBackingObject(PersonalSettingsController)', 'Calls', 'getId(PersonalSettingsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['formBackingObject(PersonalSettingsController)', 'Calls', 'equals(PersonalSettingsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['ping(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getLicense(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getLicense(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getMusicFolders(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getIndexes(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getIndexes(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getIndexes(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getIndexes(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getIndexes(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getGenres(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getArtists(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getTopSongs(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getTopSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getArtistInfo(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getArtistInfo(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbArtist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: unable to recover ['getArtist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getArtist(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbAlbum(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbAlbum(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbPlaylist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbPlaylist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: unable to recover ['getAlbum(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getAlbum(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getSong(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getSong(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['search(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['search(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['search2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['search3(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getPlaylists(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getPlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getPlaylist(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# ...
# WARNING: Unable to recover target method for edge ['getStarred(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getStarred2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getStarred2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getPodcasts(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getPodcasts(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getPodcasts(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['getNewestPodcasts(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getNewestPodcasts(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbPodcastEpisode(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: unable to recover ['createPodcastChannel(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePodcastChannel(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deletePodcastEpisode(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['downloadPodcastEpisode(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getInternetRadioStations(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getBookmarks(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getBookmarks(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getBookmarks(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['createBookmark(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createBookmark(SubsonicRESTController)', 'Calls', 'getRequiredLongParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteBookmark(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getPlayQueue(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getPlayQueue(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getShares(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['createShare(SubsonicRESTController)', 'Calls', 'getRequiredIntParameters(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createShare(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['createShare(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['deleteShare(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateShare(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['createJaxbShare(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbShare(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['createJaxbShare(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)']: discarding
# WARNING: unable to recover ['changePassword(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changePassword(SubsonicRESTController)', 'Calls', 'decrypt(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['changePassword(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['getUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getUser(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getUsers(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'decrypt(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'decrypt(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['updateUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['deleteUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getLyrics(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['setRating(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['setRating(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['getAlbumInfo(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getAlbumInfo2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['getScanStatus(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['wrapRequest(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['wrapRequest(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['createResponse(SubsonicRESTController)', 'Calls', 'createResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['writeEmptyResponse(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)']: discarding
# WARNING: Unable to recover target method for edge ['error(SubsonicRESTController)', 'Calls', 'writeErrorResponse(JAXBWriter)']: discarding
# WARNING: unable to recover ['gettingStarted(GettingStartedController)', 'Calls', 'equals(GettingStartedController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['formBackingObject(GeneralSettingsController)', 'Calls', 'getId(GeneralSettingsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['formBackingObject(GeneralSettingsController)', 'Calls', 'getDisplayName(GeneralSettingsController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: unable to recover ['handleRequestInternal(SetMusicFileInfoController)', 'Calls', 'equals(SetMusicFileInfoController)'] since target method may be from a superclass. (Not implemented yet)
# WARNING: Unable to recover target method for edge ['deletePlayer(PlayerDao)', 'Calls', 'remove(PlayQueue)']: discarding
# WARNING: Unable to recover target method for edge ['addPlaylist(PlayerDao)', 'Calls', 'get(PlayQueue)']: discarding
# WARNING: Unable to recover target method for edge ['addPlaylist(PlayerDao)', 'Calls', 'put(PlayQueue)']: discarding

# %%
# Updates nodes.csv and edges.csv files

with open(analysis_results_basedir + project + '_nodes.csv', 'a') as nodes_file:

    counter = len(node_dict.keys())
    
    # write new nodes in nodes.csv and to the node dictionary
    for (method_name, class_name) in methods_to_add:
        print('Adding new node for method ' + method_name + '(' + class_name + ')')
        nodes_file.write(str(counter) + ',' + 'Method,' + method_name + ',' + class_name + '\n')
        node_dict[(method_name, class_name)] = (str(counter), 'Method')
        counter+=1
    
with open(analysis_results_basedir + project + '_edges.csv', 'a') as edges_file:

    # Write previously discarded edges
    for edge in discarded_edges:
        if edge[1] == 'Calls':
            out_names = edge[0].split('(')
            out_method_name = out_names[0]
            out_class_name = out_names[1].replace(')', '')

            in_names = edge[2].split('(')
            in_method_name = in_names[0]
            in_class_name = in_names[1].replace(')', '')

            if (in_method_name, in_class_name) in node_dict:
                edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Calls,' + node_dict[(in_method_name, in_class_name)][0] + '\n')
                print('INFO: Added edge ' + str(edge))
            else:
                print('INFO: Edge ' + str(edge) + ' skipped')

    # Write persists
    for (out_method_name, out_class_name) in methods_to_add:
        for persisted_entity in methods_to_add[(out_method_name, out_class_name)][1]:
            edges_file.write(node_dict[(out_method_name, out_class_name)][0] + ',Persists,' + node_dict[persisted_entity][0] + '\n')
            print('INFO: Added edge [ \'' + out_method_name + '(' + out_class_name + ')\', \'Persists\', \'' + persisted_entity + '\']')
# Out:
# Adding new node for method checkpoint(MediaFileDao)
# Adding new node for method namedQueryForStrings(RatingDao)
# Adding new node for method update(RatingDao)
# Adding new node for method queryForDouble(RatingDao)
# Adding new node for method queryForInt(RatingDao)
# Adding new node for method namedQueryForInt(RatingDao)
# Adding new node for method query(PlaylistDao)
# Adding new node for method prefix(PlaylistDao)
# Adding new node for method queryOne(PlaylistDao)
# Adding new node for method update(PlaylistDao)
# Adding new node for method questionMarks(PlaylistDao)
# Adding new node for method queryForInt(PlaylistDao)
# Adding new node for method queryForStrings(PlaylistDao)
# Adding new node for method query(UserDao)
# Adding new node for method namedQuery(UserDao)
# Adding new node for method queryForInt(UserDao)
# Adding new node for method update(UserDao)
# Adding new node for method questionMarks(UserDao)
# Adding new node for method namedUpdate(UserDao)
# Adding new node for method queryOne(UserDao)
# Adding new node for method queryForStrings(UserDao)
# Adding new node for method queryForInts(UserDao)
# Adding new node for method query(PlayerDao)
# Adding new node for method queryOne(PlayerDao)
# Adding new node for method queryForInt(PlayerDao)
# Adding new node for method questionMarks(PlayerDao)
# Adding new node for method update(PlayerDao)
# Adding new node for method queryOne(AlbumDao)
# Adding new node for method query(AlbumDao)
# Adding new node for method namedQuery(AlbumDao)
# Adding new node for method update(AlbumDao)
# Adding new node for method questionMarks(AlbumDao)
# Adding new node for method queryForInt(AlbumDao)
# Adding new node for method namedQueryForInt(AlbumDao)
# Adding new node for method prefix(AlbumDao)
# Adding new node for method queryForInts(AlbumDao)
# Adding new node for method queryForInstant(AlbumDao)
# Adding new node for method queryOne(ArtistDao)
# Adding new node for method update(ArtistDao)
# Adding new node for method questionMarks(ArtistDao)
# Adding new node for method queryForInt(ArtistDao)
# Adding new node for method namedQuery(ArtistDao)
# Adding new node for method prefix(ArtistDao)
# Adding new node for method queryForInts(ArtistDao)
# Adding new node for method queryForInstant(ArtistDao)
# Adding new node for method queryOne(PlayQueueDao)
# Adding new node for method queryForInts(PlayQueueDao)
# Adding new node for method update(PlayQueueDao)
# Adding new node for method questionMarks(PlayQueueDao)
# Adding new node for method queryForInt(PlayQueueDao)
# Adding new node for method queryOne(MediaFileDao)
# Adding new node for method query(MediaFileDao)
# Adding new node for method prefix(MediaFileDao)
# Adding new node for method namedQuery(MediaFileDao)
# Adding new node for method namedQueryOne(MediaFileDao)
# Adding new node for method update(MediaFileDao)
# Adding new node for method questionMarks(MediaFileDao)
# Adding new node for method queryForInt(MediaFileDao)
# Adding new node for method batchedUpdate(MediaFileDao)
# Adding new node for method namedQueryForInt(MediaFileDao)
# Adding new node for method queryForInstant(MediaFileDao)
# Adding new node for method queryForInts(MediaFileDao)
# Adding new node for method queryOne(InternetRadioDao)
# Adding new node for method query(InternetRadioDao)
# Adding new node for method update(InternetRadioDao)
# Adding new node for method query(AvatarDao)
# Adding new node for method queryOne(AvatarDao)
# Adding new node for method update(AvatarDao)
# Adding new node for method questionMarks(AvatarDao)
# Adding new node for method questionMarks(ShareDao)
# Adding new node for method update(ShareDao)
# Adding new node for method queryForInt(ShareDao)
# Adding new node for method query(ShareDao)
# Adding new node for method queryOne(ShareDao)
# Adding new node for method namedQuery(ShareDao)
# Adding new node for method query(BookmarkDao)
# Adding new node for method update(BookmarkDao)
# Adding new node for method questionMarks(BookmarkDao)
# Adding new node for method queryForInt(BookmarkDao)
# Adding new node for method query(MusicFolderDao)
# Adding new node for method queryOne(MusicFolderDao)
# Adding new node for method update(MusicFolderDao)
# Adding new node for method queryForInt(MusicFolderDao)
# Adding new node for method prefix(MusicFolderDao)
# Adding new node for method questionMarks(PodcastDao)
# Adding new node for method update(PodcastDao)
# Adding new node for method queryForInt(PodcastDao)
# Adding new node for method query(PodcastDao)
# Adding new node for method queryOne(PodcastDao)
# Adding new node for method query(TranscodingDao)
# Adding new node for method update(TranscodingDao)
# Adding new node for method queryForInt(TranscodingDao)
# Adding new node for method questionMarks(TranscodingDao)
# INFO: Edge ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'isAssignableFrom(MultipleCredsMatchingAuthenticationProvider)'] skipped
# INFO: Edge ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'equals(MultipleCredsMatchingAuthenticationProvider)'] skipped
# INFO: Edge ['additionalAuthenticationChecks(MultipleCredsMatchingAuthenticationProvider)', 'Calls', 'getPasswordEncoder(MultipleCredsMatchingAuthenticationProvider)'] skipped
# INFO: Edge ['parseSearchResult(LyricsWSController)', 'Calls', 'createSAXBuilder(LyricsWSController)'] skipped
# INFO: Edge ['doRefreshChannel(PodcastService)', 'Calls', 'createSAXBuilder(PodcastService)'] skipped
# INFO: Edge ['getCurrentUsername(SecurityService)', 'Calls', 'getRemoteUser(SecurityService)'] skipped
# INFO: Edge ['removeStreamStatus(StatusService)', 'Calls', 'compute(TransferStatus)'] skipped
# INFO: Edge ['removeStreamStatus(StatusService)', 'Calls', 'remove(TransferStatus)'] skipped
# INFO: Edge ['getAllStreamStatuses(StatusService)', 'Calls', 'values(TransferStatus)'] skipped
# INFO: Edge ['getStreamStatusesForPlayer(StatusService)', 'Calls', 'parallelStream(TransferStatus)'] skipped
# INFO: Edge ['getInactiveStreamStatusForPlayer(StatusService)', 'Calls', 'get(TransferStatus)'] skipped
# INFO: Edge ['removeDownloadStatus(StatusService)', 'Calls', 'remove(TransferStatus)'] skipped
# INFO: Edge ['removeUploadStatus(StatusService)', 'Calls', 'remove(TransferStatus)'] skipped
# INFO: Edge ['cleanupRemotePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)'] skipped
# INFO: Edge ['cleanupRemotePlays(StatusService)', 'Calls', 'remove(PlayStatus)'] skipped
# INFO: Edge ['addRemotePlay(StatusService)', 'Calls', 'add(PlayStatus)'] skipped
# INFO: Edge ['addActiveLocalPlay(StatusService)', 'Calls', 'add(PlayStatus)'] skipped
# INFO: Edge ['removeActiveLocalPlay(StatusService)', 'Calls', 'remove(PlayStatus)'] skipped
# INFO: Edge ['getActivePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)'] skipped
# INFO: Edge ['getInactivePlays(StatusService)', 'Calls', 'parallelStream(PlayStatus)'] skipped
# INFO: Edge ['getInactivePlays(StatusService)', 'Calls', 'values(TransferStatus)'] skipped
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'getResourceAsStream(SettingsService)'] skipped
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)'] skipped
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)'] skipped
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'add(Theme)'] skipped
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'toArray(Theme)'] skipped
# INFO: Edge ['getAvailableThemes(SettingsService)', 'Calls', 'size(Theme)'] skipped
# INFO: Edge ['getAvailableLocales(SettingsService)', 'Calls', 'getResourceAsStream(SettingsService)'] skipped
# INFO: Edge ['getAllMusicFolders(SettingsService)', 'Calls', 'parallelStream(MusicFolder)'] skipped
# INFO: Edge ['setMusicFoldersForUser(SettingsService)', 'Calls', 'remove(MusicFolder)'] skipped
# INFO: Edge ['clearMusicFolderCache(SettingsService)', 'Calls', 'clear(MusicFolder)'] skipped
# INFO: Edge ['createPlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped
# INFO: Edge ['createPlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped
# INFO: Edge ['addPlaylistUser(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped
# INFO: Edge ['deletePlaylistUser(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped
# INFO: Edge ['deletePlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped
# INFO: Edge ['updatePlaylist(PlaylistService)', 'Calls', 'runAsync(PlaylistService)'] skipped
# INFO: Edge ['getImportHandler(PlaylistService)', 'Calls', 'stream(DefaultPlaylistImportHandler)'] skipped
# INFO: Edge ['getExportHandler(PlaylistService)', 'Calls', 'stream(DefaultPlaylistExportHandler)'] skipped
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped
# INFO: Edge ['updateJukebox(JukeboxLegacySubsonicService)', 'Calls', 'pause(AudioPlayer)'] skipped
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'getState(AudioPlayer)'] skipped
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'play(AudioPlayer)'] skipped
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'close(AudioPlayer)'] skipped
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'setGain(AudioPlayer)'] skipped
# INFO: Edge ['play(JukeboxLegacySubsonicService)', 'Calls', 'play(AudioPlayer)'] skipped
# INFO: Edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped
# INFO: Edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped
# INFO: Edge ['stateChanged(JukeboxLegacySubsonicService)', 'Calls', 'getPlayQueue(Player)'] skipped
# INFO: Edge ['getPosition(JukeboxLegacySubsonicService)', 'Calls', 'getPosition(AudioPlayer)'] skipped
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'setFile(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'addBytesTransferred(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getId(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getPlayer(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxLegacySubsonicService)', 'Calls', 'getMillisSinceLastUpdate(TransferStatus)'] skipped
# INFO: Edge ['onSongEnd(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped
# INFO: Edge ['scrobble(JukeboxLegacySubsonicService)', 'Calls', 'getClientId(Player)'] skipped
# INFO: Edge ['scrobble(JukeboxLegacySubsonicService)', 'Calls', 'getUsername(Player)'] skipped
# INFO: Edge ['setGain(JukeboxLegacySubsonicService)', 'Calls', 'setGain(AudioPlayer)'] skipped
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'setFile(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'addBytesTransferred(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getId(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getPlayer(TransferStatus)'] skipped
# INFO: Edge ['onSongStart(JukeboxJavaService)', 'Calls', 'getMillisSinceLastUpdate(TransferStatus)'] skipped
# INFO: Edge ['play(JukeboxJavaService)', 'Calls', 'getCurrentAudioFile(JukeboxJavaService)'] skipped
# INFO: Edge ['register(AudioScrobblerService)', 'Calls', 'register(LastFMScrobbler)'] skipped
# INFO: Edge ['register(AudioScrobblerService)', 'Calls', 'register(ListenBrainzScrobbler)'] skipped
# INFO: Edge ['start(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['stop(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['skip(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['playShuffle(PlayQueueService)', 'Calls', 'equals(PlayQueueService)'] skipped
# INFO: Edge ['toggleRepeat(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['setJukeboxGain(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['setJukeboxPosition(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['broadcastPlayQueue(PlayQueueService)', 'Calls', 'runAsync(PlayQueueService)'] skipped
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'getClass(UPnPService)'] skipped
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] skipped
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] skipped
# INFO: Edge ['createMediaServerDevice(UPnPService)', 'Calls', 'read(UPnPService)'] skipped
# INFO: Edge ['setMusicServiceEnabled(SonosService)', 'Calls', 'setEnabled(SonosService)'] skipped
# INFO: Edge ['getSessionId(SonosService)', 'Calls', 'authenticate(MultipleCredsMatchingAuthenticationProvider)'] skipped
# INFO: Edge ['getUsername(SonosService)', 'Calls', 'getContext(SonosService)'] skipped
# INFO: Edge ['isDownsamplingSupported(TranscodingService)', 'Calls', 'equalsIgnoreCase(TranscodingService)'] skipped
# INFO: Edge ['clearInternetRadioSourceCache(InternetRadioService)', 'Calls', 'remove(InternetRadioSource)'] skipped
# INFO: Edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'containsKey(InternetRadioSource)'] skipped
# INFO: Edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'get(InternetRadioSource)'] skipped
# INFO: Edge ['getInternetRadioSources(InternetRadioService)', 'Calls', 'put(InternetRadioSource)'] skipped
# INFO: Edge ['isExcluded(MediaFileService)', 'Calls', 'equals(MediaFileService)'] skipped
# INFO: Edge ['createMediaFile(MediaFileService)', 'Calls', 'getMetaData(JaudiotaggerParser)'] skipped
# INFO: Edge ['createMediaFile(MediaFileService)', 'Calls', 'getMetaData(JaudiotaggerParser)'] skipped
# INFO: Edge ['getCoverArtUrl(SonosHelper)', 'Calls', 'getBaseUrl(SonosHelper)'] skipped
# INFO: Edge ['canHandle(XspfPlaylistImportHandler)', 'Calls', 'equals(XspfPlaylistImportHandler)'] skipped
# INFO: Edge ['canHandle(XspfPlaylistExportHandler)', 'Calls', 'equals(XspfPlaylistExportHandler)'] skipped
# INFO: Edge ['browseRoot(GenreUpnpProcessor)', 'Calls', 'createBrowseResult(GenreUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(GenreUpnpProcessor)', 'Calls', 'getRootId(GenreUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(GenreUpnpProcessor)', 'Calls', 'getRootId(GenreUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped
# INFO: Edge ['getChildren(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped
# INFO: Edge ['getChildren(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped
# INFO: Edge ['addChild(GenreUpnpProcessor)', 'Calls', 'getDispatcher(GenreUpnpProcessor)'] skipped
# INFO: Edge ['browseObjectMetadata(MediaFileUpnpProcessor)', 'Calls', 'createBrowseResult(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['createItem(MediaFileUpnpProcessor)', 'Calls', 'getDispatcher(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['getMediaFileService(MediaFileUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(MediaFileUpnpProcessor)'] skipped
# INFO: Edge ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'addItem(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['browseRoot(AlbumUpnpProcessor)', 'Calls', 'createBrowseResult(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(AlbumUpnpProcessor)', 'Calls', 'getRootId(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['getChildren(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['getChildren(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAllItemsSize(AlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['addChild(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAlbumArtURI(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['getMediaFileDao(AlbumUpnpProcessor)', 'Calls', 'getDispatcher(AlbumUpnpProcessor)'] skipped
# INFO: Edge ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] skipped
# INFO: Edge ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] skipped
# INFO: Edge ['search(DispatchingContentDirectory)', 'Calls', 'equalsIgnoreCase(DispatchingContentDirectory)'] skipped
# INFO: Edge ['createItem(DispatchingContentDirectory)', 'Calls', 'createResourceForSong(DispatchingContentDirectory)'] skipped
# INFO: Edge ['getAlbumArtUrl(DispatchingContentDirectory)', 'Calls', 'getBaseUrl(DispatchingContentDirectory)'] skipped
# INFO: Edge ['browseRootMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browsePlaylistRootMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browsePlaylistRoot(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browsePlaylistMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browsePlaylist(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browseRoot(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browseMediaFileMetadata(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['browseMediaFile(FolderBasedContentDirectory)', 'Calls', 'createBrowseResult(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['createItem(FolderBasedContentDirectory)', 'Calls', 'createResourceForSong(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['getAlbumArtUrl(FolderBasedContentDirectory)', 'Calls', 'getBaseUrl(FolderBasedContentDirectory)'] skipped
# INFO: Edge ['createContainer(PlaylistUpnpProcessor)', 'Calls', 'getRootId(PlaylistUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(PlaylistUpnpProcessor)', 'Calls', 'getRootId(PlaylistUpnpProcessor)'] skipped
# INFO: Edge ['getItemById(PlaylistUpnpProcessor)', 'Calls', 'getDispatcher(PlaylistUpnpProcessor)'] skipped
# INFO: Edge ['addChild(PlaylistUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(PlaylistUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RootUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RootUpnpProcessor)'] skipped
# INFO: Edge ['browseRoot(RecentAlbumUpnpProcessor)', 'Calls', 'addItem(RecentAlbumUpnpProcessor)'] skipped
# INFO: Edge ['browseRoot(RecentAlbumUpnpProcessor)', 'Calls', 'createBrowseResult(RecentAlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RecentAlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RecentAlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(RecentAlbumUpnpProcessor)', 'Calls', 'getAlbumDao(RecentAlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAllItemsSize(RecentAlbumUpnpProcessor)', 'Calls', 'getDispatchingContentDirectory(RecentAlbumUpnpProcessor)'] skipped
# INFO: Edge ['getAllItemsSize(RecentAlbumUpnpProcessor)', 'Calls', 'getAlbumDao(RecentAlbumUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(ArtistUpnpProcessor)', 'Calls', 'getRootId(ArtistUpnpProcessor)'] skipped
# INFO: Edge ['createContainer(ArtistUpnpProcessor)', 'Calls', 'getRootId(ArtistUpnpProcessor)'] skipped
# INFO: Edge ['getAllItems(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] skipped
# INFO: Edge ['getChildren(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] skipped
# INFO: Edge ['getAlbumProcessor(ArtistUpnpProcessor)', 'Calls', 'getDispatcher(ArtistUpnpProcessor)'] skipped
# INFO: Edge ['getAnalyzer(AnalyzerFactory)', 'Calls', 'isEmpty(AnalyzerFactory)'] skipped
# INFO: Edge ['getQueryAnalyzer(AnalyzerFactory)', 'Calls', 'isEmpty(AnalyzerFactory)'] skipped
# INFO: Edge ['search(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['getRandomSongs(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['getRandomAlbums(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['getRandomAlbumsId3(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['searchByName(SearchServiceImpl)', 'Calls', 'isEmpty(SearchServiceImpl)'] skipped
# INFO: Edge ['setMetaData(FFmpegParser)', 'Calls', 'getClass(FFmpegParser)'] skipped
# INFO: Edge ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessArtist(DefaultMetaDataParser)'] skipped
# INFO: Edge ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessAlbum(DefaultMetaDataParser)'] skipped
# INFO: Edge ['getRawMetaData(DefaultMetaDataParser)', 'Calls', 'guessTitle(DefaultMetaDataParser)'] skipped
# INFO: Edge ['getParser(MetaDataParserFactory)', 'Calls', 'stream(MetaDataParser)'] skipped
# INFO: Edge ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Calls', 'getResourceAsStream(RegisterPrecompiledJSPInitializer)'] skipped
# INFO: Edge ['parseXmlFragment(RegisterPrecompiledJSPInitializer)', 'Calls', 'getContext(RegisterPrecompiledJSPInitializer)'] skipped
# INFO: Edge ['handleRequest(StreamController)', 'Calls', 'equals(StreamController)'] skipped
# INFO: Edge ['getShoutcastDetails(StreamController)', 'Calls', 'start(StreamController)'] skipped
# INFO: Edge ['handlePost(ImportPlaylistController)', 'Calls', 'equals(ImportPlaylistController)'] skipped
# INFO: Added edge ['expunge(MusicFolderSettingsController)', 'Calls', 'checkpoint(MediaFileDao)']
# INFO: Edge ['sendFallback(CoverArtController)', 'Calls', 'getClass(CoverArtController)'] skipped
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] skipped
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] skipped
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'equals(StatusChartController)'] skipped
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'getBackground(StatusChartController)'] skipped
# INFO: Edge ['handleRequest(StatusChartController)', 'Calls', 'getForeground(StatusChartController)'] skipped
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getIntParameter(HomeController)'] skipped
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getStringParameter(HomeController)'] skipped
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getIntParameter(HomeController)'] skipped
# INFO: Edge ['handleRequestInternal(HomeController)', 'Calls', 'getStringParameter(HomeController)'] skipped
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped
# INFO: Edge ['createDataset(UserChartController)', 'Calls', 'equals(UserChartController)'] skipped
# INFO: Edge ['createChart(UserChartController)', 'Calls', 'getBackground(UserChartController)'] skipped
# INFO: Edge ['createChart(UserChartController)', 'Calls', 'getForeground(UserChartController)'] skipped
# INFO: Edge ['handleRequestInternal(UploadController)', 'Calls', 'equals(UploadController)'] skipped
# INFO: Edge ['handleRequestInternal(UploadController)', 'Calls', 'equals(UploadController)'] skipped
# INFO: Edge ['unzip(UploadController)', 'Calls', 'createArchiveInputStream(UploadController)'] skipped
# INFO: Edge ['prepareResponse(DownloadController)', 'Calls', 'start(DownloadController)'] skipped
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'getDisplayName(PersonalSettingsController)'] skipped
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'equals(PersonalSettingsController)'] skipped
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'getId(PersonalSettingsController)'] skipped
# INFO: Edge ['formBackingObject(PersonalSettingsController)', 'Calls', 'equals(PersonalSettingsController)'] skipped
# INFO: Edge ['ping(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getLicense(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getLicense(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getMusicFolders(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getIndexes(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getGenres(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSongsByGenre(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getArtists(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSimilarSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSimilarSongs2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getTopSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getArtistInfo(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getArtistInfo2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbArtist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getArtist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getArtist(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbAlbum(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbAlbum(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbPlaylist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbPlaylist(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getAlbum(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbum(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getSong(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getSong(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getMusicDirectory(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['search(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['search3(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getPlaylists(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getPlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getPlaylist(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'getRequiredFloatParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['jukeboxControl(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createPlaylist(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createPlaylist(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['updatePlaylist(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['deletePlaylist(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'equals(SubsonicRESTController)'] skipped
# INFO: Edge ['getAlbumList2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getRandomSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getRandomSongs(SubsonicRESTController)', 'Calls', 'getStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getRandomSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getRandomSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getRandomSongs(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getRandomSongs(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getVideos(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getVideos(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getVideos(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getNowPlaying(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbChild(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbChild(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['apiException(SubsonicRESTController)', 'Calls', 'serializeForType(JAXBWriter)'] skipped
# INFO: Edge ['apiException(SubsonicRESTController)', 'Calls', 'createErrorResponse(JAXBWriter)'] skipped
# INFO: Edge ['hls(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['scrobble(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['scrobble(SubsonicRESTController)', 'Calls', 'getRequiredIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['scrobble(SubsonicRESTController)', 'Calls', 'getLongParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['starOrUnstar(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['starOrUnstar(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['starOrUnstar(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['getStarred(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getStarred(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getStarred2(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getStarred2(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getPodcasts(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getPodcasts(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getPodcasts(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getNewestPodcasts(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getNewestPodcasts(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbPodcastEpisode(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createPodcastChannel(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['deletePodcastChannel(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['deletePodcastEpisode(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['downloadPodcastEpisode(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getInternetRadioStations(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getBookmarks(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getBookmarks(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getBookmarks(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createBookmark(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createBookmark(SubsonicRESTController)', 'Calls', 'getRequiredLongParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['deleteBookmark(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getPlayQueue(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['getPlayQueue(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['savePlayQueue(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getShares(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createShare(SubsonicRESTController)', 'Calls', 'getRequiredIntParameters(SubsonicRESTController)'] skipped
# INFO: Edge ['createShare(SubsonicRESTController)', 'Calls', 'getLongParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createShare(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['deleteShare(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['updateShare(SubsonicRESTController)', 'Calls', 'getRequiredIntParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createJaxbShare(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbShare(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['createJaxbShare(SubsonicRESTController)', 'Calls', 'convertDate(JAXBWriter)'] skipped
# INFO: Edge ['changePassword(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['changePassword(SubsonicRESTController)', 'Calls', 'decrypt(SubsonicRESTController)'] skipped
# INFO: Edge ['changePassword(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['getUser(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['getUsers(SubsonicRESTController)', 'Calls', 'writeResponse(JAXBWriter)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'decrypt(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getRequiredStringParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# INFO: Edge ['createUser(SubsonicRESTController)', 'Calls', 'getBooleanParameter(SubsonicRESTController)'] skipped
# ...
# INFO: Added edge ['deleteTranscoding(TranscodingDao)', 'Calls', 'update(TranscodingDao)']
# INFO: Added edge ['updateTranscoding(TranscodingDao)', 'Calls', 'update(TranscodingDao)']
# INFO: Added edge [ 'checkpoint(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryForStrings(RatingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(RatingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(RatingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForDouble(RatingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(RatingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryForInt(RatingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForStrings(PlaylistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedUpdate(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForStrings(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(UserDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayerDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryForInt(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInstant(AlbumDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInstant(ArtistDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(PlayQueueDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryOne(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryOne(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'batchedUpdate(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'batchedUpdate(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryForInt(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryForInt(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQueryForInt(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInstant(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInts(MediaFileDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(InternetRadioDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(InternetRadioDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(InternetRadioDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(InternetRadioDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(InternetRadioDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(AvatarDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(AvatarDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(AvatarDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AvatarDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(AvatarDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(AvatarDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'namedQuery(ShareDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(BookmarkDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(BookmarkDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(BookmarkDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(BookmarkDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(BookmarkDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(BookmarkDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'prefix(MusicFolderDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryOne(PodcastDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'query(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'update(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'queryForInt(TranscodingDao)', 'Persists', 'AbstractDao']
# INFO: Added edge [ 'questionMarks(TranscodingDao)', 'Persists', 'AbstractDao']

# %% [markdown]
# ## 12. Write the resulting graph
#
# The graph will be written and displayed as image. It will contains all the nodes and edges from the _nodes.csv_ and _edges.csv_ files.

# %%
# Draw graph

def DrawInitialGraph(G):
    global DrawG
    global project
    scale = 50
    DrawG = pygv.AGraph(directed=True, strict='true', splines='true')

    for i in G.nodes():
        if G.nodes[i]['type'] == 'Entity':
            DrawG.add_node(i, shape='hexagon', label=G.nodes[i]['name'])
        else:
            DrawG.add_node(i, shape='circle', label=G.nodes[i]['name'])

    for i in G.edges():
        edge_color = 'black' if G[i[0]][i[1]]['rel_type'] in ['Calls', 'Persists', 'References'] else 'gray'
        DrawG.add_edge(i[0], i[1], color=edge_color, label=G[i[0]][i[1]]['rel_type'], fontsize='8')

    DrawG.layout(prog='dot')
    DrawG.draw(analysis_results_basedir + project + '_graph.png')

with open(analysis_results_basedir + project + '_nodes.csv', 'r') as nodes_file, open(analysis_results_basedir + project + '_edges.csv', 'r') as edges_file:
    nodes_csv = csv.reader(nodes_file, delimiter=',')
    edges_csv = csv.reader(edges_file, delimiter=',')

    G = nx.DiGraph()

    for node in nodes_csv:
        num = int(node[0])
        name = node[2]
        if node[1] == 'Method':
            class_name = node[3]
            G.add_node(num, name=name, type=node[1], class_name=class_name)
        elif node[1] == 'Entity':
            G.add_node(num, name=name, type=node[1])

    for edge in edges_csv:
        G.add_edge(int(edge[0]), int(edge[2]), rel_type=edge[1])


if not headless:
    DrawInitialGraph(G)
    display(Image(filename = analysis_results_basedir + project + '_graph.png'))

# %% [markdown]
# ## 13. Clean the graph and export as .gml file
#
# If the graph contains isolated nodes, they can be removed.

# %% [markdown]
# ### _Configuration!_
#
# Set the _remove_isolated_ variable to **True** if you want to remove the isolated nodes from the graph

# %%
remove_isolated = True # <-- Set this variable!

if remove_isolated:
    if not nx.is_weakly_connected(G):
        isolating_nodes = list(nx.isolates(G))

        for node in isolating_nodes:
            if G.nodes[node]['type']=='Entity':
                print('Removed Entity ' + G.nodes[node]['name'])
            else:
                print('Removed ' + G.nodes[node]['name'] + ' (' + G.nodes[node]['class_name'] + ')')

        G.remove_nodes_from(isolating_nodes)

        if not headless:
            DrawInitialGraph(G)
            display(Image(filename = analysis_results_basedir + project + '_graph.png'))

    else:
        print('The graph is connected')
# Out:
# Removed Entity TomcatApplication
# Removed Entity PasswordEncoderDecoderWrapper
# Removed Entity AesGcmPasswordEncoder
# Removed Entity JWTAuthenticationProvider
# Removed Entity JWTRequestParameterProcessingFilter
# Removed Entity ParameterDecodingFilter
# Removed Entity BootstrapVerificationFilter
# Removed Entity RequestEncodingFilter
# Removed Entity MetricsFilter
# Removed Entity ResponseHeaderFilter
# Removed Entity NATPMPRouter
# Removed Entity FieldNames
# Removed Entity Util
# Removed Entity FileUtil
# Removed Entity StringUtil
# Removed Entity XMLUtil
# Removed Entity ParamSearchResult
# Removed Entity DbmsVersionPrecondition
# Removed Entity CustomPropertySourceConfigurer
# Removed Entity LoggingFileOverrideListener
# Removed Entity HsqlDatabase
# Removed Entity AbstractChartController
# Removed Entity ControllerUtils
# Removed Entity ParamTag
# Removed Entity FormatBytesTag
# Removed Entity EscapeJavaScriptTag
# Removed Entity UrlTag
# Removed Entity CredentialsManagementValidators
# Removed Entity InputStreamReaderThread
# Removed Entity PipeStreams
# Removed mapUserToContext (CustomUserDetailsContextMapper)
# Removed matches (CsrfSecurityRequestMatcher)
# Removed setSecurityService (MultipleCredsMatchingAuthenticationProvider)
# Removed setUserDetailsService (MultipleCredsMatchingAuthenticationProvider)
# Removed setPasswordEncoder (MultipleCredsMatchingAuthenticationProvider)
# Removed setMediaFileService (TagWSController)
# Removed setMetaDataParserFactory (TagWSController)
# Removed setPlaylistService (PlaylistWSController)
# Removed setMediaFileService (PlaylistWSController)
# Removed setMediaFileDao (PlaylistWSController)
# Removed setSettingsService (PlaylistWSController)
# Removed setPlayerService (PlaylistWSController)
# Removed setLocaleResolver (PlaylistWSController)
# Removed setSecurityService (CoverArtWSController)
# Removed setMediaFileService (CoverArtWSController)
# Removed setLastFmService (CoverArtWSController)
# Removed setSettingsService (UserSettingsWSController)
# Removed setMediaFileDao (StarWSController)
# Removed parseDate (PodcastService)
# Removed formatDuration (PodcastService)
# Removed getITunesElement (PodcastService)
# Removed setPodcastDao (PodcastService)
# Removed setSettingsService (PodcastService)
# Removed setSecurityService (PodcastService)
# Removed setMediaFileService (PodcastService)
# Removed setMetaDataParserFactory (PodcastService)
# Removed setSettingsService (SecurityService)
# Removed setUserDao (SecurityService)
# Removed setMediaFileService (StatusService)
# Removed setSettingsService (StatusService)
# Removed setMessagingTemplate (StatusService)
# Removed getLogFile (SettingsService)
# Removed isDevelopmentMode (SettingsService)
# Removed setInternetRadioDao (SettingsService)
# Removed setMusicFolderDao (SettingsService)
# Removed setUserDao (SettingsService)
# Removed setAvatarDao (SettingsService)
# Removed setEnvironment (SettingsService)
# Removed setTranscodingService (JukeboxLegacySubsonicService)
# Removed setAudioScrobblerService (JukeboxLegacySubsonicService)
# Removed setStatusService (JukeboxLegacySubsonicService)
# Removed setSettingsService (JukeboxLegacySubsonicService)
# Removed setSecurityService (JukeboxLegacySubsonicService)
# Removed setMediaFileService (JukeboxLegacySubsonicService)
# Removed setSecurityService (ShareService)
# Removed setShareDao (ShareService)
# Removed setMediaFileService (ShareService)
# Removed setJwtSecurityService (ShareService)
# Removed generateKey (JWTSecurityService)
# Removed getAlgorithm (JWTSecurityService)
# Removed createToken (JWTSecurityService)
# Removed setSettingsService (AudioScrobblerService)
# Removed setSecurityService (AudioScrobblerService)
# Removed setRatingDao (RatingService)
# Removed setSecurityService (RatingService)
# Removed setMediaFileService (RatingService)
# Removed setStatusService (PlayerService)
# Removed setSecurityService (PlayerService)
# Removed setPlayerDao (PlayerService)
# Removed setTranscodingService (PlayerService)
# Removed getUpnpService (UPnPService)
# Removed setSettingsService (UPnPService)
# Removed getLastUpdate (SonosService)
# Removed setSonosHelper (SonosService)
# Removed rateItem (SonosService)
# Removed getStreamingMetadata (SonosService)
# Removed getExtendedMetadataText (SonosService)
# Removed getDeviceLinkCode (SonosService)
# Removed reportAccountAction (SonosService)
# Removed setPlayedSeconds (SonosService)
# Removed reportPlaySeconds (SonosService)
# Removed getDeviceAuthToken (SonosService)
# Removed reportStatus (SonosService)
# Removed getScrollIndices (SonosService)
# Removed reportPlayStatus (SonosService)
# Removed getContentKey (SonosService)
# Removed setMediaFileService (SonosService)
# Removed setSettingsService (SonosService)
# Removed setUpnpService (SonosService)
# Removed setPlaylistService (SonosService)
# Removed setSettingsService (MusicIndexService)
# Removed setMediaFileService (MusicIndexService)
# Removed setTranscodingDao (TranscodingService)
# Removed setSettingsService (TranscodingService)
# Removed setPlayerService (TranscodingService)
# Removed setMediaFileDao (LastFmService)
# Removed setMediaFileService (LastFmService)
# Removed setArtistDao (LastFmService)
# Removed setMemoryCacheEnabled (MediaFileService)
# Removed getMemoryCacheEnabled (MediaFileService)
# Removed setSecurityService (MediaFileService)
# Removed setSettingsService (MediaFileService)
# Removed setMediaFileDao (MediaFileService)
# Removed setMetaDataParserFactory (MediaFileService)
# Removed setAlbumDao (MediaFileService)
# Removed setParser (MediaFileService)
# Removed setPlaylistService (SonosHelper)
# Removed setPlayerService (SonosHelper)
# Removed setTranscodingService (SonosHelper)
# Removed setMediaFileService (SonosHelper)
# Removed setSettingsService (SonosHelper)
# Removed setMusicIndexService (SonosHelper)
# Removed setMediaFileDao (SonosHelper)
# Removed setSearchService (SonosHelper)
# Removed setRatingService (SonosHelper)
# Removed setLastFmService (SonosHelper)
# Removed setPodcastService (SonosHelper)
# Removed canHandle (DefaultPlaylistImportHandler)
# Removed getOrder (DefaultPlaylistImportHandler)
# Removed canHandle (DefaultPlaylistExportHandler)
# Removed getOrder (DefaultPlaylistExportHandler)
# Removed getOrder (XspfPlaylistImportHandler)
# Removed canHandle (XspfPlaylistExportHandler)
# Removed getOrder (XspfPlaylistExportHandler)
# Removed getMediaFileDao (MediaFileUpnpProcessor)
# Removed setMediaFileDao (MediaFileUpnpProcessor)
# Removed setAlbumDao (AlbumUpnpProcessor)
# Removed setPlaylistProcessor (DispatchingContentDirectory)
# Removed setMediaFileProcessor (DispatchingContentDirectory)
# Removed setAlbumProcessor (DispatchingContentDirectory)
# Removed setRecentAlbumProcessor (DispatchingContentDirectory)
# Removed setArtistProcessor (DispatchingContentDirectory)
# Removed setGenreProcessor (DispatchingContentDirectory)
# Removed setRootProcessor (DispatchingContentDirectory)
# Removed getMediaFileService (DispatchingContentDirectory)
# Removed setMediaFileService (DispatchingContentDirectory)
# Removed getSettingsService (DispatchingContentDirectory)
# Removed getPlaylistService (DispatchingContentDirectory)
# Removed setPlaylistService (DispatchingContentDirectory)
# Removed getJwtSecurityService (DispatchingContentDirectory)
# Removed getMusicIndexService (DispatchingContentDirectory)
# Removed setMusicIndexService (DispatchingContentDirectory)
# Removed getSearchService (DispatchingContentDirectory)
# Removed setSearchService (DispatchingContentDirectory)
# Removed setMediaFileService (FolderBasedContentDirectory)
# Removed setPlaylistService (FolderBasedContentDirectory)
# Removed setPlaylistService (PlaylistUpnpProcessor)
# Removed createContainer (RootUpnpProcessor)
# Removed addChild (RootUpnpProcessor)
# Removed setArtistDao (ArtistUpnpProcessor)
# Removed deleteOldIndexFiles (IndexManager)
# Removed initializeIndexDirectory (IndexManager)
# Removed isEditingSupported (FFmpegParser)
# Removed getSettingsService (FFmpegParser)
# Removed setTranscodingService (FFmpegParser)
# Removed setSettingsService (FFmpegParser)
# Removed getID3V1Genres (JaudiotaggerParser)
# Removed isEditingSupported (JaudiotaggerParser)
# Removed getSettingsService (JaudiotaggerParser)
# Removed isEditingSupported (DefaultMetaDataParser)
# Removed getSettingsService (DefaultMetaDataParser)
# Removed isApplicable (DefaultMetaDataParser)
# Removed resolveException (LoggingExceptionResolver)
# Removed getOrder (LoggingExceptionResolver)
# Removed setBasenamePrefix (CustomThemeSource)
# Removed setSettingsService (CustomThemeSource)
# Removed setThemeName (CustomThemeResolver)
# Removed setSecurityService (CustomThemeResolver)
# Removed setSettingsService (CustomThemeResolver)
# Removed notFound (NotFoundController)
# Removed handleGet (ImportPlaylistController)
# Removed get (RatingJspController)
# Removed setSettingsService (DLNASettingsController)
# Removed setUpnpService (DLNASettingsController)
# Removed displayForm (MusicFolderSettingsController)
# Removed handleRequestInternal (AllmusicController)
# Removed displayForm (SearchController)
# Removed get (CoverArtJspController)
# Removed handleRequestInternal (LyricsController)
# Removed accessDenied (AccessDeniedController)
# Removed computeCrc (DownloadController)
# Removed setSettingsService (SonosSettingsController)
# Removed setSonosService (SonosSettingsController)
# Removed handleRequest (ProxyController)
# Removed displayForm (PersonalSettingsController)
# Removed apiException (SubsonicRESTController)
# Removed getChatMessages (SubsonicRESTController)
# Removed addChatMessage (SubsonicRESTController)
# Removed getVideoInfo (SubsonicRESTController)
# Removed getCaptions (SubsonicRESTController)
# Removed displayForm (GeneralSettingsController)
# Removed displayForm (DatabaseSettingsController)
# Removed setLocale (LocaleResolver)
# Removed setSecurityService (LocaleResolver)
# Removed setSettingsService (LocaleResolver)
# Removed markPresent (MediaFileDao)
# Removed setUserDao (MusicFolderDao)

# %%
nx.write_graphml(G, analysis_results_basedir + project + '_graph.gml')
